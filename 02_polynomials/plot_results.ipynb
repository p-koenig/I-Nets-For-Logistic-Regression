# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

import seaborn as sns

sns.set_style("darkgrid")

# %%
lambda_net_results_d3_n5_noNoise = {'mae': 0.013, 'r2': 0.994, 'std_error': 0.017}
lambda_net_results_d3_n5_Noise01 = {'mae': 0.035, 'r2': 0.964, 'std_error': 0.045}
lambda_net_results_d3_n5_Noise02 = {'mae': 0.054, 'r2': 0.915, 'std_error': 0.069}
lambda_net_results_d3_n5_Noise03 = {'mae': 0.069, 'r2': 0.858, 'std_error': 0.086}

lambda_net_results_d3_n10_noNoise = {'mae': 0.026, 'r2': 0.988, 'std_error': 0.034}
lambda_net_results_d3_n10_Noise01 = {'mae': 0.068, 'r2': 0.921, 'std_error': 0.088}
lambda_net_results_d3_n10_Noise02 = {'mae': 0.095, 'r2': 0.839, 'std_error': 0.121}
lambda_net_results_d3_n10_Noise03 = {'mae': 0.115, 'r2': 0.743, 'std_error': 0.145}

lambda_net_results_d3_n15_noNoise = {'mae': 0.044, 'r2': 0.974, 'std_error': 0.058}
lambda_net_results_d3_n15_Noise01 = {'mae': 0.094, 'r2': 0.891, 'std_error': 0.120}
lambda_net_results_d3_n15_Noise02 = {'mae': 0.129, 'r2': 0.777, 'std_error': 0.164}
lambda_net_results_d3_n15_Noise03 = {'mae': 0.151, 'r2': 0.666, 'std_error': 0.190}

# %%
#inet_results_d3_n5_noNoise = {'mae': 0.157, 'r2': 0.272, 'std_error': 0.182}
#inet_results_d3_n5_Noise01 = {'mae': 0.163, 'r2': 0.274, 'std_error': 0.189}
#inet_results_d3_n5_Noise02 = {'mae': 0.166, 'r2': 0.232, 'std_error': 0.185}
#inet_results_d3_n5_Noise03 = {'mae': 0.167, 'r2': 0.167, 'std_error': 0.185}

#inet_results_d3_n10_noNoise = {'mae': 0.233, 'r2': 0.158, 'std_error': 0.287}
#inet_results_d3_n10_Noise01 = {'mae': 0.243, 'r2': 0.092, 'std_error': 0.289}
#inet_results_d3_n10_Noise02 = {'mae': 0.244, 'r2': 0.061, 'std_error': 0.285}
#inet_results_d3_n10_Noise03 = {'mae': 0.248, 'r2': 0.001, 'std_error': 0.281}

#inet_results_d3_n15_noNoise = {'mae': 0.281, 'r2': 0.106, 'std_error': 0.345}
#inet_results_d3_n15_Noise01 = {'mae': 0.286, 'r2': 0.080, 'std_error': 0.347}
#inet_results_d3_n15_Noise02 = {'mae': 0.281, 'r2': 0.065, 'std_error': 0.337}
#inet_results_d3_n15_Noise03 = {'mae': 0.278, 'r2': 0.026, 'std_error': 0.329}

# %%
inet_train_time_d3_n5_noNoise = {'lambda_net_training': np.nan, 'interpretation_net_training': np.nan, 'application': np.array([0 for i in range(100)])}
inet_train_time_d3_n5_Noise01 = {'lambda_net_training': 0, 'interpretation_net_training': 0, 'application': np.array([0 for i in range(100)])}
inet_train_time_d3_n5_Noise02 = {'lambda_net_training': 0, 'interpretation_net_training': 0, 'application': np.array([0 for i in range(100)])}
inet_train_time_d3_n5_Noise03 = {'lambda_net_training': 0, 'interpretation_net_training': 0, 'application': np.array([0 for i in range(100)])}

inet_train_time_d3_n10_noNoise = {'lambda_net_training': np.nan, 'interpretation_net_training': np.nan, 'application': np.array([0 for i in range(100)])}
inet_train_time_d3_n10_Noise01 = {'lambda_net_training': 0, 'interpretation_net_training': 0, 'application': np.array([0 for i in range(100)])}
inet_train_time_d3_n10_Noise02 = {'lambda_net_training': 0, 'interpretation_net_training': 0, 'application': np.array([0 for i in range(100)])}
inet_train_time_d3_n10_Noise03 = {'lambda_net_training': 0, 'interpretation_net_training': 0, 'application': np.array([0 for i in range(100)])}

inet_train_time_d3_n15_noNoise = {'lambda_net_training': np.nan, 'interpretation_net_training': np.nan, 'application': np.array([0 for i in range(100)])}
inet_train_time_d3_n15_Noise01 = {'lambda_net_training': 0, 'interpretation_net_training': 0, 'application': np.array([0 for i in range(100)])}
inet_train_time_d3_n15_Noise02 = {'lambda_net_training': 0, 'interpretation_net_training': 0, 'application': np.array([0 for i in range(100)])}
inet_train_time_d3_n15_Noise03 = {'lambda_net_training': 0, 'interpretation_net_training': 0, 'application': np.array([0 for i in range(100)])}

# %%
inet_results_single_lambda_net_d3_n5_noNoise = {'mae': np.array([]), 
                               'r2': np.array([])}
inet_results_single_lambda_net_d3_n5_Noise01 = {'mae': np.array([]), 
                               'r2': np.array([])}
inet_results_single_lambda_net_d3_n5_Noise02 = {'mae': np.array([]), 
                               'r2': np.array([])}
inet_results_single_lambda_net_d3_n5_Noise03 = {'mae': np.array([]), 
                               'r2': np.array([])}

inet_results_single_lambda_net_d3_n10_noNoise = {'mae': np.array([]), 
                                'r2': np.array([])}
inet_results_single_lambda_net_d3_n10_Noise01 = {'mae': np.array([]), 
                               'r2': np.array([])}
inet_results_single_lambda_net_d3_n10_Noise02 = {'mae': np.array([]), 
                               'r2': np.array([])}
inet_results_single_lambda_net_d3_n10_Noise03 = {'mae': np.array([]), 
                               'r2': np.array([])}

inet_results_single_lambda_net_d3_n15_noNoise = {'mae': np.array([]), 
                               'r2': np.array([])}
inet_results_single_lambda_net_d3_n15_Noise01 = {'mae': np.array([]), 
                               'r2': np.array([])}
inet_results_single_lambda_net_d3_n15_Noise02 = {'mae': np.array([]), 
                               'r2': np.array([])}
inet_results_single_lambda_net_d3_n15_Noise03 = {'mae': np.array([]), 
                               'r2': np.array([])}

# %%
#average time for a single network interpretation in seconds
#symbolic_regression_train_time_d3_n5_noNoise = {'application': 61.9*5*60/100}
symbolic_regression_train_time_d3_n5_noNoise = {'application': np.array([])}
symbolic_regression_train_time_d3_n5_Noise01 = {'application': np.array([])}
symbolic_regression_train_time_d3_n5_Noise02 = {'application': np.array([])}
symbolic_regression_train_time_d3_n5_Noise03 = {'application': np.array([])}

#symbolic_regression_train_time_d3_n10_noNoise = {'application': 169.3*5*60/100}
symbolic_regression_train_time_d3_n10_noNoise = {'application': np.array([])} 
symbolic_regression_train_time_d3_n10_Noise01 = {'application': np.array([])}
symbolic_regression_train_time_d3_n10_Noise02 = {'application': np.array([])}
symbolic_regression_train_time_d3_n10_Noise03 = {'application': np.array([])}

symbolic_regression_train_time_d3_n15_noNoise = {'application': np.array([])}
symbolic_regression_train_time_d3_n15_Noise01 = {'application': np.array([])}
symbolic_regression_train_time_d3_n15_Noise02 = {'application': np.array([])}
symbolic_regression_train_time_d3_n15_Noise03 = {'application': np.array([])}

# %%
symbolic_regression_results_single_lambda_net_d3_n5_noNoise = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_regression_results_single_lambda_net_d3_n5_Noise01 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_regression_results_single_lambda_net_d3_n5_Noise02 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_regression_results_single_lambda_net_d3_n5_Noise03 = {'mae': np.array([]), 
                                                   'r2': np.array([])}

symbolic_regression_results_single_lambda_net_d3_n10_noNoise = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_regression_results_single_lambda_net_d3_n10_Noise01 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_regression_results_single_lambda_net_d3_n10_Noise02 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_regression_results_single_lambda_net_d3_n10_Noise03 = {'mae': np.array([]), 
                                                   'r2': np.array([])}

symbolic_regression_results_single_lambda_net_d3_n15_noNoise = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_regression_results_single_lambda_net_d3_n15_Noise01 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_regression_results_single_lambda_net_d3_n15_Noise02 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_regression_results_single_lambda_net_d3_n15_Noise03 = {'mae': np.array([]), 
                                                   'r2': np.array([])}

# %%
#average time for a single network interpretation in seconds
symbolic_metamodeling_train_time_d3_n5_noNoise = {'application': np.array([])}
symbolic_metamodeling_train_time_d3_n5_Noise01 = {'application': 0}
symbolic_metamodeling_train_time_d3_n5_Noise02 = {'application': 0}
symbolic_metamodeling_train_time_d3_n5_Noise03 = {'application': 0}

symbolic_metamodeling_train_time_d3_n10_noNoise = {'application': np.array([])}
symbolic_metamodeling_train_time_d3_n10_Noise01 = {'application': 0}
symbolic_metamodeling_train_time_d3_n10_Noise02 = {'application': 0}
symbolic_metamodeling_train_time_d3_n10_Noise03 = {'application': 0}

symbolic_metamodeling_train_time_d3_n15_noNoise = {'application': np.array([])}
symbolic_metamodeling_train_time_d3_n15_Noise01 = {'application': 0}
symbolic_metamodeling_train_time_d3_n15_Noise02 = {'application': 0}
symbolic_metamodeling_train_time_d3_n15_Noise03 = {'application': 0}

# %%
symbolic_metamodeling_results_single_lambda_net_d3_n5_noNoise = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_metamodeling_results_single_lambda_net_d3_n5_Noise01 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_metamodeling_results_single_lambda_net_d3_n5_Noise02 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_metamodeling_results_single_lambda_net_d3_n5_Noise03 = {'mae': np.array([]), 
                                                   'r2': np.array([])}

symbolic_metamodeling_results_single_lambda_net_d3_n10_noNoise = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_metamodeling_results_single_lambda_net_d3_n10_Noise01 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_metamodeling_results_single_lambda_net_d3_n10_Noise02 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_metamodeling_results_single_lambda_net_d3_n10_Noise03 = {'mae': np.array([]), 
                                                   'r2': np.array([])}

symbolic_metamodeling_results_single_lambda_net_d3_n15_noNoise = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_metamodeling_results_single_lambda_net_d3_n15_Noise01 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_metamodeling_results_single_lambda_net_d3_n15_Noise02 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_metamodeling_results_single_lambda_net_d3_n15_Noise03 = {'mae': np.array([]), 
                                                   'r2': np.array([])}

# %%
common_labels = ['Interpretation Network', 'Symbolic Regression', 'Symbolic Metamodeling']

evaluate_different_variable_numbers_labels = ['5', '10', '15']#['n=5', 'n=10', 'n=15']
evaluate_different_variable_numbers = [[inet_results_d3_n5_noNoise['mae'], symbolic_regression_results_d3_n5_noNoise['mae'], symbolic_metamodeling_results_d3_n5_noNoise['mae']], 
                                      [inet_results_d3_n10_noNoise['mae'], symbolic_regression_results_d3_n10_noNoise['mae'], symbolic_metamodeling_results_d3_n10_noNoise['mae']], 
                                      [inet_results_d3_n15_noNoise['mae'], symbolic_regression_results_d3_n15_noNoise['mae'], symbolic_metamodeling_results_d3_n15_noNoise['mae']]]
evaluate_different_variable_numbers_df = pd.DataFrame(evaluate_different_variable_numbers, columns=common_labels, index=evaluate_different_variable_numbers_labels)


evaluate_different_variable_numbers_runtime = [[inet_train_time_d3_n5_noNoise['application'], symbolic_regression_train_time_d3_n5_noNoise['application'], symbolic_metamodeling_train_time_d3_n5_noNoise['application']], 
                                      [inet_train_time_d3_n10_noNoise['application'], symbolic_regression_train_time_d3_n10_noNoise['application'], symbolic_metamodeling_train_time_d3_n10_noNoise['application']], 
                                      [inet_train_time_d3_n15_noNoise['application'], symbolic_regression_train_time_d3_n15_noNoise['application'], symbolic_metamodeling_train_time_d3_n15_noNoise['application']]]
evaluate_different_variable_numbers_runtime_df = pd.DataFrame(evaluate_different_variable_numbers_runtime, columns=common_labels, index=evaluate_different_variable_numbers_labels)
#evaluate_different_variable_numbers_runtime_df = evaluate_different_variable_numbers_runtime_df[['Symbolic Regression', 'Symbolic Metamodeling']]


evaluate_different_variable_numbers_labels = ['0', '0.1', '0.2', '0.3']#['noise=0', 'noise=0.1', 'noise=0.2', 'noise=0.3']
evaluate_noise_for_fixed_variable_number_n5 = [[inet_results_d3_n5_noNoise['mae'], symbolic_regression_results_d3_n5_noNoise['mae'], symbolic_metamodeling_results_d3_n5_noNoise['mae']],
                                            [inet_results_d3_n5_Noise01['mae'], symbolic_regression_results_d3_n5_Noise01['mae'], symbolic_metamodeling_results_d3_n5_Noise01['mae']],
                                            [inet_results_d3_n5_Noise02['mae'], symbolic_regression_results_d3_n5_Noise02['mae'], symbolic_metamodeling_results_d3_n5_Noise02['mae']],
                                            [inet_results_d3_n5_Noise03['mae'], symbolic_regression_results_d3_n5_Noise03['mae'], symbolic_metamodeling_results_d3_n5_Noise03['mae']]] 
evaluate_noise_for_fixed_variable_number_df_n5 = pd.DataFrame(evaluate_noise_for_fixed_variable_number_n5, columns=common_labels, index=evaluate_different_variable_numbers_labels)
#evaluate_noise_for_fixed_variable_number_df_n5 = evaluate_noise_for_fixed_variable_number_df_n5[['Interpretation Network']]

evaluate_noise_for_fixed_variable_number_n10 = [[inet_results_d3_n10_noNoise['mae'], symbolic_regression_results_d3_n10_noNoise['mae'], symbolic_metamodeling_results_d3_n10_noNoise['mae']],
                                            [inet_results_d3_n10_Noise01['mae'], symbolic_regression_results_d3_n10_Noise01['mae'], symbolic_metamodeling_results_d3_n10_Noise01['mae']],
                                            [inet_results_d3_n10_Noise02['mae'], symbolic_regression_results_d3_n10_Noise02['mae'], symbolic_metamodeling_results_d3_n10_Noise02['mae']],
                                            [inet_results_d3_n10_Noise03['mae'], symbolic_regression_results_d3_n10_Noise03['mae'], symbolic_metamodeling_results_d3_n10_Noise03['mae']]] 
evaluate_noise_for_fixed_variable_number_df_n10 = pd.DataFrame(evaluate_noise_for_fixed_variable_number_n10, columns=common_labels, index=evaluate_different_variable_numbers_labels)
#evaluate_noise_for_fixed_variable_number_df_n10 = evaluate_noise_for_fixed_variable_number_df_n10[['Interpretation Network']]


evaluate_noise_for_fixed_variable_number_n15 = [[inet_results_d3_n15_noNoise['mae'], symbolic_regression_results_d3_n15_noNoise['mae'], symbolic_metamodeling_results_d3_n15_noNoise['mae']],
                                            [inet_results_d3_n15_Noise01['mae'], symbolic_regression_results_d3_n15_Noise01['mae'], symbolic_metamodeling_results_d3_n15_Noise01['mae']],
                                            [inet_results_d3_n15_Noise02['mae'], symbolic_regression_results_d3_n15_Noise02['mae'], symbolic_metamodeling_results_d3_n15_Noise02['mae']],
                                            [inet_results_d3_n15_Noise03['mae'], symbolic_regression_results_d3_n15_Noise03['mae'], symbolic_metamodeling_results_d3_n15_Noise03['mae']]] 
evaluate_noise_for_fixed_variable_number_df_n15 = pd.DataFrame(evaluate_noise_for_fixed_variable_number_n15, columns=common_labels, index=evaluate_different_variable_numbers_labels)
#evaluate_noise_for_fixed_variable_number_df_n15 = evaluate_noise_for_fixed_variable_number_df_n15[['Interpretation Network']]



evaluate_noise_for_fixed_variable_number_columns = ['n=5', 'n=10', 'n=15']#['n=5', 'n=10', 'n=15']
evaluate_noise_for_fixed_variable_number = [[inet_results_d3_n5_noNoise['mae'], inet_results_d3_n10_noNoise['mae'], inet_results_d3_n15_noNoise['mae']],
                                            [inet_results_d3_n5_Noise01['mae'], inet_results_d3_n10_Noise01['mae'], inet_results_d3_n15_Noise01['mae']],
                                            [inet_results_d3_n5_Noise02['mae'], inet_results_d3_n10_Noise02['mae'], inet_results_d3_n15_Noise02['mae']],
                                            [inet_results_d3_n5_Noise03['mae'], inet_results_d3_n10_Noise03['mae'], inet_results_d3_n15_Noise03['mae']]] 
evaluate_noise_for_fixed_variable_number_df = pd.DataFrame(evaluate_noise_for_fixed_variable_number, columns=evaluate_noise_for_fixed_variable_number_columns, index=evaluate_different_variable_numbers_labels)



evaluate_different_variable_numbers_single_lambda_net_n5 = [inet_results_single_lambda_net_d3_n5_noNoise['mae'], symbolic_regression_results_single_lambda_net_d3_n5_noNoise['mae'], symbolic_metamodeling_results_single_lambda_net_d3_n5_noNoise['mae']]
evaluate_different_variable_numbers_single_lambda_net_filled_n5 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_n5).fillna(0).values.T
evaluate_different_variable_numbers_single_lambda_net_df_n5 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_filled_n5, columns=common_labels)

evaluate_different_variable_numbers_single_lambda_net_n10 = [inet_results_single_lambda_net_d3_n10_noNoise['mae'], symbolic_regression_results_single_lambda_net_d3_n10_noNoise['mae'], symbolic_metamodeling_results_single_lambda_net_d3_n10_noNoise['mae']] 
evaluate_different_variable_numbers_single_lambda_net_filled_n10 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_n10).fillna(0).values.T
evaluate_different_variable_numbers_single_lambda_net_df_n10 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_filled_n10, columns=common_labels)

evaluate_different_variable_numbers_single_lambda_net_n15 = [inet_results_single_lambda_net_d3_n15_noNoise['mae'], symbolic_regression_results_single_lambda_net_d3_n15_noNoise['mae'], symbolic_metamodeling_results_single_lambda_net_d3_n15_noNoise['mae']]
evaluate_different_variable_numbers_single_lambda_net_filled_n15 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_n15).fillna(0).values.T
evaluate_different_variable_numbers_single_lambda_net_df_n15 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_filled_n15, columns=common_labels)


evaluate_different_variable_numbers_single_lambda_net_diff_labels = ['Interpretation Network - Symbolic Regression', 'Interpretation Network - Symbolic Metamodeling']

evaluate_different_variable_numbers_single_lambda_net_diff_n5 = [inet_results_single_lambda_net_d3_n5_noNoise['mae'], symbolic_regression_results_single_lambda_net_d3_n5_noNoise['mae'], symbolic_metamodeling_results_single_lambda_net_d3_n5_noNoise['mae']]
evaluate_different_variable_numbers_single_lambda_net_filled_diff_n5 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_diff_n5).fillna(0).values.T
evaluate_different_variable_numbers_single_lambda_net_filled_diff_n5 = np.array([evaluate_different_variable_numbers_single_lambda_net_filled_diff_n5[:,1:2].ravel()-evaluate_different_variable_numbers_single_lambda_net_filled_diff_n5[:,:1].ravel(), evaluate_different_variable_numbers_single_lambda_net_filled_diff_n5[:,2:3].ravel()-evaluate_different_variable_numbers_single_lambda_net_filled_diff_n5[:,:1].ravel()]).T
evaluate_different_variable_numbers_single_lambda_net_diff_df_n5 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_filled_diff_n5, columns=evaluate_different_variable_numbers_single_lambda_net_diff_labels)

evaluate_different_variable_numbers_single_lambda_net_diff_n10 = [inet_results_single_lambda_net_d3_n10_noNoise['mae'], symbolic_regression_results_single_lambda_net_d3_n10_noNoise['mae'], symbolic_metamodeling_results_single_lambda_net_d3_n10_noNoise['mae']] 
evaluate_different_variable_numbers_single_lambda_net_filled_diff_n10 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_diff_n10).fillna(0).values.T
evaluate_different_variable_numbers_single_lambda_net_filled_diff_n10 = np.array([evaluate_different_variable_numbers_single_lambda_net_filled_diff_n10[:,1:2].ravel()-evaluate_different_variable_numbers_single_lambda_net_filled_diff_n10[:,:1].ravel(), evaluate_different_variable_numbers_single_lambda_net_filled_diff_n10[:,2:3].ravel()-evaluate_different_variable_numbers_single_lambda_net_filled_diff_n10[:,:1].ravel()]).T
evaluate_different_variable_numbers_single_lambda_net_diff_df_n10 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_filled_diff_n10, columns=evaluate_different_variable_numbers_single_lambda_net_diff_labels)
    
evaluate_different_variable_numbers_single_lambda_net_diff_n15 = [inet_results_single_lambda_net_d3_n15_noNoise['mae'], symbolic_regression_results_single_lambda_net_d3_n15_noNoise['mae'], symbolic_metamodeling_results_single_lambda_net_d3_n15_noNoise['mae']]
evaluate_different_variable_numbers_single_lambda_net_filled_diff_n15 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_diff_n15).fillna(0).values.T
evaluate_different_variable_numbers_single_lambda_net_filled_diff_n15 = np.array([evaluate_different_variable_numbers_single_lambda_net_filled_diff_n15[:,1:2].ravel()-evaluate_different_variable_numbers_single_lambda_net_filled_diff_n15[:,:1].ravel(), evaluate_different_variable_numbers_single_lambda_net_filled_diff_n15[:,2:3].ravel()-evaluate_different_variable_numbers_single_lambda_net_filled_diff_n15[:,:1].ravel()]).T
evaluate_different_variable_numbers_single_lambda_net_diff_df_n15 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_filled_diff_n15, columns=evaluate_different_variable_numbers_single_lambda_net_diff_labels)

# %%
legend_fontsize = 25
label_fontsize = 35
plot_fontsize = 30

figsize = (20, 12)
legend_loc = 2

color_1 = '#84b7e9'#'#c0d6ff'
color_2 = '#0a6fd3'#'#96bcff'
color_3 = '#06427e'#'#6ca1ff'

# %%
evaluate_different_variable_numbers_df
# Out:
#     Interpretation Network  Symbolic Regression  Symbolic Metamodeling
# 5                    0.157                0.077                  0.549
# 10                   0.233                0.152                  0.564
# 15                   0.281                0.213                  0.584

# %%
axes = evaluate_different_variable_numbers_df.plot.bar(color={common_labels[0]:color_1, common_labels[1]:color_2, common_labels[2]:color_3}, 
                                                       rot=0, 
                                                       figsize=figsize, 
                                                       fontsize=plot_fontsize)

axes.legend(fontsize=legend_fontsize, loc = legend_loc) # loc=2
axes.set_xlabel('Number of Variables', fontsize=label_fontsize)
axes.set_ylabel('MAE', fontsize=label_fontsize)
#plt.title('Performance Comparison', fontsize=30)

plt.savefig('./evaluation_results/performance_comparison.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_noise_for_fixed_variable_number_df
# Out:
#        n=5   n=10   n=15
# 0    0.157  0.233  0.281
# 0.1  0.163  0.243  0.286
# 0.2  0.166  0.244  0.281
# 0.3  0.167  0.248  0.278

# %%
axes = evaluate_noise_for_fixed_variable_number_df.plot.bar(color={evaluate_noise_for_fixed_variable_number_columns[0]:color_1, evaluate_noise_for_fixed_variable_number_columns[1]:color_2, evaluate_noise_for_fixed_variable_number_columns[2]:color_3}, 
                                                       rot=0, 
                                                       figsize=figsize, 
                                                       fontsize=plot_fontsize)

axes.legend(fontsize=legend_fontsize, loc = legend_loc) # loc=2
axes.set_xlabel('Noise Level', fontsize=label_fontsize)
axes.set_ylabel('MAE', fontsize=label_fontsize)
#plt.title('Performance Comparison', fontsize=30)

plt.savefig('./evaluation_results/noise_evaluation.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_noise_for_fixed_variable_number_df_n5
# Out:
#      Interpretation Network  Symbolic Regression  Symbolic Metamodeling
# 0                     0.157                0.077                  0.549
# 0.1                   0.163                0.000                  0.000
# 0.2                   0.166                0.000                  0.000
# 0.3                   0.167                0.000                  0.000

# %%
axes = evaluate_noise_for_fixed_variable_number_df_n5.plot.bar(color={common_labels[0]:color_1, common_labels[1]:color_2, common_labels[2]:color_3}, 
                                                               rot=0, 
                                                               figsize=figsize, 
                                                               fontsize=plot_fontsize)

axes.legend(fontsize=legend_fontsize, loc = legend_loc) # loc=2
axes.set_xlabel('Noise', fontsize=label_fontsize)
axes.set_ylabel('MAE', fontsize=label_fontsize)
#plt.title('Noise Evaluation n=5', fontsize=30)

plt.savefig('./evaluation_results/noise_evaluation_n5.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_noise_for_fixed_variable_number_df_n10
# Out:
#      Interpretation Network  Symbolic Regression  Symbolic Metamodeling
# 0                     0.233                0.152                  0.564
# 0.1                   0.243                0.000                  0.000
# 0.2                   0.244                0.000                  0.000
# 0.3                   0.248                0.000                  0.000

# %%
axes = evaluate_noise_for_fixed_variable_number_df_n10.plot.bar(color={common_labels[0]:color_1, common_labels[1]:color_2, common_labels[2]:color_3}, 
                                                                rot=0, 
                                                                figsize=figsize, 
                                                                fontsize=plot_fontsize)

axes.legend(fontsize=legend_fontsize, loc = legend_loc) # loc=2
axes.set_xlabel('Noise', fontsize=label_fontsize)
axes.set_ylabel('MAE', fontsize=label_fontsize)
#plt.title('Noise Evaluation n=10', fontsize=30)

plt.savefig('./evaluation_results/noise_evaluation_n10.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_noise_for_fixed_variable_number_df_n15
# Out:
#      Interpretation Network  Symbolic Regression  Symbolic Metamodeling
# 0                     0.281                0.213                  0.584
# 0.1                   0.286                0.000                  0.000
# 0.2                   0.281                0.000                  0.000
# 0.3                   0.278                0.000                  0.000

# %%
axes = evaluate_noise_for_fixed_variable_number_df_n15.plot.bar(color={common_labels[0]:color_1, common_labels[1]:color_2, common_labels[2]:color_3}, 
                                                                rot=0, 
                                                                figsize=figsize, 
                                                                fontsize=plot_fontsize)

axes.legend(fontsize=legend_fontsize, loc = legend_loc) # loc=2
axes.set_xlabel('Noise', fontsize=label_fontsize)
axes.set_ylabel('MAE', fontsize=label_fontsize)
#plt.title('Noise Evaluation n=15', fontsize=30)

plt.savefig('./evaluation_results/noise_evaluation_n15.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_different_variable_numbers_runtime_df
# Out:
#     Interpretation Network  Symbolic Regression  Symbolic Metamodeling
# 5                        0               141.78                1457.40
# 10                       0               192.60                3494.04
# 15                       0               439.50                4018.08

# %%
axes = evaluate_different_variable_numbers_runtime_df.plot.line(color={common_labels[0]:color_1, common_labels[1]:color_2, common_labels[2]:color_3}, 
                                                                rot=0, 
                                                                figsize=figsize, 
                                                                fontsize=plot_fontsize, 
                                                                linewidth=5)

axes.legend(fontsize=legend_fontsize, loc = legend_loc) # loc=2
axes.set_xlabel('Number of Variables', fontsize=label_fontsize)
axes.set_ylabel('Seconds per Interpretation', fontsize=label_fontsize)
#plt.title('Runtime Evaluation', fontsize=30)

plt.savefig('./evaluation_results/runtime_evaluation.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
axes = evaluate_different_variable_numbers_runtime_df[['Symbolic Regression', 'Interpretation Network']].plot.line(color={common_labels[0]:color_1, common_labels[1]:color_2, common_labels[2]:color_3}, 
                                                                rot=0, 
                                                                figsize=figsize, 
                                                                fontsize=plot_fontsize, 
                                                                linewidth=5)

axes.legend(fontsize=legend_fontsize, loc = legend_loc) # loc=2
axes.set_ylim(bottom=-20) 
axes.set_xlabel('Number of Variables', fontsize=label_fontsize)
axes.set_ylabel('Seconds per Interpretation', fontsize=label_fontsize)
plt.title('Symbolic Regression', fontsize=40)

plt.savefig('./evaluation_results/runtime_evaluation_reg.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
axes = evaluate_different_variable_numbers_runtime_df[['Symbolic Metamodeling', 'Interpretation Network']].plot.line(color={common_labels[0]:color_1, common_labels[1]:color_2, common_labels[2]:color_3}, 
                                                                rot=0, 
                                                                figsize=figsize, 
                                                                fontsize=plot_fontsize, 
                                                                linewidth=5)

axes.legend(fontsize=legend_fontsize, loc = legend_loc) # loc=2
axes.set_ylim(bottom=-100) 
axes.set_xlabel('Nuber of Variables', fontsize=label_fontsize)
axes.set_ylabel('Seconds per Interpretation', fontsize=label_fontsize)
plt.title('Symbolic Metamodeling', fontsize=40)

plt.savefig('./evaluation_results/runtime_evaluation_meta.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_different_variable_numbers_single_lambda_net_df_n5
# Out:
#     Interpretation Network  Symbolic Regression  Symbolic Metamodeling
# 0                 0.102526             0.080183               0.631814
# 1                 0.144517             0.045093               0.242610
# 2                 0.152643             0.109433               0.877605
# 3                 0.077680             0.052660               0.762354
# 4                 0.148420             0.058121               0.234193
# ..                     ...                  ...                    ...
# 95                0.057691             0.058276               0.435640
# 96                0.196734             0.091035               0.291498
# 97                0.237417             0.114639               0.530119
# 98                0.117612             0.056064               0.326320
# 99                0.099475             0.083200               0.582696
#
# [100 rows x 3 columns]

# %%
axes = evaluate_different_variable_numbers_single_lambda_net_df_n5.plot.hist(bins=20, 
                                                                      #alpha=0.5,
                                                                      stacked=True,
                                                                      color={common_labels[0]:color_1, common_labels[1]:color_2, common_labels[2]:color_3}, 
                                                                      #color={common_labels[0]:'#c0d6ff', common_labels[1]:'#96bcff', common_labels[2]:'#6ca1ff'}, 
                                                                      rot=0, 
                                                                      figsize=figsize, 
                                                                      fontsize=plot_fontsize, 
                                                                      linewidth=5)

axes.legend(fontsize=legend_fontsize, loc = legend_loc) # loc=2
axes.set_xlabel('Error', fontsize=label_fontsize)
axes.set_ylabel('Frequency', fontsize=label_fontsize)
#plt.title('Runtime Evaluation', fontsize=30)

plt.savefig('./evaluation_results/error_hist_n5.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
axes = evaluate_different_variable_numbers_single_lambda_net_df_n5[['Interpretation Network', 'Symbolic Regression']].plot.hist(bins=20, 
                                                                      #alpha=0.5,
                                                                      stacked=True,
                                                                      color={common_labels[0]:color_1, common_labels[1]:color_2, common_labels[2]:color_3}, 
                                                                      #color={common_labels[0]:'#c0d6ff', common_labels[1]:'#96bcff', common_labels[2]:'#6ca1ff'}, 
                                                                      rot=0, 
                                                                      figsize=figsize, 
                                                                      fontsize=plot_fontsize, 
                                                                      linewidth=5)

axes.legend(fontsize=legend_fontsize, loc = legend_loc) # loc=2
axes.set_xlabel('Error', fontsize=label_fontsize)
axes.set_ylabel('Frequency', fontsize=label_fontsize)
#plt.title('Runtime Evaluation', fontsize=30)

plt.savefig('./evaluation_results/error_hist_n5.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_different_variable_numbers_single_lambda_net_df_n10
# Out:
#     Interpretation Network  Symbolic Regression  Symbolic Metamodeling
# 0                 0.303234             0.132253               0.431521
# 1                 0.243829             0.160833               0.438265
# 2                 0.186619             0.112357               0.641834
# 3                 0.250109             0.113758               0.247600
# 4                 0.169298             0.134679               0.000000
# ..                     ...                  ...                    ...
# 95                0.258260             0.161688               0.591513
# 96                0.269929             0.166182               0.879401
# 97                0.255533             0.159679               0.780040
# 98                0.277904             0.157502               0.000000
# 99                0.187257             0.163503               0.570925
#
# [100 rows x 3 columns]

# %%
axes = evaluate_different_variable_numbers_single_lambda_net_df_n10.plot.hist(bins=20, 
                                                                      #alpha=0.5,
                                                                      stacked=True,
                                                                      color={common_labels[0]:color_1, common_labels[1]:color_2, common_labels[2]:color_3}, 
                                                                      rot=0, 
                                                                      figsize=figsize, 
                                                                      fontsize=plot_fontsize, 
                                                                      linewidth=5)

axes.legend(fontsize=legend_fontsize, loc = legend_loc) # loc=2
axes.set_xlabel('Error', fontsize=label_fontsize)
axes.set_ylabel('Frequency', fontsize=label_fontsize)
#plt.title('Runtime Evaluation', fontsize=30)

plt.savefig('./evaluation_results/error_hist_n10.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_different_variable_numbers_single_lambda_net_df_n15
# Out:
#     Interpretation Network  Symbolic Regression  Symbolic Metamodeling
# 0                 0.263322             0.231295               0.400228
# 1                 0.193792             0.190581               0.475198
# 2                 0.172251             0.245194               0.401668
# 3                 0.298602             0.183764               0.392481
# 4                 0.210676             0.176348               0.748318
# ..                     ...                  ...                    ...
# 95                0.302891             0.188944               0.803805
# 96                0.230453             0.137813               0.821675
# 97                0.339452             0.155094               0.454616
# 98                0.367081             0.227223               0.930738
# 99                0.204295             0.166457               0.695381
#
# [100 rows x 3 columns]

# %%
axes = evaluate_different_variable_numbers_single_lambda_net_df_n15.plot.hist(bins=20, 
                                                                      #alpha=0.5,
                                                                      stacked=True,                                                                              
                                                                      color={common_labels[0]:color_1, common_labels[1]:color_2, common_labels[2]:color_3}, 
                                                                      rot=0, 
                                                                      figsize=figsize, 
                                                                      fontsize=plot_fontsize, 
                                                                      linewidth=5)

axes.legend(fontsize=legend_fontsize, loc = legend_loc) # loc=2
axes.set_xlabel('Error', fontsize=label_fontsize)
axes.set_ylabel('Frequency', fontsize=label_fontsize)
#plt.title('Runtime Evaluation', fontsize=30)

plt.savefig('./evaluation_results/error_hist_n15.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_different_variable_numbers_single_lambda_net_diff_df_n5
# Out:
#     Interpretation Network - Symbolic Regression  \
# 0                                      -0.022343
# 1                                      -0.099424
# 2                                      -0.043210
# 3                                      -0.025020
# 4                                      -0.090299
# ..                                           ...
# 95                                      0.000586
# 96                                     -0.105699
# 97                                     -0.122778
# 98                                     -0.061548
# 99                                     -0.016275
#
#     Interpretation Network - Symbolic Metamodeling
# 0                                         0.529288
# 1                                         0.098093
# 2                                         0.724962
# 3                                         0.684675
# 4                                         0.085773
# ..                                             ...
# ...

# %%
axes = evaluate_different_variable_numbers_single_lambda_net_diff_df_n5.plot.hist(bins=20, 
                                                                      #alpha=0.5,
                                                                      stacked=True,                                                                                  
                                                                      color={evaluate_different_variable_numbers_single_lambda_net_diff_labels[0]:color_1, evaluate_different_variable_numbers_single_lambda_net_diff_labels[1]:color_2}, 
                                                                      rot=0, 
                                                                      figsize=figsize, 
                                                                      fontsize=plot_fontsize, 
                                                                      linewidth=5)

axes.legend(fontsize=legend_fontsize, loc = legend_loc) # loc=2
axes.set_xlabel('Error', fontsize=label_fontsize)
axes.set_ylabel('Frequency', fontsize=label_fontsize)
plt.title('n=5', fontsize=40)

plt.savefig('./evaluation_results/error_diff_hist_n5.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
axes = evaluate_different_variable_numbers_single_lambda_net_diff_df_n5['Interpretation Network - Symbolic Regression'].plot.hist(bins=[i/100 for i in range(-60, 20, 5)],#20, 
                                                                      #alpha=0.5,
                                                                      stacked=True,                                                                                  
                                                                      color={evaluate_different_variable_numbers_single_lambda_net_diff_labels[0]:color_1, evaluate_different_variable_numbers_single_lambda_net_diff_labels[1]:color_2}, 
                                                                      rot=0, 
                                                                      figsize=figsize, 
                                                                      fontsize=plot_fontsize, 
                                                                      linewidth=5)

axes.legend(fontsize=legend_fontsize, loc = legend_loc) # loc=2
axes.set_xlabel('Error', fontsize=label_fontsize)
axes.set_ylabel('Frequency', fontsize=label_fontsize)
plt.title('n=5', fontsize=40)

plt.savefig('./evaluation_results/error_diff_hist_n5_inet_symReg.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_different_variable_numbers_single_lambda_net_diff_df_n10
# Out:
#     Interpretation Network - Symbolic Regression  \
# 0                                      -0.170981
# 1                                      -0.082996
# 2                                      -0.074262
# 3                                      -0.136351
# 4                                      -0.034619
# ..                                           ...
# 95                                     -0.096572
# 96                                     -0.103747
# 97                                     -0.095854
# 98                                     -0.120402
# 99                                     -0.023753
#
#     Interpretation Network - Symbolic Metamodeling
# 0                                         0.128287
# 1                                         0.194436
# 2                                         0.455214
# 3                                        -0.002509
# 4                                        -0.169298
# ..                                             ...
# ...

# %%
axes = evaluate_different_variable_numbers_single_lambda_net_diff_df_n10.plot.hist(bins=20, 
                                                                      #alpha=0.5,
                                                                      stacked=True,                                                                                   
                                                                      color={evaluate_different_variable_numbers_single_lambda_net_diff_labels[0]:color_1, evaluate_different_variable_numbers_single_lambda_net_diff_labels[1]:color_2}, 
                                                                      rot=0, 
                                                                      figsize=figsize, 
                                                                      fontsize=plot_fontsize, 
                                                                      linewidth=5)

axes.legend(fontsize=legend_fontsize, loc = legend_loc) # loc=2
axes.set_xlabel('Error', fontsize=label_fontsize)
axes.set_ylabel('Frequency', fontsize=label_fontsize)
plt.title('n=10', fontsize=40)

plt.savefig('./evaluation_results/error_diff_hist_n10.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
axes = evaluate_different_variable_numbers_single_lambda_net_diff_df_n10['Interpretation Network - Symbolic Regression'].plot.hist(bins=[i/100 for i in range(-60, 20, 5)],#20, 
                                                                      #alpha=0.5,
                                                                      stacked=True,                                                                                   
                                                                      color={evaluate_different_variable_numbers_single_lambda_net_diff_labels[0]:color_1, evaluate_different_variable_numbers_single_lambda_net_diff_labels[1]:color_2}, 
                                                                      rot=0, 
                                                                      figsize=figsize, 
                                                                      fontsize=plot_fontsize, 
                                                                      linewidth=5)

axes.legend(fontsize=legend_fontsize, loc = legend_loc) # loc=2
axes.set_xlabel('Error', fontsize=label_fontsize)
axes.set_ylabel('Frequency', fontsize=label_fontsize)
plt.title('n=10', fontsize=40)

plt.savefig('./evaluation_results/error_diff_hist_n10_inet_symReg.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_different_variable_numbers_single_lambda_net_diff_df_n15
# Out:
#     Interpretation Network - Symbolic Regression  \
# 0                                      -0.032027
# 1                                      -0.003210
# 2                                       0.072943
# 3                                      -0.114838
# 4                                      -0.034328
# ..                                           ...
# 95                                     -0.113947
# 96                                     -0.092640
# 97                                     -0.184358
# 98                                     -0.139858
# 99                                     -0.037838
#
#     Interpretation Network - Symbolic Metamodeling
# 0                                         0.136905
# 1                                         0.281406
# 2                                         0.229417
# 3                                         0.093880
# 4                                         0.537642
# ..                                             ...
# ...

# %%
axes = evaluate_different_variable_numbers_single_lambda_net_diff_df_n15.plot.hist(bins=20, 
                                                                      #alpha=0.5,
                                                                      stacked=True,                                                                                   
                                                                      color={evaluate_different_variable_numbers_single_lambda_net_diff_labels[0]:color_1, evaluate_different_variable_numbers_single_lambda_net_diff_labels[1]:color_2}, 
                                                                      rot=0, 
                                                                      figsize=figsize, 
                                                                      fontsize=plot_fontsize, 
                                                                      linewidth=5)

axes.legend(fontsize=legend_fontsize, loc = legend_loc) # loc=2
axes.set_xlabel('Error', fontsize=label_fontsize)
axes.set_ylabel('Frequency', fontsize=label_fontsize)
plt.title('n=15', fontsize=40)

plt.savefig('./evaluation_results/error_diff_hist_n15.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
axes = evaluate_different_variable_numbers_single_lambda_net_diff_df_n15['Interpretation Network - Symbolic Regression'].plot.hist(bins=[i/100 for i in range(-60, 20, 5)],#20, 
                                                                      #alpha=0.5,
                                                                      stacked=True,                                                                                   
                                                                      color={evaluate_different_variable_numbers_single_lambda_net_diff_labels[0]:color_1, evaluate_different_variable_numbers_single_lambda_net_diff_labels[1]:color_2}, 
                                                                      rot=0, 
                                                                      figsize=figsize, 
                                                                      fontsize=plot_fontsize, 
                                                                      linewidth=5)

axes.legend(fontsize=legend_fontsize, loc = legend_loc) # loc=2
axes.set_xlabel('Error', fontsize=label_fontsize)
axes.set_ylabel('Frequency', fontsize=label_fontsize)
plt.title('n=15', fontsize=40)

plt.savefig('./evaluation_results/error_diff_hist_n15_inet_symReg.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_different_variable_numbers_single_lambda_net_df_n15
# Out:
#     Interpretation Network  Symbolic Regression  Symbolic Metamodeling
# 0                 0.263322             0.231295               0.400228
# 1                 0.193792             0.190581               0.475198
# 2                 0.172251             0.245194               0.401668
# 3                 0.298602             0.183764               0.392481
# 4                 0.210676             0.176348               0.748318
# ..                     ...                  ...                    ...
# 95                0.302891             0.188944               0.803805
# 96                0.230453             0.137813               0.821675
# 97                0.339452             0.155094               0.454616
# 98                0.367081             0.227223               0.930738
# 99                0.204295             0.166457               0.695381
#
# [100 rows x 3 columns]

# %%
identifier_row
# Out:
# array(['n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5',
#        'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5',
#        'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5',
#        'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5',
#        'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5',
#        'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5',
#        'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5',
#        'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5',
#        'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5',
#        'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5',
#        'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5', 'n=5',
#        'n=5', 'n=10', 'n=10', 'n=10', 'n=10', 'n=10', 'n=10', 'n=10',
#        'n=10', 'n=10', 'n=10', 'n=10', 'n=10', 'n=10', 'n=10', 'n=10',
# ...

# %%
evaluate_different_variable_numbers_single_lambda_net_df_rows_np.shape
# Out:
# (900, 1)

# %%
identifier_row_type.shape
# Out:
# (900, 1)

# %%
identifier_row_variables.shape
# Out:
# (900, 1)

# %%
np.concatenate([evaluate_different_variable_numbers_single_lambda_net_df_rows_np, identifier_row_type, identifier_row_variables], axis=1)
# Out:
# array([['0.10252578', 'Interpretation Network', 'n=5'],
#        ['0.14451668', 'Interpretation Network', 'n=5'],
#        ['0.15264297', 'Interpretation Network', 'n=5'],
#        ...,
#        ['0.45461607', 'Symbolic Metamodeling', 'n=15'],
#        ['0.9307379', 'Symbolic Metamodeling', 'n=15'],
#        ['0.69538087', 'Symbolic Metamodeling', 'n=15']], dtype='<U32')

# %%
identifier_row_variables = np.array([[['n=5'] * 100*3], [['n=10'] * 100*3], [['n=15'] * 100*3]]).flatten().reshape(-1,1)
identifier_row_type = np.array([[[['Interpretation Network'] * 100], [['Symbolic Regression'] * 100], [['Symbolic Metamodeling'] * 100]]*3]).flatten().reshape(-1,1)


evaluate_different_variable_numbers_single_lambda_net_df_rows_np = np.concatenate([evaluate_different_variable_numbers_single_lambda_net_df_n5[['Interpretation Network']], 
                                                                           evaluate_different_variable_numbers_single_lambda_net_df_n5[['Symbolic Regression']],
                                                                           evaluate_different_variable_numbers_single_lambda_net_df_n5[['Symbolic Metamodeling']],
                                                                           evaluate_different_variable_numbers_single_lambda_net_df_n10[['Interpretation Network']],
                                                                           evaluate_different_variable_numbers_single_lambda_net_df_n10[['Symbolic Regression']],
                                                                           evaluate_different_variable_numbers_single_lambda_net_df_n10[['Symbolic Metamodeling']],
                                                                           evaluate_different_variable_numbers_single_lambda_net_df_n15[['Interpretation Network']],
                                                                           evaluate_different_variable_numbers_single_lambda_net_df_n15[['Symbolic Regression']],
                                                                           evaluate_different_variable_numbers_single_lambda_net_df_n15[['Symbolic Metamodeling']]],
                                                                     axis=0).flatten().reshape(-1,1)
evaluate_different_variable_numbers_single_lambda_net_df_rows = pd.DataFrame(data=np.concatenate([evaluate_different_variable_numbers_single_lambda_net_df_rows_np, identifier_row_type, identifier_row_variables], axis=1), columns=['MAE', 'Approach', 'Variables'])

evaluate_different_variable_numbers_single_lambda_net_df_rows['MAE'] = evaluate_different_variable_numbers_single_lambda_net_df_rows['MAE'].astype('float')

evaluate_different_variable_numbers_single_lambda_net_df_rows.head()
# Out:
#         MAE                Approach Variables
# 0  0.102526  Interpretation Network       n=5
# 1  0.144517  Interpretation Network       n=5
# 2  0.152643  Interpretation Network       n=5
# 3  0.077680  Interpretation Network       n=5
# 4  0.148420  Interpretation Network       n=5

# %%
sns.set(rc={'figure.figsize':(25, 12)})
sns.set(font_scale=3)

sns_plot = sns.boxplot(x="Variables", 
            y="MAE",
            hue="Approach", 
            palette=[color_1, color_2, color_3],
            data=evaluate_different_variable_numbers_single_lambda_net_df_rows)
#sns.despine(offset=10, trim=True)
sns_plot.get_figure().savefig('./evaluation_results/error_boxplot_complete_grouped.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_different_variable_numbers_single_lambda_net_df = evaluate_different_variable_numbers_single_lambda_net_df_n15.rename(columns={"Interpretation Network": "Interpretation \n Network \n n=15",
                                                                                                                                         "Symbolic Regression": "Symbolic \n Regression \n n=15",
                                                                                                                                         "Symbolic Metamodeling": "Symbolic \n Metamodeling \n n=15"})
evaluate_different_variable_numbers_single_lambda_net_df = pd.concat([evaluate_different_variable_numbers_single_lambda_net_df, 
                                                                      evaluate_different_variable_numbers_single_lambda_net_df_n10.rename(columns={"Interpretation Network": "Interpretation \n Network \n n=10",
                                                                                                                                                 "Symbolic Regression": "Symbolic \n Regression \n n=10",
                                                                                                                                                 "Symbolic Metamodeling": "Symbolic \n Metamodeling \n n=10"})],
                                                                     axis=1)
evaluate_different_variable_numbers_single_lambda_net_df = pd.concat([evaluate_different_variable_numbers_single_lambda_net_df, 
                                                                      evaluate_different_variable_numbers_single_lambda_net_df_n5.rename(columns={"Interpretation Network": "Interpretation \n Network \n n=5",
                                                                                                                                                 "Symbolic Regression": "Symbolic \n Regression \n n=5",
                                                                                                                                                 "Symbolic Metamodeling": "Symbolic \n Metamodeling \n n=5"})],
                                                                     axis=1)

# %%
evaluate_different_variable_numbers_single_lambda_net_df
# Out:
#     Interpretation \n Network \n n=15  Symbolic \n Regression \n n=15  \
# 0                            0.263322                        0.231295
# 1                            0.193792                        0.190581
# 2                            0.172251                        0.245194
# 3                            0.298602                        0.183764
# 4                            0.210676                        0.176348
# ..                                ...                             ...
# 95                           0.302891                        0.188944
# 96                           0.230453                        0.137813
# 97                           0.339452                        0.155094
# 98                           0.367081                        0.227223
# 99                           0.204295                        0.166457
#
#     Symbolic \n Metamodeling \n n=15  Interpretation \n Network \n n=10  \
# ...

# %%
boxprops = dict(linestyle='-', 
                linewidth=3, 
                color=color_1
               )
medianprops = dict(linestyle='-', 
                   linewidth=2, 
                   color=color_2
                  )
flierprops = dict(#linestyle='-', 
                #linewidth=2, 
                #color='red'
               )
whiskerprops = dict(linestyle='-', 
                   linewidth=3, 
                   color=color_1
                  )
capprops = dict(linestyle='-', 
                   linewidth=3, 
                   color=color_1
                  )

figsize_boxplot = (30, 12) 
boxplot_fontsize = 25

axes = evaluate_different_variable_numbers_single_lambda_net_df.plot.box(
                                                                      #color={common_labels[0]:color_1, common_labels[1]:color_2, common_labels[2]:color_3}, 
                                                                      #color={common_labels[0]:'#c0d6ff', common_labels[1]:'#96bcff', common_labels[2]:'#6ca1ff'}, 
                                                                      #ot=0, 
                                                                      figsize=figsize_boxplot, 
                                                                      fontsize=boxplot_fontsize,
                                                                      boxprops=boxprops,
                                                                      medianprops=medianprops,
                                                                      #lierprops=flierprops,
                                                                      whiskerprops=whiskerprops,
                                                                      capprops=capprops,
                                                                      )

axes.set_ylabel('Error', fontsize=label_fontsize)

plt.savefig('./evaluation_results/error_boxplot_complete.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
X_data = np.array([])


inet_poly_fv = np.array([])

lambda_net_fv = np.array([])

target_function_fv = np.array([])

symbolic_metamodeling_fv = np.array([])

symbolic_regression_fv = np.array([])

# %%
pd.DataFrame(data=np.concatenate([X_data,
                                 inet_poly_fv,
                                 lambda_net_fv,
                                 target_function_fv,
                                 symbolic_metamodeling_fv,
                                 symbolic_regression_fv], axis=1), columns=['X_data', 
                                                                            'inet_poly_fv', 
                                                                            'lambda_net_preds', 
                                                                            'target_function_fv', 
                                                                            'symbolic_metamodeling_fv', 
                                                                            'symbolic_regression_fv'])
