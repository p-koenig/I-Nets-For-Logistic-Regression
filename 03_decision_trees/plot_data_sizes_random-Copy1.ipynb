# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

import seaborn as sns
from copy import deepcopy

sns.set_style("darkgrid")

pd.set_option('max_columns', 50)

sns.set(rc={'figure.figsize':(15,10)})

# %%
def excel_selection_to_numpy(selection_string):
    selection_string_by_row = selection_string.split('  ')
    
    selection_string_by_row_list = []
    for row in selection_string_by_row:
        row_by_value = row.split('\t')
        selection_string_by_row_list.append(row_by_value)
        
    return np.array(selection_string_by_row_list).astype(np.float64)

# %%
columns = [500, 1000, 5000, 10000, 20000, 30000, 40000, 50000, 100000]
index =  [
           'Titanic (n=9)', 
           'Medical Insurance (n=9)', 
           'Brest Cancer Wisconsin (n=9)', 
           'Wisconsin Diagnostic Breast Cancer (n=10)',  
           'Heart Disease (n=13)',                       
           'Cervical Cancer (n=15)',                     
           'Loan House (n=16)',                          
           'Credit Card (n=23)', 
          ]


multi_distrib_sampling_results = excel_selection_to_numpy('0.71	0.76	0.77	0.71	0.73	0.78	0.74	0.6	0.75  0.83	0.76	0.75	0.88	0.81	0.85	0.86	0.89	0.85  0.7	0.78	0.8	0.84	0.74	0.73	0.82	0.74	0.71  0.72	0.61	0.66	0.56	0.56	0.63	0.64	0.62	0.57  0.66	0.84	0.73	0.75	0.74	0.77	0.78	0.72	0.78  0.57	0.62	0.53	0.65	0.66	0.75	0.65	0.73	0.61  0.7	0.81	0.92	0.77	0.75	0.85	0.93	0.74	0.91  0.53	0.62	0.68	0.69	0.76	0.71	0.75	0.68	0.7')
standard_uniform_results = excel_selection_to_numpy('0.77	0.83	0.87	0.86	0.87	0.87	0.87	0.87	0.88  0.81	0.84	0.88	0.89	0.92	0.92	0.91	0.91	0.92  0.8	0.77	0.48	0.39	0.36	0.32	0.34	0.32	0.32  0.44	0.46	0.37	0.38	0.34	0.36	0.36	0.29	0.38  0.8	0.84	0.85	0.86	0.86	0.85	0.85	0.87	0.87  0.68	0.75	0.71	0.72	0.78	0.75	0.77	0.79	0.81  0.71	0.83	0.89	0.97	1	1	1	1	1  0.66	0.69	0.74	0.75	0.75	0.75	0.75	0.75	0.75')
standard_normal_results = excel_selection_to_numpy('0.72	0.75	0.85	0.86	0.85	0.83	0.88	0.85	0.88  0.64	0.75	0.9	0.91	0.89	0.89	0.91	0.85	0.88  0.37	0.45	0.4	0.32	0.34	0.37	0.32	0.32	0.39  0.45	0.51	0.34	0.33	0.37	0.35	0.31	0.34	0.38  0.78	0.7	0.74	0.8	0.82	0.79	0.8	0.82	0.82  0.57	0.47	0.49	0.61	0.36	0.34	0.42	0.28	0.35  0.68	0.87	0.87	0.6	0.69	0.56	0.78	0.81	0.84  0.55	0.71	0.56	0.34	0.5	0.6	0.54	0.55	0.64')

multi_distrib_sampling_results_df = pd.DataFrame(data=multi_distrib_sampling_results, 
                                                 index=index, 
                                                 columns =columns).T

standard_uniform_results_df = pd.DataFrame(data=standard_uniform_results, 
                                                 index=index, 
                                                 columns =columns).T

standard_normal_results_df = pd.DataFrame(data=standard_normal_results, 
                                                 index=index, 
                                                 columns =columns).T

# %%
sns.lineplot(data=multi_distrib_sampling_results_df)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=standard_uniform_results_df)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=standard_normal_results_df)
# Out:
# <AxesSubplot:>

# %%
index_mean = ['multi_distrib_sampling', 'standard_uniform', 'standard_normal']
results_mean = np.array([multi_distrib_sampling_results_df.mean(axis=1).values,
                         standard_uniform_results_df.mean(axis=1).values,
                         standard_normal_results_df.mean(axis=1).values])

standard_uniform_results_df = pd.DataFrame(data=results_mean, 
                                                 index=index_mean, 
                                                 columns=columns).T
standard_uniform_results_df.head()
# Out:
#        multi_distrib_sampling  standard_uniform  standard_normal
# 500                   0.67750           0.70875          0.59500
# 1000                  0.72500           0.75125          0.65125
# 5000                  0.73000           0.72375          0.64375
# 10000                 0.73125           0.72750          0.59625
# 20000                 0.71875           0.73500          0.60250

# %%
sns.lineplot(data=standard_uniform_results_df)
# Out:
# <AxesSubplot:>
