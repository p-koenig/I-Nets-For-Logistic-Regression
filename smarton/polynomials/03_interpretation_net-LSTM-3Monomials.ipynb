# %% [markdown]
# # Inerpretation-Net Training
#
# # Experiment 1: I-Net Performance for Different Algebras and Complexities
# # Experiment 2: I-Net Performance Comparison for λ-Nets with Different Training Levels
# # Experiment 3: I-Net Performance Comparison Different Training Data Sizes

# %% [markdown]
# ## Specitication of Experiment Settings

# %%
#######################################################################################################################################
###################################################### CONFIG FILE ####################################################################
#######################################################################################################################################
sleep_time = 0 #minutes


config = {
    'data': {
        'd': 5, #degree
        'n': 1, #number of variables
        'sparsity': None,
        'sample_sparsity': None,
        'x_max': 1,
        'x_min': 0,
        'x_distrib': 'uniform', #'normal', 'uniform', 'beta', 'Gamma', 'laplace'
        'a_max': 1,
        'a_min': -1,
        'lambda_nets_total': 10000,
        'noise': 0.1,
        'noise_distrib': 'normal', #'normal', 'uniform', 'beta', 'Gamma', 'laplace'
        
        'same_training_all_lambda_nets': False,

        'fixed_seed_lambda_training': True,
        'fixed_initialization_lambda_training': False,
        'number_different_lambda_trainings': 1,
    },
    'lambda_net': {
        'epochs_lambda': 1000,
        'early_stopping_lambda': True,  #if early stopping is used, multi_epoch_analysis is deactivated
        'early_stopping_min_delta_lambda': 1e-4,
        'batch_lambda': 64,
        'dropout': 0,
        'lambda_network_layers': [5*'sparsity'],
        'optimizer_lambda': 'adam',
        'loss_lambda': 'mae',
        'number_of_lambda_weights': None,
        'lambda_dataset_size': 5000,
    },
    'i_net': {
        'optimizer': 'custom',#adam
        'inet_loss': 'mae',
        'inet_metrics': ['r2'],
        'dropout': 0.25,
        'dropout_output': 0,
        'epochs': 500,
        'early_stopping': True,
        'batch_size': 256,
        'dense_layers': [512, 1024],
        'convolution_layers': None,
        'lstm_layers': None,
        'interpretation_dataset_size': 10000,
                
        'interpretation_net_output_monomials': 3, #(None, int)
        'interpretation_net_output_shape': None, #calculated automatically later
        
        'evaluate_with_real_function': False,
        'consider_labels_training': False,
                      
        'data_reshape_version': None, #default to 2 options:(None, 0,1 2)
        'nas': True,
        'nas_type': 'LSTM', #options:(None, 'SEQUENTIAL', 'CNN', 'LSTM', 'CNN-LSTM', 'CNN-LSTM-parallel')      
        'nas_trials': 100,
    },
    'evaluation': {   
        'inet_holdout_seed_evaluation': False,
        
        #set if multi_epoch_analysis should be performed
        'multi_epoch_analysis': True,
        'each_epochs_save_lambda': 20,
        'epoch_start': 0, #use to skip first epochs in multi_epoch_analysis
        
        #set if samples analysis should be performed
        'samples_list': None,#[100, 500, 750, 1000, 2500, 5000, 7500, 10000, 15000, 20000, 25000, 28125] 
       
        'random_evaluation_dataset_size': 500,
    },
    'computation':{
        'n_jobs': 11,
        'use_gpu': True,
        'gpu_numbers': '1',
        'RANDOM_SEED': 42,   
    }
}

# %% [markdown]
# ## Imports

# %%
#######################################################################################################################################
########################################### IMPORT GLOBAL VARIABLES FROM CONFIG #######################################################
#######################################################################################################################################
globals().update(config['data'])
globals().update(config['lambda_net'])
globals().update(config['i_net'])
globals().update(config['evaluation'])
globals().update(config['computation'])

# %%
#######################################################################################################################################
##################################################### IMPORT LIBRARIES ################################################################
#######################################################################################################################################
from itertools import product       
from tqdm import tqdm_notebook as tqdm
import pickle
import numpy as np
import pandas as pd
import scipy as sp
import timeit
import psutil

from functools import reduce
from more_itertools import random_product 
from sklearn.preprocessing import Normalizer

import sys
import os
import shutil

import logging

from prettytable import PrettyTable
import colored
import math

import time
from datetime import datetime
from collections.abc import Iterable


from joblib import Parallel, delayed

from scipy.integrate import quad

from sklearn.model_selection import cross_val_score, train_test_split, StratifiedKFold, KFold, ParameterGrid, ParameterSampler
from sklearn.metrics import accuracy_score, log_loss, roc_auc_score, f1_score, mean_absolute_error, r2_score

from similaritymeasures import frechet_dist, area_between_two_curves, dtw
import keras
from keras.models import Sequential
from keras.layers.core import Dense, Dropout
from keras.utils import plot_model
from IPython.display import Image

import keras.backend as K
from livelossplot import PlotLossesKerasTF
from keras_tqdm import TQDMNotebookCallback
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

from matplotlib import pyplot as plt
import seaborn as sns


import tensorflow as tf
import random 


import warnings


from IPython.display import display, Math, Latex, clear_output

# %%
sys.path.append('..')

from utilities.InterpretationNet import *
from utilities.LambdaNet import *
from utilities.metrics import *
from utilities.utility_functions import *

# %%
#######################################################################################################################################
################################################### VARIABLE ADJUSTMENTS ##############################################################
#######################################################################################################################################
variables = 'abcdefghijklmnopqrstuvwxyz'[:n]

n_jobs = min((epochs_lambda//each_epochs_save_lambda+1, n_jobs)) if multi_epoch_analysis else min(len(samples_list), n_jobs) if samples_list!=None else 1

multi_epoch_analysis = False if early_stopping_lambda else multi_epoch_analysis #deactivate multi_epoch_analysis if early stopping is used

each_epochs_save_lambda = each_epochs_save_lambda if multi_epoch_analysis else epochs_lambda
epochs_save_range_lambda = range(epoch_start//each_epochs_save_lambda, epochs_lambda//each_epochs_save_lambda) if each_epochs_save_lambda == 1 else range(epoch_start//each_epochs_save_lambda, epochs_lambda//each_epochs_save_lambda+1) if multi_epoch_analysis else range(1,2)

data_reshape_version = 2 if data_reshape_version == None and (convolution_layers != None or lstm_layers != None or (nas and nas_type != 'SEQUENTIAL')) else data_reshape_version
#######################################################################################################################################
###################################################### SET VARIABLES + DESIGN #########################################################
#######################################################################################################################################

#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 
os.environ['CUDA_VISIBLE_DEVICES'] = gpu_numbers if use_gpu else ''

logging.getLogger('tensorflow').disabled = True

sns.set_style("darkgrid")
#np.set_printoptions(suppress=True)

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
if int(tf.__version__[0]) >= 2:
    tf.random.set_seed(RANDOM_SEED)
else:
    tf.set_random_seed(RANDOM_SEED)
    
    
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.max_columns', 500)

warnings.filterwarnings('ignore')

# %%
#######################################################################################################################################
####################################################### CONFIG ADJUSTMENTS ############################################################
#######################################################################################################################################
config['evaluation']['multi_epoch_analysis'] = multi_epoch_analysis
config['evaluation']['each_epochs_save_lambda'] = each_epochs_save_lambda
config['i_net']['data_reshape_version'] = data_reshape_version

config['data']['sparsity'] = nCr(config['data']['n']+config['data']['d'], config['data']['d'])
config['data']['sample_sparsity'] = config['data']['sparsity'] if config['data']['sample_sparsity'] == None else config['data']['sample_sparsity']

config['i_net']['interpretation_net_output_shape'] = config['data']['sparsity'] if config['i_net']['interpretation_net_output_monomials'] is None else config['data']['sparsity']*config['i_net']['interpretation_net_output_monomials']+config['i_net']['interpretation_net_output_monomials']


transformed_layers = []
for layer in config['lambda_net']['lambda_network_layers']:
    if type(layer) == str:
        transformed_layers.append(layer.count('sparsity')*config['data']['sparsity'])
    else:
        transformed_layers.append(layer)
config['lambda_net']['lambda_network_layers'] = transformed_layers

layers_with_input_output = list(flatten([[config['data']['n']], config['lambda_net']['lambda_network_layers'], [1]]))
number_of_lambda_weights = 0
for i in range(len(layers_with_input_output)-1):
    number_of_lambda_weights += (layers_with_input_output[i]+1)*layers_with_input_output[i+1]  
config['lambda_net']['number_of_lambda_weights'] = number_of_lambda_weights
    
#######################################################################################################################################
################################################## UPDATE VARIABLES ###################################################################
#######################################################################################################################################
globals().update(config['data'])
globals().update(config['lambda_net'])
globals().update(config['i_net'])
globals().update(config['evaluation'])
globals().update(config['computation'])



initialize_LambdaNet_config_from_curent_notebook(config)
initialize_metrics_config_from_curent_notebook(config)
initialize_utility_functions_config_from_curent_notebook(config)
initialize_InterpretationNet_config_from_curent_notebook(config)


#######################################################################################################################################
###################################################### PATH + FOLDER CREATION #########################################################
#######################################################################################################################################
globals().update(generate_paths(path_type='interpretation_net'))
create_folders_inet()

#######################################################################################################################################
############################################################ SLEEP TIMER ##############################################################
#######################################################################################################################################
sleep_minutes(sleep_time)

# %%
print(path_identifier_interpretation_net_data)

print(path_identifier_lambda_net_data)
# Out:
# inet_dense512-1024-output_21_drop0.25e500b256_custom/lnets_10000_30-1000e_ES0.0001_64b_adam_mae_train_5000_diffX_1-FixSeed_42/var_1_d_5_sparsity_6_amin_-1_amax_1_xdist_uniform_noise_normal_0.1
# lnets_10000_30-1000e_ES0.0001_64b_adam_mae_train_5000_diffX_1-FixSeed_42/var_1_d_5_sparsity_6_amin_-1_amax_1_xmin_0_xmax_1_xdist_uniform_noise_normal_0.1

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print("Num XLA-GPUs Available: ", len(tf.config.experimental.list_physical_devices('XLA_GPU')))
# Out:
# Num GPUs Available:  1
# Num XLA-GPUs Available:  0

# %% [markdown]
# ## Utility functions

# %% [markdown]
# ### Generate List of Monomial Identifiers

# %%
list_of_monomial_identifiers_extended = []
for i in tqdm(range((d+1)**n)):    
    monomial_identifier = dec_to_base(i, base = (d+1)).zfill(n) 
    list_of_monomial_identifiers_extended.append(monomial_identifier)

print('List length: ' + str(len(list_of_monomial_identifiers_extended)))
print('Number of monomials in a polynomial with ' + str(n) + ' variables and degree ' + str(d) + ': ' + str(nCr(n+d, d)))
print('Sparsity: ' + str(sparsity))
print(list_of_monomial_identifiers_extended)

list_of_monomial_identifiers = []
for monomial_identifier in tqdm(list_of_monomial_identifiers_extended):
    monomial_identifier_values = list(map(int, list(monomial_identifier)))
    if sum(monomial_identifier_values) <= d:
        list_of_monomial_identifiers.append(monomial_identifier)

print('List length: ' + str(len(list_of_monomial_identifiers)))
print('Number of monomials in a polynomial with ' + str(n) + ' variables and degree ' + str(d) + ': ' + str(nCr(n+d, d)))
print('Sparsity: ' + str(sparsity))
print(list_of_monomial_identifiers)


layers_with_input_output = list(flatten([[n], lambda_network_layers, [1]]))
number_of_lambda_weights = 0
for i in range(len(layers_with_input_output)-1):
    number_of_lambda_weights += (layers_with_input_output[i]+1)*layers_with_input_output[i+1]
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# List length: 6
# Number of monomials in a polynomial with 1 variables and degree 5: 6
# Sparsity: 6
# ['0', '1', '2', '3', '4', '5']
#   0%|          | 0/6 [00:00<?, ?it/s]
# List length: 6
# Number of monomials in a polynomial with 1 variables and degree 5: 6
# Sparsity: 6
# ['0', '1', '2', '3', '4', '5']

# %% [markdown]
# ## Load Data and Generate Datasets

# %%
def load_lambda_nets(index):
    
    if psutil.virtual_memory().percent > 80:
        raise SystemExit("Out of RAM!")
    
    directory = './data/weights/' + 'weights_' + path_identifier_lambda_net_data + '/'
    path_weights = directory + 'weights_epoch_' + str(index).zfill(3) + '.txt'
    path_X_data = directory + 'lambda_X_test_data.txt'
    path_y_data = directory + 'lambda_y_test_data.txt'        
    
    weight_data = pd.read_csv(path_weights, sep=",", header=None)
    weight_data = weight_data.sort_values(by=0).sample(frac=1, random_state=RANDOM_SEED)
    weight_data = weight_data.sort_values(by=0).sample(n=interpretation_dataset_size, random_state=RANDOM_SEED)
    
    lambda_X_test_data = pd.read_csv(path_X_data, sep=",", header=None)
    lambda_X_test_data = lambda_X_test_data.sort_values(by=0).sample(frac=1, random_state=RANDOM_SEED)
    lambda_X_test_data = lambda_X_test_data.sort_values(by=0).sample(n=interpretation_dataset_size, random_state=RANDOM_SEED)
    
    lambda_y_test_data = pd.read_csv(path_y_data, sep=",", header=None)
    lambda_y_test_data = lambda_y_test_data.sort_values(by=0).sample(frac=1, random_state=RANDOM_SEED)
    lambda_y_test_data = lambda_y_test_data.sort_values(by=0).sample(n=interpretation_dataset_size, random_state=RANDOM_SEED)
        
    lambda_nets = [None] * weight_data.shape[0]
    for i, (row_weights, row_lambda_X_test_data, row_lambda_y_test_data) in enumerate(zip(weight_data.values, lambda_X_test_data.values, lambda_y_test_data.values)):        
        lambda_net = LambdaNet(row_weights, row_lambda_X_test_data, row_lambda_y_test_data)
        lambda_nets[i] = lambda_net
                
    lambda_net_dataset = LambdaNetDataset(lambda_nets)
        
    return lambda_net_dataset

# %%
#LOAD DATA

parallel = Parallel(n_jobs=n_jobs, verbose=3, backend='multiprocessing')
lambda_net_dataset_list = parallel(delayed(load_lambda_nets)((i+1)*each_epochs_save_lambda if each_epochs_save_lambda==1 else i*each_epochs_save_lambda if i > 1 else each_epochs_save_lambda if i==1 else 1) for i in epochs_save_range_lambda)  
del parallel

lambda_net_dataset = lambda_net_dataset_list[-1]
# Out:
# [Parallel(n_jobs=11)]: Using backend MultiprocessingBackend with 11 concurrent workers.
# [Parallel(n_jobs=11)]: Done   1 out of   1 | elapsed:   37.9s finished

# %% [markdown]
# ## Data Inspection

# %%
lambda_net_dataset.as_pandas().head()
# Out:
#             seed  0-target  1-target  2-target  3-target  4-target  5-target  \
# 6252  1373158606     0.924     0.492    -0.142    -0.402    -0.741     0.255
# 4684  1373158606    -0.794     0.241    -0.127    -0.188    -0.535    -0.939
# 1731  1373158606    -0.739     0.951     0.737     0.786     0.773     0.083
# 4742  1373158606     0.173    -0.607    -0.085     0.746    -0.828    -0.939
# 4521  1373158606     0.131     0.208     0.871     0.323     0.573     0.164
#
#       0-lstsq_lambda  1-lstsq_lambda  2-lstsq_lambda  3-lstsq_lambda  \
# 6252           0.941           0.421          -1.533           6.634
# 4684          -0.768           1.420         -14.454          48.213
# 1731          -0.721           0.346           4.731          -9.701
# 4742           0.161          -0.337          -2.491           8.142
# 4521           0.124           0.308           0.697          -0.264
#
#       4-lstsq_lambda  5-lstsq_lambda  0-lstsq_target  1-lstsq_target  \
# 6252         -11.500           5.498           0.911           0.605
# 4684         -63.525          27.058          -0.794           0.232
# 1731          12.714          -4.814          -0.744           0.972
# 4742         -10.118           3.139           0.181          -0.787
# 4521           2.311          -0.934           0.132           0.241
#
#       2-lstsq_target  3-lstsq_target  4-lstsq_target  5-lstsq_target   wb_0  \
# 6252          -0.683           0.915          -2.125           0.759 -0.009
# 4684           0.112          -0.997           0.376          -1.277 -0.009
# 1731           0.672           0.758           0.980          -0.046 -0.009
# 4742           0.885          -1.338           1.146          -1.629 -0.009
# 4521           0.293           2.685          -2.779           1.703 -0.009
#
#        wb_1   wb_2  wb_3  wb_4   wb_5  wb_6   wb_7  wb_8  wb_9  wb_10  wb_11  \
# 6252 -0.227  0.414 0.340 0.169  0.103 0.419 -0.297 0.334 0.062  0.544 -0.088
# 4684 -0.227  0.231 0.122 0.313  0.080 0.185 -0.297 0.089 0.253  0.358 -0.088
# 1731 -0.227 -0.173 0.082 0.724  0.671 0.528 -0.297 0.067 0.916  0.416 -0.088
# 4742 -0.227  0.511 0.469 0.050 -0.029 0.515 -0.297 0.433 0.595  0.678 -0.088
# 4521 -0.227  0.128 0.083 0.634  0.562 0.108 -0.297 0.067 0.951  0.400 -0.088
#
#       wb_12  wb_13  wb_14  wb_15  wb_16  wb_17  wb_18  wb_19  wb_20  wb_21  \
#
#
#       wb_82  wb_83  wb_84  wb_85  wb_86  wb_87  wb_88  wb_89  wb_90
# 6252 -0.044 -0.261 -0.383 -0.059 -0.969  0.144 -0.258 -0.315  0.202
# 4684 -0.229 -0.261 -0.383 -0.059 -0.479  0.144 -0.258 -0.315 -0.168
# 1731 -0.042 -0.261 -0.383 -0.059 -0.331  0.144 -0.258 -0.315 -0.437
# 4742 -1.217 -0.261 -0.383 -0.059 -1.255  0.144 -0.258 -0.315  0.121
# 4521 -0.044 -0.261 -0.383 -0.059 -0.334  0.144 -0.258 -0.315  0.078

# %%
lambda_net_dataset.as_pandas().describe()
# Out:
#                 seed  0-target  1-target  2-target  3-target  4-target  \
# count      10000.000 10000.000 10000.000 10000.000 10000.000 10000.000
# mean  1373158606.000     0.001    -0.005    -0.000     0.004    -0.003
# std            0.000     0.574     0.577     0.577     0.577     0.575
# min   1373158606.000    -1.000    -1.000    -1.000    -1.000    -1.000
# 25%   1373158606.000    -0.491    -0.505    -0.506    -0.494    -0.497
# 50%   1373158606.000     0.005    -0.005     0.002     0.003    -0.005
# 75%   1373158606.000     0.500     0.490     0.496     0.507     0.495
# max   1373158606.000     1.000     1.000     1.000     1.000     0.999
#
#        5-target  0-lstsq_lambda  1-lstsq_lambda  2-lstsq_lambda  \
# count 10000.000       10000.000       10000.000       10000.000
# mean     -0.003           0.004          -0.025           0.136
# std       0.580           0.542           0.650           3.538
# min      -1.000          -1.038          -2.548         -19.920
# 25%      -0.505          -0.444          -0.453          -1.840
# 50%       0.001           0.002          -0.005           0.012
# 75%       0.502           0.459           0.395           1.952
# max       1.000           1.031           2.526          21.905
#
#        3-lstsq_lambda  4-lstsq_lambda  5-lstsq_lambda  0-lstsq_target  \
# count       10000.000       10000.000       10000.000       10000.000
# mean           -0.544           0.793          -0.364           0.001
# std            10.664          13.939           5.786           0.574
# min           -73.162         -89.155         -43.752          -1.024
# 25%            -5.518          -6.649          -2.946          -0.494
# 50%            -0.028           0.022          -0.008           0.005
# 75%             5.079           7.322           2.590           0.500
# max            66.969          99.952          38.263           1.040
#
#        1-lstsq_target  2-lstsq_target  3-lstsq_target  4-lstsq_target  \
# count       10000.000       10000.000       10000.000       10000.000
# mean           -0.006           0.003           0.001          -0.003
# std             0.621           1.539           3.677           4.051
# min            -1.581          -5.513         -14.253         -18.883
# 25%            -0.507          -1.054          -2.436          -2.738
# 50%            -0.005           0.011           0.004           0.018
# 75%             0.487           1.047           2.453           2.710
# max             1.668           5.906          16.745          15.501
#
#        5-lstsq_target      wb_0      wb_1      wb_2      wb_3      wb_4  \
# count       10000.000 10000.000 10000.000 10000.000 10000.000 10000.000
# mean           -0.001    -0.009    -0.227     0.287     0.192     0.282
# std             1.706     0.000     0.000     0.142     0.143     0.158
# min            -6.767    -0.009    -0.227    -0.173    -0.289    -0.227
# 25%            -1.150    -0.009    -0.227     0.182     0.083     0.174
# 50%            -0.015    -0.009    -0.227     0.288     0.183     0.268
# 75%             1.145    -0.009    -0.227     0.367     0.275     0.375
# max             8.136    -0.009    -0.227     0.794     0.680     0.884
#
#            wb_5      wb_6      wb_7      wb_8      wb_9     wb_10     wb_11  \
# count 10000.000 10000.000 10000.000 10000.000 10000.000 10000.000 10000.000
# mean      0
10000.000 10000.000 10000.000 10000.000 10000.000 10000.000 10000.000
# mean     -0.258    -0.261    -0.383    -0.059    -0.544     0.144    -0.258
# std       0.334     0.000     0.000     0.000     0.278     0.000     0.000
# min      -3.002    -0.261    -0.383    -0.059    -2.170     0.144    -0.258
# 25%      -0.309    -0.261    -0.383    -0.059    -0.569     0.144    -0.258
# 50%      -0.129    -0.261    -0.383    -0.059    -0.460     0.144    -0.258
# 75%      -0.044    -0.261    -0.383    -0.059    -0.335     0.144    -0.258
# max       0.441    -0.261    -0.383    -0.059    -0.236     0.144    -0.258
#
#           wb_89     wb_90
# count 10000.000 10000.000
# mean     -0.315     0.004
# std       0.000     0.139
# min      -0.315    -0.578
# 25%      -0.315    -0.125
# 50%      -0.315     0.002
# 75%      -0.315     0.137
# max      -0.315     0.443

# %%
lambda_net_dataset.X_test_data_list[0][:10]
# Out:
# array([[0.04991591],
#        [0.55931928],
#        [0.41215429],
#        [0.47204459],
#        [0.50702493],
#        [0.36030918],
#        [0.48300684],
#        [0.91632547],
#        [0.27265516],
#        [0.88145597]])

# %%
lambda_net_dataset.y_test_data_list[0][:10]
# Out:
# array([[1.0879322 ],
#        [0.92128287],
#        [0.94887895],
#        [1.06356541],
#        [1.04696906],
#        [0.91303792],
#        [0.84312583],
#        [0.62768837],
#        [1.02064446],
#        [0.61265825]])

# %% [markdown]
# ## Generate Datasets for Interpretation-Net training

# %%
#generate train, test and validation data for training

lambda_net_train_dataset_list = []
lambda_net_valid_dataset_list = []
lambda_net_test_dataset_list = []

for lambda_net_dataset in lambda_net_dataset_list:
    
    
    if inet_holdout_seed_evaluation:
        complete_seed_list = list(set(lambda_net_dataset.train_settings_list['seed']))#list(weight_data.iloc[:,1].unique())

        random.seed(RANDOM_SEED)
        test_seeds = random.sample(complete_seed_list, int(len(complete_seed_list)-len(complete_seed_list)/(1/0.9)))
        lambda_net_test_dataset = lambda_net_dataset.get_lambda_nets_by_seed(test_seeds)
        complete_seed_list = list(set(complete_seed_list) - set(test_seeds))#complete_seed_list.remove(test_seeds)
        
        random.seed(RANDOM_SEED)
        valid_seeds = random.sample(complete_seed_list, int(len(complete_seed_list)-len(complete_seed_list)/(1/0.9)))
        lambda_net_valid_dataset = lambda_net_dataset.get_lambda_nets_by_seed(valid_seeds)
        complete_seed_list = list(set(complete_seed_list) - set(valid_seeds))

        train_seeds = complete_seed_list
        lambda_net_train_dataset = lambda_net_dataset.get_lambda_nets_by_seed(train_seeds)       
        
        lambda_net_train_dataset_list.append(lambda_net_train_dataset)
        lambda_net_valid_dataset_list.append(lambda_net_valid_dataset)
        lambda_net_test_dataset_list.append(lambda_net_test_dataset)
        
        del lambda_net_dataset
    else:
        lambda_net_train_with_valid_dataset, lambda_net_test_dataset = split_LambdaNetDataset(lambda_net_dataset, test_split=0.1)
        lambda_net_train_dataset, lambda_net_valid_dataset = split_LambdaNetDataset(lambda_net_train_with_valid_dataset, test_split=0.1)

        lambda_net_train_dataset_list.append(lambda_net_train_dataset)
        lambda_net_valid_dataset_list.append(lambda_net_valid_dataset)
        lambda_net_test_dataset_list.append(lambda_net_test_dataset)
    
        del lambda_net_dataset, lambda_net_train_with_valid_dataset

        
del lambda_net_dataset_list

# %%
lambda_net_train_dataset_list[-1].as_pandas().shape
# Out:
# (8100, 110)

# %%
lambda_net_valid_dataset_list[-1].as_pandas().shape
# Out:
# (900, 110)

# %%
lambda_net_test_dataset_list[-1].as_pandas().shape
# Out:
# (1000, 110)

# %%
lambda_net_train_dataset_list[-1].as_pandas().head()
# Out:
#             seed  0-target  1-target  2-target  3-target  4-target  5-target  \
#
0.000  0.000  0.000 -0.052  0.000  0.000  0.000 -0.254 -0.359
#
#       wb_62  wb_63  wb_64  wb_65  wb_66  wb_67  wb_68  wb_69  wb_70  wb_71  \
# 8323 -0.198 -0.225  0.356  0.385 -0.040 -0.408 -0.258  1.138  1.249 -0.352
# 5392 -0.495 -0.566  0.183  0.269 -0.373 -0.408 -0.632 -0.250 -0.363 -0.352
# 4718 -0.399 -0.428  0.254  0.299 -0.253 -0.408 -0.473 -0.041 -0.244 -0.352
# 990  -0.344 -0.334  0.595  0.712 -0.182 -0.408 -0.357 -0.071 -0.212 -0.352
# 6498 -0.350 -0.372  0.325  0.377 -0.198 -0.408 -0.405  0.072 -0.203 -0.352
#
#       wb_72  wb_73  wb_74  wb_75  wb_76  wb_77  wb_78  wb_79  wb_80  wb_81  \
# 8323 -0.364 -0.032  0.319 -0.049  0.551  0.238  0.396  0.278  0.220 -0.310
# 5392 -0.364 -0.353  0.205 -0.440  0.671  0.016  0.180  0.061  0.264 -0.731
# 4718 -0.364 -0.258  0.236 -0.322  0.562  0.130  0.279  0.166  0.200 -0.581
# 990  -0.364 -0.202  0.667 -0.289  0.394  0.450  0.559  0.468  0.896 -0.393
# 6498 -0.364 -0.208  0.315 -0.281  0.647  0.200  0.342  0.233  0.291 -0.310
#
#       wb_82  wb_83  wb_84  wb_85  wb_86  wb_87  wb_88  wb_89  wb_90
# 8323 -0.045 -0.261 -0.383 -0.059 -0.334  0.144 -0.258 -0.315  0.083
# 5392 -0.549 -0.261 -0.383 -0.059 -0.743  0.144 -0.258 -0.315  0.173
# 4718 -0.045 -0.261 -0.383 -0.059 -0.588  0.144 -0.258 -0.315  0.122
# 990  -0.109 -0.261 -0.383 -0.059 -0.421  0.144 -0.258 -0.315 -0.042
# 6498 -0.045 -0.261 -0.383 -0.059 -0.335  0.144 -0.258 -0.315  0.183

# %%
lambda_net_test_dataset_list[-1].as_pandas().head()
# Out:
#             seed  0-target  1-target  2-target  3-target  4-target  5-target  \
# 7217  1373158606     0.715     0.432     0.981    -0.843    -0.740    -0.831
# 8291  1373158606    -0.213     0.402    -0.761    -0.041    -0.451    -0.243
# 4607  1373158606     0.514    -0.410    -0.766    -0.485    -0.225    -0.896
# 5114  1373158606    -0.373     0.948     0.872     0.284    -0.963     0.497
# 1859  1373158606     0.664    -0.380     0.886    -0.641     0.325     0.344
#
#       0-lstsq_lambda  1-lstsq_lambda  2-lstsq_lambda  3-lstsq_lambda  \
# 7217           0.712           0.906          -3.423          12.732
# 8291          -0.180          -0.014           0.537          -0.987
# 4607           0.504          -0.223          -2.133           3.540
# 5114          -0.337           0.233           4.836          -8.996
# 1859           0.522           0.397          -0.001           0.002
#
#       4-lstsq_lambda  5-lstsq_lambda  0-lstsq_target  1-lstsq_target  \
# 7217         -17.553           6.388           0.718           0.388
# 8291          -1.331           0.714          -0.217           0.535
# 4607          -5.265           1.293           0.540          -1.066
# 5114           8.775          -3.282          -0.362           0.882
# 1859          -0.002           0.001           0.652          -0.318
#
#       2-lstsq_target  3-lstsq_target  4-lstsq_target  5-lstsq_target   wb_0  \
# 7217           1.013          -0.441          -1.667          -0.267 -0.009
# 8291          -1.376           1.067          -1.325           0.011 -0.009
# 4607           3.452         -11.112          11.162          -5.249 -0.009
# 5114           1.143          -0.511           0.152          -0.040 -0.009
# 1859           1.239          -2.754           3.568          -1.206 -0.009
#
#        wb_1  wb_2  wb_3   wb_4   wb_5  wb_6   wb_7  wb_8  wb_9  wb_10  wb_11  \
# 7217 -0.022  0.000  0.000  0.000 -0.386  0.000  0.000  0.000 -0.254 -0.359
# 8291 -0.373  0.000  0.000  0.000 -0.253  0.000  0.000  0.000 -0.254 -0.359
# 4607 -0.428  0.000  0.000  0.000 -0.414  0.000  0.000  0.000 -0.254 -0.359
# 5114 -0.024  0.000  0.000  0.000 -0.057  0.000  0.000  0.000 -0.254 -0.359
# 1859 -0.022  0.000  0.000  0.000 -0.052  0.000  0.000  0.000 -0.254 -0.359
#
#       wb_62  wb_63  wb_64  wb_65  wb_66  wb_67  wb_68  wb_69  wb_70  wb_71  \
# 7217 -0.910 -1.276  0.346  0.391 -1.018 -0.408 -1.491  0.093 -0.683 -0.352
# 8291 -0.323 -0.733  0.222  0.248 -0.644 -0.408 -0.880 -0.641 -0.180 -0.352
# 4607 -0.857 -1.084  0.122  0.305 -0.857 -0.408 -1.183 -0.686 -0.608 -0.352
# 5114 -0.190 -0.225  0.474  0.509 -0.032 -0.408 -0.257  0.262  0.036 -0.352
# 1859 -0.251 -0.225  0.319  0.356 -0.086 -0.408 -0.258  0.062 -0.116 -0.352
#
#       wb_72  wb_73  wb_74  wb_75  wb_76  wb_77  wb_78  wb_79  wb_80  wb_81  \
# 7217 -0.364 -0.898  0.329 -0.754  0.625  0.223  0.369  0.257  0.278 -1.739
# 8291 -0.364 -0.542  0.181 -0.261  0.393  0.103  0.263  0.144  0.047 -1.077
# 4607 -0.364 -0.755  0.244 -0.657  0.805 -0.222  0.051 -0.113  0.405 -1.307
# 5114 -0.364 -0.006  0.445 -0.043  0.778  0.354  0.505  0.390  0.407 -0.309
# 1859 -0.364 -0.108  0.291 -0.194  0.561  0.198  0.351  0.236  0.216 -0.310
#
#       wb_82  wb_83  wb_84  wb_85  wb_86  wb_87  wb_88  wb_89  wb_90
# 7217 -0.045 -0.261 -0.383 -0.059 -1.706  0.144 -0.258 -0.315  0.164
# 8291 -1.181 -0.261 -0.383 -0.059 -1.001  0.144 -0.258 -0.315 -0.108
# 4607 -1.185 -0.261 -0.383 -0.059 -1.311  0.144 -0.258 -0.315  0.132
# 5114 -0.044 -0.261 -0.383 -0.059 -0.334  0.144 -0.258 -0.315 -0.328
# 1859 -0.045 -0.261 -0.383 -0.059 -0.334  0.144 -0.258 -0.315  0.134

# %% [markdown]
# ## Interpretation Network Training

# %%
(history_list, 
scores_list, 

function_values_complete_list, 
function_values_valid_list, 
function_values_test_list, 

inet_preds_list, 
inet_preds_valid_list, 
inet_preds_test_list, 
 
per_network_preds_list,

distrib_dict_list,
model_list) = calculate_interpretation_net_results(lambda_net_train_dataset_list, 
                                                   lambda_net_valid_dataset_list, 
                                                   lambda_net_test_dataset_list)
# Out:
# Trial 78 Complete [00h 25m 42s]
# val_loss: 0.11473916471004486
#
# Best val_loss So Far: 0.08176565170288086
# Total elapsed time: 06h 10m 02s
# Epoch 1/500
# 32/32 [==============================] - 43s 818ms/step - loss: 0.6255 - val_loss: 0.6182
# Epoch 2/500
# 32/32 [==============================] - 22s 687ms/step - loss: 0.6238 - val_loss: 0.6150
# Epoch 3/500
# 32/32 [==============================] - 22s 693ms/step - loss: 0.6189 - val_loss: 0.5994
# Epoch 4/500
# 32/32 [==============================] - 22s 700ms/step - loss: 0.5973 - val_loss: 0.5621
# Epoch 5/500
# 32/32 [==============================] - 22s 693ms/step - loss: 0.5536 - val_loss: 0.4888
# Epoch 6/500
# 32/32 [==============================] - 22s 696ms/step - loss: 0.4715 - val_loss: 0.3944
# Epoch 7/500
# 32/32 [==============================] - 22s 695ms/step - loss: 0.3904 - val_loss: 0.3411
# Epoch 8/500
# 32/32 [==============================] - 23s 708ms/step - loss: 0.3379 - val_loss: 0.2956
# Epoch 9/500
# 32/32 [==============================] - 22s 703ms/step - loss: 0.2929 - val_loss: 0.2609
# Epoch 10/500
# 32/32 [==============================] - 22s 696ms/step - loss: 0.2571 - val_loss: 0.2286
# Epoch 11/500
# 32/32 [==============================] - 22s 678ms/step - loss: 0.2226 - val_loss: 0.1853
# Epoch 12/500
# 32/32 [==============================] - 22s 691ms/step - loss: 0.1753 - val_loss: 0.1499
# Epoch 13/500
# 32/32 [==============================] - 22s 698ms/step - loss: 0.1466 - val_loss: 0.1420
# Epoch 14/500
# 32/32 [==============================] - 22s 697ms/step - loss: 0.1399 - val_loss: 0.1382
# Epoch 15/500
# 32/32 [==============================] - 22s 678ms/step - loss: 0.1360 - val_loss: 0.1347
# Epoch 16/500
# 32/32 [==============================] - 22s 696ms/step - loss: 0.1328 - val_loss: 0.1302
# Epoch 17/500
# 32/32 [==============================] - 22s 703ms/step - loss: 0.1285 - val_loss: 0.1248
# Epoch 18/500
# 32/32 [==============================] - 22s 696ms/step - loss: 0.1246 - val_loss: 0.1189
# Epoch 19/500
# 32/32 [==============================] - 22s 685ms/step - loss: 0.1181 - val_loss: 0.1126
# Epoch 20/500
# 32/32 [==============================] - 23s 706ms/step - loss: 0.1136 - val_loss: 0.1072
# Epoch 21/500
# 32/32 [==============================] - 22s 703ms/step - loss: 0.1075 - val_loss: 0.1212
# Epoch 22/500
# 32/32 [==============================] - 23s 708ms/step - loss: 0.1077 - val_loss: 0.1036
# Epoch 23/500
# 32/32 [==============================] - 22s 703ms/step - loss: 0.1036 - val_loss: 0.1004
# Epoch 24/500
# 32/32 [==============================] - 23s 708ms/step - loss: 0.0989 - val_loss: 0.1058
# Epoch 25/500
# 32/32 [==============================] - 23s 708ms/step - loss: 0.0964 - val_loss: 0.0983
# Epoch 26/500
# 32/32 [==============================] - 24s 745ms/step - loss: 0.0949 - val_loss: 0.0986
# Epoch 27/500
# 32/32 [==============================] - 24s 748ms/step - loss: 0.0928 - val_loss: 0.0995
# Epoch 28/500
# 32/32 [==============================] - 24s 762ms/step - loss: 0.0955 - val_loss: 0.0985
# Epoch 29/500
# 32/32 [==============================] - 24s 750ms/step - loss: 0.0953 - val_loss: 0.0985
# Epoch 30/500
# 32/32 [==============================] - 24s 746ms/step - loss: 0.0946 - val_loss: 0.0984
# Epoch 31/500
# 32/32 [==============================] - 24s 745ms/step - loss: 0.0966 - val_loss: 0.0989
# Epoch 32/500
# 32/32 [==============================] - 24s 753ms/step - loss: 0.0972 - val_loss: 0.0974
# Epoch 33/500
# 32/32 [==============================] - 24s 751ms/step - loss: 0.0961 - val_loss: 0.1014
# Epoch 34/500
# 32/32 [==============================] - 24s 750ms/step - loss: 0.0990 - val_loss: 0.0999
# Epoch 35/500
# 32/32 [==============================] - 24s 748ms/step - loss: 0.1004 - val_loss: 0.0987
# Epoch 36/500
# 32/32 [==============================] - 24s 753ms/step - loss: 0.0983 - val_loss: 0.1046
# Epoch 37/500
# 32/32 [==============================] - 24s 743ms/step - loss: 0.0994 - val_loss: 0.1037
# Epoch 38/500
# 32/32 [==============================] - 24s 737ms/step - loss: 0.1018 - val_loss: 0.1006
# Epoch 39/500
# 32/32 [==============================] - 24s 751ms/step - loss: 0.0999 - val_loss: 0.1036
# Epoch 40/500
# 32/32 [==============================] - 24s 749ms/step - loss: 0.1006 - val_loss: 0.1047
# Epoch 41/500
# 32/32 [==============================] - 24s 759ms/step - loss: 0.1012 - val_loss: 0.1007
# Epoch 42/500
# 32/32 [==============================] - 24s 756ms/step - loss: 0.1004 - val_loss: 0.1074
# Epoch 43/500
# 32/32 [==============================] - 23s 707ms/step - loss: 0.1007 - val_loss: 0.1034
# Epoch 44/500
# 32/32 [==============================] - 23s 717ms/step - loss: 0.1008 - val_loss: 0.1020
# Epoch 45/500
# 32/32 [==============================] - 23s 731ms/step - loss: 0.1003 - val_loss: 0.1074
# Epoch 46/500
# 32/32 [==============================] - 24s 754ms/step - loss: 0.0996 - val_loss: 0.1048
# Epoch 47/500
# 32/32 [==============================] - 24s 745ms/step - loss: 0.1010 - val_loss: 0.0985
# Epoch 48/500
# 32/32 [==============================] - 24s 742ms/step - loss: 0.0979 - val_loss: 0.1029
# Epoch 49/500
# 32/32 [==============================] - 24s 744ms/step - loss: 0.0972 - val_loss: 0.1001
# Epoch 50/500
# 32/32 [==============================] - 24s 744ms/step - loss: 0.0960 - val_loss: 0.0927
# Epoch 51/500
# 32/32 [==============================] - 24s 738ms/step - loss: 0.0900 - val_loss: 0.0907
# Epoch 52/500
# 32/32 [==============================] - 24s 745ms/step - loss: 0.0843 - val_loss: 0.0837
# Epoch 53/500
# 32/32 [==============================] - 24s 742ms/step - loss: 0.0790 - val_loss: 0.0759
# Epoch 54/500
# 32/32 [==============================] - 24s 748ms/step - loss: 0.0748 - val_loss: 0.0749
# Epoch 55/500
# 32/32 [==============================] - 24s 747ms/step - loss: 0.0724 - val_loss: 0.0702
# Epoch 56/500
# 32/32 [==============================] - 24s 747ms/step - loss: 0.
500
# 32/32 [==============================] - 22s 693ms/step - loss: 0.0631 - val_loss: 0.0598
# Epoch 106/500
# 32/32 [==============================] - 22s 692ms/step - loss: 0.0645 - val_loss: 0.0598
# Epoch 107/500
# 32/32 [==============================] - 22s 695ms/step - loss: 0.0653 - val_loss: 0.0615
# Epoch 108/500
# 32/32 [==============================] - 22s 692ms/step - loss: 0.0644 - val_loss: 0.0614
# Epoch 109/500
# 32/32 [==============================] - 22s 687ms/step - loss: 0.0641 - val_loss: 0.0605
# Epoch 110/500
# 32/32 [==============================] - 22s 695ms/step - loss: 0.0626 - val_loss: 0.0600
# Epoch 111/500
# 32/32 [==============================] - 22s 694ms/step - loss: 0.0646 - val_loss: 0.0649
# Epoch 112/500
# 32/32 [==============================] - 22s 698ms/step - loss: 0.0655 - val_loss: 0.0641
# Epoch 113/500
# 32/32 [==============================] - 23s 705ms/step - loss: 0.0651 - val_loss: 0.0620
# Epoch 114/500
# 32/32 [==============================] - 23s 729ms/step - loss: 0.0653 - val_loss: 0.0614
# Epoch 115/500
# 32/32 [==============================] - 24s 748ms/step - loss: 0.0634 - val_loss: 0.0604
# Epoch 116/500
# 32/32 [==============================] - 24s 747ms/step - loss: 0.0638 - val_loss: 0.0611
# Epoch 117/500
# 32/32 [==============================] - 24s 741ms/step - loss: 0.0631 - val_loss: 0.0604
# Epoch 118/500
# 32/32 [==============================] - 24s 745ms/step - loss: 0.0636 - val_loss: 0.0592
# Epoch 119/500
# 32/32 [==============================] - 24s 749ms/step - loss: 0.0629 - val_loss: 0.0600
# Epoch 120/500
# 32/32 [==============================] - 24s 752ms/step - loss: 0.0649 - val_loss: 0.0638
# Epoch 121/500
# 32/32 [==============================] - 24s 745ms/step - loss: 0.0659 - val_loss: 0.0627
# Epoch 122/500
# 32/32 [==============================] - 24s 750ms/step - loss: 0.0652 - val_loss: 0.0628
# Epoch 123/500
# 32/32 [==============================] - 24s 743ms/step - loss: 0.0629 - val_loss: 0.0627
# Epoch 124/500
# 32/32 [==============================] - 24s 748ms/step - loss: 0.0669 - val_loss: 0.0661
# Epoch 125/500
# 32/32 [==============================] - 24s 749ms/step - loss: 0.0660 - val_loss: 0.0645
# Epoch 126/500
# 32/32 [==============================] - 24s 754ms/step - loss: 0.0640 - val_loss: 0.0642
# Epoch 127/500
# 32/32 [==============================] - 24s 741ms/step - loss: 0.0639 - val_loss: 0.0633
# Epoch 128/500
# 32/32 [==============================] - 23s 736ms/step - loss: 0.0643 - val_loss: 0.0640
# Epoch 129/500
# 32/32 [==============================] - 24s 736ms/step - loss: 0.0641 - val_loss: 0.0645
# Epoch 130/500
# 32/32 [==============================] - 24s 743ms/step - loss: 0.0640 - val_loss: 0.0647
# Epoch 131/500
# 32/32 [==============================] - 23s 734ms/step - loss: 0.0638 - val_loss: 0.0638
# Epoch 132/500
# 32/32 [==============================] - 23s 705ms/step - loss: 0.0632 - val_loss: 0.0651
# Epoch 133/500
# 32/32 [==============================] - 22s 700ms/step - loss: 0.0636 - val_loss: 0.0641
# Epoch 134/500
# 32/32 [==============================] - 24s 740ms/step - loss: 0.0629 - val_loss: 0.0658
# Epoch 135/500
# 32/32 [==============================] - 24s 749ms/step - loss: 0.0650 - val_loss: 0.0667
# Epoch 136/500
# 32/32 [==============================] - 23s 734ms/step - loss: 0.0680 - val_loss: 0.0656
# Epoch 137/500
# 32/32 [==============================] - 24s 742ms/step - loss: 0.0652 - val_loss: 0.0645
# Epoch 138/500
# 32/32 [==============================] - 24s 751ms/step - loss: 0.0651 - val_loss: 0.0642
# Epoch 139/500
# 32/32 [==============================] - 24s 742ms/step - loss: 0.0652 - val_loss: 0.0644
# Epoch 140/500
# 32/32 [==============================] - 24s 750ms/step - loss: 0.0640 - val_loss: 0.0638
# Epoch 141/500
# 32/32 [==============================] - 24s 749ms/step - loss: 0.0625 - val_loss: 0.0631
# Epoch 142/500
# 32/32 [==============================] - 24s 745ms/step - loss: 0.0632 - val_loss: 0.0630
# Epoch 143/500
# 32/32 [==============================] - 24s 743ms/step - loss: 0.0624 - val_loss: 0.0639
# Epoch 144/500
# 32/32 [==============================] - 24s 743ms/step - loss: 0.0628 - val_loss: 0.0624
# Epoch 145/500
# 32/32 [==============================] - 24s 749ms/step - loss: 0.0620 - val_loss: 0.0627
# Epoch 146/500
# 32/32 [==============================] - 24s 741ms/step - loss: 0.0627 - val_loss: 0.0618
# Epoch 147/500
# 32/32 [==============================] - 24s 747ms/step - loss: 0.0619 - val_loss: 0.0616
# Epoch 148/500
# 32/32 [==============================] - 22s 688ms/step - loss: 0.0621 - val_loss: 0.0596
# Epoch 149/500
# 32/32 [==============================] - 22s 693ms/step - loss: 0.0616 - val_loss: 0.0585
# Epoch 150/500
# 32/32 [==============================] - 21s 664ms/step - loss: 0.0614 - val_loss: 0.0609
# Epoch 151/500
# 32/32 [==============================] - 22s 686ms/step - loss: 0.0629 - val_loss: 0.0581
# Epoch 152/500
# 32/32 [==============================] - 21s 672ms/step - loss: 0.0606 - val_loss: 0.0584
# Epoch 153/500
# 32/32 [==============================] - 22s 690ms/step - loss: 0.0612 - val_loss: 0.0580
# Epoch 154/500
# 32/32 [==============================] - 22s 692ms/step - loss: 0.0612 - val_loss: 0.0566
# Epoch 155/500
# 32/32 [==============================] - 22s 691ms/step - loss: 0.0607 - val_loss: 0.0568
# Epoch 156/500
# 32/32 [==============================] - 22s 691ms/step - loss: 0.0608 - val_loss: 0.0562
# Epoch 157/500
# 32/32 [==============================] - 22s 696ms/step - loss: 0
500
# 32/32 [==============================] - 24s 745ms/step - loss: 0.0841 - val_loss: 0.0802
# Epoch 385/500
# 32/32 [==============================] - 24s 753ms/step - loss: 0.0813 - val_loss: 0.0850
# Epoch 386/500
# 32/32 [==============================] - 24s 746ms/step - loss: 0.0851 - val_loss: 0.0822
# Epoch 387/500
# 32/32 [==============================] - 24s 752ms/step - loss: 0.0820 - val_loss: 0.0847
# Epoch 388/500
# 32/32 [==============================] - 24s 750ms/step - loss: 0.0850 - val_loss: 0.0829
# Epoch 389/500
# 32/32 [==============================] - 24s 746ms/step - loss: 0.0847 - val_loss: 0.0845
# Epoch 390/500
# 32/32 [==============================] - 24s 752ms/step - loss: 0.0845 - val_loss: 0.0864
# Epoch 391/500
# 32/32 [==============================] - 24s 747ms/step - loss: 0.0862 - val_loss: 0.0852
# Epoch 392/500
# 32/32 [==============================] - 24s 749ms/step - loss: 0.0853 - val_loss: 0.0857
# Epoch 393/500
# 32/32 [==============================] - 24s 744ms/step - loss: 0.0862 - val_loss: 0.0851
# Epoch 394/500
# 32/32 [==============================] - 24s 747ms/step - loss: 0.0849 - val_loss: 0.0867
# Epoch 395/500
# 32/32 [==============================] - 24s 753ms/step - loss: 0.0865 - val_loss: 0.0880
# Epoch 396/500
# 32/32 [==============================] - 24s 748ms/step - loss: 0.0877 - val_loss: 0.0867
# Epoch 397/500
# 32/32 [==============================] - 24s 750ms/step - loss: 0.0865 - val_loss: 0.0873
# Epoch 398/500
# 32/32 [==============================] - 24s 748ms/step - loss: 0.0876 - val_loss: 0.0898
# Epoch 399/500
# 32/32 [==============================] - 24s 753ms/step - loss: 0.0881 - val_loss: 0.0878
# Epoch 400/500
# 32/32 [==============================] - 24s 753ms/step - loss: 0.0882 - val_loss: 0.0882
# Epoch 401/500
# 32/32 [==============================] - 23s 710ms/step - loss: 0.0878 - val_loss: 0.0890
# Epoch 402/500
# 32/32 [==============================] - 23s 713ms/step - loss: 0.0879 - val_loss: 0.0940
# Epoch 403/500
# 32/32 [==============================] - 24s 741ms/step - loss: 0.0896 - val_loss: 0.0880
# Epoch 404/500
# 32/32 [==============================] - 24s 755ms/step - loss: 0.0888 - val_loss: 0.0905
# Epoch 405/500
# 32/32 [==============================] - 24s 738ms/step - loss: 0.0889 - val_loss: 0.0940
# Epoch 406/500
# 32/32 [==============================] - 24s 743ms/step - loss: 0.0919 - val_loss: 0.0923
# Epoch 407/500
# 32/32 [==============================] - 24s 740ms/step - loss: 0.0906 - val_loss: 0.0944
# Epoch 408/500
# 32/32 [==============================] - 24s 742ms/step - loss: 0.0923 - val_loss: 0.0946
# Epoch 409/500
# 32/32 [==============================] - 24s 740ms/step - loss: 0.0926 - val_loss: 0.0949
# Epoch 410/500
# 32/32 [==============================] - 24s 744ms/step - loss: 0.0933 - val_loss: 0.0950
# Epoch 411/500
# 32/32 [==============================] - 24s 745ms/step - loss: 0.0937 - val_loss: 0.0963
# Epoch 412/500
# 32/32 [==============================] - 24s 740ms/step - loss: 0.0937 - val_loss: 0.0968
# Epoch 413/500
# 32/32 [==============================] - 24s 743ms/step - loss: 0.0944 - val_loss: 0.0973
# Epoch 414/500
# 32/32 [==============================] - 24s 746ms/step - loss: 0.0955 - val_loss: 0.0974
# Epoch 415/500
# 32/32 [==============================] - 24s 750ms/step - loss: 0.0963 - val_loss: 0.0981
# Epoch 416/500
# 32/32 [==============================] - 24s 748ms/step - loss: 0.0970 - val_loss: 0.1005
# Epoch 417/500
# 32/32 [==============================] - 23s 723ms/step - loss: 0.0999 - val_loss: 0.1009
# Epoch 418/500
# 32/32 [==============================] - 22s 703ms/step - loss: 0.1011 - val_loss: 0.1024
# Epoch 419/500
# 32/32 [==============================] - 22s 701ms/step - loss: 0.1014 - val_loss: 0.1030
# Epoch 420/500
# 32/32 [==============================] - 22s 700ms/step - loss: 0.1051 - val_loss: 0.1037
# Epoch 421/500
# 32/32 [==============================] - 22s 701ms/step - loss: 0.1046 - val_loss: 0.1101
# Epoch 422/500
# 32/32 [==============================] - 22s 693ms/step - loss: 0.1082 - val_loss: 0.1110
# Epoch 423/500
# 32/32 [==============================] - 22s 698ms/step - loss: 0.1083 - val_loss: 0.1141
# Epoch 424/500
# 32/32 [==============================] - 22s 693ms/step - loss: 0.1118 - val_loss: 0.1144
# Epoch 425/500
# 32/32 [==============================] - 22s 693ms/step - loss: 0.1118 - val_loss: 0.1168
# Epoch 426/500
# 32/32 [==============================] - 22s 698ms/step - loss: 0.1158 - val_loss: 0.1176
# Epoch 427/500
# 32/32 [==============================] - 22s 697ms/step - loss: 0.1171 - val_loss: 0.1194
# Epoch 428/500
# 32/32 [==============================] - 22s 700ms/step - loss: 0
ms/step - loss: 0.0987 - val_loss: 0.1003
# Epoch 487/500
# 32/32 [==============================] - 24s 752ms/step - loss: 0.0987 - val_loss: 0.1003
# Epoch 488/500
# 32/32 [==============================] - 24s 755ms/step - loss: 0.0987 - val_loss: 0.1003
# Epoch 489/500
# 32/32 [==============================] - 24s 750ms/step - loss: 0.0987 - val_loss: 0.1003
# Epoch 490/500
# 32/32 [==============================] - 24s 750ms/step - loss: 0.0987 - val_loss: 0.1003
# Epoch 491/500
# 32/32 [==============================] - 23s 705ms/step - loss: 0.0987 - val_loss: 0.1003
# Epoch 492/500
# 32/32 [==============================] - 23s 714ms/step - loss: 0.0987 - val_loss: 0.1003
# Epoch 493/500
# 32/32 [==============================] - 24s 753ms/step - loss: 0.0987 - val_loss: 0.1003
# Epoch 494/500
# 32/32 [==============================] - 24s 754ms/step - loss: 0.0987 - val_loss: 0.1003
# Epoch 495/500
# 32/32 [==============================] - 24s 746ms/step - loss: 0.0987 - val_loss: 0.1003
# Epoch 496/500
# 32/32 [==============================] - 24s 743ms/step - loss: 0.0987 - val_loss: 0.1003
# Epoch 497/500
# 32/32 [==============================] - 24s 743ms/step - loss: 0.0987 - val_loss: 0.1003
# Epoch 498/500
# 32/32 [==============================] - 24s 739ms/step - loss: 0.0987 - val_loss: 0.1003
# Epoch 499/500
# 32/32 [==============================] - 24s 737ms/step - loss: 0.0987 - val_loss: 0.1003
# Epoch 500/500
# 32/32 [==============================] - 24s 748ms/step - loss: 0.0987 - val_loss: 0.1003
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 5 of 20). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 5 of 20). These functions will not be directly callable after loading.
# [Parallel(n_jobs=11)]: Using backend LokyBackend with 11 concurrent workers.
# [Parallel(n_jobs=11)]: Done  28 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=11)]: Done 178 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=11)]: Done 428 tasks      | elapsed: 23.8min
# [Parallel(n_jobs=11)]: Done 778 tasks      | elapsed: 43.6min
# [Parallel(n_jobs=11)]: Done 1000 out of 1000 | elapsed: 56.9min finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 2091.1min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 2091.1min finished

# %% [markdown]
# ## Evaluate Interpretation Net

# %%
if nas:
    for trial in history_list[-1]: 
        print(trial.summary())
# Out:
# Trial summary
# Hyperparameters:
# rnn_block_1/bidirectional: True
# rnn_block_1/layer_type: lstm
# rnn_block_1/num_layers: 2
# dense_block_1/use_batchnorm: False
# dense_block_1/num_layers: 2
# dense_block_1/units_0: 128
# dense_block_1/dropout: 0.0
# dense_block_1/units_1: 32
# optimizer: adam_weight_decay
# learning_rate: 0.001
# dense_block_1/units_2: 256
# Score: 0.08176565170288086
# None
# Trial summary
# Hyperparameters:
# rnn_block_1/bidirectional: True
# rnn_block_1/layer_type: lstm
# rnn_block_1/num_layers: 2
# dense_block_1/use_batchnorm: False
# dense_block_1/num_layers: 2
# dense_block_1/units_0: 128
# dense_block_1/dropout: 0.0
# dense_block_1/units_1: 32
# optimizer: adam_weight_decay
# learning_rate: 0.01
# dense_block_1/units_2: 256
# Score: 0.08594612032175064
# None
# Trial summary
# Hyperparameters:
# rnn_block_1/bidirectional: True
# rnn_block_1/layer_type: lstm
# rnn_block_1/num_layers: 2
# dense_block_1/use_batchnorm: False
# dense_block_1/num_layers: 2
# dense_block_1/units_0: 128
# dense_block_1/dropout: 0.0
# dense_block_1/units_1: 32
# optimizer: adam
# learning_rate: 0.001
# dense_block_1/units_2: 256
# Score: 0.09405026584863663
# None
# Trial summary
# Hyperparameters:
# rnn_block_1/bidirectional: True
# rnn_block_1/layer_type: lstm
# rnn_block_1/num_layers: 2
# dense_block_1/use_batchnorm: False
# dense_block_1/num_layers: 2
# dense_block_1/units_0: 1024
# dense_block_1/dropout: 0.0
# dense_block_1/units_1: 32
# optimizer: adam_weight_decay
# learning_rate: 0.001
# dense_block_1/units_2: 256
# Score: 0.10834565758705139
# None
# Trial summary
# Hyperparameters:
# rnn_block_1/bidirectional: True
# rnn_block_1/layer_type: lstm
# rnn_block_1/num_layers: 2
# dense_block_1/use_batchnorm: True
# dense_block_1/num_layers: 2
# dense_block_1/units_0: 128
# dense_block_1/dropout: 0.0
# dense_block_1/units_1: 32
# optimizer: adam
# learning_rate: 0.001
# dense_block_1/units_2: 256
# Score: 0.11302318423986435
# None

# %%
if len(model_list) >= 1:
    print(model_list[-1].summary())
    print(model_list[-1].get_config())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 4, 30)]      0
# __________________________________________________________________________________________________
# cast_to_float32 (CastToFloat32) (None, 4, 30)        0           input_1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 4, 60)        14640       cast_to_float32[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 60)           21840       bidirectional[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          7808        bidirectional_1[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 128)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           4128        re_lu[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 32)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 3)            99          re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 6)            198         re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 6)            198         re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 6)            198         re_lu_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 21)           0           dense_2[0][0]
#                                                                  dense_3[0][0]
#                                                                  dense_4[0][0]
#                                                                  dense_5[0][0]
# ==================================================================================================
# Total params: 49,109
# Trainable params: 49,109
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# {'name': 'model', 'layers': [{'class_name': 'InputLayer', 'config': {'batch_input_shape': (None, 4, 30), 'dtype': 'float64', 'sparse': False, 'ragged': False, 'name': 'input_1'}, 'name': 'input_1', 'inbound_nodes': []}, {'class_name': 'Custom>CastToFloat32', 'config': {'name': 'cast_to_float32', 'trainable': True, 'dtype': 'float32'}, 'name': 'cast_to_float32', 'inbound_nodes': [[['input_1', 0, 0, {}]]]}, {'class_name': 'Bidirectional', 'config': {'name': 'bidirectional', 'trainable': True, 'dtype': 'float32', 'layer': {'class_name': 'LSTM', 'config': {'name': 'lstm', 'trainable': True, 'dtype': 'float32', 'return_sequences': True, 'return_state': False, 'go_backwards': False, 'stateful': False, 'unroll': False, 'time_major': False, 'units': 30, 'activation': 'tanh', 'recurrent_activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'recurrent_initializer': {'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'unit_forget_bias': True, 'kernel_regularizer': None, 'recurrent_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'recurrent_constraint': None, 'bias_constraint': None, 'dropout': 0.0, 'recurrent_dropout': 0.0, 'implementation': 2}}, 'merge_mode': 'concat'}, 'name': 'bidirectional', 'inbound_nodes': [[['cast_to_float32', 0, 0, {}]]]}, {'class_name': 'Bidirectional', 'config': {'name': 'bidirectional_1', 'trainable': True, 'dtype': 'float32', 'layer': {'class_name': 'LSTM', 'config': {'name': 'lstm_1', 'trainable': True, 'dtype': 'float32', 'return_sequences': False, 'return_state': False, 'go_backwards': False, 'stateful': False, 'unroll': False, 'time_major': False, 'units': 30, 'activation': 'tanh', 'recurrent_activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'recurrent_initializer': {'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'unit_forget_bias': True, 'kernel_regularizer': None, 'recurrent_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'recurrent_constraint': None, 'bias_constraint': None, 'dropout': 0.0, 'recurrent_dropout': 0.0, 'implementation': 2}}, 'merge_mode': 'concat'}, 'name': 'bidirectional_1', 'inbound_nodes': [[['bidirectional', 0, 0, {}]]]}, {'class_name': 'Dense', 'config': {'name': 'dense', 'trainable': True, 'dtype': 'float32', 'units': 128, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'name': 'dense', 'inbound_nodes': [[['bidirectional_1', 0, 0, {}]]]}, {'class_name': 'ReLU', 'config': {'name': 're_lu', 'trainable': True, 'dtype': 'float32', 'max_value': None, 'negative_slope': array(0., dtype=float32), 'threshold': array(0., dtype=float32)}, 'name': 're_lu', 'inbound_nodes': [[['dense', 0, 0, {}]]]}, {'class_name': 'Dense', 'config': {'name': 'dense_1', 'trainable': True, 'dtype': 'float32', 'units': 32, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'name': 'dense_1', 'inbound_nodes': [[['re_lu', 0, 0, {}]]]}, {'class_name': 'ReLU', 'config': {'name': 're_lu_1', 'trainable': True, 'dtype': 'float32', 'max_value': None, 'negative_slope': array(0., dtype=float32), 'threshold': array(0., dtype=float32)}, 'name': 're_lu_1', 'inbound_nodes': [[['dense_1', 0, 0, {}]]]}, ...

# %%
if evaluate_with_real_function:
    keys = ['inetPoly_VS_targetPoly_test', 'perNetworkPoly_VS_targetPoly_test', 'predLambda_VS_targetPoly_test', 'lstsqLambda_VS_targetPoly_test', 'lstsqTarget_VS_targetPoly_test']
else:
    keys = ['inetPoly_VS_predLambda_test', 'inetPoly_VS_lstsqLambda_test', 'perNetworkPoly_VS_predLambda_test', 'perNetworkPoly_VS_lstsqLambda_test', 'lstsqLambda_VS_predLambda_test', 'predLambda_VS_targetPoly_test']

# %%
scores_list[-1]
# Out:
#                                        MAE    RMSE   MAPE  Accuracy  \
# inetPoly_VS_targetPoly_valid         0.659   0.944  6.787     0.118
# inetPoly_VS_targetPoly_test          0.690   0.973  3.754     0.118
# inetPoly_VS_predLambda_valid           NaN     NaN    NaN       NaN
# inetPoly_VS_predLambda_test            NaN     NaN    NaN       NaN
# inetPoly_VS_lstsqTarget_valid        1.601   2.431 11.305     0.103
# inetPoly_VS_lstsqTarget_test         1.611   2.477 14.120     0.104
# inetPoly_VS_lstsqLambda_valid        3.413   5.995 46.252     0.112
# inetPoly_VS_lstsqLambda_test         3.296   5.904 47.521     0.112
# lstsqLambda_VS_predLambda_valid        NaN     NaN    NaN       NaN
# lstsqLambda_VS_predLambda_test         NaN     NaN    NaN       NaN
# lstsqLambda_VS_lstsqTarget_valid     4.271   8.022 23.863     0.116
# lstsqLambda_VS_lstsqTarget_test      4.169   7.676 22.089     0.124
# lstsqLambda_VS_targetPoly_valid      4.045   7.836 16.081     0.122
# lstsqLambda_VS_targetPoly_test       3.781   7.275  6.449     0.127
# predLambda_VS_lstsqTarget_valid        NaN     NaN    NaN       NaN
# predLambda_VS_lstsqTarget_test         NaN     NaN    NaN       NaN
# predLambda_VS_targetPoly_valid         NaN     NaN    NaN       NaN
# predLambda_VS_targetPoly_test          NaN     NaN    NaN       NaN
# lstsqTarget_VS_targetPoly_valid      1.449   2.361  1.481     0.194
# lstsqTarget_VS_targetPoly_test       1.422   2.364  1.839     0.198
# perNetworkPoly_VS_targetPoly_test    0.641   0.984  3.611     0.141
# perNetworkPoly_VS_inetPoly_test    257.435 907.822  1.666     0.006
# perNetworkPoly_VS_predLambda_test      NaN     NaN    NaN       NaN
# perNetworkPoly_VS_lstsqTarget_test   1.132   1.890 10.564     0.127
# perNetworkPoly_VS_lstsqLambda_test   2.642   5.813  9.257     0.197
#
#                                     Accuracy Multilabel  MAE FV  RMSE FV  \
# inetPoly_VS_targetPoly_valid                      0.000   0.108    0.130
# inetPoly_VS_targetPoly_test                       0.001   0.114    0.137
# inetPoly_VS_predLambda_valid                        NaN   0.099    0.117
# inetPoly_VS_predLambda_test                         NaN   0.107    0.126
# inetPoly_VS_lstsqTarget_valid                     0.000   0.108    0.130
# inetPoly_VS_lstsqTarget_test                      0.000   0.114    0.138
# inetPoly_VS_lstsqLambda_valid                     0.000   0.099    0.117
# inetPoly_VS_lstsqLambda_test                      0.001   0.106    0.126
# lstsqLambda_VS_predLambda_valid                     NaN   0.004    0.006
# lstsqLambda_VS_predLambda_test                      NaN   0.004    0.005
# lstsqLambda_VS_lstsqTarget_valid                  0.000   0.023    0.030
# lstsqLambda_VS_lstsqTarget_test                   0.000   0.023    0.030
# lstsqLambda_VS_targetPoly_valid                   0.000   0.023    0.030
# lstsqLambda_VS_targetPoly_test                    0.000   0.023    0.030
# predLambda_VS_lstsqTarget_valid                     NaN   0.024    0.031
# predLambda_VS_lstsqTarget_test                      NaN   0.024    0.031
# predLambda_VS_targetPoly_valid                      NaN   0.024    0.031
# predLambda_VS_targetPoly_test                       NaN   0.024    0.031
# lstsqTarget_VS_targetPoly_valid                   0.000   0.004    0.004
# lstsqTarget_VS_targetPoly_test                    0.000   0.004    0.004
# perNetworkPoly_VS_targetPoly_test                 0.002   0.033    0.043
# perNetworkPoly_VS_inetPoly_test                   0.000   0.033    0.043
# perNetworkPoly_VS_predLambda_test                   NaN   0.021    0.028
# perNetworkPoly_VS_lstsqTarget_test                0.001   0.033    0.043
# perNetworkPoly_VS_lstsqLambda_test                0.035   0.020    0.027
#
#                                     MAPE FV    R2 FV  RAAE FV  RMAE FV  \
# inetPoly_VS_targetPoly_valid         22.201 -232.550    2.047    4.539
# inetPoly_VS_targetPoly_test        1770.835  -16.904    1.190    2.478
# inetPoly_VS_predLambda_valid         21.725 -147.805    1.685    3.999
# inetPoly_VS_predLambda_test        1695.146  -13.427    1.000    1.929
# inetPoly_VS_lstsqTarget_valid        22.192 -199.241    1.998    4.412
# inetPoly_VS_lstsqTarget_test       1777.296  -17.032    1.194    2.485
# inetPoly_VS_lstsqLambda_valid        21.737 -146.818    1.681    4.102
# inetPoly_VS_lstsqLambda_test       1695.980  -13.436    0.998    1.953
# lstsqLambda_VS_predLambda_valid       0.065    0.999    0.018    0.067
# lstsqLambda_VS_predLambda_test        0.040    0.999    0.016    0.064
# lstsqLambda_VS_lstsqTarget_valid      0.431   -1.372    0.293    0.876
# lstsqLambda_VS_lstsqTarget_test       0.204  -15.883    0.427    1.485
# lstsqLambda_VS_targetPoly_valid       0.404   -1.372    0.294    0.877
# lstsqLambda_VS_targetPoly_test        0.203  -16.713    0.428    1.503
# predLambda_VS_lstsqTarget_valid       0.196   -1.366    0.297    0.890
# predLambda_VS_lstsqTarget_test        0.237  -15.328    0.428    1.491
# predLambda_VS_targetPoly_valid        0.206   -1.366    0.298    0.891
# predLambda_VS_targetPoly_test         0.232  -16.122    0.429    1.508
# lstsqTarget_VS_targetPoly_valid       0.040    0.998    0.021    0.060
# lstsqTarget_VS_targetPoly_test        0.042    0.999    0.021    0.060
# perNetworkPoly_VS_targetPoly_test     0.447  -20.290      inf      inf
# perNetworkPoly_VS_inetPoly_test       0.447  -20.290      inf      inf
# perNetworkPoly_VS_predLambda_test     0.363    0.368      inf      inf
# perNetworkPoly_VS_lstsqTarget_test    0.454  -19.276      inf      inf
# perNetworkPoly_VS_lstsqLambda_test    0.338    0.368      inf      inf
#
#                                     MEAN STD FV DIFF  MEAN FV1  MEAN FV2  \
# inetPoly_VS_targetPoly_valid                   0.102     0.060     0.009
# inetPoly_VS_targetPoly_test                    0.105    -0.000    -0.053
# inetPoly_VS_predLambda_valid                   0.089     0.060     0.010
# inetPoly_VS_predLambda_test                    0.095    -0.000    -0.053
# inetPoly_VS_lstsqTarget_valid                  0.102     0.060     0.009
# inetPoly_VS_lstsqTarget_test                   0.105    -0.000    -0.053
# inetPoly_VS_lstsqLambda_valid                  0.089     0.060     0.010
# inetPoly_VS_lstsqLambda_test                   0.094    -0.000    -0.053
# lstsqLambda_VS_predLambda_valid                0.006     0.010     0.010
# lstsqLambda_VS_predLambda_test                 0.005    -0.053    -0.053
# lstsqLambda_VS_lstsqTarget_valid               0.029     0.010     0.009
# lstsqLambda_VS_lstsqTarget_test                0.029    -0.053    -0.053
# lstsqLambda_VS_targetPoly_valid                0.029     0.010     0.009
# lstsqLambda_VS_targetPoly_test                 0.029    -0.053    -0.053
# predLambda_VS_lstsqTarget_valid                0.031     0.010     0.009
# predLambda_VS_lstsqTarget_test                 0.031    -0.053    -0.053
# predLambda_VS_targetPoly_valid                 0.031     0.010     0.009
# predLambda_VS_targetPoly_test                  0.031    -0.053    -0.053
# lstsqTarget_VS_targetPoly_valid                0.004     0.009     0.009
# lstsqTarget_VS_targetPoly_test                 0.004    -0.053    -0.053
# perNetworkPoly_VS_targetPoly_test              0.041    -0.053    -0.053
# perNetworkPoly_VS_inetPoly_test                0.041    -0.053    -0.053
# perNetworkPoly_VS_predLambda_test              0.027    -0.053    -0.053
# perNetworkPoly_VS_lstsqTarget_test             0.041    -0.053    -0.053
# perNetworkPoly_VS_lstsqLambda_test             0.026    -0.053    -0.053
#
#                                     STD FV1  STD FV2
# inetPoly_VS_targetPoly_valid          0.750    0.785
# inetPoly_VS_targetPoly_test           0.736    0.773
# inetPoly_VS_predLambda_valid          0.750    0.781
# inetPoly_VS_predLambda_test           0.736    0.769
# inetPoly_VS_lstsqTarget_valid         0.750    0.785
# inetPoly_VS_lstsqTarget_test          0.736    0.773
# inetPoly_VS_lstsqLambda_valid         0.750    0.781
# inetPoly_VS_lstsqLambda_test          0.736    0.769
# lstsqLambda_VS_predLambda_valid       0.781    0.781
# lstsqLambda_VS_predLambda_test        0.769    0.769
# lstsqLambda_VS_lstsqTarget_valid      0.781    0.785
# lstsqLambda_VS_lstsqTarget_test       0.769    0.773
# lstsqLambda_VS_targetPoly_valid       0.781    0.785
# lstsqLambda_VS_targetPoly_test        0.769    0.773
# predLambda_VS_lstsqTarget_valid       0.781    0.785
# predLambda_VS_lstsqTarget_test        0.769    0.773
# predLambda_VS_targetPoly_valid        0.781    0.785
# predLambda_VS_targetPoly_test         0.769    0.773
# lstsqTarget_VS_targetPoly_valid       0.785    0.785
# lstsqTarget_VS_targetPoly_test        0.773    0.773
# perNetworkPoly_VS_targetPoly_test     0.771    0.773
# perNetworkPoly_VS_inetPoly_test       0.771    0.773
# perNetworkPoly_VS_predLambda_test     0.771    0.769
# perNetworkPoly_VS_lstsqTarget_test    0.771    0.773
# perNetworkPoly_VS_lstsqLambda_test    0.771    0.769

# %%
distrib_dict_list[-1]['MAE']
# Out:
#                                      L-0   L-1   L-2   L-3   L-4   L-5   L-6  \
# inetPoly_VS_targetPoly_valid       0.027 0.085 0.018 0.010 0.059 0.362 0.124
# inetPoly_VS_targetPoly_test        0.146 0.047 0.048 0.096 0.058 0.045 0.047
# inetPoly_VS_predLambda_valid       0.032 0.091 0.018 0.015 0.006 0.358 0.121
# inetPoly_VS_predLambda_test        0.146 0.045 0.045 0.098 0.010 0.049 0.035
# inetPoly_VS_lstsqTarget_valid      0.026 0.086 0.020 0.011 0.061 0.364 0.123
# inetPoly_VS_lstsqTarget_test       0.144 0.046 0.048 0.094 0.057 0.046 0.049
# inetPoly_VS_lstsqLambda_valid      0.030 0.091 0.018 0.014 0.006 0.358 0.121
# inetPoly_VS_lstsqLambda_test       0.146 0.045 0.043 0.097 0.010 0.048 0.035
# lstsqLambda_VS_predLambda_valid    0.007 0.004 0.002 0.003 0.000 0.003 0.005
# lstsqLambda_VS_predLambda_test     0.006 0.005 0.007 0.002 0.000 0.002 0.009
# lstsqLambda_VS_lstsqTarget_valid   0.019 0.010 0.009 0.008 0.058 0.009 0.009
# lstsqLambda_VS_lstsqTarget_test    0.009 0.008 0.011 0.007 0.066 0.006 0.015
# lstsqLambda_VS_targetPoly_valid    0.019 0.009 0.008 0.008 0.056 0.009 0.010
# lstsqLambda_VS_targetPoly_test     0.009 0.008 0.009 0.005 0.067 0.005 0.014
# predLambda_VS_lstsqTarget_valid    0.020 0.010 0.010 0.009 0.058 0.009 0.008
# predLambda_VS_lstsqTarget_test     0.010 0.010 0.010 0.007 0.066 0.006 0.018
# predLambda_VS_targetPoly_valid     0.021 0.010 0.009 0.008 0.056 0.009 0.010
# predLambda_VS_targetPoly_test      0.010 0.009 0.009 0.005 0.067 0.005 0.016
# lstsqTarget_VS_targetPoly_valid    0.004 0.003 0.003 0.004 0.003 0.003 0.004
# lstsqTarget_VS_targetPoly_test     0.004 0.002 0.005 0.003 0.003 0.003 0.004
# perNetworkPoly_VS_targetPoly_test  0.007 0.030 0.031 0.089 0.067 0.009 0.040
# perNetworkPoly_VS_inetPoly_test    0.007 0.030 0.031 0.089 0.067 0.009 0.040
# perNetworkPoly_VS_predLambda_test  0.012 0.029 0.026 0.091 0.000 0.007 0.032
# perNetworkPoly_VS_lstsqTarget_test 0.009 0.029 0.029 0.088 0.066 0.010 0.043
# perNetworkPoly_VS_lstsqLambda_test 0.013 0.028 0.026 0.091 0.000 0.007 0.032
#
#                                      L-7   L-8   L-9  L-10  L-11  L-12  L-13  \
# inetPoly_VS_targetPoly_valid       0.091 0.023 0.607 0.069 0.481 0.103 0.019
# inetPoly_VS_targetPoly_test        0.069 0.288 0.032 0.026 0.097 0.047 0.051
# inetPoly_VS_predLambda_valid       0.096 0.026 0.633 0.004 0.481 0.098 0.019
# inetPoly_VS_predLambda_test        0.064 0.312 0.025 0.025 0.014 0.048 0.053
# inetPoly_VS_lstsqTarget_valid      0.094 0.023 0.608 0.069 0.481 0.102 0.020
# inetPoly_VS_lstsqTarget_test       0.068 0.288 0.034 0.026 0.097 0.049 0.051
# inetPoly_VS_lstsqLambda_valid      0.095 0.024 0.633 0.004 0.480 0.099 0.020
# inetPoly_VS_lstsqLambda_test       0.063 0.312 0.027 0.025 0.014 0.047 0.054
# lstsqLambda_VS_predLambda_valid    0.013 0.007 0.000 0.001 0.004 0.007 0.003
# lstsqLambda_VS_predLambda_test     0.004 0.000 0.005 0.006 0.000 0.007 0.005
# lstsqLambda_VS_lstsqTarget_valid   0.025 0.006 0.048 0.073 0.005 0.020 0.004
# lstsqLambda_VS_lstsqTarget_test    0.009 0.104 0.010 0.005 0.109 0.010 0.019
# lstsqLambda_VS_targetPoly_valid    0.026 0.010 0.047 0.073 0.005 0.021 0.005
# lstsqLambda_VS_targetPoly_test     0.009 0.105 0.009 0.009 0.109 0.010 0.019
# predLambda_VS_lstsqTarget_valid    0.028 0.009 0.048 0.073 0.007 0.021 0.006
# predLambda_VS_lstsqTarget_test     0.009 0.104 0.013 0.006 0.109 0.013 0.019
# predLambda_VS_targetPoly_valid     0.028 0.011 0.047 0.073 0.006 0.022 0.005
# predLambda_VS_targetPoly_test      0.009 0.105 0.011 0.009 0.109 0.013 0.020
# lstsqTarget_VS_targetPoly_valid    0.004 0.005 0.003 0.001 0.001 0.003 0.004
# lstsqTarget_VS_targetPoly_test     0.003 0.002 0.004 0.005 0.002 0.004 0.003
# perNetworkPoly_VS_targetPoly_test  0.008 0.105 0.017 0.018 0.109 0.015 0.047
# perNetworkPoly_VS_inetPoly_test    0.008 0.105 0.017 0.018 0.109 0.015 0.047
# perNetworkPoly_VS_predLambda_test  0.005 0.000 0.013 0.013 0.000 0.016 0.046
# perNetworkPoly_VS_lstsqTarget_test 0.006 0.104 0.018 0.013 0.109 0.013 0.046
# perNetworkPoly_VS_lstsqLambda_test 0.005 0.000 0.014 0.012 0.000 0.014 0.045
#
#                                     L-14  L-15  L-16  L-17  L-18  L-19  L-20  \
# inetPoly_VS_targetPoly_valid       0.059 0.206 0.014 0.025 0.027 0.458 0.076
# inetPoly_VS_targetPoly_test        0.033 0.066 0.100 0.394 0.039 0.030 0.022
# inetPoly_VS_predLambda_valid       0.056 0.182 0.016 0.023 0.025 0.465 0.078
# inetPoly_VS_predLambda_test        0.031 0.063 0.097 0.388 0.041 0.027 0.021
# inetPoly_VS_lstsqTarget_valid      0.059 0.206 0.017 0.025 0.028 0.459 0.078
# inetPoly_VS_lstsqTarget_test       0.033 0.063 0.100 0.389 0.040 0.032 0.022
# inetPoly_VS_lstsqLambda_valid      0.056 0.182 0.015 0.023 0.025 0.465 0.076
# inetPoly_VS_lstsqLambda_test       0.031 0.063 0.097 0.387 0.040 0.027 0.020
# lstsqLambda_VS_predLambda_valid    0.004 0.022 0.006 0.003 0.003 0.001 0.007
# lstsqLambda_VS_predLambda_test     0.002 0.006 0.005 0.003 0.006 0.006 0.002
# lstsqLambda_VS_lstsqTarget_valid   0.010 0.049 0.006 0.006 0.006 0.012 0.009
# lstsqLambda_VS_lstsqTarget_test    0.007 0.007 0.010 0.007 0.018 0.010 0.005
# lstsqLambda_VS_targetPoly_valid    0.011 0.047 0.006 0.007 0.008 0.011 0.008
# lstsqLambda_VS_targetPoly_test     0.006 0.005 0.008 0.009 0.016 0.010 0.007
# predLambda_VS_lstsqTarget_valid    0.012 0.055 0.007 0.006 0.008 0.012 0.011
# predLambda_VS_lstsqTarget_test     0.006 0.009 0.009 0.008 0.018 0.011 0.005
# predLambda_VS_targetPoly_valid     0.012 0.053 0.007 0.007 0.009 0.011 0.010
# predLambda_VS_targetPoly_test      0.006 0.007 0.008 0.009 0.017 0.010 0.007
# lstsqTarget_VS_targetPoly_valid    0.003 0.003 0.004 0.004 0.003 0.003 0.002
# lstsqTarget_VS_targetPoly_test     0.004 0.005 0.004 0.006 0.003 0.004 0.004
# perNetworkPoly_VS_targetPoly_test  0.012 0.008 0.023 0.011 0.032 0.021 0.018
# perNetworkPoly_VS_inetPoly_test    0.012 0.008 0.023 0.011 0.032 0.021 0.018
# perNetworkPoly_VS_predLambda_test  0.010 0.008 0.017 0.009 0.037 0.016 0.015
# perNetworkPoly_VS_lstsqTarget_test 0.013 0.008 0.021 0.011 0.031 0.021 0.018
# perNetworkPoly_VS_lstsqLambda_test 0.010 0.004 0.017 0.009 0.033 0.015 0.014
#
#                                     L-21  L-22  L-23  L-24  L-25  L-26  L-27  \
# inetPoly_VS_targetPoly_valid       0.466 0.252 0.146 0.017 0.115 0.014 0.010
# inetPoly_VS_targetPoly_test        0.049 0.017 0.031 0.025 0.084 0.006 0.012
# inetPoly_VS_predLambda_valid       0.472 0.247 0.147 0.015 0.012 0.019 0.015
# inetPoly_VS_predLambda_test        0.053 0.016 0.028 0.025 0.085 0.011 0.008
# inetPoly_VS_lstsqTarget_valid      0.466 0.252 0.145 0.018 0.113 0.015 0.010
# inetPoly_VS_lstsqTarget_test       0.048 0.016 0.031 0.024 0.086 0.007 0.011
# inetPoly_VS_lstsqLambda_valid      0.471 0.248 0.146 0.015 0.012 0.018 0.015
# inetPoly_VS_lstsqLambda_test       0.054 0.016 0.026 0.025 0.082 0.011 0.008
# lstsqLambda_VS_predLambda_valid    0.007 0.002 0.007 0.002 0.000 0.006 0.000
# lstsqLambda_VS_predLambda_test     0.002 0.002 0.010 0.003 0.009 0.002 0.001
# lstsqLambda_VS_lstsqTarget_valid   0.010 0.008 0.008 0.008 0.124 0.013 0.017
# lstsqLambda_VS_lstsqTarget_test    0.011 0.014 0.018 0.007 0.020 0.006 0.011
# lstsqLambda_VS_targetPoly_valid    0.009 0.008 0.009 0.008 0.126 0.015 0.019
# lstsqLambda_VS_targetPoly_test     0.010 0.012 0.015 0.006 0.018 0.006 0.011
# predLambda_VS_lstsqTarget_valid    0.011 0.008 0.010 0.008 0.124 0.014 0.017
# predLambda_VS_lstsqTarget_test     0.011 0.014 0.022 0.007 0.021 0.006 0.011
# predLambda_VS_targetPoly_valid     0.011 0.008 0.011 0.008 0.126 0.016 0.019
# predLambda_VS_targetPoly_test      0.011 0.012 0.020 0.006 0.019 0.007 0.012
# lstsqTarget_VS_targetPoly_valid    0.002 0.002 0.004 0.003 0.004 0.004 0.005
# lstsqTarget_VS_targetPoly_test     0.002 0.003 0.004 0.003 0.003 0.003 0.004
# perNetworkPoly_VS_targetPoly_test  0.010 0.019 0.038 0.021 0.046 0.014 0.015
# perNetworkPoly_VS_inetPoly_test    0.010 0.019 0.038 0.021 0.046 0.014 0.015
# perNetworkPoly_VS_predLambda_test  0.005 0.015 0.033 0.021 0.047 0.010 0.006
# perNetworkPoly_VS_lstsqTarget_test 0.010 0.020 0.039 0.021 0.047 0.014 0.014
# perNetworkPoly_VS_lstsqLambda_test 0.005 0.015 0.033 0.021 0.043 0.010 0.006
#
#                                     L-28  L-29  L-30  L-31  L-32  L-33  L-34  \
# inetPoly_VS_targetPoly_valid       0.125 0.085 0.064 0.041 0.025 0.344 0.145
# inetPoly_VS_targetPoly_test        0.044 0.071 0.078 0.464 0.043 0.024 0.016
# inetPoly_VS_predLambda_valid       0.124 0.093 0.062 0.033 0.027 0.345 0.010
# inetPoly_VS_predLambda_test        0.042 0.002 0.005 0.477 0.018 0.021 0.022
# inetPoly_VS_lstsqTarget_valid      0.128 0.086 0.062 0.043 0.025 0.345 0.145
# inetPoly_VS_lstsqTarget_test       0.042 0.073 0.076 0.465 0.044 0.024 0.017
# inetPoly_VS_lstsqLambda_valid      0.124 0.089 0.061 0.035 0.025 0.345 0.010
# inetPoly_VS_lstsqLambda_test       0.043 0.002 0.005 0.477 0.019 0.021 0.022
# lstsqLambda_VS_predLambda_valid    0.005 0.013 0.007 0.005 0.006 0.002 0.000
# lstsqLambda_VS_predLambda_test     0.002 0.001 0.000 0.000 0.002 0.001 0.000
# lstsqLambda_VS_lstsqTarget_valid   0.011 0.018 0.012 0.020 0.012 0.006 0.153
# lstsqLambda_VS_lstsqTarget_test    0.008 0.072 0.076 0.105 0.029 0.010 0.010
# lstsqLambda_VS_targetPoly_valid    0.010 0.021 0.012 0.016 0.012 0.009 0.154
# lstsqLambda_VS_targetPoly_test     0.008 0.071 0.078 0.106 0.027 0.011 0.009
# predLambda_VS_lstsqTarget_valid    0.011 0.023 0.014 0.022 0.016 0.006 0.153
# predLambda_VS_lstsqTarget_test     0.008 0.072 0.076 0.105 0.029 0.010 0.010
# predLambda_VS_targetPoly_valid     0.011 0.026 0.013 0.018 0.016 0.009 0.154
# predLambda_VS_targetPoly_test      0.008 0.071 0.078 0.106 0.028 0.011 0.009
# lstsqTarget_VS_targetPoly_valid    0.004 0.006 0.004 0.004 0.003 0.004 0.003
# lstsqTarget_VS_targetPoly_test     0.003 0.004 0.004 0.003 0.002 0.003 0.004
# perNetworkPoly_VS_targetPoly_test  0.009 0.071 0.078 0.106 0.029 0.012 0.061
# perNetworkPoly_VS_inetPoly_test    0.009 0.071 0.078 0.106 0.029 0.012 0.061
# perNetworkPoly_VS_predLambda_test  0.007 0.000 0.000 0.000 0.011 0.002 0.058
# perNetworkPoly_VS_lstsqTarget_test 0.010 0.072 0.076 0.105 0.031 0.010 0.060
# perNetworkPoly_VS_lstsqLambda_test 0.007 0.001 0.000 0.000 0.011 0.002 0.058
#
#                                     L-35  L-36  L-37  L-38  L-39  L-40  L-41  \
# inetPoly_VS_targetPoly_valid       0.060 0.032 0.104 0.066 0.225 0.085 0.059
# inetPoly_VS_targetPoly_test        0.016 0.109 0.036 0.031 0.047 0.073 0.163
# inetPoly_VS_predLambda_valid       0.065 0.026 0.107 0.060 0.228 0.092 0.060
# inetPoly_VS_predLambda_test        0.015 0.019 0.034 0.038 0.054 0.075 0.022
# inetPoly_VS_lstsqTarget_valid      0.060 0.029 0.102 0.064 0.225 0.086 0.059
# inetPoly_VS_lstsqTarget_test       0.017 0.108 0.033 0.033 0.049 0.072 0.165
# inetPoly_VS_lstsqLambda_valid      0.063 0.026 0.107 0.059 0.227 0.091 0.060
# inetPoly_VS_lstsqLambda_test       0.013 0.019 0.034 0.036 0.053 0.073 0.022
# lstsqLambda_VS_predLambda_valid    0.012 0.002 0.005 0.004 0.004 0.002 0.006
# lstsqLambda_VS_predLambda_test     0.007 0.000 0.004 0.006 0.008 0.012 0.000
# lstsqLambda_VS_lstsqTarget_valid   0.025 0.008 0.008 0.008 0.009 0.006 0.012
# lstsqLambda_VS_lstsqTarget_test    0.010 0.112 0.007 0.023 0.020 0.022 0.185
# lstsqLambda_VS_targetPoly_valid    0.024 0.010 0.007 0.011 0.007 0.007 0.013
# lstsqLambda_VS_targetPoly_test     0.009 0.114 0.009 0.022 0.018 0.020 0.184
# predLambda_VS_lstsqTarget_valid    0.027 0.009 0.009 0.009 0.010 0.007 0.012
# predLambda_VS_lstsqTarget_test     0.012 0.112 0.008 0.025 0.021 0.025 0.185
# predLambda_VS_targetPoly_valid     0.027 0.010 0.009 0.012 0.008 0.008 0.012
# predLambda_VS_targetPoly_test      0.011 0.114 0.010 0.024 0.020 0.024 0.184
# lstsqTarget_VS_targetPoly_valid    0.004 0.005 0.003 0.003 0.002 0.004 0.004
# lstsqTarget_VS_targetPoly_test     0.002 0.004 0.004 0.003 0.004 0.003 0.006
# perNetworkPoly_VS_targetPoly_test  0.017 0.067 0.012 0.025 0.020 0.014 0.174
# perNetworkPoly_VS_inetPoly_test    0.017 0.067 0.012 0.025 0.020 0.014 0.174
# perNetworkPoly_VS_predLambda_test  0.010 0.049 0.011 0.032 0.030 0.028 0.016
# perNetworkPoly_VS_lstsqTarget_test 0.017 0.066 0.013 0.027 0.018 0.015 0.175
# perNetworkPoly_VS_lstsqLambda_test 0.011 0.049 0.011 0.032 0.029 0.025 0.016
#
#                                     L-42  L-43  L-44  L-45  L-46  L-47  L-48  \
# inetPoly_VS_targetPoly_valid       0.085 0.014 0.055 0.123 0.022 0.054 0.120
# inetPoly_VS_targetPoly_test        0.026 0.019 0.119 0.069 0.166 0.027 0.026
# inetPoly_VS_predLambda_valid       0.005 0.012 0.005 0.124 0.017 0.056 0.118
# inetPoly_VS_predLambda_test        0.027 0.020 0.118 0.020 0.171 0.028 0.031
# inetPoly_VS_lstsqTarget_valid      0.085 0.015 0.055 0.121 0.021 0.054 0.120
# inetPoly_VS_lstsqTarget_test       0.028 0.018 0.121 0.067 0.168 0.025 0.026
# inetPoly_VS_lstsqLambda_valid      0.005 0.012 0.005 0.122 0.017 0.057 0.120
# inetPoly_VS_lstsqLambda_test       0.028 0.020 0.117 0.020 0.171 0.028 0.030
# lstsqLambda_VS_predLambda_valid    0.000 0.002 0.000 0.006 0.003 0.007 0.011
# lstsqLambda_VS_predLambda_test     0.004 0.000 0.006 0.000 0.003 0.003 0.002
# lstsqLambda_VS_lstsqTarget_valid   0.081 0.006 0.058 0.005 0.005 0.010 0.017
# lstsqLambda_VS_lstsqTarget_test    0.004 0.027 0.009 0.066 0.008 0.008 0.014
# lstsqLambda_VS_targetPoly_valid    0.082 0.005 0.058 0.005 0.008 0.009 0.015
# lstsqLambda_VS_targetPoly_test     0.004 0.029 0.008 0.068 0.010 0.006 0.011
# predLambda_VS_lstsqTarget_valid    0.081 0.007 0.058 0.008 0.006 0.011 0.020
# predLambda_VS_lstsqTarget_test     0.005 0.027 0.010 0.066 0.007 0.008 0.015
# predLambda_VS_targetPoly_valid     0.082 0.006 0.058 0.008 0.008 0.010 0.018
# predLambda_VS_targetPoly_test      0.005 0.029 0.010 0.068 0.010 0.006 0.012
# lstsqTarget_VS_targetPoly_valid    0.004 0.002 0.003 0.003 0.004 0.003 0.003
# lstsqTarget_VS_targetPoly_test     0.003 0.003 0.002 0.004 0.004 0.003 0.004
# perNetworkPoly_VS_targetPoly_test  0.009 0.029 0.014 0.034 0.018 0.022 0.021
# perNetworkPoly_VS_inetPoly_test    0.009 0.029 0.014 0.034 0.018 0.022 0.021
# perNetworkPoly_VS_predLambda_test  0.009 0.000 0.013 0.049 0.015 0.020 0.012
# perNetworkPoly_VS_lstsqTarget_test 0.009 0.027 0.015 0.032 0.016 0.022 0.023
# perNetworkPoly_VS_lstsqLambda_test 0.007 0.000 0.007 0.049 0.015 0.020 0.012
#
#                                     L-49  L-50  L-51  L-52  L-53  L-54  L-55  \
# inetPoly_VS_targetPoly_valid       0.068 0.037 0.114 0.018 0.571 0.098 0.132
# inetPoly_VS_targetPoly_test        0.165 0.332 0.212 0.034 0.021 0.019 0.492
# inetPoly_VS_predLambda_valid       0.027 0.037 0.118 0.020 0.608 0.101 0.127
# inetPoly_VS_predLambda_test        0.160 0.332 0.189 0.026 0.019 0.021 0.486
# inetPoly_VS_lstsqTarget_valid      0.068 0.036 0.115 0.019 0.573 0.100 0.133
# inetPoly_VS_lstsqTarget_test       0.165 0.333 0.214 0.032 0.021 0.022 0.490
# inetPoly_VS_lstsqLambda_valid      0.027 0.037 0.116 0.020 0.608 0.101 0.127
# inetPoly_VS_lstsqLambda_test       0.159 0.331 0.189 0.027 0.018 0.020 0.486
# lstsqLambda_VS_predLambda_valid    0.000 0.005 0.007 0.004 0.000 0.002 0.006
# lstsqLambda_VS_predLambda_test     0.007 0.007 0.001 0.007 0.004 0.003 0.005
# lstsqLambda_VS_lstsqTarget_valid   0.054 0.017 0.010 0.009 0.066 0.007 0.009
# lstsqLambda_VS_lstsqTarget_test    0.008 0.009 0.077 0.010 0.007 0.010 0.008
# lstsqLambda_VS_targetPoly_valid    0.054 0.016 0.011 0.011 0.066 0.007 0.009
# lstsqLambda_VS_targetPoly_test     0.009 0.010 0.080 0.011 0.008 0.010 0.009
# predLambda_VS_lstsqTarget_valid    0.054 0.016 0.012 0.009 0.066 0.007 0.009
# predLambda_VS_lstsqTarget_test     0.009 0.011 0.077 0.012 0.010 0.011 0.009
# predLambda_VS_targetPoly_valid     0.054 0.016 0.013 0.011 0.066 0.008 0.010
# predLambda_VS_targetPoly_test      0.010 0.011 0.080 0.013 0.012 0.011 0.010
# lstsqTarget_VS_targetPoly_valid    0.003 0.003 0.004 0.003 0.004 0.002 0.003
# lstsqTarget_VS_targetPoly_test     0.003 0.005 0.005 0.003 0.003 0.003 0.003
# perNetworkPoly_VS_targetPoly_test  0.045 0.014 0.119 0.059 0.014 0.055 0.020
# perNetworkPoly_VS_inetPoly_test    0.045 0.014 0.119 0.059 0.014 0.055 0.020
# perNetworkPoly_VS_predLambda_test  0.042 0.013 0.040 0.058 0.009 0.053 0.017
# perNetworkPoly_VS_lstsqTarget_test 0.044 0.014 0.116 0.060 0.013 0.056 0.021
# perNetworkPoly_VS_lstsqLambda_test 0.043 0.014 0.040 0.058 0.009 0.054 0.016
#
#                                     L-56  L-57  L-58  L-59  L-60  L-61  L-62  \
# inetPoly_VS_targetPoly_valid       0.038 0.479 0.044 0.091 0.056 0.033 0.056
# inetPoly_VS_targetPoly_test        0.029 0.025 0.484 0.041 0.036 0.024 0.112
# inetPoly_VS_predLambda_valid       0.043 0.468 0.045 0.091 0.066 0.032 0.011
# inetPoly_VS_predLambda_test        0.036 0.011 0.487 0.048 0.041 0.024 0.108
# inetPoly_VS_lstsqTarget_valid      0.040 0.476 0.045 0.092 0.057 0.034 0.059
# inetPoly_VS_lstsqTarget_test       0.029 0.026 0.486 0.042 0.039 0.024 0.114
# inetPoly_VS_lstsqLambda_valid      0.043 0.469 0.042 0.091 0.062 0.031 0.011
# inetPoly_VS_lstsqLambda_test       0.037 0.011 0.487 0.042 0.040 0.024 0.110
# lstsqLambda_VS_predLambda_valid    0.001 0.006 0.012 0.006 0.019 0.002 0.000
# lstsqLambda_VS_predLambda_test     0.001 0.001 0.006 0.018 0.006 0.002 0.005
# lstsqLambda_VS_lstsqTarget_valid   0.009 0.008 0.015 0.008 0.023 0.007 0.065
# lstsqLambda_VS_lstsqTarget_test    0.010 0.016 0.006 0.014 0.006 0.009 0.009
# lstsqLambda_VS_targetPoly_valid    0.009 0.011 0.017 0.011 0.021 0.008 0.062
# lstsqLambda_VS_targetPoly_test     0.012 0.014 0.006 0.014 0.006 0.009 0.008
# predLambda_VS_lstsqTarget_valid    0.009 0.010 0.020 0.009 0.031 0.008 0.065
# predLambda_VS_lstsqTarget_test     0.010 0.016 0.008 0.025 0.007 0.008 0.010
# predLambda_VS_targetPoly_valid     0.009 0.012 0.022 0.012 0.029 0.008 0.062
# predLambda_VS_targetPoly_test      0.012 0.014 0.008 0.025 0.008 0.008 0.008
# lstsqTarget_VS_targetPoly_valid    0.004 0.005 0.004 0.005 0.003 0.004 0.005
# lstsqTarget_VS_targetPoly_test     0.004 0.003 0.003 0.003 0.004 0.003 0.003
# perNetworkPoly_VS_targetPoly_test  0.011 0.021 0.029 0.020 0.037 0.024 0.057
# perNetworkPoly_VS_inetPoly_test    0.011 0.021 0.029 0.020 0.037 0.024 0.057
# perNetworkPoly_VS_predLambda_test  0.004 0.009 0.027 0.031 0.041 0.021 0.054
# perNetworkPoly_VS_lstsqTarget_test 0.009 0.023 0.030 0.020 0.040 0.023 0.057
# perNetworkPoly_VS_lstsqLambda_test 0.005 0.009 0.027 0.021 0.040 0.021 0.054
#
#                                     L-63  L-64  L-65  L-66  L-67  L-68  L-69  \
# inetPoly_VS_targetPoly_valid       0.039 0.111 0.013 0.073 0.084 0.111 0.025
# inetPoly_VS_targetPoly_test        0.113 0.026 0.022 0.023 0.008 0.038 0.061
# inetPoly_VS_predLambda_valid       0.039 0.110 0.013 0.072 0.022 0.105 0.029
# inetPoly_VS_predLambda_test        0.101 0.025 0.021 0.025 0.007 0.043 0.015
# inetPoly_VS_lstsqTarget_valid      0.038 0.112 0.013 0.075 0.083 0.112 0.026
# inetPoly_VS_lstsqTarget_test       0.114 0.028 0.019 0.021 0.007 0.038 0.061
# inetPoly_VS_lstsqLambda_valid      0.039 0.109 0.013 0.073 0.022 0.105 0.029
# inetPoly_VS_lstsqLambda_test       0.101 0.024 0.022 0.023 0.007 0.042 0.015
# lstsqLambda_VS_predLambda_valid    0.001 0.004 0.004 0.003 0.001 0.003 0.006
# lstsqLambda_VS_predLambda_test     0.003 0.004 0.002 0.007 0.002 0.005 0.000
# lstsqLambda_VS_lstsqTarget_valid   0.004 0.009 0.006 0.010 0.067 0.011 0.010
# lstsqLambda_VS_lstsqTarget_test    0.015 0.009 0.010 0.008 0.008 0.010 0.049
# lstsqLambda_VS_targetPoly_valid    0.006 0.008 0.006 0.009 0.068 0.012 0.009
# lstsqLambda_VS_targetPoly_test     0.013 0.009 0.010 0.008 0.010 0.008 0.049
# predLambda_VS_lstsqTarget_valid    0.005 0.009 0.007 0.010 0.067 0.013 0.012
# predLambda_VS_lstsqTarget_test     0.015 0.009 0.010 0.010 0.008 0.010 0.049
# predLambda_VS_targetPoly_valid     0.006 0.009 0.006 0.009 0.068 0.013 0.011
# predLambda_VS_targetPoly_test      0.013 0.009 0.010 0.010 0.010 0.009 0.049
# lstsqTarget_VS_targetPoly_valid    0.005 0.004 0.004 0.003 0.003 0.003 0.003
# lstsqTarget_VS_targetPoly_test     0.003 0.003 0.004 0.004 0.002 0.004 0.002
# perNetworkPoly_VS_targetPoly_test  0.058 0.023 0.015 0.024 0.027 0.040 0.055
# perNetworkPoly_VS_inetPoly_test    0.058 0.023 0.015 0.024 0.027 0.040 0.055
# perNetworkPoly_VS_predLambda_test  0.055 0.023 0.010 0.021 0.024 0.042 0.012
# perNetworkPoly_VS_lstsqTarget_test 0.058 0.025 0.015 0.020 0.026 0.042 0.055
# perNetworkPoly_VS_lstsqLambda_test 0.056 0.022 0.009 0.020 0.024 0.042 0.012
#
#                                     L-70  L-71  L-72  L-73  L-74  L-75  L-76  \
# inetPoly_VS_targetPoly_valid       0.011 0.029 0.454 0.026 0.164 0.089 0.097
# inetPoly_VS_targetPoly_test        0.065 0.054 0.111 0.054 0.037 0.469 0.124
# inetPoly_VS_predLambda_valid       0.004 0.025 0.449 0.016 0.165 0.085 0.090
# inetPoly_VS_predLambda_test        0.063 0.027 0.024 0.004 0.022 0.472 0.013
# inetPoly_VS_lstsqTarget_valid      0.009 0.029 0.455 0.024 0.166 0.087 0.097
# inetPoly_VS_lstsqTarget_test       0.063 0.055 0.111 0.058 0.034 0.473 0.123
# inetPoly_VS_lstsqLambda_valid      0.004 0.025 0.449 0.017 0.164 0.086 0.095
# inetPoly_VS_lstsqLambda_test       0.064 0.027 0.024 0.004 0.022 0.472 0.013
# lstsqLambda_VS_predLambda_valid    0.001 0.001 0.004 0.003 0.005 0.006 0.016
# lstsqLambda_VS_predLambda_test     0.007 0.000 0.000 0.000 0.000 0.002 0.000
# lstsqLambda_VS_lstsqTarget_valid   0.010 0.009 0.012 0.011 0.006 0.017 0.028
# lstsqLambda_VS_lstsqTarget_test    0.013 0.034 0.131 0.055 0.029 0.009 0.131
# lstsqLambda_VS_targetPoly_valid    0.012 0.010 0.012 0.013 0.004 0.017 0.028
# lstsqLambda_VS_targetPoly_test     0.014 0.034 0.131 0.051 0.029 0.007 0.132
# predLambda_VS_lstsqTarget_valid    0.010 0.009 0.013 0.012 0.008 0.018 0.033
# predLambda_VS_lstsqTarget_test     0.013 0.034 0.131 0.055 0.029 0.009 0.131
# predLambda_VS_targetPoly_valid     0.012 0.009 0.013 0.014 0.008 0.017 0.032
# predLambda_VS_targetPoly_test      0.013 0.035 0.131 0.051 0.029 0.007 0.132
# lstsqTarget_VS_targetPoly_valid    0.005 0.004 0.003 0.004 0.002 0.004 0.003
# lstsqTarget_VS_targetPoly_test     0.003 0.003 0.003 0.005 0.005 0.006 0.003
# perNetworkPoly_VS_targetPoly_test  0.021 0.034 0.082 0.051 0.029 0.032 0.103
# perNetworkPoly_VS_inetPoly_test    0.021 0.034 0.082 0.051 0.029 0.032 0.103
# perNetworkPoly_VS_predLambda_test  0.017 0.000 0.053 0.000 0.000 0.029 0.030
# perNetworkPoly_VS_lstsqTarget_test 0.020 0.034 0.083 0.055 0.029 0.034 0.102
# perNetworkPoly_VS_lstsqLambda_test 0.013 0.000 0.053 0.000 0.000 0.030 0.030
#
#                                     L-77  L-78  L-79  L-80  L-81  L-82  L-83  \
# inetPoly_VS_targetPoly_valid       0.080 0.047 0.041 0.130 0.030 0.523 0.047
# inetPoly_VS_targetPoly_test        0.190 0.028 0.063 0.021 0.018 0.085 0.020
# inetPoly_VS_predLambda_valid       0.080 0.049 0.043 0.131 0.030 0.555 0.050
# inetPoly_VS_predLambda_test        0.192 0.025 0.057 0.016 0.020 0.081 0.020
# inetPoly_VS_lstsqTarget_valid      0.080 0.046 0.041 0.135 0.029 0.527 0.049
# inetPoly_VS_lstsqTarget_test       0.191 0.027 0.062 0.021 0.019 0.084 0.021
# inetPoly_VS_lstsqLambda_valid      0.079 0.050 0.043 0.131 0.030 0.555 0.051
# inetPoly_VS_lstsqLambda_test       0.192 0.025 0.058 0.017 0.020 0.082 0.021
# lstsqLambda_VS_predLambda_valid    0.005 0.007 0.004 0.004 0.005 0.000 0.006
# lstsqLambda_VS_predLambda_test     0.004 0.005 0.002 0.004 0.001 0.011 0.001
# lstsqLambda_VS_lstsqTarget_valid   0.011 0.016 0.006 0.013 0.006 0.043 0.012
# lstsqLambda_VS_lstsqTarget_test    0.009 0.011 0.008 0.007 0.012 0.013 0.007
# lstsqLambda_VS_targetPoly_valid    0.013 0.017 0.008 0.015 0.009 0.044 0.014
# lstsqLambda_VS_targetPoly_test     0.009 0.012 0.010 0.009 0.013 0.013 0.007
# predLambda_VS_lstsqTarget_valid    0.010 0.016 0.006 0.013 0.007 0.043 0.012
# predLambda_VS_lstsqTarget_test     0.010 0.012 0.009 0.009 0.012 0.015 0.008
# predLambda_VS_targetPoly_valid     0.013 0.017 0.008 0.015 0.009 0.044 0.014
# predLambda_VS_targetPoly_test      0.010 0.013 0.010 0.011 0.013 0.015 0.007
# lstsqTarget_VS_targetPoly_valid    0.006 0.003 0.002 0.006 0.005 0.005 0.004
# lstsqTarget_VS_targetPoly_test     0.002 0.002 0.004 0.004 0.003 0.002 0.005
# perNetworkPoly_VS_targetPoly_test  0.035 0.051 0.012 0.022 0.019 0.052 0.007
# perNetworkPoly_VS_inetPoly_test    0.035 0.051 0.012 0.022 0.019 0.052 0.007
# perNetworkPoly_VS_predLambda_test  0.033 0.048 0.015 0.017 0.015 0.051 0.008
# perNetworkPoly_VS_lstsqTarget_test 0.035 0.051 0.015 0.022 0.018 0.051 0.007
# perNetworkPoly_VS_lstsqLambda_test 0.034 0.047 0.015 0.017 0.015 0.051 0.008
#
#                                     L-84  L-85  L-86  L-87  L-88  L-89  L-90  \
# inetPoly_VS_targetPoly_valid       0.123 0.094 0.025 0.015 0.044 0.152 0.039
# inetPoly_VS_targetPoly_test        0.040 0.521 0.040 0.096 0.091 0.017 0.142
# inetPoly_VS_predLambda_valid       0.119 0.090 0.025 0.016 0.021 0.018 0.046
# inetPoly_VS_predLambda_test        0.035 0.541 0.042 0.017 0.098 0.012 0.147
# inetPoly_VS_lstsqTarget_valid      0.124 0.095 0.027 0.014 0.045 0.149 0.039
# inetPoly_VS_lstsqTarget_test       0.041 0.519 0.044 0.096 0.091 0.017 0.145
# inetPoly_VS_lstsqLambda_valid      0.123 0.089 0.024 0.014 0.021 0.018 0.045
# inetPoly_VS_lstsqLambda_test       0.038 0.541 0.041 0.017 0.099 0.012 0.148
# lstsqLambda_VS_predLambda_valid    0.021 0.004 0.004 0.009 0.000 0.000 0.002
# lstsqLambda_VS_predLambda_test     0.007 0.000 0.008 0.000 0.002 0.003 0.005
# lstsqLambda_VS_lstsqTarget_valid   0.045 0.012 0.008 0.011 0.046 0.154 0.008
# lstsqLambda_VS_lstsqTarget_test    0.012 0.035 0.009 0.089 0.012 0.011 0.005
# lstsqLambda_VS_targetPoly_valid    0.047 0.013 0.006 0.013 0.045 0.158 0.008
# lstsqLambda_VS_targetPoly_test     0.013 0.033 0.007 0.089 0.010 0.012 0.007
# predLambda_VS_lstsqTarget_valid    0.050 0.012 0.009 0.013 0.046 0.154 0.008
# predLambda_VS_lstsqTarget_test     0.014 0.035 0.012 0.089 0.012 0.012 0.007
# predLambda_VS_targetPoly_valid     0.052 0.014 0.007 0.014 0.045 0.158 0.009
# predLambda_VS_targetPoly_test      0.015 0.033 0.010 0.089 0.011 0.013 0.009
# lstsqTarget_VS_targetPoly_valid    0.003 0.005 0.002 0.003 0.003 0.005 0.002
# lstsqTarget_VS_targetPoly_test     0.002 0.003 0.006 0.003 0.004 0.004 0.003
# perNetworkPoly_VS_targetPoly_test  0.009 0.033 0.025 0.089 0.032 0.008 0.021
# perNetworkPoly_VS_inetPoly_test    0.009 0.033 0.025 0.089 0.032 0.008 0.021
# perNetworkPoly_VS_predLambda_test  0.014 0.000 0.023 0.000 0.028 0.010 0.018
# perNetworkPoly_VS_lstsqTarget_test 0.009 0.035 0.025 0.089 0.035 0.007 0.019
# perNetworkPoly_VS_lstsqLambda_test 0.014 0.000 0.024 0.000 0.028 0.010 0.019
#
#                                     L-91  L-92  L-93  L-94  L-95  L-96  L-97  \
# inetPoly_VS_targetPoly_valid       0.294 0.031 0.022 0.090 0.633 0.365 0.291
# inetPoly_VS_targetPoly_test        0.025 0.047 0.057 0.071 0.356 0.064 0.014
# inetPoly_VS_predLambda_valid       0.299 0.024 0.021 0.092 0.622 0.368 0.288
# inetPoly_VS_predLambda_test        0.018 0.044 0.065 0.070 0.365 0.071 0.014
# inetPoly_VS_lstsqTarget_valid      0.292 0.031 0.020 0.091 0.638 0.366 0.292
# inetPoly_VS_lstsqTarget_test       0.023 0.048 0.057 0.070 0.355 0.067 0.013
# inetPoly_VS_lstsqLambda_valid      0.299 0.023 0.021 0.094 0.622 0.367 0.288
# inetPoly_VS_lstsqLambda_test       0.018 0.044 0.065 0.069 0.365 0.070 0.015
# lstsqLambda_VS_predLambda_valid    0.000 0.003 0.000 0.011 0.001 0.004 0.002
# lstsqLambda_VS_predLambda_test     0.000 0.002 0.001 0.007 0.000 0.005 0.005
# lstsqLambda_VS_lstsqTarget_valid   0.026 0.011 0.012 0.014 0.028 0.007 0.011
# lstsqLambda_VS_lstsqTarget_test    0.037 0.006 0.011 0.012 0.032 0.013 0.008
# lstsqLambda_VS_targetPoly_valid    0.029 0.012 0.012 0.013 0.028 0.010 0.012
# lstsqLambda_VS_targetPoly_test     0.039 0.004 0.014 0.012 0.033 0.015 0.009
# predLambda_VS_lstsqTarget_valid    0.026 0.012 0.012 0.015 0.028 0.008 0.012
# predLambda_VS_lstsqTarget_test     0.037 0.006 0.011 0.011 0.032 0.013 0.008
# predLambda_VS_targetPoly_valid     0.029 0.013 0.012 0.014 0.028 0.010 0.013
# predLambda_VS_targetPoly_test      0.039 0.005 0.014 0.011 0.033 0.016 0.008
# lstsqTarget_VS_targetPoly_valid    0.002 0.002 0.005 0.003 0.006 0.005 0.002
# lstsqTarget_VS_targetPoly_test     0.004 0.004 0.004 0.002 0.005 0.005 0.003
# perNetworkPoly_VS_targetPoly_test  0.024 0.008 0.016 0.039 0.033 0.020 0.006
# perNetworkPoly_VS_inetPoly_test    0.024 0.008 0.016 0.039 0.033 0.020 0.006
# perNetworkPoly_VS_predLambda_test  0.044 0.008 0.003 0.031 0.000 0.022 0.008
# perNetworkPoly_VS_lstsqTarget_test 0.021 0.008 0.013 0.039 0.032 0.018 0.006
# perNetworkPoly_VS_lstsqLambda_test 0.044 0.007 0.003 0.031 0.000 0.022 0.008
#
#                                     L-98  L-99  L-100  L-101  L-102  L-103  \
# inetPoly_VS_targetPoly_valid       0.044 0.075  0.251  0.030  0.011  0.114
# inetPoly_VS_targetPoly_test        0.602 0.020  0.228  0.545  0.051  0.038
# inetPoly_VS_predLambda_valid       0.005 0.075  0.249  0.029  0.013  0.014
# inetPoly_VS_predLambda_test        0.606 0.027  0.225  0.546  0.008  0.026
# inetPoly_VS_lstsqTarget_valid      0.043 0.074  0.252  0.032  0.014  0.115
# inetPoly_VS_lstsqTarget_test       0.604 0.018  0.225  0.542  0.054  0.036
# inetPoly_VS_lstsqLambda_valid      0.005 0.075  0.249  0.028  0.011  0.014
# inetPoly_VS_lstsqLambda_test       0.606 0.026  0.223  0.546  0.008  0.026
# lstsqLambda_VS_predLambda_valid    0.000 0.002  0.008  0.005  0.005  0.000
# lstsqLambda_VS_predLambda_test     0.002 0.005  0.006  0.002  0.000  0.001
# lstsqLambda_VS_lstsqTarget_valid   0.041 0.012  0.007  0.009  0.007  0.103
# lstsqLambda_VS_lstsqTarget_test    0.009 0.016  0.004  0.010  0.060  0.025
# lstsqLambda_VS_targetPoly_valid    0.043 0.009  0.008  0.009  0.007  0.102
# lstsqLambda_VS_targetPoly_test     0.011 0.012  0.006  0.010  0.057  0.024
# predLambda_VS_lstsqTarget_valid    0.041 0.011  0.009  0.009  0.010  0.103
# predLambda_VS_lstsqTarget_test     0.010 0.017  0.007  0.010  0.060  0.025
# predLambda_VS_targetPoly_valid     0.043 0.009  0.011  0.010  0.010  0.102
# predLambda_VS_targetPoly_test      0.012 0.014  0.008  0.010  0.057  0.024
# lstsqTarget_VS_targetPoly_valid    0.006 0.004  0.005  0.003  0.006  0.003
# lstsqTarget_VS_targetPoly_test     0.004 0.005  0.004  0.003  0.005  0.002
# perNetworkPoly_VS_targetPoly_test  0.035 0.021  0.017  0.013  0.057  0.024
# perNetworkPoly_VS_inetPoly_test    0.035 0.021  0.017  0.013  0.057  0.024
# perNetworkPoly_VS_predLambda_test  0.035 0.022  0.017  0.007  0.000  0.004
# perNetworkPoly_VS_lstsqTarget_test 0.036 0.021  0.018  0.013  0.060  0.025
# perNetworkPoly_VS_lstsqLambda_test 0.035 0.022  0.016  0.007  0.000  0.004
#
#                                     L-104  L-105  L-106  L-107  L-108  L-109  \
# inetPoly_VS_targetPoly_valid        0.107  0.041  0.058  0.016  0.058  0.048
# inetPoly_VS_targetPoly_test         0.042  0.034  0.089  0.015  0.016  0.053
# inetPoly_VS_predLambda_valid        0.106  0.041  0.053  0.009  0.058  0.050
# inetPoly_VS_predLambda_test         0.051  0.034  0.089  0.020  0.014  0.012
# inetPoly_VS_lstsqTarget_valid       0.107  0.042  0.061  0.013  0.058  0.050
# inetPoly_VS_lstsqTarget_test        0.040  0.033  0.090  0.015  0.016  0.053
# inetPoly_VS_lstsqLambda_valid       0.105  0.040  0.053  0.009  0.058  0.049
# inetPoly_VS_lstsqLambda_test        0.051  0.033  0.091  0.020  0.013  0.012
# lstsqLambda_VS_predLambda_valid     0.006  0.005  0.007  0.002  0.005  0.007
# lstsqLambda_VS_predLambda_test      0.000  0.007  0.008  0.000  0.007  0.000
# lstsqLambda_VS_lstsqTarget_valid    0.007  0.010  0.012  0.007  0.007  0.018
# lstsqLambda_VS_lstsqTarget_test     0.019  0.013  0.007  0.016  0.005  0.052
# lstsqLambda_VS_targetPoly_valid     0.008  0.009  0.011  0.010  0.006  0.020
# lstsqLambda_VS_targetPoly_test      0.018  0.013  0.007  0.016  0.007  0.051
# predLambda_VS_lstsqTarget_valid     0.007  0.012  0.015  0.007  0.007  0.020
# predLambda_VS_lstsqTarget_test      0.019  0.014  0.009  0.016  0.008  0.052
# predLambda_VS_targetPoly_valid      0.009  0.010  0.014  0.010  0.006  0.021
# predLambda_VS_targetPoly_test       0.018  0.013  0.010  0.016  0.009  0.051
# lstsqTarget_VS_targetPoly_valid     0.002  0.006  0.005  0.004  0.003  0.003
# lstsqTarget_VS_targetPoly_test      0.002  0.003  0.002  0.002  0.004  0.004
# perNetworkPoly_VS_targetPoly_test   0.018  0.024  0.037  0.009  0.013  0.051
# perNetworkPoly_VS_inetPoly_test     0.018  0.024  0.037  0.009  0.013  0.051
# perNetworkPoly_VS_predLambda_test   0.000  0.022  0.033  0.016  0.010  0.000
# perNetworkPoly_VS_lstsqTarget_test  0.018  0.024  0.037  0.008  0.012  0.052
# perNetworkPoly_VS_lstsqLambda_test  0.000  0.019  0.032  0.016  0.008  0.000
#
#                                     L-110  L-111  L-112  L-113  L-114  L-115  \
# inetPoly_VS_targetPoly_valid        0.059  0.038  0.047  0.056  0.447  0.418
# inetPoly_VS_targetPoly_test         0.038  0.128  0.032  0.426  0.031  0.432
# inetPoly_VS_predLambda_valid        0.008  0.035  0.007  0.072  0.444  0.419
# inetPoly_VS_predLambda_test         0.026  0.024  0.033  0.436  0.030  0.446
# inetPoly_VS_lstsqTarget_valid       0.060  0.037  0.050  0.056  0.445  0.418
# inetPoly_VS_lstsqTarget_test        0.039  0.128  0.033  0.427  0.030  0.433
# inetPoly_VS_lstsqLambda_valid       0.008  0.035  0.007  0.073  0.443  0.418
# inetPoly_VS_lstsqLambda_test        0.026  0.024  0.032  0.436  0.030  0.446
# lstsqLambda_VS_predLambda_valid     0.000  0.004  0.000  0.020  0.005  0.002
# lstsqLambda_VS_predLambda_test      0.000  0.000  0.004  0.001  0.002  0.001
# lstsqLambda_VS_lstsqTarget_valid    0.066  0.009  0.054  0.045  0.005  0.012
# lstsqLambda_VS_lstsqTarget_test     0.024  0.119  0.008  0.017  0.009  0.032
# lstsqLambda_VS_targetPoly_valid     0.065  0.009  0.051  0.044  0.009  0.011
# lstsqLambda_VS_targetPoly_test      0.025  0.118  0.008  0.017  0.008  0.032
# predLambda_VS_lstsqTarget_valid     0.066  0.012  0.054  0.050  0.006  0.013
# predLambda_VS_lstsqTarget_test      0.024  0.119  0.009  0.017  0.010  0.032
# predLambda_VS_targetPoly_valid      0.065  0.012  0.052  0.049  0.009  0.012
# predLambda_VS_targetPoly_test       0.025  0.118  0.009  0.017  0.009  0.032
# lstsqTarget_VS_targetPoly_valid     0.003  0.003  0.005  0.002  0.004  0.003
# lstsqTarget_VS_targetPoly_test      0.004  0.002  0.003  0.004  0.004  0.002
# perNetworkPoly_VS_targetPoly_test   0.025  0.142  0.012  0.017  0.067  0.031
# perNetworkPoly_VS_inetPoly_test     0.025  0.142  0.012  0.017  0.067  0.031
# perNetworkPoly_VS_predLambda_test   0.001  0.030  0.012  0.000  0.073  0.000
# perNetworkPoly_VS_lstsqTarget_test  0.024  0.142  0.011  0.017  0.066  0.032
# perNetworkPoly_VS_lstsqLambda_test  0.001  0.030  0.012  0.001  0.074  0.001
#
#                                     L-116  L-117  L-118  L-119  L-120  L-121  \
# inetPoly_VS_targetPoly_valid        0.038  0.074  0.154  0.020  0.121  0.020
# inetPoly_VS_targetPoly_test         0.245  0.414  0.389  0.031  0.349  0.008
# inetPoly_VS_predLambda_valid        0.012  0.074  0.152  0.017  0.125  0.019
# inetPoly_VS_predLambda_test         0.244  0.415  0.396  0.027  0.392  0.011
# inetPoly_VS_lstsqTarget_valid       0.037  0.074  0.153  0.020  0.122  0.019
# inetPoly_VS_lstsqTarget_test        0.246  0.414  0.388  0.032  0.348  0.008
# inetPoly_VS_lstsqLambda_valid       0.012  0.073  0.151  0.017  0.124  0.018
# inetPoly_VS_lstsqLambda_test        0.244  0.413  0.395  0.027  0.392  0.011
# lstsqLambda_VS_predLambda_valid     0.000  0.006  0.006  0.003  0.018  0.005
# lstsqLambda_VS_predLambda_test      0.001  0.007  0.008  0.005  0.000  0.001
# lstsqLambda_VS_lstsqTarget_valid    0.045  0.008  0.007  0.010  0.016  0.009
# lstsqLambda_VS_lstsqTarget_test     0.008  0.008  0.018  0.014  0.072  0.013
# lstsqLambda_VS_targetPoly_valid     0.046  0.009  0.007  0.009  0.018  0.006
# lstsqLambda_VS_targetPoly_test      0.004  0.010  0.018  0.012  0.072  0.013
# predLambda_VS_lstsqTarget_valid     0.045  0.009  0.008  0.010  0.027  0.010
# predLambda_VS_lstsqTarget_test      0.008  0.010  0.022  0.014  0.072  0.012
# predLambda_VS_targetPoly_valid      0.046  0.009  0.008  0.010  0.026  0.007
# predLambda_VS_targetPoly_test       0.005  0.011  0.021  0.012  0.072  0.012
# lstsqTarget_VS_targetPoly_valid     0.003  0.001  0.003  0.004  0.005  0.005
# lstsqTarget_VS_targetPoly_test      0.004  0.004  0.007  0.004  0.004  0.002
# perNetworkPoly_VS_targetPoly_test   0.022  0.039  0.033  0.018  0.072  0.012
# perNetworkPoly_VS_inetPoly_test     0.022  0.039  0.033  0.018  0.072  0.012
# perNetworkPoly_VS_predLambda_test   0.019  0.035  0.044  0.016  0.000  0.001
# perNetworkPoly_VS_lstsqTarget_test  0.027  0.036  0.029  0.018  0.072  0.012
# perNetworkPoly_VS_lstsqLambda_test  0.019  0.033  0.041  0.015  0.000  0.001
#
#                                     L-122  L-123  L-124  L-125  L-126  L-127  \
# inetPoly_VS_targetPoly_valid        0.060  0.212  0.339  0.073  0.257  0.021
# inetPoly_VS_targetPoly_test         0.020  0.063  0.056  0.217  0.064  0.063
# inetPoly_VS_predLambda_valid        0.056  0.015  0.386  0.075  0.255  0.029
# inetPoly_VS_predLambda_test         0.023  0.006  0.050  0.196  0.069  0.063
# inetPoly_VS_lstsqTarget_valid       0.061  0.215  0.336  0.075  0.258  0.019
# inetPoly_VS_lstsqTarget_test        0.016  0.063  0.056  0.220  0.063  0.061
# inetPoly_VS_lstsqLambda_valid       0.056  0.015  0.386  0.078  0.255  0.025
# inetPoly_VS_lstsqLambda_test        0.022  0.006  0.051  0.196  0.071  0.062
# lstsqLambda_VS_predLambda_valid     0.003  0.000  0.000  0.010  0.004  0.009
# lstsqLambda_VS_predLambda_test      0.005  0.000  0.007  0.003  0.008  0.005
# lstsqLambda_VS_lstsqTarget_valid    0.006  0.228  0.140  0.020  0.006  0.013
# lstsqLambda_VS_lstsqTarget_test     0.008  0.067  0.015  0.033  0.012  0.011
# lstsqLambda_VS_targetPoly_valid     0.007  0.225  0.138  0.020  0.008  0.014
# lstsqLambda_VS_targetPoly_test      0.008  0.067  0.016  0.030  0.010  0.010
# predLambda_VS_lstsqTarget_valid     0.007  0.228  0.140  0.021  0.007  0.018
# predLambda_VS_lstsqTarget_test      0.009  0.067  0.018  0.034  0.013  0.010
# predLambda_VS_targetPoly_valid      0.008  0.225  0.138  0.021  0.009  0.018
# predLambda_VS_targetPoly_test       0.009  0.067  0.019  0.031  0.012  0.009
# lstsqTarget_VS_targetPoly_valid     0.003  0.004  0.006  0.002  0.003  0.005
# lstsqTarget_VS_targetPoly_test      0.005  0.002  0.002  0.003  0.004  0.004
# perNetworkPoly_VS_targetPoly_test   0.043  0.067  0.012  0.038  0.019  0.032
# perNetworkPoly_VS_inetPoly_test     0.043  0.067  0.012  0.038  0.019  0.032
# perNetworkPoly_VS_predLambda_test   0.038  0.000  0.016  0.013  0.015  0.033
# perNetworkPoly_VS_lstsqTarget_test  0.043  0.067  0.011  0.040  0.021  0.036
# perNetworkPoly_VS_lstsqLambda_test  0.038  0.000  0.017  0.012  0.014  0.032
#
#                                     L-128  L-129  L-130  L-131  L-132  L-133  \
# inetPoly_VS_targetPoly_valid        0.039  0.086  0.110  0.038  0.036  0.132
# inetPoly_VS_targetPoly_test         0.022  0.173  0.028  0.083  0.041  0.033
# inetPoly_VS_predLambda_valid        0.038  0.094  0.116  0.036  0.032  0.021
# inetPoly_VS_predLambda_test         0.023  0.197  0.028  0.089  0.043  0.029
# inetPoly_VS_lstsqTarget_valid       0.041  0.090  0.111  0.037  0.038  0.129
# inetPoly_VS_lstsqTarget_test        0.017  0.174  0.028  0.084  0.044  0.031
# inetPoly_VS_lstsqLambda_valid       0.038  0.092  0.115  0.036  0.033  0.021
# inetPoly_VS_lstsqLambda_test        0.023  0.197  0.028  0.090  0.042  0.029
# lstsqLambda_VS_predLambda_valid     0.006  0.006  0.003  0.006  0.009  0.000
# lstsqLambda_VS_predLambda_test      0.001  0.000  0.003  0.008  0.009  0.008
# lstsqLambda_VS_lstsqTarget_valid    0.009  0.009  0.009  0.004  0.010  0.121
# lstsqLambda_VS_lstsqTarget_test     0.011  0.058  0.009  0.017  0.012  0.019
# lstsqLambda_VS_targetPoly_valid     0.010  0.013  0.007  0.005  0.007  0.123
# lstsqLambda_VS_targetPoly_test      0.007  0.057  0.010  0.017  0.011  0.023
# predLambda_VS_lstsqTarget_valid     0.010  0.011  0.010  0.007  0.012  0.121
# predLambda_VS_lstsqTarget_test      0.011  0.058  0.010  0.018  0.012  0.021
# predLambda_VS_targetPoly_valid      0.011  0.015  0.009  0.008  0.010  0.123
# predLambda_VS_targetPoly_test       0.007  0.057  0.011  0.018  0.012  0.025
# lstsqTarget_VS_targetPoly_valid     0.003  0.005  0.003  0.002  0.003  0.003
# lstsqTarget_VS_targetPoly_test      0.007  0.004  0.004  0.003  0.003  0.005
# perNetworkPoly_VS_targetPoly_test   0.008  0.057  0.007  0.039  0.023  0.021
# perNetworkPoly_VS_inetPoly_test     0.008  0.057  0.007  0.039  0.023  0.021
# perNetworkPoly_VS_predLambda_test   0.005  0.000  0.011  0.043  0.026  0.016
# perNetworkPoly_VS_lstsqTarget_test  0.008  0.057  0.006  0.037  0.024  0.020
# perNetworkPoly_VS_lstsqLambda_test  0.005  0.000  0.010  0.045  0.024  0.016
#
#                                     L-134  L-135  L-136  L-137  L-138  L-139  \
# inetPoly_VS_targetPoly_valid        0.027  0.039  0.076  0.035  0.032  0.036
# inetPoly_VS_targetPoly_test         0.019  0.010  0.039  0.048  0.066  0.017
# inetPoly_VS_predLambda_valid        0.028  0.033  0.072  0.011  0.025  0.031
# inetPoly_VS_predLambda_test         0.014  0.016  0.033  0.044  0.026  0.012
# inetPoly_VS_lstsqTarget_valid       0.027  0.040  0.074  0.036  0.030  0.033
# inetPoly_VS_lstsqTarget_test        0.021  0.013  0.041  0.049  0.067  0.013
# inetPoly_VS_lstsqLambda_valid       0.028  0.033  0.074  0.011  0.025  0.030
# inetPoly_VS_lstsqLambda_test        0.014  0.016  0.034  0.044  0.026  0.012
# lstsqLambda_VS_predLambda_valid     0.003  0.006  0.008  0.000  0.002  0.006
# lstsqLambda_VS_predLambda_test      0.002  0.000  0.005  0.002  0.000  0.001
# lstsqLambda_VS_lstsqTarget_valid    0.008  0.011  0.011  0.030  0.006  0.007
# lstsqLambda_VS_lstsqTarget_test     0.012  0.012  0.011  0.016  0.052  0.011
# lstsqLambda_VS_targetPoly_valid     0.008  0.012  0.012  0.029  0.008  0.008
# lstsqLambda_VS_targetPoly_test      0.009  0.009  0.010  0.018  0.051  0.010
# predLambda_VS_lstsqTarget_valid     0.008  0.012  0.015  0.030  0.006  0.008
# predLambda_VS_lstsqTarget_test      0.012  0.012  0.012  0.016  0.052  0.011
# predLambda_VS_targetPoly_valid      0.009  0.013  0.015  0.029  0.008  0.009
# predLambda_VS_targetPoly_test       0.009  0.009  0.011  0.018  0.051  0.010
# lstsqTarget_VS_targetPoly_valid     0.005  0.003  0.003  0.003  0.004  0.004
# lstsqTarget_VS_targetPoly_test      0.004  0.005  0.002  0.003  0.004  0.006
# perNetworkPoly_VS_targetPoly_test   0.026  0.032  0.036  0.020  0.051  0.016
# perNetworkPoly_VS_inetPoly_test     0.026  0.032  0.036  0.020  0.051  0.016
# perNetworkPoly_VS_predLambda_test   0.019  0.040  0.029  0.014  0.000  0.009
# perNetworkPoly_VS_lstsqTarget_test  0.029  0.030  0.037  0.019  0.052  0.014
# perNetworkPoly_VS_lstsqLambda_test  0.020  0.040  0.029  0.014  0.000  0.009
#
#                                     L-140  L-141  L-142  L-143  L-144  L-145  \
# inetPoly_VS_targetPoly_valid        0.028  0.023  0.024  0.362  0.070  0.022
# inetPoly_VS_targetPoly_test         0.249  0.103  0.161  0.052  0.040  0.087
# inetPoly_VS_predLambda_valid        0.031  0.025  0.023  0.372  0.062  0.011
# inetPoly_VS_predLambda_test         0.251  0.109  0.152  0.050  0.040  0.012
# inetPoly_VS_lstsqTarget_valid       0.028  0.026  0.025  0.360  0.067  0.019
# inetPoly_VS_lstsqTarget_test        0.250  0.104  0.163  0.051  0.041  0.087
# inetPoly_VS_lstsqLambda_valid       0.030  0.025  0.023  0.372  0.064  0.010
# inetPoly_VS_lstsqLambda_test        0.251  0.105  0.153  0.052  0.040  0.012
# lstsqLambda_VS_predLambda_valid     0.004  0.002  0.001  0.003  0.006  0.001
# lstsqLambda_VS_predLambda_test      0.001  0.015  0.008  0.005  0.005  0.000
# lstsqLambda_VS_lstsqTarget_valid    0.011  0.006  0.006  0.026  0.007  0.012
# lstsqLambda_VS_lstsqTarget_test     0.017  0.028  0.010  0.005  0.013  0.096
# lstsqLambda_VS_targetPoly_valid     0.010  0.007  0.008  0.026  0.008  0.015
# lstsqLambda_VS_targetPoly_test      0.014  0.028  0.010  0.005  0.011  0.096
# predLambda_VS_lstsqTarget_valid     0.013  0.007  0.006  0.026  0.009  0.013
# predLambda_VS_lstsqTarget_test      0.018  0.033  0.012  0.007  0.012  0.096
# predLambda_VS_targetPoly_valid      0.012  0.007  0.007  0.027  0.009  0.015
# predLambda_VS_targetPoly_test       0.014  0.032  0.012  0.007  0.010  0.096
# lstsqTarget_VS_targetPoly_valid     0.002  0.005  0.004  0.002  0.004  0.004
# lstsqTarget_VS_targetPoly_test      0.004  0.003  0.004  0.002  0.004  0.003
# perNetworkPoly_VS_targetPoly_test   0.062  0.006  0.024  0.007  0.030  0.096
# perNetworkPoly_VS_inetPoly_test     0.062  0.006  0.024  0.007  0.030  0.096
# perNetworkPoly_VS_predLambda_test   0.048  0.035  0.020  0.009  0.027  0.000
# perNetworkPoly_VS_lstsqTarget_test  0.065  0.007  0.022  0.007  0.032  0.096
# perNetworkPoly_VS_lstsqLambda_test  0.048  0.032  0.021  0.008  0.026  0.000
#
#                                     L-146  L-147  L-148  L-149  L-150  L-151  \
# inetPoly_VS_targetPoly_valid        0.071  0.047  0.021  0.091  0.100  0.034
# inetPoly_VS_targetPoly_test         0.070  0.027  0.178  0.061  0.008  0.113
# inetPoly_VS_predLambda_valid        0.070  0.005  0.024  0.091  0.005  0.036
# inetPoly_VS_predLambda_test         0.072  0.028  0.180  0.048  0.021  0.007
# inetPoly_VS_lstsqTarget_valid       0.069  0.050  0.021  0.092  0.098  0.035
# inetPoly_VS_lstsqTarget_test        0.070  0.026  0.182  0.059  0.010  0.114
# inetPoly_VS_lstsqLambda_valid       0.068  0.004  0.024  0.091  0.005  0.036
# inetPoly_VS_lstsqLambda_test        0.071  0.028  0.180  0.051  0.021  0.007
# lstsqLambda_VS_predLambda_valid     0.005  0.000  0.003  0.006  0.000  0.006
# lstsqLambda_VS_predLambda_test      0.004  0.007  0.009  0.011  0.000  0.001
# lstsqLambda_VS_lstsqTarget_valid    0.009  0.048  0.010  0.008  0.103  0.007
# lstsqLambda_VS_lstsqTarget_test     0.004  0.008  0.014  0.020  0.021  0.108
# lstsqLambda_VS_targetPoly_valid     0.006  0.046  0.009  0.009  0.105  0.007
# lstsqLambda_VS_targetPoly_test      0.004  0.008  0.014  0.017  0.020  0.106
# predLambda_VS_lstsqTarget_valid     0.011  0.048  0.011  0.009  0.103  0.009
# predLambda_VS_lstsqTarget_test      0.006  0.011  0.015  0.023  0.021  0.108
# predLambda_VS_targetPoly_valid      0.008  0.046  0.010  0.010  0.105  0.009
# predLambda_VS_targetPoly_test       0.006  0.011  0.015  0.021  0.020  0.106
# lstsqTarget_VS_targetPoly_valid     0.005  0.004  0.003  0.003  0.004  0.002
# lstsqTarget_VS_targetPoly_test      0.003  0.004  0.004  0.007  0.004  0.004
# perNetworkPoly_VS_targetPoly_test   0.016  0.006  0.034  0.027  0.020  0.106
# perNetworkPoly_VS_inetPoly_test     0.016  0.006  0.034  0.027  0.020  0.106
# perNetworkPoly_VS_predLambda_test   0.013  0.010  0.038  0.027  0.001  0.000
# perNetworkPoly_VS_lstsqTarget_test  0
# lstsqTarget_VS_targetPoly_valid       NaN    NaN    NaN    NaN    NaN    NaN
# lstsqTarget_VS_targetPoly_test      0.004  0.004  0.004  0.004  0.005  0.004
# perNetworkPoly_VS_targetPoly_test   0.091  0.023  0.119  0.028  0.011  0.032
# perNetworkPoly_VS_inetPoly_test     0.091  0.023  0.119  0.028  0.011  0.032
# perNetworkPoly_VS_predLambda_test   0.089  0.024  0.000  0.033  0.005  0.038
# perNetworkPoly_VS_lstsqTarget_test  0.087  0.024  0.120  0.027  0.011  0.029
# perNetworkPoly_VS_lstsqLambda_test  0.091  0.022  0.000  0.032  0.005  0.036
#
#                                     L-993  L-994  L-995  L-996  L-997  L-998  \
# inetPoly_VS_targetPoly_valid          NaN    NaN    NaN    NaN    NaN    NaN
# inetPoly_VS_targetPoly_test         0.033  0.045  0.522  0.087  0.080  0.082
# inetPoly_VS_predLambda_valid          NaN    NaN    NaN    NaN    NaN    NaN
# inetPoly_VS_predLambda_test         0.033  0.038  0.519  0.011  0.027  0.088
# inetPoly_VS_lstsqTarget_valid         NaN    NaN    NaN    NaN    NaN    NaN
# inetPoly_VS_lstsqTarget_test        0.034  0.046  0.525  0.084  0.079  0.085
# inetPoly_VS_lstsqLambda_valid         NaN    NaN    NaN    NaN    NaN    NaN
# inetPoly_VS_lstsqLambda_test        0.033  0.038  0.520  0.011  0.027  0.088
# lstsqLambda_VS_predLambda_valid       NaN    NaN    NaN    NaN    NaN    NaN
# lstsqLambda_VS_predLambda_test      0.005  0.005  0.006  0.000  0.000  0.001
# lstsqLambda_VS_lstsqTarget_valid      NaN    NaN    NaN    NaN    NaN    NaN
# lstsqLambda_VS_lstsqTarget_test     0.010  0.013  0.007  0.094  0.069  0.006
# lstsqLambda_VS_targetPoly_valid       NaN    NaN    NaN    NaN    NaN    NaN
# lstsqLambda_VS_targetPoly_test      0.010  0.014  0.007  0.097  0.070  0.007
# predLambda_VS_lstsqTarget_valid       NaN    NaN    NaN    NaN    NaN    NaN
# predLambda_VS_lstsqTarget_test      0.011  0.016  0.009  0.094  0.069  0.006
# predLambda_VS_targetPoly_valid        NaN    NaN    NaN    NaN    NaN    NaN
# predLambda_VS_targetPoly_test       0.011  0.017  0.010  0.097  0.070  0.007
# lstsqTarget_VS_targetPoly_valid       NaN    NaN    NaN    NaN    NaN    NaN
# lstsqTarget_VS_targetPoly_test      0.002  0.003  0.006  0.006  0.003  0.006
# perNetworkPoly_VS_targetPoly_test   0.015  0.011  0.015  0.097  0.070  0.047
# perNetworkPoly_VS_inetPoly_test     0.015  0.011  0.015  0.097  0.070  0.047
# perNetworkPoly_VS_predLambda_test   0.009  0.014  0.012  0.000  0.000  0.052
# perNetworkPoly_VS_lstsqTarget_test  0.016  0.011  0.018  0.094  0.069  0.050
# perNetworkPoly_VS_lstsqLambda_test  0.009  0.014  0.012  0.000  0.000  0.053
#
#                                     L-999
# inetPoly_VS_targetPoly_valid          NaN
# inetPoly_VS_targetPoly_test         0.219
# inetPoly_VS_predLambda_valid          NaN
# inetPoly_VS_predLambda_test         0.214
# inetPoly_VS_lstsqTarget_valid         NaN
# inetPoly_VS_lstsqTarget_test        0.216
# inetPoly_VS_lstsqLambda_valid         NaN
# inetPoly_VS_lstsqLambda_test        0.214
# lstsqLambda_VS_predLambda_valid       NaN
# lstsqLambda_VS_predLambda_test      0.001
# lstsqLambda_VS_lstsqTarget_valid      NaN
# lstsqLambda_VS_lstsqTarget_test     0.006
# lstsqLambda_VS_targetPoly_valid       NaN
# lstsqLambda_VS_targetPoly_test      0.007
# predLambda_VS_lstsqTarget_valid       NaN
# predLambda_VS_lstsqTarget_test      0.006
# predLambda_VS_targetPoly_valid        NaN
# predLambda_VS_targetPoly_test       0.007
# lstsqTarget_VS_targetPoly_valid       NaN
# lstsqTarget_VS_targetPoly_test      0.004
# perNetworkPoly_VS_targetPoly_test   0.002
# perNetworkPoly_VS_inetPoly_test     0.002
# perNetworkPoly_VS_predLambda_test   0.008
# perNetworkPoly_VS_lstsqTarget_test  0.005
# perNetworkPoly_VS_lstsqLambda_test  0.008
#
# [25 rows x 1000 columns]

# %%
distrib_dict_list[-1]['R2']
# Out:
#                                      L-0   L-1   L-2   L-3    L-4     L-5  \
# inetPoly_VS_targetPoly_valid       0.997 0.939 0.953 0.986 -0.739 -25.052
# inetPoly_VS_targetPoly_test        0.119 0.953 0.994 0.883  0.482   0.977
# inetPoly_VS_predLambda_valid       0.995 0.932 0.948 0.970  0.984 -24.811
# inetPoly_VS_predLambda_test        0.148 0.959 0.995 0.882  0.974   0.972
# inetPoly_VS_lstsqTarget_valid      0.997 0.939 0.945 0.985 -0.847 -25.331
# inetPoly_VS_lstsqTarget_test       0.161 0.955 0.994 0.888  0.506   0.975
# inetPoly_VS_lstsqLambda_valid      0.995 0.933 0.949 0.970  0.984 -24.808
# inetPoly_VS_lstsqLambda_test       0.143 0.959 0.995 0.882  0.974   0.972
# lstsqLambda_VS_predLambda_valid    1.000 1.000 0.999 0.999  1.000   1.000
# lstsqLambda_VS_predLambda_test     0.999 0.999 1.000 1.000  1.000   1.000
# lstsqLambda_VS_lstsqTarget_valid   0.998 0.999 0.985 0.989 -0.618   0.994
# lstsqLambda_VS_lstsqTarget_test    0.999 0.998 1.000 1.000  0.475   0.999
# lstsqLambda_VS_targetPoly_valid    0.998 0.999 0.986 0.991 -0.525   0.994
# lstsqLambda_VS_targetPoly_test     0.999 0.999 1.000 1.000  0.448   1.000
# predLambda_VS_lstsqTarget_valid    0.998 0.999 0.984 0.988 -0.618   0.993
# predLambda_VS_lstsqTarget_test     0.998 0.998 1.000 1.000  0.475   0.999
# predLambda_VS_targetPoly_valid     0.998 0.999 0.985 0.990 -0.525   0.993
# predLambda_VS_targetPoly_test      0.998 0.998 1.000 1.000  0.448   1.000
# lstsqTarget_VS_targetPoly_valid    1.000 1.000 0.998 0.998  0.999   1.000
# lstsqTarget_VS_targetPoly_test     1.000 1.000 1.000 1.000  0.999   1.000
# perNetworkPoly_VS_targetPoly_test  0.999 0.986 0.998 0.896  0.448   0.999
# perNetworkPoly_VS_inetPoly_test    0.999 0.986 0.998 0.896  0.448   0.999
# perNetworkPoly_VS_predLambda_test  0.996 0.989 0.998 0.896  1.000   0.999
# perNetworkPoly_VS_lstsqTarget_test 0.998 0.987 0.998 0.900  0.475   0.999
# perNetworkPoly_VS_lstsqLambda_test 0.997 0.990 0.998 0.895  1.000   0.999
#
#                                       L-6   L-7    L-8    L-9     L-10  \
# inetPoly_VS_targetPoly_valid       -3.634 0.966  0.915 -1.406 -377.311
# inetPoly_VS_targetPoly_test         0.913 0.855 -4.572  0.950    0.995
# inetPoly_VS_predLambda_valid       -3.303 0.968  0.926 -1.477   -0.231
# inetPoly_VS_predLambda_test         0.952 0.873 -4.439  0.964    0.996
# inetPoly_VS_lstsqTarget_valid      -3.594 0.964  0.924 -1.421 -379.223
# inetPoly_VS_lstsqTarget_test        0.903 0.859 -4.568  0.941    0.996
# inetPoly_VS_lstsqLambda_valid      -3.309 0.969  0.930 -1.477   -0.138
# inetPoly_VS_lstsqLambda_test        0.952 0.873 -4.439  0.965    0.996
# lstsqLambda_VS_predLambda_valid     0.998 0.999  0.997  1.000    0.984
# lstsqLambda_VS_predLambda_test      0.997 1.000  1.000  0.998    1.000
# lstsqLambda_VS_lstsqTarget_valid    0.993 0.998  0.997 -0.727 -166.815
# lstsqLambda_VS_lstsqTarget_test     0.991 0.997 -2.145  0.984    1.000
# lstsqLambda_VS_targetPoly_valid     0.992 0.998  0.992 -0.674 -166.133
# lstsqLambda_VS_targetPoly_test      0.993 0.996 -2.210  0.989    0.999
# predLambda_VS_lstsqTarget_valid     0.992 0.997  0.994 -0.725 -162.119
# predLambda_VS_lstsqTarget_test      0.988 0.996 -2.147  0.982    1.000
# predLambda_VS_targetPoly_valid      0.991 0.997  0.989 -0.673 -161.456
# predLambda_VS_targetPoly_test       0.990 0.996 -2.212  0.987    0.999
# lstsqTarget_VS_targetPoly_valid     0.999 1.000  0.998  0.998    1.000
# lstsqTarget_VS_targetPoly_test      1.000 1.000  1.000  0.999    1.000
# perNetworkPoly_VS_targetPoly_test   0.957 0.997 -2.202  0.982    0.998
# perNetworkPoly_VS_inetPoly_test     0.957 0.997 -2.202  0.982    0.998
# perNetworkPoly_VS_predLambda_test   0.973 0.999  1.000  0.988    0.999
# perNetworkPoly_VS_lstsqTarget_test  0.950 0.998 -2.137  0.976    0.999
# perNetworkPoly_VS_lstsqLambda_test  0.975 0.999  1.000  0.989    0.999
#
#                                       L-11  L-12  L-13   L-14  L-15   L-16  \
# inetPoly_VS_targetPoly_valid       -47.955 0.938 0.979 -1.424 0.661  0.980
# inetPoly_VS_targetPoly_test         -0.054 0.995 0.980  0.773 0.916 -6.829
# inetPoly_VS_predLambda_valid       -47.920 0.943 0.975 -1.174 0.660  0.969
# inetPoly_VS_predLambda_test          0.970 0.993 0.979  0.791 0.926 -6.500
# inetPoly_VS_lstsqTarget_valid      -47.958 0.940 0.978 -1.501 0.664  0.973
# inetPoly_VS_lstsqTarget_test        -0.072 0.994 0.980  0.764 0.923 -6.820
# inetPoly_VS_lstsqLambda_valid      -47.883 0.943 0.977 -1.182 0.664  0.973
# inetPoly_VS_lstsqLambda_test         0.970 0.994 0.980  0.791 0.925 -6.484
# lstsqLambda_VS_predLambda_valid      1.000 1.000 0.998  0.996 0.995  0.996
# lstsqLambda_VS_predLambda_test       1.000 1.000 1.000  0.999 0.999  0.997
# lstsqLambda_VS_lstsqTarget_valid     1.000 0.997 0.998  0.961 0.977  0.993
# lstsqLambda_VS_lstsqTarget_test     -0.259 1.000 0.997  0.980 0.998  0.986
# lstsqLambda_VS_targetPoly_valid      1.000 0.997 0.998  0.964 0.979  0.994
# lstsqLambda_VS_targetPoly_test      -0.242 1.000 0.997  0.984 0.998  0.989
# predLambda_VS_lstsqTarget_valid      1.000 0.997 0.997  0.957 0.973  0.990
# predLambda_VS_lstsqTarget_test      -0.259 1.000 0.997  0.979 0.997  0.983
# predLambda_VS_targetPoly_valid       1.000 0.997 0.996  0.959 0.975  0.990
# predLambda_VS_targetPoly_test       -0.242 1.000 0.997  0.984 0.997  0.986
# lstsqTarget_VS_targetPoly_valid      1.000 1.000 0.999  0.997 1.000  0.998
# lstsqTarget_VS_targetPoly_test       1.000 1.000 1.000  0.992 0.999  0.998
# perNetworkPoly_VS_targetPoly_test   -0.242 0.999 0.977  0.932 0.997  0.945
# perNetworkPoly_VS_inetPoly_test     -0.242 0.999 0.977  0.932 0.997  0.945
# perNetworkPoly_VS_predLambda_test    1.000 0.999 0.973  0.957 0.999  0.967
# perNetworkPoly_VS_lstsqTarget_test  -0.259 1.000 0.977  0.923 0.998  0.951
# perNetworkPoly_VS_lstsqLambda_test   1.000 0.999 0.974  0.957 1.000  0.970
#
#                                      L-17  L-18   L-19  L-20     L-21   L-22  \
# inetPoly_VS_targetPoly_valid        0.990 0.986 -1.649 0.977 -166.383 -3.085
# inetPoly_VS_targetPoly_test        -2.170 0.986  0.994 0.959    0.957  0.983
# inetPoly_VS_predLambda_valid        0.994 0.989 -1.687 0.978 -169.463 -2.966
# inetPoly_VS_predLambda_test        -2.090 0.987  0.995 0.964    0.949  0.984
# inetPoly_VS_lstsqTarget_valid       0.991 0.986 -1.655 0.976 -166.678 -3.093
# inetPoly_VS_lstsqTarget_test       -2.098 0.986  0.993 0.959    0.958  0.982
# inetPoly_VS_lstsqLambda_valid       0.994 0.989 -1.686 0.977 -169.305 -2.968
# inetPoly_VS_lstsqLambda_test       -2.090 0.988  0.996 0.965    0.949  0.985
# lstsqLambda_VS_predLambda_valid     1.000 1.000  0.982 1.000    1.000  1.000
# lstsqLambda_VS_predLambda_test      0.998 1.000  1.000 1.000    1.000  0.999
# lstsqLambda_VS_lstsqTarget_valid    0.999 0.998 -0.685 1.000    0.999  0.999
# lstsqLambda_VS_lstsqTarget_test     0.987 0.997  0.999 0.998    0.997  0.985
# lstsqLambda_VS_targetPoly_valid     0.999 0.998 -0.641 1.000    0.999  0.999
# lstsqLambda_VS_targetPoly_test      0.982 0.997  0.999 0.997    0.998  0.986
# predLambda_VS_lstsqTarget_valid     0.999 0.998 -0.706 0.999    0.999  0.999
# predLambda_VS_lstsqTarget_test      0.985 0.996  0.999 0.998    0.998  0.984
# predLambda_VS_targetPoly_valid      0.999 0.998 -0.657 1.000    0.999  0.999
# predLambda_VS_targetPoly_test       0.979 0.997  0.999 0.997    0.998  0.985
# lstsqTarget_VS_targetPoly_valid     1.000 1.000  0.955 1.000    1.000  1.000
# lstsqTarget_VS_targetPoly_test      0.995 1.000  1.000 0.999    1.000  0.999
# perNetworkPoly_VS_targetPoly_test   0.968 0.987  0.997 0.976    0.999  0.974
# perNetworkPoly_VS_inetPoly_test     0.968 0.987  0.997 0.976    0.999  0.974
# perNetworkPoly_VS_predLambda_test   0.980 0.983  0.998 0.981    0.999  0.985
# perNetworkPoly_VS_lstsqTarget_test  0.973 0.989  0.998 0.972    0.999  0.973
# perNetworkPoly_VS_lstsqLambda_test  0.981 0.984  0.999 0.981    0.999  0.985
#
#                                     L-23  L-24   L-25  L-26    L-27    L-28  \
# inetPoly_VS_targetPoly_valid       0.747 0.953 -7.744 0.981   0.993 -30.271
# inetPoly_VS_targetPoly_test        0.997 0.996  0.979 0.981  -0.634   0.981
# inetPoly_VS_predLambda_valid       0.751 0.965  0.921 0.972   0.984 -28.483
# inetPoly_VS_predLambda_test        0.997 0.995  0.978 0.936  -0.088   0.982
# inetPoly_VS_lstsqTarget_valid      0.748 0.948 -7.397 0.981   0.994 -31.853
# inetPoly_VS_lstsqTarget_test       0.997 0.996  0.977 0.975  -0.684   0.982
# inetPoly_VS_lstsqLambda_valid      0.750 0.966  0.921 0.975   0.984 -28.695
# inetPoly_VS_lstsqLambda_test       0.998 0.995  0.979 0.939  -0.064   0.982
# lstsqLambda_VS_predLambda_valid    1.000 0.999  1.000 0.997   1.000   0.998
# lstsqLambda_VS_predLambda_test     1.000 1.000  1.000 0.997   0.992   1.000
# lstsqLambda_VS_lstsqTarget_valid   0.999 0.989 -7.735 0.989   0.987   0.988
# lstsqLambda_VS_lstsqTarget_test    0.999 1.000  0.998 0.971   0.265   0.999
# lstsqLambda_VS_targetPoly_valid    0.999 0.989 -8.060 0.984   0.984   0.991
# lstsqLambda_VS_targetPoly_test     0.999 1.000  0.999 0.966   0.331   0.999
# predLambda_VS_lstsqTarget_valid    0.999 0.989 -7.735 0.986   0.987   0.984
# predLambda_VS_lstsqTarget_test     0.998 0.999  0.998 0.968   0.261   0.999
# predLambda_VS_targetPoly_valid     0.999 0.989 -8.059 0.982   0.984   0.988
# predLambda_VS_targetPoly_test      0.999 1.000  0.998 0.963   0.327   0.999
# lstsqTarget_VS_targetPoly_valid    1.000 0.998  0.999 0.999   0.999   0.999
# lstsqTarget_VS_targetPoly_test     1.000 1.000  1.000 0.993   0.947   1.000
# perNetworkPoly_VS_targetPoly_test  0.996 0.996  0.987 0.907 -11.964   0.999
# perNetworkPoly_VS_inetPoly_test    0.996 0.996  0.987 0.907 -11.964   0.999
# perNetworkPoly_VS_predLambda_test  0.997 0.995  0.985 0.948  -7.378   0.999
# perNetworkPoly_VS_lstsqTarget_test 0.996 0.996  0.987 0.907 -12.266   0.999
# perNetworkPoly_VS_lstsqLambda_test 0.997 0.995  0.986 0.951  -7.282   0.999
#
#                                       L-29     L-30   L-31  L-32    L-33  \
# inetPoly_VS_targetPoly_valid         0.971    0.952  0.959 0.991 -24.242
# inetPoly_VS_targetPoly_test        -12.682 -374.823 -1.056 0.879   0.964
# inetPoly_VS_predLambda_valid         0.971    0.962  0.972 0.992 -24.231
# inetPoly_VS_predLambda_test          0.992    0.106 -1.147 0.973   0.974
# inetPoly_VS_lstsqTarget_valid        0.972    0.955  0.954 0.992 -24.348
# inetPoly_VS_lstsqTarget_test       -13.124 -365.105 -1.062 0.872   0.966
# inetPoly_VS_lstsqLambda_valid        0.972    0.961  0.972 0.992 -24.233
# inetPoly_VS_lstsqLambda_test         0.993    0.109 -1.147 0.973   0.974
# lstsqLambda_VS_predLambda_valid      0.999    1.000  0.999 1.000   1.000
# lstsqLambda_VS_predLambda_test       0.998    0.999  1.000 1.000   1.000
# lstsqLambda_VS_lstsqTarget_valid     0.999    0.999  0.987 0.998   0.999
# lstsqLambda_VS_lstsqTarget_test    -13.502 -274.545 -1.013 0.942   0.995
# lstsqLambda_VS_targetPoly_valid      0.999    0.998  0.991 0.997   0.999
# lstsqLambda_VS_targetPoly_test     -13.049 -281.760 -1.047 0.947   0.992
# predLambda_VS_lstsqTarget_valid      0.998    0.998  0.986 0.997   0.999
# predLambda_VS_lstsqTarget_test     -13.611 -274.837 -1.013 0.940   0.995
# predLambda_VS_targetPoly_valid       0.998    0.998  0.991 0.997   0.999
# predLambda_VS_targetPoly_test      -13.155 -282.058 -1.047 0.945   0.992
# lstsqTarget_VS_targetPoly_valid      1.000    1.000  0.999 1.000   1.000
# lstsqTarget_VS_targetPoly_test       0.998    0.998  1.000 1.000   0.999
# perNetworkPoly_VS_targetPoly_test  -12.616 -279.083 -1.048 0.947   0.992
# perNetworkPoly_VS_inetPoly_test    -12.616 -279.083 -1.048 0.947   0.992
# perNetworkPoly_VS_predLambda_test    0.996    0.999  1.000 0.993   1.000
# perNetworkPoly_VS_lstsqTarget_test -13.056 -271.937 -1.013 0.941   0.994
# perNetworkPoly_VS_lstsqLambda_test   0.998    1.000  1.000 0.993   1.000
#
#                                      L-34  L-35  L-36  L-37  L-38   L-39  \
# inetPoly_VS_targetPoly_valid       -1.795 0.986 0.889 0.951 0.885 -0.400
# inetPoly_VS_targetPoly_test         0.989 0.973 0.572 0.974 0.996  0.990
# inetPoly_VS_predLambda_valid        0.982 0.986 0.933 0.951 0.906 -0.440
# inetPoly_VS_predLambda_test         0.984 0.984 0.988 0.969 0.994  0.987
# inetPoly_VS_lstsqTarget_valid      -1.798 0.986 0.897 0.953 0.888 -0.386
# inetPoly_VS_lstsqTarget_test        0.989 0.965 0.572 0.976 0.996  0.989
# inetPoly_VS_lstsqLambda_valid       0.982 0.987 0.933 0.951 0.906 -0.433
# inetPoly_VS_lstsqLambda_test        0.984 0.984 0.988 0.970 0.994  0.988
# lstsqLambda_VS_predLambda_valid     1.000 0.999 1.000 1.000 1.000  1.000
# lstsqLambda_VS_predLambda_test      1.000 0.997 1.000 0.999 1.000  1.000
# lstsqLambda_VS_lstsqTarget_valid   -1.642 0.997 0.994 1.000 0.998  0.999
# lstsqLambda_VS_lstsqTarget_test     0.998 0.993 0.615 0.998 0.997  0.998
# lstsqLambda_VS_targetPoly_valid    -1.642 0.998 0.992 1.000 0.997  0.999
# lstsqLambda_VS_targetPoly_test      0.998 0.995 0.612 0.997 0.998  0.999
# predLambda_VS_lstsqTarget_valid    -1.642 0.997 0.994 0.999 0.998  0.998
# predLambda_VS_lstsqTarget_test      0.998 0.988 0.615 0.997 0.997  0.998
# predLambda_VS_targetPoly_valid     -1.642 0.997 0.992 1.000 0.997  0.999
# predLambda_VS_targetPoly_test       0.998 0.991 0.612 0.996 0.998  0.998
# lstsqTarget_VS_targetPoly_valid     1.000 1.000 0.998 1.000 1.000  1.000
# lstsqTarget_VS_targetPoly_test      1.000 0.999 1.000 1.000 1.000  1.000
# perNetworkPoly_VS_targetPoly_test   0.892 0.985 0.784 0.997 0.997  0.998
# perNetworkPoly_VS_inetPoly_test     0.892 0.985 0.784 0.997 0.997  0.998
# perNetworkPoly_VS_predLambda_test   0.898 0.991 0.922 0.993 0.994  0.995
# perNetworkPoly_VS_lstsqTarget_test  0.897 0.982 0.781 0.996 0.997  0.998
# perNetworkPoly_VS_lstsqLambda_test  0.898 0.994 0.922 0.994 0.994  0.996
#
#                                     L-40   L-41   L-42  L-43    L-44   L-45  \
# inetPoly_VS_targetPoly_valid       0.923  0.937 -7.083 0.985 -12.911 -0.972
# inetPoly_VS_targetPoly_test        0.984 -0.447  0.942 0.935   0.966  0.854
# inetPoly_VS_predLambda_valid       0.912  0.945  0.974 0.990   0.874 -0.908
# inetPoly_VS_predLambda_test        0.983  0.972  0.926 0.916   0.968  0.989
# inetPoly_VS_lstsqTarget_valid      0.921  0.939 -6.958 0.984 -12.638 -0.914
# inetPoly_VS_lstsqTarget_test       0.985 -0.420  0.931 0.937   0.965  0.863
# inetPoly_VS_lstsqLambda_valid      0.913  0.943  0.974 0.990   0.874 -0.897
# inetPoly_VS_lstsqLambda_test       0.984  0.972  0.929 0.916   0.968  0.989
# lstsqLambda_VS_predLambda_valid    1.000  1.000  1.000 1.000   1.000  0.998
# lstsqLambda_VS_predLambda_test     0.999  1.000  0.996 1.000   1.000  1.000
# lstsqLambda_VS_lstsqTarget_valid   0.999  0.999 -5.339 0.993 -15.260  0.998
# lstsqLambda_VS_lstsqTarget_test    0.998 -0.443  0.996 0.878   1.000  0.874
# lstsqLambda_VS_targetPoly_valid    0.999  0.999 -5.457 0.995 -15.562  0.998
# lstsqLambda_VS_targetPoly_test     0.998 -0.464  0.994 0.852   1.000  0.867
# predLambda_VS_lstsqTarget_valid    0.999  0.999 -5.351 0.992 -15.259  0.996
# predLambda_VS_lstsqTarget_test     0.998 -0.443  0.991 0.878   1.000  0.874
# predLambda_VS_targetPoly_valid     0.999  0.998 -5.469 0.995 -15.561  0.996
# predLambda_VS_targetPoly_test      0.998 -0.464  0.990 0.852   1.000  0.867
# lstsqTarget_VS_targetPoly_valid    1.000  1.000  0.998 1.000   0.997  1.000
# lstsqTarget_VS_targetPoly_test     1.000  1.000  0.998 0.997   1.000  1.000
# perNetworkPoly_VS_targetPoly_test  0.999 -0.511  0.985 0.852   0.999  0.951
# perNetworkPoly_VS_inetPoly_test    0.999 -0.511  0.985 0.852   0.999  0.951
# perNetworkPoly_VS_predLambda_test  0.997  0.988  0.985 1.000   0.999  0.921
# perNetworkPoly_VS_lstsqTarget_test 0.999 -0.484  0.986 0.879   0.999  0.956
# perNetworkPoly_VS_lstsqLambda_test 0.998  0.988  0.990 1.000   1.000  0.921
#
#                                       L-46  L-47  L-48   L-49   L-50    L-51  \
# inetPoly_VS_targetPoly_valid         0.995 0.994 0.699  0.668  0.988   0.769
# inetPoly_VS_targetPoly_test        -14.423 0.966 0.965 -3.772 -1.014 -73.518
# inetPoly_VS_predLambda_valid         0.996 0.994 0.697  0.938  0.991   0.772
# inetPoly_VS_predLambda_test        -15.176 0.968 0.970 -3.498 -1.017 -57.930
# inetPoly_VS_lstsqTarget_valid        0.995 0.994 0.695  0.655  0.989   0.766
# inetPoly_VS_lstsqTarget_test       -14.850 0.968 0.960 -3.782 -1.021 -74.072
# inetPoly_VS_lstsqLambda_valid        0.996 0.994 0.694  0.938  0.991   0.772
# inetPoly_VS_lstsqLambda_test       -15.170 0.967 0.970 -3.509 -1.017 -57.935
# lstsqLambda_VS_predLambda_valid      1.000 1.000 0.999  1.000  1.000   0.999
# lstsqLambda_VS_predLambda_test       0.999 0.999 1.000  0.998  1.000   1.000
# lstsqLambda_VS_lstsqTarget_valid     1.000 1.000 0.998  0.821  0.998   0.999
# lstsqLambda_VS_lstsqTarget_test      0.990 0.997 0.994  0.997  0.999   0.636
# lstsqLambda_VS_targetPoly_valid      0.999 1.000 0.998  0.824  0.998   0.998
# lstsqLambda_VS_targetPoly_test       0.986 0.998 0.996  0.997  0.999   0.615
# predLambda_VS_lstsqTarget_valid      0.999 1.000 0.997  0.821  0.997   0.998
# predLambda_VS_lstsqTarget_test       0.988 0.997 0.994  0.995  0.999   0.636
# predLambda_VS_targetPoly_valid       0.999 1.000 0.997  0.824  0.998   0.998
# predLambda_VS_targetPoly_test        0.985 0.998 0.996  0.995  0.999   0.615
# lstsqTarget_VS_targetPoly_valid      1.000 1.000 1.000  1.000  1.000   1.000
# lstsqTarget_VS_targetPoly_test       0.998 1.000 1.000  1.000  1.000   0.999
# perNetworkPoly_VS_targetPoly_test    0.963 0.983 0.989  0.926  0.998   0.214
# perNetworkPoly_VS_inetPoly_test      0.963 0.983 0.989  0.926  0.998   0.214
# perNetworkPoly_VS_predLambda_test    0.964 0.986 0.996  0.935  0.998   0.916
# perNetworkPoly_VS_lstsqTarget_test   0.968 0.981 0.986  0.927  0.999   0.248
# perNetworkPoly_VS_lstsqLambda_test   0.966 0.987 0.996  0.935  0.999   0.916
#
#                                     L-52   L-53  L-54   L-55  L-56     L-57  \
# inetPoly_VS_targetPoly_valid       0.954 -0.924 0.919 -2.297 0.666 -314.803
# inetPoly_VS_targetPoly_test        0.935  0.973 0.995 -9.750 0.983    0.927
# inetPoly_VS_predLambda_valid       0.952 -1.042 0.913 -2.144 0.632 -307.225
# inetPoly_VS_predLambda_test        0.962  0.983 0.993 -9.474 0.972    0.975
# inetPoly_VS_lstsqTarget_valid      0.947 -0.942 0.915 -2.332 0.649 -311.955
# inetPoly_VS_lstsqTarget_test       0.941  0.973 0.994 -9.683 0.984    0.920
# inetPoly_VS_lstsqLambda_valid      0.954 -1.042 0.912 -2.146 0.635 -307.074
# inetPoly_VS_lstsqLambda_test       0.963  0.984 0.993 -9.486 0.972    0.976
# lstsqLambda_VS_predLambda_valid    0.998  1.000 1.000  0.998 1.000    1.000
# lstsqLambda_VS_predLambda_test     0.997  0.999 1.000  1.000 1.000    1.000
# lstsqLambda_VS_lstsqTarget_valid   0.991 -0.651 0.999  0.993 0.968    0.998
# lstsqLambda_VS_lstsqTarget_test    0.993  0.996 0.999  1.000 0.997    0.978
# lstsqLambda_VS_targetPoly_valid    0.988 -0.607 0.999  0.993 0.971    0.997
# lstsqLambda_VS_targetPoly_test     0.992  0.995 0.999  1.000 0.997    0.983
# predLambda_VS_lstsqTarget_valid    0.988 -0.652 0.999  0.991 0.967    0.998
# predLambda_VS_lstsqTarget_test     0.988  0.996 0.998  0.999 0.997    0.978
# predLambda_VS_targetPoly_valid     0.986 -0.608 0.999  0.991 0.970    0.997
# predLambda_VS_targetPoly_test      0.988  0.994 0.999  0.999 0.997    0.982
# lstsqTarget_VS_targetPoly_valid    0.999  0.999 1.000  1.000 0.995    1.000
# lstsqTarget_VS_targetPoly_test     0.999  1.000 1.000  1.000 1.000    0.999
# perNetworkPoly_VS_targetPoly_test  0.521  0.994 0.961  0.998 0.997    0.955
# perNetworkPoly_VS_inetPoly_test    0.521  0.994 0.961  0.998 0.997    0.955
# perNetworkPoly_VS_predLambda_test  0.593  0.996 0.966  0.998 1.000    0.990
# perNetworkPoly_VS_lstsqTarget_test 0.513  0.995 0.960  0.998 0.998    0.950
# perNetworkPoly_VS_lstsqLambda_test 0.595  0.997 0.966  0.999 1.000    0.990
#
#                                      L-58  L-59  L-60  L-61    L-62  L-63  \
# inetPoly_VS_targetPoly_valid        0.993 0.805 0.993 0.928   0.265 0.989
# inetPoly_VS_targetPoly_test        -5.841 0.996 0.994 0.993 -67.752 0.762
# inetPoly_VS_predLambda_valid        0.994 0.820 0.992 0.934   0.968 0.989
# inetPoly_VS_predLambda_test        -5.924 0.995 0.993 0.992 -63.907 0.808
# inetPoly_VS_lstsqTarget_valid       0.993 0.808 0.993 0.921   0.253 0.989
# inetPoly_VS_lstsqTarget_test       -5.898 0.996 0.993 0.993 -69.409 0.758
# inetPoly_VS_lstsqLambda_valid       0.995 0.817 0.993 0.934   0.968 0.988
# inetPoly_VS_lstsqLambda_test       -5.932 0.996 0.993 0.992 -64.040 0.807
# lstsqLambda_VS_predLambda_valid     0.999 0.999 0.999 1.000   1.000 1.000
# lstsqLambda_VS_predLambda_test      1.000 0.999 1.000 1.000   0.998 1.000
# lstsqLambda_VS_lstsqTarget_valid    0.999 0.999 0.999 0.996   0.219 1.000
# lstsqLambda_VS_lstsqTarget_test     1.000 1.000 1.000 0.999   0.989 0.996
# lstsqLambda_VS_targetPoly_valid     0.999 0.998 0.999 0.995   0.238 0.999
# lstsqLambda_VS_targetPoly_test      1.000 1.000 1.000 0.999   0.991 0.996
# predLambda_VS_lstsqTarget_valid     0.999 0.998 0.998 0.996   0.217 1.000
# predLambda_VS_lstsqTarget_test      1.000 0.999 1.000 0.999   0.987 0.996
# predLambda_VS_targetPoly_valid      0.999 0.997 0.998 0.995   0.237 0.999
# predLambda_VS_targetPoly_test       1.000 0.999 1.000 0.999   0.988 0.996
# lstsqTarget_VS_targetPoly_valid     1.000 1.000 1.000 0.999   0.999 1.000
# lstsqTarget_VS_targetPoly_test      1.000 1.000 1.000 1.000   0.999 1.000
# perNetworkPoly_VS_targetPoly_test   0.997 0.999 0.995 0.995   0.652 0.927
# perNetworkPoly_VS_inetPoly_test     0.997 0.999 0.995 0.995   0.652 0.927
# perNetworkPoly_VS_predLambda_test   0.997 0.998 0.994 0.996   0.712 0.933
# perNetworkPoly_VS_lstsqTarget_test  0.997 0.999 0.994 0.996   0.660 0.925
# perNetworkPoly_VS_lstsqLambda_test  0.997 0.999 0.994 0.996   0.709 0.933
#
#                                     L-64  L-65     L-66  L-67  L-68  L-69  \
# inetPoly_VS_targetPoly_valid       0.717 0.993 -210.907 0.629 0.593 0.983
# inetPoly_VS_targetPoly_test        0.995 0.991    0.997 0.988 0.991 0.737
# inetPoly_VS_predLambda_valid       0.736 0.992 -206.162 0.977 0.626 0.978
# inetPoly_VS_predLambda_test        0.995 0.989    0.997 0.978 0.990 0.967
# inetPoly_VS_lstsqTarget_valid      0.713 0.992 -226.065 0.626 0.595 0.983
# inetPoly_VS_lstsqTarget_test       0.995 0.992    0.998 0.992 0.991 0.735
# inetPoly_VS_lstsqLambda_valid      0.733 0.993 -207.497 0.977 0.628 0.978
# inetPoly_VS_lstsqLambda_test       0.995 0.989    0.997 0.979 0.990 0.967
# lstsqLambda_VS_predLambda_valid    1.000 0.999    0.999 1.000 1.000 1.000
# lstsqLambda_VS_predLambda_test     1.000 1.000    1.000 0.999 1.000 1.000
# lstsqLambda_VS_lstsqTarget_valid   0.999 0.998    0.969 0.749 0.993 0.998
# lstsqLambda_VS_lstsqTarget_test    0.999 0.997    1.000 0.973 0.999 0.852
# lstsqLambda_VS_targetPoly_valid    0.999 0.998    0.978 0.749 0.991 0.998
# lstsqLambda_VS_targetPoly_test     0.999 0.998    1.000 0.967 1.000 0.851
# predLambda_VS_lstsqTarget_valid    0.998 0.997    0.968 0.748 0.993 0.998
# predLambda_VS_lstsqTarget_test     0.999 0.997    0.999 0.972 0.999 0.852
# predLambda_VS_targetPoly_valid     0.998 0.997    0.977 0.749 0.991 0.998
# predLambda_VS_targetPoly_test      0.999 0.997    0.999 0.966 1.000 0.851
# lstsqTarget_VS_targetPoly_valid    1.000 0.999    0.998 1.000 1.000 1.000
# lstsqTarget_VS_targetPoly_test     1.000 1.000    1.000 0.999 1.000 1.000
# perNetworkPoly_VS_targetPoly_test  0.996 0.995    0.997 0.840 0.992 0.817
# perNetworkPoly_VS_inetPoly_test    0.996 0.995    0.997 0.840 0.992 0.817
# perNetworkPoly_VS_predLambda_test  0.996 0.998    0.998 0.890 0.991 0.989
# perNetworkPoly_VS_lstsqTarget_test 0.996 0.995    0.998 0.855 0.991 0.815
# perNetworkPoly_VS_lstsqLambda_test 0.996 0.998    0.998 0.890 0.991 0.989
#
#                                      L-70  L-71   L-72   L-73   L-74    L-75  \
# inetPoly_VS_targetPoly_valid       -6.154 0.967 -3.041  0.918 -0.599   0.892
# inetPoly_VS_targetPoly_test         0.978 0.907  0.685 -1.252  0.955 -10.750
# inetPoly_VS_predLambda_valid       -0.566 0.978 -3.005  0.965 -0.629   0.895
# inetPoly_VS_predLambda_test         0.980 0.980  0.982  0.989  0.983 -10.908
# inetPoly_VS_lstsqTarget_valid      -4.502 0.969 -3.062  0.931 -0.624   0.894
# inetPoly_VS_lstsqTarget_test        0.979 0.909  0.680 -1.599  0.961 -10.968
# inetPoly_VS_lstsqLambda_valid      -0.495 0.978 -3.003  0.966 -0.622   0.895
# inetPoly_VS_lstsqLambda_test        0.980 0.980  0.982  0.989  0.983 -10.909
# lstsqLambda_VS_predLambda_valid     0.967 1.000  0.998  0.999  0.999   0.999
# lstsqLambda_VS_predLambda_test      1.000 1.000  1.000  1.000  1.000   1.000
# lstsqLambda_VS_lstsqTarget_valid   -1.411 0.998  0.985  0.987  0.999   0.996
# lstsqLambda_VS_lstsqTarget_test     0.999 0.969  0.600 -1.379  0.975   0.996
# lstsqLambda_VS_targetPoly_valid    -2.567 0.997  0.986  0.983  0.999   0.997
# lstsqLambda_VS_targetPoly_test      0.999 0.967  0.604 -1.051  0.975   0.997
# predLambda_VS_lstsqTarget_valid    -1.333 0.998  0.984  0.986  0.998   0.996
# predLambda_VS_lstsqTarget_test      0.999 0.969  0.600 -1.383  0.975   0.996
# predLambda_VS_targetPoly_valid     -2.454 0.997  0.984  0.982  0.998   0.996
# predLambda_VS_targetPoly_test       0.999 0.967  0.604 -1.055  0.975   0.997
# lstsqTarget_VS_targetPoly_valid     0.665 1.000  0.998  0.998  1.000   1.000
# lstsqTarget_VS_targetPoly_test      1.000 1.000  1.000  0.994  0.999   0.998
# perNetworkPoly_VS_targetPoly_test   0.994 0.967  0.789 -1.045  0.975   0.940
# perNetworkPoly_VS_inetPoly_test     0.994 0.967  0.789 -1.045  0.975   0.940
# perNetworkPoly_VS_predLambda_test   0.997 1.000  0.921  1.000  1.000   0.942
# perNetworkPoly_VS_lstsqTarget_test  0.995 0.969  0.783 -1.372  0.975   0.937
# perNetworkPoly_VS_lstsqLambda_test  0.998 1.000  0.921  1.000  1.000   0.941
#
#                                      L-76  L-77  L-78    L-79  L-80  L-81  \
# inetPoly_VS_targetPoly_valid        0.836 0.946 0.979   0.973 0.629 0.995
# inetPoly_VS_targetPoly_test        -0.373 0.819 0.997 -45.505 0.998 0.961
# inetPoly_VS_predLambda_valid        0.853 0.949 0.978   0.972 0.599 0.995
# inetPoly_VS_predLambda_test         0.969 0.815 0.997 -37.651 0.999 0.958
# inetPoly_VS_lstsqTarget_valid       0.837 0.944 0.980   0.973 0.599 0.996
# inetPoly_VS_lstsqTarget_test       -0.347 0.817 0.997 -45.345 0.998 0.955
# inetPoly_VS_lstsqLambda_valid       0.854 0.948 0.978   0.971 0.602 0.996
# inetPoly_VS_lstsqLambda_test        0.969 0.815 0.997 -37.546 0.999 0.959
# lstsqLambda_VS_predLambda_valid     0.996 1.000 0.999   1.000 1.000 1.000
# lstsqLambda_VS_predLambda_test      1.000 1.000 1.000   0.998 1.000 1.000
# lstsqLambda_VS_lstsqTarget_valid    0.987 0.999 0.998   0.999 0.996 1.000
# lstsqLambda_VS_lstsqTarget_test    -0.150 1.000 1.000   0.973 0.999 0.989
# lstsqLambda_VS_targetPoly_valid     0.987 0.999 0.997   0.999 0.996 0.999
# lstsqLambda_VS_targetPoly_test     -0.173 1.000 1.000   0.964 0.999 0.987
# predLambda_VS_lstsqTarget_valid     0.983 0.999 0.997   0.999 0.996 1.000
# predLambda_VS_lstsqTarget_test     -0.150 1.000 0.999   0.971 0.999 0.989
# predLambda_VS_targetPoly_valid      0.983 0.999 0.997   0.999 0.995 0.999
# predLambda_VS_targetPoly_test      -0.173 1.000 0.999   0.962 0.999 0.987
# lstsqTarget_VS_targetPoly_valid     1.000 1.000 1.000   1.000 0.999 1.000
# lstsqTarget_VS_targetPoly_test      1.000 1.000 1.000   0.995 1.000 0.999
# perNetworkPoly_VS_targetPoly_test   0.137 0.997 0.994   0.959 0.998 0.968
# perNetworkPoly_VS_inetPoly_test     0.137 0.997 0.994   0.959 0.998 0.968
# perNetworkPoly_VS_predLambda_test   0.920 0.997 0.995   0.900 0.999 0.973
# perNetworkPoly_VS_lstsqTarget_test  0.156 0.997 0.994   0.943 0.998 0.970
# perNetworkPoly_VS_lstsqLambda_test  0.920 0.997 0.995   0.902 0.999 0.974
#
#                                      L-82  L-83  L-84   L-85  L-86  L-87  \
# inetPoly_VS_targetPoly_valid       -0.532 0.956 0.918  0.940 0.946 0.999
# inetPoly_VS_targetPoly_test         0.939 0.426 0.950 -0.633 0.992 0.289
# inetPoly_VS_predLambda_valid       -0.639 0.954 0.929  0.946 0.954 0.999
# inetPoly_VS_predLambda_test         0.945 0.568 0.948 -0.687 0.992 0.982
# inetPoly_VS_lstsqTarget_valid      -0.555 0.954 0.919  0.937 0.946 0.999
# inetPoly_VS_lstsqTarget_test        0.938 0.466 0.946 -0.628 0.992 0.308
# inetPoly_VS_lstsqLambda_valid      -0.639 0.955 0.930  0.945 0.955 1.000
# inetPoly_VS_lstsqLambda_test        0.944 0.567 0.949 -0.687 0.991 0.982
# lstsqLambda_VS_predLambda_valid     1.000 0.999 0.998  1.000 0.999 1.000
# lstsqLambda_VS_predLambda_test      0.999 0.999 0.998  1.000 1.000 1.000
# lstsqLambda_VS_lstsqTarget_valid    0.702 0.998 0.989  0.999 0.994 1.000
# lstsqLambda_VS_lstsqTarget_test     0.999 0.965 0.996  0.771 1.000 0.471
# lstsqLambda_VS_targetPoly_valid     0.685 0.997 0.988  0.999 0.996 1.000
# lstsqLambda_VS_targetPoly_test      0.999 0.964 0.996  0.797 1.000 0.458
# predLambda_VS_lstsqTarget_valid     0.702 0.997 0.987  0.999 0.993 1.000
# predLambda_VS_lstsqTarget_test      0.998 0.963 0.994  0.771 0.999 0.470
# predLambda_VS_targetPoly_valid      0.685 0.996 0.986  0.999 0.995 0.999
# predLambda_VS_targetPoly_test       0.998 0.963 0.994  0.797 0.999 0.457
# lstsqTarget_VS_targetPoly_valid     0.998 1.000 1.000  1.000 1.000 1.000
# lstsqTarget_VS_targetPoly_test      1.000 0.983 1.000  0.999 1.000 1.000
# perNetworkPoly_VS_targetPoly_test   0.984 0.955 0.998  0.797 0.997 0.456
# perNetworkPoly_VS_inetPoly_test     0.984 0.955 0.998  0.797 0.997 0.456
# perNetworkPoly_VS_predLambda_test   0.984 0.955 0.992  1.000 0.997 1.000
# perNetworkPoly_VS_lstsqTarget_test  0.984 0.971 0.998  0.771 0.997 0.469
# perNetworkPoly_VS_lstsqLambda_test  0.985 0.956 0.993  1.000 0.997 1.000
#
#                                     L-88  L-89  L-90    L-91    L-92  L-93  \
# inetPoly_VS_targetPoly_valid       0.951 0.138 0.962 -43.580 -96.411 0.940
# inetPoly_VS_targetPoly_test        0.847 0.983 0.940   0.982  -8.106 0.913
# inetPoly_VS_predLambda_valid       0.989 0.987 0.951 -43.412 -65.614 0.947
# inetPoly_VS_predLambda_test        0.822 0.985 0.935   0.983  -6.625 0.885
# inetPoly_VS_lstsqTarget_valid      0.950 0.161 0.962 -43.284 -88.615 0.954
# inetPoly_VS_lstsqTarget_test       0.847 0.983 0.937   0.984  -8.273 0.912
# inetPoly_VS_lstsqLambda_valid      0.989 0.987 0.951 -43.416 -64.867 0.947
# inetPoly_VS_lstsqLambda_test       0.822 0.986 0.934   0.983  -6.567 0.885
# lstsqLambda_VS_predLambda_valid    1.000 1.000 1.000   1.000   0.992 1.000
# lstsqLambda_VS_predLambda_test     1.000 0.999 1.000   1.000   0.997 1.000
# lstsqLambda_VS_lstsqTarget_valid   0.942 0.196 0.997   0.947   0.797 0.986
# lstsqLambda_VS_lstsqTarget_test    0.997 0.989 1.000   0.961   0.959 0.996
# lstsqLambda_VS_targetPoly_valid    0.946 0.173 0.997   0.935   0.784 0.986
# lstsqLambda_VS_targetPoly_test     0.997 0.988 1.000   0.956   0.972 0.994
# predLambda_VS_lstsqTarget_valid    0.942 0.196 0.997   0.947   0.792 0.986
# predLambda_VS_lstsqTarget_test     0.997 0.989 1.000   0.961   0.954 0.996
# predLambda_VS_targetPoly_valid     0.946 0.173 0.997   0.935   0.780 0.986
# predLambda_VS_targetPoly_test      0.997 0.987 1.000   0.956   0.967 0.994
# lstsqTarget_VS_targetPoly_valid    1.000 1.000 1.000   0.999   0.995 0.997
# lstsqTarget_VS_targetPoly_test     1.000 0.999 1.000   1.000   0.992 1.000
# perNetworkPoly_VS_targetPoly_test  0.975 0.996 0.998   0.983   0.960 0.993
# perNetworkPoly_VS_inetPoly_test    0.975 0.996 0.998   0.983   0.960 0.993
# perNetworkPoly_VS_predLambda_test  0.979 0.992 0.998   0.925   0.960 1.000
# perNetworkPoly_VS_lstsqTarget_test 0.971 0.995 0.998   0.986   0.942 0.995
# perNetworkPoly_VS_lstsqLambda_test 0.979 0.994 0.998   0.925   0.964 1.000
#
#                                     L-94     L-95    L-96   L-97      L-98  \
# inetPoly_VS_targetPoly_valid       0.952   -2.778 -25.509 -3.987 -3469.530
# inetPoly_VS_targetPoly_test        0.875   -1.188   0.965  0.993    -4.835
# inetPoly_VS_predLambda_valid       0.949   -2.751 -25.964 -3.968   -33.852
# inetPoly_VS_predLambda_test        0.889   -1.240   0.963  0.992    -4.868
# inetPoly_VS_lstsqTarget_valid      0.952   -2.838 -25.809 -4.024 -3313.755
# inetPoly_VS_lstsqTarget_test       0.877   -1.185   0.962  0.995    -4.865
# inetPoly_VS_lstsqLambda_valid      0.948   -2.751 -25.957 -3.970   -33.547
# inetPoly_VS_lstsqLambda_test       0.889   -1.241   0.963  0.993    -4.868
# lstsqLambda_VS_predLambda_valid    1.000    0.996   1.000  1.000     0.990
# lstsqLambda_VS_predLambda_test     0.999    0.997   1.000  0.999     1.000
# lstsqLambda_VS_lstsqTarget_valid   0.999   -4.582   0.999  0.997  -101.624
# lstsqLambda_VS_lstsqTarget_test    0.997 -369.753   0.999  0.997     0.997
# lstsqLambda_VS_targetPoly_valid    0.999   -4.213   0.999  0.997  -107.896
# lstsqLambda_VS_targetPoly_test     0.996 -424.770   0.999  0.996     0.995
# predLambda_VS_lstsqTarget_valid    0.999   -4.603   0.999  0.997  -100.027
# predLambda_VS_lstsqTarget_test     0.996 -371.578   0.999  0.996     0.996
# predLambda_VS_targetPoly_valid     0.999   -4.233   0.999  0.997  -106.190
# predLambda_VS_targetPoly_test      0.996 -426.845   0.999  0.995     0.995
# lstsqTarget_VS_targetPoly_valid    1.000    0.971   1.000  1.000     0.986
# lstsqTarget_VS_targetPoly_test     1.000    0.977   1.000  1.000     0.999
# perNetworkPoly_VS_targetPoly_test  0.971 -422.087   0.998  0.997     0.959
# perNetworkPoly_VS_inetPoly_test    0.971 -422.087   0.998  0.997     0.959
# perNetworkPoly_VS_predLambda_test  0.982    0.996   0.997  0.997     0.958
# perNetworkPoly_VS_lstsqTarget_test 0.972 -367.396   0.998  0.998     0.955
# perNetworkPoly_VS_lstsqLambda_test 0.982    1.000   0.997  0.998     0.959
#
#                                     L-99  L-100  L-101   L-102  L-103  L-104  \
# inetPoly_VS_targetPoly_valid       0.891  0.209  0.956   0.960 -0.821  0.888
# inetPoly_VS_targetPoly_test        0.995  0.760 -1.087 -18.808  0.955  0.987
# inetPoly_VS_predLambda_valid       0.886  0.214  0.964   0.961  0.958  0.897
# inetPoly_VS_predLambda_test        0.993  0.768 -1.090   0.581  0.979  0.982
# inetPoly_VS_lstsqTarget_valid      0.892  0.202  0.951   0.945 -0.809  0.888
# inetPoly_VS_lstsqTarget_test       0.995  0.767 -1.069 -21.119  0.958  0.988
# inetPoly_VS_lstsqLambda_valid      0.886  0.215  0.965   0.966  0.958  0.895
# inetPoly_VS_lstsqLambda_test       0.993  0.768 -1.088   0.582  0.979  0.982
# lstsqLambda_VS_predLambda_valid    1.000  1.000  0.999   0.993  1.000  1.000
# lstsqLambda_VS_predLambda_test     1.000  1.000  0.998   1.000  1.000  1.000
# lstsqLambda_VS_lstsqTarget_valid   0.997  1.000  0.994   0.973 -0.323  1.000
# lstsqLambda_VS_lstsqTarget_test    0.997  1.000  0.963 -15.789  0.981  0.997
# lstsqLambda_VS_targetPoly_valid    0.998  0.999  0.994   0.961 -0.325  0.999
# lstsqLambda_VS_targetPoly_test     0.998  1.000  0.963 -14.243  0.981  0.997
# predLambda_VS_lstsqTarget_valid    0.997  0.999  0.992   0.968 -0.323  0.999
# predLambda_VS_lstsqTarget_test     0.997  1.000  0.960 -15.776  0.981  0.997
# predLambda_VS_targetPoly_valid     0.998  0.999  0.993   0.958 -0.325  0.999
# predLambda_VS_targetPoly_test      0.998  1.000  0.960 -14.231  0.981  0.997
# lstsqTarget_VS_targetPoly_valid    0.999  1.000  0.999   0.991  0.999  1.000
# lstsqTarget_VS_targetPoly_test     1.000  1.000  0.996   0.993  1.000  1.000
# perNetworkPoly_VS_targetPoly_test  0.996  0.999  0.937 -14.258  0.980  0.997
# perNetworkPoly_VS_inetPoly_test    0.996  0.999  0.937 -14.258  0.980  0.997
# perNetworkPoly_VS_predLambda_test  0.995  0.999  0.969   1.000  1.000  1.000
# perNetworkPoly_VS_lstsqTarget_test 0.996  0.999  0.931 -15.806  0.980  0.997
# perNetworkPoly_VS_lstsqLambda_test 0.995  0.999  0.972   1.000  1.000  1.000
#
#                                     L-105  L-106  L-107  L-108  L-109  L-110  \
# inetPoly_VS_targetPoly_valid        0.981  0.963  0.978  0.960  0.985  0.301
# inetPoly_VS_targetPoly_test         0.998  0.942  0.991  0.997  0.736  0.974
# inetPoly_VS_predLambda_valid        0.983  0.967  0.990  0.962  0.984  0.977
# inetPoly_VS_predLambda_test         0.998  0.943  0.978  0.998  0.981  0.988
# inetPoly_VS_lstsqTarget_valid       0.981  0.959  0.985  0.960  0.984  0.296
# inetPoly_VS_lstsqTarget_test        0.998  0.941  0.993  0.997  0.735  0.973
# inetPoly_VS_lstsqLambda_valid       0.983  0.967  0.991  0.962  0.985  0.977
# inetPoly_VS_lstsqLambda_test        0.998  0.942  0.978  0.998  0.981  0.988
# lstsqLambda_VS_predLambda_valid     1.000  0.999  0.999  1.000  1.000  1.000
# lstsqLambda_VS_predLambda_test      1.000  1.000  1.000  0.999  1.000  1.000
# lstsqLambda_VS_lstsqTarget_valid    0.999  0.998  0.993  0.999  0.998  0.351
# lstsqLambda_VS_lstsqTarget_test     1.000  1.000  0.991  0.999  0.818  0.987
# lstsqLambda_VS_targetPoly_valid     0.999  0.998  0.986  1.000  0.997  0.355
# lstsqLambda_VS_targetPoly_test      1.000  1.000  0.993  0.999  0.818  0.985
# predLambda_VS_lstsqTarget_valid     0.999  0.997  0.992  0.999  0.997  0.351
# predLambda_VS_lstsqTarget_test      1.000  1.000  0.991  0.999  0.818  0.987
# predLambda_VS_targetPoly_valid      0.999  0.997  0.985  0.999  0.997  0.355
# predLambda_VS_targetPoly_test       0.999  1.000  0.993  0.998  0.818  0.985
# lstsqTarget_VS_targetPoly_valid     1.000  1.000  0.998  1.000  1.000  0.999
# lstsqTarget_VS_targetPoly_test      1.000  1.000  1.000  1.000  0.999  1.000
# perNetworkPoly_VS_targetPoly_test   0.999  0.997  0.996  0.998  0.818  0.985
# perNetworkPoly_VS_inetPoly_test     0.999  0.997  0.996  0.998  0.818  0.985
# perNetworkPoly_VS_predLambda_test   0.999  0.997  0.988  0.999  1.000  1.000
# perNetworkPoly_VS_lstsqTarget_test  0.999  0.997  0.997  0.998  0.818  0.987
# perNetworkPoly_VS_lstsqLambda_test  0.999  0.997  0.988  0.999  1.000  1.000
#
#                                     L-111  L-112  L-113  L-114   L-115  \
# inetPoly_VS_targetPoly_valid        0.974 -0.491  0.994 -7.718  -1.363
# inetPoly_VS_targetPoly_test        -0.264  0.968 -1.925  0.994  -1.348
# inetPoly_VS_predLambda_valid        0.976  0.955  0.989 -7.636  -1.363
# inetPoly_VS_predLambda_test         0.949  0.966 -1.951  0.994  -1.341
# inetPoly_VS_lstsqTarget_valid       0.975 -0.557  0.994 -7.669  -1.353
# inetPoly_VS_lstsqTarget_test       -0.287  0.970 -1.952  0.994  -1.358
# inetPoly_VS_lstsqLambda_valid       0.977  0.955  0.989 -7.632  -1.361
# inetPoly_VS_lstsqLambda_test        0.949  0.968 -1.951  0.994  -1.341
# lstsqLambda_VS_predLambda_valid     1.000  1.000  0.999  1.000   0.995
# lstsqLambda_VS_predLambda_test      1.000  0.999  1.000  1.000   0.987
# lstsqLambda_VS_lstsqTarget_valid    0.996 -0.274  0.995  1.000   0.853
# lstsqLambda_VS_lstsqTarget_test     0.064  0.998  0.966  0.999 -25.347
# lstsqLambda_VS_targetPoly_valid     0.997 -0.207  0.996  0.999   0.877
# lstsqLambda_VS_targetPoly_test      0.087  0.998  0.966  0.999 -24.680
# predLambda_VS_lstsqTarget_valid     0.996 -0.275  0.995  1.000   0.847
# predLambda_VS_lstsqTarget_test      0.063  0.997  0.966  0.999 -25.710
# predLambda_VS_targetPoly_valid      0.996 -0.208  0.995  0.999   0.872
# predLambda_VS_targetPoly_test       0.087  0.998  0.966  0.999 -25.031
# lstsqTarget_VS_targetPoly_valid     1.000  0.997  1.000  1.000   0.993
# lstsqTarget_VS_targetPoly_test      1.000  1.000  0.998  1.000   0.995
# perNetworkPoly_VS_targetPoly_test  -0.304  0.995  0.967  0.963 -28.263
# perNetworkPoly_VS_inetPoly_test    -0.304  0.995  0.967  0.963 -28.263
# perNetworkPoly_VS_predLambda_test   0.932  0.993  1.000  0.953   0.965
# perNetworkPoly_VS_lstsqTarget_test -0.324  0.996  0.968  0.964 -29.037
# perNetworkPoly_VS_lstsqLambda_test  0.932  0.994  1.000  0.953   0.971
#
#                                       L-116   L-117   L-118  L-119      L-120  \
# inetPoly_VS_targetPoly_valid          0.902   0.874 -91.378  0.920      0.904
# inetPoly_VS_targetPoly_test        -140.244 -81.109   0.431  0.996     -1.181
# inetPoly_VS_predLambda_valid          0.975   0.888 -86.917  0.919      0.902
# inetPoly_VS_predLambda_test        -140.609 -80.944   0.429  0.997     -1.274
# inetPoly_VS_lstsqTarget_valid         0.905   0.874 -90.613  0.914      0.903
# inetPoly_VS_lstsqTarget_test       -140.634 -80.939   0.427  0.996     -1.193
# inetPoly_VS_lstsqLambda_valid         0.975   0.886 -87.188  0.923      0.904
# inetPoly_VS_lstsqLambda_test       -140.680 -80.831   0.429  0.997     -1.274
# lstsqLambda_VS_predLambda_valid       1.000   0.999   0.997  0.997      0.998
# lstsqLambda_VS_predLambda_test        1.000   0.999   0.999  1.000      0.960
# lstsqLambda_VS_lstsqTarget_valid      0.876   0.999   0.997  0.963      0.999
# lstsqLambda_VS_lstsqTarget_test       0.997   0.999   0.993  0.999 -12170.039
# lstsqLambda_VS_targetPoly_valid       0.873   0.999   0.997  0.973      0.999
# lstsqLambda_VS_targetPoly_test        0.999   0.998   0.993  0.999 -12964.855
# predLambda_VS_lstsqTarget_valid       0.876   0.998   0.994  0.958      0.997
# predLambda_VS_lstsqTarget_test        0.997   0.998   0.993  0.999 -11619.237
# predLambda_VS_targetPoly_valid        0.873   0.998   0.994  0.969      0.997
# predLambda_VS_targetPoly_test         0.999   0.998   0.993  0.999 -12377.940
# lstsqTarget_VS_targetPoly_valid       0.999   1.000   1.000  0.996      1.000
# lstsqTarget_VS_targetPoly_test        0.999   1.000   1.000  1.000      0.997
# perNetworkPoly_VS_targetPoly_test     0.977   0.977   0.979  0.999 -13874.926
# perNetworkPoly_VS_inetPoly_test       0.977   0.977   0.979  0.999 -13874.926
# perNetworkPoly_VS_predLambda_test     0.982   0.979   0.970  0.999      0.945
# perNetworkPoly_VS_lstsqTarget_test    0.969   0.980   0.981  0.998 -13024.871
# perNetworkPoly_VS_lstsqLambda_test    0.981   0.980   0.970  0.999      0.987
#
#                                     L-121  L-122   L-123    L-124  L-125  \
# inetPoly_VS_targetPoly_valid        0.997 -1.459  -2.013   -0.918  0.945
# inetPoly_VS_targetPoly_test         0.995  0.992 -16.072    0.920 -1.775
# inetPoly_VS_predLambda_valid        0.997 -1.216   0.986   -0.839  0.948
# inetPoly_VS_predLambda_test         0.984  0.986   0.896    0.928 -1.636
# inetPoly_VS_lstsqTarget_valid       0.998 -1.594  -2.060   -0.923  0.945
# inetPoly_VS_lstsqTarget_test        0.995  0.994 -16.471    0.919 -1.810
# inetPoly_VS_lstsqLambda_valid       0.998 -1.192   0.986   -0.839  0.948
# inetPoly_VS_lstsqLambda_test        0.984  0.987   0.897    0.930 -1.632
# lstsqLambda_VS_predLambda_valid     1.000  0.997   1.000    1.000  0.999
# lstsqLambda_VS_predLambda_test      1.000  0.999   1.000    0.999  1.000
# lstsqLambda_VS_lstsqTarget_valid    0.999  0.980  -2.075 -109.468  0.997
# lstsqLambda_VS_lstsqTarget_test     0.986  0.997 -18.397    0.994  0.983
# lstsqLambda_VS_targetPoly_valid     1.000  0.977  -2.028 -109.289  0.998
# lstsqLambda_VS_targetPoly_test      0.987  0.997 -18.003    0.993  0.985
# predLambda_VS_lstsqTarget_valid     0.999  0.979  -2.075 -109.425  0.997
# predLambda_VS_lstsqTarget_test      0.986  0.997 -18.415    0.993  0.983
# predLambda_VS_targetPoly_valid      1.000  0.975  -2.028 -109.246  0.997
# predLambda_VS_targetPoly_test       0.987  0.996 -18.020    0.992  0.985
# lstsqTarget_VS_targetPoly_valid     1.000  0.998   1.000    0.999  1.000
# lstsqTarget_VS_targetPoly_test      0.999  0.999   0.999    1.000  1.000
# perNetworkPoly_VS_targetPoly_test   0.990  0.948 -18.156    0.997  0.981
# perNetworkPoly_VS_inetPoly_test     0.990  0.948 -18.156    0.997  0.981
# perNetworkPoly_VS_predLambda_test   0.999  0.964   1.000    0.993  0.995
# perNetworkPoly_VS_lstsqTarget_test  0.989  0.950 -18.554    0.997  0.979
# perNetworkPoly_VS_lstsqLambda_test  0.999  0.964   1.000    0.993  0.995
#
#                                      L-126  L-127  L-128  L-129  L-130  L-131  \
# inetPoly_VS_targetPoly_valid       -39.592  0.997  0.994  0.905  0.940  0.997
# inetPoly_VS_targetPoly_test          0.986 -6.316  0.944 -3.620  0.994 -0.086
# inetPoly_VS_predLambda_valid       -39.499  0.995  0.994  0.899  0.936  0.997
# inetPoly_VS_predLambda_test          0.983 -5.784  0.942 -3.667  0.994 -0.145
# inetPoly_VS_lstsqTarget_valid      -39.928  0.998  0.994  0.902  0.938  0.997
# inetPoly_VS_lstsqTarget_test         0.987 -5.831  0.967 -3.661  0.994 -0.155
# inetPoly_VS_lstsqLambda_valid      -39.498  0.995  0.994  0.899  0.936  0.997
# inetPoly_VS_lstsqLambda_test         0.982 -5.854  0.942 -3.667  0.994 -0.155
# lstsqLambda_VS_predLambda_valid      0.999  1.000  1.000  1.000  1.000  1.000
# lstsqLambda_VS_predLambda_test       1.000  0.996  1.000  1.000  1.000  0.997
# lstsqLambda_VS_lstsqTarget_valid     0.995  0.999  1.000  0.999  0.999  1.000
# lstsqLambda_VS_lstsqTarget_test      0.999  0.973  0.979 -2.529  0.999  0.980
# lstsqLambda_VS_targetPoly_valid      0.994  0.999  1.000  0.998  0.999  1.000
# lstsqLambda_VS_targetPoly_test       0.999  0.982  0.991 -2.377  0.999  0.981
# predLambda_VS_lstsqTarget_valid      0.993  0.998  0.999  0.999  0.999  1.000
# predLambda_VS_lstsqTarget_test       0.999  0.970  0.979 -2.534  0.999  0.978
# predLambda_VS_targetPoly_valid       0.992  0.998  0.999  0.998  0.999  1.000
# predLambda_VS_targetPoly_test        0.999  0.977  0.991 -2.382  0.999  0.979
# lstsqTarget_VS_targetPoly_valid      0.999  1.000  1.000  1.000  1.000  1.000
# lstsqTarget_VS_targetPoly_test       1.000  0.996  0.994  0.995  1.000  0.999
# perNetworkPoly_VS_targetPoly_test    0.999  0.809  0.992 -2.328  1.000  0.845
# perNetworkPoly_VS_inetPoly_test      0.999  0.809  0.992 -2.328  1.000  0.845
# perNetworkPoly_VS_predLambda_test    0.999  0.756  0.997  0.999  0.998  0.843
# perNetworkPoly_VS_lstsqTarget_test   0.998  0.780  0.987 -2.482  1.000  0.853
# perNetworkPoly_VS_lstsqLambda_test   0.999  0.760  0.997  1.000  0.998  0.842
#
#                                     L-132  L-133  L-134  L-135  L-136  L-137  \
# inetPoly_VS_targetPoly_valid        0.994  0.182  0.989  0.994  0.977  0.808
# inetPoly_VS_targetPoly_test         0.992  0.858  0.737  0.990  0.957  0.862
# inetPoly_VS_predLambda_valid        0.995  0.984  0.987  0.995  0.979  0.971
# inetPoly_VS_predLambda_test         0.993  0.823  0.845  0.975  0.968  0.904
# inetPoly_VS_lstsqTarget_valid       0.994  0.210  0.989  0.994  0.978  0.801
# inetPoly_VS_lstsqTarget_test        0.991  0.869  0.722  0.988  0.953  0.863
# inetPoly_VS_lstsqLambda_valid       0.995  0.984  0.987  0.995  0.980  0.971
# inetPoly_VS_lstsqLambda_test        0.993  0.833  0.846  0.975  0.968  0.904
# lstsqLambda_VS_predLambda_valid     1.000  1.000  1.000  1.000  1.000  1.000
# lstsqLambda_VS_predLambda_test      1.000  0.992  0.998  1.000  0.999  1.000
# lstsqLambda_VS_lstsqTarget_valid    0.999  0.306  0.999  0.999  0.999  0.906
# lstsqLambda_VS_lstsqTarget_test     0.999  0.963  0.925  0.993  0.996  0.988
# lstsqLambda_VS_targetPoly_valid     1.000  0.280  0.999  0.999  0.999  0.910
# lstsqLambda_VS_targetPoly_test      1.000  0.943  0.953  0.996  0.997  0.987
# predLambda_VS_lstsqTarget_valid     0.999  0.306  0.999  0.999  0.999  0.906
# ...
# predLambda_VS_targetPoly_test       0.992  0.996   0.965  1.000 -0.146  0.999
# lstsqTarget_VS_targetPoly_valid       NaN    NaN     NaN    NaN    NaN    NaN
# lstsqTarget_VS_targetPoly_test      1.000  1.000   0.993  1.000  1.000  1.000
# perNetworkPoly_VS_targetPoly_test   0.990  0.992   0.799  0.999  0.097  0.991
# perNetworkPoly_VS_inetPoly_test     0.990  0.992   0.799  0.999  0.097  0.991
# perNetworkPoly_VS_predLambda_test   0.997  0.987   0.858  0.999  0.917  0.990
# perNetworkPoly_VS_lstsqTarget_test  0.992  0.993   0.780  0.999  0.090  0.991
# perNetworkPoly_VS_lstsqLambda_test  0.997  0.987   0.878  1.000  0.917  0.990
#
#                                     L-961    L-962  L-963  L-964  L-965  \
# inetPoly_VS_targetPoly_valid          NaN      NaN    NaN    NaN    NaN
# inetPoly_VS_targetPoly_test         0.968 -962.484  0.348  0.856  0.997
# inetPoly_VS_predLambda_valid          NaN      NaN    NaN    NaN    NaN
# inetPoly_VS_predLambda_test         0.965 -977.710  0.976  0.848  0.995
# inetPoly_VS_lstsqTarget_valid         NaN      NaN    NaN    NaN    NaN
# inetPoly_VS_lstsqTarget_test        0.968 -973.458  0.433  0.857  0.997
# inetPoly_VS_lstsqLambda_valid         NaN      NaN    NaN    NaN    NaN
# inetPoly_VS_lstsqLambda_test        0.966 -977.699  0.975  0.847  0.996
# lstsqLambda_VS_predLambda_valid       NaN      NaN    NaN    NaN    NaN
# lstsqLambda_VS_predLambda_test      0.999    1.000  1.000  0.999  0.999
# lstsqLambda_VS_lstsqTarget_valid      NaN      NaN    NaN    NaN    NaN
# lstsqLambda_VS_lstsqTarget_test     0.998    1.000  0.591  0.999  0.999
# lstsqLambda_VS_targetPoly_valid       NaN      NaN    NaN    NaN    NaN
# lstsqLambda_VS_targetPoly_test      0.998    1.000  0.521  0.998  0.998
# predLambda_VS_lstsqTarget_valid       NaN      NaN    NaN    NaN    NaN
# predLambda_VS_lstsqTarget_test      0.998    0.999  0.589  0.998  0.998
# predLambda_VS_targetPoly_valid        NaN      NaN    NaN    NaN    NaN
# predLambda_VS_targetPoly_test       0.998    0.999  0.519  0.998  0.997
# lstsqTarget_VS_targetPoly_valid       NaN      NaN    NaN    NaN    NaN
# lstsqTarget_VS_targetPoly_test      1.000    1.000  0.997  1.000  1.000
# perNetworkPoly_VS_targetPoly_test   0.998    0.999  0.528  0.987  0.999
# perNetworkPoly_VS_inetPoly_test     0.998    0.999  0.528  0.987  0.999
# perNetworkPoly_VS_predLambda_test   0.999    0.998  1.000  0.990  0.996
# perNetworkPoly_VS_lstsqTarget_test  0.998    0.999  0.597  0.988  0.999
# perNetworkPoly_VS_lstsqLambda_test  1.000    0.999  1.000  0.991  0.997
#
#                                     L-966  L-967  L-968  L-969  L-970  L-971  \
# inetPoly_VS_targetPoly_valid          NaN    NaN    NaN    NaN    NaN    NaN
# inetPoly_VS_targetPoly_test         0.995  0.681  0.904  0.767  0.980  0.996
# inetPoly_VS_predLambda_valid          NaN    NaN    NaN    NaN    NaN    NaN
# inetPoly_VS_predLambda_test         0.995  0.962  0.911  0.986  0.976  0.996
# inetPoly_VS_lstsqTarget_valid         NaN    NaN    NaN    NaN    NaN    NaN
# inetPoly_VS_lstsqTarget_test        0.996  0.675  0.908  0.757  0.982  0.996
# inetPoly_VS_lstsqLambda_valid         NaN    NaN    NaN    NaN    NaN    NaN
# inetPoly_VS_lstsqLambda_test        0.995  0.962  0.911  0.986  0.976  0.996
# lstsqLambda_VS_predLambda_valid       NaN    NaN    NaN    NaN    NaN    NaN
# lstsqLambda_VS_predLambda_test      1.000  1.000  0.997  1.000  1.000  1.000
# lstsqLambda_VS_lstsqTarget_valid      NaN    NaN    NaN    NaN    NaN    NaN
# lstsqLambda_VS_lstsqTarget_test     0.999  0.782  0.989  0.793  0.998  1.000
# lstsqLambda_VS_targetPoly_valid       NaN    NaN    NaN    NaN    NaN    NaN
# lstsqLambda_VS_targetPoly_test      0.999  0.798  0.990  0.808  0.997  1.000
# predLambda_VS_lstsqTarget_valid       NaN    NaN    NaN    NaN    NaN    NaN
# predLambda_VS_lstsqTarget_test      0.999  0.781  0.986  0.792  0.998  1.000
# predLambda_VS_targetPoly_valid        NaN    NaN    NaN    NaN    NaN    NaN
# predLambda_VS_targetPoly_test       0.999  0.797  0.986  0.808  0.997  1.000
# lstsqTarget_VS_targetPoly_valid       NaN    NaN    NaN    NaN    NaN    NaN
# lstsqTarget_VS_targetPoly_test      1.000  0.995  1.000  0.999  0.999  1.000
# perNetworkPoly_VS_targetPoly_test   0.997  0.798  0.997  0.769  0.999  0.996
# perNetworkPoly_VS_inetPoly_test     0.997  0.798  0.997  0.769  0.999  0.996
# perNetworkPoly_VS_predLambda_test   0.998  1.000  0.986  0.982  0.999  0.996
# perNetworkPoly_VS_lstsqTarget_test  0.998  0.782  0.997  0.759  0.999  0.996
# perNetworkPoly_VS_lstsqLambda_test  0.998  1.000  0.989  0.982  1.000  0.996
#
#                                     L-972  L-973    L-974  L-975  L-976  \
# inetPoly_VS_targetPoly_valid          NaN    NaN      NaN    NaN    NaN
# inetPoly_VS_targetPoly_test         0.981  0.985 -167.169  0.969 -3.423
# inetPoly_VS_predLambda_valid          NaN    NaN      NaN    NaN    NaN
# inetPoly_VS_predLambda_test         0.986  0.985 -168.927  0.970 -3.405
# inetPoly_VS_lstsqTarget_valid         NaN    NaN      NaN    NaN    NaN
# inetPoly_VS_lstsqTarget_test        0.981  0.985 -165.967  0.964 -3.405
# inetPoly_VS_lstsqLambda_valid         NaN    NaN      NaN    NaN    NaN
# inetPoly_VS_lstsqLambda_test        0.986  0.985 -168.935  0.971 -3.405
# lstsqLambda_VS_predLambda_valid       NaN    NaN      NaN    NaN    NaN
# lstsqLambda_VS_predLambda_test      1.000  1.000    1.000  1.000  0.999
# lstsqLambda_VS_lstsqTarget_valid      NaN    NaN      NaN    NaN    NaN
# lstsqLambda_VS_lstsqTarget_test     0.994  0.998    0.928  0.997  0.995
# lstsqLambda_VS_targetPoly_valid       NaN    NaN      NaN    NaN    NaN
# lstsqLambda_VS_targetPoly_test      0.994  0.998    0.930  0.998  0.994
# predLambda_VS_lstsqTarget_valid       NaN    NaN      NaN    NaN    NaN
# predLambda_VS_lstsqTarget_test      0.994  0.998    0.928  0.997  0.994
# predLambda_VS_targetPoly_valid        NaN    NaN      NaN    NaN    NaN
# predLambda_VS_targetPoly_test       0.994  0.998    0.929  0.998  0.993
# lstsqTarget_VS_targetPoly_valid       NaN    NaN      NaN    NaN    NaN
# lstsqTarget_VS_targetPoly_test      1.000  1.000    0.999  1.000  0.998
# perNetworkPoly_VS_targetPoly_test   0.946  0.955    0.930  0.996  0.989
# perNetworkPoly_VS_inetPoly_test     0.946  0.955    0.930  0.996  0.989
# perNetworkPoly_VS_predLambda_test   0.912  0.949    1.000  0.997  0.981
# perNetworkPoly_VS_lstsqTarget_test  0.946  0.953    0.929  0.996  0.986
# perNetworkPoly_VS_lstsqLambda_test  0.912  0.950    1.000  0.997  0.982
#
#                                      L-977  L-978  L-979  L-980  L-981  L-982  \
# inetPoly_VS_targetPoly_valid           NaN    NaN    NaN    NaN    NaN    NaN
# inetPoly_VS_targetPoly_test        -37.404  0.130  0.989  0.981  0.992 -1.648
# inetPoly_VS_predLambda_valid           NaN    NaN    NaN    NaN    NaN    NaN
# inetPoly_VS_predLambda_test        -40.045  0.982  0.990  0.982  0.992 -1.650
# inetPoly_VS_lstsqTarget_valid          NaN    NaN    NaN    NaN    NaN    NaN
# inetPoly_VS_lstsqTarget_test       -38.244  0.180  0.991  0.980  0.992 -1.647
# inetPoly_VS_lstsqLambda_valid          NaN    NaN    NaN    NaN    NaN    NaN
# inetPoly_VS_lstsqLambda_test       -40.071  0.982  0.990  0.982  0.992 -1.650
# lstsqLambda_VS_predLambda_valid        NaN    NaN    NaN    NaN    NaN    NaN
# lstsqLambda_VS_predLambda_test       1.000  1.000  1.000  1.000  1.000  1.000
# lstsqLambda_VS_lstsqTarget_valid       NaN    NaN    NaN    NaN    NaN    NaN
# lstsqLambda_VS_lstsqTarget_test      0.986  0.399  1.000  1.000  1.000 -0.469
# lstsqLambda_VS_targetPoly_valid        NaN    NaN    NaN    NaN    NaN    NaN
# lstsqLambda_VS_targetPoly_test       0.989  0.364  0.999  1.000  1.000 -0.571
# predLambda_VS_lstsqTarget_valid        NaN    NaN    NaN    NaN    NaN    NaN
# predLambda_VS_lstsqTarget_test       0.986  0.399  0.999  0.999  1.000 -0.473
# predLambda_VS_targetPoly_valid         NaN    NaN    NaN    NaN    NaN    NaN
# predLambda_VS_targetPoly_test        0.989  0.364  0.999  0.999  0.999 -0.575
# lstsqTarget_VS_targetPoly_valid        NaN    NaN    NaN    NaN    NaN    NaN
# lstsqTarget_VS_targetPoly_test       0.999  0.998  1.000  1.000  1.000  0.996
# perNetworkPoly_VS_targetPoly_test    0.960  0.364  0.989  0.999  0.999 -0.567
# perNetworkPoly_VS_inetPoly_test      0.960  0.364  0.989  0.999  0.999 -0.567
# perNetworkPoly_VS_predLambda_test    0.934  1.000  0.991  0.999  0.999  1.000
# perNetworkPoly_VS_lstsqTarget_test   0.957  0.400  0.989  0.999  0.999 -0.465
# perNetworkPoly_VS_lstsqLambda_test   0.934  1.000  0.991  0.999  0.999  1.000
#
#                                     L-983  L-984  L-985  L-986  L-987   L-988  \
# inetPoly_VS_targetPoly_valid          NaN    NaN    NaN    NaN    NaN     NaN
# inetPoly_VS_targetPoly_test         0.950 -4.789  0.995 -0.962  0.997 -32.477
# inetPoly_VS_predLambda_valid          NaN    NaN    NaN    NaN    NaN     NaN
# inetPoly_VS_predLambda_test         0.963 -4.817  0.996 -1.054  0.997 -32.461
# inetPoly_VS_lstsqTarget_valid         NaN    NaN    NaN    NaN    NaN     NaN
# inetPoly_VS_lstsqTarget_test        0.945 -5.019  0.995 -0.946  0.998 -32.556
# inetPoly_VS_lstsqLambda_valid         NaN    NaN    NaN    NaN    NaN     NaN
# inetPoly_VS_lstsqLambda_test        0.964 -4.865  0.996 -1.054  0.998 -32.534
# lstsqLambda_VS_predLambda_valid       NaN    NaN    NaN    NaN    NaN     NaN
# lstsqLambda_VS_predLambda_test      0.997  0.998  1.000  1.000  1.000   1.000
# lstsqLambda_VS_lstsqTarget_valid      NaN    NaN    NaN    NaN    NaN     NaN
# lstsqLambda_VS_lstsqTarget_test     0.995  0.996  0.997  0.178  1.000   0.998
# lstsqLambda_VS_targetPoly_valid       NaN    NaN    NaN    NaN    NaN     NaN
# lstsqLambda_VS_targetPoly_test      0.995  0.995  0.997  0.128  1.000   0.999
# predLambda_VS_lstsqTarget_valid       NaN    NaN    NaN    NaN    NaN     NaN
# predLambda_VS_lstsqTarget_test      0.991  0.993  0.997  0.178  0.999   0.998
# predLambda_VS_targetPoly_valid        NaN    NaN    NaN    NaN    NaN     NaN
# predLambda_VS_targetPoly_test       0.992  0.992  0.997  0.128  0.999   0.998
# lstsqTarget_VS_targetPoly_valid       NaN    NaN    NaN    NaN    NaN     NaN
# lstsqTarget_VS_targetPoly_test      0.999  0.999  1.000  0.998  1.000   1.000
# perNetworkPoly_VS_targetPoly_test   0.964  0.974  0.999  0.128  0.970   0.995
# perNetworkPoly_VS_inetPoly_test     0.964  0.974  0.999  0.128  0.970   0.995
# perNetworkPoly_VS_predLambda_test   0.967  0.975  0.998  1.000  0.968   0.996
# perNetworkPoly_VS_lstsqTarget_test  0.959  0.978  0.999  0.178  0.972   0.995
# perNetworkPoly_VS_lstsqLambda_test  0.969  0.978  0.998  1.000  0.968   0.996
#
#                                        L-989  L-990  L-991  L-992  L-993  \
# inetPoly_VS_targetPoly_valid             NaN    NaN    NaN    NaN    NaN
# inetPoly_VS_targetPoly_test         -932.083  0.979  0.880  0.993  0.996
# inetPoly_VS_predLambda_valid             NaN    NaN    NaN    NaN    NaN
# inetPoly_VS_predLambda_test           -1.504  0.980  0.924  0.994  0.996
# inetPoly_VS_lstsqTarget_valid            NaN    NaN    NaN    NaN    NaN
# inetPoly_VS_lstsqTarget_test        -949.781  0.979  0.881  0.993  0.996
# inetPoly_VS_lstsqLambda_valid            NaN    NaN    NaN    NaN    NaN
# inetPoly_VS_lstsqLambda_test          -1.500  0.980  0.924  0.994  0.997
# lstsqLambda_VS_predLambda_valid          NaN    NaN    NaN    NaN    NaN
# lstsqLambda_VS_predLambda_test         0.999  1.000  1.000  0.999  1.000
# lstsqLambda_VS_lstsqTarget_valid         NaN    NaN    NaN    NaN    NaN
# lstsqLambda_VS_lstsqTarget_test    -1013.665  0.998  0.991  0.997  1.000
# lstsqLambda_VS_targetPoly_valid          NaN    NaN    NaN    NaN    NaN
# lstsqLambda_VS_targetPoly_test      -995.387  0.998  0.987  0.997  1.000
# predLambda_VS_lstsqTarget_valid          NaN    NaN    NaN    NaN    NaN
# predLambda_VS_lstsqTarget_test     -1010.822  0.998  0.991  0.997  1.000
# predLambda_VS_targetPoly_valid           NaN    NaN    NaN    NaN    NaN
# predLambda_VS_targetPoly_test       -992.597  0.998  0.987  0.997  0.999
# lstsqTarget_VS_targetPoly_valid          NaN    NaN    NaN    NaN    NaN
# lstsqTarget_VS_targetPoly_test         0.999  1.000  0.998  1.000  1.000
# perNetworkPoly_VS_targetPoly_test  -1003.841  0.996  0.989  0.990  0.999
# perNetworkPoly_VS_inetPoly_test    -1003.841  0.996  0.989  0.990  0.999
# perNetworkPoly_VS_predLambda_test      0.999  0.993  0.997  0.982  1.000
# perNetworkPoly_VS_lstsqTarget_test -1022.280  0.996  0.990  0.992  0.999
# perNetworkPoly_VS_lstsqLambda_test     1.000  0.994  0.998  0.982  1.000
#
#                                     L-994     L-995  L-996  L-997  L-998  \
# inetPoly_VS_targetPoly_valid          NaN       NaN    NaN    NaN    NaN
# inetPoly_VS_targetPoly_test         0.957 -1782.218  0.273  0.838  0.847
# inetPoly_VS_predLambda_valid          NaN       NaN    NaN    NaN    NaN
# inetPoly_VS_predLambda_test         0.965 -1785.826  0.984  0.986  0.828
# inetPoly_VS_lstsqTarget_valid         NaN       NaN    NaN    NaN    NaN
# inetPoly_VS_lstsqTarget_test        0.956 -1799.681  0.302  0.843  0.836
# inetPoly_VS_lstsqLambda_valid         NaN       NaN    NaN    NaN    NaN
# inetPoly_VS_lstsqLambda_test        0.967 -1783.789  0.984  0.986  0.827
# lstsqLambda_VS_predLambda_valid       NaN       NaN    NaN    NaN    NaN
# lstsqLambda_VS_predLambda_test      0.999     1.000  1.000  1.000  1.000
# lstsqLambda_VS_lstsqTarget_valid      NaN       NaN    NaN    NaN    NaN
# lstsqLambda_VS_lstsqTarget_test     0.995     0.999  0.273  0.892  0.999
# lstsqLambda_VS_targetPoly_valid       NaN       NaN    NaN    NaN    NaN
# lstsqLambda_VS_targetPoly_test      0.995     0.999  0.238  0.889  0.999
# predLambda_VS_lstsqTarget_valid       NaN       NaN    NaN    NaN    NaN
# predLambda_VS_lstsqTarget_test      0.995     0.999  0.273  0.892  0.999
# predLambda_VS_targetPoly_valid        NaN       NaN    NaN    NaN    NaN
# predLambda_VS_targetPoly_test       0.994     0.999  0.238  0.889  0.999
# lstsqTarget_VS_targetPoly_valid       NaN       NaN    NaN    NaN    NaN
# lstsqTarget_VS_targetPoly_test      1.000     1.000  0.999  1.000  0.999
# perNetworkPoly_VS_targetPoly_test   0.997     0.998  0.238  0.889  0.939
# perNetworkPoly_VS_inetPoly_test     0.997     0.998  0.238  0.889  0.939
# perNetworkPoly_VS_predLambda_test   0.995     0.998  1.000  1.000  0.929
# perNetworkPoly_VS_lstsqTarget_test  0.997     0.997  0.273  0.892  0.934
# perNetworkPoly_VS_lstsqLambda_test  0.996     0.998  1.000  1.000  0.928
#
#                                      L-999
# inetPoly_VS_targetPoly_valid           NaN
# inetPoly_VS_targetPoly_test        -28.234
# inetPoly_VS_predLambda_valid           NaN
# inetPoly_VS_predLambda_test        -27.487
# inetPoly_VS_lstsqTarget_valid          NaN
# inetPoly_VS_lstsqTarget_test       -27.639
# inetPoly_VS_lstsqLambda_valid          NaN
# inetPoly_VS_lstsqLambda_test       -27.466
# lstsqLambda_VS_predLambda_valid        NaN
# lstsqLambda_VS_predLambda_test       1.000
# lstsqLambda_VS_lstsqTarget_valid       NaN
# lstsqLambda_VS_lstsqTarget_test      0.995
# lstsqLambda_VS_targetPoly_valid        NaN
# lstsqLambda_VS_targetPoly_test       0.993
# predLambda_VS_lstsqTarget_valid        NaN
# predLambda_VS_lstsqTarget_test       0.995
# predLambda_VS_targetPoly_valid         NaN
# predLambda_VS_targetPoly_test        0.993
# lstsqTarget_VS_targetPoly_valid        NaN
# lstsqTarget_VS_targetPoly_test       0.999
# perNetworkPoly_VS_targetPoly_test    1.000
# perNetworkPoly_VS_inetPoly_test      1.000
# perNetworkPoly_VS_predLambda_test    0.992
# perNetworkPoly_VS_lstsqTarget_test   0.998
# perNetworkPoly_VS_lstsqLambda_test   0.992
#
# [25 rows x 1000 columns]

# %%
index_min = int(np.argmin(distrib_dict_list[-1]['R2'].loc['predLambda_VS_lstsqTarget_test']))
polynomial_inet = inet_preds_test_list[-1][index_min]

print(distrib_dict_list[-1]['R2'].loc['inetPoly_VS_targetPoly_test'][index_min])

print_polynomial_from_coefficients(polynomial_inet)
# Out:
# -1.1811099769300375
# -1.03394842147827*a**2.0 + 0.228029027581215*a**3.0 - 0.201126158237457*a**5.0

# %%
index_min = int(np.argmin(distrib_dict_list[-1]['R2'].loc['predLambda_VS_lstsqTarget_test']))
#polynomial_target = lambda_net_test_dataset.get_lambda_net_by_lambda_index(index_min).target_polynomial

print(distrib_dict_list[-1]['R2'].loc['lstsqLambda_VS_targetPoly_test'][index_min])

polynomial_lambda = lambda_net_test_dataset.lstsq_lambda_pred_polynomial_list[index_min]
print_polynomial_from_coefficients(polynomial_lambda, force_complete_poly_representation=True)
# Out:
# -12964.854577020506
# -0.0144180507096363*a**1.0 + 0.0607845608051884*a**2.0 - 0.137557339109865*a**3.0 + 0.138166555509527*a**4.0 - 0.0508871552762161*a**5.0 - 0.646764747333045

# %%
index_min = int(np.argmin(distrib_dict_list[-1]['R2'].loc['predLambda_VS_lstsqTarget_test']))
#polynomial_target = lambda_net_test_dataset.get_lambda_net_by_lambda_index(index_min).target_polynomial
polynomial_target = lambda_net_test_dataset.target_polynomial_list[index_min]
print_polynomial_from_coefficients(polynomial_target, force_complete_poly_representation=True)
# Out:
# 0.004393827627128*a**1.0 + 0.457417409203298*a**2.0 + 0.50202434551022*a**3.0 - 0.548171232247483*a**4.0 - 0.799800974305493*a**5.0 - 0.701293378218257

# %%
index_max = int(np.argmax(distrib_dict_list[-1]['R2'].loc['predLambda_VS_lstsqTarget_test']))
polynomial_inet = inet_preds_test_list[-1][index_max]

print(distrib_dict_list[-1]['R2'].loc['inetPoly_VS_targetPoly_test'][index_max])

print_polynomial_from_coefficients(polynomial_inet)
# Out:
# 0.9464712823789438
# 0.598352074623108 - 1.42541839182377*a**3.0

# %%
index_max = int(np.argmax(distrib_dict_list[-1]['R2'].loc['predLambda_VS_lstsqTarget_test']))
#polynomial_target = lambda_net_test_dataset.get_lambda_net_by_lambda_index(index_min).target_polynomial

print(distrib_dict_list[-1]['R2'].loc['lstsqLambda_VS_targetPoly_test'][index_max])

polynomial_lambda = lambda_net_test_dataset.lstsq_lambda_pred_polynomial_list[index_max]
print_polynomial_from_coefficients(polynomial_lambda, force_complete_poly_representation=True)
# Out:
# 0.9998232418462257
# 0.0515725748404566*a**1.0 - 2.31155843859545*a**2.0 + 2.44145924559806*a**3.0 - 3.13063218736376*a**4.0 + 1.60934559521781*a**5.0 + 0.752756024263297

# %%
index_max = int(np.argmax(distrib_dict_list[-1]['R2'].loc['predLambda_VS_lstsqTarget_test']))
#polynomial_target = lambda_net_test_dataset.get_lambda_net_by_lambda_index(index_min).target_polynomial
polynomial_target = lambda_net_test_dataset.target_polynomial_list[index_max]
print_polynomial_from_coefficients(polynomial_target, force_complete_poly_representation=True)
# Out:
# -0.308245078524285*a**1.0 - 0.691080505553352*a**2.0 - 0.949104480188498*a**3.0 + 0.291644772572969*a**4.0 + 0.273804634909486*a**5.0 + 0.780194070367617

# %%
r2_values_inet = distrib_dict_list[-1]['R2'].loc['inetPoly_VS_targetPoly_test']
print('Mean: ' + str(np.mean(r2_values_inet)) + ' (' + str(r2_values_inet.shape[0]) + ' Samples)')

r2_values_positive_inet = r2_values_inet[r2_values_inet>0]
print('Mean (only positive): ' + str(np.mean(r2_values_positive_inet)) + ' (' + str(r2_values_positive_inet.shape[0]) + ' Samples)')
# Out:
# Mean: -16.90394679707326 (1000 Samples)
# Mean (only positive): 0.872204545292573 (732 Samples)

# %%
r2_values_lstsq_lambda = distrib_dict_list[-1]['R2'].loc['lstsqLambda_VS_targetPoly_test']
print('Mean: ' + str(np.mean(r2_values_lstsq_lambda)) + ' (' + str(r2_values_inet.shape[0]) + ' Samples)')

r2_values_positive_lstsq_lambda = r2_values_lstsq_lambda[r2_values_lstsq_lambda>0]
print('Mean (only positive): ' + str(np.mean(r2_values_positive_lstsq_lambda)) + ' (' + str(r2_values_positive_lstsq_lambda.shape[0]) + ' Samples)')
# Out:
# Mean: -16.71293076867653 (1000 Samples)
# Mean (only positive): 0.9541026786486356 (904 Samples)

# %%
sns.histplot(distrib_dict_list[-1]['MAE'].loc['inetPoly_VS_targetPoly_test'][distrib_dict_list[-1]['R2'].loc['inetPoly_VS_targetPoly_test'] > -50])
# Out:
# <AxesSubplot:xlabel='inetPoly_VS_targetPoly_test', ylabel='Count'>

# %%
sns.histplot(distrib_dict_list[-1]['MAE'].loc['lstsqLambda_VS_targetPoly_test'][distrib_dict_list[-1]['R2'].loc['lstsqLambda_VS_targetPoly_test'] > -50])
# Out:
# <AxesSubplot:xlabel='lstsqLambda_VS_targetPoly_test', ylabel='Count'>

# %%
p = sns.histplot(distrib_dict_list[-1]['R2'].loc['inetPoly_VS_targetPoly_test'][distrib_dict_list[-1]['R2'].loc['inetPoly_VS_targetPoly_test'] > -50], binwidth=0.2)
p.set(xlim=(-30, 1))
# Out:
# [(-30.0, 1.0)]

# %%
p = sns.histplot(distrib_dict_list[-1]['R2'].loc['inetPoly_VS_targetPoly_test'][distrib_dict_list[-1]['R2'].loc['inetPoly_VS_targetPoly_test'] > -50], binwidth=0.1)
p.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
p = sns.histplot(distrib_dict_list[-1]['R2'].loc['lstsqLambda_VS_targetPoly_test'][distrib_dict_list[-1]['R2'].loc['lstsqLambda_VS_targetPoly_test'] > -50], binwidth=0.2)
p.set(xlim=(-10, 1))
# Out:
# [(-10.0, 1.0)]

# %%
p = sns.histplot(distrib_dict_list[-1]['R2'].loc['lstsqLambda_VS_targetPoly_test'][distrib_dict_list[-1]['R2'].loc['lstsqLambda_VS_targetPoly_test'] > -50], binwidth=0.1)
p.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
if not nas:
    history = history_list[-1]

    plt.plot(history[list(history.keys())[1]])
    if consider_labels_training or evaluate_with_real_function:
        plt.plot(history[list(history.keys())[len(history.keys())//2+1]]) 
    plt.title('model ' + list(history.keys())[1])
    plt.ylabel('metric')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')
    plt.savefig('./data/results/' + path_identifier_interpretation_net_data + '/metric_' + '_epoch_' + str(epochs_lambda).zfill(3) + '.png')

# %%
if not nas:
    history = history_list[-1]

    plt.plot(history['loss'])
    if consider_labels_training or evaluate_with_real_function:
        plt.plot(history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')
    plt.savefig('./data/results/' + path_identifier_interpretation_net_data + '/loss_' + '_epoch_' + str(epochs_lambda).zfill(3) + '.png')

# %% [markdown]
# ### Multi Epoch/Sampes Analysis

# %% [markdown]
# ### Generate Comparison Plots

# %%
if len(scores_list) > 1:
    plot_metric_list = ['MAE FV', 'RMSE FV', 'MAPE FV', 'R2 FV', 'RAAE FV', 'RMAE FV']

    generate_inet_comparison_plot(scores_list, plot_metric_list)

# %%
if len(scores_list) > 1:
    plot_metric_list = ['MAE FV']

    generate_inet_comparison_plot(scores_list, plot_metric_list)

# %%
if len(scores_list) > 1:
    plot_metric_list = ['R2 FV']

    generate_inet_comparison_plot(scores_list, plot_metric_list, ylim=(-5, 1))

# %% [markdown]
# #### Generate and Analyze Predictions for Random Function

# %%
index = 6

polynomial_target = lambda_net_test_dataset.target_polynomial_list[index]
polynomial_lstsq_target = lambda_net_test_dataset.lstsq_target_polynomial_list[index]
polynomial_lstsq_lambda = lambda_net_test_dataset.lstsq_lambda_pred_polynomial_list[index]
polynomial_inet = inet_preds_test_list[-1][index]
per_network_poly = per_network_preds_list[-1][index]

print('Target Poly:')
print_polynomial_from_coefficients(polynomial_target, force_complete_poly_representation=True, round_digits=4)
print('LSTSQ Target Poly:')
print_polynomial_from_coefficients(polynomial_lstsq_target, force_complete_poly_representation=True, round_digits=4)
print('LSTSQ Lambda Poly:')
print_polynomial_from_coefficients(polynomial_lstsq_lambda, force_complete_poly_representation=True, round_digits=4)
print('I-Net Poly:')
print_polynomial_from_coefficients(polynomial_inet, round_digits=4)
print('Per Network Optimization Poly:')
print_polynomial_from_coefficients(per_network_poly, round_digits=4)
# Out:
# Target Poly:
# 0.8804*a**1.0 - 0.7895*a**2.0 - 0.3549*a**3.0 + 0.3058*a**4.0 + 0.9988*a**5.0 - 0.3765
# LSTSQ Target Poly:
# 0.9886*a**1.0 - 1.4002*a**2.0 + 1.4736*a**3.0 - 2.2087*a**4.0 + 2.213*a**5.0 - 0.3826
# LSTSQ Lambda Poly:
# -0.1089*a**1.0 + 4.2759*a**2.0 - 11.677*a**3.0 + 12.2308*a**4.0 - 3.8129*a**5.0 - 0.3189
# I-Net Poly:
# 0.699700027704239*a**2.0 - 0.29339998960495
# Per Network Optimization Poly:
# 0.792200028896332*a**3.0 - 0.251999996602535

# %%
lambda_net_test_dataset_list[0].X_test_data_list[0][:10]
# Out:
# array([[0.52705768],
#        [0.0322892 ],
#        [0.40475921],
#        [0.14230531],
#        [0.13426314],
#        [0.90257457],
#        [0.4960394 ],
#        [0.63989715],
#        [0.81111041],
#        [0.02596585]])

# %%
lambda_net_test_dataset_list[0].y_test_data_list[0][:10]
# Out:
# array([[0.93729651],
#        [0.51808388],
#        [1.04651217],
#        [0.95772168],
#        [0.91528308],
#        [0.33733302],
#        [1.0665945 ],
#        [1.01929303],
#        [0.66982232],
#        [0.7507296 ]])

# %%
plot_and_save_single_polynomial_prediction_evaluation(lambda_net_test_dataset_list, 
                                                      function_values_test_list, 
                                                      inet_preds_test_list,
                                                      per_network_preds_list,
                                                      rand_index=index, 
                                                      plot_type=1)
# Out:
# +---------------------------+----------------------+--------------------+--------+----------------------------------------------------+
# |         Comparison        |         MAE          |      R2-Score      | Poly 1 |                       Poly 2                       |
# +---------------------------+----------------------+--------------------+--------+----------------------------------------------------+
# |       Lambda Preds        | 0.008978770175955293 | 0.997420532159953  |   -    |  -0.1089*a**1.0 + 4.2759*a**2.0 - 11.677*a**3.0 +  |
# |            vs.            |                      |                    |        |      12.2308*a**4.0 - 3.8129*a**5.0 - 0.3189       |
# |  LSTSQ Lambda Preds Poly  |                      |                    |        |                                                    |
# |                           |                      |                    |        |                                                    |
# |       Lambda Preds        | 0.03504685981155667  | 0.9574253493506687 |   -    |    0.699700027704239*a**2.0 - 0.29339998960495     |
# |            vs.            |                      |                    |        |                                                    |
# |         I-Net Poly        |                      |                    |        |                                                    |
# |                           |                      |                    |        |                                                    |
# |       Lambda Preds        | 0.03185905427425366  | 0.972304441863804  |   -    |    0.792200028896332*a**3.0 - 0.251999996602535    |
# |            vs.            |                      |                    |        |                                                    |
# |    Per Network Opt Poly   |                      |                    |        |                                                    |
# |                           |                      |                    |        |                                                    |
# |       Lambda Preds        | 0.016330547248236387 | 0.9901621988164027 |   -    |  0.8804*a**1.0 - 0.7895*a**2.0 - 0.3549*a**3.0 +   |
# |            vs.            |                      |                    |        |       0.3058*a**4.0 + 0.9988*a**5.0 - 0.3765       |
# |        Target Poly        |                      |                    |        |                                                    |
# |                           |                      |                    |        |                                                    |
# |       Lambda Preds        | 0.01791094394390229  | 0.987518170537625  |   -    |  0.9886*a**1.0 - 1.4002*a**2.0 + 1.4736*a**3.0 -   |
# |            vs.            |                      |                    |        |       2.2087*a**4.0 + 2.213*a**5.0 - 0.3826        |
# |     LSTSQ Target Poly     |                      |                    |        |                                                    |
# |                           |                      |                    |        |                                                    |
# +---------------------------+----------------------+--------------------+--------+----------------------------------------------------+

# %%
plot_and_save_single_polynomial_prediction_evaluation(lambda_net_test_dataset_list, 
                                                      function_values_test_list, 
                                                      inet_preds_test_list,
                                                      per_network_preds_list,
                                                      rand_index=index, 
                                                      plot_type=2)
# Out:
# +---------------------------+----------------------+--------------------+--------+----------------------------------------------------+
# |         Comparison        |         MAE          |      R2-Score      | Poly 1 |                       Poly 2                       |
# +---------------------------+----------------------+--------------------+--------+----------------------------------------------------+
# |       Lambda Preds        | 0.008978770175955293 | 0.997420532159953  |   -    |  -0.1089*a**1.0 + 4.2759*a**2.0 - 11.677*a**3.0 +  |
# |            vs.            |                      |                    |        |      12.2308*a**4.0 - 3.8129*a**5.0 - 0.3189       |
# |  LSTSQ Lambda Preds Poly  |                      |                    |        |                                                    |
# |                           |                      |                    |        |                                                    |
# |       Lambda Preds        | 0.03504685981155667  | 0.9574253493506687 |   -    |    0.699700027704239*a**2.0 - 0.29339998960495     |
# |            vs.            |                      |                    |        |                                                    |
# |         I-Net Poly        |                      |                    |        |                                                    |
# |                           |                      |                    |        |                                                    |
# |       Lambda Preds        | 0.03185905427425366  | 0.972304441863804  |   -    |    0.792200028896332*a**3.0 - 0.251999996602535    |
# |            vs.            |                      |                    |        |                                                    |
# |    Per Network Opt Poly   |                      |                    |        |                                                    |
# |                           |                      |                    |        |                                                    |
# |       Lambda Preds        | 0.016330547248236387 | 0.9901621988164027 |   -    |  0.8804*a**1.0 - 0.7895*a**2.0 - 0.3549*a**3.0 +   |
# |            vs.            |                      |                    |        |       0.3058*a**4.0 + 0.9988*a**5.0 - 0.3765       |
# |        Target Poly        |                      |                    |        |                                                    |
# |                           |                      |                    |        |                                                    |
# |       Lambda Preds        | 0.01791094394390229  | 0.987518170537625  |   -    |  0.9886*a**1.0 - 1.4002*a**2.0 + 1.4736*a**3.0 -   |
# |            vs.            |                      |                    |        |       2.2087*a**4.0 + 2.213*a**5.0 - 0.3826        |
# |     LSTSQ Target Poly     |                      |                    |        |                                                    |
# |                           |                      |                    |        |                                                    |
# +---------------------------+----------------------+--------------------+--------+----------------------------------------------------+

# %%
plot_and_save_single_polynomial_prediction_evaluation(lambda_net_test_dataset_list, 
                                                      function_values_test_list, 
                                                      inet_preds_test_list,
                                                      per_network_preds_list,
                                                      rand_index=index, 
                                                      plot_type=3)
# Out:
# +---------------------------+----------------------+--------------------+--------+----------------------------------------------------+
# |         Comparison        |         MAE          |      R2-Score      | Poly 1 |                       Poly 2                       |
# +---------------------------+----------------------+--------------------+--------+----------------------------------------------------+
# |       Lambda Preds        | 0.008978770175955293 | 0.997420532159953  |   -    |  -0.1089*a**1.0 + 4.2759*a**2.0 - 11.677*a**3.0 +  |
# |            vs.            |                      |                    |        |      12.2308*a**4.0 - 3.8129*a**5.0 - 0.3189       |
# |  LSTSQ Lambda Preds Poly  |                      |                    |        |                                                    |
# |                           |                      |                    |        |                                                    |
# |       Lambda Preds        | 0.03504685981155667  | 0.9574253493506687 |   -    |    0.699700027704239*a**2.0 - 0.29339998960495     |
# |            vs.            |                      |                    |        |                                                    |
# |         I-Net Poly        |                      |                    |        |                                                    |
# |                           |                      |                    |        |                                                    |
# |       Lambda Preds        | 0.03185905427425366  | 0.972304441863804  |   -    |    0.792200028896332*a**3.0 - 0.251999996602535    |
# |            vs.            |                      |                    |        |                                                    |
# |    Per Network Opt Poly   |                      |                    |        |                                                    |
# |                           |                      |                    |        |                                                    |
# |       Lambda Preds        | 0.016330547248236387 | 0.9901621988164027 |   -    |  0.8804*a**1.0 - 0.7895*a**2.0 - 0.3549*a**3.0 +   |
# |            vs.            |                      |                    |        |       0.3058*a**4.0 + 0.9988*a**5.0 - 0.3765       |
# |        Target Poly        |                      |                    |        |                                                    |
# |                           |                      |                    |        |                                                    |
# |       Lambda Preds        | 0.01791094394390229  | 0.987518170537625  |   -    |  0.9886*a**1.0 - 1.4002*a**2.0 + 1.4736*a**3.0 -   |
# |            vs.            |                      |                    |        |       2.2087*a**4.0 + 2.213*a**5.0 - 0.3826        |
# |     LSTSQ Target Poly     |                      |                    |        |                                                    |
# |                           |                      |                    |        |                                                    |
# +---------------------------+----------------------+--------------------+--------+----------------------------------------------------+

# %% [markdown]
# # BENCHMARK (RANDOM GUESS) EVALUATION

# %%
list_of_random_polynomials = np.random.uniform(low=-10, high=10, size=(len(lambda_net_test_dataset_list[-1]), sparsity))

# %%
true_fv_test = parallel_fv_calculation_from_polynomial(lambda_net_test_dataset_list[-1].target_polynomial_list, lambda_net_test_dataset_list[-1].X_test_data_list, force_complete_poly_representation=True)
random_fv_test = parallel_fv_calculation_from_polynomial(list_of_random_polynomials, lambda_net_test_dataset_list[-1].X_test_data_list, force_complete_poly_representation=True)

# %%
print('Random Guess Error Coefficients: ' + str(np.round(mean_absolute_error(lambda_net_test_dataset_list[-1].target_polynomial_list, list_of_random_polynomials), 4)))
# Out:
# Random Guess Error Coefficients: 5.0486

# %%
print('Random Guess Error FVs: ' + str(np.round(mean_absolute_error_function_values(true_fv_test, random_fv_test), 4)))
# Out:
# Random Guess Error FVs: 6.387

# %% [markdown]
# # BENCHMARK (EDUCATED GUESS/MEAN PREDICTION) EVALUATION

# %%
true_fv_train = parallel_fv_calculation_from_polynomial(lambda_net_test_dataset_list[-1].target_polynomial_list, lambda_net_test_dataset_list[-1].X_test_data_list, force_complete_poly_representation=True)

mean_fv = np.mean(true_fv_train)
mean_fv_pred_test = [mean_fv for _ in range(true_fv_test.shape[0])]

# %%
print('Educated Guess/Mean Prediction Error FVs: ' + str(np.round(mean_absolute_error_function_values(true_fv_test, mean_fv_pred_test), 4)))
# Out:
# Educated Guess/Mean Prediction Error FVs: 0.6149

# %%
# %%script false --no-raise-error
#
# base_model = generate_base_model()
# random_evaluation_dataset = np.random.uniform(low=x_min, high=x_max, size=(random_evaluation_dataset_size, n))
# #random_evaluation_dataset = lambda_train_input_train_split[0]#lambda_train_input[0] #JUST [0] HERE BECAUSE EVALUATION ALWAYS ON THE SAME DATASET FOR ALL!!
# list_of_monomial_identifiers_numbers = np.array([list(monomial_identifiers) for monomial_identifiers in list_of_monomial_identifiers]).astype(float)
#
#
# loss_function = mean_absolute_error_tf_fv_lambda_extended_wrapper(random_evaluation_dataset, list_of_monomial_identifiers_numbers, base_model)
#
# X_train = X_train_list[-1].values[:,1:]
# y_train = y_train_list[-1].values[:,2:]
#
# #X_train = X_train[:,1:]
# y_train_model = np.hstack((y_train, X_train))
#
# print('seed_in_inet_training = ' + str(seed_in_inet_training), loss_function(y_train_model, y_train))
#
#
# seed_in_inet_training = False
#
# loss_function = mean_absolute_error_tf_fv_lambda_extended_wrapper(random_evaluation_dataset, list_of_monomial_identifiers_numbers, base_model)
#
# X_train = X_train_list[-1].values[:,1:]
# y_train = y_train_list[-1].values[:,2:]
#
# X_train = X_train[:,1:]
# y_train_model = np.hstack((y_train, X_train))
#
# print('seed_in_inet_training = ' + str(seed_in_inet_training), loss_function(y_train_model, y_train))
#
# seed_in_inet_training = True

# %%
if use_gpu:
    from numba import cuda 
    device = cuda.get_current_device()
    device.reset()

# %%
lambda_net_test_dataset = lambda_net_test_dataset_list[-1]
current_jobs = 1

lr=0.5
max_steps = 100
early_stopping=10
restarts=2
per_network_dataset_size = 500

list_of_monomial_identifiers_numbers = np.array([list(monomial_identifiers) for monomial_identifiers in list_of_monomial_identifiers]).astype(float)  

if n_jobs != -1:
    n_jobs_per_network = min(n_jobs, os.cpu_count() // current_jobs)
else: 
    n_jobs_per_network = os.cpu_count() // current_jobs - 1

printing = True if n_jobs_per_network == 1 else False


lambda_network_weights_list = np.array(lambda_net_test_dataset.weight_list)
if evaluate_with_real_function: #target polynomial as inet target
    poly_representation_list = np.array(lambda_net_test_dataset.target_polynomial_list)
else: #lstsq lambda pred polynomial as inet target
    poly_representation_list = np.array(lambda_net_test_dataset.lstsq_lambda_pred_polynomial_list)


config = {
         'n': n,
         'inet_loss': inet_loss,
         'sparsity': sparsity,
         'lambda_network_layers': lambda_network_layers,
         'interpretation_net_output_shape': interpretation_net_output_shape,
         'RANDOM_SEED': RANDOM_SEED,
         'nas': nas,
         'number_of_lambda_weights': number_of_lambda_weights,
         'interpretation_net_output_monomials': interpretation_net_output_monomials,
         #'list_of_monomial_identifiers': list_of_monomial_identifiers,
         'x_min': x_min,
         'x_max': x_max,
         }


lambda_network_weights = lambda_network_weights_list[0]
poly_representation = poly_representation_list[0]



per_network_poly_optimization_tf(per_network_dataset_size, 
                                lambda_network_weights, 
                                  list_of_monomial_identifiers_numbers, 
                                  config, 
                                  lr=lr, 
                                  max_steps = max_steps, 
                                  early_stopping=early_stopping, 
                                  restarts=restarts, 
                                  printing=True)

# %% [markdown]
# # Evaluate Per-Network Poly Optimization

# %% [markdown]
# ## Example Optimization (Common Optimizer)

# %%
random_index = RANDOM_SEED

per_network_hyperparams = {
    'optimizer':  'Powell',
    'jac': 'fprime',
    'max_steps': 5000,#100,
    'restarts': 3,
    'per_network_dataset_size': 500,
}

lambda_net_test_dataset = lambda_net_test_dataset_list[-1]
lambda_network_weights_list = np.array(lambda_net_test_dataset.weight_list)
lambda_network_weights = lambda_network_weights_list[random_index]

list_of_monomial_identifiers_numbers = np.array([list(monomial_identifiers) for monomial_identifiers in list_of_monomial_identifiers]).astype(float)  

printing = True

config = {
         'n': n,
         'inet_loss': inet_loss,
         'sparsity': sparsity,
         'lambda_network_layers': lambda_network_layers,
         'interpretation_net_output_shape': interpretation_net_output_shape,
         'RANDOM_SEED': RANDOM_SEED,
         'nas': nas,
         'number_of_lambda_weights': number_of_lambda_weights,
         'interpretation_net_output_monomials': interpretation_net_output_monomials,
         'x_min': x_min,
         'x_max': x_max,
         }


per_network_optimization_error, per_network_optimization_polynomial = per_network_poly_optimization_scipy(per_network_hyperparams['per_network_dataset_size'], 
                                                                                                      lambda_network_weights, 
                                                                                                      list_of_monomial_identifiers_numbers, 
                                                                                                      config,
                                                                                                      optimizer = per_network_hyperparams['optimizer'],
                                                                                                      jac = per_network_hyperparams['jac'],
                                                                                                      max_steps = per_network_hyperparams['max_steps'], 
                                                                                                      restarts = per_network_hyperparams['restarts'],
                                                                                                      printing = True,
                                                                                                      return_error = True)

print('\n\nError: ' + str(per_network_optimization_error))
print_polynomial_from_coefficients(per_network_optimization_polynomial)

# %% [markdown]
# ## Example Optimization (Neural Optimizer)

# %%
random_index = RANDOM_SEED

per_network_hyperparams = {
    'optimizer': tf.keras.optimizers.RMSprop,
    'lr': 0.02,
    'max_steps': 500,
    'early_stopping': 10,
    'restarts': 3,
    'per_network_dataset_size': 5000,
}

lambda_net_test_dataset = lambda_net_test_dataset_list[-1]
lambda_network_weights_list = np.array(lambda_net_test_dataset.weight_list)
lambda_network_weights = lambda_network_weights_list[random_index]

list_of_monomial_identifiers_numbers = np.array([list(monomial_identifiers) for monomial_identifiers in list_of_monomial_identifiers]).astype(float)  

printing = True

config = {
         'n': n,
         'inet_loss': inet_loss,
         'sparsity': sparsity,
         'lambda_network_layers': lambda_network_layers,
         'interpretation_net_output_shape': interpretation_net_output_shape,
         'RANDOM_SEED': RANDOM_SEED,
         'nas': nas,
         'number_of_lambda_weights': number_of_lambda_weights,
         'interpretation_net_output_monomials': interpretation_net_output_monomials,
         'x_min': x_min,
         'x_max': x_max,
         }


per_network_optimization_error, per_network_optimization_polynomial = per_network_poly_optimization_tf(per_network_hyperparams['per_network_dataset_size'], 
                                                                                                      lambda_network_weights, 
                                                                                                      list_of_monomial_identifiers_numbers, 
                                                                                                      config,
                                                                                                      optimizer = per_network_hyperparams['optimizer'],
                                                                                                      lr = per_network_hyperparams['lr'], 
                                                                                                      max_steps = per_network_hyperparams['max_steps'], 
                                                                                                      early_stopping = per_network_hyperparams['early_stopping'], 
                                                                                                      restarts = per_network_hyperparams['restarts'],
                                                                                                      printing = True,
                                                                                                      return_error = True)

print('\n\nError: ' + str(per_network_optimization_error.numpy()))
print_polynomial_from_coefficients(per_network_optimization_polynomial)

# %% [markdown]
# ## Grid Search Common Optimizers

# %%
# %%script false --no-raise-error
#
# pd.set_option('max_colwidth', 100)
#
# evaluation_size = 10
#
# per_network_hyperparams = {
#     'optimizer':  [
#                    'Nelder-Mead',
#                    'Powell',
#
#                    'CG',
#                    'BFGS',
#                    'Newton-CG',
#                    #'L-BFGS-B', #'>' not supported between instances of 'int' and 'NoneType'
#                    'TNC',
#
#                    'COBYLA',
#                    'SLSQP',
#
#                    #'trust-constr', # TypeError: _minimize_trustregion_constr() got an unexpected keyword argument 'maxfun'
#                    #'dogleg', # ValueError: Hessian is required for dogleg minimization
#                    #'trust-ncg', #ValueError: Either the Hessian or the Hessian-vector product is required for Newton-CG trust-region minimization
#                    #'trust-exact', # ValueError: Hessian matrix is required for trust region exact minimization.
#                    #'trust-krylov' #ValueError: Either the Hessian or the Hessian-vector product is required for Krylov trust-region minimization
#                    ],
#     'jac': ['fprime'],
#     'max_steps': [5000],#100,
#     'restarts': [3],
#     'per_network_dataset_size': [500],
# }
#
# #param_iterator = ParameterSampler(per_network_hyperparams, n_iter=60, random_state=RANDOM_SEED)
# param_iterator = ParameterGrid(per_network_hyperparams)
#
#
# lambda_net_test_dataset = lambda_net_test_dataset_list[-1]
# lambda_network_weights_list = np.array(lambda_net_test_dataset.weight_list)
#
# list_of_monomial_identifiers_numbers = np.array([list(monomial_identifiers) for monomial_identifiers in list_of_monomial_identifiers]).astype(float)
# printing = True if n_jobs == 1 else False
#
# config = {
#          'n': n,
#          'inet_loss': inet_loss,
#          'sparsity': sparsity,
#          'lambda_network_layers': lambda_network_layers,
#          'interpretation_net_output_shape': interpretation_net_output_shape,
#          'RANDOM_SEED': RANDOM_SEED,
#          'nas': nas,
#          'number_of_lambda_weights': number_of_lambda_weights,
#          'interpretation_net_output_monomials': interpretation_net_output_monomials,
#          'x_min': x_min,
#          'x_max': x_max,
#          }

# %%
# %%script false --no-raise-error
#
# params_error_list = []
# for params in tqdm(param_iterator):
#     parallel_per_network = Parallel(n_jobs=n_jobs, verbose=0, backend='loky')
#
#     result_list = parallel_per_network(delayed(per_network_poly_optimization_scipy)(params['per_network_dataset_size'],
#                                                                                   lambda_network_weights,
#                                                                                   list_of_monomial_identifiers_numbers,
#                                                                                   config,
#                                                                                   optimizer = params['optimizer'],
#                                                                                   jac = params['jac'],
#                                                                                   max_steps = params['max_steps'],
#                                                                                   restarts = params['restarts'],
#                                                                                   printing = printing,
#                                                                                   return_error = True) for lambda_network_weights in lambda_network_weights_list[:evaluation_size])
#
#
#     per_network_optimization_errors = [result[0] for result in result_list]
#     per_network_optimization_polynomials = [result[1] for result in result_list]
#
#     params_score = np.mean(per_network_optimization_errors)
#
#     evaluation_result = list(params.values())
#     evaluation_result.append(params_score)
#
#     params_error_list.append(evaluation_result)
#
#     del parallel_per_network
#
# columns = list(params.keys())
# columns.append('score')
# params_error_df = pd.DataFrame(data=params_error_list, columns=columns).sort_values(by='score')
# params_error_df.head(10)

# %% [markdown]
# ## Grid Search Neural Optimizers

# %%
# %%script false --no-raise-error
#
# pd.set_option('max_colwidth', 100)
#
# evaluation_size = 100
#
# per_network_hyperparams = {
#     'optimizer': [tf.keras.optimizers.RMSprop], #[tf.keras.optimizers.SGD, tf.optimizers.Adam, tf.keras.optimizers.RMSprop, tf.keras.optimizers.Adadelta]
#     'lr': [0.02], #[0.5, 0.25, 0.1, 0.05, 0.025]
#     'max_steps': [5000],#100,
#     'early_stopping': [10],
#     'restarts': [3],
#     'per_network_dataset_size': [5000],
# }
#
# #param_iterator = ParameterSampler(per_network_hyperparams, n_iter=60, random_state=RANDOM_SEED)
# param_iterator = ParameterGrid(per_network_hyperparams)
#
#
# lambda_net_test_dataset = lambda_net_test_dataset_list[-1]
# lambda_network_weights_list = np.array(lambda_net_test_dataset.weight_list)
#
# list_of_monomial_identifiers_numbers = np.array([list(monomial_identifiers) for monomial_identifiers in list_of_monomial_identifiers]).astype(float)
# printing = True if n_jobs == 1 else False
#
# config = {
#          'n': n,
#          'inet_loss': inet_loss,
#          'sparsity': sparsity,
#          'lambda_network_layers': lambda_network_layers,
#          'interpretation_net_output_shape': interpretation_net_output_shape,
#          'RANDOM_SEED': RANDOM_SEED,
#          'nas': nas,
#          'number_of_lambda_weights': number_of_lambda_weights,
#          'interpretation_net_output_monomials': interpretation_net_output_monomials,
#          'x_min': x_min,
#          'x_max': x_max,
#          }

# %%
# %%script false --no-raise-error
#
# params_error_list = []
# for params in tqdm(param_iterator):
#     parallel_per_network = Parallel(n_jobs=n_jobs, verbose=0, backend='loky')
#
#     result_list = parallel_per_network(delayed(per_network_poly_optimization_tf)(params['per_network_dataset_size'],
#                                                                                   lambda_network_weights,
#                                                                                   list_of_monomial_identifiers_numbers,
#                                                                                   config,
#                                                                                   optimizer = params['optimizer'],
#                                                                                   lr = params['lr'],
#                                                                                   max_steps = params['max_steps'],
#                                                                                   early_stopping = params['early_stopping'],
#                                                                                   restarts = params['restarts'],
#                                                                                   printing = printing,
#                                                                                   return_error = True) for lambda_network_weights in lambda_network_weights_list[:evaluation_size])
#
#
#     per_network_optimization_errors = [result[0] for result in result_list]
#     per_network_optimization_polynomials = [result[1] for result in result_list]
#
#     params_score = np.mean(per_network_optimization_errors)
#
#     evaluation_result = list(params.values())
#     evaluation_result.append(params_score)
#
#     params_error_list.append(evaluation_result)
#
#     del parallel_per_network
#
# columns = list(params.keys())
# columns.append('score')
# params_error_df = pd.DataFrame(data=params_error_list, columns=columns).sort_values(by='score')
# params_error_df.head(10)
