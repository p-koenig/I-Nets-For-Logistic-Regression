# %% [markdown]
# # Inerpretation-Net Training
#
# # Experiment 1: I-Net Performance for Different Algebras and Complexities
# # Experiment 2: I-Net Performance Comparison for λ-Nets with Different Training Levels
# # Experiment 3: I-Net Performance Comparison Different Training Data Sizes

# %% [markdown]
# ## Specitication of Experiment Settings

# %%
#######################################################################################################################################
###################################################### CONFIG FILE ####################################################################
#######################################################################################################################################
sleep_time = 0 #minutes


config = {
    'data': {
        'd': 5, #degree
        'n': 1, #number of variables
        'sparsity': None,
        'sample_sparsity': None,
        'x_max': 1,
        'x_min': 0,
        'x_distrib': 'uniform', #'normal', 'uniform', 'beta', 'Gamma', 'laplace'
        'a_max': 100,
        'a_min': -100,
        'lambda_nets_total': 10000,
        'noise': 0.1,
        'noise_distrib': 'normal', #'normal', 'uniform', 'beta', 'Gamma', 'laplace'
        
        'same_training_all_lambda_nets': False,

        'fixed_seed_lambda_training': True,
        'fixed_initialization_lambda_training': False,
        'number_different_lambda_trainings': 1,
    },
    'lambda_net': {
        'epochs_lambda': 1000,
        'early_stopping_lambda': True,  #if early stopping is used, multi_epoch_analysis is deactivated
        'early_stopping_min_delta_lambda': 1e-4,
        'batch_lambda': 64,
        'dropout': 0,
        'lambda_network_layers': [5*'sparsity'],
        'optimizer_lambda': 'adam',
        'loss_lambda': 'mae',
        'number_of_lambda_weights': None,
        'lambda_dataset_size': 5000,
    },
    'i_net': {
        'optimizer': 'custom',#adam
        'inet_loss': 'mae',
        'inet_metrics': ['r2'],
        'dropout': 0.25,
        'dropout_output': 0,
        'epochs': 500,
        'early_stopping': True,
        'batch_size': 256,
        'dense_layers': [512, 1024],
        'convolution_layers': None,
        'lstm_layers': None,
        'interpretation_dataset_size': 10000,
                
        'interpretation_net_output_monomials': None, #(None, int)
        'interpretation_net_output_shape': None, #calculated automatically later
        'test_size': 100, #Float for fraction, Int for number
        
        'evaluate_with_real_function': False,
        'consider_labels_training': False,
                      
        'data_reshape_version': None, #default to 2 options:(None, 0,1 2)
        'nas': False,
        'nas_type': 'SEQUENTIAL', #options:(None, 'SEQUENTIAL', 'CNN', 'LSTM', 'CNN-LSTM', 'CNN-LSTM-parallel')      
        'nas_trials': 100,
    },
    'evaluation': {   
        'inet_holdout_seed_evaluation': False,
        
        #set if multi_epoch_analysis should be performed
        'multi_epoch_analysis': True,
        'each_epochs_save_lambda': 100,
        'epoch_start': 0, #use to skip first epochs in multi_epoch_analysis
        
        #set if samples analysis should be performed
        'samples_list': None,#[100, 500, 750, 1000, 2500, 5000, 7500, 10000, 15000, 20000, 25000, 28125] 
       
        'random_evaluation_dataset_size': 500,
    },
    'computation':{
        'n_jobs': -3,
        'use_gpu': False,
        'gpu_numbers': '0',
        'RANDOM_SEED': 42,   
    }
}

# %% [markdown]
# ## Imports

# %%
#######################################################################################################################################
########################################### IMPORT GLOBAL VARIABLES FROM CONFIG #######################################################
#######################################################################################################################################
globals().update(config['data'])
globals().update(config['lambda_net'])
globals().update(config['i_net'])
globals().update(config['evaluation'])
globals().update(config['computation'])

# %%
#######################################################################################################################################
##################################################### IMPORT LIBRARIES ################################################################
#######################################################################################################################################
from itertools import product       
from tqdm import tqdm_notebook as tqdm
import pickle
import numpy as np
import pandas as pd
import scipy as sp
import timeit
import psutil

from functools import reduce
from more_itertools import random_product 
from sklearn.preprocessing import Normalizer

import sys
import os
import shutil

import logging

from prettytable import PrettyTable
import colored
import math

import time
from datetime import datetime
from collections.abc import Iterable


from joblib import Parallel, delayed

from scipy.integrate import quad

from sklearn.model_selection import cross_val_score, train_test_split, StratifiedKFold, KFold, ParameterGrid, ParameterSampler
from sklearn.metrics import accuracy_score, log_loss, roc_auc_score, f1_score, mean_absolute_error, r2_score

from similaritymeasures import frechet_dist, area_between_two_curves, dtw
import keras
from keras.models import Sequential
from keras.layers.core import Dense, Dropout
from keras.utils import plot_model
from IPython.display import Image

import keras.backend as K
from livelossplot import PlotLossesKerasTF
from keras_tqdm import TQDMNotebookCallback
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

from matplotlib import pyplot as plt
import seaborn as sns


import tensorflow as tf
import random 


import warnings


from IPython.display import display, Math, Latex, clear_output

# %%
sys.path.append('..')

from utilities.InterpretationNet import *
from utilities.LambdaNet import *
from utilities.metrics import *
from utilities.utility_functions import *

#from symbolic_metamodeling.pysymbolic.algorithms.symbolic_metamodeling import *

# %%
#######################################################################################################################################
################################################### VARIABLE ADJUSTMENTS ##############################################################
#######################################################################################################################################
variables = 'abcdefghijklmnopqrstuvwxyz'[:n]

n_jobs = min((epochs_lambda//each_epochs_save_lambda+1, n_jobs)) if multi_epoch_analysis else min(len(samples_list), n_jobs) if samples_list!=None else 1

multi_epoch_analysis = False if early_stopping_lambda else multi_epoch_analysis #deactivate multi_epoch_analysis if early stopping is used

each_epochs_save_lambda = each_epochs_save_lambda if multi_epoch_analysis else epochs_lambda
epochs_save_range_lambda = range(epoch_start//each_epochs_save_lambda, epochs_lambda//each_epochs_save_lambda) if each_epochs_save_lambda == 1 else range(epoch_start//each_epochs_save_lambda, epochs_lambda//each_epochs_save_lambda+1) if multi_epoch_analysis else range(1,2)

data_reshape_version = 2 if data_reshape_version == None and (convolution_layers != None or lstm_layers != None or (nas and nas_type != 'SEQUENTIAL')) else data_reshape_version
#######################################################################################################################################
###################################################### SET VARIABLES + DESIGN #########################################################
#######################################################################################################################################

#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 
os.environ['CUDA_VISIBLE_DEVICES'] = gpu_numbers if use_gpu else ''

logging.getLogger('tensorflow').disabled = True

sns.set_style("darkgrid")
#np.set_printoptions(suppress=True)

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
if int(tf.__version__[0]) >= 2:
    tf.random.set_seed(RANDOM_SEED)
else:
    tf.set_random_seed(RANDOM_SEED)
    
    
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.max_columns', 500)

warnings.filterwarnings('ignore')

# %%
#######################################################################################################################################
####################################################### CONFIG ADJUSTMENTS ############################################################
#######################################################################################################################################
config['evaluation']['multi_epoch_analysis'] = multi_epoch_analysis
config['evaluation']['each_epochs_save_lambda'] = each_epochs_save_lambda
config['i_net']['data_reshape_version'] = data_reshape_version

config['data']['sparsity'] = nCr(config['data']['n']+config['data']['d'], config['data']['d'])
config['data']['sample_sparsity'] = config['data']['sparsity'] if config['data']['sample_sparsity'] == None else config['data']['sample_sparsity']

config['i_net']['interpretation_net_output_shape'] = config['data']['sparsity'] if config['i_net']['interpretation_net_output_monomials'] is None else config['data']['sparsity']*config['i_net']['interpretation_net_output_monomials']+config['i_net']['interpretation_net_output_monomials']


transformed_layers = []
for layer in config['lambda_net']['lambda_network_layers']:
    if type(layer) == str:
        transformed_layers.append(layer.count('sparsity')*config['data']['sparsity'])
    else:
        transformed_layers.append(layer)
config['lambda_net']['lambda_network_layers'] = transformed_layers

layers_with_input_output = list(flatten([[config['data']['n']], config['lambda_net']['lambda_network_layers'], [1]]))
number_of_lambda_weights = 0
for i in range(len(layers_with_input_output)-1):
    number_of_lambda_weights += (layers_with_input_output[i]+1)*layers_with_input_output[i+1]  
config['lambda_net']['number_of_lambda_weights'] = number_of_lambda_weights
    
#######################################################################################################################################
################################################## UPDATE VARIABLES ###################################################################
#######################################################################################################################################
globals().update(config['data'])
globals().update(config['lambda_net'])
globals().update(config['i_net'])
globals().update(config['evaluation'])
globals().update(config['computation'])



initialize_LambdaNet_config_from_curent_notebook(config)
initialize_metrics_config_from_curent_notebook(config)
initialize_utility_functions_config_from_curent_notebook(config)
initialize_InterpretationNet_config_from_curent_notebook(config)


#######################################################################################################################################
###################################################### PATH + FOLDER CREATION #########################################################
#######################################################################################################################################
globals().update(generate_paths(path_type='interpretation_net'))
create_folders_inet()

#######################################################################################################################################
############################################################ SLEEP TIMER ##############################################################
#######################################################################################################################################
sleep_minutes(sleep_time)

# %%
print(path_identifier_interpretation_net_data)

print(path_identifier_lambda_net_data)
# Out:
# inet_dense512-1024-output_6_drop0.25e500b256_custom/lnets_10000_30-1000e_ES0.0001_64b_adam_mae_train_5000_diffX_1-FixSeed_42/var_1_d_5_sparsity_6_amin_-100_amax_100_xdist_uniform_noise_normal_0.1
# lnets_10000_30-1000e_ES0.0001_64b_adam_mae_train_5000_diffX_1-FixSeed_42/var_1_d_5_sparsity_6_amin_-100_amax_100_xmin_0_xmax_1_xdist_uniform_noise_normal_0.1

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print("Num XLA-GPUs Available: ", len(tf.config.experimental.list_physical_devices('XLA_GPU')))
# Out:
# Num GPUs Available:  0
# Num XLA-GPUs Available:  0

# %% [markdown]
# ## Utility functions

# %% [markdown]
# ### Generate List of Monomial Identifiers

# %%
list_of_monomial_identifiers_extended = []
for i in tqdm(range((d+1)**n)):    
    monomial_identifier = dec_to_base(i, base = (d+1)).zfill(n) 
    list_of_monomial_identifiers_extended.append(monomial_identifier)

print('List length: ' + str(len(list_of_monomial_identifiers_extended)))
print('Number of monomials in a polynomial with ' + str(n) + ' variables and degree ' + str(d) + ': ' + str(nCr(n+d, d)))
print('Sparsity: ' + str(sparsity))
print(list_of_monomial_identifiers_extended)

list_of_monomial_identifiers = []
for monomial_identifier in tqdm(list_of_monomial_identifiers_extended):
    monomial_identifier_values = list(map(int, list(monomial_identifier)))
    if sum(monomial_identifier_values) <= d:
        list_of_monomial_identifiers.append(monomial_identifier)

print('List length: ' + str(len(list_of_monomial_identifiers)))
print('Number of monomials in a polynomial with ' + str(n) + ' variables and degree ' + str(d) + ': ' + str(nCr(n+d, d)))
print('Sparsity: ' + str(sparsity))
print(list_of_monomial_identifiers)


layers_with_input_output = list(flatten([[n], lambda_network_layers, [1]]))
number_of_lambda_weights = 0
for i in range(len(layers_with_input_output)-1):
    number_of_lambda_weights += (layers_with_input_output[i]+1)*layers_with_input_output[i+1]
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# List length: 6
# Number of monomials in a polynomial with 1 variables and degree 5: 6
# Sparsity: 6
# ['0', '1', '2', '3', '4', '5']
#   0%|          | 0/6 [00:00<?, ?it/s]
# List length: 6
# Number of monomials in a polynomial with 1 variables and degree 5: 6
# Sparsity: 6
# ['0', '1', '2', '3', '4', '5']

# %% [markdown]
# ## Load Data and Generate Datasets

# %%
def load_lambda_nets(index):
    
    if psutil.virtual_memory().percent > 80:
        raise SystemExit("Out of RAM!")
    
    directory = './data/weights/' + 'weights_' + path_identifier_lambda_net_data + '/'
    path_weights = directory + 'weights_epoch_' + str(index).zfill(3) + '.txt'
    path_X_data = directory + 'lambda_X_test_data.txt'
    path_y_data = directory + 'lambda_y_test_data.txt'        
    
    weight_data = pd.read_csv(path_weights, sep=",", header=None)
    weight_data = weight_data.sort_values(by=0).sample(frac=1, random_state=RANDOM_SEED)
    weight_data = weight_data.sort_values(by=0).sample(n=interpretation_dataset_size, random_state=RANDOM_SEED)
    
    lambda_X_test_data = pd.read_csv(path_X_data, sep=",", header=None)
    lambda_X_test_data = lambda_X_test_data.sort_values(by=0).sample(frac=1, random_state=RANDOM_SEED)
    lambda_X_test_data = lambda_X_test_data.sort_values(by=0).sample(n=interpretation_dataset_size, random_state=RANDOM_SEED)
    
    lambda_y_test_data = pd.read_csv(path_y_data, sep=",", header=None)
    lambda_y_test_data = lambda_y_test_data.sort_values(by=0).sample(frac=1, random_state=RANDOM_SEED)
    lambda_y_test_data = lambda_y_test_data.sort_values(by=0).sample(n=interpretation_dataset_size, random_state=RANDOM_SEED)
        
    lambda_nets = [None] * weight_data.shape[0]
    for i, (row_weights, row_lambda_X_test_data, row_lambda_y_test_data) in enumerate(zip(weight_data.values, lambda_X_test_data.values, lambda_y_test_data.values)):        
        lambda_net = LambdaNet(row_weights, row_lambda_X_test_data, row_lambda_y_test_data)
        lambda_nets[i] = lambda_net
                
    lambda_net_dataset = LambdaNetDataset(lambda_nets)
        
    return lambda_net_dataset

# %%
#LOAD DATA

parallel = Parallel(n_jobs=n_jobs, verbose=3, backend='multiprocessing')
lambda_net_dataset_list = parallel(delayed(load_lambda_nets)((i+1)*each_epochs_save_lambda if each_epochs_save_lambda==1 else i*each_epochs_save_lambda if i > 1 else each_epochs_save_lambda if i==1 else 1) for i in epochs_save_range_lambda)  
del parallel

lambda_net_dataset = lambda_net_dataset_list[-1]
# Out:
# [Parallel(n_jobs=-3)]: Using backend MultiprocessingBackend with 22 concurrent workers.
# [Parallel(n_jobs=-3)]: Done   1 out of   1 | elapsed:   11.4s finished

# %% [markdown]
# ## Data Inspection

# %%
lambda_net_dataset.as_pandas().head()
# Out:
#             seed  0-target  1-target  2-target  3-target  4-target  5-target  \
# 6252  1373158606    19.441    64.331     9.054    86.972    79.463     5.935
# 4684  1373158606     1.590   -44.282   -11.825   -83.220    -1.186    39.111
# 1731  1373158606   -19.084   -21.097    93.004    45.811     3.748    43.701
# 4742  1373158606    -2.763    80.962   -48.518   -66.867   -71.702   -69.024
# 4521  1373158606    93.063   -23.940   -91.272    26.621   -90.579   -61.679
#
#       0-lstsq_lambda  1-lstsq_lambda  2-lstsq_lambda  3-lstsq_lambda  \
# 6252          15.294         121.910        -262.623         257.461
# 4684           0.440         -44.165         125.741        -625.284
# 1731         -18.767         -35.482         429.612       -1371.706
# 4742           6.019          74.395        -606.442        2191.199
# 4521          97.680         -10.869        -818.271        2848.944
#
#       4-lstsq_lambda  5-lstsq_lambda  0-lstsq_target  1-lstsq_target  \
# 6252         616.384        -523.246          19.451          64.248
# 4684         696.732        -250.025           1.586         -44.076
# 1731        2065.681        -938.295         -19.088         -21.132
# 4742       -3137.256        1310.095          -2.768          81.211
#        [ 23.20323121],
#        [ 28.77382938],
#        [ 95.58188424],
#        [ 35.14243119],
#        [ 38.71071122],
#        [ 26.63158243]])

# %% [markdown]
# ## Generate Datasets for Interpretation-Net training

# %%
#generate train, test and validation data for training

lambda_net_train_dataset_list = []
lambda_net_valid_dataset_list = []
lambda_net_test_dataset_list = []

for lambda_net_dataset in lambda_net_dataset_list:
    
    
    if inet_holdout_seed_evaluation:
        complete_seed_list = list(set(lambda_net_dataset.train_settings_list['seed']))#list(weight_data.iloc[:,1].unique())

        random.seed(RANDOM_SEED)
        
        if isinstance(test_size, float):
            test_size = int(len(complete_seed_list)-len(complete_seed_list)/(1/(1-test_size)))
        
        test_seeds = random.sample(complete_seed_list, test_size)
        lambda_net_test_dataset = lambda_net_dataset.get_lambda_nets_by_seed(test_seeds)
        complete_seed_list = list(set(complete_seed_list) - set(test_seeds))#complete_seed_list.remove(test_seeds)
        
        random.seed(RANDOM_SEED)
        valid_seeds = random.sample(complete_seed_list, int(len(complete_seed_list)-len(complete_seed_list)/(1/(1-0.1))))
        lambda_net_valid_dataset = lambda_net_dataset.get_lambda_nets_by_seed(valid_seeds)
        complete_seed_list = list(set(complete_seed_list) - set(valid_seeds))

        train_seeds = complete_seed_list
        lambda_net_train_dataset = lambda_net_dataset.get_lambda_nets_by_seed(train_seeds)       
        
        lambda_net_train_dataset_list.append(lambda_net_train_dataset)
        lambda_net_valid_dataset_list.append(lambda_net_valid_dataset)
        lambda_net_test_dataset_list.append(lambda_net_test_dataset)
        
        del lambda_net_dataset
    else:
        lambda_net_train_with_valid_dataset, lambda_net_test_dataset = split_LambdaNetDataset(lambda_net_dataset, test_split=test_size)
        lambda_net_train_dataset, lambda_net_valid_dataset = split_LambdaNetDataset(lambda_net_train_with_valid_dataset, test_split=0.1)
        
        lambda_net_train_dataset_list.append(lambda_net_train_dataset)
        lambda_net_valid_dataset_list.append(lambda_net_valid_dataset)
        lambda_net_test_dataset_list.append(lambda_net_test_dataset)
    
        del lambda_net_dataset, lambda_net_train_with_valid_dataset

        
del lambda_net_dataset_list

# %%
lambda_net_train_dataset_list[-1].as_pandas().shape
# Out:
# (8910, 110)

# %%
lambda_net_valid_dataset_list[-1].as_pandas().shape
# Out:
# (990, 110)

# %%
lambda_net_test_dataset_list[-1].as_pandas().shape
# Out:
# (100, 110)

# %%
lambda_net_train_dataset_list[-1].as_pandas().head()
# Out:
#             seed  0-target  1-target  2-target  3-target  4-target  5-target  \
# 5548  1373158606    94.239   -75.912   -41.685    37.081    71.046    50.261
# 1854  1373158606   -99.843   -20.508    33.484     0.301   -97.480   -88.433
# 739   1373158606   -20.835   -25.978   -59.778   -14.422   -39.218    15.534
# 3588  1373158606   -78.752    17.057    24.938    32.825   -89.422    69.631
# 4649  1373158606   -69.515   -52.541    30.787    13.316   -14.228    -5.614
#
#       0-lstsq_lambda  1-lstsq_lambda  2-lstsq_lambda  3-lstsq_lambda  \
#
#
#       wb_41  wb_42  wb_43  wb_44  wb_45  wb_46  wb_47  wb_48  wb_49  wb_50  \
# 7217  0.000  0.000  0.328 -0.080  0.261 -0.023  0.201 -0.148 -0.137 -0.040
# 8291  0.000  0.000 -2.664  2.196 -2.561  2.013  2.271  2.138  2.259  2.268
# 4607  0.000  0.000 -1.269  1.134 -1.199 -0.016 -1.235 -1.315 -1.324 -0.001
# 5114  0.000  0.000 -2.613  2.025 -2.418  1.882  2.111  1.996  2.077  2.101
# 1859  0.000  0.000  2.565 -0.079  2.498 -0.024  2.598 -0.148 -6.059 -0.040
#
#       wb_51  wb_52  wb_53  wb_54  wb_55  wb_56  wb_57  wb_58  wb_59  wb_60  \
# 7217  0.277  0.412  0.000  0.000  0.000  0.267  0.000  0.000  0.000 -0.254
# 8291 -2.686 -0.022  0.000  0.000  0.000 -2.857  0.000  0.000  0.000 -0.254
# 4607 -1.553 -1.380  0.000  0.000  0.000 -1.506  0.000  0.000  0.000 -0.254
# 5114 -2.784 -2.567  0.000  0.000  0.000 -2.794  0.000  0.000  0.000 -0.254
# 1859  2.362  2.555  0.000  0.000  0.000  2.344  0.000  0.000  0.000 -0.254
#
#       wb_61  wb_62  wb_63  wb_64  wb_65  wb_66  wb_67  wb_68  wb_69  wb_70  \
# 7217 -0.359 -2.321 -2.333  0.138  0.187 -2.172 -0.408 -2.388 -1.998 -2.178
# 8291 -0.359 -8.278 -9.151  2.345  2.402 -8.666 -0.408 -9.308  2.093  2.278
# 4607 -0.359 -2.896 -3.608 -3.234  1.248 -3.342 -0.408 -3.654 -2.600 -2.656
# 5114 -0.359 -7.519 -7.349  2.561  2.555 -6.076 -0.408 -7.722 -5.671 -5.733
# 1859 -0.359 -2.380 -2.436  0.138  0.187 -2.243 -0.408 -2.519 -2.042 -2.125
#
#       wb_71  wb_72  wb_73  wb_74  wb_75  wb_76  wb_77  wb_78   wb_79  wb_80  \
# 7217 -0.352 -0.364 -2.200  0.121 -2.271  0.394 -2.170  0.149   0.003  0.049
# 8291 -0.352 -0.364 -8.145  2.334 -7.977  2.612  2.193  2.333   2.251  2.267
# 4607 -0.352 -0.364 -2.853  1.129 -2.758  0.383 -2.687 -3.201  -2.865  0.010
# 5114 -0.352 -0.364 -6.793  2.520 -6.304  2.781  2.373  2.562   2.440  2.439
# 1859 -0.352 -0.364 -2.228  0.121 -2.243  0.393 -2.147  0.149 -22.680  0.048
#
#       wb_81  wb_82  wb_83  wb_84  wb_85  wb_86  wb_87  wb_88  wb_89   wb_90
# 7217 -2.411 -2.125 -0.261 -0.383 -0.059 -2.432  0.144 -0.258 -0.315  -0.666
# 8291 -9.371 -0.045 -0.261 -0.383 -0.059 -9.604  0.144 -0.258 -0.315   5.247
# 4607 -3.865 -3.283 -0.261 -0.383 -0.059 -3.840  0.144 -0.258 -0.315   1.866
# 5114 -7.872 -7.156 -0.261 -0.383 -0.059 -7.879  0.144 -0.258 -0.315   3.579
# 1859 -2.607 -2.306 -0.261 -0.383 -0.059 -2.619  0.144 -0.258 -0.315 -10.214

# %% [markdown]
# ## Interpretation Network Training

# %%
(history_list, 

#scores_valid_list,
scores_test_list, 

#function_values_valid_list, 
function_values_test_list, 

#polynomial_dict_valid_list,
polynomial_dict_test_list,

#distrib_dict_valid_list,
distrib_dict_test_list,

model_list) = calculate_interpretation_net_results(lambda_net_train_dataset_list, 
                                                   lambda_net_valid_dataset_list, 
                                                   lambda_net_test_dataset_list)
# Out:
# ----------------------------------------------- TRAINING INTERPRETATION NET -----------------------------------------------
#
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:   23.3s finished
# FV Calculation Time: 0:01:11
# ---------------------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------- CALCULATE SCORES ----------------------------------------------------
# lambda_preds_VS_target_polynomials
# lambda_preds_VS_lstsq_lambda_pred_polynomials
# lambda_preds_VS_lstsq_target_polynomials
# lambda_preds_VS_inet_polynomials
# lambda_preds_VS_symbolic_regression_functions
# lambda_preds_VS_per_network_polynomials
# target_polynomials_VS_lstsq_lambda_pred_polynomials
# target_polynomials_VS_lstsq_target_polynomials
# target_polynomials_VS_inet_polynomials
# target_polynomials_VS_symbolic_regression_functions
# target_polynomials_VS_per_network_polynomials
# lstsq_lambda_pred_polynomials_VS_lstsq_target_polynomials
# lstsq_lambda_pred_polynomials_VS_inet_polynomials
# lstsq_lambda_pred_polynomials_VS_symbolic_regression_functions
# lstsq_lambda_pred_polynomials_VS_per_network_polynomials
# lstsq_target_polynomials_VS_inet_polynomials
# lstsq_target_polynomials_VS_symbolic_regression_functions
# lstsq_target_polynomials_VS_per_network_polynomials
# inet_polynomials_VS_symbolic_regression_functions
# inet_polynomials_VS_per_network_polynomials
# symbolic_regression_functions_VS_per_network_polynomials
# Score Calculation Time: 0:00:02
# ---------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Evaluate Interpretation Net

# %%
poly_optimize = tf.constant([float(i) for i in range(interpretation_net_output_shape)])

if interpretation_net_output_monomials != None:
    poly_optimize_coeffs = poly_optimize[:interpretation_net_output_monomials]

    poly_optimize_identifiers_list = []
    for i in range(interpretation_net_output_monomials):
        poly_optimize_identifiers = tf.math.softmax(poly_optimize[sparsity*i+interpretation_net_output_monomials:sparsity*(i+1)+interpretation_net_output_monomials])
        poly_optimize_identifiers_list.append(poly_optimize_identifiers)
    poly_optimize_identifiers_list = tf.keras.backend.flatten(poly_optimize_identifiers_list)
    poly_optimize = tf.concat([poly_optimize_coeffs, poly_optimize_identifiers_list], axis=0)

# %%
poly_optimize
# Out:
# <tf.Tensor: shape=(6,), dtype=float32, numpy=array([0., 1., 2., 3., 4., 5.], dtype=float32)>

# %%
if nas:
    for trial in history_list[-1]: 
        print(trial.summary())

# %%
if len(model_list) >= 1:
    print(model_list[-1].summary())
    print(model_list[-1].get_config())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 91)]              0
# _________________________________________________________________
# hidden1_512 (Dense)          (None, 512)               47104
# _________________________________________________________________
# dropout1_0.25 (Dropout)      (None, 512)               0
# _________________________________________________________________
# hidden2_1024 (Dense)         (None, 1024)              525312
# _________________________________________________________________
# output_1024 (Dense)          (None, 6)                 6150
# =================================================================
# Total params: 578,566
# Trainable params: 578,566
# Non-trainable params: 0
# _________________________________________________________________
# None
# {'name': 'model', 'layers': [{'class_name': 'InputLayer', 'config': {'batch_input_shape': (None, 91), 'dtype': 'float32', 'sparse': False, 'ragged': False, 'name': 'input'}, 'name': 'input', 'inbound_nodes': []}, {'class_name': 'Dense', 'config': {'name': 'hidden1_512', 'trainable': True, 'dtype': 'float32', 'units': 512, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'name': 'hidden1_512', 'inbound_nodes': [[['input', 0, 0, {}]]]}, {'class_name': 'Dropout', 'config': {'name': 'dropout1_0.25', 'trainable': True, 'dtype': 'float32', 'rate': 0.25, 'noise_shape': None, 'seed': None}, 'name': 'dropout1_0.25', 'inbound_nodes': [[['hidden1_512', 0, 0, {}]]]}, {'class_name': 'Dense', 'config': {'name': 'hidden2_1024', 'trainable': True, 'dtype': 'float32', 'units': 1024, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'name': 'hidden2_1024', 'inbound_nodes': [[['dropout1_0.25', 0, 0, {}]]]}, {'class_name': 'Dense', 'config': {'name': 'output_1024', 'trainable': True, 'dtype': 'float32', 'units': 6, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'name': 'output_1024', 'inbound_nodes': [[['hidden2_1024', 0, 0, {}]]]}], 'input_layers': [['input', 0, 0]], 'output_layers': [['output_1024', 0, 0]]}

# %%
if evaluate_with_real_function:
    keys = ['inetPoly_VS_targetPoly_test', 'perNetworkPoly_VS_targetPoly_test', 'predLambda_VS_targetPoly_test', 'lstsqLambda_VS_targetPoly_test', 'lstsqTarget_VS_targetPoly_test']
else:
    keys = ['inetPoly_VS_predLambda_test', 'inetPoly_VS_lstsqLambda_test', 'perNetworkPoly_VS_predLambda_test', 'perNetworkPoly_VS_lstsqLambda_test', 'lstsqLambda_VS_predLambda_test', 'predLambda_VS_targetPoly_test']

# %%
scores_test_list[-1].index
# Out:
# Index(['lambda_preds_VS_target_polynomials',
#        'lambda_preds_VS_lstsq_lambda_pred_polynomials',
#        'lambda_preds_VS_lstsq_target_polynomials',
#        'lambda_preds_VS_inet_polynomials',
#        'lambda_preds_VS_symbolic_regression_functions',
#        'lambda_preds_VS_per_network_polynomials',
#        'target_polynomials_VS_lstsq_lambda_pred_polynomials',
#        'target_polynomials_VS_lstsq_target_polynomials',
#        'target_polynomials_VS_inet_polynomials',
#        'target_polynomials_VS_symbolic_regression_functions',
#        'target_polynomials_VS_per_network_polynomials',
#        'lstsq_lambda_pred_polynomials_VS_lstsq_target_polynomials',
#        'lstsq_lambda_pred_polynomials_VS_inet_polynomials',
#        'lstsq_lambda_pred_polynomials_VS_symbolic_regression_functions',
#        'lstsq_lambda_pred_polynomials_VS_per_network_polynomials',
#        'lstsq_target_polynomials_VS_inet_polynomials',
#        'lstsq_target_polynomials_VS_symbolic_regression_functions',
#        'lstsq_target_polynomials_VS_per_network_polynomials',
#        'inet_polynomials_VS_symbolic_regression_functions',
#        'inet_polynomials_VS_per_network_polynomials',
#        'symbolic_regression_functions_VS_per_network_polynomials'],
#       dtype='object')

# %%
scores_test_list[-1]
# Out:
#                                                        MAE    RMSE     MAPE  \
# lambda_preds_VS_target_polynomials                     NaN     NaN      NaN
# lambda_preds_VS_lstsq_lambda_pred_polynomials          NaN     NaN      NaN
# lambda_preds_VS_lstsq_target_polynomials               NaN     NaN      NaN
# lambda_preds_VS_inet_polynomials                       NaN     NaN      NaN
# lambda_preds_VS_symbolic_regression_functions          NaN     NaN      NaN
# lambda_preds_VS_per_network_polynomials                NaN     NaN      NaN
# target_polynomials_VS_lstsq_lambda_pred_polynom... 387.993 891.192   23.869
# target_polynomials_VS_lstsq_target_polynomials       1.335   2.179    0.125
# target_polynomials_VS_inet_polynomials              34.217  44.436    5.506
# target_polynomials_VS_symbolic_regression_funct...     NaN     NaN      NaN
# target_polynomials_VS_per_network_polynomials       79.624 153.558   11.210
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 387.919 891.251 1118.107
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  372.725 889.224  267.292
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...     NaN     NaN      NaN
# lstsq_lambda_pred_polynomials_VS_per_network_po... 358.067 846.325   84.034
# lstsq_target_polynomials_VS_inet_polynomials        34.208  44.426    9.439
# lstsq_target_polynomials_VS_symbolic_regression...     NaN     NaN      NaN
# lstsq_target_polynomials_VS_per_network_polynom...  79.613 153.651   10.143
# inet_polynomials_VS_symbolic_regression_functions      NaN     NaN      NaN
# inet_polynomials_VS_per_network_polynomials         62.539 148.409   38.324
# symbolic_regression_functions_VS_per_network_po...     NaN     NaN      NaN
#
#                                                     Accuracy  \
# lambda_preds_VS_target_polynomials                       NaN
# lambda_preds_VS_lstsq_lambda_pred_polynomials            NaN
# lambda_preds_VS_lstsq_target_polynomials                 NaN
# lambda_preds_VS_inet_polynomials                         NaN
# lambda_preds_VS_symbolic_regression_functions            NaN
# lambda_preds_VS_per_network_polynomials                  NaN
# target_polynomials_VS_lstsq_lambda_pred_polynom...     0.000
# target_polynomials_VS_lstsq_target_polynomials         0.190
# target_polynomials_VS_inet_polynomials                 0.002
# target_polynomials_VS_symbolic_regression_funct...       NaN
# target_polynomials_VS_per_network_polynomials          0.002
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...     0.003
# lstsq_lambda_pred_polynomials_VS_inet_polynomials      0.002
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...       NaN
# lstsq_lambda_pred_polynomials_VS_per_network_po...     0.075
# lstsq_target_polynomials_VS_inet_polynomials           0.002
# lstsq_target_polynomials_VS_symbolic_regression...       NaN
# lstsq_target_polynomials_VS_per_network_polynom...     0.002
# inet_polynomials_VS_symbolic_regression_functions        NaN
# inet_polynomials_VS_per_network_polynomials            0.005
# symbolic_regression_functions_VS_per_network_po...       NaN
#
#                                                     Accuracy Multilabel  \
# lambda_preds_VS_target_polynomials                                  NaN
# lambda_preds_VS_lstsq_lambda_pred_polynomials                       NaN
# lambda_preds_VS_lstsq_target_polynomials                            NaN
# lambda_preds_VS_inet_polynomials                                    NaN
# lambda_preds_VS_symbolic_regression_functions                       NaN
# lambda_preds_VS_per_network_polynomials                             NaN
# target_polynomials_VS_lstsq_lambda_pred_polynom...                0.000
# target_polynomials_VS_lstsq_target_polynomials                    0.000
# target_polynomials_VS_inet_polynomials                            0.000
# target_polynomials_VS_symbolic_regression_funct...                  NaN
# target_polynomials_VS_per_network_polynomials                     0.000
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...                0.000
# lstsq_lambda_pred_polynomials_VS_inet_polynomials                 0.000
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...                  NaN
# lstsq_lambda_pred_polynomials_VS_per_network_po...                0.000
# lstsq_target_polynomials_VS_inet_polynomials                      0.000
# lstsq_target_polynomials_VS_symbolic_regression...                  NaN
# lstsq_target_polynomials_VS_per_network_polynom...                0.000
# inet_polynomials_VS_symbolic_regression_functions                   NaN
# inet_polynomials_VS_per_network_polynomials                       0.000
# symbolic_regression_functions_VS_per_network_po...                  NaN
#
#                                                     MAE FV  RMSE FV  MAPE FV  \
# lambda_preds_VS_target_polynomials                   4.846    7.075    0.210
# lambda_preds_VS_lstsq_lambda_pred_polynomials        0.316    0.397    0.084
# lambda_preds_VS_lstsq_target_polynomials             4.846    7.075    0.210
# lambda_preds_VS_inet_polynomials                     2.224    2.808    0.397
# lambda_preds_VS_symbolic_regression_functions          inf      inf      inf
# lambda_preds_VS_per_network_polynomials              0.526    0.746    0.118
# target_polynomials_VS_lstsq_lambda_pred_polynom...   4.781    7.040    0.340
# target_polynomials_VS_lstsq_target_polynomials       0.004    0.004    0.000
# target_polynomials_VS_inet_polynomials               5.771    7.983    0.500
# target_polynomials_VS_symbolic_regression_funct...     inf      inf      inf
# target_polynomials_VS_per_network_polynomials        4.791    6.940    0.353
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...   4.781    7.040    0.245
# lstsq_lambda_pred_polynomials_VS_inet_polynomials    2.191    2.766    0.551
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...     inf      inf      inf
# lstsq_lambda_pred_polynomials_VS_per_network_po...   0.478    0.609    0.213
# lstsq_target_polynomials_VS_inet_polynomials         5.771    7.983    0.556
# lstsq_target_polynomials_VS_symbolic_regression...     inf      inf      inf
# lstsq_target_polynomials_VS_per_network_polynom...   4.791    6.940    0.418
# inet_polynomials_VS_symbolic_regression_functions      inf      inf      inf
# inet_polynomials_VS_per_network_polynomials          2.130    2.665    0.250
# symbolic_regression_functions_VS_per_network_po...     inf      inf    0.422
#
#                                                     R2 FV  RAAE FV  RMAE FV  \
# lambda_preds_VS_target_polynomials                 -0.610    0.439    1.361
# lambda_preds_VS_lstsq_lambda_pred_polynomials       0.999    0.013    0.045
# lambda_preds_VS_lstsq_target_polynomials           -0.610    0.439    1.360
# lambda_preds_VS_inet_polynomials                    0.887    0.145    0.348
# lambda_preds_VS_symbolic_regression_functions        -inf      inf     -inf
# lambda_preds_VS_per_network_polynomials             0.997    0.021    0.075
# target_polynomials_VS_lstsq_lambda_pred_polynom...  0.788    0.236    0.796
# target_polynomials_VS_lstsq_target_polynomials      1.000    0.000    0.001
# target_polynomials_VS_inet_polynomials              0.716    0.291    0.841
# target_polynomials_VS_symbolic_regression_funct...   -inf      inf     -inf
# target_polynomials_VS_per_network_polynomials       0.788    0.238    0.760
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... -0.609    0.437    1.361
# lstsq_lambda_pred_polynomials_VS_inet_polynomials   0.890    0.143    0.336
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...   -inf      inf     -inf
# lstsq_lambda_pred_polynomials_VS_per_network_po...  0.998    0.019    0.062
# lstsq_target_polynomials_VS_inet_polynomials        0.716    0.291    0.841
# lstsq_target_polynomials_VS_symbolic_regression...   -inf      inf     -inf
# lstsq_target_polynomials_VS_per_network_polynom...  0.788    0.238    0.760
# inet_polynomials_VS_symbolic_regression_functions    -inf      inf     -inf
# inet_polynomials_VS_per_network_polynomials         0.956    0.124    0.218
# symbolic_regression_functions_VS_per_network_po...    NaN      NaN      inf
#
#                                                     MEAN STD FV DIFF  \
# lambda_preds_VS_target_polynomials                             6.810
# lambda_preds_VS_lstsq_lambda_pred_polynomials                  0.396
# lambda_preds_VS_lstsq_target_polynomials                       6.810
# lambda_preds_VS_inet_polynomials                               2.427
# lambda_preds_VS_symbolic_regression_functions                    inf
# lambda_preds_VS_per_network_polynomials                        0.736
# target_polynomials_VS_lstsq_lambda_pred_polynom...             6.772
# target_polynomials_VS_lstsq_target_polynomials                 0.004
# target_polynomials_VS_inet_polynomials                         7.411
# target_polynomials_VS_symbolic_regression_funct...               inf
# target_polynomials_VS_per_network_polynomials                  6.676
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...             6.772
# lstsq_lambda_pred_polynomials_VS_inet_polynomials              2.381
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...               inf
# lstsq_lambda_pred_polynomials_VS_per_network_po...             0.594
# lstsq_target_polynomials_VS_inet_polynomials                   7.411
# lstsq_target_polynomials_VS_symbolic_regression...               inf
# lstsq_target_polynomials_VS_per_network_polynom...             6.676
# inet_polynomials_VS_symbolic_regression_functions                inf
# inet_polynomials_VS_per_network_polynomials                    2.257
# symbolic_regression_functions_VS_per_network_po...               inf
#
#                                                     MEAN FV1  MEAN FV2  \
# lambda_preds_VS_target_polynomials                     8.639     9.030
# lambda_preds_VS_lstsq_lambda_pred_polynomials          8.639     8.643
# lambda_preds_VS_lstsq_target_polynomials               8.639     9.030
# lambda_preds_VS_inet_polynomials                       8.639     8.727
# lambda_preds_VS_symbolic_regression_functions          8.639       inf
# lambda_preds_VS_per_network_polynomials                8.639     8.627
# target_polynomials_VS_lstsq_lambda_pred_polynom...     9.030     8.643
# target_polynomials_VS_lstsq_target_polynomials         9.030     9.030
# target_polynomials_VS_inet_polynomials                 9.030     8.727
# target_polynomials_VS_symbolic_regression_funct...     9.030       inf
# target_polynomials_VS_per_network_polynomials          9.030     8.627
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...     8.643     9.030
# lstsq_lambda_pred_polynomials_VS_inet_polynomials      8.643     8.727
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...     8.643       inf
# lstsq_lambda_pred_polynomials_VS_per_network_po...     8.643     8.627
# lstsq_target_polynomials_VS_inet_polynomials           9.030     8.727
# lstsq_target_polynomials_VS_symbolic_regression...     9.030       inf
# lstsq_target_polynomials_VS_per_network_polynom...     9.030     8.627
# inet_polynomials_VS_symbolic_regression_functions      8.727       inf
# inet_polynomials_VS_per_network_polynomials            8.727     8.627
# symbolic_regression_functions_VS_per_network_po...       inf     8.627
#
#                                                     STD FV1  STD FV2
# lambda_preds_VS_target_polynomials                   71.177   74.280
# lambda_preds_VS_lstsq_lambda_pred_polynomials        71.177   71.157
# lambda_preds_VS_lstsq_target_polynomials             71.177   74.281
# lambda_preds_VS_inet_polynomials                     71.177   70.317
# lambda_preds_VS_symbolic_regression_functions        71.177      inf
# lambda_preds_VS_per_network_polynomials              71.177   71.202
# target_polynomials_VS_lstsq_lambda_pred_polynom...   74.280   71.157
# target_polynomials_VS_lstsq_target_polynomials       74.280   74.281
# target_polynomials_VS_inet_polynomials               74.280   70.317
# target_polynomials_VS_symbolic_regression_funct...   74.280      inf
# target_polynomials_VS_per_network_polynomials        74.280   71.202
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...   71.157   74.281
# lstsq_lambda_pred_polynomials_VS_inet_polynomials    71.157   70.317
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...   71.157      inf
# lstsq_lambda_pred_polynomials_VS_per_network_po...   71.157   71.202
# lstsq_target_polynomials_VS_inet_polynomials         74.281   70.317
# lstsq_target_polynomials_VS_symbolic_regression...   74.281      inf
# lstsq_target_polynomials_VS_per_network_polynom...   74.281   71.202
# inet_polynomials_VS_symbolic_regression_functions    70.317      inf
# inet_polynomials_VS_per_network_polynomials          70.317   71.202
# symbolic_regression_functions_VS_per_network_po...      inf   71.202

# %%
distrib_dict_test_list[-1]['MAE']
# Out:
#                                                       L-0   L-1   L-2    L-3  \
# lambda_preds_VS_target_polynomials                 11.215 3.758 1.546  1.977
# lambda_preds_VS_lstsq_lambda_pred_polynomials       0.000 0.977 0.297  0.423
# lambda_preds_VS_lstsq_target_polynomials           11.213 3.757 1.546  1.976
# lambda_preds_VS_inet_polynomials                    0.829 3.105 1.749  3.211
# lambda_preds_VS_symbolic_regression_functions       0.544 2.547 1.024 12.976
# lambda_preds_VS_per_network_polynomials             0.000 1.843 0.373  1.166
# target_polynomials_VS_lstsq_lambda_pred_polynom... 11.215 3.488 1.532  1.957
# target_polynomials_VS_lstsq_target_polynomials      0.003 0.003 0.005  0.003
# target_polynomials_VS_inet_polynomials             11.177 4.051 2.578  2.319
# target_polynomials_VS_symbolic_regression_funct... 11.185 4.325 1.731 12.745
# target_polynomials_VS_per_network_polynomials      11.215 3.620 1.402  1.673
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 11.213 3.486 1.533  1.956
# lstsq_lambda_pred_polynomials_VS_inet_polynomials   0.829 2.978 1.675  3.161
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...  0.544 2.550 0.911 12.962
# lstsq_lambda_pred_polynomials_VS_per_network_po...  0.000 1.541 0.249  1.142
# lstsq_target_polynomials_VS_inet_polynomials       11.175 4.050 2.580  2.318
# lstsq_target_polynomials_VS_symbolic_regression... 11.183 4.323 1.732 12.746
# lstsq_target_polynomials_VS_per_network_polynom... 11.213 3.617 1.404  1.674
# inet_polynomials_VS_symbolic_regression_functions   0.824 2.518 1.269 14.114
# inet_polynomials_VS_per_network_polynomials         0.829 2.348 1.767  3.328
# symbolic_regression_functions_VS_per_network_po...  0.544 1.914 0.956 12.117
#
#                                                      L-4   L-5   L-6   L-7  \
# lambda_preds_VS_target_polynomials                 3.709 1.103 1.606 0.918
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.144 0.406 0.286 0.214
# lambda_preds_VS_lstsq_target_polynomials           3.711 1.102 1.606 0.918
# lambda_preds_VS_inet_polynomials                   3.214 1.606 4.531 2.440
# lambda_preds_VS_symbolic_regression_functions      3.261 0.717 0.607 0.853
# lambda_preds_VS_per_network_polynomials            1.500 0.540 0.539 0.467
# target_polynomials_VS_lstsq_lambda_pred_polynom... 3.150 1.109 1.629 0.958
# target_polynomials_VS_lstsq_target_polynomials     0.004 0.003 0.002 0.003
# target_polynomials_VS_inet_polynomials             4.870 1.563 5.237 1.940
# target_polynomials_VS_symbolic_regression_funct... 4.637 0.583 2.038 1.038
# target_polynomials_VS_per_network_polynomials      3.129 0.917 1.809 0.956
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 3.152 1.108 1.629 0.959
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  2.961 1.504 4.452 2.437
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 2.858 0.657 0.484 0.838
# lstsq_lambda_pred_polynomials_VS_per_network_po... 1.355 0.633 0.480 0.483
# lstsq_target_polynomials_VS_inet_polynomials       4.869 1.562 5.236 1.938
# lstsq_target_polynomials_VS_symbolic_regression... 4.635 0.581 2.038 1.037
# lstsq_target_polynomials_VS_per_network_polynom... 3.131 0.915 1.809 0.956
# inet_polynomials_VS_symbolic_regression_functions  0.987 1.327 4.697 1.693
# inet_polynomials_VS_per_network_polynomials        3.054 1.373 4.255 2.324
# symbolic_regression_functions_VS_per_network_po... 2.702 0.469 0.720 0.804
#
#                                                      L-8   L-9  L-10  L-11  \
# lambda_preds_VS_target_polynomials                 2.081 6.694 2.717 2.845
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.336 0.000 0.000 0.157
# lambda_preds_VS_lstsq_target_polynomials           2.082 6.694 2.716 2.842
# lambda_preds_VS_inet_polynomials                   3.548 1.337 0.945 1.130
# lambda_preds_VS_symbolic_regression_functions      1.516 0.533 0.055 0.633
# lambda_preds_VS_per_network_polynomials            0.651 0.001 0.001 0.147
# target_polynomials_VS_lstsq_lambda_pred_polynom... 2.106 6.694 2.717 2.821
# target_polynomials_VS_lstsq_target_polynomials     0.003 0.002 0.002 0.004
# target_polynomials_VS_inet_polynomials             4.082 6.751 3.544 3.534
# target_polynomials_VS_symbolic_regression_funct... 2.449 6.694 2.720 2.906
# target_polynomials_VS_per_network_polynomials      2.070 6.694 2.717 2.807
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 2.107 6.694 2.716 2.818
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  3.556 1.337 0.945 1.174
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 1.625 0.533 0.055 0.629
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.585 0.001 0.001 0.143
# lstsq_target_polynomials_VS_inet_polynomials       4.082 6.750 3.543 3.531
# lstsq_target_polynomials_VS_symbolic_regression... 2.447 6.693 2.720 2.904
# lstsq_target_polynomials_VS_per_network_polynom... 2.070 6.694 2.717 2.804
# inet_polynomials_VS_symbolic_regression_functions  2.534 0.875 0.942 1.523
# inet_polynomials_VS_per_network_polynomials        3.465 1.337 0.945 1.169
# symbolic_regression_functions_VS_per_network_po... 1.316 0.533 0.055 0.547
#
#                                                     L-12  L-13  L-14  L-15  \
# lambda_preds_VS_target_polynomials                 1.765 0.865 0.784 3.972
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.384 0.329 0.377 0.952
# lambda_preds_VS_lstsq_target_polynomials           1.764 0.863 0.783 3.974
# lambda_preds_VS_inet_polynomials                   1.598 1.625 2.396 3.266
# lambda_preds_VS_symbolic_regression_functions      0.816 0.585 0.559 1.528
# lambda_preds_VS_per_network_polynomials            0.369 0.396 0.458 1.766
# target_polynomials_VS_lstsq_lambda_pred_polynom... 1.702 0.799 0.692 3.745
# target_polynomials_VS_lstsq_target_polynomials     0.003 0.003 0.004 0.004
# target_polynomials_VS_inet_polynomials             2.225 1.703 2.683 4.204
# target_polynomials_VS_symbolic_regression_funct... 2.024 1.227 1.119 4.346
# target_polynomials_VS_per_network_polynomials      1.848 0.854 0.885 3.212
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 1.702 0.797 0.692 3.748
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  1.403 1.606 2.487 3.390
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.885 0.484 0.557 1.381
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.211 0.310 0.317 1.688
# lstsq_target_polynomials_VS_inet_polynomials       2.225 1.703 2.684 4.207
# lstsq_target_polynomials_VS_symbolic_regression... 2.024 1.225 1.118 4.348
# lstsq_target_polynomials_VS_per_network_polynom... 1.848 0.853 0.885 3.214
# inet_polynomials_VS_symbolic_regression_functions  1.590 1.564 2.743 4.430
# inet_polynomials_VS_per_network_polynomials        1.318 1.707 2.602 3.478
# symbolic_regression_functions_VS_per_network_po... 0.696 0.405 0.404 1.946
#
#                                                     L-16  L-17   L-18  L-19  \
# lambda_preds_VS_target_polynomials                 0.969 4.600 17.040 4.205
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.123 0.000  0.000 1.025
# lambda_preds_VS_lstsq_target_polynomials           0.971 4.600 17.039 4.208
# lambda_preds_VS_inet_polynomials                   1.358 0.692  0.663 4.705
# lambda_preds_VS_symbolic_regression_functions      0.234 0.117  1.122 3.226
# lambda_preds_VS_per_network_polynomials            0.117 0.071  0.001 2.463
# target_polynomials_VS_lstsq_lambda_pred_polynom... 1.002 4.600 17.040 4.112
# target_polynomials_VS_lstsq_target_polynomials     0.003 0.004  0.002 0.003
# target_polynomials_VS_inet_polynomials             1.917 4.140 17.385 6.649
# target_polynomials_VS_symbolic_regression_funct... 0.872 4.576 17.133 3.859
# target_polynomials_VS_per_network_polynomials      0.872 4.594 17.040 4.265
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 1.004 4.600 17.039 4.114
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  1.393 0.692  0.663 4.818
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.245 0.117  1.122 2.820
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.205 0.071  0.001 2.925
# lstsq_target_polynomials_VS_inet_polynomials       1.918 4.139 17.385 6.650
# lstsq_target_polynomials_VS_symbolic_regression... 0.873 4.575 17.132 3.862
# lstsq_target_polynomials_VS_per_network_polynom... 0.873 4.593 17.039 4.268
# inet_polynomials_VS_symbolic_regression_functions  1.360 0.705  0.853 6.460
# inet_polynomials_VS_per_network_polynomials        1.453 0.696  0.664 3.991
# symbolic_regression_functions_VS_per_network_po... 0.145 0.125  1.122 3.955
#
#                                                     L-20  L-21   L-22  L-23  \
# lambda_preds_VS_target_polynomials                 1.984 4.796 23.827 2.739
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.220 1.409  0.000 0.817
# lambda_preds_VS_lstsq_target_polynomials           1.984 4.797 23.825 2.739
# lambda_preds_VS_inet_polynomials                   2.090 3.825  1.281 2.693
# lambda_preds_VS_symbolic_regression_functions      1.422 3.012  0.393   inf
# lambda_preds_VS_per_network_polynomials            1.438 1.437  0.001 1.375
# target_polynomials_VS_lstsq_lambda_pred_polynom... 1.900 3.902 23.827 2.705
# target_polynomials_VS_lstsq_target_polynomials     0.002 0.002  0.004 0.002
# target_polynomials_VS_inet_polynomials             2.031 5.956 24.760 4.892
# target_polynomials_VS_symbolic_regression_funct... 0.927 5.165 23.650   inf
# target_polynomials_VS_per_network_polynomials      1.617 3.982 23.827 2.891
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 1.899 3.902 23.825 2.705
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  2.042 3.593  1.281 2.839
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 1.362 3.096  0.393   inf
# lstsq_lambda_pred_polynomials_VS_per_network_po... 1.427 0.902  0.001 1.411
# lstsq_target_polynomials_VS_inet_polynomials       2.031 5.955 24.758 4.892
# lstsq_target_polynomials_VS_symbolic_regression... 0.928 5.165 23.649   inf
# lstsq_target_polynomials_VS_per_network_polynom... 1.615 3.983 23.825 2.892
# inet_polynomials_VS_symbolic_regression_functions  1.265 2.133  1.517   inf
# inet_polynomials_VS_per_network_polynomials        1.533 3.248  1.281 2.421
# symbolic_regression_functions_VS_per_network_po... 0.891 2.488  0.393   inf
#
#                                                     L-24   L-25  L-26   L-27  \
# lambda_preds_VS_target_polynomials                 4.607 12.540 2.616  2.417
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.153  0.000 0.577  0.322
# lambda_preds_VS_lstsq_target_polynomials           4.607 12.539 2.616  2.417
# lambda_preds_VS_inet_polynomials                   3.171  1.154 1.771  9.856
# lambda_preds_VS_symbolic_regression_functions      3.180  2.404 1.319  1.239
# lambda_preds_VS_per_network_polynomials            1.434  0.007 1.098  0.375
# target_polynomials_VS_lstsq_lambda_pred_polynom... 4.073 12.540 2.577  2.306
# target_polynomials_VS_lstsq_target_polynomials     0.004  0.004 0.003  0.005
# target_polynomials_VS_inet_polynomials             5.941 12.945 1.484 11.774
# target_polynomials_VS_symbolic_regression_funct... 5.490 12.610 2.650  2.289
# target_polynomials_VS_per_network_polynomials      4.215 12.541 2.555  2.427
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 4.074 12.539 2.575  2.305
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  3.544  1.154 1.612  9.808
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 3.203  2.404 1.243  1.185
# lstsq_lambda_pred_polynomials_VS_per_network_po... 1.337  0.007 0.837  0.305
# lstsq_target_polynomials_VS_inet_polynomials       5.940 12.944 1.483 11.772
# lstsq_target_polynomials_VS_symbolic_regression... 5.489 12.609 2.649  2.288
# lstsq_target_polynomials_VS_per_network_polynom... 4.214 12.540 2.553  2.427
# inet_polynomials_VS_symbolic_regression_functions  2.992  3.175 1.274  9.557
# inet_polynomials_VS_per_network_polynomials        2.946  1.154 1.309  9.741
# symbolic_regression_functions_VS_per_network_po... 2.816  2.403 0.926  1.232
#
#                                                     L-28   L-29  L-30  L-31  \
# lambda_preds_VS_target_polynomials                 4.862 22.803 4.822 1.885
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.000  0.000 0.000 0.307
# lambda_preds_VS_lstsq_target_polynomials           4.862 22.804 4.817 1.886
# lambda_preds_VS_inet_polynomials                   1.740  0.794 0.691 2.588
# lambda_preds_VS_symbolic_regression_functions      0.409  0.138 1.663 2.017
# lambda_preds_VS_per_network_polynomials            0.000  0.003 0.001 0.825
# target_polynomials_VS_lstsq_lambda_pred_polynom... 4.862 22.803 4.822 1.899
# target_polynomials_VS_lstsq_target_polynomials     0.003  0.005 0.006 0.004
# target_polynomials_VS_inet_polynomials             5.921 23.357 5.240 2.722
# target_polynomials_VS_symbolic_regression_funct... 4.722 22.784 4.973 1.763
# target_polynomials_VS_per_network_polynomials      4.862 22.803 4.822 1.961
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 4.862 22.804 4.817 1.899
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  1.740  0.794 0.691 2.594
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.409  0.138 1.663 2.093
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.000  0.003 0.001 0.694
# lstsq_target_polynomials_VS_inet_polynomials       5.922 23.357 5.235 2.721
# lstsq_target_polynomials_VS_symbolic_regression... 4.722 22.785 4.968 1.762
# lstsq_target_polynomials_VS_per_network_polynom... 4.862 22.804 4.817 1.960
# inet_polynomials_VS_symbolic_regression_functions  2.149  0.764 1.521 2.753
# inet_polynomials_VS_per_network_polynomials        1.740  0.794 0.691 2.506
# symbolic_regression_functions_VS_per_network_po... 0.409  0.138 1.663 1.968
#
#                                                     L-32  L-33  L-34  L-35  \
# lambda_preds_VS_target_polynomials                 5.453 2.088 8.069 6.897
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.000 0.658 0.000 0.000
# lambda_preds_VS_lstsq_target_polynomials           5.453 2.089 8.067 6.898
# lambda_preds_VS_inet_polynomials                   0.937 1.802 0.847 0.699
# lambda_preds_VS_symbolic_regression_functions      2.325 1.545 0.343 0.276
# lambda_preds_VS_per_network_polynomials            0.000 0.637 0.089 0.000
# target_polynomials_VS_lstsq_lambda_pred_polynom... 5.453 1.617 8.069 6.897
# target_polynomials_VS_lstsq_target_polynomials     0.002 0.005 0.003 0.003
# target_polynomials_VS_inet_polynomials             6.097 2.597 7.990 6.342
# target_polynomials_VS_symbolic_regression_funct... 6.896 2.677 8.105 6.861
# target_polynomials_VS_per_network_polynomials      5.453 1.854 8.056 6.897
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 5.453 1.619 8.067 6.898
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.937 1.648 0.847 0.699
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 2.325 1.473 0.343 0.276
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.000 0.397 0.089 0.000
# lstsq_target_polynomials_VS_inet_polynomials       6.097 2.600 7.988 6.343
# lstsq_target_polynomials_VS_symbolic_regression... 6.896 2.679 8.103 6.861
# lstsq_target_polynomials_VS_per_network_polynom... 5.453 1.854 8.054 6.898
# inet_polynomials_VS_symbolic_regression_functions  1.403 1.068 0.842 0.707
# inet_polynomials_VS_per_network_polynomials        0.937 1.419 0.825 0.699
# symbolic_regression_functions_VS_per_network_po... 2.325 1.208 0.341 0.276
#
#                                                     L-36   L-37  L-38  L-39  \
# lambda_preds_VS_target_polynomials                 4.252  9.818 1.999 2.018
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.257  0.000 0.335 0.385
# lambda_preds_VS_lstsq_target_polynomials           4.252  9.818 1.999 2.019
# lambda_preds_VS_inet_polynomials                   4.858  1.314 2.045 1.655
# lambda_preds_VS_symbolic_regression_functions      2.020  2.200 1.247 1.371
# lambda_preds_VS_per_network_polynomials            2.410  0.003 0.995 1.111
# target_polynomials_VS_lstsq_lambda_pred_polynom... 3.807  9.818 1.987 1.967
# target_polynomials_VS_lstsq_target_polynomials     0.002  0.004 0.003 0.005
# target_polynomials_VS_inet_polynomials             7.689 10.077 1.549 2.647
# target_polynomials_VS_symbolic_regression_funct... 3.059 10.222 1.134 1.887
# target_polynomials_VS_per_network_polynomials      3.696  9.818 1.791 2.038
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 3.807  9.818 1.988 1.969
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  4.857  1.314 1.983 1.681
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 1.792  2.200 1.261 1.272
# lstsq_lambda_pred_polynomials_VS_per_network_po... 2.202  0.003 0.922 1.097
# lstsq_target_polynomials_VS_inet_polynomials       7.689 10.078 1.549 2.651
# lstsq_target_polynomials_VS_symbolic_regression... 3.059 10.223 1.135 1.889
# lstsq_target_polynomials_VS_per_network_polynom... 3.695  9.818 1.791 2.041
# inet_polynomials_VS_symbolic_regression_functions  4.632  0.886 1.714 1.180
# inet_polynomials_VS_per_network_polynomials        4.915  1.314 1.820 1.129
# symbolic_regression_functions_VS_per_network_po... 1.719  2.200 1.015 0.915
#
#                                                      L-40  L-41  L-42  L-43  \
# lambda_preds_VS_target_polynomials                 10.775 3.209 0.903 2.263
# lambda_preds_VS_lstsq_lambda_pred_polynomials       0.000 0.913 0.332 0.031
# lambda_preds_VS_lstsq_target_polynomials           10.775 3.210 0.903 2.264
# lambda_preds_VS_inet_polynomials                    1.121 2.355 5.411 1.724
# lambda_preds_VS_symbolic_regression_functions       1.811 1.386 1.026 3.154
# lambda_preds_VS_per_network_polynomials             0.003 0.858 0.451 0.040
# target_polynomials_VS_lstsq_lambda_pred_polynom... 10.775 3.205 0.846 2.266
# target_polynomials_VS_lstsq_target_polynomials      0.002 0.004 0.004 0.002
# target_polynomials_VS_inet_polynomials             10.954 3.603 5.629 2.311
# target_polynomials_VS_symbolic_regression_funct... 10.807 2.931 1.761 4.833
# target_polynomials_VS_per_network_polynomials      10.774 3.414 1.073 2.281
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 10.775 3.207 0.845 2.267
# lstsq_lambda_pred_polynomials_VS_inet_polynomials   1.121 2.180 5.358 1.728
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...  1.811 1.178 1.070 3.150
# lstsq_lambda_pred_polynomials_VS_per_network_po...  0.003 0.417 0.412 0.024
# lstsq_target_polynomials_VS_inet_polynomials       10.954 3.606 5.628 2.310
# lstsq_target_polynomials_VS_symbolic_regression... 10.807 2.932 1.760 4.834
# lstsq_target_polynomials_VS_per_network_polynom... 10.775 3.416 1.071 2.281
# inet_polynomials_VS_symbolic_regression_functions   1.679 1.866 4.490 4.878
# inet_polynomials_VS_per_network_polynomials         1.120 1.977 5.100 1.743
# symbolic_regression_functions_VS_per_network_po...  1.811 1.219 0.775 3.135
#
#                                                      L-44  L-45  L-46  L-47  \
# lambda_preds_VS_target_polynomials                  9.832 3.488 1.580 7.549
# lambda_preds_VS_lstsq_lambda_pred_polynomials       0.000 0.899 0.709 0.000
# lambda_preds_VS_lstsq_target_polynomials            9.834 3.488 1.580 7.549
# lambda_preds_VS_inet_polynomials                    2.168 2.509 6.957 1.645
# lambda_preds_VS_symbolic_regression_functions       0.385 2.070 1.114   inf
# lambda_preds_VS_per_network_polynomials             0.001 1.632 0.768 0.000
# target_polynomials_VS_lstsq_lambda_pred_polynom...  9.832 3.148 1.476 7.549
# target_polynomials_VS_lstsq_target_polynomials      0.004 0.003 0.003 0.003
# target_polynomials_VS_inet_polynomials             11.106 1.767 7.599 8.179
# target_polynomials_VS_symbolic_regression_funct...  9.733 2.332 1.864   inf
# target_polynomials_VS_per_network_polynomials       9.832 3.140 1.599 7.549
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  9.834 3.147 1.477 7.549
# lstsq_lambda_pred_polynomials_VS_inet_polynomials   2.168 2.335 6.841 1.645
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...  0.385 2.082 1.096   inf
# lstsq_lambda_pred_polynomials_VS_per_network_po...  0.001 1.588 0.793 0.000
# lstsq_target_polynomials_VS_inet_polynomials       11.109 1.767 7.602 8.179
# lstsq_target_polynomials_VS_symbolic_regression...  9.733 2.332 1.865   inf
# lstsq_target_polynomials_VS_per_network_polynom...  9.834 3.140 1.599 7.549
# inet_polynomials_VS_symbolic_regression_functions   2.552 1.056 6.869   inf
# inet_polynomials_VS_per_network_polynomials         2.168 2.390 6.846 1.645
# symbolic_regression_functions_VS_per_network_po...  0.385 1.834 0.680   inf
#
#                                                     L-48   L-49  L-50  L-51  \
# lambda_preds_VS_target_polynomials                 2.082  0.650 1.124 1.586
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.000  0.251 0.045 0.085
# lambda_preds_VS_lstsq_target_polynomials           2.082  0.647 1.124 1.586
# lambda_preds_VS_inet_polynomials                   0.684  2.524 0.927 1.468
# lambda_preds_VS_symbolic_regression_functions      0.660 27.881 0.505 2.107
# lambda_preds_VS_per_network_polynomials            0.032  0.439 0.045 0.302
# target_polynomials_VS_lstsq_lambda_pred_polynom... 2.082  0.651 1.123 1.573
# target_polynomials_VS_lstsq_target_polynomials     0.003  0.007 0.005 0.004
# target_polynomials_VS_inet_polynomials             1.628  2.582 1.061 2.883
# target_polynomials_VS_symbolic_regression_funct... 2.309 28.458 1.027 2.085
# target_polynomials_VS_per_network_polynomials      2.069  0.771 1.156 1.711
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 2.082  0.649 1.123 1.573
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.684  2.418 0.929 1.486
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.660 27.885 0.496 2.124
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.032  0.297 0.045 0.347
# lstsq_target_polynomials_VS_inet_polynomials       1.628  2.584 1.059 2.883
# lstsq_target_polynomials_VS_symbolic_regression... 2.309 28.457 1.028 2.088
# lstsq_target_polynomials_VS_per_network_polynom... 2.070  0.771 1.155 1.712
# inet_polynomials_VS_symbolic_regression_functions  0.823 27.639 1.087 3.264
# inet_polynomials_VS_per_network_polynomials        0.671  2.296 0.947 1.496
# symbolic_regression_functions_VS_per_network_po... 0.663 27.845 0.485 2.036
#
#                                                      L-52  L-53  L-54   L-55  \
# lambda_preds_VS_target_polynomials                 12.166 3.441 3.540 13.954
# lambda_preds_VS_lstsq_lambda_pred_polynomials       0.000 0.000 0.000  0.000
# lambda_preds_VS_lstsq_target_polynomials           12.165 3.443 3.541 13.953
# lambda_preds_VS_inet_polynomials                    0.812 0.658 0.912  1.362
# lambda_preds_VS_symbolic_regression_functions       0.195 0.919 0.619  1.024
# lambda_preds_VS_per_network_polynomials             0.002 0.014 0.000  0.006
# target_polynomials_VS_lstsq_lambda_pred_polynom... 12.166 3.441 3.540 13.954
# target_polynomials_VS_lstsq_target_polynomials      0.004 0.006 0.005  0.002
# target_polynomials_VS_inet_polynomials             12.082 3.607 4.349 14.515
# target_polynomials_VS_symbolic_regression_funct... 12.300 3.104 3.500 13.963
# target_polynomials_VS_per_network_polynomials      12.167 3.446 3.540 13.954
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 12.165 3.443 3.541 13.953
# lstsq_lambda_pred_polynomials_VS_inet_polynomials   0.812 0.658 0.912  1.362
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...  0.195 0.919 0.619  1.024
# lstsq_lambda_pred_polynomials_VS_per_network_po...  0.002 0.014 0.000  0.006
# lstsq_target_polynomials_VS_inet_polynomials       12.081 3.609 4.350 14.514
# lstsq_target_polynomials_VS_symbolic_regression... 12.298 3.106 3.500 13.962
# lstsq_target_polynomials_VS_per_network_polynom... 12.165 3.448 3.541 13.953
# inet_polynomials_VS_symbolic_regression_functions   0.994 1.567 1.075  1.353
# inet_polynomials_VS_per_network_polynomials         0.813 0.656 0.912  1.363
# symbolic_regression_functions_VS_per_network_po...  0.195 0.917 0.619  1.024
#
#                                                     L-56   L-57  L-58  L-59  \
# lambda_preds_VS_target_polynomials                 6.487 14.946 5.416 2.099
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.061  0.000 0.000 0.492
# lambda_preds_VS_lstsq_target_polynomials           6.486 14.947 5.414 2.102
# lambda_preds_VS_inet_polynomials                   5.422  0.286 0.290 4.688
# lambda_preds_VS_symbolic_regression_functions      2.075  2.475 0.382 2.766
# lambda_preds_VS_per_network_polynomials            1.059  0.002 0.000 0.484
# target_polynomials_VS_lstsq_lambda_pred_polynom... 6.520 14.946 5.416 2.047
# target_polynomials_VS_lstsq_target_polynomials     0.005  0.002 0.004 0.003
# target_polynomials_VS_inet_polynomials             7.304 15.030 5.309 4.887
# target_polynomials_VS_symbolic_regression_funct... 6.245 14.896 5.409 1.526
# target_polynomials_VS_per_network_polynomials      6.378 14.947 5.416 2.039
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 6.519 14.947 5.414 2.049
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  5.023  0.286 0.290 4.671
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 1.829  2.475 0.382 2.685
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.814  0.002 0.000 0.297
# lstsq_target_polynomials_VS_inet_polynomials       7.305 15.031 5.307 4.886
# lstsq_target_polynomials_VS_symbolic_regression... 6.245 14.898 5.407 1.525
# lstsq_target_polynomials_VS_per_network_polynom... 6.377 14.948 5.414 2.041
# inet_polynomials_VS_symbolic_regression_functions  4.629  2.401 0.510 4.221
# inet_polynomials_VS_per_network_polynomials        5.274  0.286 0.290 4.498
# symbolic_regression_functions_VS_per_network_po... 2.235  2.475 0.382 2.524
#
#                                                     L-60  L-61  L-62  L-63  \
# lambda_preds_VS_target_polynomials                 1.872 4.753 1.773 1.872
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.000 0.000 0.348 0.482
# lambda_preds_VS_lstsq_target_polynomials           1.870 4.753 1.773 1.871
# lambda_preds_VS_inet_polynomials                   1.396 0.830 4.474 1.484
# lambda_preds_VS_symbolic_regression_functions      0.169 0.682   inf 1.017
# lambda_preds_VS_per_network_polynomials            0.002 0.002 0.371 0.861
# target_polynomials_VS_lstsq_lambda_pred_polynom... 1.872 4.753 1.748 1.584
# target_polynomials_VS_lstsq_target_polynomials     0.005 0.005 0.005 0.003
# target_polynomials_VS_inet_polynomials             3.149 5.249 5.426 1.662
# target_polynomials_VS_symbolic_regression_funct... 1.918 4.695   inf 1.806
# target_polynomials_VS_per_network_polynomials      1.873 4.753 1.777 1.840
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 1.870 4.753 1.748 1.584
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  1.396 0.830 4.355 1.263
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.169 0.682   inf 1.030
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.002 0.002 0.210 0.865
# lstsq_target_polynomials_VS_inet_polynomials       3.147 5.249 5.427 1.662
# lstsq_target_polynomials_VS_symbolic_regression... 1.916 4.694   inf 1.805
# lstsq_target_polynomials_VS_per_network_polynom... 1.870 4.753 1.777 1.839
# inet_polynomials_VS_symbolic_regression_functions  1.308 1.313   inf 1.640
# inet_polynomials_VS_per_network_polynomials        1.396 0.830 4.247 1.493
# symbolic_regression_functions_VS_per_network_po... 0.169 0.682   inf 0.375
#
#                                                     L-64  L-65  L-66  L-67  \
# lambda_preds_VS_target_polynomials                 8.882 1.104 3.091 1.193
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.000 0.237 0.000 0.530
# lambda_preds_VS_lstsq_target_polynomials           8.878 1.103 3.091 1.191
# lambda_preds_VS_inet_polynomials                   2.235 2.015 1.016 2.493
# lambda_preds_VS_symbolic_regression_functions      1.228 0.903 0.175 0.819
# lambda_preds_VS_per_network_polynomials            0.007 0.257 0.002 0.638
# target_polynomials_VS_lstsq_lambda_pred_polynom... 8.882 1.104 3.091 1.177
# target_polynomials_VS_lstsq_target_polynomials     0.007 0.003 0.003 0.004
# target_polynomials_VS_inet_polynomials             7.770 1.658 2.577 2.763
# target_polynomials_VS_symbolic_regression_funct... 8.776 0.980 3.130 1.340
# target_polynomials_VS_per_network_polynomials      8.881 1.041 3.092 1.284
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 8.878 1.104 3.091 1.175
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  2.235 1.965 1.016 2.415
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 1.228 0.901 0.175 0.599
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.007 0.116 0.002 0.459
# lstsq_target_polynomials_VS_inet_polynomials       7.765 1.660 2.577 2.760
# lstsq_target_polynomials_VS_symbolic_regression... 8.771 0.981 3.130 1.339
# lstsq_target_polynomials_VS_per_network_polynom... 8.877 1.041 3.091 1.283
# inet_polynomials_VS_symbolic_regression_functions  1.367 1.206 1.049 2.658
# inet_polynomials_VS_per_network_polynomials        2.232 1.933 1.016 2.637
# symbolic_regression_functions_VS_per_network_po... 1.229 0.885 0.175 0.519
#
#                                                      L-68  L-69  L-70  L-71  \
# lambda_preds_VS_target_polynomials                  5.036 3.351 1.870 3.138
# lambda_preds_VS_lstsq_lambda_pred_polynomials       1.543 0.868 0.411 0.026
# lambda_preds_VS_lstsq_target_polynomials            5.035 3.351 1.870 3.140
# lambda_preds_VS_inet_polynomials                    7.413 6.030 2.299 0.815
# lambda_preds_VS_symbolic_regression_functions       4.049 2.215 2.584 1.337
# lambda_preds_VS_per_network_polynomials             1.782 2.896 0.723 0.034
# target_polynomials_VS_lstsq_lambda_pred_polynom...  4.214 3.297 1.757 3.135
# target_polynomials_VS_lstsq_target_polynomials      0.003 0.001 0.004 0.004
# target_polynomials_VS_inet_polynomials             10.477 6.978 2.520 3.904
# target_polynomials_VS_symbolic_regression_funct...  5.701 3.196 3.091 3.171
# target_polynomials_VS_per_network_polynomials       4.028 2.565 2.106 3.131
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  4.212 3.297 1.757 3.137
# lstsq_lambda_pred_polynomials_VS_inet_polynomials   7.002 5.831 2.101 0.821
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...  3.572 2.464 2.433 1.329
# lstsq_lambda_pred_polynomials_VS_per_network_po...  1.351 3.093 0.590 0.025
# lstsq_target_polynomials_VS_inet_polynomials       10.475 6.978 2.518 3.906
# lstsq_target_polynomials_VS_symbolic_regression...  5.700 3.195 3.090 3.174
# lstsq_target_polynomials_VS_per_network_polynom...  4.028 2.565 2.108 3.133
# inet_polynomials_VS_symbolic_regression_functions   5.870 5.268 1.163 1.821
# inet_polynomials_VS_per_network_polynomials         7.445 5.373 2.140 0.832
# symbolic_regression_functions_VS_per_network_po...  3.158 1.145 2.341 1.325
#
#                                                      L-72  L-73  L-74  L-75  \
# lambda_preds_VS_target_polynomials                  7.749 2.349 1.474 3.730
# lambda_preds_VS_lstsq_lambda_pred_polynomials       0.654 0.859 0.338 0.699
# lambda_preds_VS_lstsq_target_polynomials            7.751 2.350 1.473 3.729
# lambda_preds_VS_inet_polynomials                    5.322 2.349 1.743 3.795
# lambda_preds_VS_symbolic_regression_functions         inf 7.730 0.737 2.567
# lambda_preds_VS_per_network_polynomials             0.780 1.312 0.662 1.573
# target_polynomials_VS_lstsq_lambda_pred_polynom...  7.886 2.270 1.546 3.613
# target_polynomials_VS_lstsq_target_polynomials      0.004 0.003 0.004 0.003
# target_polynomials_VS_inet_polynomials             12.327 2.526 1.804 5.374
# target_polynomials_VS_symbolic_regression_funct...    inf 8.536 1.360 2.937
# target_polynomials_VS_per_network_polynomials       8.369 2.292 1.704 3.184
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  7.887 2.270 1.544 3.612
# lstsq_lambda_pred_polynomials_VS_inet_polynomials   5.449 2.390 1.794 3.805
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...    inf 7.981 0.656 2.736
# lstsq_lambda_pred_polynomials_VS_per_network_po...  0.820 1.320 0.570 1.342
# lstsq_target_polynomials_VS_inet_polynomials       12.325 2.529 1.803 5.375
# lstsq_target_polynomials_VS_symbolic_regression...    inf 8.538 1.360 2.938
# lstsq_target_polynomials_VS_per_network_polynom...  8.370 2.293 1.704 3.183
# inet_polynomials_VS_symbolic_regression_functions     inf 7.311 1.902 3.580
# inet_polynomials_VS_per_network_polynomials         4.854 1.929 1.849 3.709
# symbolic_regression_functions_VS_per_network_po...    inf 6.844 0.456 2.848
#
#                                                     L-76  L-77  L-78  L-79  \
# lambda_preds_VS_target_polynomials                 0.733 0.804 6.124 1.965
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.250 0.174 0.000 0.270
# lambda_preds_VS_lstsq_target_polynomials           0.734 0.804 6.124 1.964
# lambda_preds_VS_inet_polynomials                   2.595 2.012 1.269 1.755
# lambda_preds_VS_symbolic_regression_functions      0.945 1.151 0.411 0.784
# lambda_preds_VS_per_network_polynomials            0.218 0.409 0.002 0.434
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.765 0.752 6.124 2.035
# target_polynomials_VS_lstsq_target_polynomials     0.003 0.003 0.002 0.003
# target_polynomials_VS_inet_polynomials             2.682 2.182 6.197 1.786
# target_polynomials_VS_symbolic_regression_funct... 1.149 0.821 6.154 1.357
# target_polynomials_VS_per_network_polynomials      0.721 0.706 6.125 2.126
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.765 0.752 6.124 2.034
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  2.519 1.987 1.269 1.767
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.982 1.116 0.411 0.763
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.117 0.341 0.002 0.341
# lstsq_target_polynomials_VS_inet_polynomials       2.681 2.181 6.198 1.785
# lstsq_target_polynomials_VS_symbolic_regression... 1.151 0.822 6.154 1.355
# lstsq_target_polynomials_VS_per_network_polynom... 0.722 0.706 6.125 2.124
# inet_polynomials_VS_symbolic_regression_functions  2.716 2.529 1.169 1.351
# inet_polynomials_VS_per_network_polynomials        2.480 1.909 1.269 1.732
# symbolic_regression_functions_VS_per_network_po... 0.987 1.040 0.411 0.801
#
#                                                     L-80  L-81  L-82  L-83  \
# lambda_preds_VS_target_polynomials                 0.766 1.042 3.597 3.034
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.085 0.193 0.000 1.048
# lambda_preds_VS_lstsq_target_polynomials           0.766 1.045 3.598 3.035
# lambda_preds_VS_inet_polynomials                   1.001 1.566 0.763 2.523
# lambda_preds_VS_symbolic_regression_functions      0.359 0.777 0.227 2.310
# lambda_preds_VS_per_network_polynomials            0.144 0.241 0.000 1.550
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.758 1.087 3.597 2.766
# target_polynomials_VS_lstsq_target_polynomials     0.004 0.006 0.002 0.003
# target_polynomials_VS_inet_polynomials             1.502 1.940 3.018 3.518
# target_polynomials_VS_symbolic_regression_funct... 0.718 1.218 3.601 1.815
# target_polynomials_VS_per_network_polynomials      0.738 1.194 3.597 2.645
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.757 1.088 3.598 2.767
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  1.031 1.521 0.763 2.736
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.339 0.758 0.227 2.220
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.153 0.185 0.000 1.502
# lstsq_target_polynomials_VS_inet_polynomials       1.501 1.943 3.019 3.519
# lstsq_target_polynomials_VS_symbolic_regression... 0.716 1.217 3.602 1.816
# lstsq_target_polynomials_VS_per_network_polynom... 0.737 1.195 3.598 2.647
# inet_polynomials_VS_symbolic_regression_functions  0.979 1.328 0.785 2.312
# inet_polynomials_VS_per_network_polynomials        1.058 1.513 0.763 2.723
# symbolic_regression_functions_VS_per_network_po... 0.275 0.712 0.227 1.962
#
#                                                     L-84  L-85  L-86  L-87  \
# lambda_preds_VS_target_polynomials                 5.917 8.869 1.679 2.751
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.000 0.000 0.379 0.000
# lambda_preds_VS_lstsq_target_polynomials           5.917 8.868 1.680 2.751
# lambda_preds_VS_inet_polynomials                   1.195 4.303 1.738 0.781
# lambda_preds_VS_symbolic_regression_functions      0.147 3.833 0.776 0.271
# lambda_preds_VS_per_network_polynomials            0.001 0.004 0.363 0.000
# target_polynomials_VS_lstsq_lambda_pred_polynom... 5.917 8.869 1.737 2.751
# target_polynomials_VS_lstsq_target_polynomials     0.003 0.003 0.003 0.002
# target_polynomials_VS_inet_polynomials             6.716 7.534 3.149 3.161
# target_polynomials_VS_symbolic_regression_funct... 5.911 9.508 2.189 2.682
# target_polynomials_VS_per_network_polynomials      5.917 8.869 1.860 2.751
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 5.917 8.868 1.738 2.751
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  1.195 4.303 1.610 0.781
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.147 3.833 0.791 0.271
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.001 0.004 0.218 0.000
# lstsq_target_polynomials_VS_inet_polynomials       6.717 7.533 3.149 3.162
# lstsq_target_polynomials_VS_symbolic_regression... 5.912 9.507 2.190 2.683
# lstsq_target_polynomials_VS_per_network_polynom... 5.917 8.867 1.861 2.751
# inet_polynomials_VS_symbolic_regression_functions  1.139 2.398 1.363 1.052
# inet_polynomials_VS_per_network_polynomials        1.196 4.302 1.516 0.781
# symbolic_regression_functions_VS_per_network_po... 0.147 3.833 0.595 0.271
#
#                                                     L-88  L-89  L-90  L-91  \
# lambda_preds_VS_target_polynomials                 6.334 1.218 8.838 2.027
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.000 0.643 0.000 0.684
# lambda_preds_VS_lstsq_target_polynomials           6.333 1.218 8.839 2.027
# lambda_preds_VS_inet_polynomials                   2.852 4.862 1.731 2.223
# lambda_preds_VS_symbolic_regression_functions      1.404 0.863 1.245 1.189
# lambda_preds_VS_per_network_polynomials            0.002 0.873 0.001 1.244
# target_polynomials_VS_lstsq_lambda_pred_polynom... 6.334 0.974 8.838 1.982
# target_polynomials_VS_lstsq_target_polynomials     0.003 0.003 0.005 0.004
# target_polynomials_VS_inet_polynomials             4.994 4.631 9.684 3.371
# target_polynomials_VS_symbolic_regression_funct... 6.469 0.904 9.316 1.060
# target_polynomials_VS_per_network_polynomials      6.334 1.079 8.838 1.972
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 6.333 0.974 8.839 1.982
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  2.852 4.844 1.731 2.162
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 1.404 0.742 1.245 1.018
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.002 0.716 0.001 1.476
# lstsq_target_polynomials_VS_inet_polynomials       4.993 4.634 9.686 3.369
# lstsq_target_polynomials_VS_symbolic_regression... 6.468 0.903 9.318 1.059
# lstsq_target_polynomials_VS_per_network_polynom... 6.333 1.078 8.840 1.968
# inet_polynomials_VS_symbolic_regression_functions  1.731 4.639 0.510 2.570
# inet_polynomials_VS_per_network_polynomials        2.852 4.752 1.731 2.212
# symbolic_regression_functions_VS_per_network_po... 1.404 0.224 1.245 1.202
#
#                                                      L-92  L-93  L-94   L-95  \
# lambda_preds_VS_target_polynomials                 14.128 3.098 6.253 12.663
# lambda_preds_VS_lstsq_lambda_pred_polynomials       0.000 0.996 0.000  0.000
# lambda_preds_VS_lstsq_target_polynomials           14.127 3.097 6.253 12.662
# lambda_preds_VS_inet_polynomials                    1.448 3.608 0.576  0.812
# lambda_preds_VS_symbolic_regression_functions       0.663   inf 0.105  0.027
# lambda_preds_VS_per_network_polynomials             0.001 2.774 0.000  0.001
# target_polynomials_VS_lstsq_lambda_pred_polynom... 14.128 2.809 6.253 12.663
# target_polynomials_VS_lstsq_target_polynomials      0.005 0.004 0.003  0.003
# target_polynomials_VS_inet_polynomials             13.358 2.857 6.709 12.593
# target_polynomials_VS_symbolic_regression_funct... 14.148   inf 6.260 12.666
# target_polynomials_VS_per_network_polynomials      14.128 3.070 6.253 12.663
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 14.127 2.810 6.253 12.662
# lstsq_lambda_pred_polynomials_VS_inet_polynomials   1.448 3.098 0.576  0.812
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...  0.663   inf 0.105  0.027
# lstsq_lambda_pred_polynomials_VS_per_network_po...  0.001 2.731 0.000  0.000
# lstsq_target_polynomials_VS_inet_polynomials       13.356 2.853 6.709 12.592
# lstsq_target_polynomials_VS_symbolic_regression... 14.147   inf 6.261 12.665
# lstsq_target_polynomials_VS_per_network_polynom... 14.127 3.069 6.253 12.662
# inet_polynomials_VS_symbolic_regression_functions   1.574   inf 0.611  0.822
# inet_polynomials_VS_per_network_polynomials         1.447 3.086 0.576  0.812
# symbolic_regression_functions_VS_per_network_po...  0.663   inf 0.105  0.027
#
#                                                     L-96  L-97   L-98  L-99
# lambda_preds_VS_target_polynomials                 8.463 0.693 16.976 1.481
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.119 0.000  0.000 0.051
# lambda_preds_VS_lstsq_target_polynomials           8.465 0.692 16.977 1.483
# lambda_preds_VS_inet_polynomials                   0.994 0.659  0.695 1.000
# lambda_preds_VS_symbolic_regression_functions      3.219 0.047  0.927 0.517
# lambda_preds_VS_per_network_polynomials            0.146 0.000  0.000 0.083
# target_polynomials_VS_lstsq_lambda_pred_polynom... 8.432 0.693 16.976 1.498
# target_polynomials_VS_lstsq_target_polynomials     0.003 0.002  0.005 0.002
# target_polynomials_VS_inet_polynomials             8.160 1.074 17.145 2.012
# target_polynomials_VS_symbolic_regression_funct... 9.821 0.683 17.009 1.363
# target_polynomials_VS_per_network_polynomials      8.474 0.693 16.976 1.546
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 8.433 0.692 16.977 1.500
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.983 0.659  0.695 1.010
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 3.238 0.047  0.927 0.505
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.121 0.000  0.000 0.083
# lstsq_target_polynomials_VS_inet_polynomials       8.162 1.075 17.146 2.014
# lstsq_target_polynomials_VS_symbolic_regression... 9.823 0.681 17.010 1.365
# lstsq_target_polynomials_VS_per_network_polynom... 8.476 0.692 16.977 1.547
# inet_polynomials_VS_symbolic_regression_functions  2.489 0.666  1.621 1.382
# inet_polynomials_VS_per_network_polynomials        0.966 0.659  0.695 1.047
# symbolic_regression_functions_VS_per_network_po... 3.210 0.047  0.927 0.464

# %%
distrib_dict_test_list[-1]['R2']
# Out:
#                                                      L-0   L-1   L-2     L-3  \
# lambda_preds_VS_target_polynomials                 0.506 0.955 0.972   0.994
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000 0.997 0.999   1.000
# lambda_preds_VS_lstsq_target_polynomials           0.506 0.955 0.972   0.994
# lambda_preds_VS_inet_polynomials                   0.998 0.974 0.973   0.991
# lambda_preds_VS_symbolic_regression_functions      0.999 0.978 0.994 -67.424
# lambda_preds_VS_per_network_polynomials            1.000 0.991 0.999   0.998
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.757 0.968 0.973   0.995
# target_polynomials_VS_lstsq_target_polynomials     1.000 1.000 1.000   1.000
# target_polynomials_VS_inet_polynomials             0.741 0.963 0.960   0.996
# target_polynomials_VS_symbolic_regression_funct... 0.749 0.961 0.978 -62.486
# target_polynomials_VS_per_network_polynomials      0.757 0.972 0.973   0.996
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.506 0.959 0.972   0.995
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.998 0.976 0.973   0.991
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.999 0.980 0.994 -67.361
# lstsq_lambda_pred_polynomials_VS_per_network_po... 1.000 0.993 1.000   0.998
# lstsq_target_polynomials_VS_inet_polynomials       0.741 0.963 0.960   0.996
# lstsq_target_polynomials_VS_symbolic_regression... 0.749 0.962 0.977 -62.475
# lstsq_target_polynomials_VS_per_network_polynom... 0.757 0.972 0.973   0.996
# inet_polynomials_VS_symbolic_regression_functions  0.998 0.980 0.987 -59.109
# inet_polynomials_VS_per_network_polynomials        0.998 0.984 0.972   0.992
# symbolic_regression_functions_VS_per_network_po... 0.999 0.988 0.994   0.022
#
#                                                      L-4   L-5    L-6   L-7  \
# lambda_preds_VS_target_polynomials                 0.890 0.992  0.735 0.998
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.993 0.999  0.986 1.000
# lambda_preds_VS_lstsq_target_polynomials           0.890 0.992  0.735 0.998
# lambda_preds_VS_inet_polynomials                   0.940 0.991 -0.910 0.995
# lambda_preds_VS_symbolic_regression_functions      0.952 0.998  0.932 0.999
# lambda_preds_VS_per_network_polynomials            0.985 0.998  0.962 1.000
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.933 0.994  0.796 0.999
# target_polynomials_VS_lstsq_target_polynomials     1.000 1.000  1.000 1.000
# target_polynomials_VS_inet_polynomials             0.878 0.992 -0.841 0.998
# target_polynomials_VS_symbolic_regression_funct... 0.882 0.998  0.715 0.999
# target_polynomials_VS_per_network_polynomials      0.932 0.997  0.772 0.998
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.897 0.994  0.737 0.998
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.947 0.992 -0.925 0.995
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.959 0.998  0.964 0.999
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.991 0.998  0.978 1.000
# lstsq_target_polynomials_VS_inet_polynomials       0.878 0.992 -0.839 0.998
# lstsq_target_polynomials_VS_symbolic_regression... 0.882 0.998  0.715 0.999
# lstsq_target_polynomials_VS_per_network_polynom... 0.932 0.997  0.772 0.998
# inet_polynomials_VS_symbolic_regression_functions  0.994 0.994  0.457 0.998
# inet_polynomials_VS_per_network_polynomials        0.930 0.992  0.545 0.995
# symbolic_regression_functions_VS_per_network_po... 0.954 0.999  0.930 0.999
#
#                                                      L-8   L-9  L-10  L-11  \
# lambda_preds_VS_target_polynomials                 0.995 0.785 0.834 0.949
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000 1.000 1.000 1.000
# lambda_preds_VS_lstsq_target_polynomials           0.995 0.785 0.834 0.949
# lambda_preds_VS_inet_polynomials                   0.989 0.995 0.990 0.994
# lambda_preds_VS_symbolic_regression_functions      0.998 0.999 1.000 0.998
# lambda_preds_VS_per_network_polynomials            1.000 1.000 1.000 1.000
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.995 0.865 0.890 0.946
# target_polynomials_VS_lstsq_target_polynomials     1.000 1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials             0.987 0.836 0.838 0.942
# target_polynomials_VS_symbolic_regression_funct... 0.995 0.858 0.890 0.938
# target_polynomials_VS_per_network_polynomials      0.995 0.865 0.890 0.946
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.995 0.785 0.834 0.950
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.990 0.995 0.990 0.994
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.998 0.999 1.000 0.998
# lstsq_lambda_pred_polynomials_VS_per_network_po... 1.000 1.000 1.000 1.000
# lstsq_target_polynomials_VS_inet_polynomials       0.987 0.836 0.838 0.942
# lstsq_target_polynomials_VS_symbolic_regression... 0.995 0.858 0.890 0.938
# lstsq_target_polynomials_VS_per_network_polynom... 0.995 0.865 0.891 0.946
# inet_polynomials_VS_symbolic_regression_functions  0.995 0.997 0.990 0.988
# inet_polynomials_VS_per_network_polynomials        0.990 0.994 0.990 0.992
# symbolic_regression_functions_VS_per_network_po... 0.999 0.999 1.000 0.999
#
#                                                     L-12  L-13  L-14  L-15  \
# lambda_preds_VS_target_polynomials                 0.977 0.916 0.990 0.991
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.999 0.991 0.999 1.000
# lambda_preds_VS_lstsq_target_polynomials           0.977 0.916 0.990 0.991
# lambda_preds_VS_inet_polynomials                   0.985 0.829 0.943 0.993
# lambda_preds_VS_symbolic_regression_functions      0.993 0.978 0.995 0.999
# lambda_preds_VS_per_network_polynomials            0.999 0.985 0.998 0.998
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.981 0.940 0.993 0.992
# target_polynomials_VS_lstsq_target_polynomials     1.000 1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials             0.968 0.840 0.937 0.993
# target_polynomials_VS_symbolic_regression_funct... 0.977 0.909 0.985 0.992
# target_polynomials_VS_per_network_polynomials      0.979 0.948 0.992 0.994
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.978 0.927 0.992 0.991
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.986 0.839 0.944 0.994
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.994 0.987 0.997 0.999
# lstsq_lambda_pred_polynomials_VS_per_network_po... 1.000 0.994 0.999 0.999
# lstsq_target_polynomials_VS_inet_polynomials       0.968 0.840 0.937 0.993
# lstsq_target_polynomials_VS_symbolic_regression... 0.977 0.909 0.985 0.992
# lstsq_target_polynomials_VS_per_network_polynom... 0.979 0.948 0.992 0.994
# inet_polynomials_VS_symbolic_regression_functions  0.986 0.907 0.944 0.991
# inet_polynomials_VS_per_network_polynomials        0.987 0.900 0.950 0.995
# symbolic_regression_functions_VS_per_network_po... 0.996 0.990 0.998 0.999
#
#                                                     L-16  L-17   L-18  L-19  \
# lambda_preds_VS_target_polynomials                 0.984 0.668 -1.136 0.984
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000 1.000  1.000 0.999
# lambda_preds_VS_lstsq_target_polynomials           0.984 0.668 -1.136 0.984
# lambda_preds_VS_inet_polynomials                   0.986 0.993  0.997 0.984
# lambda_preds_VS_symbolic_regression_functions      0.999 1.000  0.994 0.899
# lambda_preds_VS_per_network_polynomials            0.999 1.000  1.000 0.992
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.985 0.769  0.512 0.987
# target_polynomials_VS_lstsq_target_polynomials     1.000 1.000  1.000 1.000
# target_polynomials_VS_inet_polynomials             0.966 0.806  0.481 0.969
# target_polynomials_VS_symbolic_regression_funct... 0.988 0.772  0.483 0.918
# target_polynomials_VS_per_network_polynomials      0.987 0.768  0.512 0.991
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.985 0.668 -1.136 0.985
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.985 0.993  0.997 0.985
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.999 1.000  0.994 0.903
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.999 1.000  1.000 0.992
# lstsq_target_polynomials_VS_inet_polynomials       0.966 0.806  0.481 0.969
# lstsq_target_polynomials_VS_symbolic_regression... 0.988 0.772  0.483 0.918
# lstsq_target_polynomials_VS_per_network_polynom... 0.987 0.768  0.512 0.991
# inet_polynomials_VS_symbolic_regression_functions  0.981 0.993  0.997 0.860
# inet_polynomials_VS_per_network_polynomials        0.978 0.993  0.997 0.983
# symbolic_regression_functions_VS_per_network_po... 1.000 1.000  0.994 0.910
#
#                                                     L-20  L-21   L-22  L-23  \
# lambda_preds_VS_target_polynomials                 0.986 0.980 -1.856 0.887
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000 0.999  1.000 0.995
# lambda_preds_VS_lstsq_target_polynomials           0.986 0.980 -1.856 0.887
# lambda_preds_VS_inet_polynomials                   0.993 0.992  0.993 0.923
# lambda_preds_VS_symbolic_regression_functions      0.995 0.994  1.000  -inf
# lambda_preds_VS_per_network_polynomials            0.996 0.998  1.000 0.978
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.988 0.983  0.404 0.919
# target_polynomials_VS_lstsq_target_polynomials     1.000 1.000  1.000 1.000
# target_polynomials_VS_inet_polynomials             0.993 0.976  0.357 0.855
# target_polynomials_VS_symbolic_regression_funct... 0.997 0.982  0.404  -inf
# target_polynomials_VS_per_network_polynomials      0.992 0.983  0.404 0.932
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.986 0.980 -1.856 0.893
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.993 0.993  0.993 0.925
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.995 0.995  1.000  -inf
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.996 1.000  1.000 0.983
# lstsq_target_polynomials_VS_inet_polynomials       0.993 0.976  0.357 0.855
# lstsq_target_polynomials_VS_symbolic_regression... 0.997 0.982  0.404  -inf
# lstsq_target_polynomials_VS_per_network_polynom... 0.992 0.983  0.404 0.932
# inet_polynomials_VS_symbolic_regression_functions  0.998 0.997  0.992  -inf
# inet_polynomials_VS_per_network_polynomials        0.997 0.994  0.993 0.933
# symbolic_regression_functions_VS_per_network_po... 0.999 0.997  1.000   NaN
#
#                                                     L-24  L-25  L-26  L-27  \
# lambda_preds_VS_target_polynomials                 0.953 0.636 0.906 0.992
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.999 1.000 0.997 1.000
# lambda_preds_VS_lstsq_target_polynomials           0.953 0.636 0.906 0.992
# lambda_preds_VS_inet_polynomials                   0.988 0.998 0.964 0.905
# lambda_preds_VS_symbolic_regression_functions      0.990 0.995 0.977 0.998
# lambda_preds_VS_per_network_polynomials            0.997 1.000 0.989 1.000
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.963 0.809 0.940 0.993
# target_polynomials_VS_lstsq_target_polynomials     1.000 1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials             0.967 0.792 0.985 0.877
# target_polynomials_VS_symbolic_regression_funct... 0.953 0.824 0.959 0.993
# target_polynomials_VS_per_network_polynomials      0.964 0.809 0.945 0.993
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.951 0.636 0.910 0.992
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.988 0.998 0.969 0.905
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.991 0.995 0.981 0.998
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.998 1.000 0.993 1.000
# lstsq_target_polynomials_VS_inet_polynomials       0.967 0.792 0.985 0.877
# lstsq_target_polynomials_VS_symbolic_regression... 0.953 0.824 0.959 0.993
# lstsq_target_polynomials_VS_per_network_polynom... 0.964 0.809 0.945 0.993
# inet_polynomials_VS_symbolic_regression_functions  0.993 0.990 0.989 0.846
# inet_polynomials_VS_per_network_polynomials        0.993 0.998 0.980 0.836
# symbolic_regression_functions_VS_per_network_po... 0.992 0.995 0.989 0.998
#
#                                                     L-28   L-29  L-30  L-31  \
# lambda_preds_VS_target_polynomials                 0.858 -5.198 0.926 0.995
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000  1.000 1.000 1.000
# lambda_preds_VS_lstsq_target_polynomials           0.858 -5.200 0.926 0.995
# lambda_preds_VS_inet_polynomials                   0.986  0.995 0.998 0.995
# lambda_preds_VS_symbolic_regression_functions      0.999  1.000 0.995 0.993
# lambda_preds_VS_per_network_polynomials            1.000  1.000 1.000 1.000
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.845  0.273 0.940 0.995
# target_polynomials_VS_lstsq_target_polynomials     1.000  1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials             0.780  0.239 0.923 0.996
# target_polynomials_VS_symbolic_regression_funct... 0.852  0.277 0.925 0.993
# target_polynomials_VS_per_network_polynomials      0.845  0.273 0.940 0.996
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.858 -5.200 0.926 0.995
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.986  0.995 0.998 0.995
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.999  1.000 0.995 0.992
# lstsq_lambda_pred_polynomials_VS_per_network_po... 1.000  1.000 1.000 1.000
# lstsq_target_polynomials_VS_inet_polynomials       0.780  0.239 0.923 0.996
# lstsq_target_polynomials_VS_symbolic_regression... 0.852  0.277 0.925 0.993
# lstsq_target_polynomials_VS_per_network_polynom... 0.845  0.273 0.940 0.996
# inet_polynomials_VS_symbolic_regression_functions  0.980  0.995 0.995 0.990
# inet_polynomials_VS_per_network_polynomials        0.987  0.995 0.998 0.995
# symbolic_regression_functions_VS_per_network_po... 0.999  1.000 0.995 0.994
#
#                                                      L-32  L-33  L-34  L-35  \
# lambda_preds_VS_target_polynomials                 -1.231 0.984 0.020 0.478
# lambda_preds_VS_lstsq_lambda_pred_polynomials       1.000 0.999 1.000 1.000
# lambda_preds_VS_lstsq_target_polynomials           -1.231 0.984 0.021 0.477
# lambda_preds_VS_inet_polynomials                    0.959 0.994 0.993 0.995
# lambda_preds_VS_symbolic_regression_functions       0.772 0.995 0.999 0.999
# lambda_preds_VS_per_network_polynomials             1.000 0.999 1.000 1.000
# target_polynomials_VS_lstsq_lambda_pred_polynom... -0.211 0.986 0.239 0.535
# target_polynomials_VS_lstsq_target_polynomials      1.000 1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials             -0.357 0.985 0.269 0.609
# target_polynomials_VS_symbolic_regression_funct... -0.457 0.979 0.227 0.529
# target_polynomials_VS_per_network_polynomials      -0.211 0.986 0.235 0.535
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... -1.231 0.984 0.021 0.477
# lstsq_lambda_pred_polynomials_VS_inet_polynomials   0.959 0.994 0.993 0.995
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...  0.772 0.996 0.999 0.999
# lstsq_lambda_pred_polynomials_VS_per_network_po...  1.000 1.000 1.000 1.000
# lstsq_target_polynomials_VS_inet_polynomials       -0.357 0.985 0.270 0.609
# lstsq_target_polynomials_VS_symbolic_regression... -0.457 0.979 0.228 0.529
# lstsq_target_polynomials_VS_per_network_polynom... -0.211 0.986 0.235 0.535
# inet_polynomials_VS_symbolic_regression_functions   0.912 0.997 0.994 0.995
# inet_polynomials_VS_per_network_polynomials         0.959 0.995 0.993 0.995
# symbolic_regression_functions_VS_per_network_po...  0.770 0.997 0.999 0.999
#
#                                                     L-36    L-37  L-38  L-39  \
# lambda_preds_VS_target_polynomials                 0.993 -13.973 0.992 0.992
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000   1.000 1.000 1.000
# lambda_preds_VS_lstsq_target_polynomials           0.993 -13.970 0.992 0.992
# lambda_preds_VS_inet_polynomials                   0.990   0.823 0.993 0.996
# lambda_preds_VS_symbolic_regression_functions      0.998   0.568 0.995 0.996
# lambda_preds_VS_per_network_polynomials            0.998   1.000 0.998 0.998
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.994  -0.147 0.992 0.993
# target_polynomials_VS_lstsq_target_polynomials     1.000   1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials             0.984  -0.150 0.996 0.991
# target_polynomials_VS_symbolic_regression_funct... 0.997  -0.149 0.997 0.995
# target_polynomials_VS_per_network_polynomials      0.996  -0.147 0.993 0.994
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.994 -13.970 0.992 0.992
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.991   0.823 0.993 0.996
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.998   0.568 0.995 0.996
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.999   1.000 0.998 0.998
# lstsq_target_polynomials_VS_inet_polynomials       0.984  -0.150 0.996 0.991
# lstsq_target_polynomials_VS_symbolic_regression... 0.997  -0.149 0.997 0.995
# lstsq_target_polynomials_VS_per_network_polynom... 0.996  -0.147 0.993 0.994
# inet_polynomials_VS_symbolic_regression_functions  0.992   0.890 0.994 0.997
# inet_polynomials_VS_per_network_polynomials        0.992   0.787 0.994 0.998
# symbolic_regression_functions_VS_per_network_po... 0.999   0.585 0.997 0.998
#
#                                                     L-40  L-41   L-42   L-43  \
# lambda_preds_VS_target_polynomials                 0.781 0.945  0.878  0.029
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000 0.997  0.981  1.000
# lambda_preds_VS_lstsq_target_polynomials           0.781 0.945  0.878  0.030
# lambda_preds_VS_inet_polynomials                   0.999 0.982 -4.536  0.633
# lambda_preds_VS_symbolic_regression_functions      0.997 0.990  0.839  0.000
# lambda_preds_VS_per_network_polynomials            1.000 0.997  0.961  1.000
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.867 0.958  0.940 -0.895
# target_polynomials_VS_lstsq_target_polynomials     1.000 1.000  1.000  1.000
# target_polynomials_VS_inet_polynomials             0.854 0.961 -2.310 -1.224
# target_polynomials_VS_symbolic_regression_funct... 0.852 0.972  0.768 -4.462
# target_polynomials_VS_per_network_polynomials      0.867 0.955  0.904 -0.908
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.781 0.948  0.913  0.030
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.999 0.984 -4.232  0.634
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.997 0.994  0.867  0.005
# lstsq_lambda_pred_polynomials_VS_per_network_po... 1.000 1.000  0.980  1.000
# lstsq_target_polynomials_VS_inet_polynomials       0.854 0.961 -2.311 -1.223
# lstsq_target_polynomials_VS_symbolic_regression... 0.852 0.972  0.768 -4.466
# lstsq_target_polynomials_VS_per_network_polynom... 0.867 0.955  0.904 -0.909
# inet_polynomials_VS_symbolic_regression_functions  0.996 0.987  0.427 -0.589
# inet_polynomials_VS_per_network_polynomials        0.999 0.986  0.387  0.761
# symbolic_regression_functions_VS_per_network_po... 0.997 0.993  0.895  0.013
#
#                                                     L-44  L-45  L-46    L-47  \
# lambda_preds_VS_target_polynomials                 0.028 0.992 0.964 -13.895
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000 1.000 0.998   1.000
# lambda_preds_VS_lstsq_target_polynomials           0.028 0.992 0.964 -13.893
# lambda_preds_VS_inet_polynomials                   0.978 0.996 0.781   0.335
# lambda_preds_VS_symbolic_regression_functions      0.999 0.998 0.993    -inf
# lambda_preds_VS_per_network_polynomials            1.000 0.999 0.995   1.000
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.138 0.993 0.976  -0.068
# target_polynomials_VS_lstsq_target_polynomials     1.000 1.000 1.000   1.000
# target_polynomials_VS_inet_polynomials             0.085 0.999 0.754  -0.284
# target_polynomials_VS_symbolic_regression_funct... 0.135 0.997 0.975    -inf
# target_polynomials_VS_per_network_polynomials      0.138 0.994 0.979  -0.068
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.028 0.992 0.969 -13.893
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.978 0.996 0.781   0.335
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.999 0.998 0.995    -inf
# lstsq_lambda_pred_polynomials_VS_per_network_po... 1.000 0.999 0.997   1.000
# lstsq_target_polynomials_VS_inet_polynomials       0.084 0.999 0.754  -0.284
# lstsq_target_polynomials_VS_symbolic_regression... 0.134 0.997 0.975    -inf
# lstsq_target_polynomials_VS_per_network_polynom... 0.137 0.994 0.979  -0.068
# inet_polynomials_VS_symbolic_regression_functions  0.971 1.000 0.702    -inf
# inet_polynomials_VS_per_network_polynomials        0.979 0.997 0.703   0.698
# symbolic_regression_functions_VS_per_network_po... 0.999 0.998 0.997     NaN
#
#                                                     L-48   L-49  L-50  L-51  \
# lambda_preds_VS_target_polynomials                 0.613  0.998 0.954 0.983
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000  1.000 1.000 1.000
# lambda_preds_VS_lstsq_target_polynomials           0.614  0.998 0.955 0.983
# lambda_preds_VS_inet_polynomials                   0.970  0.986 0.979 0.991
# lambda_preds_VS_symbolic_regression_functions      0.978 -0.881 0.994 0.978
# lambda_preds_VS_per_network_polynomials            1.000  1.000 1.000 0.998
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.663  0.998 0.959 0.983
# target_polynomials_VS_lstsq_target_polynomials     1.000  1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials             0.719  0.982 0.973 0.967
# target_polynomials_VS_symbolic_regression_funct... 0.581 -0.854 0.965 0.956
# target_polynomials_VS_per_network_polynomials      0.663  0.998 0.958 0.983
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.614  0.998 0.954 0.983
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.970  0.986 0.979 0.991
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.978 -0.878 0.994 0.978
# lstsq_lambda_pred_polynomials_VS_per_network_po... 1.000  1.000 1.000 0.999
# lstsq_target_polynomials_VS_inet_polynomials       0.719  0.982 0.974 0.967
# lstsq_target_polynomials_VS_symbolic_regression... 0.582 -0.853 0.964 0.956
# lstsq_target_polynomials_VS_per_network_polynom... 0.664  0.998 0.958 0.982
# inet_polynomials_VS_symbolic_regression_functions  0.962 -0.766 0.975 0.951
# inet_polynomials_VS_per_network_polynomials        0.976  0.986 0.980 0.987
# symbolic_regression_functions_VS_per_network_po... 0.978  0.000 0.995 0.979
#
#                                                       L-52  L-53  L-54  L-55  \
# lambda_preds_VS_target_polynomials                 -31.510 0.828 0.818 0.576
# lambda_preds_VS_lstsq_lambda_pred_polynomials        1.000 1.000 1.000 1.000
# lambda_preds_VS_lstsq_target_polynomials           -31.511 0.828 0.818 0.576
# lambda_preds_VS_inet_polynomials                     0.869 0.994 0.992 0.996
# lambda_preds_VS_symbolic_regression_functions        0.990 0.992 0.998 0.999
# lambda_preds_VS_per_network_polynomials              1.000 1.000 1.000 1.000
# target_polynomials_VS_lstsq_lambda_pred_polynom...   0.047 0.799 0.887 0.770
# target_polynomials_VS_lstsq_target_polynomials       1.000 1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials               0.023 0.806 0.841 0.740
# target_polynomials_VS_symbolic_regression_funct...   0.033 0.807 0.897 0.760
# target_polynomials_VS_per_network_polynomials        0.047 0.799 0.887 0.770
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... -31.510 0.828 0.818 0.576
# lstsq_lambda_pred_polynomials_VS_inet_polynomials    0.869 0.994 0.992 0.996
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...   0.990 0.992 0.998 0.999
# lstsq_lambda_pred_polynomials_VS_per_network_po...   1.000 1.000 1.000 1.000
# lstsq_target_polynomials_VS_inet_polynomials         0.023 0.805 0.841 0.740
# lstsq_target_polynomials_VS_symbolic_regression...   0.033 0.807 0.897 0.760
# lstsq_target_polynomials_VS_per_network_polynom...   0.047 0.799 0.887 0.770
# inet_polynomials_VS_symbolic_regression_functions    0.721 0.973 0.988 0.997
# inet_polynomials_VS_per_network_polynomials          0.775 0.994 0.992 0.996
# symbolic_regression_functions_VS_per_network_po...   0.992 0.993 0.998 0.999
#
#                                                     L-56   L-57   L-58  L-59  \
# lambda_preds_VS_target_polynomials                 0.979 -0.235 -0.458 0.997
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000  1.000  1.000 1.000
# lambda_preds_VS_lstsq_target_polynomials           0.979 -0.235 -0.457 0.997
# lambda_preds_VS_inet_polynomials                   0.990  1.000  0.997 0.993
# lambda_preds_VS_symbolic_regression_functions      0.998  0.983  0.996 0.997
# lambda_preds_VS_per_network_polynomials            0.999  1.000  1.000 1.000
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.983  0.587  0.440 0.998
# target_polynomials_VS_lstsq_target_polynomials     1.000  1.000  1.000 1.000
# target_polynomials_VS_inet_polynomials             0.984  0.578  0.452 0.993
# target_polynomials_VS_symbolic_regression_funct... 0.986  0.553  0.457 0.999
# target_polynomials_VS_per_network_polynomials      0.983  0.587  0.440 0.998
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.979 -0.235 -0.457 0.997
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.991  1.000  0.997 0.993
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.998  0.983  0.996 0.997
# lstsq_lambda_pred_polynomials_VS_per_network_po... 1.000  1.000  1.000 1.000
# lstsq_target_polynomials_VS_inet_polynomials       0.984  0.578  0.452 0.993
# lstsq_target_polynomials_VS_symbolic_regression... 0.986  0.553  0.457 0.999
# lstsq_target_polynomials_VS_per_network_polynom... 0.983  0.587  0.440 0.998
# inet_polynomials_VS_symbolic_regression_functions  0.992  0.983  0.989 0.993
# inet_polynomials_VS_per_network_polynomials        0.990  1.000  0.996 0.993
# symbolic_regression_functions_VS_per_network_po... 0.998  0.982  0.996 0.997
#
#                                                     L-60  L-61  L-62  L-63  \
# lambda_preds_VS_target_polynomials                 0.976 0.905 0.983 0.986
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000 1.000 1.000 1.000
# lambda_preds_VS_lstsq_target_polynomials           0.976 0.905 0.983 0.986
# lambda_preds_VS_inet_polynomials                   0.992 0.999 0.949 0.996
# lambda_preds_VS_symbolic_regression_functions      1.000 0.999  -inf 0.998
# lambda_preds_VS_per_network_polynomials            1.000 1.000 0.999 0.998
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.980 0.932 0.985 0.988
# target_polynomials_VS_lstsq_target_polynomials     1.000 1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials             0.953 0.923 0.942 0.995
# target_polynomials_VS_symbolic_regression_funct... 0.979 0.927  -inf 0.990
# target_polynomials_VS_per_network_polynomials      0.980 0.932 0.985 0.988
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.976 0.905 0.983 0.986
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.992 0.999 0.950 0.996
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 1.000 0.999  -inf 0.998
# lstsq_lambda_pred_polynomials_VS_per_network_po... 1.000 1.000 1.000 0.999
# lstsq_target_polynomials_VS_inet_polynomials       0.953 0.923 0.942 0.995
# lstsq_target_polynomials_VS_symbolic_regression... 0.979 0.927  -inf 0.990
# lstsq_target_polynomials_VS_per_network_polynom... 0.980 0.932 0.985 0.988
# inet_polynomials_VS_symbolic_regression_functions  0.993 0.997  -inf 0.996
# inet_polynomials_VS_per_network_polynomials        0.992 0.999 0.941 0.996
# symbolic_regression_functions_VS_per_network_po... 1.000 0.999   NaN 1.000
#
#                                                     L-64  L-65  L-66  L-67  \
# lambda_preds_VS_target_polynomials                 0.896 0.997 0.312 0.994
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000 1.000 1.000 0.999
# lambda_preds_VS_lstsq_target_polynomials           0.896 0.997 0.312 0.994
# lambda_preds_VS_inet_polynomials                   0.996 0.993 0.961 0.985
# lambda_preds_VS_symbolic_regression_functions      0.999 0.998 0.999 0.999
# lambda_preds_VS_per_network_polynomials            1.000 1.000 1.000 0.999
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.926 0.997 0.453 0.995
# target_polynomials_VS_lstsq_target_polynomials     1.000 1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials             0.922 0.996 0.466 0.987
# target_polynomials_VS_symbolic_regression_funct... 0.920 0.998 0.440 0.996
# target_polynomials_VS_per_network_polynomials      0.926 0.997 0.453 0.995
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.896 0.997 0.312 0.995
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.996 0.993 0.961 0.986
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.999 0.998 0.999 0.999
# lstsq_lambda_pred_polynomials_VS_per_network_po... 1.000 1.000 1.000 1.000
# lstsq_target_polynomials_VS_inet_polynomials       0.922 0.996 0.466 0.987
# lstsq_target_polynomials_VS_symbolic_regression... 0.920 0.998 0.440 0.996
# lstsq_target_polynomials_VS_per_network_polynom... 0.926 0.997 0.453 0.995
# inet_polynomials_VS_symbolic_regression_functions  0.998 0.997 0.970 0.987
# inet_polynomials_VS_per_network_polynomials        0.996 0.993 0.972 0.987
# symbolic_regression_functions_VS_per_network_po... 0.999 0.998 0.999 0.999
#
#                                                     L-68  L-69  L-70  L-71  \
# lambda_preds_VS_target_polynomials                 0.965 0.996 0.991 0.971
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.997 1.000 1.000 1.000
# lambda_preds_VS_lstsq_target_polynomials           0.965 0.996 0.991 0.971
# lambda_preds_VS_inet_polynomials                   0.922 0.990 0.994 0.997
# lambda_preds_VS_symbolic_regression_functions      0.986 0.997 0.972 0.995
# lambda_preds_VS_per_network_polynomials            0.996 0.997 0.999 1.000
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.971 0.997 0.991 0.970
# target_polynomials_VS_lstsq_target_polynomials     1.000 1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials             0.873 0.987 0.992 0.955
# target_polynomials_VS_symbolic_regression_funct... 0.964 0.998 0.969 0.962
# target_polynomials_VS_per_network_polynomials      0.972 0.998 0.991 0.970
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.964 0.996 0.991 0.971
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.926 0.991 0.994 0.997
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.988 0.998 0.972 0.995
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.998 0.997 1.000 1.000
# lstsq_target_polynomials_VS_inet_polynomials       0.873 0.987 0.992 0.955
# lstsq_target_polynomials_VS_symbolic_regression... 0.964 0.998 0.969 0.962
# lstsq_target_polynomials_VS_per_network_polynom... 0.972 0.998 0.991 0.970
# inet_polynomials_VS_symbolic_regression_functions  0.931 0.990 0.977 0.991
# inet_polynomials_VS_per_network_polynomials        0.881 0.991 0.995 0.997
# symbolic_regression_functions_VS_per_network_po... 0.990 1.000 0.974 0.995
#
#                                                     L-72    L-73  L-74  L-75  \
# lambda_preds_VS_target_polynomials                 0.245   0.966 0.993 0.985
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.998   0.998 1.000 1.000
# lambda_preds_VS_lstsq_target_polynomials           0.245   0.966 0.994 0.985
# lambda_preds_VS_inet_polynomials                   0.869   0.987 0.994 0.989
# lambda_preds_VS_symbolic_regression_functions       -inf -44.443 0.999 0.989
# lambda_preds_VS_per_network_polynomials            0.995   0.995 0.999 0.998
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.427   0.974 0.994 0.988
# target_polynomials_VS_lstsq_target_polynomials     1.000   1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials             0.186   0.986 0.996 0.978
# target_polynomials_VS_symbolic_regression_funct...  -inf -35.174 0.997 0.994
# target_polynomials_VS_per_network_polynomials      0.425   0.974 0.995 0.988
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.235   0.967 0.994 0.986
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.872   0.987 0.994 0.990
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...  -inf -44.672 0.999 0.990
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.997   0.996 1.000 0.999
# lstsq_target_polynomials_VS_inet_polynomials       0.186   0.986 0.996 0.978
# lstsq_target_polynomials_VS_symbolic_regression...  -inf -35.168 0.997 0.994
# lstsq_target_polynomials_VS_per_network_polynom... 0.424   0.974 0.995 0.988
# inet_polynomials_VS_symbolic_regression_functions   -inf -38.963 0.995 0.983
# inet_polynomials_VS_per_network_polynomials        0.886   0.993 0.995 0.990
# symbolic_regression_functions_VS_per_network_po...   NaN   0.032 1.000 0.992
#
#                                                     L-76  L-77  L-78  L-79  \
# lambda_preds_VS_target_polynomials                 0.999 0.994 0.947 0.995
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000 1.000 1.000 1.000
# lambda_preds_VS_lstsq_target_polynomials           0.999 0.994 0.947 0.995
# lambda_preds_VS_inet_polynomials                   0.993 0.984 0.998 0.997
# lambda_preds_VS_symbolic_regression_functions      0.999 0.942 1.000 0.999
# lambda_preds_VS_per_network_polynomials            1.000 0.999 1.000 1.000
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.999 0.995 0.957 0.995
# target_polynomials_VS_lstsq_target_polynomials     1.000 1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials             0.992 0.982 0.949 0.998
# target_polynomials_VS_symbolic_regression_funct... 0.998 0.938 0.955 0.998
# target_polynomials_VS_per_network_polynomials      0.999 0.997 0.957 0.996
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.999 0.994 0.947 0.995
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.993 0.984 0.998 0.997
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.999 0.943 1.000 0.999
# lstsq_lambda_pred_polynomials_VS_per_network_po... 1.000 0.999 1.000 1.000
# lstsq_target_polynomials_VS_inet_polynomials       0.992 0.982 0.949 0.998
# lstsq_target_polynomials_VS_symbolic_regression... 0.998 0.938 0.955 0.998
# lstsq_target_polynomials_VS_per_network_polynom... 0.999 0.997 0.957 0.996
# inet_polynomials_VS_symbolic_regression_functions  0.988 0.935 0.999 0.999
# inet_polynomials_VS_per_network_polynomials        0.992 0.987 0.998 0.998
# symbolic_regression_functions_VS_per_network_po... 0.999 0.940 1.000 0.999
#
#                                                     L-80  L-81   L-82  L-83  \
# lambda_preds_VS_target_polynomials                 0.985 0.973 -7.666 0.993
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000 1.000  1.000 1.000
# lambda_preds_VS_lstsq_target_polynomials           0.985 0.973 -7.666 0.993
# lambda_preds_VS_inet_polynomials                   0.977 0.981  0.652 0.995
# lambda_preds_VS_symbolic_regression_functions      0.998 0.995  0.974 0.996
# lambda_preds_VS_per_network_polynomials            0.999 0.999  1.000 0.999
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.986 0.972 -0.122 0.994
# target_polynomials_VS_lstsq_target_polynomials     1.000 1.000  1.000 1.000
# target_polynomials_VS_inet_polynomials             0.950 0.955  0.195 0.993
# target_polynomials_VS_symbolic_regression_funct... 0.984 0.977 -0.113 0.999
# target_polynomials_VS_per_network_polynomials      0.988 0.972 -0.122 0.995
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.985 0.973 -7.666 0.994
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.976 0.982  0.652 0.996
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.998 0.996  0.974 0.997
# lstsq_lambda_pred_polynomials_VS_per_network_po... 0.999 1.000  1.000 0.999
# lstsq_target_polynomials_VS_inet_polynomials       0.950 0.955  0.195 0.993
# lstsq_target_polynomials_VS_symbolic_regression... 0.984 0.977 -0.113 0.999
# lstsq_target_polynomials_VS_per_network_polynom... 0.988 0.972 -0.122 0.995
# inet_polynomials_VS_symbolic_regression_functions  0.979 0.990  0.717 0.996
# inet_polynomials_VS_per_network_polynomials        0.978 0.984  0.750 0.996
# symbolic_regression_functions_VS_per_network_po... 0.998 0.996  0.978 0.997
#
#                                                     L-84  L-85  L-86  L-87  \
# lambda_preds_VS_target_polynomials                 0.849 0.955 0.958 0.444
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000 1.000 0.998 1.000
# lambda_preds_VS_lstsq_target_polynomials           0.849 0.955 0.958 0.444
# lambda_preds_VS_inet_polynomials                   0.993 0.991 0.967 0.945
# lambda_preds_VS_symbolic_regression_functions      1.000 0.993 0.992 0.995
# lambda_preds_VS_per_network_polynomials            1.000 1.000 0.998 1.000
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.893 0.962 0.965 0.446
# target_polynomials_VS_lstsq_target_polynomials     1.000 1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials             0.847 0.962 0.910 0.281
# target_polynomials_VS_symbolic_regression_funct... 0.892 0.947 0.954 0.469
# target_polynomials_VS_per_network_polynomials      0.893 0.962 0.961 0.446
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.849 0.955 0.960 0.444
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.993 0.991 0.969 0.945
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 1.000 0.993 0.993 0.995
# lstsq_lambda_pred_polynomials_VS_per_network_po... 1.000 1.000 0.999 1.000
# lstsq_target_polynomials_VS_inet_polynomials       0.847 0.962 0.909 0.281
# lstsq_target_polynomials_VS_symbolic_regression... 0.892 0.947 0.954 0.469
# lstsq_target_polynomials_VS_per_network_polynom... 0.893 0.962 0.961 0.446
# inet_polynomials_VS_symbolic_regression_functions  0.993 0.997 0.970 0.899
# inet_polynomials_VS_per_network_polynomials        0.992 0.991 0.965 0.929
# symbolic_regression_functions_VS_per_network_po... 1.000 0.993 0.996 0.995
#
#                                                     L-88  L-89   L-90  L-91  \
# lambda_preds_VS_target_polynomials                 0.971 0.993 -0.222 0.959
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000 0.999  1.000 0.997
# lambda_preds_VS_lstsq_target_polynomials           0.971 0.993 -0.223 0.959
# lambda_preds_VS_inet_polynomials                   0.996 0.894  0.969 0.971
# lambda_preds_VS_symbolic_regression_functions      0.999 0.996  0.981 0.978
# lambda_preds_VS_per_network_polynomials            1.000 0.997  1.000 0.982
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.975 0.995  0.213 0.971
# target_polynomials_VS_lstsq_target_polynomials     1.000 1.000  1.000 1.000
# target_polynomials_VS_inet_polynomials             0.975 0.920  0.106 0.952
# target_polynomials_VS_symbolic_regression_funct... 0.971 0.997  0.154 0.995
# target_polynomials_VS_per_network_polynomials      0.975 0.996  0.213 0.982
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.971 0.995 -0.223 0.964
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.996 0.899  0.969 0.973
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.999 0.998  0.981 0.983
# lstsq_lambda_pred_polynomials_VS_per_network_po... 1.000 0.998  1.000 0.984
# lstsq_target_polynomials_VS_inet_polynomials       0.975 0.920  0.106 0.952
# lstsq_target_polynomials_VS_symbolic_regression... 0.971 0.997  0.155 0.995
# lstsq_target_polynomials_VS_per_network_polynom... 0.975 0.996  0.213 0.982
# inet_polynomials_VS_symbolic_regression_functions  0.997 0.934  0.997 0.951
# inet_polynomials_VS_per_network_polynomials        0.995 0.930  0.972 0.967
# symbolic_regression_functions_VS_per_network_po... 0.999 1.000  0.984 0.991
#
#                                                     L-92  L-93  L-94    L-95  \
# lambda_preds_VS_target_polynomials                 0.842 0.989 0.797 -54.841
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000 0.999 1.000   1.000
# lambda_preds_VS_lstsq_target_polynomials           0.842 0.989 0.797 -54.828
# lambda_preds_VS_inet_polynomials                   0.999 0.993 0.997   0.839
# lambda_preds_VS_symbolic_regression_functions      1.000  -inf 1.000   1.000
# lambda_preds_VS_per_network_polynomials            1.000 0.996 1.000   1.000
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.886 0.990 0.857  -0.017
# target_polynomials_VS_lstsq_target_polynomials     1.000 1.000 1.000   1.000
# target_polynomials_VS_inet_polynomials             0.891 0.996 0.825   0.024
# target_polynomials_VS_symbolic_regression_funct... 0.888  -inf 0.859  -0.016
# target_polynomials_VS_per_network_polynomials      0.886 0.992 0.857  -0.017
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.842 0.989 0.797 -54.828
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.999 0.993 0.997   0.839
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 1.000  -inf 1.000   1.000
# lstsq_lambda_pred_polynomials_VS_per_network_po... 1.000 0.996 1.000   1.000
# lstsq_target_polynomials_VS_inet_polynomials       0.891 0.996 0.825   0.024
# lstsq_target_polynomials_VS_symbolic_regression... 0.888  -inf 0.859  -0.016
# lstsq_target_polynomials_VS_per_network_polynom... 0.886 0.992 0.857  -0.017
# inet_polynomials_VS_symbolic_regression_functions  0.998  -inf 0.997   0.914
# inet_polynomials_VS_per_network_polynomials        0.999 0.996 0.997   0.915
# symbolic_regression_functions_VS_per_network_po... 1.000   NaN 1.000   1.000
#
#                                                      L-96  L-97   L-98  L-99
# lambda_preds_VS_target_polynomials                 -0.062 0.947 -3.470 0.978
# lambda_preds_VS_lstsq_lambda_pred_polynomials       1.000 1.000  1.000 1.000
# lambda_preds_VS_lstsq_target_polynomials           -0.062 0.947 -3.469 0.978
# lambda_preds_VS_inet_polynomials                    0.988 0.948  0.994 0.991
# lambda_preds_VS_symbolic_regression_functions       0.909 1.000  0.993 0.995
# lambda_preds_VS_per_network_polynomials             1.000 1.000  1.000 1.000
# target_polynomials_VS_lstsq_lambda_pred_polynom...  0.367 0.951  0.302 0.980
# target_polynomials_VS_lstsq_target_polynomials      1.000 1.000  1.000 1.000
# target_polynomials_VS_inet_polynomials              0.438 0.902  0.269 0.971
# target_polynomials_VS_symbolic_regression_funct...  0.322 0.953  0.315 0.986
# target_polynomials_VS_per_network_polynomials       0.364 0.951  0.302 0.980
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... -0.061 0.947 -3.469 0.977
# lstsq_lambda_pred_polynomials_VS_inet_polynomials   0.988 0.948  0.994 0.991
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...  0.908 1.000  0.993 0.995
# lstsq_lambda_pred_polynomials_VS_per_network_po...  1.000 1.000  1.000 1.000
# lstsq_target_polynomials_VS_inet_polynomials        0.438 0.901  0.269 0.971
# lstsq_target_polynomials_VS_symbolic_regression...  0.322 0.953  0.315 0.986
# lstsq_target_polynomials_VS_per_network_polynom...  0.364 0.951  0.302 0.980
# inet_polynomials_VS_symbolic_regression_functions   0.941 0.928  0.974 0.983
# inet_polynomials_VS_per_network_polynomials         0.989 0.932  0.994 0.991
# symbolic_regression_functions_VS_per_network_po...  0.885 1.000  0.993 0.996

# %%
index_min = int(np.argmin(distrib_dict_test_list[-1]['R2'].loc['lambda_preds_VS_lstsq_target_polynomials']))
polynomial_inet = polynomial_dict_test_list[-1]['inet_polynomials'][index_min]

print(distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_inet_polynomials'][index_min])

print_polynomial_from_coefficients(polynomial_inet)
# Out:
# 0.02382943016981165
# -7.22246885299683*a**1.0 - 3.54161190986633*a**2.0 - 0.334064394235611*a**3.0 + 0.684189975261688*a**4.0 - 0.684608697891235*a**5.0 - 5.77878618240356

# %%
index_min = int(np.argmin(distrib_dict_test_list[-1]['R2'].loc['lambda_preds_VS_lstsq_lambda_pred_polynomials']))
#polynomial_target = lambda_net_test_dataset.get_lambda_net_by_lambda_index(index_min).target_polynomial

print(distrib_dict_test_list[-1]['R2'].loc['lstsq_lambda_pred_polynomials_VS_inet_polynomials'][index_min])

polynomial_lambda = lambda_net_test_dataset.lstsq_lambda_pred_polynomial_list[index_min]
print_polynomial_from_coefficients(polynomial_lambda, force_complete_poly_representation=True)
# Out:
# -4.2315369976891875
# 12.0184322958308*a**1.0 - 62.2497342537696*a**2.0 + 119.881859258699*a**3.0 - 40.0484827500752*a**4.0 - 44.8237015756248*a**5.0 - 23.1913836225427

# %%
index_min = int(np.argmin(distrib_dict_test_list[-1]['R2'].loc['lambda_preds_VS_lstsq_target_polynomials']))
#polynomial_target = lambda_net_test_dataset.get_lambda_net_by_lambda_index(index_min).target_polynomial
polynomial_target = lambda_net_test_dataset.target_polynomial_list[index_min]
print_polynomial_from_coefficients(polynomial_target, force_complete_poly_representation=True)
# Out:
# 39.7310117109495*a**1.0 + 81.6824889434104*a**2.0 - 77.1365104959688*a**3.0 - 42.498159990529*a**4.0 - 56.0503344649584*a**5.0 - 25.9466010625288

# %%
index_max = int(np.argmax(distrib_dict_test_list[-1]['R2'].loc['lambda_preds_VS_lstsq_target_polynomials']))
polynomial_inet = polynomial_dict_test_list[-1]['inet_polynomials'][index_max]

print(distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_inet_polynomials'][index_max])

print_polynomial_from_coefficients(polynomial_inet)
# Out:
# 0.9921596611231788
# -57.3086585998535*a**1.0 - 45.3862724304199*a**2.0 - 26.4500198364258*a**3.0 - 2.48156571388245*a**4.0 + 13.5333805084229*a**5.0 + 83.7317962646484

# %%
index_max = int(np.argmax(distrib_dict_test_list[-1]['R2'].loc['lambda_preds_VS_lstsq_target_polynomials']))
#polynomial_target = lambda_net_test_dataset.get_lambda_net_by_lambda_index(index_min).target_polynomial

print(distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_lstsq_lambda_pred_polynomials'][index_max])

polynomial_lambda = lambda_net_test_dataset.lstsq_lambda_pred_polynomial_list[index_max]
print_polynomial_from_coefficients(polynomial_lambda, force_complete_poly_representation=True)
# Out:
# 0.9991129193544597
# -85.8334599430251*a**1.0 - 75.0209737752179*a**2.0 + 245.354038866534*a**3.0 - 458.359947661319*a**4.0 + 250.776958036101*a**5.0 + 91.993350432237

# %%
index_max = int(np.argmax(distrib_dict_test_list[-1]['R2'].loc['lambda_preds_VS_lstsq_target_polynomials']))
#polynomial_target = lambda_net_test_dataset.get_lambda_net_by_lambda_index(index_min).target_polynomial
polynomial_target = lambda_net_test_dataset.target_polynomial_list[index_max]
print_polynomial_from_coefficients(polynomial_target, force_complete_poly_representation=True)
# Out:
# -97.0287754984992*a**1.0 - 3.77486163663087*a**2.0 - 33.3264323766874*a**3.0 - 10.1753172139498*a**4.0 + 14.1329157961578*a**5.0 + 93.1306349532824

# %%
r2_values_inet = distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_inet_polynomials']
print('Mean: ' + str(np.mean(r2_values_inet)) + ' (' + str(r2_values_inet.shape[0]) + ' Samples)')

r2_values_positive_inet = r2_values_inet[r2_values_inet>0]
print('Mean (only positive): ' + str(np.mean(r2_values_positive_inet)) + ' (' + str(r2_values_positive_inet.shape[0]) + ' Samples)')
# Out:
# Mean: 0.7162931248157695 (100 Samples)
# Mean (only positive): 0.8169669557227859 (94 Samples)

# %%
r2_values_lstsq_lambda = distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_lstsq_lambda_pred_polynomials']
print('Mean: ' + str(np.mean(r2_values_lstsq_lambda)) + ' (' + str(r2_values_inet.shape[0]) + ' Samples)')

r2_values_positive_lstsq_lambda = r2_values_lstsq_lambda[r2_values_lstsq_lambda>0]
print('Mean (only positive): ' + str(np.mean(r2_values_positive_lstsq_lambda)) + ' (' + str(r2_values_positive_lstsq_lambda.shape[0]) + ' Samples)')
# Out:
# Mean: 0.7880583147908922 (100 Samples)
# Mean (only positive): 0.8538952002213546 (94 Samples)

# %%
sns.histplot(distrib_dict_test_list[-1]['MAE'].loc['target_polynomials_VS_inet_polynomials'][distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_inet_polynomials'] > -50])
# Out:
# <AxesSubplot:xlabel='target_polynomials_VS_inet_polynomials', ylabel='Count'>

# %%
sns.histplot(distrib_dict_test_list[-1]['MAE'].loc['target_polynomials_VS_lstsq_lambda_pred_polynomials'][distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_lstsq_lambda_pred_polynomials'] > -50])
# Out:
# <AxesSubplot:xlabel='target_polynomials_VS_lstsq_lambda_pred_polynomials', ylabel='Count'>

# %%
p = sns.histplot(distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_inet_polynomials'][distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_inet_polynomials'] > -50], binwidth=0.2)
p.set(xlim=(-30, 1))
# Out:
# [(-30.0, 1.0)]

# %%
p = sns.histplot(distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_inet_polynomials'][distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_inet_polynomials'] > -50], binwidth=0.1)
p.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
p = sns.histplot(distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_lstsq_lambda_pred_polynomials'][distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_lstsq_lambda_pred_polynomials'] > -50], binwidth=0.2)
p.set(xlim=(-10, 1))
# Out:
# [(-10.0, 1.0)]

# %%
p = sns.histplot(distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_lstsq_lambda_pred_polynomials'][distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_lstsq_lambda_pred_polynomials'] > -50], binwidth=0.1)
p.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
if not nas:
    history = history_list[-1]

    plt.plot(history[list(history.keys())[1]])
    if consider_labels_training or evaluate_with_real_function:
        plt.plot(history[list(history.keys())[len(history.keys())//2+1]]) 
    plt.title('model ' + list(history.keys())[1])
    plt.ylabel('metric')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')
    plt.savefig('./data/results/' + path_identifier_interpretation_net_data + '/metric_' + '_epoch_' + str(epochs_lambda).zfill(3) + '.png')

# %%
if not nas:
    history = history_list[-1]

    plt.plot(history['loss'])
    if consider_labels_training or evaluate_with_real_function:
        plt.plot(history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')
    plt.savefig('./data/results/' + path_identifier_interpretation_net_data + '/loss_' + '_epoch_' + str(epochs_lambda).zfill(3) + '.png')

# %% [markdown]
# ### Multi Epoch/Sampes Analysis

# %% [markdown]
# ### Generate Comparison Plots

# %%
if len(scores_test_list) > 1:
    plot_metric_list = ['MAE FV', 'RMSE FV', 'MAPE FV', 'R2 FV', 'RAAE FV', 'RMAE FV']

    generate_inet_comparison_plot(scores_test_list, plot_metric_list)

# %%
if len(scores_test_list) > 1:
    plot_metric_list = ['MAE FV']

    generate_inet_comparison_plot(scores_test_list, plot_metric_list)

# %%
if len(scores_test_list) > 1:
    plot_metric_list = ['R2 FV']

    generate_inet_comparison_plot(scores_test_list, plot_metric_list, ylim=(-5, 1))

# %% [markdown]
# #### Generate and Analyze Predictions for Random Function

# %%
index = 6

custom_representation_keys_fixed = ['target_polynomials', 'lstsq_target_polynomials', 'lstsq_lambda_pred_polynomials', 'lstsq_lambda_pred_polynomials']
custom_representation_keys_dynamic = ['inet_polynomials', 'per_network_polynomials']
sympy_representation_keys = ['metamodel_functions']


print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')

for key in polynomial_dict_test_list[-1].keys():
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print(key)
    if key in custom_representation_keys_fixed:
        print_polynomial_from_coefficients(polynomial_dict_test_list[-1][key][index], force_complete_poly_representation=True, round_digits=4)
    elif key in custom_representation_keys_dynamic:
        print_polynomial_from_coefficients(polynomial_dict_test_list[-1][key][index], round_digits=4)
    else:
        display(polynomial_dict_test_list[-1][key][index])

print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# lstsq_lambda_pred_polynomials
# -19.5767*a**1.0 - 2.9894*a**2.0 + 88.3672*a**3.0 - 233.0321*a**4.0 + 168.9666*a**5.0 - 6.881
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# lstsq_target_polynomials
# 36.6934*a**1.0 - 63.697*a**2.0 - 81.2686*a**3.0 + 81.1018*a**4.0 + 39.0385*a**5.0 - 13.7474
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# target_polynomials
# 36.843*a**1.0 - 64.7192*a**2.0 - 78.4084*a**3.0 + 77.7464*a**4.0 + 40.4184*a**5.0 - 13.7547
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# inet_polynomials
# -42.5279998779297*a**1.0 - 13.2686004638672*a**2.0 + 10.8488998413086*a**3.0 + 27.128999710083*a**4.0 + 29.4277992248535*a**5.0 - 0.564100027084351
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# symbolic_regression_functions
# (-19.593253968254*x**2 + 12.3819199154021*x + 7.23951282051282)/(1.0*x - 1.047)
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# per_network_polynomials
# -8.17440032958984*a**1.0 - 16.9734992980957*a**2.0 - 17.2616996765137*a**3.0 + 19.7063999176025*a**4.0 + 23.2688999176025*a**5.0 - 7.69859981536865
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
plot_and_save_single_polynomial_prediction_evaluation(lambda_net_test_dataset_list, 
                                                      function_values_test_list, 
                                                      polynomial_dict_test_list,
                                                      rand_index=index, 
                                                      plot_type=1)

# %%
plot_and_save_single_polynomial_prediction_evaluation(lambda_net_test_dataset_list, 
                                                      function_values_test_list, 
                                                      polynomial_dict_test_list,
                                                      rand_index=index, 
                                                      plot_type=2)

# %%
plot_and_save_single_polynomial_prediction_evaluation(lambda_net_test_dataset_list, 
                                                      function_values_test_list, 
                                                      polynomial_dict_test_list,
                                                      rand_index=index, 
                                                      plot_type=3)

# %% [markdown]
# # BENCHMARK (RANDOM GUESS) EVALUATION

# %%
list_of_random_polynomials = np.random.uniform(low=-10, high=10, size=(len(lambda_net_test_dataset_list[-1]), sparsity))

# %%
true_fv_test = parallel_fv_calculation_from_polynomial(lambda_net_test_dataset_list[-1].target_polynomial_list, lambda_net_test_dataset_list[-1].X_test_data_list, force_complete_poly_representation=True)
random_fv_test = parallel_fv_calculation_from_polynomial(list_of_random_polynomials, lambda_net_test_dataset_list[-1].X_test_data_list, force_complete_poly_representation=True)

# %%
print('Random Guess Error Coefficients: ' + str(np.round(mean_absolute_error(lambda_net_test_dataset_list[-1].target_polynomial_list, list_of_random_polynomials), 4)))
# Out:
# Random Guess Error Coefficients: 47.4903

# %%
print('Random Guess Error FVs: ' + str(np.round(mean_absolute_error_function_values(true_fv_test, random_fv_test), 4)))
# Out:
# Random Guess Error FVs: 60.2965

# %% [markdown]
# # BENCHMARK (EDUCATED GUESS/MEAN PREDICTION) EVALUATION

# %%
true_fv_train = parallel_fv_calculation_from_polynomial(lambda_net_test_dataset_list[-1].target_polynomial_list, lambda_net_test_dataset_list[-1].X_test_data_list, force_complete_poly_representation=True)

mean_fv = np.mean(true_fv_train)
mean_fv_pred_test = [mean_fv for _ in range(true_fv_test.shape[0])]

# %%
print('Educated Guess/Mean Prediction Error FVs: ' + str(np.round(mean_absolute_error_function_values(true_fv_test, mean_fv_pred_test), 4)))
# Out:
# Educated Guess/Mean Prediction Error FVs: 59.8068

# %%
# %%script false --no-raise-error
#
# base_model = generate_base_model()
# random_evaluation_dataset = np.random.uniform(low=x_min, high=x_max, size=(random_evaluation_dataset_size, n))
# #random_evaluation_dataset = lambda_train_input_train_split[0]#lambda_train_input[0] #JUST [0] HERE BECAUSE EVALUATION ALWAYS ON THE SAME DATASET FOR ALL!!
# list_of_monomial_identifiers_numbers = np.array([list(monomial_identifiers) for monomial_identifiers in list_of_monomial_identifiers]).astype(float)
#
#
# loss_function = mean_absolute_error_tf_fv_lambda_extended_wrapper(random_evaluation_dataset, list_of_monomial_identifiers_numbers, base_model)
#
# X_train = X_train_list[-1].values[:,1:]
# y_train = y_train_list[-1].values[:,2:]
#
# #X_train = X_train[:,1:]
# y_train_model = np.hstack((y_train, X_train))
#
# print('seed_in_inet_training = ' + str(seed_in_inet_training), loss_function(y_train_model, y_train))
#
#
# seed_in_inet_training = False
#
# loss_function = mean_absolute_error_tf_fv_lambda_extended_wrapper(random_evaluation_dataset, list_of_monomial_identifiers_numbers, base_model)
#
# X_train = X_train_list[-1].values[:,1:]
# y_train = y_train_list[-1].values[:,2:]
#
# X_train = X_train[:,1:]
# y_train_model = np.hstack((y_train, X_train))
#
# print('seed_in_inet_training = ' + str(seed_in_inet_training), loss_function(y_train_model, y_train))
#
# seed_in_inet_training = True

# %%
lambda_net_test_dataset = lambda_net_test_dataset_list[-1]
current_jobs = 1

lr=0.5
max_steps = 100
early_stopping=10
restarts=2
per_network_dataset_size = 500

list_of_monomial_identifiers_numbers = np.array([list(monomial_identifiers) for monomial_identifiers in list_of_monomial_identifiers]).astype(float)  

if n_jobs != -1:
    n_jobs_per_network = min(n_jobs, os.cpu_count() // current_jobs)
else: 
    n_jobs_per_network = os.cpu_count() // current_jobs - 1

printing = True if n_jobs_per_network == 1 else False


lambda_network_weights_list = np.array(lambda_net_test_dataset.weight_list)
if evaluate_with_real_function: #target polynomial as inet target
    poly_representation_list = np.array(lambda_net_test_dataset.target_polynomial_list)
else: #lstsq lambda pred polynomial as inet target
    poly_representation_list = np.array(lambda_net_test_dataset.lstsq_lambda_pred_polynomial_list)


config = {
         'n': n,
         'inet_loss': inet_loss,
         'sparsity': sparsity,
         'lambda_network_layers': lambda_network_layers,
         'interpretation_net_output_shape': interpretation_net_output_shape,
         'RANDOM_SEED': RANDOM_SEED,
         'nas': nas,
         'number_of_lambda_weights': number_of_lambda_weights,
         'interpretation_net_output_monomials': interpretation_net_output_monomials,
         #'list_of_monomial_identifiers': list_of_monomial_identifiers,
         'x_min': x_min,
         'x_max': x_max,
         }


lambda_network_weights = lambda_network_weights_list[0]
poly_representation = poly_representation_list[0]



per_network_poly_optimization_tf(per_network_dataset_size, 
                                lambda_network_weights, 
                                  list_of_monomial_identifiers_numbers, 
                                  config, 
                                  lr=lr, 
                                  max_steps = max_steps, 
                                  early_stopping=early_stopping, 
                                  restarts=restarts, 
                                  printing=True)
# Out:
# Current best: 5.084824562072754
#  Curr_res: 5.048698902130127
#  Iteration 1, Step 99
# Optimization terminated at 5.048698902130127
# array([-23.589212, -27.850266, -21.384018, -14.740056,  -8.74567 ,
#         -4.661557], dtype=float32)

# %% [markdown]
# # Evaluate Real Dataset

# %% [markdown]
# ##  Auto MPG-Dataset

# %%
interpretation_possible_autoMPG = False
print_head_autoMPG = None

url_autoMPG = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'
column_names_autoMPG = ['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
                'Acceleration', 'Model Year', 'Origin']

raw_dataset_autoMPG = pd.read_csv(url_autoMPG, names=column_names_autoMPG,
                          na_values='?', comment='\t',
                          sep=' ', skipinitialspace=True)

dataset_autoMPG = raw_dataset_autoMPG.dropna()

dataset_autoMPG['Origin'] = dataset_autoMPG['Origin'].map({1: 'USA', 2: 'Europe', 3: 'Japan'})
dataset_autoMPG = pd.get_dummies(dataset_autoMPG, columns=['Origin'], prefix='', prefix_sep='')


features_autoMPG = dataset_autoMPG.copy()

labels_autoMPG = features_autoMPG.pop('MPG')

features_autoMPG_normalized = (features_autoMPG-features_autoMPG.min())/(features_autoMPG.max()-features_autoMPG.min())


if features_autoMPG_normalized.shape[1] >= n:
    if n == 1:
        features_autoMPG_model = features_autoMPG_normalized[['Horsepower']]
    elif n == train_features_normalized.shape[1]:
        features_autoMPG_model = features_autoMPG_normalized
    else:
        features_autoMPG_model = features_autoMPG_normalized.sample(n=n, axis='columns')
        
    print_head_autoMPG = features_autoMPG_model.head()
    interpretation_possible_autoMPG = True

print_head_autoMPG
# Out:
#    Horsepower
# 0       0.457
# 1       0.647
# 2       0.565
# 3       0.565
# 4       0.511

# %%
#%autoreload 2
if interpretation_possible_autoMPG:
    ((lambda_index_autoMPG, 
     current_seed_autoMPG, 
     polynomial_autoMPG, 
     polynomial_lstsq_pred_list_autoMPG, 
     polynomial_lstsq_true_list_autoMPG), 
    scores_list_autoMPG, 
    pred_list_autoMPG, 
    history_autoMPG, 
    model_autoMPG) = train_nn(lambda_index=0, 
                              X_data_lambda=features_autoMPG_model.values, 
                              y_data_real_lambda=labels_autoMPG.values, 
                              polynomial=None, 
                              seed_list=[RANDOM_SEED+1], 
                              callbacks=[PlotLossesKerasTF()], 
                              return_history=True, 
                              each_epochs_save=None, 
                              printing=False, 
                              return_model=True)
    
    polynomial_lstsq_pred_autoMPG = polynomial_lstsq_pred_list_autoMPG[-1]
# Out:
# Loss
# 	training         	 (min:    5.673, max:   23.527, cur:    6.247)
# 	validation       	 (min:    4.061, max:   22.360, cur:    4.061)
# mae
# 	training         	 (min:    5.673, max:   23.527, cur:    6.247)
# 	validation       	 (min:    4.061, max:   22.360, cur:    4.061)
# r2_keras_loss
# 	training         	 (min:   -0.094, max:   11.202, cur:    0.139)
# 	validation       	 (min:   -0.515, max:   13.554, cur:   -0.515)
# root_mean_squared_error
# 	training         	 (min:    7.017, max:   24.878, cur:    7.930)
# 	validation       	 (min:    4.480, max:   23.096, cur:    4.480)

# %%
if interpretation_possible_autoMPG:
    x = tf.linspace(0.0, 1, 250)#tf.linspace(0.0, 250, 251)
    y = model_autoMPG.predict(x)

    plt.scatter(features_autoMPG_model['Horsepower'], labels_autoMPG, label='Data')
    plt.plot(x, y, color='k', label='Predictions')
    plt.xlabel('Horsepower')
    plt.ylabel('MPG')
    plt.legend()

# %%
config = {
        'n': n,
        'd': d,
        'inet_loss': inet_loss,
        'sparsity': sparsity,
        'lambda_network_layers': lambda_network_layers,
        'interpretation_net_output_shape': interpretation_net_output_shape,
        'RANDOM_SEED': RANDOM_SEED,
        'nas': nas,
        'number_of_lambda_weights': number_of_lambda_weights,
        'interpretation_net_output_monomials': interpretation_net_output_monomials,
        'fixed_initialization_lambda_training': fixed_initialization_lambda_training,
        'dropout': dropout,
        'lambda_network_layers': lambda_network_layers,
        'optimizer_lambda': optimizer_lambda,
        'loss_lambda': loss_lambda,        
         #'list_of_monomial_identifiers': list_of_monomial_identifiers,
         'x_min': x_min,
         'x_max': x_max,
         }

weights_autoMPG = model_autoMPG.get_weights()

weights_flat_autoMPG = []
for layer_weights, biases in pairwise(weights_autoMPG):    #clf.get_weights()
    for neuron in layer_weights:
        for weight in neuron:
            weights_flat_autoMPG.append(weight)
    for bias in biases:
        weights_flat_autoMPG.append(bias)
        
weights_flat_autoMPG = np.array(weights_flat_autoMPG)

x = pred_list_autoMPG['X_test_lambda']
y = pred_list_autoMPG['y_test_real_lambda']

y_model_autoMPG = model_autoMPG.predict(x)

# %%
if interpretation_possible_autoMPG:
    y_polynomial_lstsq_pred_autoMPG = calculate_function_values_from_polynomial(polynomial_lstsq_pred_autoMPG, x, force_complete_poly_representation=True)

    mae_model_polynomial_lstsq_pred_autoMPGy = mean_absolute_error(y_model_autoMPG, y_polynomial_lstsq_pred_autoMPG)
    mae_data_polynomial_lstsq_pred_autoMPG = mean_absolute_error(y, y_polynomial_lstsq_pred_autoMPG)

    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('LSTSQt Poly:')
    print_polynomial_from_coefficients(y_polynomial_lstsq_pred_autoMPG, force_complete_poly_representation=True)
    print('MAE Model: ', mae_model_polynomial_lstsq_pred_autoMPGy)
    print('MAE Data: ', mae_data_polynomial_lstsq_pred_autoMPG)
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# LSTSQt Poly:
# 14.5075956711233*a**1.0 + 17.3734706286986*a**2.0 + 17.0839850380018*a**3.0 + 21.4395846752636*a**4.0 + 18.5376713646147*a**5.0 + 17.3734706286986
# MAE Model:  0.04336287897827347
# MAE Data:  4.66952276909255
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
if interpretation_possible_autoMPG:
    interpretation_net = model_list[-1]
    
    start = time.time() 
    
    interpretation_net_poly = interpretation_net.predict(np.array([weights_flat_autoMPG]))[0]
    
    end = time.time()     
    generation_time = (end - start) 
    minutes, seconds = divmod(int(generation_time), 60)
    hours, minutes = divmod(minutes, 60)        
    
    y_interpretation_net_poly = calculate_function_values_from_polynomial(interpretation_net_poly, x, force_complete_poly_representation=False)
    
    mae_model_interpretation_net_poly = mean_absolute_error(y_model_autoMPG, y_interpretation_net_poly)
    mae_data_interpretation_net_poly = mean_absolute_error(y, y_interpretation_net_poly)
    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('Interpretation Net Poly:')
    print_polynomial_from_coefficients(interpretation_net_poly, force_complete_poly_representation=False)
    print('MAE Model: ', mae_model_interpretation_net_poly)
    print('MAE Data: ', mae_data_interpretation_net_poly)    
    print('Computation Time: ' +  f'{hours:d}:{minutes:02d}:{seconds:02d}')    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Interpretation Net Poly:
# 17.6665458679199*a**1.0 + 7.83293771743774*a**2.0 + 3.05799341201782*a**3.0 + 0.956114888191223*a**4.0 - 2.75414347648621*a**5.0 + 5.60359859466553
# MAE Model:  11.487858406451748
# MAE Data:  14.994469481009046
# Computation Time: 0:00:00
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
if interpretation_possible_autoMPG:
    start = time.time() 
    
    if False:
        per_network_hyperparams = {
            'optimizer':  'Powell',
            'jac': 'fprime',
            'max_steps': 5000,#100,
            'restarts': 3,
            'per_network_dataset_size': 500,
        }      
        
        per_network_function =  per_network_poly_optimization_scipy(per_network_dataset_size, 
                                                                  weights_flat_autoMPG, 
                                                                  list_of_monomial_identifiers_numbers, 
                                                                  config, 
                                                                  optimizer = per_network_hyperparams['optimizer'],
                                                                  jac = per_network_hyperparams['jac'],
                                                                  max_steps = per_network_hyperparams['max_steps'], 
                                                                  restarts=per_network_hyperparams['restarts'], 
                                                                  printing=True,
                                                                  return_error=False)
    else:
        per_network_hyperparams = {
            'optimizer': tf.keras.optimizers.RMSprop,
            'lr': 0.02,
            'max_steps': 500,
            'early_stopping': 10,
            'restarts': 3,
            'per_network_dataset_size': 5000,
        }   
        
        per_network_function =  per_network_poly_optimization_tf(per_network_hyperparams['per_network_dataset_size'], 
                                                              weights_flat_autoMPG, 
                                                              list_of_monomial_identifiers_numbers, 
                                                              config, 
                                                              optimizer = per_network_hyperparams['optimizer'],
                                                              lr=per_network_hyperparams['lr'], 
                                                              max_steps = per_network_hyperparams['max_steps'], 
                                                              early_stopping=per_network_hyperparams['early_stopping'], 
                                                              restarts=per_network_hyperparams['restarts'], 
                                                              printing=True,
                                                              return_error=False)
            
    end = time.time()     
    generation_time = (end - start) 
    minutes, seconds = divmod(int(generation_time), 60)
    hours, minutes = divmod(minutes, 60)  
    
    y_per_network_function = calculate_function_values_from_polynomial(per_network_function, x, force_complete_poly_representation=False)
    
    mae_model_interpretation_net_poly = mean_absolute_error(y_model_autoMPG, y_per_network_function)
    mae_data_interpretation_net_poly = mean_absolute_error(y, y_per_network_function)    
    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('Per Network Poly:')
    print_polynomial_from_coefficients(per_network_function)
    print('MAE Model: ', mae_model_interpretation_net_poly)
    print('MAE Data: ', mae_data_interpretation_net_poly)       
    print('Computation Time: ' +  f'{hours:d}:{minutes:02d}:{seconds:02d}')    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
# Out:
# Current best: 5.34072208404541
#  Curr_res: 5.327816963195801
#  Iteration 2, Step 499
# Optimization terminated at 5.121694087982178
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Per Network Poly:
# 9.88890552520752*a**1.0 + 1.54637122154236*a**2.0 - 4.03090953826904*a**3.0 - 4.8018856048584*a**4.0 - 5.23200559616089*a**5.0 + 11.0169439315796
# MAE Model:  8.058731209513825
# MAE Data:  11.254050677286433
# Computation Time: 0:00:39
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
if interpretation_possible_autoMPG:
    
    symbolic_regression_hyperparams = {
        'dataset_size': 500,
    }

    start = time.time() 
    
    symbolic_regression_function =  symbolic_regression(model_autoMPG, 
                                                      config,
                                                      symbolic_regression_hyperparams,
                                                      #printing = True,
                                                      return_error = False)
    
    end = time.time()     
    generation_time = (end - start) 
    minutes, seconds = divmod(int(generation_time), 60)
    hours, minutes = divmod(minutes, 60)        
    
    y_symbolic_regression_function = calculate_function_values_from_sympy(symbolic_regression_function, x)
    
    mae_model_symbolic_regression_function = mean_absolute_error(y_model_autoMPG, y_symbolic_regression_function)
    mae_data_symbolic_regression_function = mean_absolute_error(y, y_symbolic_regression_function)
    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('Symbolic Regression Poly:')    
    display(symbolic_regression_function)
    print('MAE Model: ', mae_model_symbolic_regression_function)
    print('MAE Data: ', mae_data_symbolic_regression_function)      
    print('Computation Time: ' +  f'{hours:d}:{minutes:02d}:{seconds:02d}')    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
# Out:
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0    48.81          15459.1       63           3.0601           2.6637      7.17m
#    1    34.21          658.138       63          1.98072          2.13261      4.42m
#    2    46.51          64.8364       35          1.30296          1.16111      4.92m
#    3    48.26          110.279       51         0.323227         0.346854      4.82m
#    4    59.92          65.3168       51         0.322101         0.356988      5.14m
#    5    59.70          59.9967       75         0.284662         0.262534      4.70m
#    6    57.69           64.949       67         0.140427           0.1229      4.28m
#    7    57.25          21.8808       37         0.144616         0.154336      4.00m
#    8    49.93          17.8229       67          0.13585         0.132816      3.50m
#    9    46.76          21.0458       43         0.132475         0.115445      3.03m
#   10    44.34          274.174       43         0.130886        0.0616902      2.73m
#   11    40.79          22.7213       43         0.122952         0.133096      2.27m
#   12    36.33          22.4101       43         0.118637         0.171932      1.89m
#   13    32.73          28.9679       37          0.11538           0.1203      1.54m
#   14    30.26          59.4514       39         0.118095         0.131494      1.25m
#   15    28.93          31.9794       39         0.116981         0.186834      1.03m
#   16    28.33          64.7358       29           0.1204         0.144776     43.77s
#   17    28.43          34.4946       31         0.115847        0.0967091     29.33s
#   18    28.01          38.3896       31         0.112032         0.131048     14.45s
#   19    27.21          33.7316       31         0.109713         0.151919      0.00s
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Symbolic Regression Poly:
# (-19.0008461538462*x**2 + 24.8138323324984*x + 5.43402859328731)/(1.0*x + 0.217)
# MAE Model:  0.46483672858601943
# MAE Data:  4.837689210467087
# Computation Time: 0:05:50
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
#%load_ext autoreload

# %%
#%autoreload 2
if interpretation_possible_autoMPG:
    metamodeling_hyperparams = {
        'num_iter': 500,
        'batch_size': None,
        'learning_rate': 0.01,        
        'dataset_size': 500,
    }
    
    start = time.time() 

    metamodel_function =  symbolic_metamodeling(model_autoMPG, 
                                              config,
                                              metamodeling_hyperparams,
                                              #printing = True,
                                              return_error = False,
                                              return_expression = 'approx', #'approx', #'exact',
                                              function_metamodeling = False,
                                              force_polynomial=False)
    
    end = time.time()     
    generation_time = (end - start) 
    minutes, seconds = divmod(int(generation_time), 60)
    hours, minutes = divmod(minutes, 60)        
    
    y_metamodel_function = calculate_function_values_from_sympy(metamodel_function, x)
    
    mae_model_metamodel_function = mean_absolute_error(y_model_autoMPG, y_metamodel_function)
    mae_data_metamodel_function = mean_absolute_error(y, y_metamodel_function)
    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('Metamodel Function:')    
    display(metamodel_function)
    print('MAE Model: ', mae_model_metamodel_function)
    print('MAE Data: ', mae_data_metamodel_function)      
    print('Computation Time: ' +  f'{hours:d}:{minutes:02d}:{seconds:02d}')    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
# Out:
# ---- Tuning the basis functions ----
#   0%|          | 0/1 [00:00<?, ?it/s]
# a, b, c 2 1 1
# a, b, c 1.516643929958524 1.1727381689735183 2.3182859210485844
# a, b, c 1.516643929958524 1.1727381689735183 2.3182859210485844
# ----  Optimizing the metamodel  ----
#   0%|          | 0/500 [00:00<?, ?it/s]
# a, b, c 1.0479299958414294 1.9017809404812656 3.237040330894737
# a, b, c -0.9617978543962555 29.904181871058306 37.444514437749206
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Metamodel Function:
# 1/(5.31405627009345e-95544151629986206900199158793404*exp(1.17517643783826e+33*X0**5 - 3.86739757927061e+33*X0**4 + 5.33213316652378e+33*X0**3 - 3.88735197609036e+33*X0**2 + 1.49767094476921e+33*X0) + 1)
# MAE Model:  21.51319878441947
# MAE Data:  24.157142857142855
# Computation Time: 0:00:09
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
if interpretation_possible_autoMPG and False:
    metamodeling_hyperparams = {
        'num_iter': 500,
        'batch_size': None,
        'learning_rate': 0.01,        
        'dataset_size': 500,
    }
    
    start = time.time() 

    metamodel_function_basic =  symbolic_metamodeling(model_autoMPG, 
                                              config,
                                              metamodeling_hyperparams,
                                              #printing = True,
                                              return_error = False,
                                              return_expression = 'approx', #'approx', #'exact',
                                              function_metamodeling = True,
                                              force_polynomial=False)
    
    end = time.time()     
    generation_time = (end - start) 
    minutes, seconds = divmod(int(generation_time), 60)
    hours, minutes = divmod(minutes, 60)        
    
    y_metamodel_function_basic = calculate_function_values_from_sympy(metamodel_function_basic, x)
    
    mae_metamodel_function_basic = mean_absolute_error(y_model_autoMPG, y_metamodel_function_basic)
    mae_metamodel_function_basic = mean_absolute_error(y, y_metamodel_function_basic)
    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('Metamodel Function Basic:')    
    display(metamodel_function_basic)
    print('MAE Model: ', mae_metamodel_function_basic)
    print('MAE Data: ', mae_metamodel_function_basic)      
    print('Computation Time: ' +  f'{hours:d}:{minutes:02d}:{seconds:02d}')    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')

# %%
if interpretation_possible_autoMPG:
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('Interpretation Net Poly:')
    print_polynomial_from_coefficients(interpretation_net_poly, force_complete_poly_representation=False)
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('Per Network Poly:')
    print_polynomial_from_coefficients(per_network_function, force_complete_poly_representation=False)
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('LSTSQ Poly:')
    print_polynomial_from_coefficients(polynomial_lstsq_pred_autoMPG, force_complete_poly_representation=True)
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('Symbolic Regression Function:')
    display(symbolic_regression_function)
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('Metamodel Function:')
    display(metamodel_function)
    #print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    #print('Metamodel Function Basic:')
    #display(metamodel_function_basic)
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Interpretation Net Poly:
# 17.6665458679199*a**1.0 + 7.83293771743774*a**2.0 + 3.05799341201782*a**3.0 + 0.956114888191223*a**4.0 - 2.75414347648621*a**5.0 + 5.60359859466553
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Per Network Poly:
# 9.88890552520752*a**1.0 + 1.54637122154236*a**2.0 - 4.03090953826904*a**3.0 - 4.8018856048584*a**4.0 - 5.23200559616089*a**5.0 + 11.0169439315796
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# LSTSQ Poly:
# -2.67124683707394*a**1.0 - 46.6576064003588*a**2.0 + 67.3430456399329*a**3.0 - 45.3238569230935*a**4.0 + 11.4290383584108*a**5.0 + 25.5953992872427
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Symbolic Regression Function:
# (-19.0008461538462*x**2 + 24.8138323324984*x + 5.43402859328731)/(1.0*x + 0.217)
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Metamodel Function:
# 1/(5.31405627009345e-95544151629986206900199158793404*exp(1.17517643783826e+33*X0**5 - 3.86739757927061e+33*X0**4 + 5.33213316652378e+33*X0**3 - 3.88735197609036e+33*X0**2 + 1.49767094476921e+33*X0) + 1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
if interpretation_possible_autoMPG:
    fig, ax = plt.subplots(1, 1, figsize=(20,10))
    
    plt.scatter(features_autoMPG_model['Horsepower'], labels_autoMPG, label='Data')
    plt.scatter(x, y, label='Test Data')
    plt.plot(np.sort(x, axis=0), np.array([y for _, y in sorted(zip(x, y_model_autoMPG))]) , label='Model Predictions')
    plt.plot(np.sort(x, axis=0), np.array([y for _, y in sorted(zip(x, y_interpretation_net_poly))]) , label='Interpretation Net Poly')
    plt.plot(np.sort(x, axis=0), np.array([y for _, y in sorted(zip(x, y_per_network_function))]) , label='Per Network Poly')
    plt.plot(np.sort(x, axis=0), np.array([y for _, y in sorted(zip(x, y_polynomial_lstsq_pred_autoMPG))]) , label='LSTSQ Poly')
    plt.plot(np.sort(x, axis=0), np.array([y for _, y in sorted(zip(x, y_symbolic_regression_function))]) , label='Symbolic Regression Function')
    plt.plot(np.sort(x, axis=0), np.array([y for _, y in sorted(zip(x, y_metamodel_function))]) , label='Metamodel Function')
    #plt.plot(np.sort(x, axis=0), np.array([y for _, y in sorted(zip(x, y))]) y_metamodel_function_basic, label='Metamodel Function Basic')
    plt.xlabel('Horsepower')
    plt.ylabel('MPG')
    plt.legend()

# %%
    #Plot Polynom, lamdba net, and Interpration net
    length_plt = len(plot_metric_list)
    if length_plt >= 2:
        fig, ax = plt.subplots(length_plt//2, 2, figsize=(30,20))
    else:
        fig, ax = plt.subplots(1, 1, figsize=(20,10))

    for index, metric in enumerate(plot_metric_list):
        
        plot_scores_dict = {}
        for key in evaluation_key_list:
            try:
                scores_list[-1][metric].loc[key]
                plot_scores_dict[key] = []
            except:
                #print(key + 'not in scores_list')
                continue
            
        
        for scores in scores_list:
            for key in evaluation_key_list:
                try:
                    plot_scores_dict[key].append(scores[metric].loc[key])
                except:
                    #print(key + 'not in scores_list')
                    continue
                                        
            
        plot_df = pd.DataFrame(data=np.vstack(plot_scores_dict.values()).T, 
                               index=x_axis_steps,
                               columns=plot_scores_dict.keys())

        if length_plt >= 2:
            ax[index//2, index%2].set_title(metric)
            sns.set(font_scale = 1.25)
            p = sns.lineplot(data=plot_df, ax=ax[index//2, index%2])
        else:
            ax.set_title(metric)
            sns.set(font_scale = 1.25)
            p = sns.lineplot(data=plot_df, ax=ax)

        if ylim != None:
            p.set(ylim=ylim)

        p.set_yticklabels(np.round(p.get_yticks(), 2), size = 20)
        p.set_xticklabels(p.get_xticks(), size = 20)     
        
        #p.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
        p.legend(loc='upper center', bbox_to_anchor=(0.47, -0.1),
          fancybox=False, shadow=False, ncol=2, fontsize=12)   
        
    plt.subplots_adjust(wspace=0.1, hspace=0.75)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-121-907b5cbea90a> in <module>
#       1 #Plot Polynom, lamdba net, and Interpration net
# ----> 2 length_plt = len(plot_metric_list)
#       3 if length_plt >= 2:
#       4     fig, ax = plt.subplots(length_plt//2, 2, figsize=(30,20))
#       5 else:
#
# NameError: name 'plot_metric_list' is not defined

# %% [markdown]
# # Evaluate Per-Network Poly Optimization

# %% [markdown]
# ## Example Optimization (Common Optimizer)

# %%
random_index = RANDOM_SEED

per_network_hyperparams = {
    'optimizer':  'Powell',
    'jac': 'fprime',
    'max_steps': 5000,#100,
    'restarts': 3,
    'per_network_dataset_size': 500,
}

lambda_net_test_dataset = lambda_net_test_dataset_list[-1]
lambda_network_weights_list = np.array(lambda_net_test_dataset.weight_list)
lambda_network_weights = lambda_network_weights_list[random_index]

list_of_monomial_identifiers_numbers = np.array([list(monomial_identifiers) for monomial_identifiers in list_of_monomial_identifiers]).astype(float)  

printing = True

config = {
         'n': n,
         'inet_loss': inet_loss,
         'sparsity': sparsity,
         'lambda_network_layers': lambda_network_layers,
         'interpretation_net_output_shape': interpretation_net_output_shape,
         'RANDOM_SEED': RANDOM_SEED,
         'nas': nas,
         'number_of_lambda_weights': number_of_lambda_weights,
         'interpretation_net_output_monomials': interpretation_net_output_monomials,
         'x_min': x_min,
         'x_max': x_max,
         }


per_network_optimization_error, per_network_optimization_polynomial = per_network_poly_optimization_scipy(per_network_hyperparams['per_network_dataset_size'], 
                                                                                                      lambda_network_weights, 
                                                                                                      list_of_monomial_identifiers_numbers, 
                                                                                                      config,
                                                                                                      optimizer = per_network_hyperparams['optimizer'],
                                                                                                      jac = per_network_hyperparams['jac'],
                                                                                                      max_steps = per_network_hyperparams['max_steps'], 
                                                                                                      restarts = per_network_hyperparams['restarts'],
                                                                                                      printing = True,
                                                                                                      return_error = True)

print('\n\nError: ' + str(per_network_optimization_error))
print_polynomial_from_coefficients(per_network_optimization_polynomial)

# %% [markdown]
# ## Example Optimization (Neural Optimizer)

# %%
random_index = RANDOM_SEED

per_network_hyperparams = {
    'optimizer': tf.keras.optimizers.RMSprop,
    'lr': 0.02,
    'max_steps': 500,
    'early_stopping': 10,
    'restarts': 3,
    'per_network_dataset_size': 5000,
}

lambda_net_test_dataset = lambda_net_test_dataset_list[-1]
lambda_network_weights_list = np.array(lambda_net_test_dataset.weight_list)
lambda_network_weights = lambda_network_weights_list[random_index]

list_of_monomial_identifiers_numbers = np.array([list(monomial_identifiers) for monomial_identifiers in list_of_monomial_identifiers]).astype(float)  

printing = True

config = {
         'n': n,
         'inet_loss': inet_loss,
         'sparsity': sparsity,
         'lambda_network_layers': lambda_network_layers,
         'interpretation_net_output_shape': interpretation_net_output_shape,
         'RANDOM_SEED': RANDOM_SEED,
         'nas': nas,
         'number_of_lambda_weights': number_of_lambda_weights,
         'interpretation_net_output_monomials': interpretation_net_output_monomials,
         'x_min': x_min,
         'x_max': x_max,
         }


per_network_optimization_error, per_network_optimization_polynomial = per_network_poly_optimization_tf(per_network_hyperparams['per_network_dataset_size'], 
                                                                                                      lambda_network_weights, 
                                                                                                      list_of_monomial_identifiers_numbers, 
                                                                                                      config,
                                                                                                      optimizer = per_network_hyperparams['optimizer'],
                                                                                                      lr = per_network_hyperparams['lr'], 
                                                                                                      max_steps = per_network_hyperparams['max_steps'], 
                                                                                                      early_stopping = per_network_hyperparams['early_stopping'], 
                                                                                                      restarts = per_network_hyperparams['restarts'],
                                                                                                      printing = True,
                                                                                                      return_error = True)

print('\n\nError: ' + str(per_network_optimization_error.numpy()))
print_polynomial_from_coefficients(per_network_optimization_polynomial)

# %% [markdown]
# ## Grid Search Common Optimizers

# %%
# %%script false --no-raise-error
#
# pd.set_option('max_colwidth', 100)
#
# evaluation_size = 10
#
# per_network_hyperparams = {
#     'optimizer':  [
#                    'Nelder-Mead',
#                    'Powell',
#
#                    'CG',
#                    'BFGS',
#                    'Newton-CG',
#                    #'L-BFGS-B', #'>' not supported between instances of 'int' and 'NoneType'
#                    'TNC',
#
#                    'COBYLA',
#                    'SLSQP',
#
#                    #'trust-constr', # TypeError: _minimize_trustregion_constr() got an unexpected keyword argument 'maxfun'
#                    #'dogleg', # ValueError: Hessian is required for dogleg minimization
#                    #'trust-ncg', #ValueError: Either the Hessian or the Hessian-vector product is required for Newton-CG trust-region minimization
#                    #'trust-exact', # ValueError: Hessian matrix is required for trust region exact minimization.
#                    #'trust-krylov' #ValueError: Either the Hessian or the Hessian-vector product is required for Krylov trust-region minimization
#                    ],
#     'jac': ['fprime'],
#     'max_steps': [5000],#100,
#     'restarts': [3],
#     'per_network_dataset_size': [500],
# }
#
# #param_iterator = ParameterSampler(per_network_hyperparams, n_iter=60, random_state=RANDOM_SEED)
# param_iterator = ParameterGrid(per_network_hyperparams)
#
#
# lambda_net_test_dataset = lambda_net_test_dataset_list[-1]
# lambda_network_weights_list = np.array(lambda_net_test_dataset.weight_list)
#
# list_of_monomial_identifiers_numbers = np.array([list(monomial_identifiers) for monomial_identifiers in list_of_monomial_identifiers]).astype(float)
# printing = True if n_jobs == 1 else False
#
# config = {
#          'n': n,
#          'inet_loss': inet_loss,
#          'sparsity': sparsity,
#          'lambda_network_layers': lambda_network_layers,
#          'interpretation_net_output_shape': interpretation_net_output_shape,
#          'RANDOM_SEED': RANDOM_SEED,
#          'nas': nas,
#          'number_of_lambda_weights': number_of_lambda_weights,
#          'interpretation_net_output_monomials': interpretation_net_output_monomials,
#          'x_min': x_min,
#          'x_max': x_max,
#          }

# %%
# %%script false --no-raise-error
#
# params_error_list = []
# for params in tqdm(param_iterator):
#     parallel_per_network = Parallel(n_jobs=n_jobs, verbose=0, backend='loky')
#
#     result_list = parallel_per_network(delayed(per_network_poly_optimization_scipy)(params['per_network_dataset_size'],
#                                                                                   lambda_network_weights,
#                                                                                   list_of_monomial_identifiers_numbers,
#                                                                                   config,
#                                                                                   optimizer = params['optimizer'],
#                                                                                   jac = params['jac'],
#                                                                                   max_steps = params['max_steps'],
#                                                                                   restarts = params['restarts'],
#                                                                                   printing = printing,
#                                                                                   return_error = True) for lambda_network_weights in lambda_network_weights_list[:evaluation_size])
#
#
#     per_network_optimization_errors = [result[0] for result in result_list]
#     per_network_optimization_polynomials = [result[1] for result in result_list]
#
#     params_score = np.mean(per_network_optimization_errors)
#
#     evaluation_result = list(params.values())
#     evaluation_result.append(params_score)
#
#     params_error_list.append(evaluation_result)
#
#     del parallel_per_network
#
# columns = list(params.keys())
# columns.append('score')
# params_error_df = pd.DataFrame(data=params_error_list, columns=columns).sort_values(by='score')
# params_error_df.head(10)

# %% [markdown]
# ## Grid Search Neural Optimizers

# %%
# %%script false --no-raise-error
#
# pd.set_option('max_colwidth', 100)
#
# evaluation_size = 100
#
# per_network_hyperparams = {
#     'optimizer': [tf.keras.optimizers.RMSprop], #[tf.keras.optimizers.SGD, tf.optimizers.Adam, tf.keras.optimizers.RMSprop, tf.keras.optimizers.Adadelta]
#     'lr': [0.02], #[0.5, 0.25, 0.1, 0.05, 0.025]
#     'max_steps': [5000],#100,
#     'early_stopping': [10],
#     'restarts': [3],
#     'per_network_dataset_size': [5000],
# }
#
# #param_iterator = ParameterSampler(per_network_hyperparams, n_iter=60, random_state=RANDOM_SEED)
# param_iterator = ParameterGrid(per_network_hyperparams)
#
#
# lambda_net_test_dataset = lambda_net_test_dataset_list[-1]
# lambda_network_weights_list = np.array(lambda_net_test_dataset.weight_list)
#
# list_of_monomial_identifiers_numbers = np.array([list(monomial_identifiers) for monomial_identifiers in list_of_monomial_identifiers]).astype(float)
# printing = True if n_jobs == 1 else False
#
# config = {
#          'n': n,
#          'inet_loss': inet_loss,
#          'sparsity': sparsity,
#          'lambda_network_layers': lambda_network_layers,
#          'interpretation_net_output_shape': interpretation_net_output_shape,
#          'RANDOM_SEED': RANDOM_SEED,
#          'nas': nas,
#          'number_of_lambda_weights': number_of_lambda_weights,
#          'interpretation_net_output_monomials': interpretation_net_output_monomials,
#          'x_min': x_min,
#          'x_max': x_max,
#          }

# %%
# %%script false --no-raise-error
#
# params_error_list = []
# for params in tqdm(param_iterator):
#     parallel_per_network = Parallel(n_jobs=n_jobs, verbose=0, backend='loky')
#
#     result_list = parallel_per_network(delayed(per_network_poly_optimization_tf)(params['per_network_dataset_size'],
#                                                                                   lambda_network_weights,
#                                                                                   list_of_monomial_identifiers_numbers,
#                                                                                   config,
#                                                                                   optimizer = params['optimizer'],
#                                                                                   lr = params['lr'],
#                                                                                   max_steps = params['max_steps'],
#                                                                                   early_stopping = params['early_stopping'],
#                                                                                   restarts = params['restarts'],
#                                                                                   printing = printing,
#                                                                                   return_error = True) for lambda_network_weights in lambda_network_weights_list[:evaluation_size])
#
#
#     per_network_optimization_errors = [result[0] for result in result_list]
#     per_network_optimization_polynomials = [result[1] for result in result_list]
#
#     params_score = np.mean(per_network_optimization_errors)
#
#     evaluation_result = list(params.values())
#     evaluation_result.append(params_score)
#
#     params_error_list.append(evaluation_result)
#
#     del parallel_per_network
#
# columns = list(params.keys())
# columns.append('score')
# params_error_df = pd.DataFrame(data=params_error_list, columns=columns).sort_values(by='score')
# params_error_df.head(10)

# %%
if use_gpu:
    from numba import cuda 
    device = cuda.get_current_device()
    device.reset()
