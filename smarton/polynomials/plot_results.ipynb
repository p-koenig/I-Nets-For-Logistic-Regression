# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

import seaborn as sns

sns.set_style("darkgrid")

# %%
lambda_net_results_d3_n5_noNoise = {'mae': 0.013, 'r2': 0.994, 'std_error': 0.017}
lambda_net_results_d3_n5_Noise01 = {'mae': 0, 'r2': 0, 'std_error': 0}
lambda_net_results_d3_n5_Noise02 = {'mae': 0, 'r2': 0, 'std_error': 0}
lambda_net_results_d3_n5_Noise03 = {'mae': 0, 'r2': 0, 'std_error': 0}

lambda_net_results_d3_n10_noNoise = {'mae': 0, 'r2': 0, 'std_error': 0}
lambda_net_results_d3_n10_Noise01 = {'mae': 0, 'r2': 0, 'std_error': 0}
lambda_net_results_d3_n10_Noise02 = {'mae': 0, 'r2': 0, 'std_error': 0}
lambda_net_results_d3_n10_Noise03 = {'mae': 0, 'r2': 0, 'std_error': 0}

lambda_net_results_d3_n15_noNoise = {'mae': 0.044, 'r2': 0.974, 'std_error': 0.058}
lambda_net_results_d3_n15_Noise01 = {'mae': 0, 'r2': 0, 'std_error': 0}
lambda_net_results_d3_n15_Noise02 = {'mae': 0, 'r2': 0, 'std_error': 0}
lambda_net_results_d3_n15_Noise03 = {'mae': 0, 'r2': 0, 'std_error': 0}

# %%
inet_results_d3_n5_noNoise = {'mae': 0.157	, 'r2': 0.272, 'std_error': 0.182}
inet_results_d3_n5_Noise01 = {'mae': 0, 'r2': 0, 'std_error': 0}
inet_results_d3_n5_Noise02 = {'mae': 0, 'r2': 0, 'std_error': 0}
inet_results_d3_n5_Noise03 = {'mae': 0, 'r2': 0, 'std_error': 0}

inet_results_d3_n10_noNoise = {'mae': 0, 'r2': 0, 'std_error': 0}
inet_results_d3_n10_Noise01 = {'mae': 0, 'r2': 0, 'std_error': 0}
inet_results_d3_n10_Noise02 = {'mae': 0, 'r2': 0, 'std_error': 0}
inet_results_d3_n10_Noise03 = {'mae': 0, 'r2': 0, 'std_error': 0}

inet_results_d3_n15_noNoise = {'mae': 0.281, 'r2': 0.106, 'std_error': 0.345}
inet_results_d3_n15_Noise01 = {'mae': 0, 'r2': 0, 'std_error': 0}
inet_results_d3_n15_Noise02 = {'mae': 0, 'r2': 0, 'std_error': 0}
inet_results_d3_n15_Noise03 = {'mae': 0, 'r2': 0, 'std_error': 0}

# %%
inet_results_single_lambda_net_d3_n5_noNoise = {'mae': np.array([0.10252578, 0.14451668, 0.15264297, 0.07767963, 0.14841956,
       0.15588711, 0.05226585, 0.11477606, 0.08484218, 0.2043573 ,
       0.06794029, 0.2659243 , 0.10765101, 0.10715321, 0.1647947 ,
       0.27530056, 0.14097553, 0.21068442, 0.04538986, 0.13520567,
       0.21440974, 0.10982154, 0.06397665, 0.1714468 , 0.11786942,
       0.10928094, 0.21333183, 0.1022973 , 0.10623601, 0.0383977 ,
       0.09235612, 0.25826928, 0.3804633 , 0.12462652, 0.1227455 ,
       0.11212344, 0.13908237, 0.13231389, 0.2195443 , 0.19172178,
       0.12560849, 0.08220954, 0.23527856, 0.13306883, 0.08495475,
       0.10542188, 0.16014057, 0.1977605 , 0.10345535, 0.083988  ,
       0.188542  , 0.22879077, 0.11898465, 0.20541783, 0.21198592,
       0.07621726, 0.16371967, 0.12982957, 0.08515473, 0.18552369,
       0.07596322, 0.26290688, 0.14634107, 0.09191569, 0.17699078,
       0.09398943, 0.18625806, 0.5103461 , 0.10103247, 0.13937826,
       0.39757985, 0.19104844, 0.14904277, 0.12354353, 0.14450353,
       0.11366496, 0.09715206, 0.67824537, 0.05665826, 0.19109793,
       0.2704291 , 0.23012628, 0.12608773, 0.3387441 , 0.07611302,
       0.16848275, 0.08236966, 0.09423167, 0.11907372, 0.16348422,
       0.24713098, 0.09483625, 0.2749454 , 0.07984723, 0.03873961,
       0.05769058, 0.19673376, 0.2374168 , 0.11761183, 0.09947504]), 
                               'r2': np.array([0.38957769,  0.60680387,  0.55008383,  0.87713644,  0.7351517 ,
        0.3971538 ,  0.82563442,  0.1616591 ,  0.50387131,  0.33778003,
        0.66175839, -2.88551228, -0.09735068,  0.59913598,  0.46531639,
       -0.13806416,  0.61519755,  0.45892524,  0.97298132,  0.4992514 ,
        0.19727821,  0.54873627,  0.6425559 ,  0.519271  ,  0.7336916 ,
        0.29769551, -0.38507362,  0.5291078 ,  0.15802346,  0.53227189,
        0.72590208,  0.12420054, -0.27626566,  0.43766568,  0.37750865,
        0.83338508,  0.62373601,  0.06212219,  0.19787384,  0.57722009,
        0.45111372,  0.67569277,  0.65392462,  0.59735894,  0.79710263,
        0.65701246,  0.61663105,  0.39870253,  0.45420565,  0.8415309 ,
        0.13301035,  0.11222754,  0.83235184,  0.60432513,  0.01684232,
        0.76801735,  0.64245767,  0.79016768,  0.45526282,  0.09102103,
        0.71253608,  0.06792019,  0.59160366,  0.44229696,  0.66899551,
        0.84390527,  0.67797813, -6.37910653,  0.38586386,  0.83914523,
       -2.46687371,  0.15708276,  0.63515134,  0.8015749 ,  0.4793249 ,
        0.67303335,  0.57239642, -2.90883002,  0.19874895,  0.23150325,
       -0.47309463,  0.64897293,  0.83578541, -0.02145079,  0.67689805,
        0.21730534,  0.11933657,  0.21931084,  0.37646945,  0.46154411,
        0.1961467 ,  0.5300923 , -1.06538861,  0.67278166,  0.90026431,
        0.45101054, -0.39178257,  0.55139348,  0.2904368 ,  0.20453433])}
inet_results_single_lambda_net_d3_n5_Noise01 = {'mae': np.array([]), 
                               'r2': np.array([])}
inet_results_single_lambda_net_d3_n5_Noise02 = {'mae': np.array([]), 
                               'r2': np.array([])}
inet_results_single_lambda_net_d3_n5_Noise03 = {'mae': np.array([]), 
                               'r2': np.array([])}

inet_results_single_lambda_net_d3_n10_noNoise = {'mae': np.array([]), 
                                'r2': np.array([])}
inet_results_single_lambda_net_d3_n10_Noise01 = {'mae': np.array([]), 
                               'r2': np.array([])}
inet_results_single_lambda_net_d3_n10_Noise02 = {'mae': np.array([]), 
                               'r2': np.array([])}
inet_results_single_lambda_net_d3_n10_Noise03 = {'mae': np.array([]), 
                               'r2': np.array([])}

inet_results_single_lambda_net_d3_n15_noNoise = {'mae': np.array([0.26332211, 0.19379157, 0.17225063, 0.29860172, 0.21067615,
       0.27698442, 0.34955668, 0.29933077, 0.32295138, 0.18172352,
       0.28912923, 0.23252207, 0.29960382, 0.32418454, 0.2784951 ,
       0.2634605 , 0.33466944, 0.1866637 , 0.28658575, 0.19653794,
       0.21173291, 0.27492696, 0.36799505, 0.2753122 , 0.37523788,
       0.24397232, 0.28927076, 0.2808597 , 0.34765992, 0.4239866 ,
       0.296928  , 0.338358  , 0.3450765 , 0.18379879, 0.48035493,
       0.31054744, 0.2549755 , 0.24602082, 0.31048104, 0.27321437,
       0.3241832 , 0.23510455, 0.15977705, 0.19136891, 0.3348276 ,
       0.2845684 , 0.30617467, 0.24030596, 0.2540486 , 0.18141286,
       0.34922332, 0.2955038 , 0.22759604, 0.26996768, 0.3507458 ,
       0.27481392, 0.2969538 , 0.284862  , 0.23813018, 0.30712712,
       0.3947652 , 0.3285979 , 0.25856444, 0.27749282, 0.19619912,
       0.38423893, 0.37575382, 0.24885869, 0.35698774, 0.34630525,
       0.23744853, 0.3480727 , 0.21598658, 0.17822249, 0.2670467 ,
       0.20751673, 0.35833788, 0.28226915, 0.28046596, 0.26401156,
       0.3015151 , 0.25126114, 0.2886254 , 0.28742614, 0.32452968,
       0.32272416, 0.30755958, 0.25255656, 0.21745087, 0.2519814 ,
       0.19735403, 0.33378458, 0.21328062, 0.24691555, 0.22632372,
       0.3028911 , 0.23045337, 0.3394522 , 0.3670812 , 0.20429529]), 
                               'r2': np.array([-0.18519573,  0.05514364,  0.49477321,  0.06235378,  0.02651586,
        0.22197761,  0.15476031,  0.22562324,  0.15973334,  0.0219766 ,
        0.12052263,  0.20778653,  0.08619041,  0.3521988 ,  0.14112647,
        0.13412089,  0.25056008, -0.07995394,  0.17123774,  0.21061184,
        0.0390501 ,  0.09523897,  0.13048522,  0.17079537,  0.13707365,
        0.10752153, -0.01515107, -0.11755069, -0.1247341 , -0.02104787,
        0.22483244,  0.06656775,  0.0613874 ,  0.02593725, -0.06878421,
       -0.02909714,  0.24466497,  0.21078888,  0.35922435, -0.08400884,
       -0.09561846,  0.1737635 ,  0.04442985,  0.3726553 ,  0.10630373,
        0.33575632,  0.14337832,  0.18020997,  0.01711664,  0.2466625 ,
        0.01036585,  0.16624314,  0.08880607,  0.02878846,  0.14882134,
        0.02685009,  0.1282028 ,  0.08719159,  0.11546837, -0.05938487,
        0.05157318,  0.09810981, -0.05095365, -0.05083018,  0.15856777,
        0.1143184 , -0.12997865,  0.45821389,  0.00175293,  0.20154059,
        0.32357597,  0.3189024 ,  0.23835131,  0.30468627, -0.02117692,
        0.16630496,  0.40270038, -0.08628906,  0.08069488, -0.03108786,
        0.0435271 ,  0.04451289,  0.0353272 , -0.46484867, -0.11290251,
       -0.11543732,  0.12436963,  0.20849895,  0.47632689,  0.23973467,
        0.28000916,  0.13264506,  0.06253249,  0.08332058,  0.34753916,
        0.14025823,  0.02193665, -0.02020378, -0.01871238,  0.06262195])}
inet_results_single_lambda_net_d3_n15_Noise01 = {'mae': np.array([]), 
                               'r2': np.array([])}
inet_results_single_lambda_net_d3_n15_Noise02 = {'mae': np.array([]), 
                               'r2': np.array([])}
inet_results_single_lambda_net_d3_n15_Noise03 = {'mae': np.array([]), 
                               'r2': np.array([])}

# %%
inet_train_time_d3_n5_noNoise = {'lambda_net_training': 78240, 'interpretation_net_training': 20040, 'application': 0}
inet_train_time_d3_n5_Noise01 = {'lambda_net_training': 0, 'interpretation_net_training': 0, 'application': 0}
inet_train_time_d3_n5_Noise02 = {'lambda_net_training': 0, 'interpretation_net_training': 0, 'application': 0}
inet_train_time_d3_n5_Noise03 = {'lambda_net_training': 0, 'interpretation_net_training': 0, 'application': 0}

inet_train_time_d3_n10_noNoise = {'lambda_net_training': 154560, 'interpretation_net_training': 0, 'application': 0}
inet_train_time_d3_n10_Noise01 = {'lambda_net_training': 0, 'interpretation_net_training': 0, 'application': 0}
inet_train_time_d3_n10_Noise02 = {'lambda_net_training': 0, 'interpretation_net_training': 0, 'application': 0}
inet_train_time_d3_n10_Noise03 = {'lambda_net_training': 0, 'interpretation_net_training': 0, 'application': 0}

inet_train_time_d3_n15_noNoise = {'lambda_net_training': 419220, 'interpretation_net_training': 18020, 'application': 0}
inet_train_time_d3_n15_Noise01 = {'lambda_net_training': 0, 'interpretation_net_training': 0, 'application': 0}
inet_train_time_d3_n15_Noise02 = {'lambda_net_training': 0, 'interpretation_net_training': 0, 'application': 0}
inet_train_time_d3_n15_Noise03 = {'lambda_net_training': 0, 'interpretation_net_training': 0, 'application': 0}

# %%
symbolic_regression_results_d3_n5_noNoise = {'mae': 0, 'r2': 0, 'std_error': 0}
symbolic_regression_results_d3_n5_Noise01 = {'mae': 0, 'r2': 0, 'std_error': 0}
symbolic_regression_results_d3_n5_Noise02 = {'mae': 0, 'r2': 0, 'std_error': 0}
symbolic_regression_results_d3_n5_Noise03 = {'mae': 0, 'r2': 0, 'std_error': 0}

symbolic_regression_results_d3_n10_noNoise = {'mae': 0, 'r2': 0, 'std_error': 0}
symbolic_regression_results_d3_n10_Noise01 = {'mae': 0, 'r2': 0, 'std_error': 0}
symbolic_regression_results_d3_n10_Noise02 = {'mae': 0, 'r2': 0, 'std_error': 0}
symbolic_regression_results_d3_n10_Noise03 = {'mae': 0, 'r2': 0, 'std_error': 0}

symbolic_regression_results_d3_n15_noNoise = {'mae': 0, 'r2': 0, 'std_error': 0}
symbolic_regression_results_d3_n15_Noise01 = {'mae': 0, 'r2': 0, 'std_error': 0}
symbolic_regression_results_d3_n15_Noise02 = {'mae': 0, 'r2': 0, 'std_error': 0}
symbolic_regression_results_d3_n15_Noise03 = {'mae': 0, 'r2': 0, 'std_error': 0}

# %%
symbolic_regression_results_single_lambda_net_d3_n5_noNoise = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_regression_results_single_lambda_net_d3_n5_Noise01 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_regression_results_single_lambda_net_d3_n5_Noise02 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_regression_results_single_lambda_net_d3_n5_Noise03 = {'mae': np.array([]), 
                                                   'r2': np.array([])}

symbolic_regression_results_single_lambda_net_d3_n10_noNoise = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_regression_results_single_lambda_net_d3_n10_Noise01 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_regression_results_single_lambda_net_d3_n10_Noise02 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_regression_results_single_lambda_net_d3_n10_Noise03 = {'mae': np.array([]), 
                                                   'r2': np.array([])}

symbolic_regression_results_single_lambda_net_d3_n15_noNoise = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_regression_results_single_lambda_net_d3_n15_Noise01 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_regression_results_single_lambda_net_d3_n15_Noise02 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_regression_results_single_lambda_net_d3_n15_Noise03 = {'mae': np.array([]), 
                                                   'r2': np.array([])}

# %%
#average time for a single network interpretation in seconds
symbolic_regression_train_time_d3_n5_noNoise = {'application': 135}
symbolic_regression_train_time_d3_n5_Noise01 = {'application': 182}
symbolic_regression_train_time_d3_n5_Noise02 = {'application': 0}
symbolic_regression_train_time_d3_n5_Noise03 = {'application': 134}

symbolic_regression_train_time_d3_n10_noNoise = {'application': 153}
symbolic_regression_train_time_d3_n10_Noise01 = {'application': 0}
symbolic_regression_train_time_d3_n10_Noise02 = {'application': 0}
symbolic_regression_train_time_d3_n10_Noise03 = {'application': 0}

symbolic_regression_train_time_d3_n15_noNoise = {'application': 0}
symbolic_regression_train_time_d3_n15_Noise01 = {'application': 0}
symbolic_regression_train_time_d3_n15_Noise02 = {'application': 0}
symbolic_regression_train_time_d3_n15_Noise03 = {'application': 0}

# %%
symbolic_metamodeling_results_d3_n5_noNoise = {'mae': 0, 'r2': 0, 'std_error': 0}
symbolic_metamodeling_results_d3_n5_Noise01 = {'mae': 0, 'r2': 0, 'std_error': 0}
symbolic_metamodeling_results_d3_n5_Noise02 = {'mae': 0, 'r2': 0, 'std_error': 0}
symbolic_metamodeling_results_d3_n5_Noise03 = {'mae': 0, 'r2': 0, 'std_error': 0}

symbolic_metamodeling_results_d3_n10_noNoise = {'mae': 0, 'r2': 0, 'std_error': 0}
symbolic_metamodeling_results_d3_n10_Noise01 = {'mae': 0, 'r2': 0, 'std_error': 0}
symbolic_metamodeling_results_d3_n10_Noise02 = {'mae': 0, 'r2': 0, 'std_error': 0}
symbolic_metamodeling_results_d3_n10_Noise03 = {'mae': 0, 'r2': 0, 'std_error': 0}

symbolic_metamodeling_results_d3_n15_noNoise = {'mae': 0, 'r2': 0, 'std_error': 0}
symbolic_metamodeling_results_d3_n15_Noise01 = {'mae': 0, 'r2': 0, 'std_error': 0}
symbolic_metamodeling_results_d3_n15_Noise02 = {'mae': 0, 'r2': 0, 'std_error': 0}
symbolic_metamodeling_results_d3_n15_Noise03 = {'mae': 0, 'r2': 0, 'std_error': 0}

# %%
symbolic_metamodeling_results_single_lambda_net_d3_n5_noNoise = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_metamodeling_results_single_lambda_net_d3_n5_Noise01 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_metamodeling_results_single_lambda_net_d3_n5_Noise02 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_metamodeling_results_single_lambda_net_d3_n5_Noise03 = {'mae': np.array([]), 
                                                   'r2': np.array([])}

symbolic_metamodeling_results_single_lambda_net_d3_n10_noNoise = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_metamodeling_results_single_lambda_net_d3_n10_Noise01 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_metamodeling_results_single_lambda_net_d3_n10_Noise02 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_metamodeling_results_single_lambda_net_d3_n10_Noise03 = {'mae': np.array([]), 
                                                   'r2': np.array([])}

symbolic_metamodeling_results_single_lambda_net_d3_n15_noNoise = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_metamodeling_results_single_lambda_net_d3_n15_Noise01 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_metamodeling_results_single_lambda_net_d3_n15_Noise02 = {'mae': np.array([]), 
                                                   'r2': np.array([])}
symbolic_metamodeling_results_single_lambda_net_d3_n15_Noise03 = {'mae': np.array([]), 
                                                   'r2': np.array([])}

# %%
#average time for a single network interpretation in seconds
symbolic_metamodeling_train_time_d3_n5_noNoise = {'application': 0}
symbolic_metamodeling_train_time_d3_n5_Noise01 = {'application': 0}
symbolic_metamodeling_train_time_d3_n5_Noise02 = {'application': 0}
symbolic_metamodeling_train_time_d3_n5_Noise03 = {'application': 0}

symbolic_metamodeling_train_time_d3_n10_noNoise = {'application': 0}
symbolic_metamodeling_train_time_d3_n10_Noise01 = {'application': 0}
symbolic_metamodeling_train_time_d3_n10_Noise02 = {'application': 0}
symbolic_metamodeling_train_time_d3_n10_Noise03 = {'application': 0}

symbolic_metamodeling_train_time_d3_n15_noNoise = {'application': 0}
symbolic_metamodeling_train_time_d3_n15_Noise01 = {'application': 0}
symbolic_metamodeling_train_time_d3_n15_Noise02 = {'application': 0}
symbolic_metamodeling_train_time_d3_n15_Noise03 = {'application': 0}

# %%
common_labels = ['Interpretation Network', 'Symbolic Regression', 'Symbolic Metamodeling']

evaluate_different_variable_numbers_labels = ['n=5', 'n=10', 'n=15']
evaluate_different_variable_numbers = [[inet_results_d3_n5_noNoise['mae'], symbolic_regression_results_d3_n5_noNoise['mae'], symbolic_metamodeling_results_d3_n5_noNoise['mae']], 
                                      [inet_results_d3_n10_noNoise['mae'], symbolic_regression_results_d3_n10_noNoise['mae'], symbolic_metamodeling_results_d3_n10_noNoise['mae']], 
                                      [inet_results_d3_n15_noNoise['mae'], symbolic_regression_results_d3_n15_noNoise['mae'], symbolic_metamodeling_results_d3_n15_noNoise['mae']]]
evaluate_different_variable_numbers_df = pd.DataFrame(evaluate_different_variable_numbers, columns=common_labels, index=evaluate_different_variable_numbers_labels)


evaluate_different_variable_numbers_runtime = [[inet_train_time_d3_n5_noNoise['application'], symbolic_regression_train_time_d3_n5_noNoise['application'], symbolic_metamodeling_train_time_d3_n5_noNoise['application']], 
                                      [inet_train_time_d3_n10_noNoise['application'], symbolic_regression_train_time_d3_n10_noNoise['application'], symbolic_metamodeling_train_time_d3_n10_noNoise['application']], 
                                      [inet_train_time_d3_n15_noNoise['application'], symbolic_regression_train_time_d3_n15_noNoise['application'], symbolic_metamodeling_train_time_d3_n15_noNoise['application']]]
evaluate_different_variable_numbers_runtime_df = pd.DataFrame(evaluate_different_variable_numbers_runtime, columns=common_labels, index=evaluate_different_variable_numbers_labels)
evaluate_different_variable_numbers_runtime_df = evaluate_different_variable_numbers_runtime_df[['Symbolic Regression', 'Symbolic Metamodeling']]


evaluate_different_variable_numbers_labels = ['noise=0', 'noise=0.1', 'noise=0.2', 'noise=0.3']
evaluate_noise_for_fixed_variable_number_n5 = [[inet_results_d3_n5_noNoise['mae'], symbolic_regression_results_d3_n5_noNoise['mae'], symbolic_metamodeling_results_d3_n5_noNoise['mae']],
                                            [inet_results_d3_n5_Noise01['mae'], symbolic_regression_results_d3_n5_Noise01['mae'], symbolic_metamodeling_results_d3_n5_Noise01['mae']],
                                            [inet_results_d3_n5_Noise02['mae'], symbolic_regression_results_d3_n5_Noise02['mae'], symbolic_metamodeling_results_d3_n5_Noise02['mae']],
                                            [inet_results_d3_n5_Noise03['mae'], symbolic_regression_results_d3_n5_Noise03['mae'], symbolic_metamodeling_results_d3_n5_Noise03['mae']]] 
evaluate_noise_for_fixed_variable_number_df_n5 = pd.DataFrame(evaluate_noise_for_fixed_variable_number_n5, columns=common_labels, index=evaluate_different_variable_numbers_labels)
#evaluate_noise_for_fixed_variable_number_df_n5 = evaluate_noise_for_fixed_variable_number_df_n5[['Interpretation Network']]

evaluate_noise_for_fixed_variable_number_n10 = [[inet_results_d3_n10_noNoise['mae'], symbolic_regression_results_d3_n10_noNoise['mae'], symbolic_metamodeling_results_d3_n10_noNoise['mae']],
                                            [inet_results_d3_n10_Noise01['mae'], symbolic_regression_results_d3_n10_Noise01['mae'], symbolic_metamodeling_results_d3_n10_Noise01['mae']],
                                            [inet_results_d3_n10_Noise02['mae'], symbolic_regression_results_d3_n10_Noise02['mae'], symbolic_metamodeling_results_d3_n10_Noise02['mae']],
                                            [inet_results_d3_n10_Noise03['mae'], symbolic_regression_results_d3_n10_Noise03['mae'], symbolic_metamodeling_results_d3_n10_Noise03['mae']]] 
evaluate_noise_for_fixed_variable_number_df_n10 = pd.DataFrame(evaluate_noise_for_fixed_variable_number_n10, columns=common_labels, index=evaluate_different_variable_numbers_labels)
#evaluate_noise_for_fixed_variable_number_df_n10 = evaluate_noise_for_fixed_variable_number_df_n10[['Interpretation Network']]


evaluate_noise_for_fixed_variable_number_n15 = [[inet_results_d3_n15_noNoise['mae'], symbolic_regression_results_d3_n15_noNoise['mae'], symbolic_metamodeling_results_d3_n15_noNoise['mae']],
                                            [inet_results_d3_n15_Noise01['mae'], symbolic_regression_results_d3_n15_Noise01['mae'], symbolic_metamodeling_results_d3_n15_Noise01['mae']],
                                            [inet_results_d3_n15_Noise02['mae'], symbolic_regression_results_d3_n15_Noise02['mae'], symbolic_metamodeling_results_d3_n15_Noise02['mae']],
                                            [inet_results_d3_n15_Noise03['mae'], symbolic_regression_results_d3_n15_Noise03['mae'], symbolic_metamodeling_results_d3_n15_Noise03['mae']]] 
evaluate_noise_for_fixed_variable_number_df_n15 = pd.DataFrame(evaluate_noise_for_fixed_variable_number_n15, columns=common_labels, index=evaluate_different_variable_numbers_labels)
#evaluate_noise_for_fixed_variable_number_df_n15 = evaluate_noise_for_fixed_variable_number_df_n15[['Interpretation Network']]



evaluate_noise_for_fixed_variable_number_columns = ['n=5', 'n=10', 'n=15']
evaluate_noise_for_fixed_variable_number = [[inet_results_d3_n5_noNoise['mae'], inet_results_d3_n10_noNoise['mae'], inet_results_d3_n15_noNoise['mae']],
                                            [inet_results_d3_n5_Noise01['mae'], inet_results_d3_n10_Noise01['mae'], inet_results_d3_n15_Noise01['mae']],
                                            [inet_results_d3_n5_Noise02['mae'], inet_results_d3_n10_Noise02['mae'], inet_results_d3_n15_Noise02['mae']],
                                            [inet_results_d3_n5_Noise03['mae'], inet_results_d3_n10_Noise03['mae'], inet_results_d3_n15_Noise03['mae']]] 
evaluate_noise_for_fixed_variable_number_df = pd.DataFrame(evaluate_noise_for_fixed_variable_number, columns=evaluate_noise_for_fixed_variable_number_columns, index=evaluate_different_variable_numbers_labels)



evaluate_different_variable_numbers_single_lambda_net_n5 = [inet_results_single_lambda_net_d3_n5_noNoise['mae'], symbolic_regression_results_single_lambda_net_d3_n5_noNoise['mae'], symbolic_metamodeling_results_single_lambda_net_d3_n5_noNoise['mae']]
evaluate_different_variable_numbers_single_lambda_net_filled_n5 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_n5).fillna(0).values.T
evaluate_different_variable_numbers_single_lambda_net_df_n5 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_filled_n5, columns=common_labels)

evaluate_different_variable_numbers_single_lambda_net_n10 = [inet_results_single_lambda_net_d3_n10_noNoise['mae'], symbolic_regression_results_single_lambda_net_d3_n10_noNoise['mae'], symbolic_metamodeling_results_single_lambda_net_d3_n10_noNoise['mae']] 
evaluate_different_variable_numbers_single_lambda_net_filled_n10 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_n10).fillna(0).values.T
evaluate_different_variable_numbers_single_lambda_net_df_n10 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_filled_n10, columns=common_labels)

evaluate_different_variable_numbers_single_lambda_net_n15 = [inet_results_single_lambda_net_d3_n15_noNoise['mae'], symbolic_regression_results_single_lambda_net_d3_n15_noNoise['mae'], symbolic_metamodeling_results_single_lambda_net_d3_n15_noNoise['mae']]
evaluate_different_variable_numbers_single_lambda_net_filled_n15 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_n15).fillna(0).values.T
evaluate_different_variable_numbers_single_lambda_net_df_n15 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_filled_n15, columns=common_labels)


evaluate_different_variable_numbers_single_lambda_net_diff_labels = ['Symbolic Regression - Interpretation Network', 'Symbolic Metamodeling - Interpretation Network']

evaluate_different_variable_numbers_single_lambda_net_diff_n5 = [inet_results_single_lambda_net_d3_n5_noNoise['mae'], symbolic_regression_results_single_lambda_net_d3_n5_noNoise['mae'], symbolic_metamodeling_results_single_lambda_net_d3_n5_noNoise['mae']]
evaluate_different_variable_numbers_single_lambda_net_filled_diff_n5 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_diff_n5).fillna(0).values.T
evaluate_different_variable_numbers_single_lambda_net_filled_diff_n5 = np.array([evaluate_different_variable_numbers_single_lambda_net_filled_diff_n5[:,1:2].ravel()-evaluate_different_variable_numbers_single_lambda_net_filled_diff_n5[:,:1].ravel(), evaluate_different_variable_numbers_single_lambda_net_filled_diff_n5[:,2:3].ravel()-evaluate_different_variable_numbers_single_lambda_net_filled_diff_n5[:,:1].ravel()]).T
evaluate_different_variable_numbers_single_lambda_net_diff_df_n5 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_filled_diff_n5, columns=evaluate_different_variable_numbers_single_lambda_net_diff_labels)

evaluate_different_variable_numbers_single_lambda_net_diff_n10 = [inet_results_single_lambda_net_d3_n10_noNoise['mae'], symbolic_regression_results_single_lambda_net_d3_n10_noNoise['mae'], symbolic_metamodeling_results_single_lambda_net_d3_n10_noNoise['mae']] 
evaluate_different_variable_numbers_single_lambda_net_filled_diff_n10 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_diff_n10).fillna(0).values.T
evaluate_different_variable_numbers_single_lambda_net_filled_diff_n10 = np.array([evaluate_different_variable_numbers_single_lambda_net_filled_diff_n10[:,1:2].ravel()-evaluate_different_variable_numbers_single_lambda_net_filled_diff_n10[:,:1].ravel(), evaluate_different_variable_numbers_single_lambda_net_filled_diff_n10[:,2:3].ravel()-evaluate_different_variable_numbers_single_lambda_net_filled_diff_n10[:,:1].ravel()]).T
evaluate_different_variable_numbers_single_lambda_net_diff_df_n10 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_filled_diff_n10, columns=evaluate_different_variable_numbers_single_lambda_net_diff_labels)
    
evaluate_different_variable_numbers_single_lambda_net_diff_n15 = [inet_results_single_lambda_net_d3_n15_noNoise['mae'], symbolic_regression_results_single_lambda_net_d3_n15_noNoise['mae'], symbolic_metamodeling_results_single_lambda_net_d3_n15_noNoise['mae']]
evaluate_different_variable_numbers_single_lambda_net_filled_diff_n15 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_diff_n15).fillna(0).values.T
evaluate_different_variable_numbers_single_lambda_net_filled_diff_n15 = np.array([evaluate_different_variable_numbers_single_lambda_net_filled_diff_n15[:,1:2].ravel()-evaluate_different_variable_numbers_single_lambda_net_filled_diff_n15[:,:1].ravel(), evaluate_different_variable_numbers_single_lambda_net_filled_diff_n15[:,2:3].ravel()-evaluate_different_variable_numbers_single_lambda_net_filled_diff_n15[:,:1].ravel()]).T
evaluate_different_variable_numbers_single_lambda_net_diff_df_n15 = pd.DataFrame(evaluate_different_variable_numbers_single_lambda_net_filled_diff_n15, columns=evaluate_different_variable_numbers_single_lambda_net_diff_labels)

# %%
evaluate_different_variable_numbers_df
# Out:
#       Interpretation Network  Symbolic Regression  Symbolic Metamodeling
# n=5                     0.14                0.103                      0
# n=10                    0.23                0.180                      0
# n=15                    0.00                0.000                      0

# %%
axes = evaluate_different_variable_numbers_df.plot.bar(color={common_labels[0]:'#c0d6ff', common_labels[1]:'#96bcff', common_labels[2]:'#6ca1ff'}, 
                                                       rot=0, 
                                                       figsize=(20,15), 
                                                       fontsize=20)

axes.legend(fontsize=20) # loc=2
axes.set_xlabel('Nuber of Variables', fontsize=25)
axes.set_ylabel('MAE', fontsize=25)
#plt.title('Performance Comparison', fontsize=30)

plt.savefig('./evaluation_results/performance_comparison.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_noise_for_fixed_variable_number_df
# Out:
#              n=5  n=10  n=15
# noise=0    0.140  0.23     0
# noise=0.1  0.146  0.00     0
# noise=0.2  0.000  0.00     0
# noise=0.3  0.152  0.00     0

# %%
axes = evaluate_noise_for_fixed_variable_number_df.plot.bar(color={evaluate_noise_for_fixed_variable_number_columns[0]:'#c0d6ff', evaluate_noise_for_fixed_variable_number_columns[1]:'#96bcff', evaluate_noise_for_fixed_variable_number_columns[2]:'#6ca1ff'}, 
                                                       rot=0, 
                                                       figsize=(20,15), 
                                                       fontsize=20)

axes.legend(fontsize=20) # loc=2
axes.set_xlabel('Noise Level', fontsize=25)
axes.set_ylabel('MAE', fontsize=25)
#plt.title('Performance Comparison', fontsize=30)

plt.savefig('./evaluation_results/noise_evaluation.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_noise_for_fixed_variable_number_df_n5
# Out:
#            Interpretation Network  Symbolic Regression  Symbolic Metamodeling
# noise=0                     0.140                0.103                      0
# noise=0.1                   0.146                0.104                      0
# noise=0.2                   0.000                0.000                      0
# noise=0.3                   0.152                0.107                      0

# %%
axes = evaluate_noise_for_fixed_variable_number_df_n5.plot.bar(color={common_labels[0]:'#c0d6ff', common_labels[1]:'#96bcff', common_labels[2]:'#6ca1ff'}, 
                                                               rot=0, 
                                                               figsize=(20,15), 
                                                               fontsize=20)

axes.legend(fontsize=20) # loc=2
axes.set_xlabel('Noise', fontsize=25)
axes.set_ylabel('MAE', fontsize=25)
#plt.title('Noise Evaluation n=5', fontsize=30)

plt.savefig('./evaluation_results/noise_evaluation_n5.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_noise_for_fixed_variable_number_df_n10
# Out:
#            Interpretation Network  Symbolic Regression  Symbolic Metamodeling
# noise=0                      0.23                 0.18                      0
# noise=0.1                    0.00                 0.00                      0
# noise=0.2                    0.00                 0.00                      0
# noise=0.3                    0.00                 0.00                      0

# %%
axes = evaluate_noise_for_fixed_variable_number_df_n10.plot.bar(color={common_labels[0]:'#c0d6ff', common_labels[1]:'#96bcff', common_labels[2]:'#6ca1ff'}, 
                                                                rot=0, 
                                                                figsize=(20,15), 
                                                                fontsize=20)

axes.legend(fontsize=20) # loc=2
axes.set_xlabel('Noise', fontsize=25)
axes.set_ylabel('MAE', fontsize=25)
#plt.title('Noise Evaluation n=10', fontsize=30)

plt.savefig('./evaluation_results/noise_evaluation_n10.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_noise_for_fixed_variable_number_df_n15
# Out:
#            Interpretation Network  Symbolic Regression  Symbolic Metamodeling
# noise=0                         0                    0                      0
# noise=0.1                       0                    0                      0
# noise=0.2                       0                    0                      0
# noise=0.3                       0                    0                      0

# %%
axes = evaluate_noise_for_fixed_variable_number_df_n15.plot.bar(color={common_labels[0]:'#c0d6ff', common_labels[1]:'#96bcff', common_labels[2]:'#6ca1ff'}, 
                                                                rot=0, 
                                                                figsize=(20,15), 
                                                                fontsize=20)

axes.legend(fontsize=20) # loc=2
axes.set_xlabel('Noise', fontsize=25)
axes.set_ylabel('MAE', fontsize=25)
#plt.title('Noise Evaluation n=15', fontsize=30)

plt.savefig('./evaluation_results/noise_evaluation_n15.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_different_variable_numbers_runtime_df
# Out:
#       Symbolic Regression  Symbolic Metamodeling
# n=5                   135                      0
# n=10                  153                      0
# n=15                    0                      0

# %%
axes = evaluate_different_variable_numbers_runtime_df.plot.line(color={common_labels[0]:'#c0d6ff', common_labels[1]:'#96bcff', common_labels[2]:'#6ca1ff'}, 
                                                                rot=0, 
                                                                figsize=(20,15), 
                                                                fontsize=20, 
                                                                linewidth=5)

axes.legend(fontsize=20) # loc=2
axes.set_xlabel('Nuber of Variables', fontsize=25)
axes.set_ylabel('Seconds per Interpretation', fontsize=25)
#plt.title('Runtime Evaluation', fontsize=30)

plt.savefig('./evaluation_results/runtime_evaluation.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_different_variable_numbers_single_lambda_net_df_n5
# Out:
# Empty DataFrame
# Columns: [Interpretation Network, Symbolic Regression, Symbolic Metamodeling]
# Index: []

# %%
axes = evaluate_different_variable_numbers_single_lambda_net_df_n5.plot.hist(bins=10, 
                                                                      alpha=0.5,
                                                                      color={common_labels[0]:'#c0d6ff', common_labels[1]:'#96bcff', common_labels[2]:'#6ca1ff'}, 
                                                                      rot=0, 
                                                                      figsize=(20,15), 
                                                                      fontsize=20, 
                                                                      linewidth=5)

axes.legend(fontsize=20) # loc=2
axes.set_xlabel('Error', fontsize=25)
axes.set_ylabel('Frequency', fontsize=25)
#plt.title('Runtime Evaluation', fontsize=30)

plt.savefig('./evaluation_results/error_hist_n5.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_different_variable_numbers_single_lambda_net_df_n10
# Out:
#     Interpretation Network  Symbolic Regression  Symbolic Metamodeling
# 0                 0.268203                  0.0                    0.0
# 1                 0.226721                  0.0                    0.0
# 2                 0.162909                  0.0                    0.0
# 3                 0.337378                  0.0                    0.0
# 4                 0.149075                  0.0                    0.0
# ..                     ...                  ...                    ...
# 95                0.227133                  0.0                    0.0
# 96                0.278359                  0.0                    0.0
# 97                0.213941                  0.0                    0.0
# 98                0.197566                  0.0                    0.0
# 99                0.178459                  0.0                    0.0
#
# [100 rows x 3 columns]

# %%
axes = evaluate_different_variable_numbers_single_lambda_net_df_n10.plot.hist(bins=10, 
                                                                      alpha=0.5,
                                                                      color={common_labels[0]:'#c0d6ff', common_labels[1]:'#96bcff', common_labels[2]:'#6ca1ff'}, 
                                                                      rot=0, 
                                                                      figsize=(20,15), 
                                                                      fontsize=20, 
                                                                      linewidth=5)

axes.legend(fontsize=20) # loc=2
axes.set_xlabel('Error', fontsize=25)
axes.set_ylabel('Frequency', fontsize=25)
#plt.title('Runtime Evaluation', fontsize=30)

plt.savefig('./evaluation_results/error_hist_n10.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_different_variable_numbers_single_lambda_net_df_n15
# Out:
# Empty DataFrame
# Columns: [Interpretation Network, Symbolic Regression, Symbolic Metamodeling]
# Index: []

# %%
axes = evaluate_different_variable_numbers_single_lambda_net_df_n15.plot.hist(bins=10, 
                                                                      alpha=0.5,
                                                                      color={common_labels[0]:'#c0d6ff', common_labels[1]:'#96bcff', common_labels[2]:'#6ca1ff'}, 
                                                                      rot=0, 
                                                                      figsize=(20,15), 
                                                                      fontsize=20, 
                                                                      linewidth=5)

axes.legend(fontsize=20) # loc=2
axes.set_xlabel('Error', fontsize=25)
axes.set_ylabel('Frequency', fontsize=25)
#plt.title('Runtime Evaluation', fontsize=30)

plt.savefig('./evaluation_results/error_hist_n15.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_different_variable_numbers_single_lambda_net_diff_df_n5
# Out:
# Empty DataFrame
# Columns: [Symbolic Regression - Interpretation Network, Symbolic Metamodeling - Interpretation Network]
# Index: []

# %%
axes = evaluate_different_variable_numbers_single_lambda_net_diff_df_n5.plot.hist(bins=10, 
                                                                      alpha=0.5,
                                                                      color={evaluate_different_variable_numbers_single_lambda_net_diff_labels[0]:'#c0d6ff', evaluate_different_variable_numbers_single_lambda_net_diff_labels[1]:'#96bcff'}, 
                                                                      rot=0, 
                                                                      figsize=(20,15), 
                                                                      fontsize=20, 
                                                                      linewidth=5)

axes.legend(fontsize=20) # loc=2
axes.set_xlabel('Error', fontsize=25)
axes.set_ylabel('Frequency', fontsize=25)
#plt.title('Runtime Evaluation', fontsize=30)

plt.savefig('./evaluation_results/error_diff_hist_n5.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_different_variable_numbers_single_lambda_net_diff_df_n10
# Out:
#     Symbolic Regression - Interpretation Network  \
# 0                                      -0.268203
# 1                                      -0.226721
# 2                                      -0.162909
# 3                                      -0.337378
# 4                                      -0.149075
# ..                                           ...
# 95                                     -0.227133
# 96                                     -0.278359
# 97                                     -0.213941
# 98                                     -0.197566
# 99                                     -0.178459
#
#     Symbolic Metamodeling - Interpretation Network
# 0                                        -0.268203
# 1                                        -0.226721
# 2                                        -0.162909
# 3                                        -0.337378
# 4                                        -0.149075
# ..                                             ...
# ...

# %%
axes = evaluate_different_variable_numbers_single_lambda_net_diff_df_n10.plot.hist(bins=10, 
                                                                      alpha=0.5,
                                                                      color={evaluate_different_variable_numbers_single_lambda_net_diff_labels[0]:'#c0d6ff', evaluate_different_variable_numbers_single_lambda_net_diff_labels[1]:'#96bcff'}, 
                                                                      rot=0, 
                                                                      figsize=(20,15), 
                                                                      fontsize=20, 
                                                                      linewidth=5)

axes.legend(fontsize=20) # loc=2
axes.set_xlabel('Error', fontsize=25)
axes.set_ylabel('Frequency', fontsize=25)
#plt.title('Runtime Evaluation', fontsize=30)

plt.savefig('./evaluation_results/error_diff_hist_n10.pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
evaluate_different_variable_numbers_single_lambda_net_diff_df_n15
# Out:
# Empty DataFrame
# Columns: [Symbolic Regression - Interpretation Network, Symbolic Metamodeling - Interpretation Network]
# Index: []

# %%
axes = evaluate_different_variable_numbers_single_lambda_net_diff_df_n15.plot.hist(bins=10, 
                                                                      alpha=0.5,
                                                                      color={evaluate_different_variable_numbers_single_lambda_net_diff_labels[0]:'#c0d6ff', evaluate_different_variable_numbers_single_lambda_net_diff_labels[1]:'#96bcff'}, 
                                                                      rot=0, 
                                                                      figsize=(20,15), 
                                                                      fontsize=20, 
                                                                      linewidth=5)

axes.legend(fontsize=20) # loc=2
axes.set_xlabel('Error', fontsize=25)
axes.set_ylabel('Frequency', fontsize=25)
#plt.title('Runtime Evaluation', fontsize=30)

plt.savefig('./evaluation_results/error_diff_hist_n15.pdf', bbox_inches = 'tight', pad_inches = 0)
