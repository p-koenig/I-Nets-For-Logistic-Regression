# %% [markdown]
# # Config & Imports

# %%
import numpy as np
from pathlib import Path
from sklearn.model_selection import train_test_split

import os
import tensorflow as tf
from tensorflow import keras
import keras.layers
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import BatchNormalization
from keras.layers import LeakyReLU
from keras.layers import ReLU
from keras.callbacks import EarlyStopping

from keras.regularizers import L1L2
from keras.regularizers import L2

import utilities_LR

from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()

import sys

# %%
config = {
    'data': {
        'n_datasets': 45_000, # the number of datasets
        
        'n_samples': 5_000, # the number of samples per dataset
        
        'n_features': 5, 
        # The total number of features. 
        # These comprise n_informative informative features, n_redundant redundant features, n_repeated duplicated features and 
        # n_features-n_informative-n_redundant-n_repeated useless features drawn at random.
        
        #'n_informative': random.randint(2, 10),
        'n_informative': 'random',
        # The number of informative features. Each class is composed of a number of gaussian clusters each located around the vertices 
        # of a hypercube in a subspace of dimension n_informative. For each cluster, informative features are drawn independently 
        # from N(0, 1) and then randomly linearly combined within each cluster in order to add covariance. The clusters are then 
        # placed on the vertices of the hypercube.
        ### int or 'random'
        
        'n_targets': 1,
        # The number of targets (or labels) of the classification problem.
    
        'n_clusters_per_class': 1,
        # The number of clusters per class.
        
        'class_sep': 1.0,
        # class_sepfloat, default=1.0
        # The factor multiplying the hypercube size. Larger values spread out the clusters/classes and make the classification task 
        # easier.
        
        'shuffle': True,
        # Shuffle the samples and the features.
        
        'random_state': 42,
        # Determines random number generation for dataset creation. Pass an int for reproducible output across multiple function calls.
    },
    'lambda': {
        'data_prep': {
            'train_test_val_split': { # refer to sklearn doc
                'test_size': 0.1,
                'val_size': 0.15,
                'random_state': None,
                'shuffle': False, # should be always false
                'stratify': None
            }
        },
        'model_compile': {
            'optimizer_lambda': 'adam',
            'loss': 'mae',# keras.losses.BinaryCrossentropy(from_logits=False), #tf.keras.losses.get(config['lambda_net']['loss_lambda']), # 'mae'
            'metrics': ['mae', keras.losses.BinaryCrossentropy(from_logits=False)]
        },
        'model_fit': { # refer to keras API
            'batch_size': 64,
            'epochs': 500,
            'verbose': 0,
            'callbacks': None,
            'shuffle': True, # usually true
            'class_weight': None,
            'sample_weight': None,
            'initial_epoch': 0,
            'steps_per_epoch': None,
            'validation_steps': None,
            'validation_batch_size': None,
            'validation_freq': 1
        }
    },
    'inets': {
        'data_prep': {
            'train_test_val_split': { # refer to sklearn doc
                'test_size': 0.1,
                'val_size': 0.15,
                'random_state': None,
                'shuffle': False,
                'stratify': None
            },
            'train_noise': 0.1 # y_flip fraction on Y_train pred data from lambda net
        },
        'model_compile': {
            
        },
        'model_fit': { # refer to keras API
            'batch_size': 256,
            'epochs': 1000,
            'verbose': 'auto',
            'callbacks': None,
            'shuffle': True,
            'class_weight': None,
            'sample_weight': None,
            'initial_epoch': 0,
            'steps_per_epoch': None,
            'validation_steps': None,
            'validation_batch_size': None,
            'validation_freq': 1
        }
    },
    'computation':{
        'n_jobs': 45,
        'use_gpu': True,
        'gpu_numbers': '4',
        'RANDOM_SEED': 1,   
    }
}

# %%
os.environ['CUDA_DEVICE_ORDER']='PCI_BUS_ID'

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

os.environ['CUDA_VISIBLE_DEVICES'] = config['computation']['gpu_numbers'] if config['computation']['use_gpu'] else ''
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true' if config['computation']['use_gpu'] else ''

os.environ['XLA_FLAGS'] = '--xla_gpu_cuda_data_dir=/usr/local/cuda-11.4' if config['computation']['use_gpu'] else ''#-10.1' #--xla_gpu_cuda_data_dir=/usr/local/cuda, 
os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2 ,--tf_xla_enable_xla_devices' if config['computation']['use_gpu'] else ''#'--tf_xla_auto_jit=2' #, --tf_xla_enable_xla_devices

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print("Num XLA-GPUs Available: ", len(tf.config.experimental.list_physical_devices('XLA_GPU')))
# Out:
# Num GPUs Available:  1
# Num XLA-GPUs Available:  0

# %% [markdown]
# # Functions

# %%
def load_lambda():
    directory = utilities_LR.lambda_path_LR(config)
    
    return np.load(directory + '/lambda_weights_list.npy', allow_pickle=True)

# %%
def get_X_data():
    directory = utilities_LR.data_path_LR(config)
    return np.load(directory + '/X.npy', allow_pickle=True)

# %%
def get_y_pred_data():
    directory = utilities_LR.lambda_path_LR(config)
    
    return np.load(directory + '/lambda_preds_list.npy', allow_pickle=True)
    #return np.load(directory + '/lambda_preds_list_with0.2_noise.npy', allow_pickle=True)

# %% [markdown]
# # Model Training

# %%
lambda_nets = load_lambda()

# %%
y_predictions = get_y_pred_data()

# %%
valid_feature_data = get_X_data()

# %%
y_predictions = y_predictions.round()

# %%
indexcol = np.array([np.arange(config['data']['n_datasets'], dtype=int)], ndmin=2).reshape(config['data']['n_datasets'], 1)
y_predictions = np.concatenate([indexcol, y_predictions], axis=1)

# %%
import pandas as pd

# %%
lambda_nets.shape
# Out:
# (45000, 371)

# %%
y_predictions.shape
# Out:
# (45000, 5001)

# %%
valid_feature_data = tf.convert_to_tensor(valid_feature_data, dtype=tf.float32)

# %% [markdown]
# # Custom Loss

# %%
@tf.function
def custom_loss(y_predictions_index, y_coef_pred):
    
    index = y_predictions_index[:, 0]
    y_true = y_predictions_index[:, 1:]
    
    # ADD NOISE TO TRAINING DATA
    noise = tf.cast(config['inets']['data_prep']['train_noise'], tf.float32)
    noise_logits = tf.tile([[1-noise, noise]], [tf.shape(y_true)[0], tf.constant(1)])
    noise_flip = tf.random.categorical(tf.math.log(noise_logits), y_true.shape[1])
    y_true = y_true*(1-noise_flip) + (1-y_true)*noise_flip   
    
    index = tf.cast(index, tf.int32)
    
    X_feature_data_samples = tf.gather(valid_feature_data, index)
    
    y_pred = tf.transpose(tf.math.add(tf.transpose(tf.linalg.matvec(X_feature_data_samples, y_coef_pred[:, 1:])), y_coef_pred[:, 0]))

    metric = tf.keras.losses.BinaryCrossentropy(
                                from_logits=True,
                                label_smoothing=0.0,
                                axis=-1,
                                reduction='auto',
                                name='binary_crossentropy')
    loss = metric(y_true, y_pred)
    return loss

# %%
# Data Prep

early_stopping = EarlyStopping(monitor='val_loss',
                                min_delta=0.001,
                                patience=45,
                                verbose=0,
                                mode='auto',
                                baseline=None,
                                restore_best_weights=True)


#reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1,
#                              patience=5, min_lr=0.0001)
#

#X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X,
#                                                                      y)

X_train, X_test, y_train, y_test = train_test_split(lambda_nets, 
                                                    y_predictions, 
                                                    test_size=config['inets']['data_prep']['train_test_val_split']['test_size'], 
                                                    random_state=config['inets']['data_prep']['train_test_val_split']['random_state'], 
                                                    shuffle=config['inets']['data_prep']['train_test_val_split']['shuffle'], 
                                                    stratify=config['inets']['data_prep']['train_test_val_split']['stratify'])




# Model Def
model = Sequential()
#model.add(BatchNormalization())
#regval = 0.0000000000001
#model.add(Dense(2056, activation='swish', kernel_regularizer=L2(regval), bias_regularizer= L2(regval), input_dim=X_train.shape[1]))
##model.add(keras.layers.Dropout(0.1))
#model.add(Dense(1028, activation='swish', kernel_regularizer=L2(regval), bias_regularizer= L2(regval)))
##model.add(keras.layers.Dropout(0.2))
#model.add(Dense(1028, activation='swish', kernel_regularizer=L2(regval), bias_regularizer= L2(regval)))
##model.add(keras.layers.Dropout(0.2))
#model.add(Dense(1028, activation='swish', kernel_regularizer=L2(regval), bias_regularizer=  L2(regval)))
##model.add(keras.layers.Dropout(0.1))

#model.add(Dense(10000, activation='ELU', input_dim=X_train.shape[1]))
##model.add(keras.layers.Dropout(0.3))
##model.add(Dense(4112, activation='relu'))
#model.add(Dense(10000, activation='ELU'))
#model.add(Dense(10000, activation='ELU'))
#model.add(Dense(10000, activation='ELU'))
#model.add(Dense(10000, activation='ELU'))
#model.add(Dense(10000, activation='ELU'))
#model.add(Dense(10000, activation='ELU'))

#model.add(Dense(1028, activation='LeakyReLU', kernel_regularizer=L2(regval), bias_regularizer= L2(regval), input_dim=X_train.shape[1]))
##model.add(keras.layers.Dropout(0.2))
#model.add(Dense(1028, activation='LeakyReLU', kernel_regularizer=L2(regval), bias_regularizer= L2(regval)))
##model.add(keras.layers.Dropout(0.2))
#model.add(Dense(2000, activation='LeakyReLU', kernel_regularizer=L2(regval), bias_regularizer=  L2(regval), input_dim=X_train.shape[1]))
#model.add(keras.layers.Dropout(0.1))


#model.add(Dense(4096, activation='swish'))
#model.add(Dense(2048, activation='swish'))
#model.add(keras.layers.Dropout(0))
model.add(Dense(2048, activation='swish'))
model.add(keras.layers.Dropout(0.5))

model.add(Dense(1024, activation='swish'))
model.add(keras.layers.Dropout(0.5))
model.add(Dense(512 , activation='swish'))
model.add(keras.layers.Dropout(0.5))

model.add(Dense(config['data']['n_features'] + 1, activation='linear'))

#lr = tf.keras.optimizers.schedules.CosineDecayRestarts(
#                                                        0.01,
#                                                        10,
#                                                        t_mul=2.0,
#                                                        m_mul=1.0,
#                                                        alpha=0.0,
#                                                        name=None
#)
#
#
#opt = tf.keras.optimizers.RMSprop(
#    #learning_rate=0.001,
#    learning_rate=lr,
#    rho=0.9,
#    momentum=0.0,
#    epsilon=1e-07,
#    centered=False,
#    name="RMSprop",
#)

opt = tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999, # 0.999
    epsilon=1e-08, # 1.0, 0.1, 0.01
    amsgrad=False,
    name='Adam',)

#opt = tf.keras.optimizers.SGD(
#    learning_rate=0.1, # 0.001
#    momentum=0.0,
#    nesterov=False,
#    name='SGD'
#)

model.compile(optimizer=opt, loss=custom_loss, metrics=[])
model.build(input_shape=X_train.shape)
model.summary()

# Model fit
history = model.fit(x=X_train,
                    y=y_train,
                    batch_size=config['inets']['model_fit']['batch_size'],
                    epochs=config['inets']['model_fit']['epochs'],
                    verbose=config['inets']['model_fit']['verbose'],
                    callbacks=[early_stopping],
                    validation_split=config['inets']['data_prep']['train_test_val_split']['val_size'],
                    shuffle=config['inets']['model_fit']['shuffle'],
                    class_weight=config['inets']['model_fit']['class_weight'],
                    sample_weight=config['inets']['model_fit']['sample_weight'],
                    initial_epoch=config['inets']['model_fit']['initial_epoch'],
                    steps_per_epoch=config['inets']['model_fit']['steps_per_epoch'],
                    validation_steps=config['inets']['model_fit']['validation_steps'],
                    validation_batch_size=config['inets']['model_fit']['validation_batch_size'],
                    validation_freq=config['inets']['model_fit']['validation_freq'],
                    workers=config['computation']['n_jobs'],
                    #use_multiprocessing=True
                   )
print(history.history['val_loss'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (40500, 2048)             761856
#
#  dropout (Dropout)           (40500, 2048)             0
#
#  dense_1 (Dense)             (40500, 1024)             2098176
#
#  dropout_1 (Dropout)         (40500, 1024)             0
#
#  dense_2 (Dense)             (40500, 512)              524800
#
#  dropout_2 (Dropout)         (40500, 512)              0
#
#  dense_3 (Dense)             (40500, 6)                3078
#
# =================================================================
# Total params: 3,387,910
# Trainable params: 3,387,910
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 135/135 [==============================] - 7s 14ms/step - loss: 0.7308 - val_loss: 0.6944
# Epoch 2/1000
# 135/135 [==============================] - 3s 22ms/step - loss: 0.7057 - val_loss: 0.6905
# Epoch 3/1000
# 135/135 [==============================] - 1s 7ms/step - loss: 0.6936 - val_loss: 0.6862
# Epoch 4/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.6843 - val_loss: 0.6770
# Epoch 5/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.6677 - val_loss: 0.6455
# Epoch 6/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.6322 - val_loss: 0.5850
# Epoch 7/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.5855 - val_loss: 0.5394
# Epoch 8/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.5527 - val_loss: 0.5175
# Epoch 9/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.5347 - val_loss: 0.5097
# Epoch 10/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.5238 - val_loss: 0.5023
# Epoch 11/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.5149 - val_loss: 0.5004
# Epoch 12/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.5093 - val_loss: 0.4954
# Epoch 13/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.5042 - val_loss: 0.4939
# Epoch 14/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.5006 - val_loss: 0.4922
# Epoch 15/1000
# 135/135 [==============================] - 1s 7ms/step - loss: 0.4963 - val_loss: 0.4894
# Epoch 16/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4939 - val_loss: 0.4892
# Epoch 17/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4912 - val_loss: 0.4856
# Epoch 18/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4887 - val_loss: 0.4877
# Epoch 19/1000
# 135/135 [==============================] - 1s 7ms/step - loss: 0.4873 - val_loss: 0.4844
# Epoch 20/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4853 - val_loss: 0.4833
# Epoch 21/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4835 - val_loss: 0.4834
# Epoch 22/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4823 - val_loss: 0.4817
# Epoch 23/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4810 - val_loss: 0.4806
# Epoch 24/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4793 - val_loss: 0.4799
# Epoch 25/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4793 - val_loss: 0.4791
# Epoch 26/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4779 - val_loss: 0.4787
# Epoch 27/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4764 - val_loss: 0.4788
# Epoch 28/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4758 - val_loss: 0.4779
# Epoch 29/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4750 - val_loss: 0.4773
# Epoch 30/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4738 - val_loss: 0.4765
# Epoch 31/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.4737 - val_loss: 0.4760
# Epoch 32/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.4729 - val_loss: 0.4760
# Epoch 33/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4723 - val_loss: 0.4754
# Epoch 34/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4720 - val_loss: 0.4745
# Epoch 35/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4708 - val_loss: 0.4739
# Epoch 36/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4706 - val_loss: 0.4719
# Epoch 37/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4695 - val_loss: 0.4709
# Epoch 38/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4688 - val_loss: 0.4699
# Epoch 39/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4689 - val_loss: 0.4693
# Epoch 40/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4683 - val_loss: 0.4682
# Epoch 41/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4673 - val_loss: 0.4674
# Epoch 42/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4670 - val_loss: 0.4666
# Epoch 43/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4662 - val_loss: 0.4659
# Epoch 44/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4656 - val_loss: 0.4641
# Epoch 45/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4651 - val_loss: 0.4643
# Epoch 46/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4643 - val_loss: 0.4632
# Epoch 47/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4645 - val_loss: 0.4627
# Epoch 48/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4637 - val_loss: 0.4611
# Epoch 49/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4630 - val_loss: 0.4597
# Epoch 50/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4618 - val_loss: 0.4595
# Epoch 51/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4616 - val_loss: 0.4588
# Epoch 52/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4611 - val_loss: 0.4579
# Epoch 53/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4603 - val_loss: 0.4569
# Epoch 54/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4599 - val_loss: 0.4567
# Epoch 55/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4598 - val_loss: 0.4561
# Epoch 56/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4591 - val_loss: 0.4555
# Epoch 57/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4588 - val_loss: 0.4553
# Epoch 58/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4586 - val_loss: 0.4552
# Epoch 59/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4578 - val_loss: 0.4557
# Epoch 60/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4577 - val_loss: 0.4535
# Epoch 61/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4570 - val_loss: 0.4540
# Epoch 62/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4573 - val_loss: 0.4541
# Epoch 63/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4566 - val_loss: 0.4526
# Epoch 64/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.4563 - val_loss: 0.4526
# Epoch 65/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4565 - val_loss: 0.4529
# Epoch 66/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4564 - val_loss: 0.4531
# Epoch 67/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4556 - val_loss: 0.4522
# Epoch 68/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4556 - val_loss: 0.4528
# Epoch 69/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4554 - val_loss: 0.4528
# Epoch 70/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4552 - val_loss: 0.4517
# Epoch 71/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4550 - val_loss: 0.4530
# Epoch 72/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4550 - val_loss: 0.4513
# Epoch 73/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.4548 - val_loss: 0.4518
# Epoch 74/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4547 - val_loss: 0.4516
# Epoch 75/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4547 - val_loss: 0.4521
# Epoch 76/1000
# 135/135 [==============================] - 1s 7ms/step - loss: 0.4543 - val_loss: 0.4509
# Epoch 77/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4539 - val_loss: 0.4506
# Epoch 78/1000
# 135/135 [==============================] - 1s 7ms/step - loss: 0.4539 - val_loss: 0.4503
# Epoch 79/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4536 - val_loss: 0.4512
# Epoch 80/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4537 - val_loss: 0.4506
# Epoch 81/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4539 - val_loss: 0.4503
# Epoch 82/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4535 - val_loss: 0.4507
# Epoch 83/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4534 - val_loss: 0.4517
# Epoch 84/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4533 - val_loss: 0.4506
# Epoch 85/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4532 - val_loss: 0.4516
# Epoch 86/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4525 - val_loss: 0.4513
# Epoch 87/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4526 - val_loss: 0.4503
# Epoch 88/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4524 - val_loss: 0.4507
# Epoch 89/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4526 - val_loss: 0.4511
# Epoch 90/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4525 - val_loss: 0.4497
# Epoch 91/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4522 - val_loss: 0.4501
# Epoch 92/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4521 - val_loss: 0.4494
# Epoch 93/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4522 - val_loss: 0.4498
# Epoch 94/1000
# 135/135 [==============================] - 1s 7ms/step - loss: 0.4523 - val_loss: 0.4497
# Epoch 95/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4520 - val_loss: 0.4501
# Epoch 96/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4516 - val_loss: 0.4506
# Epoch 97/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4514 - val_loss: 0.4492
# Epoch 98/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.4518 - val_loss: 0.4501
# Epoch 99/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.4516 - val_loss: 0.4494
# Epoch 100/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4514 - val_loss: 0.4492
# Epoch 101/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4512 - val_loss: 0.4493
# Epoch 102/1000
# 135/135 [==============================] - 1s 7ms/step - loss: 0.4509 - val_loss: 0.4496
# Epoch 103/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4509 - val_loss: 0.4492
# Epoch 104/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4506 - val_loss: 0.4480
# Epoch 105/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4507 - val_loss: 0.4490
# Epoch 106/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4507 - val_loss: 0.4499
# Epoch 107/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4507 - val_loss: 0.4486
# Epoch 108/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4503 - val_loss: 0.4483
# Epoch 109/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4504 - val_loss: 0.4484
# Epoch 110/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4504 - val_loss: 0.4485
# Epoch 111/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4500 - val_loss: 0.4487
# Epoch 112/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4506 - val_loss: 0.4491
# Epoch 113/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4501 - val_loss: 0.4492
# Epoch 114/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4503 - val_loss: 0.4483
# Epoch 115/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4497 - val_loss: 0.4487
# Epoch 116/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4498 - val_loss: 0.4478
# Epoch 117/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4495 - val_loss: 0.4490
# Epoch 118/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4495 - val_loss: 0.4488
# Epoch 119/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4495 - val_loss: 0.4476
# Epoch 120/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4494 - val_loss: 0.4483
# Epoch 121/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4492 - val_loss: 0.4482
# Epoch 122/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4492 - val_loss: 0.4482
# Epoch 123/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4490 - val_loss: 0.4485
# Epoch 124/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4491 - val_loss: 0.4482
# Epoch 125/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4489 - val_loss: 0.4476
# Epoch 126/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4486 - val_loss: 0.4485
# Epoch 127/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4486 - val_loss: 0.4480
# Epoch 128/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4485 - val_loss: 0.4479
# Epoch 129/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4485 - val_loss: 0.4477
# Epoch 130/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4482 - val_loss: 0.4478
# Epoch 131/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4483 - val_loss: 0.4483
# Epoch 132/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4483 - val_loss: 0.4477
# Epoch 133/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4481 - val_loss: 0.4474
# Epoch 134/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4482 - val_loss: 0.4469
# Epoch 135/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4480 - val_loss: 0.4479
# Epoch 136/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4481 - val_loss: 0.4480
# Epoch 137/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4482 - val_loss: 0.4472
# Epoch 138/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4475 - val_loss: 0.4475
# Epoch 139/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4476 - val_loss: 0.4477
# Epoch 140/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4476 - val_loss: 0.4478
# Epoch 141/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4474 - val_loss: 0.4471
# Epoch 142/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4475 - val_loss: 0.4471
# Epoch 143/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4472 - val_loss: 0.4476
# Epoch 144/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4471 - val_loss: 0.4480
# Epoch 145/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4473 - val_loss: 0.4475
# Epoch 146/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4475 - val_loss: 0.4474
# Epoch 147/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4472 - val_loss: 0.4467
# Epoch 148/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4472 - val_loss: 0.4470
# Epoch 149/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.4471 - val_loss: 0.4473
# Epoch 150/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4466 - val_loss: 0.4472
# Epoch 151/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4468 - val_loss: 0.4467
# Epoch 152/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4466 - val_loss: 0.4481
# Epoch 153/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4466 - val_loss: 0.4465
# Epoch 154/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4464 - val_loss: 0.4475
# Epoch 155/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.4466 - val_loss: 0.4470
# Epoch 156/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4465 - val_loss: 0.4473
# Epoch 157/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.4462 - val_loss: 0.4470
# Epoch 158/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4464 - val_loss: 0.4465
# Epoch 159/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.4460 - val_loss: 0.4474
# Epoch 160/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4463 - val_loss: 0.4463
# Epoch 161/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4463 - val_loss: 0.4467
# Epoch 162/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.4458 - val_loss: 0.4460
# Epoch 163/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4456 - val_loss: 0.4474
# Epoch 164/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4455 - val_loss: 0.4473
# Epoch 165/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4455 - val_loss: 0.4466
# Epoch 166/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.4456 - val_loss: 0.4462
# Epoch 167/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.4457 - val_loss: 0.4464
# Epoch 168/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4455 - val_loss: 0.4465
# Epoch 169/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.4455 - val_loss: 0.4467
# Epoch 170/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.4454 - val_loss: 0.4464
# Epoch 171/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4454 - val_loss: 0.4462
# Epoch 172/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.4452 - val_loss: 0.4464
# Epoch 173/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.4452 - val_loss: 0.4465
# Epoch 174/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.4454 - val_loss: 0.4468
# Epoch 175/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.4454 - val_loss: 0.4472
# Epoch 176/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4453 - val_loss: 0.4459
# Epoch 177/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4452 - val_loss: 0.4463
# Epoch 178/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4450 - val_loss: 0.4464
# Epoch 179/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.4452 - val_loss: 0.4472
# [0.6943767666816711, 0.6905212998390198, 0.6862243413925171, 0.6770437359809875, 0.6455368399620056, 0.5849831700325012, 0.5393773913383484, 0.5174532532691956, 0.5096912980079651, 0.5022634267807007, 0.5004130005836487, 0.49540597200393677, 0.49393928050994873, 0.4921550750732422, 0.4893852770328522, 0.48916298151016235, 0.485584020614624, 0.48771923780441284, 0.4844413101673126, 0.4833306074142456, 0.48338091373443604, 0.4817390739917755, 0.4806252717971802, 0.4798678159713745, 0.4791076183319092, 0.4786853790283203, 0.4787937104701996, 0.47787076234817505, 0.4773109555244446, 0.47654080390930176, 0.47595563530921936, 0.47600656747817993, 0.4754244089126587, 0.4744551479816437, 0.4739106297492981, 0.4718819856643677, 0.4708913564682007, 0.46986645460128784, 0.46928203105926514, 0.46818384528160095, 0.46736660599708557, 0.4665983021259308, 0.4659108817577362, 0.46414870023727417, 0.46428027749061584, 0.46319690346717834, 0.4626648426055908, 0.4611276686191559, 0.4596904218196869, 0.4595177471637726, 0.4588397443294525, 0.4579027593135834, 0.4568633437156677, 0.4566720128059387, 0.4561452567577362, 0.45551079511642456, 0.45528286695480347, 0.4552247226238251, 0.4556581676006317, 0.4534502923488617, 0.4539603292942047, 0.45412570238113403, 0.45259740948677063, 0.45256033539772034, 0.45291730761528015, 0.45307692885398865, 0.4522256851196289, 0.45280778408050537, 0.4527634382247925, 0.4516662359237671, 0.45296594500541687, 0.45131468772888184, 0.45181792974472046, 0.4516056180000305, 0.45209065079689026, 0.45092809200286865, 0.45064061880111694, 0.45033547282218933, 0.4512117803096771, 0.45063677430152893, 0.45026540756225586, 0.45067864656448364, 0.4517170190811157, 0.4506266415119171, 0.4515562355518341, 0.4513382911682129, 0.45032259821891785, 0.450737327337265, 0.45112305879592896, 0.4496849775314331, 0.45007550716400146, 0.44940581917762756, 0.4498118460178375, 0.4497385025024414, 0.4501292109489441, 0.45058318972587585, 0.44918638467788696, 0.4500931203365326, 0.44940751791000366, 0.4492419362068176, 0.44930869340896606, 0.4495769441127777, 0.4491943120956421, 0.4480270743370056, 0.4490329325199127, 0.4498542249202728, 0.44859516620635986, 0.4483017921447754, 0.44836077094078064, 0.44852113723754883, 0.44871431589126587, 0.4490847587585449, 0.4491640627384186, 0.4482574164867401, 0.44865214824676514, 0.4478178322315216, 0.449032723903656, 0.4487987756729126, 0.4476431906223297, 0.44833606481552124, 0.4481521546840668, 0.44820594787597656, 0.44853946566581726, 0.4481732249259949, 0.4475773870944977, 0.44852450489997864, 0.4480186104774475, 0.4479493796825409, 0.44768932461738586, 0.4478417634963989, 0.44831976294517517, 0.44768965244293213, 0.44740402698516846, 0.44687148928642273, 0.4478617310523987, 0.4479774236679077, 0.4472014307975769, 0.4475288987159729, 0.44771793484687805, 0.44776731729507446, 0.44706907868385315, 0.4471394419670105, 0.4476442039012909, 0.4479743242263794, 0.44747838377952576, 0.4473802447319031, 0.4467237591743469, 0.44701895117759705, 0.44726839661598206, 0.44721904397010803, 0.4467206299304962, 0.44807958602905273, 0.4465230703353882, 0.44748616218566895, 0.446991503238678, 0.44726675748825073, 0.446990430355072, 0.4465394616127014, 0.4473825991153717, 0.446268230676651, 0.446731835603714, 0.4460490345954895, 0.4473699629306793, 0.44725221395492554, 0.44656434655189514, 0.4461970627307892, 0.44639623165130615, 0.446544885635376, 0.4467000961303711, 0.4464494585990906, 0.4461827576160431, 0.44639715552330017, 0.44650787115097046, 0.4467935860157013, 0.4472050666809082, 0.4459202289581299, 0.4463004767894745, 0.4463670253753662, 0.4472295641899109]

# %%
def save_model(model):
    path = utilities_LR.inet_path_LR(config)
    
    Path(path).mkdir(parents=True, exist_ok=True)
    model.save(path + '/modelKeras' + '.h5')

# %%
save_model(model)

# %%
def save_testData(X_test, y_test):
    path = utilities_LR.inet_path_LR(config)
    
    Path(path).mkdir(parents=True, exist_ok=True)
    np.save(path + '/X_test', X_test)
    
    np.save(path + '/y_test', y_test)

# %%
save_testData(X_test, y_test)
