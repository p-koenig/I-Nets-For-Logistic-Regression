# %% [markdown]
# # Symbolic Metamodeling of Univariate Functions using Meijer $G$-functions
#
# In this notebook, we carry out the first experiment (Section 5.1) in our paper *"Demystifying Black-box Models with Symbolic Metamodels"* submitted to **NeurIPS 2019** by *Ahmed M. Alaa and Mihaela van der Schaar*. In this experiment, we demonstrate the first use case of symbolic metamodeling using synthetic data, where we show how can we learn symbolic expressions for unobserved black-box functions for which we have only query access.

# %% [markdown]
# ## Can we learn complex symbolic expressions?

# %% [markdown]
# We start off with four synthetic experiments with the aim of evaluating the richness of symbolic expressions discovered by our metamodeling algorithm. In each experiment, we apply our Meijer $G$-function-based symbolic metamodeling on a ground-truth univariate function $f(x)$ to fit a metamodel $g(x) \approx f(x)$, and compare the resulting mathematical expression for $g(x)$ with that obtained by Symbolic regression [1-3], which we implement using the [**gplearn library** ](https://gplearn.readthedocs.io/en/stable/).

# %% [markdown]
# We use the following four expressions for the underlying univariate functions:

# %% [markdown]
# | **Function** | **Notation** | **Expression**   |
# |------|------|------|
# |   Exponential function  | $f_1(x)$ | $e^{-3x}$ |
# |   Rational function  | $f_2(x)$| $\frac{x}{(x+1)^2}$ |
# |   Sinusoid function  | $f_3(x)$| $\sin(x)$ |
# |   Bessel function  | $f_4(x)$| $J_0\left(10\sqrt{x}\right)$ |

# %% [markdown]
# As we can see, the functions $f_1(x)$, $f_2(x)$, $f_3(x)$ and $f_4(x)$ have very different functional forms and are of varying levels of complexity. To run the experiments, we first import the univariate functions above from the **benchmarks.univariate_functions** module in **pysymbolic** as follows:

# %%
from pysymbolic.benchmarks.univariate_functions import *

# %% [markdown]
# Then, we create a list of the univariate functions $f_1(x)$, $f_2(x)$, $f_3(x)$ and $f_4(x)$ as follows:

# %%
True_functions  = [('Exponential function exp(-3x)', exponential_function), ('Rational function x/(x+1)^2', rational_function), 
                   ('Sinusoid function sin(x)', sinusoidal_function), ('Bessel function J_0(10*sqrt(x))', bessel_function)]

# %% [markdown]
# Before running the experimens, let us visualize the four functions in the range $x \in [0,1]$ to see how different they are, and the extent to which their complexity vary from one function to another.

# %%
import numpy as np

from matplotlib import pyplot as plt
get_ipython().magic('matplotlib inline')

x_points = np.linspace(0,1,100)

fig, axs = plt.subplots(1, 4, figsize=(20,2.5))

axs[0].plot(x_points, True_functions[0][1](x_points), linewidth=4)
axs[0].set_title('$f_1(x)$')
axs[1].plot(x_points, True_functions[1][1](x_points), linewidth=4)
axs[1].set_title('$f_2(x)$')
axs[2].plot(x_points, True_functions[2][1](x_points), linewidth=4)
axs[2].set_title('$f_3(x)$')
axs[3].plot(x_points, True_functions[3][1](x_points), linewidth=4)
axs[3].set_title('$f_4(x)$')

for ax in axs.flat:
    ax.set(xlabel='$x$', ylabel='$f(x)$')

for ax in axs.flat:
    ax.label_outer()

# %% [markdown]
# As we can see, the Bessel function is the most complex. So will our symbolic metamodeling algorithm be able top recover the underlying mathematical expression describing these function and recognizing their varying levels of complexity?

# %% [markdown]
# ## Running the experiments

# %% [markdown]
# Now we set up the experiment by first setting the number of evaluation points (npoints=100) that we will input to both the symbolic metamodeling and the symbolic regression models, and creating an empty list of learned symbolic expressions and $R^2$ scores.

# %%
npoints             = 100
xrange              = [0.01, 1]

symbolic_metamodels = []
symbolic_regssion   = []

sym_metamodel_R2    = []
sym_regression_R2   = []

# %% [markdown]
# Before running the experiments, we first import the **algorithms.symbolic_expressions** from **pysymbolic**. This module contains two functions **get_symbolic_model** and **symbolic_regressor**, which recovers univariate metamodels and symbolic regression models respectively.

# %%
from mpmath import *
from sympy import *

from pysymbolic.algorithms.symbolic_expressions import *

# %% [markdown]
# Now we run the experiments by feeding in each function in **true_function** to both the functions **get_symbolic_model** and **symbolic_regressor**:

# %%
for true_function in True_functions:
    
    print('Now working on the ' + true_function[0])
    print('--------------------------------------------------------')
    print('--------------------------------------------------------')
    
    symbolic_model, _mod_R2 = get_symbolic_model(true_function[1], npoints, xrange)
    
    symbolic_metamodels.append(symbolic_model)
    sym_metamodel_R2.append(_mod_R2)
    
    symbolic_reg, _reg_R2   = symbolic_regressor(true_function[1], npoints, xrange)
    
    symbolic_regssion.append(symbolic_reg)
    sym_regression_R2.append(_reg_R2) 
    
    print('--------------------------------------------------------')
# Out:
# Now working on the Exponential function exp(-3x)
# --------------------------------------------------------
# --------------------------------------------------------
# Expression: 1.0*x**1.0*exp(-1.0*x)
# Loss: 0.12910507935488647
# Expression: 1.0*x**1.00000001490116*exp(-1.0*x)
# Loss: 0.129105080025377
# Expression: 1.00000001490116*x**1.0*exp(-1.00000001490116*x)
# Loss: 0.12910507918478836
# Expression: 1.0*x**1.0*exp(-1.0*x)
# Loss: 0.12910507935488647
# Expression: 1.01089867003132*x**0.955004142597318*exp(-1.0114150904119*x)
# Loss: 0.12685323562651737
# Expression: 1.01089867003132*x**0.955004142597318*exp(-1.0114150904119*x)
# Loss: 0.12685323562651737
# Expression: 1.0108986702023*x**0.955004157498479*exp(-1.0114150904119*x)
# Loss: 0.1268532363500405
# Expression: 1.01089868425472*x**0.955004142597318*exp(-1.01141510531306*x)
# Loss: 0.12685323541009175
# Expression: 1.04395706961156*x**0.775020712986588*exp(-1.05707545205951*x)
# Loss: 0.11573880599108886
# Expression: 1.04395706961156*x**0.775020712986588*exp(-1.05707545205951*x)
# Loss: 0.11573880599108886
# Expression: 1.04395707047502*x**0.77502072788775*exp(-1.05707545205951*x)
# Loss: 0.11573880695580373
# Expression: 1.04395708101695*x**0.775020712986588*exp(-1.05707546696067*x)
# Loss: 0.1157388055726235
# Expression: 1.01190759882027*x**0.0550869945436716*exp(-1.23971689864993*x)
# Loss: 0.06299772759656244
# Expression: 1.01190759882027*x**0.0550869945436716*exp(-1.23971689864993*x)
# Loss: 0.06299772759656244
# Expression: 1.0119076020604*x**0.0550870094448328*exp(-1.23971689864993*x)
# Loss: 0.06299772611984321
# Expression: 1.01190759949029*x**0.0550869945436716*exp(-1.23971691355109*x)
# Loss: 0.06299772597072556
# Expression: 1.05905511401511*x**0.413937972971719*exp(-1.14867926541858*x)
# Loss: 0.08300258204742068
# Expression: 1.05905511401511*x**0.413937972971719*exp(-1.14867926541858*x)
# Loss: 8.994515557546208e-16
# Expression: 1.00000000629998*x**1.0*hyper((2.0, 2.0), (1.99999998509884,), 1.0*x*exp_polar(I*pi))
# Loss: 9.141454972461101e-16
# Expression: 0.999999985098839/(x*(1 + 0.999999985098839/x)**2)
# Loss: 9.259103164904267e-16
# Expression: 1.0/(x*(1 + 1.0/x)**2)
# Loss: 9.199671832399667e-16
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 0
#          Function evaluations: 7
#          Gradient evaluations: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0    48.81           4145.8        7        0.0240575        0.0365675      3.70m
#    1    11.16           5.6349        7        0.0235343        0.0248796      1.64m
#    2     6.57          1.01578        9        0.0131061        0.0125311      1.44m
#    3     3.59         0.566502       15       0.00796443        0.0086243      1.31m
# --------------------------------------------------------
# Now working on the Sinusoid function sin(x)
# --------------------------------------------------------
# --------------------------------------------------------
# Expression: 1.0*x**1.0*exp(-1.0*x)
# Loss: 0.06172434509293938
# Expression: 1.0*x**1.00000001490116*exp(-1.0*x)
# Loss: 0.06172434574968129
# Expression: 1.00000001490116*x**1.0*exp(-1.00000001490116*x)
# Loss: 0.06172434459427152
# Expression: 1.0*x**1.0*exp(-1.0*x)
# Loss: 0.06172434509293938
# Expression: 1.0319668010266*x**0.955926796421409*exp(-1.03346503339708*x)
# Loss: 0.059012814032295705
# Expression: 1.0319668010266*x**0.955926796421409*exp(-1.03346503339708*x)
# Loss: 0.059012814032295705
# Expression: 1.03196680153279*x**0.95592681132257*exp(-1.03346503339708*x)
# Loss: 0.05901281458122756
# Expression: 1.03196681525037*x**0.955926796421409*exp(-1.03346504829824*x)
# Loss: 0.059012813703896716
# Expression: 1.11692817176879*x**0.80644165556936*exp(-1.14696994851087*x)
# Loss: 0.05502147896278215
# Expression: 1.11692817176879*x**0.80644165556936*exp(-1.14696994851087*x)
# Loss: 0.05502147896278215
# Expression: 1.11692817405101*x**0.806441670470521*exp(-1.14696994851087*x)
# Loss: 0.055021479092123196
# Expression: 1.11692818347095*x**0.80644165556936*exp(-1.14696996341203*x)
# Loss: 0.05502147913804035
# Expression: 1.10791068173536*x**0.794527660191582*exp(-1.13766421374907*x)
# Loss: 0.054805294642733475
# Expression: 1.10791068173536*x**0.794527660191582*exp(-1.13766421374907*x)
# Loss: 0.054805294642733475
# Expression: 1.10791068386467*x**0.794527675092743*exp(-1.13766421374907*x)
# Loss: 0.05480529477072415
# Expression: 1.10791069326511*x**0.794527660191582*exp(-1.13766422865023*x)
# Loss: 0.05480529482954311
# Expression: 1.0741009950948*x**0.746871678680471*exp(-1.10044127470186*x)
# Loss: 0.05387128528750321
# Expression: 1.0741009950948*x**0.746871678680471*exp(-1.10044127470186*x)
# Loss: 0.05387128528750321
# Expression: 1.07410099662669*x**0.746871693581632*exp(-1.10044127470186*x)
# Loss: 0.05387128540566787
# Expression: 1.07410100595767*x**0.746871678680471*exp(-1.10044128960302*x)
# Loss: 0.05387128552962083
# Expression: 0.972752848676816*x**0.556247752636027*exp(-0.951549518513041*x)
# Loss: 0.05001343536903101
# Expression: 0.972752848676816*x**0.556247752636027*exp(-0.951549518513041*x)
sqrt(x)*exp_polar(I*pi/2))
# Loss: 7.034487709009644e-07
# Expression: 0.999512433859177*x**(-0.000151614041567377)*exp(0.00187854331470338*I*pi)*besseli(-0.00375708662940677, 9.98873650574042*sqrt(x)*exp_polar(I*pi/2))
# Loss: 7.034469771126284e-07
# Expression: 0.999512433859177*x**(-0.000151614041567377)*exp(0.00187855821586458*I*pi)*besseli(-0.00375711643172916, 9.98873650574042*sqrt(x)*exp_polar(I*pi/2))
# Loss: 7.034487439370168e-07
# Expression: 0.999512409905071*x**(-0.000151621492147974)*exp(0.00187855076528398*I*pi)*besseli(-0.00375710153056796, 9.98873650872401*sqrt(x)*exp_polar(I*pi/2))
# Loss: 7.034484631700205e-07
# Expression: 0.999471450942124*x**(-0.000164360210341168)*exp(0.0018544383460769*I*pi)*besseli(-0.00370887669215381, 9.98886243710031*sqrt(x)*exp_polar(I*pi/2))
# Loss: 6.892260827693703e-07
# Expression: 0.999471450942124*x**(-0.000164360210341168)*exp(0.0018544383460769*I*pi)*besseli(-0.00370887669215381, 9.98886243710031*sqrt(x)*exp_polar(I*pi/2))
# Loss: 6.892260827693703e-07
# Expression: 0.999471474895345*x**(-0.000164352759760571)*exp(0.00185443089549631*I*pi)*besseli(-0.00370886179099261, 9.98886243710031*sqrt(x)*exp_polar(I*pi/2))
# Loss: 6.892242879324606e-07
# Expression: 0.999471474895345*x**(-0.000164352759760571)*exp(0.0018544457966575*I*pi)*besseli(-0.003708891593315, 9.98886243710031*sqrt(x)*exp_polar(I*pi/2))
# Loss: 6.892259702601163e-07
# Expression: 0.999471450942025*x**(-0.000164360210341168)*exp(0.0018544383460769*I*pi)*besseli(-0.00370887669215381, 9.98886244008387*sqrt(x)*exp_polar(I*pi/2))
# Loss: 6.892257751842777e-07
# Expression: 0.999307625455636*x**(-0.000215315083114057)*exp(0.00175798866924848*I*pi)*besseli(-0.00351597733849696, 9.98936614666428*sqrt(x)*exp_polar(I*pi/2))
# Loss: 6.349255678506822e-07
# Expression: 0.999307625455636*x**(-0.000215315083114057)*exp(0.00175798866924848*I*pi)*besseli(-0.00351597733849696, 9.98936614666428*sqrt(x)*exp_polar(I*pi/2))
# Loss: 6.349255678506822e-07
# Expression: 0.999307649405682*x**(-0.00021530763253346)*exp(0.00175798121866788*I*pi)*besseli(-0.00351596243733576, 9.98936614666428*sqrt(x)*exp_polar(I*pi/2))
# Loss: 6.349237811078988e-07
# Expression: 0.999307649405682*x**(-0.00021530763253346)*exp(0.00175799611982907*I*pi)*besseli(-0.00351599223965815, 9.98936614666428*sqrt(x)*exp_polar(I*pi/2))
# Loss: 6.349251249174921e-07
# Expression: 0.999307625455507*x**(-0.000215315083114057)*exp(0.00175798866924848*I*pi)*besseli(-0.00351597733849696, 9.98936614964768*sqrt(x)*exp_polar(I*pi/2))
# Loss: 6.349252668593104e-07
# Expression: 0.998652489398847*x**(-0.000419134574205557)*exp(0.00137218996193483*I*pi)*besseli(-0.00274437992386967, 9.99138073097796*sqrt(x)*exp_polar(I*pi/2))
# Loss: 4.591334187267787e-07
# Expression: 0.998652489398847*x**(-0.000419134574205557)*exp(0.00137218996193483*I*pi)*besseli(-0.00274437992386967, 9.99138073097796*sqrt(x)*exp_polar(I*pi/2))
# Loss: 4.591334187267787e-07
# Expression: 0.998652513336193*x**(-0.00041912712362496)*exp(0.00137218251135424*I*pi)*besseli(-0.00274436502270847, 9.99138073097796*sqrt(x)*exp_polar(I*pi/2))
# Loss: 4.591316442982942e-07
# Expression: 0.998652513336192*x**(-0.00041912712362496)*exp(0.00137219741251543*I*pi)*besseli(-0.00274439482503086, 9.99138073097796*sqrt(x)*exp_polar(I*pi/2))
# Loss: 4.5913163873925306e-07
# Expression: 0.998652489398597*x**(-0.000419134574205557)*exp(0.00137218996193483*I*pi)*besseli(-0.00274437992386967, 9.99138073396076*sqrt(x)*exp_polar(I*pi/2))
# Loss: 4.5913313456536707e-07
# Expression: 0.997197759422278*x**(-0.00087201162831196)*exp(0.00051496388845873*I*pi)*besseli(-0.00102992777691746, 9.99585558654918*sqrt(x)*exp_polar(I*pi/2))
# Loss: 3.0518031861417716e-07
# Expression: 0.997197759422278*x**(-0.00087201162831196)*exp(0.00051496388845873*I*pi)*besseli(-0.00102992777691746, 9.99585558654918*sqrt(x)*exp_polar(I*pi/2))
# Loss: 3.0518031861417716e-07
# Expression: 0.997197783331408*x**(-0.000872004177731363)*exp(0.000514956437878133*I*pi)*besseli(-0.00102991287575627, 9.99585558654918*sqrt(x)*exp_polar(I*pi/2))
# Loss: 3.0517857966904927e-07
# Expression: 0.997197783331408*x**(-0.000872004177731363)*exp(0.000514971339039327*I*pi)*besseli(-0.00102994267807865, 9.99585558654918*sqrt(x)*exp_polar(I*pi/2))
# Loss: 3.0517557785430354e-07
# Expression: 0.997197759421759*x**(-0.00087201162831196)*exp(0.00051496388845873*I*pi)*besseli(-0.00102992777691746, 9.99585558953065*sqrt(x)*exp_polar(I*pi/2))
# Loss: 3.0518007826537e-07
# Expression: 0.997621087216954*x**(-0.000740082892404083)*exp(0.000453861024870661*I*pi)*besseli(-0.000907722049741322, 9.99670335154249*sqrt(x)*exp_polar(I*pi/2))
# Loss: 2.0397442459629095e-07
# Expression: 0.997621087216954*x**(-0.000740082892404083)*exp(0.000453861024870661*I*pi)*besseli(-0.000907722049741322, 9.99670335154249*sqrt(x)*exp_polar(I*pi/2))
# Loss: 2.0397442459629095e-07
# Expression: 0.997621111137495*x**(-0.000740075441823486)*exp(0.000453853574290064*I*pi)*besseli(-0.000907707148580128, 9.99670335154249*sqrt(x)*exp_polar(I*pi/2))
# Loss: 2.0397244299298108e-07
# Expression: 0.997621111137495*x**(-0.000740075441823486)*exp(0.000453868475451258*I*pi)*besseli(-0.000907736950902516, 9.99670335154249*sqrt(x)*exp_polar(I*pi/2))
# Loss: 2.0397092543011323e-07
# Expression: 0.997621087216514*x**(-0.000740082892404083)*exp(0.000453861024870661*I*pi)*besseli(-0.000907722049741322, 9.99670335452371*sqrt(x)*exp_polar(I*pi/2))
# Loss: 2.0397426023824857e-07
# Expression: 0.999197956396258*x**(-0.000249271050956274)*exp(0.000226541261750035*I*pi)*besseli(-0.00045308252350007, 9.99985664365652*sqrt(x)*exp_polar(I*pi/2))
# Loss: 4.219104317728994e-08
# Expression: 0.999197956396258*x**(-0.000249271050956274)*exp(0.000226541261750035*I*pi)*besseli(-0.00045308252350007, 9.99985664365652*sqrt(x)*exp_polar(I*pi/2))
# Loss: 4.219104317728994e-08
# Expression: 0.999197980359304*x**(-0.000249263600375677)*exp(0.000226533811169438*I*pi)*besseli(-0.000453067622338876, 9.99985664365652*sqrt(x)*exp_polar(I*pi/2))
# Loss: 4.218816689592256e-08
# Expression: 0.999197980359304*x**(-0.000249263600375677)*exp(0.000226548712330632*I*pi)*besseli(-0.000453097424661264, 9.99985664365652*sqrt(x)*exp_polar(I*pi/2))
# Loss: 4.2192176192885504e-08
# Expression: 0.99919795639611*x**(-0.000249271050956274)*exp(0.000226541261750035*I*pi)*besseli(-0.00045308252350007, 9.9998566466368*sqrt(x)*exp_polar(I*pi/2))
# Loss: 4.2191162535198756e-08
# Expression: 0.999551664756148*x**(-0.000139312800087455)*exp(6.81760201270976e-5*I*pi)*besseli(-0.000136352040254195, 10.0001856217861*sqrt(x)*exp_polar(I*pi/2))
# Loss: 1.0897423941988185e-08
# Expression: 0.999551664756148*x**(-0.000139312800087455)*exp(6.81760201270976e-5*I*pi)*besseli(-0.000136352040254195, 10.0001856217861*sqrt(x)*exp_polar(I*pi/2))
# Loss: 1.0897423941988185e-08
# Expression: 0.999551688728167*x**(-0.000139305349506858)*exp(6.81685695465006e-5*I*pi)*besseli(-0.000136337139093001, 10.0001856217861*sqrt(x)*exp_polar(I*pi/2))
# Loss: 1.0895985327492829e-08
# Expression: 0.999551688728167*x**(-0.000139305349506858)*exp(6.81834707076945e-5*I*pi)*besseli(-0.000136366941415389, 10.0001856217861*sqrt(x)*exp_polar(I*pi/2))
# Loss: 1.0897903347970675e-08
# Expression: 0.999551664756065*x**(-0.000139312800087455)*exp(6.81760201270976e-5*I*pi)*besseli(-0.000136352040254195, 10.0001856247663*sqrt(x)*exp_polar(I*pi/2))
# Loss: 1.0897488955304027e-08
# Expression: 0.999877753654038*x**(-3.79791308075147e-5)*exp(-7.77678348655719e-5*I*pi)*besseli(0.000155535669731144, 10.0004887869154*sqrt(x)*exp_polar(I*pi/2))
# Loss: 1.5448601922559411e-09
# Expression: 0.999877753654038*x**(-3.79791308075147e-5)*exp(-7.77678348655719e-5*I*pi)*besseli(0.000155535669731144, 10.0004887869154*sqrt(x)*exp_polar(I*pi/2))
# Loss: 1.5448601922559411e-09
# Expression: 0.999877777634329*x**(-3.79716802269178e-5)*exp(-7.77752854461689e-5*I*pi)*besseli(0.000155550570892338, 10.0004887869154*sqrt(x)*exp_polar(I*pi/2))
# Loss: 1.5447463928686645e-09
# Expression: 0.999877777634329*x**(-3.79716802269178e-5)*exp(-7.7760384284975e-5*I*pi)*besseli(0.00015552076856995, 10.0004887869154*sqrt(x)*exp_polar(I*pi/2))
# Loss: 1.5447377970088397e-09
# Expression: 0.999877753654015*x**(-3.79791308075147e-5)*exp(-7.77678348655719e-5*I*pi)*besseli(0.000155535669731144, 10.0004887898955*sqrt(x)*exp_polar(I*pi/2))
# Loss: 1.5448750855811997e-09
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 305
#          Gradient evaluations: 61
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0    48.81          4145.82        7         0.158544         0.183304      3.95m
#    1    10.92          5.96523        9         0.129046         0.236424      1.74m
#    2     5.27           1.1395        9         0.137679         0.158721      1.53m
#    3     2.85         0.676492        9         0.130591         0.222512      1.45m
#    4     1.79         0.591574        5         0.149556         0.295419      1.24m
#    5     2.09         0.555094        5           0.1477         0.312115      1.21m
#    6     2.50          1.56043        5         0.143673         0.344462      1.09m
#    7     3.01         0.882824        5         0.143987         0.341641      1.02m
#    8     3.84           2.6096        5         0.144676          0.33544      1.04m
#    9     4.54         0.570873        5         0.145549         0.327581     53.26s
#   10     4.91           112.84        5         0.145775         0.325545     48.08s
#   11     5.17         0.470407        5         0.141409         0.368736     42.21s
#   12     5.25           0.3585        5         0.142629          0.35386     38.66s
#   13     5.32          1.00911        5          0.14207         0.358896     31.78s
#   14     5.34          1.51449        5         0.143603         0.345098     26.13s
#   15     5.36         0.854576        5          0.14236         0.360178     21.49s
#   16     5.24         0.822792        5         0.144684          0.33537     16.64s
#   17     5.30         0.498071        5         0.143584         0.345269     10.78s
#   18     5.35         0.338385        5         0.142368         0.338707      5.40s
#   19     5.33         0.628708        5         0.141401         0.364914      0.00s
# --------------------------------------------------------

# %% [markdown]
# ## Results and discussion

# %% [markdown]
# Now let us check the symbolic expressions retrieved by both symbolic metamodeling and symbolic regression. In order to enable printing in LaTex format, we first invoke the "init_print" command of sympy as follows:

# %%
init_printing()

# %% [markdown]
# Now let us start with the first function $f_1(x) = e^{-3x}$, and see what the corresponding symbolic metamodel stroed in **symbolic_metamodels[0]**...

# %%
symbolic_metamodels[0].expression()
# Out:
#                    -9.70319623538773e-6  -2.99999745460077⋅x
# 0.999989340014427⋅x                    ⋅ℯ

# %% [markdown]
# As we can see, this is almost exactly equal to $e^{-3x}$! This means that the metamodeling algorithm was able to recover the true expression for $f_1(x)$ based on 100 evaluation samples only. To check the corresponding values of the poles and zeros recovered by the gradient descent algorithm used to optimize the metamodel, we can inspect the attributes of the **MeijerG** object **symbolic_metamodels[0]** as follows:

# %%
symbolic_metamodels[0].a_p, symbolic_metamodels[0].b_q, symbolic_metamodels[0]._const
# Out:
# ([array([], dtype=float64), array([], dtype=float64)],
#  [array([-9.70319624e-06]), array([], dtype=float64)],
#  2.99999745460077)

# %% [markdown]
# Now let us check the expression learned by symbolic regression (whcih is stored in **symbolic_regssion[0]**)...

# %%
symbolic_regssion[0]
# Out:
# (x - 0.966)⋅(x - 0.941)

# %% [markdown]
# Here, the symbolic regression algorithm retreived an approximation of $f_1(x) = e^{-3x}$, but failed to capture the exponential functional form of $f_1(x)$. This is because the symbolic regression search algorithm starts with predefined forms (mostly polynomials), and hence is less flexible than our Meijer $G$-function parameterization.

# %% [markdown]
# **What if we want to restrict our metamodels to polynomials only?** In this case, we can use the *approximate_expression* method to recover a Taylor approximation of the learned symbolic expression as follows.

# %%
from copy import deepcopy

polynomial_metamodel_of_f1 = deepcopy(symbolic_metamodels[0])

# %%
polynomial_metamodel_of_f1.approximation_order = 2

polynomial_metamodel_of_f1.approx_expression()
# Out:
#                   2
# 1.00409866492725⋅x  - 1.67349112591155⋅x + 0.80885046299002

# %% [markdown]
# As we can see, the second order Taylor approximation of our metamodel appears to be very closed to the symbolic regression model!

# %% [markdown]
# But what about the other functions? Let us check $f_2(x) = \frac{x}{(x+1)^2}$ and see what the metamodel was for that.

# %%
symbolic_metamodels[1].expression()
# Out:
#     1.0
# ────────────
#            2
#   ⎛    1.0⎞
# x⋅⎜1 + ───⎟
#   ⎝     x ⎠

# %% [markdown]
# For $f_2(x)$, the metamodeling algorithm nailed it! It exactly recovered the true symbolic expression. For the symbolic regression model for $f_2(x)$, we have the following expression:

# %%
symbolic_regssion[1]
# Out:
#       0.672⋅x
# ────────────────────
# x⋅(x + 0.872) + 0.75

# %% [markdown]
# So the symbolic regression algorithm also did a good job in finding the true mathematical expression for $f_2(x)$, though it recovered a less accurate expression than that of the metamodel. Now let us examine the results third function $f_3(x) = \sin(x)$...

# %%
symbolic_metamodels[2].expression()
# Out:
#                  1.1502858723937  ┌─  ⎛1.07972667818077, 1.07972667818077 │
# 1.4914765883445⋅x               ⋅ ├─  ⎜                                   │ 1.
#                                  2╵ 1 ⎝         2.35540931647635          │
#
#                   ⅈ⋅π⎞
# 79044041678082⋅x⋅ℯ   ⎟
#                      ⎠

# %%
symbolic_regssion[2]
# Out:
#         2
# - 0.17⋅x  + x + 0.016

# %% [markdown]
# Here, both algorithms came up with approximations of the sinusoid function in the range $[0,1]$. This is because in the range $[0,1]$ we see no full cycles of sinusoid, and hence it is indistiguishable from, say, a linear approximation. The confluent hypergeometric function $_2 F_1$ in the metamodel is very close to 0, and hence the metamodel can be though of as a linear approximation for the sinusoidal function.

# %% [markdown]
# Now we look at the most tricky of the four functions: $f_4(x) = J_0\left(10\sqrt{x}\right)$. This one is diffcult because it already displays a lot of fluctuations in the range $[0,1]$, and has an unusual functional form. So what symbolic expressions did the two algorithms learn for $f_4(x)$?

# %%
symbolic_metamodels[3].expression()
# Out:
#                                                                          ⎛
#                                                                          ⎜
#                    -3.79791308075147e-5  -7.77678348655719e-5⋅ⅈ⋅π        ⎜
# 0.999877753654038⋅x                    ⋅ℯ                        ⋅besseli⎝0.00
#
#                                        ⅈ⋅π⎞
#                                        ───⎟
#                                         2 ⎟
# 0155535669731144, 10.0004887869154⋅√x⋅ℯ   ⎠

# %%
symbolic_regssion[3]
# Out:
# -x⋅(x - 0.773)

# %% [markdown]
# This is an exciting result! The symbolic metamodel is very close to the ground truth: it corresponded to a Bessel function of the second kind $I_0(x)$ instead of a Bessel function of the first kind $J_0(x)$! Using the identity $J_0(ix) = I_0(x)$, we can see that our metamodel is in fact identical to the ground truth!

# %% [markdown]
# The above "qualitative" comparisons show that symbolic metamodeling can recover richer and more complex expressions compared to symbolic regression. The quantitative comparison can be done by simply comparing the $R^2$ scores for the two algorithms on the four functions:

# %%
sym_metamodel_R2
# Out:
# [0.9999999995520327, 0.9999999999997805, 0.9998232397944465, 0.999999973404098
# 5]

# %%
sym_regression_R2
# Out:
# ⎡
# ⎢                                                                   2
# ⎢- 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.0497870683678639)  - 0.1563
# ⎣
#
#
#                                                            2
# 34617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.0513033103319191)  - 0.1563346173430
#
#
#
#                                                   2
# 64⋅(-(x - 0.966)⋅(x - 0.941) + 0.0528657287383504)  - 0.156334617343064⋅(-(x -
#
#
#
#                                          2
#  0.966)⋅(x - 0.941) + 0.0544757298691899)  - 0.156334617343064⋅(-(x - 0.966)⋅(
#
#
#
#                                 2
# x - 0.941) + 0.0561347628341337)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941
#
#
#
#                        2
# ) + 0.0578443208748385)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.059
#
#
#
#               2
# 6059427089393)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.061421213915
#
#
#
#      2                                                                    2
# 0001)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.0632917683596407)  -
#
#
#
#                                                                  2
# 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.0652192896681275)  - 0.1563346
#
#
#
#                                                         2
# 17343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.0672055127397498)  - 0.156334617343064⋅
#
#
#
#                                               2
# (-(x - 0.966)⋅(x - 0.941) + 0.069252225309346)  - 0.156334617343064⋅(-(x - 0.9
#
#
#
#                                      2
# 66)⋅(x - 0.941) + 0.0713612695563861)  - 0.156334617343064⋅(-(x - 0.966)⋅(x -
#
#
#
#                             2
# 0.941) + 0.0735345437630571)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) +
#
#
#
#                    2
# 0.0757740040228455)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.0780816
#
#
#
#           2
# 660011532)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.0804596067495324
#
#
#
#  2                                                                    2
# )  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.0829099665751727)  - 0.15
#
#
#
#                                                              2
# 6334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.0854349509673212)  - 0.15633461734
#
#
#
#                                                     2
# 3064⋅(-(x - 0.966)⋅(x - 0.941) + 0.0880368325823725)  - 0.156334617343064⋅(-(x
#
#
#
#                                            2
#  - 0.966)⋅(x - 0.941) + 0.0907179532894125)  - 0.156334617343064⋅(-(x - 0.966)
#
#
#
#                                   2
# ⋅(x - 0.941) + 0.0934807262780585)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.9
#
#
#
#                         2
# 41) + 0.096327638230493)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.09
#
#
#
#                2
# 92612515596457)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.10228420671
#
#
#
#      2                                                                   2
# 5537)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.105399224561864)  - 0
#
#
#
#                                                                2
# .156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.108609108824958)  - 0.156334617
#
#
#
#                                                      2
# 343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.111916748617329)  - 0.156334617343064⋅(-(
#
#
#
#                                            2
# x - 0.966)⋅(x - 0.941) + 0.115325121038063)  - 0.156334617343064⋅(-(x - 0.966)
#
#
#
#                                 2
# ⋅(x - 0.941) + 0.11883729385241)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941
#
#
#
#                       2
# ) + 0.122456428252982)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.1261
#
#
#
#             2
# 85781705039)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.13002871087842
#
#
#
#   2                                                                   2
# 6)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.133988674668805)  - 0.15
#
#
#
#                                                             2
# 6334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.138069237310893)  - 0.156334617343
#
#
#
#                                                   2
# 064⋅(-(x - 0.966)⋅(x - 0.941) + 0.142274071586514)  - 0.156334617343064⋅(-(x -
#
#
#
#                                        2
#  0.966)⋅(x - 0.941) + 0.14660696213035)  - 0.156334617343064⋅(-(x - 0.966)⋅(x
#
#
#
#                              2
# - 0.941) + 0.151071808836371)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) +
#
#
#
#                    2
#  0.155672630367997)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.1604135
#
#
#
#          2                                                                   2
# 67775173)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.165298888221587)
#
#
#
#                                                                    2
#  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.170332988825409)  - 0.15633
#
#
#
#                                                          2
# 4617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.175520400616997)  - 0.156334617343064
#
#
#
#                                                2
# ⋅(-(x - 0.966)⋅(x - 0.941) + 0.180865792617122)  - 0.156334617343064⋅(-(x - 0.
#
#
#
#                                     2
# 966)⋅(x - 0.941) + 0.18637397603941)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0
#
#
#
#                           2
# .941) + 0.192049908620754)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.
#
#
#
#                 2
# 197898699083615)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.2039256117
#
#
#
#       2                                                                   2
# 34213)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.210136071200765)  -
#
#
#
#                                                                 2
# 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.216535667316007)  - 0.15633461
#
#
#
#                                                      2
# 7343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.22313016014843)  - 0.156334617343064⋅(-(
#
#
#
#                                            2
# x - 0.966)⋅(x - 0.941) + 0.229925485186724)  - 0.156334617343064⋅(-(x - 0.966)
#
#
#
#                                  2
# ⋅(x - 0.941) + 0.236927758682122)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.94
#
#
#
#                        2
# 1) + 0.244143283153437)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.251
#
#
#
#              2
# 578553059756)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.2592402606458
#
#
#
#    2                                                                  2
# 92)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.26713530196585)  - 0.15
#
#
#
#                                                             2
# 6334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.275270783089752)  - 0.156334617343
#
#
#
#                                                  2
# 064⋅(-(x - 0.966)⋅(x - 0.941) + 0.28365402649977)  - 0.156334617343064⋅(-(x -
#
#
#
#                                        2
# 0.966)⋅(x - 0.941) + 0.292292577680859)  - 0.156334617343064⋅(-(x - 0.966)⋅(x
#
#
#
#                              2
# - 0.941) + 0.301194211912202)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) +
#
#
#
#                    2
#  0.310366941265485)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.3198190
#
#
#
#          2                                                                   2
# 21816304)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.329558961075189)
#
#
#
#                                                                    2
#  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.339595525644939)  - 0.15633
#
#
#
#                                                          2
# 4617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.349937749111155)  - 0.156334617343064
#
#
#
#                                                2
# ⋅(-(x - 0.966)⋅(x - 0.941) + 0.360594940173078)  - 0.156334617343064⋅(-(x - 0.
#
#
#
#                                      2
# 966)⋅(x - 0.941) + 0.371576691022046)  - 0.156334617343064⋅(-(x - 0.966)⋅(x -
#
#
#
#                            2
# 0.941) + 0.382892885975112)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0
#
#
#
#                  2
# .394553710371601)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.406569659
#
#
#
#        2                                                                   2
# 740599)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.418951549247639)  -
#
#
#
#                                                                 2
#  0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.43171052342908)  - 0.15633461
#
#
#
#                                                       2
# 7343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.444858066222941)  - 0.156334617343064⋅(-
#
#
#
#                                             2
# (x - 0.966)⋅(x - 0.941) + 0.458406011305224)  - 0.156334617343064⋅(-(x - 0.966
#
#
#
#                                   2
# )⋅(x - 0.941) + 0.472366552741015)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.9
#
#
#
#                         2
# 41) + 0.486752255959972)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.50
#
#
#
#               2
# 1576069066055)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.516851334491
#
#
#
#     2                                                                   2
# 699)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.532591801006897)  - 0.
#
#
#
#                                                               2
# 156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.548811636094026)  - 0.1563346173
#
#
#
#                                                     2
# 43064⋅(-(x - 0.966)⋅(x - 0.941) + 0.565525438699537)  - 0.156334617343064⋅(-(x
#
#
#
#                                          2
#  - 0.966)⋅(x - 0.941) + 0.58274825237399)  - 0.156334617343064⋅(-(x - 0.966)⋅(
#
#
#
#                                2
# x - 0.941) + 0.600495578812266)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941)
#
#
#
#                      2
#  + 0.618783391806141)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.63762
#
#
#
#            2
# 8151621773)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.657046819815057
#
#
#
#  2                                                                   2
# )  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.677056874498165)  - 0.156
#
#
#
#                                                            2
# 334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.697676326071031)  - 0.1563346173430
#
#
#
#                                                  2
# 64⋅(-(x - 0.966)⋅(x - 0.941) + 0.718923733431926)  - 0.156334617343064⋅(-(x -
#
#
#
#                                        2
# 0.966)⋅(x - 0.941) + 0.740818220681718)  - 0.156334617343064⋅(-(x - 0.966)⋅(x
#
#
#
#                              2
# - 0.941) + 0.763379494336853)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) +
#
#
#
#                    2
#  0.786627861066553)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.8105842
#
#
#
#          2                                                                   2
# 45970187)  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.835270211411272)
#
#
#
#                                                                    2
#  - 0.156334617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.860707976425058)  - 0.15633
#
#
#
#                                                          2
# 4617343064⋅(-(x - 0.966)⋅(x - 0.941) + 0.886920436717157)  - 0.156334617343064
#
#
#
#                                                2
# ⋅(-(x - 0.966)⋅(x - 0.941) + 0.913931185271228)  - 0.156334617343064⋅(-(x - 0.
#
#
#
#                                      2
# 966)⋅(x - 0.941) + 0.941764533584249)  - 0.156334617343064⋅(-(x - 0.966)⋅(x -
#
#
#
#                            2                         ⎛           x
# 0.941) + 0.970445533548508)  + 1, - 1.07721533920893⋅⎜- ──────────────────── +
#                                                      ⎝  x⋅(x + 0.872) + 0.75
#
#                     2
#                    ⎞                     ⎛           x
#  0.0145877388304601⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.028606213
#                    ⎠                     ⎝  x⋅(x + 0.872) + 0.75
#
#        2                                                                 2
#       ⎞                     ⎛           x                               ⎞
# 727321⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.0420801745148997⎟  - 1
#       ⎠                     ⎝  x⋅(x + 0.872) + 0.75                     ⎠
#
#                                                              2
#                 ⎛           x                               ⎞
# .07721533920893⋅⎜- ──────────────────── + 0.0550331079177233⎟  - 1.07721533920
#                 ⎝  x⋅(x + 0.872) + 0.75                     ⎠
#
#                                                  2
#     ⎛           x                               ⎞                     ⎛
# 893⋅⎜- ──────────────────── + 0.0674873123852716⎟  - 1.07721533920893⋅⎜- ─────
#     ⎝  x⋅(x + 0.872) + 0.75                     ⎠                     ⎝  x⋅(x
#
#                                      2
#     x                               ⎞                     ⎛           x
# ─────────────── + 0.0794639678584143⎟  - 1.07721533920893⋅⎜- ─────────────────
# + 0.872) + 0.75                     ⎠                     ⎝  x⋅(x + 0.872) + 0
#
#                          2
#                         ⎞                     ⎛           x
# ─── + 0.0909832008617929⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.1020
# .75                     ⎠                     ⎝  x⋅(x + 0.872) + 0.75
#
#             2                                                              2
#            ⎞                     ⎛           x                            ⎞
# 64145274022⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.1127249990982⎟  -
#            ⎠                     ⎝  x⋅(x + 0.872) + 0.75                  ⎠
#
#                                                               2
#                   ⎛           x                              ⎞
#  1.07721533920893⋅⎜- ──────────────────── + 0.122983077528532⎟  - 1.0772153392
#                   ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                  2
#      ⎛           x                              ⎞                     ⎛
# 0893⋅⎜- ──────────────────── + 0.132854862584592⎟  - 1.07721533920893⋅⎜- ─────
#      ⎝  x⋅(x + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x
#
#                                     2
#     x                              ⎞                     ⎛           x
# ─────────────── + 0.142356049562682⎟  - 1.07721533920893⋅⎜- ──────────────────
# + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.
#
#                        2
#                       ⎞                     ⎛           x
# ── + 0.151501590533621⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.160305
# 75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.75
#
#           2                                                                2
#          ⎞                     ⎛           x                              ⎞
# 735097979⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.168782068593033⎟  -
#          ⎠                     ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                               2
#                   ⎛           x                              ⎞
#  1.07721533920893⋅⎜- ──────────────────── + 0.176943547930468⎟  - 1.0772153392
#                   ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                  2
#      ⎛           x                              ⎞                     ⎛
# 0893⋅⎜- ──────────────────── + 0.184802535229886⎟  - 1.07721533920893⋅⎜- ─────
#      ⎝  x⋅(x + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x
#
#                                     2
#     x                              ⎞                     ⎛           x
# ─────────────── + 0.192370829400419⎟  - 1.07721533920893⋅⎜- ──────────────────
# + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.
#
#                        2
#                       ⎞                     ⎛           x
# ── + 0.199659695811098⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.206679
# 75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.75
#
#           2                                                                2
#          ⎞                     ⎛           x                              ⎞
# 894179894⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.213441704801585⎟  -
#          ⎠                     ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                               2
#                   ⎛           x                              ⎞
#  1.07721533920893⋅⎜- ──────────────────── + 0.219954953225579⎟  - 1.0772153392
#                   ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                  2
#      ⎛           x                              ⎞                     ⎛
# 0893⋅⎜- ──────────────────── + 0.226229033486618⎟  - 1.07721533920893⋅⎜- ─────
#      ⎝  x⋅(x + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x
#
#                                     2
#     x                              ⎞                     ⎛           x
# ─────────────── + 0.232272929983648⎟  - 1.07721533920893⋅⎜- ──────────────────
# + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.
#
#                        2
#                       ⎞                     ⎛           x
# ── + 0.238095238095238⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.243704
# 75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.75
#
#           2                                                                2
#          ⎞                     ⎛           x                              ⎞
# 183613481⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.249107641072425⎟  -
#          ⎠                     ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                               2
#                   ⎛           x                              ⎞
#  1.07721533920893⋅⎜- ──────────────────── + 0.254313151041667⎟  - 1.0772153392
#                   ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                  2
#      ⎛           x                              ⎞                     ⎛
# 0893⋅⎜- ──────────────────── + 0.259327936450706⎟  - 1.07721533920893⋅⎜- ─────
#      ⎝  x⋅(x + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x
#
#                                     2
#     x                              ⎞                     ⎛           x
# ─────────────── + 0.264158918005072⎟  - 1.07721533920893⋅⎜- ──────────────────
# + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.
#
#                        2
#                       ⎞                     ⎛           x
# ── + 0.268812728750961⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.273295
# 75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.75
#
#           2                                                                2
#          ⎞                     ⎛           x                              ⎞
# 727841182⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.277614013551602⎟  -
#          ⎠                     ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                               2
#                   ⎛           x                              ⎞
#  1.07721533920893⋅⎜- ──────────────────── + 0.281773435593886⎟  - 1.0772153392
#                   ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                  2
#      ⎛           x                              ⎞                     ⎛
# 0893⋅⎜- ──────────────────── + 0.285779606767261⎟  - 1.07721533920893⋅⎜- ─────
#      ⎝  x⋅(x + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x
#
#                                     2
#     x                              ⎞                     ⎛           x
# ─────────────── + 0.289637913989125⎟  - 1.07721533920893⋅⎜- ──────────────────
# + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.
#
#                        2
#                       ⎞                     ⎛           x
# ── + 0.293353528741669⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.296931
# 75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.75
#
#           2                                                                2
#          ⎞                     ⎛           x                              ⎞
# 416969224⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.300376348458746⎟  -
#          ⎠                     ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                               2
#                   ⎛           x                              ⎞
#  1.07721533920893⋅⎜- ──────────────────── + 0.303692905733722⎟  - 1.0772153392
#                   ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                  2
#      ⎛           x                              ⎞                     ⎛
# 0893⋅⎜- ──────────────────── + 0.306885492489838⎟  - 1.07721533920893⋅⎜- ─────
#      ⎝  x⋅(x + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x
#
#                                     2
#     x                              ⎞                     ⎛           x
# ─────────────── + 0.309958341598889⎟  - 1.07721533920893⋅⎜- ──────────────────
# + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.
#
#                        2
#                       ⎞                     ⎛           x
# ── + 0.312915522705733⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.315760
# 75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.75
#
#           2                                                                2
#          ⎞                     ⎛           x                              ⎞
# 949441505⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.318498386274843⎟  -
#          ⎠                     ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                               2
#                   ⎛           x                              ⎞
#  1.07721533920893⋅⎜- ──────────────────── + 0.321131455021491⎟  - 1.0772153392
#                   ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                  2
#      ⎛           x                              ⎞                     ⎛
# 0893⋅⎜- ──────────────────── + 0.323663641031404⎟  - 1.07721533920893⋅⎜- ─────
#      ⎝  x⋅(x + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x
#
#                                     2
#     x                              ⎞                     ⎛           x
# ─────────────── + 0.326098299071272⎟  - 1.07721533920893⋅⎜- ──────────────────
# + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.
#
#                        2
#                       ⎞                     ⎛           x
# ── + 0.328438658919268⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.330687
# 75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.75
#
#           2                                                                2
#          ⎞                     ⎛           x                              ⎞
# 830687831⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.332848809889291⎟  -
#          ⎠                     ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                               2
#                   ⎛           x                              ⎞
#  1.07721533920893⋅⎜- ──────────────────── + 0.334924482258277⎟  - 1.0772153392
#                   ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                  2
#      ⎛           x                              ⎞                     ⎛
# 0893⋅⎜- ──────────────────── + 0.336917628344003⎟  - 1.07721533920893⋅⎜- ─────
#      ⎝  x⋅(x + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x
#
#                                     2
#     x                              ⎞                     ⎛           x
# ─────────────── + 0.338830927884731⎟  - 1.07721533920893⋅⎜- ──────────────────
# + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.
#
#                        2
#                       ⎞                     ⎛           x
# ── + 0.340666963976017⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.342428
# 75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.75
#
#           2                                                                2
#          ⎞                     ⎛           x                              ⎞
# 227043612⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.344117118631298⎟  -
#          ⎠                     ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                               2
#                   ⎛           x                              ⎞
#  1.07721533920893⋅⎜- ──────────────────── + 0.345735955013314⎟  - 1.0772153392
#                   ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                  2
#      ⎛           x                              ⎞                     ⎛
# 0893⋅⎜- ──────────────────── + 0.347286970640477⎟  - 1.07721533920893⋅⎜- ─────
#      ⎝  x⋅(x + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x
#
#                                     2
#     x                              ⎞                     ⎛           x
# ─────────────── + 0.348772321428571⎟  - 1.07721533920893⋅⎜- ──────────────────
# + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.
#
#                        2
#                       ⎞                     ⎛           x
# ── + 0.350194087897109⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.351554
# 75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.75
#
#           2                                                               2
#          ⎞                     ⎛           x                             ⎞
# 278166075⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.35285483081787⎟  -
#          ⎠                     ⎝  x⋅(x + 0.872) + 0.75                   ⎠
#
#                                                              2
#                  ⎛           x                              ⎞
# 1.07721533920893⋅⎜- ──────────────────── + 0.354097617631229⎟  - 1.07721533920
#                  ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                 2
#     ⎛           x                              ⎞                     ⎛
# 893⋅⎜- ──────────────────── + 0.355284446193537⎟  - 1.07721533920893⋅⎜- ──────
#     ⎝  x⋅(x + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x +
#
#                                    2
#    x                              ⎞                     ⎛           x
# ────────────── + 0.356417062397611⎟  - 1.07721533920893⋅⎜- ───────────────────
#  0.872) + 0.75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.7
#
#                       2
#                      ⎞                     ⎛           x
# ─ + 0.357497152828646⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.3585263
# 5                    ⎠                     ⎝  x⋅(x + 0.872) + 0.75
#
#          2                                                                2
#         ⎞                     ⎛           x                              ⎞
# 47046755⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.359506219770216⎟  -
#         ⎠                     ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                              2
#                  ⎛           x                              ⎞
# 1.07721533920893⋅⎜- ──────────────────── + 0.360438292964244⎟  - 1.07721533920
#                  ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                 2
#     ⎛           x                              ⎞                     ⎛
# 893⋅⎜- ──────────────────── + 0.361324037839889⎟  - 1.07721533920893⋅⎜- ──────
#     ⎝  x⋅(x + 0.872) + 0.75                    ⎠                     ⎝  x⋅(x +
#
#                                    2
#    x                              ⎞                     ⎛           x
# ────────────── + 0.362164876767365⎟  - 1.07721533920893⋅⎜- ───────────────────
#  0.872) + 0.75                    ⎠                     ⎝  x⋅(x + 0.872) + 0.7
#
#                      2
#                     ⎞                     ⎛           x
# ─ + 0.36296218510793⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.36371729
# 5                   ⎠                     ⎝  x⋅(x + 0.872) + 0.75
#
#         2                                                                2
#        ⎞                     ⎛           x                              ⎞
# 2968185⎟  - 1.07721533920893⋅⎜- ──────────────────── + 0.364431486880466⎟  - 1
#        ⎠                     ⎝  x⋅(x + 0.872) + 0.75                    ⎠
#
#                                                            2
#                 ⎛           x                             ⎞
# .07721533920893⋅⎜- ──────────────────── + 0.36510601141283⎟  - 1.0772153392089
#                 ⎝  x⋅(x + 0.872) + 0.75                   ⎠
#
#                                               2
# ...
#
#
#                           2
# 0.773) - 0.16307455918474)  - 0.172157335837537⋅(x⋅(x - 0.773) - 0.15230615823
#
#
#
#      2                                                        2
# 0064)  - 0.172157335837537⋅(x⋅(x - 0.773) - 0.144665228624824)  - 0.1721573358
#
#
#
#                                         2
# 37537⋅(x⋅(x - 0.773) - 0.14096662899532)  - 0.172157335837537⋅(x⋅(x - 0.773) -
#
#
#
#                    2                                                       2
#  0.129075999928958)  - 0.172157335837537⋅(x⋅(x - 0.773) - 0.11805002108812)  -
#
#
#
#                                                       2
#  0.172157335837537⋅(x⋅(x - 0.773) - 0.116656668521772)  - 0.172157335837537⋅(x
#
#
#
#                                  2
# ⋅(x - 0.773) - 0.111610685814356)  - 0.172157335837537⋅(x⋅(x - 0.773) - 0.1037
#
#
#
#             2                                                         2
# 33448282157)  - 0.172157335837537⋅(x⋅(x - 0.773) - 0.0903336111828763)  - 0.17
#
#
#
#                                                  2
# 2157335837537⋅(x⋅(x - 0.773) - 0.078742457116227)  - 0.172157335837537⋅(x⋅(x -
#
#
#
#                              2
#  0.773) - 0.0764869251101016)  - 0.172157335837537⋅(x⋅(x - 0.773) - 0.06222568
#
#
#
#          2                                                         2
# 58198423)  - 0.172157335837537⋅(x⋅(x - 0.773) - 0.0475847428803149)  - 0.17215
#
#
#
#                                                2
# 7335837537⋅(x⋅(x - 0.773) - 0.0463356811122073)  - 0.172157335837537⋅(x⋅(x - 0
#
#
#
#                          2
# .773) - 0.03260151905106)  - 0.172157335837537⋅(x⋅(x - 0.773) - 0.022966965748
#
#
#
#      2                                                         2
# 8797)  - 0.172157335837537⋅(x⋅(x - 0.773) - 0.0173160225208538)  - 0.172157335
#
#
#
#                                            2
# 837537⋅(x⋅(x - 0.773) - 0.0146336217456364)  - 0.172157335837537⋅(x⋅(x - 0.773
#
#
#
#                         2
# ) - 0.00177085139649582)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.0139888101965
#
#
#
#     2                                                         2
# 281)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.0161501465472177)  - 0.1721573358
#
#
#
#                                           2
# 37537⋅(x⋅(x - 0.773) + 0.0299152050728363)  - 0.172157335837537⋅(x⋅(x - 0.773)
#
#
#
#                       2
#  + 0.0458296648598136)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.045958025710298
#
#
#
#   2                                                         2
# 2)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.0620644474772939)  - 0.172157335837
#
#
#
#                                         2
# 537⋅(x⋅(x - 0.773) + 0.0742446224274587)  - 0.172157335837537⋅(x⋅(x - 0.773) +
#
#
#
#                     2
#  0.0781791731400508)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.0904053271585646)
#
#
#
# 2                                                         2
#   - 0.172157335837537⋅(x⋅(x - 0.773) + 0.0942444894635621)  - 0.17215733583753
#
#
#
#                                      2
# 7⋅(x⋅(x - 0.773) + 0.101258491422591)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.
#
#
#
#                 2                                                        2
# 110200336758617)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.125984392267884)  - 0
#
#
#
#                                                     2
# .172157335837537⋅(x⋅(x - 0.773) + 0.126756759680424)  - 0.172157335837537⋅(x⋅(
#
#
#
#                                2
# x - 0.773) + 0.141532168325976)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.150645
#
#
#
#           2                                                        2
# 257250998)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.156777126271914)  - 0.17215
#
#
#
#                                               2
# 7335837537⋅(x⋅(x - 0.773) + 0.171650807137554)  - 0.172157335837537⋅(x⋅(x - 0.
#
#
#
#                          2
# 773) + 0.172848572818016)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.186082980182
#
#
#
#     2                                                        2
# 274)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.193308556164837)  - 0.17215733583
#
#
#
#                                         2
# 7537⋅(x⋅(x - 0.773) + 0.200001810392749)  - 0.172157335837537⋅(x⋅(x - 0.773) +
#
#
#
#                    2                                                        2
#  0.211982903003576)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.213334046116803)
#
#
#
#                                                        2
# - 0.172157335837537⋅(x⋅(x - 0.773) + 0.223890779141236)  - 0.172157335837537⋅(
#
#
#
#                                   2
# x⋅(x - 0.773) + 0.226005228052458)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.228
#
#
#
#              2                                                        2
# 843818614894)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.237939920867136)  - 0.17
#
#
#
#                                                  2
# 2157335837537⋅(x⋅(x - 0.773) + 0.243876756873418)  - 0.172157335837537⋅(x⋅(x -
#
#
#
#                            2
#  0.773) + 0.24906196877785)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.2570792313
#
#
#
#       2                                                        2
# 57342)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.259294776481033)  - 0.172157335
#
#
#
#                                           2
# 837537⋅(x⋅(x - 0.773) + 0.268459695360385)  - 0.172157335837537⋅(x⋅(x - 0.773)
#
#
#
#                      2
#  + 0.268561616880481)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.276785967123906)
#
#
#
# 2                                                        2
#   - 0.172157335837537⋅(x⋅(x - 0.773) + 0.278036487740335)  - 0.172157335837537
#
#
#
#                                     2
# ⋅(x⋅(x - 0.773) + 0.283891874522643)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.2
#
#
#
#                2                                                        2
# 85836841650678)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.289804353995502)  - 0.
#
#
#
#                                                    2
# 172157335837537⋅(x⋅(x - 0.773) + 0.291895953310688)  - 0.172157335837537⋅(x⋅(x
#
#
#
#                               2
#  - 0.773) + 0.294449818746327)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.2962561
#
#
#
#         2                                                        2
# 0807473)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.297756545955907)  - 0.1721573
#
#
#
#                                             2
# 35837537⋅(x⋅(x - 0.773) + 0.298965861163605)  - 0.172157335837537⋅(x⋅(x - 0.77
#
#
#
#                        2
# 3) + 0.299655179342289)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.30007927051955
#
#
#
#   2                                                        2
# 6)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.379439425042892)  - 0.1721573358375
#
#
#
#                                      2
# 37⋅(x⋅(x - 0.773) + 0.55913414441898)  - 0.172157335837537⋅(x⋅(x - 0.773) + 0.
#
#
#                      ⎤
#                 2    ⎥
# 765197686557967)  + 1⎥
#                      ⎦

# %% [markdown]
# Finally, to evaluate the numeric value of any metamodel for a given $x$, we can use the **evaluate** method of the **MeijerG** object. In the cell below, we evaluate all metamodels in the range $[0,1]$ and plot them along the true functions to see how accurate they are.

# %%
import numpy as np

from matplotlib import pyplot as plt
get_ipython().magic('matplotlib inline')

x_points = np.linspace(0,1,100)

fig, axs = plt.subplots(1, 4, figsize=(20,2.5))

axs[0].plot(x_points, True_functions[0][1](x_points), linewidth=4, label='True function')
axs[0].plot(x_points, symbolic_metamodels[0].evaluate(x_points), color='red', linewidth=3, linestyle='--', label='Metamodel')
axs[0].set_title('$f_1(x)$')
axs[0].legend()

axs[1].plot(x_points, True_functions[1][1](x_points), linewidth=4, label='True function')
axs[1].plot(x_points, symbolic_metamodels[1].evaluate(x_points), color='red', linewidth=3, linestyle='--', label='Metamodel')
axs[1].set_title('$f_2(x)$')
axs[1].legend()

axs[2].plot(x_points, True_functions[2][1](x_points), linewidth=4, label='True function')
axs[2].plot(x_points, symbolic_metamodels[2].evaluate(x_points), color='red', linewidth=3, linestyle='--', label='Metamodel')
axs[2].set_title('$f_3(x)$')
axs[2].legend()

axs[3].plot(x_points, True_functions[3][1](x_points), linewidth=4, label='True function')
axs[3].plot(x_points, symbolic_metamodels[3].evaluate(x_points), color='red', linewidth=3, linestyle='--', label='Metamodel')
axs[3].set_title('$f_4(x)$')
axs[3].legend()

for ax in axs.flat:
    ax.set(xlabel='$x$', ylabel='$f(x)$')

for ax in axs.flat:
    ax.label_outer()

# %%
import numpy as np
from sympy import *
from sympy.abc import x

from matplotlib import pyplot as plt
get_ipython().magic('matplotlib inline')

x_points = np.linspace(0,1,100)

f0 = lambdify(x, symbolic_metamodels[0].approx_expression(), "numpy")
f1 = lambdify(x, symbolic_metamodels[1].approx_expression(), "numpy")
f2 = lambdify(x, symbolic_metamodels[2].approx_expression(), "numpy")
f3 = lambdify(x, symbolic_metamodels[3].approx_expression(), "numpy")

fig, axs = plt.subplots(1, 4, figsize=(20,2.5))

axs[0].plot(x_points, True_functions[0][1](x_points), linewidth=4, label='True function')
axs[0].plot(x_points, f0(x_points), color='red', linewidth=3, linestyle='--', label='Metamodel Approx')
axs[0].set_title('$f_1(x)$')
axs[0].legend()

axs[1].plot(x_points, True_functions[1][1](x_points), linewidth=4, label='True function')
axs[1].plot(x_points, f1(x_points), color='red', linewidth=3, linestyle='--', label='Metamodel Approx')
axs[1].set_title('$f_2(x)$')
axs[1].legend()

axs[2].plot(x_points, True_functions[2][1](x_points), linewidth=4, label='True function')
axs[2].plot(x_points, f2(x_points), color='red', linewidth=3, linestyle='--', label='Metamodel Approx')
axs[2].set_title('$f_3(x)$')
axs[2].legend()

axs[3].plot(x_points, True_functions[3][1](x_points), linewidth=4, label='True function')
axs[3].plot(x_points, f3(x_points), color='red', linewidth=3, linestyle='--', label='Metamodel Approx')
axs[3].set_title('$f_4(x)$')
axs[3].legend()

for ax in axs.flat:
    ax.set(xlabel='$x$', ylabel='$f(x)$')

for ax in axs.flat:
    ax.label_outer()

# %%
import numpy as np
from sympy import *
from sympy.abc import x

from matplotlib import pyplot as plt
get_ipython().magic('matplotlib inline')

x_points = np.linspace(0,1,100)

polynomial_metamodel_of_f0 = deepcopy(symbolic_metamodels[0])
polynomial_metamodel_of_f1 = deepcopy(symbolic_metamodels[1])
polynomial_metamodel_of_f2 = deepcopy(symbolic_metamodels[2])
polynomial_metamodel_of_f3 = deepcopy(symbolic_metamodels[3])

polynomial_metamodel_of_f0.approximation_order = 5
polynomial_metamodel_of_f1.approximation_order = 5
polynomial_metamodel_of_f2.approximation_order = 5
polynomial_metamodel_of_f3.approximation_order = 5


f0 = lambdify(x, polynomial_metamodel_of_f0.approx_expression(), "numpy")
f1 = lambdify(x, polynomial_metamodel_of_f1.approx_expression(), "numpy")
f2 = lambdify(x, polynomial_metamodel_of_f2.approx_expression(), "numpy")
f3 = lambdify(x, polynomial_metamodel_of_f3.approx_expression(), "numpy")

display(Markdown("f1(x) = ${}$".format(latex(polynomial_metamodel_of_f0.approx_expression()))))
display(Markdown("f2(x) = ${}$".format(latex(polynomial_metamodel_of_f1.approx_expression()))))
display(Markdown("f3(x) = ${}$".format(latex(polynomial_metamodel_of_f2.approx_expression()))))
display(Markdown("f4(x) = ${}$".format(latex(polynomial_metamodel_of_f3.approx_expression()))))


fig, axs = plt.subplots(1, 4, figsize=(20,2.5))

axs[0].plot(x_points, True_functions[0][1](x_points), linewidth=4, label='True function')
axs[0].plot(x_points, f0(x_points), color='red', linewidth=3, linestyle='--', label='Metamodel Approx')
axs[0].set_title('$f_1(x)$')
axs[0].legend()

axs[1].plot(x_points, True_functions[1][1](x_points), linewidth=4, label='True function')
axs[1].plot(x_points, f1(x_points), color='red', linewidth=3, linestyle='--', label='Metamodel Approx')
axs[1].set_title('$f_2(x)$')
axs[1].legend()

axs[2].plot(x_points, True_functions[2][1](x_points), linewidth=4, label='True function')
axs[2].plot(x_points, f2(x_points), color='red', linewidth=3, linestyle='--', label='Metamodel Approx')
axs[2].set_title('$f_3(x)$')
axs[2].legend()

axs[3].plot(x_points, True_functions[3][1](x_points), linewidth=4, label='True function')
axs[3].plot(x_points, f3(x_points), color='red', linewidth=3, linestyle='--', label='Metamodel Approx')
axs[3].set_title('$f_4(x)$')
axs[3].legend()

for ax in axs.flat:
    ax.set(xlabel='$x$', ylabel='$f(x)$')

for ax in axs.flat:
    ax.label_outer()
# Out:
# f1(x) = $- 0.451935373971039 x^{5} + 1.88296311788348 x^{4} - 3.64020654298201 x^{3} + 4.20488302003884 x^{2} - 2.94437232836242 x + 0.995558578879189$
# f2(x) = $0.263374485596708 x^{5} - 0.965706447187929 x^{4} + 1.60219478737997 x^{3} - 1.58024691358025 x^{2} + 0.927297668038409 x + 0.00548696844993141$
# f3(x) = $- 0.0821977648316464 x^{5} + 0.216169488184183 x^{4} - 0.146497710059821 x^{3} - 0.253939849913607 x^{2} + 1.13120485403336 x - 0.0151267813306999$
# f4(x) = $- 50.2467991417394 x^{5} + 140.127381930922 x^{4} - 143.826925366132 x^{3} + 60.9840415861332 x^{2} - 7.59285478449218 x - 0.35934662550747$

# %%
import numpy as np
from sympy import *
from sympy.abc import x

from matplotlib import pyplot as plt
get_ipython().magic('matplotlib inline')

x_points = np.linspace(0,1,100)

f0 = lambdify(x, symbolic_regssion[0], "numpy")
f1 = lambdify(x, symbolic_regssion[1], "numpy")
f2 = lambdify(x, symbolic_regssion[2], "numpy")
f3 = lambdify(x, symbolic_regssion[3], "numpy")



fig, axs = plt.subplots(1, 4, figsize=(20,2.5))

axs[0].plot(x_points, True_functions[0][1](x_points), linewidth=4, label='True function')
axs[0].plot(x_points, f0(x_points), color='red', linewidth=3, linestyle='--', label='Symbolic Regression')
axs[0].set_title('$f_1(x)$')
axs[0].legend()

axs[1].plot(x_points, True_functions[1][1](x_points), linewidth=4, label='True function')
axs[1].plot(x_points, f1(x_points), color='red', linewidth=3, linestyle='--', label='Symbolic Regression')
axs[1].set_title('$f_2(x)$')
axs[1].legend()

axs[2].plot(x_points, True_functions[2][1](x_points), linewidth=4, label='True function')
axs[2].plot(x_points, f2(x_points), color='red', linewidth=3, linestyle='--', label='Symbolic Regression')
axs[2].set_title('$f_3(x)$')
axs[2].legend()

axs[3].plot(x_points, True_functions[3][1](x_points), linewidth=4, label='True function')
axs[3].plot(x_points, f3(x_points), color='red', linewidth=3, linestyle='--', label='Symbolic Regression')
axs[3].set_title('$f_4(x)$')
axs[3].legend()

for ax in axs.flat:
    ax.set(xlabel='$x$', ylabel='$f(x)$')

for ax in axs.flat:
    ax.label_outer()

# %% [markdown]
# ## References
#
# [1] Patryk Orzechowski, William La Cava, and Jason H Moore. Where are we now?: a large benchmark study of recent symbolic regression methods. *In Proceedings of the Genetic and Evolutionary Computation Conference*, pages 1183–1190. ACM, 2018.
#
# [2] Telmo Menezes and Camille Roth. Symbolic regression of generative network models. *Scientific reports*, 4:6284, 2014.
#
# [3] Ekaterina J Vladislavleva, Guido F Smits, and Dick Den Hertog. Order of nonlinearity as a com344 plexity measure for models generated by symbolic regression via pareto genetic programming. *IEEE Transactions on Evolutionary Computation*, 13(2):333–349, 2009.
