# %% [markdown]
# # Config & Imports

# %%
import numpy as np
from pathlib import Path
from sklearn.model_selection import train_test_split

import os
import tensorflow as tf
from tensorflow import keras
import keras.layers
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import BatchNormalization
from keras.layers import LeakyReLU
from keras.layers import ReLU
from keras.callbacks import EarlyStopping

from keras.regularizers import L1L2
from keras.regularizers import L2

import utilities_LR

from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()

import sys

# %%
config = {
    'data': {
        'n_datasets': 45_000, # the number of datasets
        
        'n_samples': 5_000, # the number of samples per dataset
        
        'n_features': 5, 
        # The total number of features. 
        # These comprise n_informative informative features, n_redundant redundant features, n_repeated duplicated features and 
        # n_features-n_informative-n_redundant-n_repeated useless features drawn at random.
        
        #'n_informative': random.randint(2, 10),
        'n_informative': 'random',
        # The number of informative features. Each class is composed of a number of gaussian clusters each located around the vertices 
        # of a hypercube in a subspace of dimension n_informative. For each cluster, informative features are drawn independently 
        # from N(0, 1) and then randomly linearly combined within each cluster in order to add covariance. The clusters are then 
        # placed on the vertices of the hypercube.
        ### int or 'random'
        
        'n_targets': 1,
        # The number of targets (or labels) of the classification problem.
    
        'n_clusters_per_class': 1,
        # The number of clusters per class.
        
        'class_sep': 1.0,
        # class_sepfloat, default=1.0
        # The factor multiplying the hypercube size. Larger values spread out the clusters/classes and make the classification task 
        # easier.
        
        'shuffle': True,
        # Shuffle the samples and the features.
        
        'random_state': 42,
        # Determines random number generation for dataset creation. Pass an int for reproducible output across multiple function calls.
    },
    'lambda': {
        'data_prep': {
            'train_test_val_split': { # refer to sklearn doc
                'test_size': 0.1,
                'val_size': 0.15,
                'random_state': None,
                'shuffle': False, # should be always false
                'stratify': None
            }
        },
        'model_compile': {
            'optimizer_lambda': 'adam',
            'loss': 'mae',# keras.losses.BinaryCrossentropy(from_logits=False), #tf.keras.losses.get(config['lambda_net']['loss_lambda']), # 'mae'
            'metrics': ['mae', keras.losses.BinaryCrossentropy(from_logits=False)]
        },
        'model_fit': { # refer to keras API
            'batch_size': 64,
            'epochs': 500,
            'verbose': 0,
            'callbacks': None,
            'shuffle': True, # usually true
            'class_weight': None,
            'sample_weight': None,
            'initial_epoch': 0,
            'steps_per_epoch': None,
            'validation_steps': None,
            'validation_batch_size': None,
            'validation_freq': 1
        }
    },
    'inets': {
        'data_prep': {
            'train_test_val_split': { # refer to sklearn doc
                'test_size': 0.1,
                'val_size': 0.15,
                'random_state': None,
                'shuffle': False,
                'stratify': None
            },
            'train_noise': 0 # y_flip fraction on Y_train pred data from lambda net
        },
        'model_compile': {
            
        },
        'model_fit': { # refer to keras API
            'batch_size': 256,
            'epochs': 1000,
            'verbose': 'auto',
            'callbacks': None,
            'shuffle': True,
            'class_weight': None,
            'sample_weight': None,
            'initial_epoch': 0,
            'steps_per_epoch': None,
            'validation_steps': None,
            'validation_batch_size': None,
            'validation_freq': 1
        }
    },
    'computation':{
        'n_jobs': 45,
        'use_gpu': True,
        'gpu_numbers': '1',
        'RANDOM_SEED': 1,   
    }
}

# %%
os.environ['CUDA_DEVICE_ORDER']='PCI_BUS_ID'

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

os.environ['CUDA_VISIBLE_DEVICES'] = config['computation']['gpu_numbers'] if config['computation']['use_gpu'] else ''
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true' if config['computation']['use_gpu'] else ''

os.environ['XLA_FLAGS'] = '--xla_gpu_cuda_data_dir=/usr/local/cuda-11.4' if config['computation']['use_gpu'] else ''#-10.1' #--xla_gpu_cuda_data_dir=/usr/local/cuda, 
os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2 ,--tf_xla_enable_xla_devices' if config['computation']['use_gpu'] else ''#'--tf_xla_auto_jit=2' #, --tf_xla_enable_xla_devices

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print("Num XLA-GPUs Available: ", len(tf.config.experimental.list_physical_devices('XLA_GPU')))
# Out:
# Num GPUs Available:  1
# Num XLA-GPUs Available:  0

# %% [markdown]
# # Functions

# %%
def load_lambda():
    directory = utilities_LR.lambda_path_LR(config)
    
    return np.load(directory + '/lambda_weights_list.npy', allow_pickle=True)

# %%
def get_X_data():
    directory = utilities_LR.data_path_LR(config)
    return np.load(directory + '/X.npy', allow_pickle=True)

# %%
def get_y_pred_data():
    directory = utilities_LR.lambda_path_LR(config)
    
    return np.load(directory + '/lambda_preds_list.npy', allow_pickle=True)
    #return np.load(directory + '/lambda_preds_list_with0.2_noise.npy', allow_pickle=True)

# %% [markdown]
# # Model Training

# %%
lambda_nets = load_lambda()

# %%
y_predictions = get_y_pred_data()

# %%
valid_feature_data = get_X_data()

# %%
y_predictions = y_predictions.round()

# %%
indexcol = np.array([np.arange(config['data']['n_datasets'], dtype=int)], ndmin=2).reshape(config['data']['n_datasets'], 1)
y_predictions = np.concatenate([indexcol, y_predictions], axis=1)

# %%
import pandas as pd

# %%
lambda_nets
# Out:
# array([[ 1.4754504 ,  1.733562  ,  1.5126163 , ..., -0.90207374,
#         -0.6453182 ,  0.1885663 ],
#        [ 1.2609234 ,  1.3853258 ,  1.2348111 , ..., -0.6348239 ,
#          0.5128916 , -0.10512284],
#        [ 1.2739321 ,  1.527161  ,  1.6995864 , ...,  0.5426504 ,
#         -0.7010185 , -0.15427388],
#        ...,
#        [ 1.7336937 ,  1.7190936 ,  2.0656013 , ...,  1.2149141 ,
#          1.112189  ,  0.25789696],
#        [ 1.4238183 ,  1.2226592 ,  1.2032247 , ..., -0.4398536 ,
#         -0.5931882 , -0.12626882],
#        [ 1.2676578 ,  1.603684  ,  1.1418661 , ..., -0.7304286 ,
#         -0.79009044,  0.09231924]], dtype=float32)

# %%
lambda_nets.shape
# Out:
# (45000, 371)

# %%
y_predictions.shape
# Out:
# (45000, 5001)

# %%
valid_feature_data = tf.convert_to_tensor(valid_feature_data, dtype=tf.float32)

# %% [markdown]
# # Custom Loss

# %%
@tf.function
def custom_loss(y_predictions_index, y_coef_pred):
    
    index = y_predictions_index[:, 0]
    y_true = y_predictions_index[:, 1:]
    
    # ADD NOISE TO TRAINING DATA
    noise = tf.cast(config['inets']['data_prep']['train_noise'], tf.float32)
    noise_logits = tf.tile([[1-noise, noise]], [tf.shape(y_true)[0], tf.constant(1)])
    noise_flip = tf.random.categorical(tf.math.log(noise_logits), y_true.shape[1])
    y_true = y_true*(1-noise_flip) + (1-y_true)*noise_flip   
    
    index = tf.cast(index, tf.int32)
    
    X_feature_data_samples = tf.gather(valid_feature_data, index)
    
    y_pred = tf.transpose(tf.math.add(tf.transpose(tf.linalg.matvec(X_feature_data_samples, y_coef_pred[:, 1:])), y_coef_pred[:, 0]))

    metric = tf.keras.losses.BinaryCrossentropy(
                                from_logits=True,
                                label_smoothing=0.0,
                                axis=-1,
                                reduction='auto',
                                name='binary_crossentropy')
    loss = metric(y_true, y_pred)
    return loss

# %%
#custom_loss(y_predictions, tf.cast(tf.tile([[0, 0.1, 0.5, 0.8, 0.3, 0.2]], [45000, 1]), tf.float32))

# %%
# Data Prep

early_stopping = EarlyStopping(monitor='val_loss',
                                min_delta=0.001,
                                patience=45,
                                verbose=0,
                                mode='auto',
                                baseline=None,
                                restore_best_weights=True)


#reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1,
#                              patience=5, min_lr=0.0001)
#

#X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X,
#                                                                      y)

X_train, X_test, y_train, y_test = train_test_split(lambda_nets, 
                                                    y_predictions, 
                                                    test_size=config['inets']['data_prep']['train_test_val_split']['test_size'], 
                                                    random_state=config['inets']['data_prep']['train_test_val_split']['random_state'], 
                                                    shuffle=config['inets']['data_prep']['train_test_val_split']['shuffle'], 
                                                    stratify=config['inets']['data_prep']['train_test_val_split']['stratify'])




# Model Def
model = Sequential()
#model.add(BatchNormalization())
#regval = 0.0000000000001
#model.add(Dense(2056, activation='swish', kernel_regularizer=L2(regval), bias_regularizer= L2(regval), input_dim=X_train.shape[1]))
##model.add(keras.layers.Dropout(0.1))
#model.add(Dense(1028, activation='swish', kernel_regularizer=L2(regval), bias_regularizer= L2(regval)))
##model.add(keras.layers.Dropout(0.2))
#model.add(Dense(1028, activation='swish', kernel_regularizer=L2(regval), bias_regularizer= L2(regval)))
##model.add(keras.layers.Dropout(0.2))
#model.add(Dense(1028, activation='swish', kernel_regularizer=L2(regval), bias_regularizer=  L2(regval)))
##model.add(keras.layers.Dropout(0.1))

#model.add(Dense(10000, activation='ELU', input_dim=X_train.shape[1]))
##model.add(keras.layers.Dropout(0.3))
##model.add(Dense(4112, activation='relu'))
#model.add(Dense(10000, activation='ELU'))
#model.add(Dense(10000, activation='ELU'))
#model.add(Dense(10000, activation='ELU'))
#model.add(Dense(10000, activation='ELU'))
#model.add(Dense(10000, activation='ELU'))
#model.add(Dense(10000, activation='ELU'))

#model.add(Dense(1028, activation='LeakyReLU', kernel_regularizer=L2(regval), bias_regularizer= L2(regval), input_dim=X_train.shape[1]))
##model.add(keras.layers.Dropout(0.2))
#model.add(Dense(1028, activation='LeakyReLU', kernel_regularizer=L2(regval), bias_regularizer= L2(regval)))
##model.add(keras.layers.Dropout(0.2))
#model.add(Dense(2000, activation='LeakyReLU', kernel_regularizer=L2(regval), bias_regularizer=  L2(regval), input_dim=X_train.shape[1]))
#model.add(keras.layers.Dropout(0.1))


#model.add(Dense(4096, activation='swish'))
#model.add(Dense(2048, activation='swish'))
#model.add(Dense(1024, activation='swish'))
#model.add(Dense(512 , activation='swish'))

model.add(Dense(2048, activation='swish'))
model.add(keras.layers.Dropout(0.5))

model.add(Dense(1024, activation='swish'))
model.add(keras.layers.Dropout(0.5))
model.add(Dense(512 , activation='swish'))
model.add(keras.layers.Dropout(0.5))

model.add(Dense(config['data']['n_features'] + 1, activation='linear'))

#lr = tf.keras.optimizers.schedules.CosineDecayRestarts(
#                                                        0.01,
#                                                        10,
#                                                        t_mul=2.0,
#                                                        m_mul=1.0,
#                                                        alpha=0.0,
#                                                        name=None
#)
#
#
#opt = tf.keras.optimizers.RMSprop(
#    #learning_rate=0.001,
#    learning_rate=lr,
#    rho=0.9,
#    momentum=0.0,
#    epsilon=1e-07,
#    centered=False,
#    name="RMSprop",
#)

opt = tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999, # 0.999
    epsilon=1e-08, # 1.0, 0.1, 0.01
    amsgrad=False,
    name='Adam',)

#opt = tf.keras.optimizers.SGD(
#    learning_rate=0.1, # 0.001
#    momentum=0.0,
#    nesterov=False,
#    name='SGD'
#)

model.compile(optimizer=opt, loss=custom_loss, metrics=[])
model.build(input_shape=X_train.shape)
model.summary()

# Model fit
history = model.fit(x=X_train,
                    y=y_train,
                    batch_size=config['inets']['model_fit']['batch_size'],
                    epochs=config['inets']['model_fit']['epochs'],
                    verbose=config['inets']['model_fit']['verbose'],
                    callbacks=[early_stopping],
                    validation_split=config['inets']['data_prep']['train_test_val_split']['val_size'],
                    shuffle=config['inets']['model_fit']['shuffle'],
                    class_weight=config['inets']['model_fit']['class_weight'],
                    sample_weight=config['inets']['model_fit']['sample_weight'],
                    initial_epoch=config['inets']['model_fit']['initial_epoch'],
                    steps_per_epoch=config['inets']['model_fit']['steps_per_epoch'],
                    validation_steps=config['inets']['model_fit']['validation_steps'],
                    validation_batch_size=config['inets']['model_fit']['validation_batch_size'],
                    validation_freq=config['inets']['model_fit']['validation_freq'],
                    workers=config['computation']['n_jobs'],
                    #use_multiprocessing=True
                   )
print(history.history['val_loss'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (40500, 2048)             761856
#
#  dropout (Dropout)           (40500, 2048)             0
#
#  dense_1 (Dense)             (40500, 1024)             2098176
#
#  dropout_1 (Dropout)         (40500, 1024)             0
#
#  dense_2 (Dense)             (40500, 512)              524800
#
#  dropout_2 (Dropout)         (40500, 512)              0
#
#  dense_3 (Dense)             (40500, 6)                3078
#
# =================================================================
# Total params: 3,387,910
# Trainable params: 3,387,910
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 135/135 [==============================] - 6s 15ms/step - loss: 0.7368 - val_loss: 0.6964
# Epoch 2/1000
# 135/135 [==============================] - 3s 21ms/step - loss: 0.7085 - val_loss: 0.6882
# Epoch 3/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.6897 - val_loss: 0.6785
# Epoch 4/1000
# 135/135 [==============================] - 1s 7ms/step - loss: 0.6685 - val_loss: 0.6456
# Epoch 5/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.6196 - val_loss: 0.5470
# Epoch 6/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.5333 - val_loss: 0.4478
# Epoch 7/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4530 - val_loss: 0.3818
# Epoch 8/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.4064 - val_loss: 0.3587
# Epoch 9/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.3794 - val_loss: 0.3345
# Epoch 10/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.3586 - val_loss: 0.3191
# Epoch 11/1000
# 135/135 [==============================] - 1s 7ms/step - loss: 0.3430 - val_loss: 0.3200
# Epoch 12/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.3313 - val_loss: 0.3099
# Epoch 13/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.3214 - val_loss: 0.3044
# Epoch 14/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.3155 - val_loss: 0.3019
# Epoch 15/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.3085 - val_loss: 0.2966
# Epoch 16/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.3021 - val_loss: 0.2946
# Epoch 17/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2976 - val_loss: 0.2914
# Epoch 18/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2936 - val_loss: 0.2892
# Epoch 19/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2908 - val_loss: 0.2880
# Epoch 20/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2864 - val_loss: 0.2851
# Epoch 21/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2827 - val_loss: 0.2830
# Epoch 22/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2815 - val_loss: 0.2826
# Epoch 23/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2778 - val_loss: 0.2800
# Epoch 24/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2744 - val_loss: 0.2747
# Epoch 25/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2716 - val_loss: 0.2732
# Epoch 26/1000
# 135/135 [==============================] - 1s 7ms/step - loss: 0.2687 - val_loss: 0.2708
# Epoch 27/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2667 - val_loss: 0.2649
# Epoch 28/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2641 - val_loss: 0.2594
# Epoch 29/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2609 - val_loss: 0.2554
# Epoch 30/1000
# 135/135 [==============================] - 1s 7ms/step - loss: 0.2577 - val_loss: 0.2544
# Epoch 31/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2555 - val_loss: 0.2480
# Epoch 32/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2518 - val_loss: 0.2446
# Epoch 33/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2486 - val_loss: 0.2397
# Epoch 34/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2463 - val_loss: 0.2385
# Epoch 35/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2440 - val_loss: 0.2357
# Epoch 36/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2425 - val_loss: 0.2329
# Epoch 37/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2397 - val_loss: 0.2305
# Epoch 38/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2375 - val_loss: 0.2295
# Epoch 39/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2368 - val_loss: 0.2276
# Epoch 40/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2338 - val_loss: 0.2258
# Epoch 41/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2329 - val_loss: 0.2251
# Epoch 42/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2318 - val_loss: 0.2235
# Epoch 43/1000
# 135/135 [==============================] - 1s 7ms/step - loss: 0.2306 - val_loss: 0.2236
# Epoch 44/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2293 - val_loss: 0.2227
# Epoch 45/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2285 - val_loss: 0.2222
# Epoch 46/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2279 - val_loss: 0.2220
# Epoch 47/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2270 - val_loss: 0.2200
# Epoch 48/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2262 - val_loss: 0.2230
# Epoch 49/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2242 - val_loss: 0.2195
# Epoch 50/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2244 - val_loss: 0.2209
# Epoch 51/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2245 - val_loss: 0.2198
# Epoch 52/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2235 - val_loss: 0.2198
# Epoch 53/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2235 - val_loss: 0.2179
# Epoch 54/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2234 - val_loss: 0.2167
# Epoch 55/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2229 - val_loss: 0.2163
# Epoch 56/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2230 - val_loss: 0.2174
# Epoch 57/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2219 - val_loss: 0.2179
# Epoch 58/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2207 - val_loss: 0.2185
# Epoch 59/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2205 - val_loss: 0.2190
# Epoch 60/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2199 - val_loss: 0.2184
# Epoch 61/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2199 - val_loss: 0.2162
# Epoch 62/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2186 - val_loss: 0.2161
# Epoch 63/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2194 - val_loss: 0.2171
# Epoch 64/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2181 - val_loss: 0.2154
# Epoch 65/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2172 - val_loss: 0.2160
# Epoch 66/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2179 - val_loss: 0.2139
# Epoch 67/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2170 - val_loss: 0.2188
# Epoch 68/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2160 - val_loss: 0.2145
# Epoch 69/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2160 - val_loss: 0.2158
# Epoch 70/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2163 - val_loss: 0.2143
# Epoch 71/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2158 - val_loss: 0.2153
# Epoch 72/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2163 - val_loss: 0.2152
# Epoch 73/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2152 - val_loss: 0.2144
# Epoch 74/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2148 - val_loss: 0.2161
# Epoch 75/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2141 - val_loss: 0.2150
# Epoch 76/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2133 - val_loss: 0.2137
# Epoch 77/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2137 - val_loss: 0.2143
# Epoch 78/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2150 - val_loss: 0.2154
# Epoch 79/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2134 - val_loss: 0.2156
# Epoch 80/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2136 - val_loss: 0.2139
# Epoch 81/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2133 - val_loss: 0.2139
# Epoch 82/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2125 - val_loss: 0.2131
# Epoch 83/1000
# 135/135 [==============================] - 1s 7ms/step - loss: 0.2128 - val_loss: 0.2141
# Epoch 84/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2118 - val_loss: 0.2145
# Epoch 85/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2121 - val_loss: 0.2123
# Epoch 86/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2123 - val_loss: 0.2145
# Epoch 87/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2125 - val_loss: 0.2133
# Epoch 88/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2120 - val_loss: 0.2141
# Epoch 89/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2113 - val_loss: 0.2129
# Epoch 90/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2116 - val_loss: 0.2140
# Epoch 91/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2110 - val_loss: 0.2141
# Epoch 92/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2112 - val_loss: 0.2133
# Epoch 93/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2100 - val_loss: 0.2131
# Epoch 94/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2108 - val_loss: 0.2132
# Epoch 95/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2102 - val_loss: 0.2122
# Epoch 96/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2097 - val_loss: 0.2133
# Epoch 97/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2094 - val_loss: 0.2123
# Epoch 98/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2090 - val_loss: 0.2128
# Epoch 99/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2086 - val_loss: 0.2126
# Epoch 100/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2094 - val_loss: 0.2125
# Epoch 101/1000
# 135/135 [==============================] - 1s 8ms/step - loss: 0.2097 - val_loss: 0.2117
# Epoch 102/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2085 - val_loss: 0.2119
# Epoch 103/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2079 - val_loss: 0.2108
# Epoch 104/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2086 - val_loss: 0.2127
# Epoch 105/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2079 - val_loss: 0.2114
# Epoch 106/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2076 - val_loss: 0.2112
# Epoch 107/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2073 - val_loss: 0.2122
# Epoch 108/1000
# 135/135 [==============================] - 1s 7ms/step - loss: 0.2086 - val_loss: 0.2108
# Epoch 109/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2078 - val_loss: 0.2126
# Epoch 110/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2076 - val_loss: 0.2103
# Epoch 111/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2072 - val_loss: 0.2105
# Epoch 112/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2076 - val_loss: 0.2100
# Epoch 113/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2066 - val_loss: 0.2105
# Epoch 114/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2073 - val_loss: 0.2096
# Epoch 115/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2057 - val_loss: 0.2102
# Epoch 116/1000
# 135/135 [==============================] - 1s 7ms/step - loss: 0.2066 - val_loss: 0.2084
# Epoch 117/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2067 - val_loss: 0.2091
# Epoch 118/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2069 - val_loss: 0.2089
# Epoch 119/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2060 - val_loss: 0.2095
# Epoch 120/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2062 - val_loss: 0.2095
# Epoch 121/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2059 - val_loss: 0.2104
# Epoch 122/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2056 - val_loss: 0.2097
# Epoch 123/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2058 - val_loss: 0.2105
# Epoch 124/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2064 - val_loss: 0.2115
# Epoch 125/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2057 - val_loss: 0.2094
# Epoch 126/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2051 - val_loss: 0.2100
# Epoch 127/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2060 - val_loss: 0.2088
# Epoch 128/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2059 - val_loss: 0.2100
# Epoch 129/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2051 - val_loss: 0.2086
# Epoch 130/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2048 - val_loss: 0.2076
# Epoch 131/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2050 - val_loss: 0.2077
# Epoch 132/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2051 - val_loss: 0.2101
# Epoch 133/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2046 - val_loss: 0.2079
# Epoch 134/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2047 - val_loss: 0.2079
# Epoch 135/1000
# 135/135 [==============================] - 1s 7ms/step - loss: 0.2043 - val_loss: 0.2077
# Epoch 136/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2042 - val_loss: 0.2097
# Epoch 137/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2055 - val_loss: 0.2079
# Epoch 138/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2041 - val_loss: 0.2095
# Epoch 139/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2049 - val_loss: 0.2086
# Epoch 140/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2036 - val_loss: 0.2092
# Epoch 141/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2038 - val_loss: 0.2093
# Epoch 142/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2040 - val_loss: 0.2113
# Epoch 143/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2043 - val_loss: 0.2101
# Epoch 144/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2032 - val_loss: 0.2101
# Epoch 145/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2043 - val_loss: 0.2086
# Epoch 146/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2026 - val_loss: 0.2085
# Epoch 147/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2036 - val_loss: 0.2092
# Epoch 148/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2031 - val_loss: 0.2091
# Epoch 149/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2031 - val_loss: 0.2098
# Epoch 150/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2025 - val_loss: 0.2087
# Epoch 151/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2031 - val_loss: 0.2096
# Epoch 152/1000
# 135/135 [==============================] - 1s 6ms/step - loss: 0.2023 - val_loss: 0.2104
# Epoch 153/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2027 - val_loss: 0.2098
# Epoch 154/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2024 - val_loss: 0.2082
# Epoch 155/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2033 - val_loss: 0.2071
# Epoch 156/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2029 - val_loss: 0.2085
# Epoch 157/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2026 - val_loss: 0.2078
# Epoch 158/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2031 - val_loss: 0.2088
# Epoch 159/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2024 - val_loss: 0.2075
# Epoch 160/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2020 - val_loss: 0.2087
# Epoch 161/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2029 - val_loss: 0.2068
# Epoch 162/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2021 - val_loss: 0.2084
# Epoch 163/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2018 - val_loss: 0.2070
# Epoch 164/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2023 - val_loss: 0.2089
# Epoch 165/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2024 - val_loss: 0.2096
# Epoch 166/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2018 - val_loss: 0.2076
# Epoch 167/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2020 - val_loss: 0.2080
# Epoch 168/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2011 - val_loss: 0.2088
# Epoch 169/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2012 - val_loss: 0.2080
# Epoch 170/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2014 - val_loss: 0.2098
# Epoch 171/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2017 - val_loss: 0.2096
# Epoch 172/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2011 - val_loss: 0.2100
# Epoch 173/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2010 - val_loss: 0.2075
# Epoch 174/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2013 - val_loss: 0.2102
# Epoch 175/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2014 - val_loss: 0.2097
# Epoch 176/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2015 - val_loss: 0.2078
# Epoch 177/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2006 - val_loss: 0.2091
# Epoch 178/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2015 - val_loss: 0.2090
# Epoch 179/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2010 - val_loss: 0.2088
# Epoch 180/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2008 - val_loss: 0.2063
# Epoch 181/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2003 - val_loss: 0.2078
# Epoch 182/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2015 - val_loss: 0.2097
# Epoch 183/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2009 - val_loss: 0.2098
# Epoch 184/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2009 - val_loss: 0.2096
# Epoch 185/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2010 - val_loss: 0.2088
# Epoch 186/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2011 - val_loss: 0.2091
# Epoch 187/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2008 - val_loss: 0.2097
# Epoch 188/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2010 - val_loss: 0.2088
# Epoch 189/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2002 - val_loss: 0.2100
# Epoch 190/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2003 - val_loss: 0.2109
# Epoch 191/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.2002 - val_loss: 0.2085
# Epoch 192/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.1988 - val_loss: 0.2089
# Epoch 193/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.1998 - val_loss: 0.2081
# Epoch 194/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.1997 - val_loss: 0.2078
# Epoch 195/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2007 - val_loss: 0.2078
# Epoch 196/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.1998 - val_loss: 0.2097
# Epoch 197/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.1997 - val_loss: 0.2080
# Epoch 198/1000
# 135/135 [==============================] - 1s 4ms/step - loss: 0.1990 - val_loss: 0.2079
# Epoch 199/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.1992 - val_loss: 0.2083
# Epoch 200/1000
# 135/135 [==============================] - 1s 5ms/step - loss: 0.1998 - val_loss: 0.2101
# [0.6964336037635803, 0.6882311105728149, 0.6785435080528259, 0.645585834980011, 0.5470163226127625, 0.4477577209472656, 0.3817645311355591, 0.35871922969818115, 0.3345341980457306, 0.31905630230903625, 0.31996989250183105, 0.309897780418396, 0.30437806248664856, 0.30193763971328735, 0.29657891392707825, 0.29459184408187866, 0.2914156913757324, 0.2891665995121002, 0.28802865743637085, 0.28506919741630554, 0.28304895758628845, 0.2826042175292969, 0.28004005551338196, 0.2747476100921631, 0.2731536626815796, 0.27075186371803284, 0.2649257183074951, 0.2594378590583801, 0.25538894534111023, 0.2543988525867462, 0.24801293015480042, 0.24461303651332855, 0.23966017365455627, 0.2384592592716217, 0.23572830855846405, 0.23286309838294983, 0.23046275973320007, 0.22951611876487732, 0.22756876051425934, 0.22577223181724548, 0.22511506080627441, 0.22352652251720428, 0.22361356019973755, 0.22266578674316406, 0.22222945094108582, 0.22198426723480225, 0.21996453404426575, 0.22298923134803772, 0.219512939453125, 0.220906600356102, 0.21981443464756012, 0.21976783871650696, 0.21786944568157196, 0.2166832685470581, 0.21633337438106537, 0.2173643857240677, 0.21786800026893616, 0.21851274371147156, 0.21904022991657257, 0.21839401125907898, 0.2162172794342041, 0.21608607470989227, 0.21710370481014252, 0.21540682017803192, 0.21601706743240356, 0.21385854482650757, 0.2187625616788864, 0.21453404426574707, 0.2158477008342743, 0.21432682871818542, 0.2152758538722992, 0.21521222591400146, 0.21443389356136322, 0.21607905626296997, 0.2149585485458374, 0.21372108161449432, 0.21429520845413208, 0.21540501713752747, 0.21564537286758423, 0.21391740441322327, 0.21391527354717255, 0.2131432294845581, 0.21413089334964752, 0.21450909972190857, 0.21231229603290558, 0.21449939906597137, 0.21326492726802826, 0.21406185626983643, 0.2129397690296173, 0.21401166915893555, 0.21412786841392517, 0.2132784128189087, 0.21311286091804504, 0.2131710797548294, 0.2122277021408081, 0.2133280336856842, 0.2122664749622345, 0.21284468472003937, 0.2126423865556717, 0.21246935427188873, 0.2117149382829666, 0.2118605524301529, 0.21083897352218628, 0.21269410848617554, 0.21139763295650482, 0.21122385561466217, 0.2121599316596985, 0.21080021560192108, 0.212636798620224, 0.2103288173675537, 0.21045301854610443, 0.20995309948921204, 0.21053443849086761, 0.20962345600128174, 0.21022434532642365, 0.20836879312992096, 0.20913071930408478, 0.20892192423343658, 0.20946399867534637, 0.20945030450820923, 0.21036547422409058, 0.20966598391532898, 0.21051450073719025, 0.21149009466171265, 0.2094295173883438, 0.20995651185512543, 0.20879992842674255, 0.20995262265205383, 0.20861297845840454, 0.2075556367635727, 0.20769482851028442, 0.2100815623998642, 0.20787964761257172, 0.20788711309432983, 0.20770283043384552, 0.20972350239753723, 0.20792840421199799, 0.20946936309337616, 0.20859140157699585, 0.20916835963726044, 0.2092786282300949, 0.2112867683172226, 0.2100542187690735, 0.21006211638450623, 0.2085828334093094, 0.2085430920124054, 0.20916521549224854, 0.2090769112110138, 0.20978793501853943, 0.2087440937757492, 0.20962296426296234, 0.210372656583786, 0.2098044455051422, 0.2081630378961563, 0.20710153877735138, 0.2085421234369278, 0.20779931545257568, 0.20884835720062256, 0.20754289627075195, 0.2087264060974121, 0.20675066113471985, 0.20836341381072998, 0.20701050758361816, 0.20890924334526062, 0.20961426198482513, 0.2076438069343567, 0.20803947746753693, 0.20881716907024384, 0.207979217171669, 0.20983770489692688, 0.20959649980068207, 0.20997807383537292, 0.20750026404857635, 0.2102186232805252, 0.2096618413925171, 0.20781198143959045, 0.20909008383750916, 0.20902283489704132, 0.20878946781158447, 0.20632390677928925, 0.20781953632831573, 0.20968006551265717, 0.20981939136981964, 0.20961202681064606, 0.20875714719295502, 0.20909006893634796, 0.20968404412269592, 0.20876063406467438, 0.20997212827205658, 0.21085989475250244, 0.20845986902713776, 0.20889310538768768, 0.20811818540096283, 0.2077774405 ...

# %%
def save_model(model):
    path = utilities_LR.inet_path_LR(config)
    
    Path(path).mkdir(parents=True, exist_ok=True)
    model.save(path + '/modelKeras' + '.h5')

# %%
save_model(model)

# %%
def save_testData(X_test, y_test):
    path = utilities_LR.inet_path_LR(config)
    
    Path(path).mkdir(parents=True, exist_ok=True)
    np.save(path + '/X_test', X_test)
    
    np.save(path + '/y_test', y_test)

# %%
save_testData(X_test, y_test)
