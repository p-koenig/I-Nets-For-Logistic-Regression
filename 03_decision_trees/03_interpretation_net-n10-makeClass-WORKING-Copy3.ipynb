#  {'exponential': {'class_0': {'scale': 1.430622716468031},
#    'class_1': {'scale': 1.430622716468031}}},
#  {'normal': {'class_0': {'loc': 1.0182689655137043,
#     'scale': 1.602165594923162},
#    'class_1': {'loc': 1.0182689655137043, 'scale': 1.602165594923162}}},
#  {'poisson': {'class_0': {'lam': 0.9740843244897848},
#    'class_1': {'lam': 0.9740843244897848}}},
#  {'exponential': {'class_0': {'scale': 0.146949443338237},
#    'class_1': {'scale': 0.146949443338237}}},
#  {'beta': {'class_0': {'a': 1.388589204115833, 'b': 0.9160736949414678},
#    'class_1': {'a': 1.388589204115833, 'b': 0.9160736949414678}}}]

# %% [markdown]
# ## Interpretation Network Training

# %%
#%load_ext tensorboard
#%tensorboard --logdir data/logging/ --port=8811

# %%
#%load_ext autoreload
#%autoreload 2

# %%
generate_data_make_classification_distribution(config, seed=1)[4]
# Out:
# [{'gamma': {'class_0': {'shape': 0.8613971343694169,
#     'scale': 1.8782555788472515},
#    'class_1': {'shape': 0.8613971343694169, 'scale': 1.8782555788472515}}},
#  {'uniform': {'class_0': {'low': 0.08504421136977791,
#     'high': 0.8946066635038473},
#    'class_1': {'low': 0.08504421136977791, 'high': 0.8946066635038473}}},
#  {'beta': {'class_0': {'a': 0.4442490950707496, 'b': 0.14672834348519914},
#    'class_1': {'a': 0.4442490950707496, 'b': 0.14672834348519914}}},
#  {'poisson': {'class_0': {'lam': 1.5669142240604819},
#    'class_1': {'lam': 1.5669142240604819}}},
#  {'poisson': {'class_0': {'lam': 1.566759861170341},
#    'class_1': {'lam': 1.566759861170341}}},
#  {'binomial': {'class_0': {'n': 883.422785114604, 'p': 0.6236722070556089},
#    'class_1': {'n': 883.422785114604, 'p': 0.6236722070556089}}},
#  {'normal': {'class_0': {'loc': 0.7130634471161099,
#     'scale': 1.5055767063512084},
#    'class_1': {'loc': 0.7130634471161099, 'scale': 1.5055767063512084}}},
#  {'normal': {'class_0': {'loc': 1.8067590411245076,
#     'scale': 1.1473589733445717},
#    'class_1': {'loc': 1.8067590411245076, 'scale': 1.1473589733445717}}},
#  {'beta': {'class_0': {'a': 0.3839121564748609, 'b': 0.9286230067312742},
#    'class_1': {'a': 0.3839121564748609, 'b': 0.9286230067312742}}},
#  {'uniform': {'class_0': {'low': 0.049304244753157755,
#     'high': 0.518861875863902},
#    'class_1': {'low': 0.049304244753157755, 'high': 0.518861875863902}}}]

# %%
generate_data_make_classification_distribution(config, seed=1)[1]
# Out:
# array([[0.03867787, 0.34814422, 0.61323669, ..., 0.31273556, 0.87264638,
#         0.11066697],
#        [0.18673656, 0.39371727, 0.50641925, ..., 0.67115011, 0.99960776,
#         0.12704758],
#        [0.0071857 , 0.58212111, 0.65810766, ..., 0.36580793, 0.00579237,
#         0.11066697],
#        ...,
#        [0.00906791, 0.48407082, 0.3814033 , ..., 0.38228008, 0.9625816 ,
#         0.61885727],
#        [0.41503933, 0.76093466, 0.66346767, ..., 0.57294558, 0.41326849,
#         0.        ],
#        [0.18743483, 0.17251803, 0.55129023, ..., 0.52373337, 0.99999907,
#         0.38114273]])

# %%
data_generation_seed = 1

np.random.seed(data_generation_seed)

informative = np.random.randint(config['data']['number_of_variables']//2, high=config['data']['number_of_variables']+1) #config['data']['number_of_variables']
redundant = np.random.randint(0, high=config['data']['number_of_variables']-informative+1) #0
repeated = config['data']['number_of_variables']-informative-redundant # 0

n_clusters_per_class =  max(2, np.random.randint(0, high=informative//2+1)) #2

X_data, _, distribution_dict_list = make_classification_distribution(n_samples=config['data']['lambda_dataset_size'], 
                                                   n_features=config['data']['number_of_variables'], #The total number of features. These comprise n_informative informative features, n_redundant redundant features, n_repeated duplicated features and n_features-n_informative-n_redundant-n_repeated useless features drawn at random.
                                                   n_informative=informative,#config['data']['number_of_variables'], #The number of informative features. Each class is composed of a number of gaussian clusters each located around the vertices of a hypercube in a subspace of dimension n_informative.
                                                   n_redundant=redundant, #The number of redundant features. These features are generated as random linear combinations of the informative features.
                                                   n_repeated=repeated, #The number of duplicated features, drawn randomly from the informative and the redundant features.
                                                   n_classes=config['data']['num_classes'], 
                                                   n_clusters_per_class=n_clusters_per_class, 
                                                   #flip_y=0.0, #The fraction of samples whose class is assigned randomly. 
                                                   class_sep=0.1, #The factor multiplying the hypercube size. Larger values spread out the clusters/classes and make the classification task easier.
                                                   #hypercube=False, #If True, the clusters are put on the vertices of a hypercube. If False, the clusters are put on the vertices of a random polytope.
                                                   #shift=0.0, #Shift features by the specified value. If None, then features are shifted by a random value drawn in [-class_sep, class_sep].
                                                   #scale=1.0, #Multiply features by the specified value. 
                                                   shuffle=False, 
                                                   random_state=data_generation_seed,
                                                   random_parameters=config['data']['random_parameters_distribution'],
                                                   distrib_param_max=config['data']['distrib_param_max']
                                                   )

X_data
# Out:
# array([[0.        , 0.        , 0.2831028 , ..., 0.92923268, 0.43764736,
#         0.55555556],
#        [0.04001804, 0.        , 0.28818057, ..., 0.64726917, 0.51757522,
#         0.59722222],
#        [0.01763462, 0.41666667, 0.54759595, ..., 0.58119099, 0.68691897,
#         0.56944444],
#        ...,
#        [0.23202275, 0.16666667, 0.42425992, ..., 0.19859893, 0.10029114,
#         0.43055556],
#        [0.32625275, 0.16666667, 0.71878569, ..., 0.08417157, 0.4283184 ,
#         0.36111111],
#        [0.36063655, 0.16666667, 0.83551643, ..., 0.72018456, 0.26673305,
#         0.44444444]])

# %%
data_seed = 1

np.random.seed(data_seed)
informative = np.random.randint(config['data']['number_of_variables']//2, high=config['data']['number_of_variables']+1) #config['data']['number_of_variables']
redundant = np.random.randint(0, high=config['data']['number_of_variables']-informative+1) #0
repeated = config['data']['number_of_variables']-informative-redundant # 0

n_clusters_per_class = max(2, np.random.randint(0, high=informative//2+1)) #2

X_data, y_data, distribution_parameter_list  = make_classification_distribution(n_samples=config['data']['lambda_dataset_size'], 
                                                   n_features=config['data']['number_of_variables'], #The total number of features. These comprise n_informative informative features, n_redundant redundant features, n_repeated duplicated features and n_features-n_informative-n_redundant-n_repeated useless features drawn at random.
                                                   n_informative=informative,#config['data']['number_of_variables'], #The number of informative features. Each class is composed of a number of gaussian clusters each located around the vertices of a hypercube in a subspace of dimension n_informative.
                                                   n_redundant=redundant, #The number of redundant features. These features are generated as random linear combinations of the informative features.
                                                   n_repeated=repeated, #The number of duplicated features, drawn randomly from the informative and the redundant features.
                                                   n_classes=config['data']['num_classes'], 
                                                   n_clusters_per_class=n_clusters_per_class, 
                                                   #flip_y=0.0, #The fraction of samples whose class is assigned randomly. 
                                                   class_sep=0.1, #The factor multiplying the hypercube size. Larger values spread out the clusters/classes and make the classification task easier.
                                                   #hypercube=False, #If True, the clusters are put on the vertices of a hypercube. If False, the clusters are put on the vertices of a random polytope.
                                                   #shift=0.0, #Shift features by the specified value. If None, then features are shifted by a random value drawn in [-class_sep, class_sep].
                                                   #scale=1.0, #Multiply features by the specified value. 
                                                   shuffle=False, 
                                                   random_state=data_seed,
                                                   random_parameters=config['data']['random_parameters_distribution'],
                                                   distrib_param_max=config['data']['distrib_param_max']
                                                   )
X_data
# Out:
# array([[0.        , 0.        , 0.2831028 , ..., 0.92923268, 0.43764736,
#         0.55555556],
#        [0.04001804, 0.        , 0.28818057, ..., 0.64726917, 0.51757522,
#         0.59722222],
#        [0.01763462, 0.41666667, 0.54759595, ..., 0.58119099, 0.68691897,
#         0.56944444],
#        ...,
#        [0.23202275, 0.16666667, 0.42425992, ..., 0.19859893, 0.10029114,
#         0.43055556],
#        [0.32625275, 0.16666667, 0.71878569, ..., 0.08417157, 0.4283184 ,
#         0.36111111],
#        [0.36063655, 0.16666667, 0.83551643, ..., 0.72018456, 0.26673305,
#         0.44444444]])

# %%
((X_valid, y_valid), 
 (X_test, y_test),
 
 history,
 loss_function,
 metrics,
 
 model,
 encoder_model) = interpretation_net_training(
                                      lambda_net_dataset_train, 
                                      lambda_net_dataset_valid, 
                                      lambda_net_dataset_test,
                                      config,
                                      #callback_names=['tensorboard'] #plot_losses
                                     )
# Out:
# ----------------------------------------------- TRAINING INTERPRETATION NET -----------------------------------------------
# 500 10
# (998, 5000, 10) (9980, 5000)
# (8982, 5000, 10) (89820, 5000)
# (998, 5000, 10) (998, 50000)
# (8982, 5000, 10) (8982, 50000)
# Epoch 1/500
# 36/36 - 46s - loss: 0.8121 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.7095 - binary_accuracy_inet_decision_function_fv_metric: 0.5060 - val_loss: 0.6837 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6867 - val_binary_accuracy_inet_decision_function_fv_metric: 0.5481
# Epoch 2/500
# 36/36 - 29s - loss: 0.7054 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6919 - binary_accuracy_inet_decision_function_fv_metric: 0.5293 - val_loss: 0.6797 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6844 - val_binary_accuracy_inet_decision_function_fv_metric: 0.5614
# Epoch 3/500
# 36/36 - 30s - loss: 0.6844 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6853 - binary_accuracy_inet_decision_function_fv_metric: 0.5580 - val_loss: 0.6680 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6785 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6054
# Epoch 4/500
# 36/36 - 30s - loss: 0.6763 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6814 - binary_accuracy_inet_decision_function_fv_metric: 0.5726 - val_loss: 0.6596 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6734 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6125
# Epoch 5/500
# 36/36 - 30s - loss: 0.6749 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6803 - binary_accuracy_inet_decision_function_fv_metric: 0.5751 - val_loss: 0.6611 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6742 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6050
# Epoch 6/500
# 36/36 - 31s - loss: 0.6699 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6773 - binary_accuracy_inet_decision_function_fv_metric: 0.5848 - val_loss: 0.6545 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6706 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6155
# Epoch 7/500
# 36/36 - 31s - loss: 0.6674 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6756 - binary_accuracy_inet_decision_function_fv_metric: 0.5879 - val_loss: 0.6445 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6650 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6263
# Epoch 8/500
# 36/36 - 30s - loss: 0.6618 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6721 - binary_accuracy_inet_decision_function_fv_metric: 0.5953 - val_loss: 0.6400 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6621 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6263
# Epoch 9/500
# 36/36 - 30s - loss: 0.6556 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6674 - binary_accuracy_inet_decision_function_fv_metric: 0.6065 - val_loss: 0.6342 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6592 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6361
# Epoch 10/500
# 36/36 - 30s - loss: 0.6559 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6680 - binary_accuracy_inet_decision_function_fv_metric: 0.6019 - val_loss: 0.6375 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6607 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6294
# Epoch 11/500
# 36/36 - 30s - loss: 0.6516 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6653 - binary_accuracy_inet_decision_function_fv_metric: 0.6084 - val_loss: 0.6349 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6585 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6275
# Epoch 12/500
# 36/36 - 30s - loss: 0.6492 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6640 - binary_accuracy_inet_decision_function_fv_metric: 0.6113 - val_loss: 0.6325 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6570 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6317
# Epoch 13/500
# 36/36 - 30s - loss: 0.6499 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6643 - binary_accuracy_inet_decision_function_fv_metric: 0.6098 - val_loss: 0.6380 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6596 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6251
# Epoch 14/500
# 36/36 - 31s - loss: 0.6463 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6619 - binary_accuracy_inet_decision_function_fv_metric: 0.6130 - val_loss: 0.6281 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6546 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6362
# Epoch 15/500
# 36/36 - 31s - loss: 0.6424 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6591 - binary_accuracy_inet_decision_function_fv_metric: 0.6180 - val_loss: 0.6230 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6524 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6401
# Epoch 16/500
# 36/36 - 31s - loss: 0.6409 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6578 - binary_accuracy_inet_decision_function_fv_metric: 0.6212 - val_loss: 0.6223 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6501 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6361
# Epoch 17/500
# 36/36 - 31s - loss: 0.6366 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6554 - binary_accuracy_inet_decision_function_fv_metric: 0.6244 - val_loss: 0.6219 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6502 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6390
# Epoch 18/500
# 36/36 - 31s - loss: 0.6372 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6561 - binary_accuracy_inet_decision_function_fv_metric: 0.6233 - val_loss: 0.6230 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6505 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6319
# Epoch 19/500
# 36/36 - 31s - loss: 0.6393 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6570 - binary_accuracy_inet_decision_function_fv_metric: 0.6208 - val_loss: 0.6280 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6533 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6317
# Epoch 20/500
# 36/36 - 31s - loss: 0.6428 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6596 - binary_accuracy_inet_decision_function_fv_metric: 0.6170 - val_loss: 0.6228 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6502 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6405
# Epoch 21/500
# 36/36 - 31s - loss: 0.6369 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6558 - binary_accuracy_inet_decision_function_fv_metric: 0.6243 - val_loss: 0.6198 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6498 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6415
# Epoch 22/500
# 36/36 - 31s - loss: 0.6338 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6542 - binary_accuracy_inet_decision_function_fv_metric: 0.6261 - val_loss: 0.6198 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6478 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6429
# Epoch 23/500
# 36/36 - 31s - loss: 0.6359 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6553 - binary_accuracy_inet_decision_function_fv_metric: 0.6223 - val_loss: 0.6215 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6508 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6434
# Epoch 24/500
# 36/36 - 31s - loss: 0.6433 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6602 - binary_accuracy_inet_decision_function_fv_metric: 0.6153 - val_loss: 0.6241 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6511 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6403
# Epoch 25/500
# 36/36 - 31s - loss: 0.6420 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6587 - binary_accuracy_inet_decision_function_fv_metric: 0.6191 - val_loss: 0.6213 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6504 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6422
# Epoch 26/500
# 36/36 - 33s - loss: 0.6376 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6567 - binary_accuracy_inet_decision_function_fv_metric: 0.6212 - val_loss: 0.6208 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6488 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6383
# Epoch 27/500
# 36/36 - 34s - loss: 0.6386 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6575 - binary_accuracy_inet_decision_function_fv_metric: 0.6200 - val_loss: 0.6109 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6441 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6537
# Epoch 28/500
# 36/36 - 35s - loss: 0.6332 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6536 - binary_accuracy_inet_decision_function_fv_metric: 0.6270 - val_loss: 0.6164 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6460 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6473
# Epoch 29/500
# 36/36 - 34s - loss: 0.6309 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6520 - binary_accuracy_inet_decision_function_fv_metric: 0.6300 - val_loss: 0.6120 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6442 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6503
# Epoch 30/500
# 36/36 - 29s - loss: 0.6295 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6511 - binary_accuracy_inet_decision_function_fv_metric: 0.6301 - val_loss: 0.6101 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6425 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6512
# Epoch 31/500
# 36/36 - 28s - loss: 0.6292 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6504 - binary_accuracy_inet_decision_function_fv_metric: 0.6335 - val_loss: 0.6151 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6462 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6475
# Epoch 32/500
# 36/36 - 28s - loss: 0.6312 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6520 - binary_accuracy_inet_decision_function_fv_metric: 0.6298 - val_loss: 0.6230 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6489 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6364
# Epoch 33/500
# 36/36 - 28s - loss: 0.6289 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6516 - binary_accuracy_inet_decision_function_fv_metric: 0.6298 - val_loss: 0.6169 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6467 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6426
# Epoch 34/500
# 36/36 - 31s - loss: 0.6295 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6517 - binary_accuracy_inet_decision_function_fv_metric: 0.6299 - val_loss: 0.6124 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6445 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6474
# Epoch 35/500
# 36/36 - 31s - loss: 0.6285 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6506 - binary_accuracy_inet_decision_function_fv_metric: 0.6297 - val_loss: 0.6197 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6481 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6398
# Epoch 36/500
# 36/36 - 31s - loss: 0.6337 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6546 - binary_accuracy_inet_decision_function_fv_metric: 0.6246 - val_loss: 0.6264 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6517 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6324
# Epoch 37/500
# 36/36 - 31s - loss: 0.6367 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6565 - binary_accuracy_inet_decision_function_fv_metric: 0.6199 - val_loss: 0.6258 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6532 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6338
# Epoch 38/500
# 36/36 - 31s - loss: 0.6348 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6552 - binary_accuracy_inet_decision_function_fv_metric: 0.6239 - val_loss: 0.6259 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6533 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6331
# Epoch 39/500
# 36/36 - 32s - loss: 0.6330 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6534 - binary_accuracy_inet_decision_function_fv_metric: 0.6260 - val_loss: 0.6225 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6502 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6396
# Epoch 40/500
# 36/36 - 31s - loss: 0.6380 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6564 - binary_accuracy_inet_decision_function_fv_metric: 0.6206 - val_loss: 0.6304 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6548 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6312
# Epoch 41/500
# 36/36 - 31s - loss: 0.6364 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6561 - binary_accuracy_inet_decision_function_fv_metric: 0.6207 - val_loss: 0.6238 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6519 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6375
# Epoch 42/500
# 36/36 - 31s - loss: 0.6366 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6559 - binary_accuracy_inet_decision_function_fv_metric: 0.6219 - val_loss: 0.6222 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6493 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6374
# Epoch 43/500
# 36/36 - 31s - loss: 0.6318 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6526 - binary_accuracy_inet_decision_function_fv_metric: 0.6285 - val_loss: 0.6221 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6491 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6366
# Epoch 44/500
# 36/36 - 31s - loss: 0.6302 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6518 - binary_accuracy_inet_decision_function_fv_metric: 0.6293 - val_loss: 0.6158 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6457 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6457
# Epoch 45/500
# 36/36 - 31s - loss: 0.6260 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6493 - binary_accuracy_inet_decision_function_fv_metric: 0.6344 - val_loss: 0.6147 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6442 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6494
# Epoch 46/500
# 36/36 - 31s - loss: 0.6258 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6488 - binary_accuracy_inet_decision_function_fv_metric: 0.6360 - val_loss: 0.6145 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6453 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6475
# Epoch 47/500
# 36/36 - 32s - loss: 0.6292 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6512 - binary_accuracy_inet_decision_function_fv_metric: 0.6289 - val_loss: 0.6244 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6518 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6389
# Epoch 48/500
# 36/36 - 32s - loss: 0.6331 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6538 - binary_accuracy_inet_decision_function_fv_metric: 0.6270 - val_loss: 0.6177 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6478 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6427
# Epoch 49/500
# 36/36 - 31s - loss: 0.6290 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6510 - binary_accuracy_inet_decision_function_fv_metric: 0.6297 - val_loss: 0.6143 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6455 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6444
# Epoch 50/500
# 36/36 - 31s - loss: 0.6233 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6479 - binary_accuracy_inet_decision_function_fv_metric: 0.6366 - val_loss: 0.6067 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6412 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6578
# Epoch 51/500
# 36/36 - 31s - loss: 0.6181 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6449 - binary_accuracy_inet_decision_function_fv_metric: 0.6410 - val_loss: 0.6103 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6414 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6538
# Epoch 52/500
# 36/36 - 31s - loss: 0.6174 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6439 - binary_accuracy_inet_decision_function_fv_metric: 0.6425 - val_loss: 0.6095 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6419 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6519
# Epoch 53/500
# 36/36 - 31s - loss: 0.6228 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6482 - binary_accuracy_inet_decision_function_fv_metric: 0.6348 - val_loss: 0.6107 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6435 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6513
# Epoch 54/500
# 36/36 - 36s - loss: 0.6185 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6448 - binary_accuracy_inet_decision_function_fv_metric: 0.6421 - val_loss: 0.6047 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6400 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6580
# Epoch 55/500
# 36/36 - 32s - loss: 0.6207 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6468 - binary_accuracy_inet_decision_function_fv_metric: 0.6363 - val_loss: 0.6082 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6420 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6525
# Epoch 56/500
# 36/36 - 31s - loss: 0.6207 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6464 - binary_accuracy_inet_decision_function_fv_metric: 0.6388 - val_loss: 0.6078 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6407 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6511
# Epoch 57/500
# 36/36 - 32s - loss: 0.6180 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6453 - binary_accuracy_inet_decision_function_fv_metric: 0.6416 - val_loss: 0.6013 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6364 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6627
# Epoch 58/500
# 36/36 - 32s - loss: 0.6164 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6438 - binary_accuracy_inet_decision_function_fv_metric: 0.6425 - val_loss: 0.6082 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6414 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6552
# Epoch 59/500
# 36/36 - 35s - loss: 0.6185 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6455 - binary_accuracy_inet_decision_function_fv_metric: 0.6413 - val_loss: 0.6074 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6409 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6541
# Epoch 60/500
# 36/36 - 51s - loss: 0.6210 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6467 - binary_accuracy_inet_decision_function_fv_metric: 0.6381 - val_loss: 0.6096 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6438 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6523
# Epoch 61/500
# 36/36 - 43s - loss: 0.6191 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6455 - binary_accuracy_inet_decision_function_fv_metric: 0.6413 - val_loss: 0.6074 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6402 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6526
# Epoch 62/500
# 36/36 - 34s - loss: 0.6153 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6427 - binary_accuracy_inet_decision_function_fv_metric: 0.6461 - val_loss: 0.6064 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6393 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6550
# Epoch 63/500
# 36/36 - 34s - loss: 0.6136 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6422 - binary_accuracy_inet_decision_function_fv_metric: 0.6448 - val_loss: 0.6040 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6383 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6599
# Epoch 64/500
# 36/36 - 34s - loss: 0.6106 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6396 - binary_accuracy_inet_decision_function_fv_metric: 0.6498 - val_loss: 0.6036 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6378 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6573
# Epoch 65/500
# 36/36 - 30s - loss: 0.6094 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6390 - binary_accuracy_inet_decision_function_fv_metric: 0.6517 - val_loss: 0.6029 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6362 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6573
# Epoch 66/500
# 36/36 - 28s - loss: 0.6115 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6399 - binary_accuracy_inet_decision_function_fv_metric: 0.6484 - val_loss: 0.6044 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6389 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6578
# Epoch 67/500
# 36/36 - 28s - loss: 0.6064 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6373 - binary_accuracy_inet_decision_function_fv_metric: 0.6530 - val_loss: 0.5975 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6341 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6625
# Epoch 68/500
# 36/36 - 28s - loss: 0.6033 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6354 - binary_accuracy_inet_decision_function_fv_metric: 0.6572 - val_loss: 0.5963 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6342 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6688
# Epoch 69/500
# 36/36 - 31s - loss: 0.6060 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6378 - binary_accuracy_inet_decision_function_fv_metric: 0.6546 - val_loss: 0.5975 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6350 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6652
# Epoch 70/500
# 36/36 - 31s - loss: 0.6109 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6396 - binary_accuracy_inet_decision_function_fv_metric: 0.6507 - val_loss: 0.6018 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6363 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6611
# Epoch 71/500
# 36/36 - 32s - loss: 0.6067 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6376 - binary_accuracy_inet_decision_function_fv_metric: 0.6543 - val_loss: 0.6005 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6366 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6636
# Epoch 72/500
# 36/36 - 31s - loss: 0.6084 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6391 - binary_accuracy_inet_decision_function_fv_metric: 0.6513 - val_loss: 0.5993 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6351 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6661
# Epoch 73/500
# 36/36 - 31s - loss: 0.6122 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6409 - binary_accuracy_inet_decision_function_fv_metric: 0.6473 - val_loss: 0.6059 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6396 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6584
# Epoch 74/500
# 36/36 - 33s - loss: 0.6138 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6417 - binary_accuracy_inet_decision_function_fv_metric: 0.6473 - val_loss: 0.6053 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6390 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6579
# Epoch 75/500
# 36/36 - 34s - loss: 0.6119 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6408 - binary_accuracy_inet_decision_function_fv_metric: 0.6482 - val_loss: 0.6042 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6376 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6607
# Epoch 76/500
# 36/36 - 32s - loss: 0.6096 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6399 - binary_accuracy_inet_decision_function_fv_metric: 0.6496 - val_loss: 0.6019 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6371 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6608
# Epoch 77/500
# 36/36 - 32s - loss: 0.6141 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6424 - binary_accuracy_inet_decision_function_fv_metric: 0.6453 - val_loss: 0.6009 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6362 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6622
# Epoch 78/500
# 36/36 - 35s - loss: 0.6126 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6422 - binary_accuracy_inet_decision_function_fv_metric: 0.6460 - val_loss: 0.6010 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6361 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6593
# Epoch 79/500
# 36/36 - 34s - loss: 0.6158 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6434 - binary_accuracy_inet_decision_function_fv_metric: 0.6437 - val_loss: 0.6049 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6388 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6599
# Epoch 80/500
# 36/36 - 32s - loss: 0.6126 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6409 - binary_accuracy_inet_decision_function_fv_metric: 0.6484 - val_loss: 0.6022 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6385 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6635
# Epoch 81/500
# 36/36 - 32s - loss: 0.6108 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6403 - binary_accuracy_inet_decision_function_fv_metric: 0.6509 - val_loss: 0.6022 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6386 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6633
# Epoch 82/500
# 36/36 - 32s - loss: 0.6068 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6377 - binary_accuracy_inet_decision_function_fv_metric: 0.6545 - val_loss: 0.5967 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6347 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6680
# Epoch 83/500
# 36/36 - 31s - loss: 0.6056 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6378 - binary_accuracy_inet_decision_function_fv_metric: 0.6533 - val_loss: 0.5915 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6309 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6713
# Epoch 84/500
# 36/36 - 32s - loss: 0.6023 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6350 - binary_accuracy_inet_decision_function_fv_metric: 0.6586 - val_loss: 0.5953 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6323 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6682
# Epoch 85/500
# 36/36 - 32s - loss: 0.6089 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6394 - binary_accuracy_inet_decision_function_fv_metric: 0.6512 - val_loss: 0.6013 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6379 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6659
# Epoch 86/500
# 36/36 - 32s - loss: 0.6111 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6403 - binary_accuracy_inet_decision_function_fv_metric: 0.6505 - val_loss: 0.5984 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6354 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6676
# Epoch 87/500
# 36/36 - 40s - loss: 0.6069 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6380 - binary_accuracy_inet_decision_function_fv_metric: 0.6533 - val_loss: 0.6017 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6371 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6620
# Epoch 88/500
# 36/36 - 57s - loss: 0.6032 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6349 - binary_accuracy_inet_decision_function_fv_metric: 0.6595 - val_loss: 0.5927 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6311 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6733
# Epoch 89/500
# 36/36 - 58s - loss: 0.6049 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6370 - binary_accuracy_inet_decision_function_fv_metric: 0.6561 - val_loss: 0.6008 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6365 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6622
# Epoch 90/500
# 36/36 - 57s - loss: 0.6060 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6371 - binary_accuracy_inet_decision_function_fv_metric: 0.6547 - val_loss: 0.6015 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6355 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6642
# Epoch 91/500
# 36/36 - 56s - loss: 0.6017 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6346 - binary_accuracy_inet_decision_function_fv_metric: 0.6576 - val_loss: 0.5936 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6322 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6694
# Epoch 92/500
# 36/36 - 57s - loss: 0.5987 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6324 - binary_accuracy_inet_decision_function_fv_metric: 0.6621 - val_loss: 0.5954 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6340 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6640
# Epoch 93/500
# 36/36 - 55s - loss: 0.6001 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6341 - binary_accuracy_inet_decision_function_fv_metric: 0.6591 - val_loss: 0.5980 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6338 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6684
# Epoch 94/500
# 36/36 - 52s - loss: 0.6057 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6368 - binary_accuracy_inet_decision_function_fv_metric: 0.6560 - val_loss: 0.5974 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6350 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6671
# Epoch 95/500
# 36/36 - 56s - loss: 0.5984 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6325 - binary_accuracy_inet_decision_function_fv_metric: 0.6629 - val_loss: 0.5924 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6317 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6712
# Epoch 96/500
# 36/36 - 55s - loss: 0.5942 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6297 - binary_accuracy_inet_decision_function_fv_metric: 0.6678 - val_loss: 0.5884 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6286 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6741
# Epoch 97/500
# 36/36 - 54s - loss: 0.5931 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6295 - binary_accuracy_inet_decision_function_fv_metric: 0.6678 - val_loss: 0.5923 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6305 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6739
# Epoch 98/500
# 36/36 - 53s - loss: 0.5964 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6316 - binary_accuracy_inet_decision_function_fv_metric: 0.6636 - val_loss: 0.5999 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6333 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6613
# Epoch 99/500
# 36/36 - 54s - loss: 0.5973 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6329 - binary_accuracy_inet_decision_function_fv_metric: 0.6613 - val_loss: 0.6001 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6357 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6646
# Epoch 100/500
# 36/36 - 53s - loss: 0.5956 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6307 - binary_accuracy_inet_decision_function_fv_metric: 0.6642 - val_loss: 0.5988 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6317 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6659
# Epoch 101/500
# 36/36 - 55s - loss: 0.5933 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6292 - binary_accuracy_inet_decision_function_fv_metric: 0.6674 - val_loss: 0.5949 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6322 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6731
# Epoch 102/500
# 36/36 - 56s - loss: 0.5932 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6304 - binary_accuracy_inet_decision_function_fv_metric: 0.6660 - val_loss: 0.5989 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6343 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6715
# Epoch 103/500
# 36/36 - 54s - loss: 0.5948 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6315 - binary_accuracy_inet_decision_function_fv_metric: 0.6655 - val_loss: 0.5945 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6318 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6686
# Epoch 104/500
# 36/36 - 54s - loss: 0.5916 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6282 - binary_accuracy_inet_decision_function_fv_metric: 0.6698 - val_loss: 0.5936 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6307 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6712
# Epoch 105/500
# 36/36 - 55s - loss: 0.5939 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6306 - binary_accuracy_inet_decision_function_fv_metric: 0.6650 - val_loss: 0.5942 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6321 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6713
# Epoch 106/500
# 36/36 - 54s - loss: 0.5918 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6291 - binary_accuracy_inet_decision_function_fv_metric: 0.6674 - val_loss: 0.5925 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6306 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6739
# Epoch 107/500
# 36/36 - 52s - loss: 0.5853 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6253 - binary_accuracy_inet_decision_function_fv_metric: 0.6736 - val_loss: 0.5935 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6333 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6731
# Epoch 108/500
# 36/36 - 52s - loss: 0.5861 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6264 - binary_accuracy_inet_decision_function_fv_metric: 0.6719 - val_loss: 0.5929 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6305 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6723
# Epoch 109/500
# 36/36 - 53s - loss: 0.5867 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6258 - binary_accuracy_inet_decision_function_fv_metric: 0.6719 - val_loss: 0.5931 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6307 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6686
# Epoch 110/500
# 36/36 - 50s - loss: 0.5887 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6276 - binary_accuracy_inet_decision_function_fv_metric: 0.6702 - val_loss: 0.5929 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6316 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6717
# Epoch 111/500
# 36/36 - 52s - loss: 0.5894 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6262 - binary_accuracy_inet_decision_function_fv_metric: 0.6724 - val_loss: 0.5921 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6298 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6717
# Epoch 112/500
# 36/36 - 52s - loss: 0.5868 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6258 - binary_accuracy_inet_decision_function_fv_metric: 0.6715 - val_loss: 0.5920 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6323 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6702
# Epoch 113/500
# 36/36 - 53s - loss: 0.5874 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6268 - binary_accuracy_inet_decision_function_fv_metric: 0.6704 - val_loss: 0.5931 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6309 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6704
# Epoch 114/500
# 36/36 - 52s - loss: 0.5859 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6264 - binary_accuracy_inet_decision_function_fv_metric: 0.6730 - val_loss: 0.5898 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6281 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6732
# Epoch 115/500
# 36/36 - 50s - loss: 0.5870 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6263 - binary_accuracy_inet_decision_function_fv_metric: 0.6716 - val_loss: 0.5914 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6307 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6728
# Epoch 116/500
# 36/36 - 49s - loss: 0.5869 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6260 - binary_accuracy_inet_decision_function_fv_metric: 0.6730 - val_loss: 0.5940 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6304 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6724
# Epoch 117/500
# 36/36 - 52s - loss: 0.5830 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6243 - binary_accuracy_inet_decision_function_fv_metric: 0.6749 - val_loss: 0.5856 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6263 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6792
# Epoch 118/500
# 36/36 - 50s - loss: 0.5807 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6223 - binary_accuracy_inet_decision_function_fv_metric: 0.6792 - val_loss: 0.5895 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6264 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6760
# Epoch 119/500
# 36/36 - 50s - loss: 0.5813 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6230 - binary_accuracy_inet_decision_function_fv_metric: 0.6777 - val_loss: 0.5890 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6284 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6746
# Epoch 120/500
# 36/36 - 49s - loss: 0.5825 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6242 - binary_accuracy_inet_decision_function_fv_metric: 0.6756 - val_loss: 0.5851 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6267 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6791
# Epoch 121/500
# 36/36 - 31s - loss: 0.5842 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6250 - binary_accuracy_inet_decision_function_fv_metric: 0.6733 - val_loss: 0.5891 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6307 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6755
# Epoch 122/500
# 36/36 - 20s - loss: 0.5844 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6250 - binary_accuracy_inet_decision_function_fv_metric: 0.6732 - val_loss: 0.5856 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6275 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6755
# Epoch 123/500
# 36/36 - 21s - loss: 0.5818 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6235 - binary_accuracy_inet_decision_function_fv_metric: 0.6747 - val_loss: 0.5866 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6280 - val_binary_accuracy_inet_decision_function_fv_metric: 0.
- soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6210 - binary_accuracy_inet_decision_function_fv_metric: 0.6807 - val_loss: 0.5879 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6274 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6762
# Epoch 144/500
# 36/36 - 25s - loss: 0.5788 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6212 - binary_accuracy_inet_decision_function_fv_metric: 0.6791 - val_loss: 0.5912 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6306 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6765
# Epoch 145/500
# 36/36 - 25s - loss: 0.5768 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6207 - binary_accuracy_inet_decision_function_fv_metric: 0.6805 - val_loss: 0.5876 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6270 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6800
# Epoch 146/500
# 36/36 - 18s - loss: 0.5790 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6216 - binary_accuracy_inet_decision_function_fv_metric: 0.6789 - val_loss: 0.5900 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6284 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6793
# Epoch 147/500
# 36/36 - 17s - loss: 0.5742 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6191 - binary_accuracy_inet_decision_function_fv_metric: 0.6830 - val_loss: 0.5861 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6268 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6824
# Epoch 148/500
# 36/36 - 17s - loss: 0.5765 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6202 - binary_accuracy_inet_decision_function_fv_metric: 0.6811 - val_loss: 0.5834 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6251 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6826
# Epoch 149/500
# ...
# Epoch 203/500
# 36/36 - 31s - loss: 0.5551 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6082 - binary_accuracy_inet_decision_function_fv_metric: 0.6974 - val_loss: 0.5737 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6188 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6866
# Epoch 204/500
# 36/36 - 31s - loss: 0.5542 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6067 - binary_accuracy_inet_decision_function_fv_metric: 0.6987 - val_loss: 0.5742 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6195 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6875
# Epoch 205/500
# 36/36 - 30s - loss: 0.5587 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6103 - binary_accuracy_inet_decision_function_fv_metric: 0.6955 - val_loss: 0.5728 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6188 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6857
# Epoch 206/500
# 36/36 - 30s - loss: 0.5562 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6088 - binary_accuracy_inet_decision_function_fv_metric: 0.6957 - val_loss: 0.5750 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6210 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6892
# Epoch 207/500
# 36/36 - 30s - loss: 0.5547 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6084 - binary_accuracy_inet_decision_function_fv_metric: 0.6970 - val_loss: 0.5768 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6210 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6879
# Epoch 208/500
# 36/36 - 30s - loss: 0.5538 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6063 - binary_accuracy_inet_decision_function_fv_metric: 0.7000 - val_loss: 0.5765 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6196 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6858
# Epoch 209/500
# 36/36 - 30s - loss: 0.5553 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6083 - binary_accuracy_inet_decision_function_fv_metric: 0.6973 - val_loss: 0.5748 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6194 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6868
# Epoch 210/500
# 36/36 - 30s - loss: 0.5551 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6067 - binary_accuracy_inet_decision_function_fv_metric: 0.7006 - val_loss: 0.5756 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6196 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6845
# Epoch 211/500
# 36/36 - 30s - loss: 0.5541 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6074 - binary_accuracy_inet_decision_function_fv_metric: 0.6983 - val_loss: 0.5780 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6222 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6825
# Epoch 212/500
# 36/36 - 30s - loss: 0.5521 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6062 - binary_accuracy_inet_decision_function_fv_metric: 0.7012 - val_loss: 0.5766 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6201 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6847
# Epoch 213/500
# 36/36 - 31s - loss: 0.5513 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6056 - binary_accuracy_inet_decision_function_fv_metric: 0.7021 - val_loss: 0.5781 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6218 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6867
# Epoch 214/500
# 36/36 - 32s - loss: 0.5530 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6073 - binary_accuracy_inet_decision_function_fv_metric: 0.6997 - val_loss: 0.5804 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6214 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6800
# Epoch 215/500
# 36/36 - 35s - loss: 0.5508 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6053 - binary_accuracy_inet_decision_function_fv_metric: 0.7003 - val_loss: 0.5757 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6192 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6856
# Epoch 216/500
# 36/36 - 33s - loss: 0.5497 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6046 - binary_accuracy_inet_decision_function_fv_metric: 0.7031 - val_loss: 0.5764 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6210 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6859
# Epoch 217/500
# 36/36 - 26s - loss: 0.5513 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6062 - binary_accuracy_inet_decision_function_fv_metric: 0.7003 - val_loss: 0.5758 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6205 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6865
# Epoch 218/500
# 36/36 - 26s - loss: 0.5510 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6063 - binary_accuracy_inet_decision_function_fv_metric: 0.6997 - val_loss: 0.5781 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6223 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6839
# Epoch 219/500
# 36/36 - 26s - loss: 0.5504 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6056 - binary_accuracy_inet_decision_function_fv_metric: 0.7017 - val_loss: 0.5751 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6196 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6870
# Epoch 220/500
# 36/36 - 27s - loss: 0.5515 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6055 - binary_accuracy_inet_decision_function_fv_metric: 0.7026 - val_loss: 0.5778 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6216 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6830
# Epoch 221/500
# 36/36 - 30s - loss: 0.5513 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6056 - binary_accuracy_inet_decision_function_fv_metric: 0.7021 - val_loss: 0.5784 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6219 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6856
# Epoch 222/500
# 36/36 - 30s - loss: 0.5511 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6060 - binary_accuracy_inet_decision_function_fv_metric: 0.7015 - val_loss: 0.5755 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6206 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6893
# Epoch 223/500
# 36/36 - 30s - loss: 0.5523 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6066 - binary_accuracy_inet_decision_function_fv_metric: 0.7003 - val_loss: 0.5801 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6232 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6851
# Epoch 224/500
# 36/36 - 30s - loss: 0.5507 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6054 - binary_accuracy_inet_decision_function_fv_metric: 0.7012 - val_loss: 0.5776 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6217 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6853
# Epoch 225/500
# 36/36 - 29s - loss: 0.5485 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6041 - binary_accuracy_inet_decision_function_fv_metric: 0.7030 - val_loss: 0.5792 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6211 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6852
# Epoch 226/500
# 36/36 - 29s - loss: 0.5500 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6043 - binary_accuracy_inet_decision_function_fv_metric: 0.7032 - val_loss: 0.5763 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6193 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6877
# Epoch 227/500
# 36/36 - 29s - loss: 0.5515 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6054 - binary_accuracy_inet_decision_function_fv_metric: 0.7010 - val_loss: 0.5805 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6210 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6820
# Epoch 228/500
# 36/36 - 29s - loss: 0.5498 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6040 - binary_accuracy_inet_decision_function_fv_metric: 0.7033 - val_loss: 0.5770 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6201 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6872
# Epoch 229/500
# 36/36 - 29s - loss: 0.5500 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6045 - binary_accuracy_inet_decision_function_fv_metric: 0.7029 - val_loss: 0.5759 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6214 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6881
# Epoch 230/500
# 36/36 - 29s - loss: 0.5501 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6053 - binary_accuracy_inet_decision_function_fv_metric: 0.7012 - val_loss: 0.5725 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6184 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6907
# Epoch 231/500
# 36/36 - 29s - loss: 0.5475 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6039 - binary_accuracy_inet_decision_function_fv_metric: 0.7027 - val_loss: 0.5752 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6184 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6922
# Epoch 232/500
# 36/36 - 29s - loss: 0.5487 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6037 - binary_accuracy_inet_decision_function_fv_metric: 0.7039 - val_loss: 0.5735 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6179 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6916
# Epoch 233/500
# 36/36 - 29s - loss: 0.5493 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6048 - binary_accuracy_inet_decision_function_fv_metric: 0.7027 - val_loss: 0.5773 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6198 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6854
# Epoch 234/500
# 36/36 - 29s - loss: 0.5479 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6032 - binary_accuracy_inet_decision_function_fv_metric: 0.7045 - val_loss: 0.5772 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6205 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6871
# Epoch 235/500
# 36/36 - 29s - loss: 0.5482 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6040 - binary_accuracy_inet_decision_function_fv_metric: 0.7031 - val_loss: 0.5728 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6201 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6911
# Epoch 236/500
# 36/36 - 29s - loss: 0.5459 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6024 - binary_accuracy_inet_decision_function_fv_metric: 0.7063 - val_loss: 0.5760 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6186 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6866
# Epoch 237/500
# 36/36 - 29s - loss: 0.5481 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6038 - binary_accuracy_inet_decision_function_fv_metric: 0.7041 - val_loss: 0.5780 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6209 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6866
# Epoch 238/500
# 36/36 - 29s - loss: 0.5463 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6026 - binary_accuracy_inet_decision_function_fv_metric: 0.7062 - val_loss: 0.5731 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6190 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6902
# Epoch 239/500
# 36/36 - 29s - loss: 0.5482 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6036 - binary_accuracy_inet_decision_function_fv_metric: 0.7033 - val_loss: 0.5767 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6196 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6860
# Epoch 240/500
# 36/36 - 29s - loss: 0.5464 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6039 - binary_accuracy_inet_decision_function_fv_metric: 0.7032 - val_loss: 0.5769 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6202 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6863
# Epoch 241/500
# 36/36 - 29s - loss: 0.5469 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6038 - binary_accuracy_inet_decision_function_fv_metric: 0.7036 - val_loss: 0.5756 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6209 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6859
# Epoch 242/500
# 36/36 - 29s - loss: 0.5462 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6039 - binary_accuracy_inet_decision_function_fv_metric: 0.7037 - val_loss: 0.5738 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6193 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6879
# Epoch 243/500
# 36/36 - 29s - loss: 0.5457 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6028 - binary_accuracy_inet_decision_function_fv_metric: 0.7046 - val_loss: 0.5752 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6206 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6858
# Epoch 244/500
# 36/36 - 30s - loss: 0.5469 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6032 - binary_accuracy_inet_decision_function_fv_metric: 0.7048 - val_loss: 0.5741 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6173 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6919
# Epoch 245/500
# 36/36 - 32s - loss: 0.5450 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6023 - binary_accuracy_inet_decision_function_fv_metric: 0.7050 - val_loss: 0.5704 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6187 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6936
# Epoch 246/500
# 36/36 - 34s - loss: 0.5458 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6033 - binary_accuracy_inet_decision_function_fv_metric: 0.7046 - val_loss: 0.5721 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6182 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6911
# Epoch 247/500
# 36/36 - 31s - loss: 0.5474 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6031 - binary_accuracy_inet_decision_function_fv_metric: 0.7052 - val_loss: 0.5757 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6200 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6914
# Epoch 248/500
# 36/36 - 26s - loss: 0.5474 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6030 - binary_accuracy_inet_decision_function_fv_metric: 0.7050 - val_loss: 0.5799 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6223 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6865
# Epoch 249/500
# 36/36 - 26s - loss: 0.5496 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6045 - binary_accuracy_inet_decision_function_fv_metric: 0.7030 - val_loss: 0.5772 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6187 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6871
# Epoch 250/500
# 36/36 - 25s - loss: 0.5486 - soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6045 - binary_accuracy_inet_decision_function_fv_metric: 0.7034 - val_loss: 0.5728 - val_soft_binary_crossentropy_inet_decision_function_fv_metric: 0.6188 - val_binary_accuracy_inet_decision_function_fv_metric: 0.6870
# Training Time: 2:07:54
# ---------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------ LOADING MODELS -----------------------------------------------------
# Loading Time: 0:00:02

# %%
if nas:
    for trial in history: 
        print(trial.summary())
        
    writepath_nas = './results_nas.csv'

    if different_eval_data:
        flat_config = flatten_dict(config_train)
    else:
        flat_config = flatten_dict(config)    

    if not os.path.exists(writepath_nas):
        with open(writepath_nas, 'w+') as text_file:       
            for key in flat_config.keys():
                text_file.write(key)
                text_file.write(';')         

            for hp in history[0].hyperparameters.values.keys():
                text_file.write(hp + ';')    
               
            text_file.write('score')
            
            text_file.write('\n')

    with open(writepath_nas, 'a+') as text_file:  
        for value in flat_config.values():
            text_file.write(str(value))
            text_file.write(';')

        for hp, value in history[0].hyperparameters.values.items():
            text_file.write(str(value) + ';')        

        
        text_file.write(str(history[0].score))
            
        text_file.write('\n')            

        text_file.close()      
        
else:
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')

# %%
index = 0
if test_size > 0:
    network_parameters = np.array([lambda_net_dataset_test.network_parameters_array[index]])
else:
    network_parameters = np.array([lambda_net_dataset_valid.network_parameters_array[index]])
    
if config['i_net']['data_reshape_version'] == 1 or config['i_net']['data_reshape_version'] == 2:
    network_parameters, network_parameters_flat = restructure_data_cnn_lstm(network_parameters, config, subsequences=None)
elif config['i_net']['data_reshape_version'] == 3: #autoencoder
    network_parameters, network_parameters_flat, _ = autoencode_data(network_parameters, config, encoder_model)    
dt_parameters = model.predict(network_parameters)[0]

if config['function_family']['dt_type'] == 'vanilla':
    image, nodes = anytree_decision_tree_from_parameters(dt_parameters, config=config)
else:
    tree = generate_random_decision_tree(config)
    tree.initialize_from_parameter_array(dt_parameters, reshape=True, config=config)
    image = tree.plot_tree()
image

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 1537)]       0
# __________________________________________________________________________________________________
# hidden1_1664 (Dense)            (None, 1664)         2559232     input[0][0]
# __________________________________________________________________________________________________
# activation1_sigmoid (Activation (None, 1664)         0           hidden1_1664[0][0]
# __________________________________________________________________________________________________
# dropout1_0.1 (Dropout)          (None, 1664)         0           activation1_sigmoid[0][0]
# __________________________________________________________________________________________________
# hidden2_1920 (Dense)            (None, 1920)         3196800     dropout1_0.1[0][0]
# __________________________________________________________________________________________________
# activation2_sigmoid (Activation (None, 1920)         0           hidden2_1920[0][0]
# __________________________________________________________________________________________________
# dropout2_0.5 (Dropout)          (None, 1920)         0           activation2_sigmoid[0][0]
# __________________________________________________________________________________________________
# output_coeff_150 (Dense)        (None, 150)          288150      dropout2_0.5[0][0]
# __________________________________________________________________________________________________
# output_identifier_1 (Dense)     (None, 10)           19210       dropout2_0.5[0][0]
# __________________________________________________________________________________________________
# output_identifier_2 (Dense)     (None, 10)           19210       dropout2_0.5[0][0]
# __________________________________________________________________________________________________
# output_identifier_3 (Dense)     (None, 10)           19210       dropout2_0.5[0][0]
# __________________________________________________________________________________________________
# output_identifier_4 (Dense)     (None, 10)           19210       dropout2_0.5[0][0]
# __________________________________________________________________________________________________
# output_identifier_5 (Dense)     (None, 10)           19210       dropout2_0.5[0][0]
# __________________________________________________________________________________________________
# output_identifier_6 (Dense)     (None, 10)           19210       dropout2_0.5[0][0]
# __________________________________________________________________________________________________
# output_identifier_7 (Dense)     (None, 10)           19210       dropout2_0.5[0][0]
# __________________________________________________________________________________________________
# output_identifier_8 (Dense)     (None, 10)           19210       dropout2_0.5[0][0]
# __________________________________________________________________________________________________
# output_identifier_9 (Dense)     (None, 10)           19210       dropout2_0.5[0][0]
# __________________________________________________________________________________________________
# output_identifier_10 (Dense)    (None, 10)           19210       dropout2_0.5[0][0]
# __________________________________________________________________________________________________
# output_identifier_11 (Dense)    (None, 10)           19210       dropout2_0.5[0][0]
# __________________________________________________________________________________________________
# output_identifier_12 (Dense)    (None, 10)           19210       dropout2_0.5[0][0]
# __________________________________________________________________________________________________
# output_identifier_13 (Dense)    (None, 10)           19210       dropout2_0.5[0][0]
# __________________________________________________________________________________________________
# output_identifier_14 (Dense)    (None, 10)           19210       dropout2_0.5[0][0]
# __________________________________________________________________________________________________
# output_identifier_15 (Dense)    (None, 10)           19210       dropout2_0.5[0][0]
# __________________________________________________________________________________________________
# output_leaf_node_16 (Dense)     (None, 16)           30736       dropout2_0.5[0][0]
# __________________________________________________________________________________________________
# output_combined (Concatenate)   (None, 316)          0           output_coeff_150[0][0]
#                                                                  output_identifier_1[0][0]
#                                                                  output_identifier_2[0][0]
#                                                                  output_identifier_3[0][0]
#                                                                  output_identifier_4[0][0]
#                                                                  output_identifier_5[0][0]
#                                                                  output_identifier_6[0][0]
#                                                                  output_identifier_7[0][0]
#                                                                  output_identifier_8[0][0]
#                                                                  output_identifier_9[0][0]
#                                                                  output_identifier_10[0][0]
#                                                                  output_identifier_11[0][0]
#                                                                  output_identifier_12[0][0]
#                                                                  output_identifier_13[0][0]
#                                                                  output_identifier_14[0][0]
#                                                                  output_identifier_15[0][0]
#                                                                  output_leaf_node_16[0][0]
# ==================================================================================================
# Total params: 6,363,068
# Trainable params: 6,363,068
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
#     Normal: This is useful for looking at means and other linear combinations (e.g. regression coefficients) because of the CLT. Related to that is if something is known to arise due to additive effects of many different small causes then the normal may be a reasonable distribution: for example, many biological measures are the result of multiple genes and multiple environmental factors and therefor are often approximately normal.
#
#     Gamma: Right skewed and useful for things with a natural minimum at 0. Commonly used for elapsed times and some financial variables.
#
#     Exponential: special case of the Gamma. It is memoryless and scales easily.
#
#     Chi-squared (𝜒2): special case of the Gamma. Arises as sum of squared normal variables (so used for variances).
#
#     Beta: Defined between 0 and 1 (but could be transformed to be between other values), useful for proportions or other quantities that must be between 0 and 1.
#
#     Binomial: How many "successes" out of a given number of independent trials with same probability of "success".
#
#     Poisson: Common for counts. Nice properties that if the number of events in a period of time or area follows a Poisson, then the number in twice the time or area still follows the Poisson (with twice the mean): this works for adding Poissons or scaling with values other than 2.
#
#     Note that if events occur over time and the time between occurrences follows an exponential then the number that occur in a time period follows a Poisson.
#
#     Negative Binomial: Counts with minimum 0 (or other value depending on which version) and no upper bound. Conceptually it is the number of "failures" before k "successes". The negative binomial is also a mixture of Poisson variables whose means come from a gamma distribution.
#
#     Geometric: special case for negative binomial where it is the number of "failures" before the 1st "success". If you truncate (round down) an exponential variable to make it discrete, the result is geometric.

# %%
mean_train_parameters = np.round(np.mean(lambda_net_dataset_train.network_parameters_array, axis=0), 5)
std_train_parameters = np.round(np.std(lambda_net_dataset_train.network_parameters_array, axis=0), 5)

(inet_evaluation_result_dict_train, 
 inet_evaluation_result_dict_mean_train, 
 dt_distilled_list_train,
 distances_dict) = evaluate_interpretation_net_synthetic_data(lambda_net_dataset_train.network_parameters_array, 
                                                               lambda_net_dataset_train.X_test_lambda_array,
                                                               model,
                                                               config,
                                                               identifier='train',
                                                               mean_train_parameters=mean_train_parameters,
                                                               std_train_parameters=std_train_parameters,
                                                               network_parameters_train_array=lambda_net_dataset_train.network_parameters_array,
                                                               encoder_model=encoder_model)


(inet_evaluation_result_dict_valid, 
 inet_evaluation_result_dict_mean_valid, 
 dt_distilled_list_valid,
 distances_dict) = evaluate_interpretation_net_synthetic_data(lambda_net_dataset_valid.network_parameters_array, 
                                                               lambda_net_dataset_valid.X_test_lambda_array,
                                                               model,
                                                               config,
                                                               identifier='valid',
                                                               mean_train_parameters=mean_train_parameters,
                                                               std_train_parameters=std_train_parameters,
                                                               network_parameters_train_array=lambda_net_dataset_train.network_parameters_array,
                                                               distances_dict=distances_dict,
                                                               encoder_model=encoder_model)
# Out:
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  20 out of  20 | elapsed:   13.9s finished
#   0%|          | 0/20 [00:00<?, ?it/s]
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  20 out of  20 | elapsed:    2.4s finished
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
#%load_ext autoreload
#%autoreload 2
#set_loky_pickler('pickle')

# %%
#config['i_net']['test_size'] = 100

# %%
if evaluate_distribution and test_size > 0:

    (distances_dict, 
     inet_evaluation_result_dict_test, 
     inet_evaluation_result_dict_complete_by_distribution_test,
     inet_evaluation_result_dict_mean_test,
     inet_evaluation_result_dict_mean_by_distribution_test,
     inet_evaluation_results_test, 
     dt_inet_list_test, 
     dt_distilled_list_test, 
     data_dict_list_test, 
     normalizer_list_list_test,
     test_network_list,
     model_history_list,
     distribution_parameter_list_list) = distribution_evaluation_interpretation_net_synthetic_data(loss_function, 
                                                                                            metrics,
                                                                                            #model,
                                                                                           config,
                                                                                           identifier='test',
                                                                                           lambda_net_parameters_train=lambda_net_dataset_train.network_parameters_array,
                                                                                           mean_train_parameters=mean_train_parameters,
                                                                                           std_train_parameters=std_train_parameters,
                                                                                           distances_dict=distances_dict,
                                                                                           max_distributions_per_class=max_distributions_per_class,#max_distributions_per_class,
                                                                                           flip_percentage=noise_injected_level, #0.1,#
                                                                                           data_noise=data_noise, #0.1,#
                                                                                           #encoder_model=encoder_model,
                                                                                           distribution_list = ['uniform', 'gamma', 'beta', 'poisson', 'normal', 'binomial', 'exponential'],#['uniform', 'gamma', 'beta', 'poisson', 'normal'],# #
                                                                                           random_parameters = random_parameters_distribution, #random_parameters_distribution
                                                                                           verbose=0,
                                                                                           backend='loky',#sequential
                                                                                    )
else:
    (inet_evaluation_result_dict_test, 
     inet_evaluation_result_dict_mean_test, 
     dt_distilled_list_test,
     distances_dict) = evaluate_interpretation_net_synthetic_data(lambda_net_dataset_test.network_parameters_array, 
                                                                   lambda_net_dataset_test.X_test_lambda_array,
                                                                   model,
                                                                   config,
                                                                   identifier='test',
                                                                   mean_train_parameters=mean_train_parameters,
                                                                   std_train_parameters=std_train_parameters,
                                                                   network_parameters_train_array=lambda_net_dataset_train.network_parameters_array,
                                                                   distances_dict=distances_dict,
                                                                   encoder_model=encoder_model)
    
    print_results_synthetic_evaluation(inet_evaluation_result_dict_mean_train, 
                                       inet_evaluation_result_dict_mean_valid, 
                                       inet_evaluation_result_dict_mean_test, 
                                       distances_dict)
# Out:
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   8 out of  20 | elapsed:   38.1s remaining:   57.1s
# [Parallel(n_jobs=10)]: Done  15 out of  20 | elapsed:  1.1min remaining:   21.3s
# [Parallel(n_jobs=10)]: Done  20 out of  20 | elapsed:  1.9min finished

# %%
# generate_dataset_from_distributions

# %%
distribution_parameter_list_list[0]
# Out:
# [{'binomial': {'class_0': {'n': 338.05876425685113, 'p': 0.6481718720511972},
#    'class_1': {'n': 338.05876425685113, 'p': 0.6481718720511972}}},
#  {'uniform': {'class_0': {'low': 0.7781567509498505,
#     'high': 0.832619845547938},
#    'class_1': {'low': 0.7781567509498505, 'high': 0.832619845547938}}},
#  {'gamma': {'class_0': {'shape': 1.136867897737297,
#     'scale': 0.037579600872710284},
#    'class_1': {'shape': 1.136867897737297, 'scale': 0.037579600872710284}}},
#  {'gamma': {'class_0': {'shape': 1.3062800715958753,
#     'scale': 0.3418191702720903},
#    'class_1': {'shape': 1.3062800715958753, 'scale': 0.3418191702720903}}},
#  {'exponential': {'class_0': {'scale': 0.9326215457126126},
#    'class_1': {'scale': 0.9326215457126126}}},
#  {'normal': {'class_0': {'loc': 1.3250537339000885,
#     'scale': 0.027143271224219667},
#    'class_1': {'loc': 1.3250537339000885, 'scale': 0.027143271224219667}}},
#  {'uniform': {'class_0': {'low': 0.44171092124884537,
#     'high': 0.9795867288127285},
#    'class_1': {'low': 0.44171092124884537, 'high': 0.9795867288127285}}},
#  {'poisson': {'class_0': {'lam': 1.33437009730274},
#    'class_1': {'lam': 1.33437009730274}}},
#  {'uniform': {'class_0': {'low': 0.14644176272911225,
#     'high': 0.36980809274834003},
#    'class_1': {'low': 0.14644176272911225, 'high': 0.36980809274834003}}},
#  {'binomial': {'class_0': {'n': 692.8390584876881, 'p': 0.7252542798196405},
#    'class_1': {'n': 692.8390584876881, 'p': 0.7252542798196405}}}]

# %%
lambda_net_dataset_valid.distribution_dict_list_list[0]
# Out:
# [{'gamma': {'class_0': {'shape': 0.41391011594416316,
#     'scale': 1.782755806596126},
#    'class_1': {'shape': 0.41391011594416316, 'scale': 1.782755806596126}}},
#  {'exponential': {'class_0': {'scale': 0.40648253504927356},
#    'class_1': {'scale': 0.40648253504927356}}},
#  {'uniform': {'class_0': {'low': 0.6129549741085206,
#     'high': 0.6397653165970542},
#    'class_1': {'low': 0.6129549741085206, 'high': 0.6397653165970542}}},
#  {'normal': {'class_0': {'loc': 0.20583716044351275,
#     'scale': 1.402585965693691},
#    'class_1': {'loc': 0.20583716044351275, 'scale': 1.402585965693691}}},
#  {'binomial': {'class_0': {'n': 920.9149957974204, 'p': 0.04353021373441257},
#    'class_1': {'n': 920.9149957974204, 'p': 0.04353021373441257}}},
#  {'poisson': {'class_0': {'lam': 1.66221890871239},
#    'class_1': {'lam': 1.66221890871239}}},
#  {'exponential': {'class_0': {'scale': 1.286699832560282},
#    'class_1': {'scale': 1.286699832560282}}},
#  {'gamma': {'class_0': {'shape': 0.3370975131387701,
#     'scale': 1.2847921757745273},
#    'class_1': {'shape': 0.3370975131387701, 'scale': 1.2847921757745273}}},
#  {'binomial': {'class_0': {'n': 130.30113707994173, 'p': 0.16816734259893518},
#    'class_1': {'n': 130.30113707994173, 'p': 0.16816734259893518}}},
#  {'binomial': {'class_0': {'n': 657.2009703278094, 'p': 0.30580002859165534},
#    'class_1': {'n': 657.2009703278094, 'p': 0.30580002859165534}}}]

# %%
#np.mean(inet_evaluation_result_dict_complete_by_distribution_test['uniform']['dt_scores']['accuracy'])

# %%
np.array(inet_evaluation_result_dict_complete_by_distribution_test['uniform']['inet_scores']['accuracy'])
# Out:
# array([0.806, 0.5  , 0.992, 0.858, 1.   , 0.998, 1.   , 0.686, 1.   ,
#        0.938, 0.786, 0.984, 0.976, 0.998, 0.998, 0.96 , 1.   , 0.604,
#        0.92 , 0.858])

# %%
np.array(inet_evaluation_result_dict_complete_by_distribution_test['uniform']['dt_scores']['accuracy'])
# Out:
# array([0.768, 1.   , 1.   , 0.998, 1.   , 1.   , 1.   , 1.   , 1.   ,
#        1.   , 1.   , 1.   , 0.948, 1.   , 1.   , 0.96 , 0.99 , 0.998,
#        0.848, 0.998])

# %%
print('Median I-Net:', np.median(inet_evaluation_result_dict_complete_by_distribution_test['uniform']['inet_scores']['accuracy']))
print('Median DT Distilled:', np.median(inet_evaluation_result_dict_complete_by_distribution_test['uniform']['dt_scores']['accuracy']))
# Out:
# Median I-Net: 0.968
# Median DT Distilled: 1.0

# %%
complete_distribution_evaluation_results = get_complete_distribution_evaluation_results_dataframe(inet_evaluation_result_dict_mean_by_distribution_test)
complete_distribution_evaluation_results.head(20)
# Out:
#              Acc Distilled Train Data  Acc Distilled Data Random  \
# uniform                         0.999                      0.831
# gamma                           0.999                      0.877
# beta                            0.999                      0.874
# poisson                         0.999                      0.894
# normal                          0.999                      0.881
# binomial                        0.999                      0.885
# exponential                     0.999                      0.882
#
#              Acc Distilled  Acc I-Net  Soft BC Distilled Train Data  \
# uniform              0.975      0.893                         0.320
# gamma                0.768      0.893                         0.320
# beta                 0.838      0.893                         0.320
# poisson              0.847      0.893                         0.320
# normal               0.945      0.893                         0.321
# binomial             0.940      0.893                         0.320
# exponential          0.784      0.893                         0.321
#
#              Soft BC Distilled Data Random  Soft BC Distilled  Soft BC I-Net  \
# uniform                              0.521              0.370          0.483
# gamma                                0.562              0.556          0.483
# beta                                 0.509              0.464          0.483
# poisson                              0.527              0.485          0.483
# normal                               0.504              0.407          0.483
# binomial                             0.498              0.412          0.483
# exponential                          0.560              0.539          0.483
#
#              BC Distilled Train Data  BC Distilled Data Random  BC Distilled  \
# uniform                        0.017                     0.373         0.103
# gamma                          0.017                     1.915         4.645
# beta                           0.017                     0.297         1.448
# poisson                        0.017                     0.256         1.122
# normal                         0.024                     0.274         0.321
# binomial                       0.021                     0.262         0.625
# exponential                    0.024                     1.908         2.967
#
#              BC I-Net  F1 Score Distilled Train Data  \
# uniform         0.309                          0.999
# gamma           0.309                          0.999
# beta            0.309                          0.999
# poisson         0.309                          0.999
# normal          0.309                          0.999
# binomial        0.309                          0.999
# exponential     0.309                          0.999
#
#              F1 Score Distilled Data Random  F1 Score Distilled  \
# uniform                               0.808               0.978
# gamma                                 0.730               0.752
# beta                                  0.807               0.786
# poisson                               0.739               0.823
# normal                                0.771               0.948
# binomial                              0.797               0.944
# exponential                           0.732               0.754
#
#              F1 Score I-Net  Runtime Distilled Train Data  \
# uniform               0.865                         0.050
# gamma                 0.865                         0.049
# beta                  0.865                         0.048
# poisson               0.865                         0.007
# normal                0.865                         0.050
# binomial              0.865                         0.015
# exponential           0.865                         0.049
#
#              Runtime Distilled Data Random  Runtime Distilled  Runtime I-Net
# uniform                              0.050              0.050          0.147
# gamma                                0.049              0.049          0.039
# beta                                 0.048              0.048          0.041
# poisson                              0.007              0.007          0.037
# normal                               0.050              0.050          0.038
# binomial                             0.015              0.015          0.037
# exponential                          0.049              0.049          0.039

# %%
complete_distribution_evaluation_results = get_complete_distribution_evaluation_results_dataframe(inet_evaluation_result_dict_mean_by_distribution_test)
complete_distribution_evaluation_results.head(20)
# Out:
#              Acc Distilled Train Data  Acc Distilled Data Random  \
# uniform                         0.999                      0.831
# gamma                           0.999                      0.877
# beta                            0.999                      0.874
# poisson                         0.999                      0.894
# normal                          0.999                      0.881
# binomial                        0.999                      0.885
# exponential                     0.999                      0.882
#
#              Acc Distilled  Acc I-Net  Soft BC Distilled Train Data  \
# uniform              0.975      0.893                         0.320
# gamma                0.768      0.893                         0.320
# beta                 0.838      0.893                         0.320
# poisson              0.847      0.893                         0.320
# normal               0.945      0.893                         0.321
# binomial             0.940      0.893                         0.320
# exponential          0.784      0.893                         0.321
#
#              Soft BC Distilled Data Random  Soft BC Distilled  Soft BC I-Net  \
# uniform                              0.521              0.370          0.483
# gamma                                0.562              0.556          0.483
# beta                                 0.509              0.464          0.483
# poisson                              0.527              0.485          0.483
# normal                               0.504              0.407          0.483
# binomial                             0.498              0.412          0.483
# exponential                          0.560              0.539          0.483
#
#              BC Distilled Train Data  BC Distilled Data Random  BC Distilled  \
# uniform                        0.017                     0.373         0.103
# gamma                          0.017                     1.915         4.645
# beta                           0.017                     0.297         1.448
# poisson                        0.017                     0.256         1.122
# normal                         0.024                     0.274         0.321
# binomial                       0.021                     0.262         0.625
# exponential                    0.024                     1.908         2.967
#
#              BC I-Net  F1 Score Distilled Train Data  \
# uniform         0.309                          0.999
# gamma           0.309                          0.999
# beta            0.309                          0.999
# poisson         0.309                          0.999
# normal          0.309                          0.999
# binomial        0.309                          0.999
# exponential     0.309                          0.999
#
#              F1 Score Distilled Data Random  F1 Score Distilled  \
# uniform                               0.808               0.978
# gamma                                 0.730               0.752
# beta                                  0.807               0.786
# poisson                               0.739               0.823
# normal                                0.771               0.948
# binomial                              0.797               0.944
# exponential                           0.732               0.754
#
#              F1 Score I-Net  Runtime Distilled Train Data  \
# uniform               0.865                         0.050
# gamma                 0.865                         0.049
# beta                  0.865                         0.048
# poisson               0.865                         0.007
# normal                0.865                         0.050
# binomial              0.865                         0.015
# exponential           0.865                         0.049
#
#              Runtime Distilled Data Random  Runtime Distilled  Runtime I-Net
# uniform                              0.050              0.050          0.147
# gamma                                0.049              0.049          0.039
# beta                                 0.048              0.048          0.041
# poisson                              0.007              0.007          0.037
# normal                               0.050              0.050          0.038
# binomial                             0.015              0.015          0.037
# exponential                          0.049              0.049          0.039

# %%
network_distances = get_print_network_distances_dataframe(distances_dict)
network_distances.head(20)
# Out:
#        Average Z-Score (Sample to Train Data)  \
# train                                 822.930
# valid                                 731.645
# test                                  725.867
#
#        Average Distance to Initialization  \
# train                             244.723
# valid                             205.620
# test                              185.222
#
#        Average Mean Distance to Train Data  \
# train                              355.543
# valid                              321.042
# test                               307.127
#
#        Average Distance to closest Train Data Sample  \
# train                                          0.000
# valid                                        163.203
# test                                         146.561
#
#        Average Biggest Distance for Single Neuron  \
# train                                       4.093
# valid                                       3.100
# test                                        3.669
#
#        Minimum Biggest Distance for Single Neuron
# train                                       0.000
# valid                                       1.242
# test                                        1.405

# %%
index = 0
dt_parameters = dt_inet_list_test[0][index]

if config['function_family']['dt_type'] == 'vanilla':
    image, nodes = anytree_decision_tree_from_parameters(dt_parameters, config=config)
else:
    tree = generate_random_decision_tree(config)
    tree.initialize_from_parameter_array(dt_parameters, reshape=True, config=config)
    image = tree.plot_tree()
image

# %%
if config['function_family']['dt_type'] == 'vanilla':
    plt.figure(figsize=(25,8))
    plot_tree(dt_distilled_list_test[0][index][0], fontsize=10)  #fist index=distrib; second index=index; third index=10k vs Train
    image = plt.show()
else:
    image = dt_distilled_list_test[0][index][0].plot_tree()
image

# %%
if config['function_family']['dt_type'] == 'vanilla':
    plt.figure(figsize=(25,8))
    plot_tree(dt_distilled_list_test[0][index][1], fontsize=10)  #fist index=distrib; second index=index; third index=10k vs Train
    image = plt.show()
else:
    image = dt_distilled_list_test[0][index][0].plot_tree()
image

# %%
number = 6

X_data, y_data, distribution_parameter_list, normalizer_list = generate_dataset_from_distributions(['uniform'],# ['uniform', 'normal', 'gamma', 'exponential', 'beta', 'binomial', 'poisson'], 
                                      number, 
                                      10000,
                                      distributions_per_class = 1, 
                                      seed=41,
                                      flip_percentage=0,
                                      config=config)

rand = np.random.RandomState(42)    

colors_list = ['green','blue','yellow','cyan','magenta','pink']

fig,ax = plt.subplots(nrows=3, ncols=4,figsize=(25,10))
plot_index = 0

for i,(colors, distribution_parameter) in enumerate(zip(colors_list[:number], distribution_parameter_list[:number])):
    print(distribution_parameter)

    x = X_data[:,i][np.where(y_data==0)]
    plt.subplot(3,4,plot_index+1)
    plt.hist(x,bins=50,color=colors)
    plt.title(list(distribution_parameter.keys())[0] + ' Class 0' )
    plot_index += 1
    
    x = X_data[:,i][np.where(y_data==1)]
    plt.subplot(3,4,plot_index+1)
    plt.hist(x,bins=50,color=colors)
    plt.title(list(distribution_parameter.keys())[0] + ' Class 1' )
    plot_index += 1
    
fig.subplots_adjust(hspace=0.4,wspace=.3) 
plt.suptitle('Sampling from Various Distributions',fontsize=20)
plt.show()
# Out:
# {'uniform': {'class_0': {'low': 0, 'high': 1.0}, 'class_1': {'low': 0, 'high': 1.0}, 'samples_class_0': 5000}}
# {'uniform': {'class_0': {'low': 0, 'high': 1.0}, 'class_1': {'low': 0, 'high': 1.0}, 'samples_class_0': 5000}}
# {'uniform': {'class_0': {'low': 0, 'high': 1.0}, 'class_1': {'low': 0, 'high': 1.0}, 'samples_class_0': 5000}}
# {'uniform': {'class_0': {'low': 0, 'high': 1.0}, 'class_1': {'low': 0, 'high': 1.0}, 'samples_class_0': 5000}}
# {'uniform': {'class_0': {'low': 0, 'high': 1.0}, 'class_1': {'low': 0, 'high': 1.0}, 'samples_class_0': 5000}}
# {'uniform': {'class_0': {'low': 0, 'high': 1.0}, 'class_1': {'low': 0, 'high': 1.0}, 'samples_class_0': 5000}}

# %%
lambda_net_dataset_valid.distribution_dict_list_list[index]
# Out:
# [{'gamma': {'class_0': {'shape': 0.41391011594416316,
#     'scale': 1.782755806596126},
#    'class_1': {'shape': 0.41391011594416316, 'scale': 1.782755806596126}}},
#  {'exponential': {'class_0': {'scale': 0.40648253504927356},
#    'class_1': {'scale': 0.40648253504927356}}},
#  {'uniform': {'class_0': {'low': 0.6129549741085206,
#     'high': 0.6397653165970542},
#    'class_1': {'low': 0.6129549741085206, 'high': 0.6397653165970542}}},
#  {'normal': {'class_0': {'loc': 0.20583716044351275,
#     'scale': 1.402585965693691},
#    'class_1': {'loc': 0.20583716044351275, 'scale': 1.402585965693691}}},
#  {'binomial': {'class_0': {'n': 920.9149957974204, 'p': 0.04353021373441257},
#    'class_1': {'n': 920.9149957974204, 'p': 0.04353021373441257}}},
#  {'poisson': {'class_0': {'lam': 1.66221890871239},
#    'class_1': {'lam': 1.66221890871239}}},
#  {'exponential': {'class_0': {'scale': 1.286699832560282},
#    'class_1': {'scale': 1.286699832560282}}},
#  {'gamma': {'class_0': {'shape': 0.3370975131387701,
#     'scale': 1.2847921757745273},
#    'class_1': {'shape': 0.3370975131387701, 'scale': 1.2847921757745273}}},
#  {'binomial': {'class_0': {'n': 130.30113707994173, 'p': 0.16816734259893518},
#    'class_1': {'n': 130.30113707994173, 'p': 0.16816734259893518}}},
#  {'binomial': {'class_0': {'n': 657.2009703278094, 'p': 0.30580002859165534},
#    'class_1': {'n': 657.2009703278094, 'p': 0.30580002859165534}}}]

# %%
if True:
    #index = 0
    test_network = network_parameters_to_network(lambda_net_dataset_valid.network_parameters_array[index], config, base_model=None)
    distribution_dict = lambda_net_dataset_valid.distribution_dict_list_list[index]

    X_test = lambda_net_dataset_valid.X_test_lambda_array[index]#generate_random_data_points_custom(config['data']['x_min'], config['data']['x_max'], config['evaluation']['random_evaluation_dataset_size'], config['data']['number_of_variables'], categorical_indices=None, distrib=config['evaluation']['random_evaluation_dataset_distribution'])


    distribution_training = 'uniform'

    evaluation_result_dict, results_list, test_network_parameters, dt_inet, dt_distilled_list = evaluate_network_real_world_data(model,
                                                                                                test_network, 
                                                                                                _, 
                                                                                                X_test, 
                                                                                                dataset_size_list=[10000],
                                                                                                config=config,
                                                                                                distribution=distribution_training)


    results_list_extended = results_list[0]

    results_list = results_list_extended
    evaluation_result_dict = results_list

    test_network_parameters = test_network_parameters#[:1]
    dt_inet = dt_inet#[:1]
    dt_distilled_list = dt_distilled_list#[:1]

    print(evaluation_result_dict)
    
    print('Class 0: ', test_network.predict(X_test[np.where(test_network.predict(X_test).ravel()<0.5)]).shape[0])
    print('Class 1: ', test_network.predict(X_test[np.where(test_network.predict(X_test).ravel()>=0.5)]).shape[0])    
    
    ############################################################################################################################################
    ############################################################################################################################################
    
    colors_list = ['green','blue','yellow','cyan','magenta','pink']

    fig,ax = plt.subplots(nrows=np.ceil(config['data']['number_of_variables']*2/4).astype(int), ncols=4,figsize=(20,15))
    for axis_1 in ax:
        for axis_2 in axis_1:
            axis_2.set_xlim([0, 1])                          
    
    plot_index = 0

    for i in range(X_test.shape[1]):
        distribution_parameter = distribution_dict[i]
        print(distribution_parameter)
        colors = colors_list[i%6]

        x = X_test[:,i][np.where(test_network.predict(X_test).ravel()<=0.5)]
        plt.subplot(np.ceil(config['data']['number_of_variables']*2/4).astype(int), 4,plot_index+1)
        plt.hist(x,bins=10,color=colors)
        plt.title(list(distribution_parameter.keys())[0] + ' Class 0' )
        plot_index += 1

        x = X_test[:,i][np.where(test_network.predict(X_test).ravel()>0.5)]
        plt.subplot(np.ceil(config['data']['number_of_variables']*2/4).astype(int),4,plot_index+1)
        plt.hist(x,bins=10,color=colors)
        plt.title(list(distribution_parameter.keys())[0] + ' Class 1' )
        plot_index += 1

    fig.subplots_adjust(hspace=0.4,wspace=.3) 
    plt.suptitle('Sampling from Various Distributions',fontsize=20)
    plt.show()
# Out:
# {'dt_scores': {'soft_binary_crossentropy': 0.56368506, 'soft_binary_crossentropy_data_random': 0.5222599, 'binary_crossentropy': 0.48371959016913796, 'binary_crossentropy_data_random': 0.3990185988590171, 'accuracy': 0.8318, 'accuracy_data_random': 0.8234, 'f1_score': 0.8453191098032004, 'f1_score_data_random': 0.6824883135562746, 'runtime': 0.04872488975524902}, 'inet_scores': {'soft_binary_crossentropy': 0.5084321, 'binary_crossentropy': 0.37857294340282677, 'accuracy': 0.8482, 'f1_score': 0.8575717770688684, 'runtime': 0.03531813621520996}}
# Class 0:  2514
# Class 1:  2486
# {'gamma': {'class_0': {'shape': 0.41391011594416316, 'scale': 1.782755806596126}, 'class_1': {'shape': 0.41391011594416316, 'scale': 1.782755806596126}}}
# {'exponential': {'class_0': {'scale': 0.40648253504927356}, 'class_1': {'scale': 0.40648253504927356}}}
# {'uniform': {'class_0': {'low': 0.6129549741085206, 'high': 0.6397653165970542}, 'class_1': {'low': 0.6129549741085206, 'high': 0.6397653165970542}}}
# {'normal': {'class_0': {'loc': 0.20583716044351275, 'scale': 1.402585965693691}, 'class_1': {'loc': 0.20583716044351275, 'scale': 1.402585965693691}}}
# {'binomial': {'class_0': {'n': 920.9149957974204, 'p': 0.04353021373441257}, 'class_1': {'n': 920.9149957974204, 'p': 0.04353021373441257}}}
# {'poisson': {'class_0': {'lam': 1.66221890871239}, 'class_1': {'lam': 1.66221890871239}}}
# {'exponential': {'class_0': {'scale': 1.286699832560282}, 'class_1': {'scale': 1.286699832560282}}}
# {'gamma': {'class_0': {'shape': 0.3370975131387701, 'scale': 1.2847921757745273}, 'class_1': {'shape': 0.3370975131387701, 'scale': 1.2847921757745273}}}
# {'binomial': {'class_0': {'n': 130.30113707994173, 'p': 0.16816734259893518}, 'class_1': {'n': 130.30113707994173, 'p': 0.16816734259893518}}}
# {'binomial': {'class_0': {'n': 657.2009703278094, 'p': 0.30580002859165534}, 'class_1': {'n': 657.2009703278094, 'p': 0.30580002859165534}}}

# %%
if True:
    #index = 0
    test_network = network_parameters_to_network(shaped_network_parameters_to_array(test_network_list[index], config), config, base_model=None)
    
    distribution_dict = distribution_parameter_list_list[index] 

    X_test = data_dict_list_test[0]['X_test']#generate_random_data_points_custom(config['data']['x_min'], config['data']['x_max'], config['evaluation']['random_evaluation_dataset_size'], config['data']['number_of_variables'], categorical_indices=None, distrib=config['evaluation']['random_evaluation_dataset_distribution'])


    distribution_training = 'uniform'

    evaluation_result_dict, results_list, test_network_parameters, dt_inet, dt_distilled_list = evaluate_network_real_world_data(model,
                                                                                                test_network, 
                                                                                                _, 
                                                                                                X_test, 
                                                                                                dataset_size_list=[10000],
                                                                                                config=config,
                                                                                                distribution=distribution_training)


    results_list_extended = results_list[0]

    results_list = results_list_extended
    evaluation_result_dict = results_list

    test_network_parameters = test_network_parameters#[:1]
    dt_inet = dt_inet#[:1]
    dt_distilled_list = dt_distilled_list#[:1]

    print(evaluation_result_dict)
    
    print('Class 0: ', test_network.predict(X_test[np.where(test_network.predict(X_test).ravel()<0.5)]).shape[0])
    print('Class 1: ', test_network.predict(X_test[np.where(test_network.predict(X_test).ravel()>=0.5)]).shape[0])
        
    ############################################################################################################################################
    ############################################################################################################################################
    
    colors_list = ['green','blue','yellow','cyan','magenta','pink']

    fig,ax = plt.subplots(nrows=np.ceil(config['data']['number_of_variables']*2/4).astype(int), ncols=4,figsize=(20,15))
    for axis_1 in ax:
        for axis_2 in axis_1:
            axis_2.set_xlim([0, 1])                          
    
    plot_index = 0

    for i in range(X_test.shape[1]):
        distribution_parameter = distribution_dict[i]
        print(distribution_parameter)
        colors = colors_list[i%6]

        x = X_test[:,i][np.where(test_network.predict(X_test).ravel()<=0.5)]
        plt.subplot(np.ceil(config['data']['number_of_variables']*2/4).astype(int), 4,plot_index+1)
        plt.hist(x,bins=10,color=colors)
        plt.title(list(distribution_parameter.keys())[0] + ' Class 0' )
        plot_index += 1

        x = X_test[:,i][np.where(test_network.predict(X_test).ravel()>0.5)]
        plt.subplot(np.ceil(config['data']['number_of_variables']*2/4).astype(int), 4,plot_index+1)
        plt.hist(x,bins=10,color=colors)
        plt.title(list(distribution_parameter.keys())[0] + ' Class 1' )
        plot_index += 1

    fig.subplots_adjust(hspace=0.4,wspace=.3) 
    plt.suptitle('Sampling from Various Distributions',fontsize=20)
    plt.show()
# Out:
# {'dt_scores': {'soft_binary_crossentropy': 0.54151547, 'soft_binary_crossentropy_data_random': 0.52753896, 'binary_crossentropy': 0.4749772088404868, 'binary_crossentropy_data_random': 0.410332359188233, 'accuracy': 0.814, 'accuracy_data_random': 0.8029, 'f1_score': 0.8280961182994455, 'f1_score_data_random': 0.8414192614047792, 'runtime': 0.047876596450805664}, 'inet_scores': {'soft_binary_crossentropy': 0.46674, 'binary_crossentropy': 0.2753778880760074, 'accuracy': 0.806, 'f1_score': 0.7236467236467237, 'runtime': 0.03060436248779297}}
# Class 0:  276
# Class 1:  224
# {'binomial': {'class_0': {'n': 338.05876425685113, 'p': 0.6481718720511972}, 'class_1': {'n': 338.05876425685113, 'p': 0.6481718720511972}}}
# {'uniform': {'class_0': {'low': 0.7781567509498505, 'high': 0.832619845547938}, 'class_1': {'low': 0.7781567509498505, 'high': 0.832619845547938}}}
# {'gamma': {'class_0': {'shape': 1.136867897737297, 'scale': 0.037579600872710284}, 'class_1': {'shape': 1.136867897737297, 'scale': 0.037579600872710284}}}
# {'gamma': {'class_0': {'shape': 1.3062800715958753, 'scale': 0.3418191702720903}, 'class_1': {'shape': 1.3062800715958753, 'scale': 0.3418191702720903}}}
# {'exponential': {'class_0': {'scale': 0.9326215457126126}, 'class_1': {'scale': 0.9326215457126126}}}
# {'normal': {'class_0': {'loc': 1.3250537339000885, 'scale': 0.027143271224219667}, 'class_1': {'loc': 1.3250537339000885, 'scale': 0.027143271224219667}}}
# {'uniform': {'class_0': {'low': 0.44171092124884537, 'high': 0.9795867288127285}, 'class_1': {'low': 0.44171092124884537, 'high': 0.9795867288127285}}}
# {'poisson': {'class_0': {'lam': 1.33437009730274}, 'class_1': {'lam': 1.33437009730274}}}
# {'uniform': {'class_0': {'low': 0.14644176272911225, 'high': 0.36980809274834003}, 'class_1': {'low': 0.14644176272911225, 'high': 0.36980809274834003}}}
# {'binomial': {'class_0': {'n': 692.8390584876881, 'p': 0.7252542798196405}, 'class_1': {'n': 692.8390584876881, 'p': 0.7252542798196405}}}

# %% [markdown]
# # REAL DATA EVALUATION

# %%
dataset_size_list = [1_000, 10_000, 100_000, 1_000_000, 'TRAIN_DATA']
dataset_size_list_print = []
for size in dataset_size_list:
    if type(size) is int:
        size = size//1000
        size = str(size) + 'k'
        dataset_size_list_print.append(size)
    else:
        dataset_size_list_print.append(size)

# %%
#distances_dict = {}
evaluation_result_dict = {}
results_dict = {}
dt_inet_dict = {}
dt_distilled_list_dict = {}
data_dict = {}
normalizer_list_dict = {}

identifier_list = []

# %% [markdown]
# ## ADULT DATASET

# %%
feature_names = [
                 "Age", #0
                 "Workclass",  #1
                 "fnlwgt",  #2
                 "Education",  #3
                 "Education-Num",  #4
                 "Marital Status", #5
                 "Occupation",  #6
                 "Relationship",  #7
                 "Race",  #8
                 "Sex",  #9
                 "Capital Gain",  #10
                 "Capital Loss", #11
                 "Hours per week",  #12
                 "Country", #13
                 "capital_gain" #14
                ] 

adult_data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', names=feature_names, index_col=False)


#adult_data['Workclass'][adult_data['Workclass'] != ' Private'] = 'Other'
#adult_data['Race'][adult_data['Race'] != ' White'] = 'Other'

#adult_data.head()

features_select = [
                 "Sex",  #9 
                 "Race",  #8
                 "Workclass",  #1
                 "Age", #0
                 "fnlwgt",  #2
                 "Education",  #3
                 "Education-Num",  #4
                 "Marital Status", #5
                 "Occupation",  #6
                 "Relationship",  #7
                 "Capital Gain",  #10
                 "Capital Loss", #11
                 "Hours per week",  #12
                 #"Country", #13 
                 "capital_gain"
                  ]

adult_data = adult_data[features_select]

nominal_features_adult = ['Race', 'Workclass', 'Education', "Marital Status", "Occupation", "Relationship"]
ordinal_features_adult = ['Sex']

X_data_adult = adult_data.drop(['capital_gain'], axis = 1)

#y_data_adult = pd.Series(OrdinalEncoder().fit_transform(adult_data['capital_gain'].values.reshape(-1, 1)).flatten(), name='capital_gain')
y_data_adult = ((adult_data['capital_gain'] != ' <=50K') * 1)

# %%
config_train_network_adult = deepcopy(config)
#config_train_network_adult['lambda_net']['batch_lambda'] = 32
#config_train_network_adult['lambda_net']['learning_rate_lambda'] = 0.0003
#config_train_network_adult['lambda_net']['dropout_lambda'] = 0.25
#config_train_network_adult['lambda_net']['epochs_lambda'] = 5

# %%
identifier = 'Adult'
identifier_list.append(identifier)

(distances_dict[identifier], 
 evaluation_result_dict[identifier], 
 results_dict[identifier], 
 dt_inet_dict[identifier], 
 dt_distilled_list_dict[identifier], 
 data_dict[identifier],
 normalizer_list_dict[identifier]) = evaluate_real_world_dataset(model,
                                                                dataset_size_list,
                                                                mean_train_parameters,
                                                                std_train_parameters,
                                                                lambda_net_dataset_train.network_parameters_array,
                                                                X_data_adult, 
                                                                y_data_adult, 
                                                                nominal_features = nominal_features_adult, 
                                                                ordinal_features = ordinal_features_adult,
                                                                config = config,
                                                                config_train_network = config_train_network_adult)

print_head = None
if verbosity > 0:
    print_results_different_data_sizes(results_dict['Adult'], dataset_size_list_print)
    print_network_distances(distances_dict)

    dt_inet_plot = plot_decision_tree_from_parameters(dt_inet_dict[identifier], normalizer_list_dict[identifier], config)
    dt_distilled_plot = plot_decision_tree_from_model(dt_distilled_list_dict[identifier][-2], config)

    display(dt_inet_plot, dt_distilled_plot)

    print_head = data_dict[identifier]['X_train'].head()
print_head
# Out:
# Original Data Shape:  (32561, 65)
# (19537, 10) (19537,)
# (6512, 10) (6512,)
# (6512, 10) (6512,)
# True Ratio:  0.5

# %% [markdown]
# ## Titanic Dataset

# %%
titanic_data = pd.read_csv("./real_world_datasets/Titanic/train.csv")

titanic_data['Age'].fillna(titanic_data['Age'].mean(), inplace = True)
titanic_data['Fare'].fillna(titanic_data['Fare'].mean(), inplace = True)
    
titanic_data['Embarked'].fillna('S', inplace = True)

features_select = [
                    #'Cabin', 
                    #'Ticket', 
                    #'Name', 
                    #'PassengerId'    
                    'Sex',    
                    'Embarked',
                    'Pclass',
                    'Age',
                    'SibSp',    
                    'Parch',
                    'Fare',    
                    'Survived',    
                  ]

titanic_data = titanic_data[features_select]

nominal_features_titanic = ['Embarked']#[1, 2, 7]
ordinal_features_titanic = ['Sex']
    
X_data_titanic = titanic_data.drop(['Survived'], axis = 1)
y_data_titanic = titanic_data['Survived']

# %% [markdown]
#     survival	Survival	0 = No, 1 = Yes
#     pclass	Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd
#     sex	Sex
#     Age	Age in years
#     sibsp	# of siblings / spouses aboard the Titanic
#     parch	# of parents / children aboard the Titanic
#     ticket	Ticket number
#     fare	Passenger fare
#     cabin	Cabin number
#     embarked	Port of Embarkation	C = Cherbourg, Q = Queenstown, S = Southampton

# %%
identifier = 'Titanic'
identifier_list.append(identifier)

(distances_dict[identifier], 
 evaluation_result_dict[identifier], 
 results_dict[identifier], 
 dt_inet_dict[identifier], 
 dt_distilled_list_dict[identifier], 
 data_dict[identifier],
 normalizer_list_dict[identifier]) = evaluate_real_world_dataset(model,
                                                                dataset_size_list,
                                                                mean_train_parameters,
                                                                std_train_parameters,
                                                                lambda_net_dataset_train.network_parameters_array,
                                                                X_data_titanic, 
                                                                y_data_titanic, 
                                                                nominal_features = nominal_features_titanic, 
                                                                ordinal_features = ordinal_features_titanic,
                                                                config = config,
                                                                config_train_network = None)
print_head = None
if verbosity > 0:
    print_results_different_data_sizes(results_dict[identifier], dataset_size_list_print)
    print_network_distances(distances_dict)

    dt_inet_plot = plot_decision_tree_from_parameters(dt_inet_dict[identifier], normalizer_list_dict[identifier], config)
    dt_distilled_plot = plot_decision_tree_from_model(dt_distilled_list_dict[identifier][-2], config)

    display(dt_inet_plot, dt_distilled_plot)

    print_head = data_dict[identifier]['X_train'].head()
print_head
# Out:
# Original Data Shape:  (891, 9)
# (535, 10) (535,)
# (178, 10) (178,)
# (178, 10) (178,)
# True Ratio:  0.5

# %% [markdown]
# ## Absenteeism at Work Dataset

# %%
absenteeism_data = pd.read_csv('real_world_datasets/Absenteeism/absenteeism.csv', delimiter=';')

features_select = [
                           'Disciplinary failure', #CATEGORICAL
                           'Social drinker', #CATEGORICAL
                           'Social smoker', #CATEGORICAL
                           'Transportation expense', 
                           'Distance from Residence to Work',
                           'Service time', 
                           'Age', 
                           'Work load Average/day ', 
                           'Hit target',
                           'Education', 
                           'Son', 
                           'Pet', 
                           'Weight', 
                           'Height', 
                           'Body mass index', 
                           'Absenteeism time in hours'
                        ]

absenteeism_data = absenteeism_data[features_select]

nominal_features_absenteeism = []
ordinal_features_absenteeism = []
    
X_data_absenteeism = absenteeism_data.drop(['Absenteeism time in hours'], axis = 1)
y_data_absenteeism = ((absenteeism_data['Absenteeism time in hours'] > 4) * 1) #absenteeism_data['Absenteeism time in hours']

# %% [markdown]
#     3. Month of absence
#     4. Day of the week (Monday (2), Tuesday (3), Wednesday (4), Thursday (5), Friday (6))
#     5. Seasons (summer (1), autumn (2), winter (3), spring (4))
#     6. Transportation expense
#     7. Distance from Residence to Work (kilometers)
#     8. Service time
#     9. Age
#     10. Work load Average/day
#     11. Hit target
#     12. Disciplinary failure (yes=1; no=0)
#     13. Education (high school (1), graduate (2), postgraduate (3), master and doctor (4))
#     14. Son (number of children)
#     15. Social drinker (yes=1; no=0)
#     16. Social smoker (yes=1; no=0)
#     17. Pet (number of pet)
#     18. Weight
#     19. Height
#     20. Body mass index
#     21. Absenteeism time in hours (target)

# %%
identifier = 'Absenteeism'
identifier_list.append(identifier)

(distances_dict[identifier], 
 evaluation_result_dict[identifier], 
 results_dict[identifier], 
 dt_inet_dict[identifier], 
 dt_distilled_list_dict[identifier], 
 data_dict[identifier],
 normalizer_list_dict[identifier]) = evaluate_real_world_dataset(model,
                                                                dataset_size_list,
                                                                mean_train_parameters,
                                                                std_train_parameters,
                                                                lambda_net_dataset_train.network_parameters_array,
                                                                X_data_absenteeism, 
                                                                y_data_absenteeism, 
                                                                nominal_features = nominal_features_absenteeism, 
                                                                ordinal_features = ordinal_features_absenteeism,
                                                                config = config,
                                                                config_train_network = None)

print_head = None
if verbosity > 0:
    print_results_different_data_sizes(results_dict[identifier], dataset_size_list_print)
    print_network_distances(distances_dict)

    dt_inet_plot = plot_decision_tree_from_parameters(dt_inet_dict[identifier], normalizer_list_dict[identifier], config)
    dt_distilled_plot = plot_decision_tree_from_model(dt_distilled_list_dict[identifier][-2], config)

    display(dt_inet_plot, dt_distilled_plot)

    print_head = data_dict[identifier]['X_train'].head()
print_head
# Out:
# Original Data Shape:  (740, 15)
# (444, 10) (444,)
# (148, 10) (148,)
# (148, 10) (148,)
# True Ratio:  0.5

# %% [markdown]
# # Loan Dataset

# %%
loan_data = pd.read_csv('real_world_datasets/Loan/loan-train.csv', delimiter=',')

loan_data['Gender'].fillna(loan_data['Gender'].mode()[0], inplace=True)
loan_data['Dependents'].fillna(loan_data['Dependents'].mode()[0], inplace=True)
loan_data['Married'].fillna(loan_data['Married'].mode()[0], inplace=True)
loan_data['Self_Employed'].fillna(loan_data['Self_Employed'].mode()[0], inplace=True)
loan_data['LoanAmount'].fillna(loan_data['LoanAmount'].mean(), inplace=True)
loan_data['Loan_Amount_Term'].fillna(loan_data['Loan_Amount_Term'].mean(), inplace=True)
loan_data['Credit_History'].fillna(loan_data['Credit_History'].mean(), inplace=True)

features_select = [
                    #'Loan_ID', 
                    'Gender', #
                    'Married', 
                    'Dependents', 
                    'Education',
                    'Self_Employed', 
                    'ApplicantIncome', 
                    'CoapplicantIncome', 
                    'LoanAmount',
                    'Loan_Amount_Term', 
                    'Credit_History', 
                    'Property_Area', 
                    'Loan_Status'
                    ]

loan_data = loan_data[features_select]

loan_data['Dependents'][loan_data['Dependents'] == '3+'] = 4
loan_data['Dependents'] = loan_data['Dependents'].astype(int)

loan_data['Property_Area'][loan_data['Property_Area'] == 'Rural'] = 0
loan_data['Property_Area'][loan_data['Property_Area'] == 'Semiurban'] = 1
loan_data['Property_Area'][loan_data['Property_Area'] == 'Urban'] = 2
loan_data['Property_Area'] = loan_data['Property_Area'].astype(int)

nominal_features_loan = [
                        #'Dependents',
                        #'Property_Area',    
                        ]


ordinal_features_loan = [
                    'Education',
                    'Gender', 
                    'Married', 
                    'Self_Employed',
                   ]
    
X_data_loan = loan_data.drop(['Loan_Status'], axis = 1)
y_data_loan = ((loan_data['Loan_Status'] == 'Y') * 1)

# %%
identifier = 'Loan House'
identifier_list.append(identifier)

(distances_dict[identifier], 
 evaluation_result_dict[identifier], 
 results_dict[identifier], 
 dt_inet_dict[identifier], 
 dt_distilled_list_dict[identifier], 
 data_dict[identifier],
 normalizer_list_dict[identifier]) = evaluate_real_world_dataset(model,
                                                                dataset_size_list,
                                                                mean_train_parameters,
                                                                std_train_parameters,
                                                                lambda_net_dataset_train.network_parameters_array,
                                                                X_data_loan, 
                                                                y_data_loan, 
                                                                nominal_features = nominal_features_loan, 
                                                                ordinal_features = ordinal_features_loan,
                                                                config = config,
                                                                config_train_network = None)
print_head = None
if verbosity > 0:
    print_results_different_data_sizes(results_dict[identifier], dataset_size_list_print)
    print_network_distances(distances_dict)

    dt_inet_plot = plot_decision_tree_from_parameters(dt_inet_dict[identifier], normalizer_list_dict[identifier], config)
    dt_distilled_plot = plot_decision_tree_from_model(dt_distilled_list_dict[identifier][-2], config)

    display(dt_inet_plot, dt_distilled_plot)

    print_head = data_dict[identifier]['X_train'].head()
print_head
# Out:
# Original Data Shape:  (614, 11)
# (370, 10) (370,)
# (122, 10) (122,)
# (122, 10) (122,)
# True Ratio:  0.5

# %% [markdown]
# # Loan Credit

# %%
loan_credit_data = pd.read_csv('real_world_datasets/Credit Loan/train_split.csv', delimiter=',')

loan_credit_data['emp_title'].fillna(loan_credit_data['emp_title'].mode()[0], inplace=True)
loan_credit_data['emp_length'].fillna(loan_credit_data['emp_length'].mode()[0], inplace=True)
#loan_credit_data['desc'].fillna(loan_credit_data['desc'].mode()[0], inplace=True)
loan_credit_data['title'].fillna(loan_credit_data['title'].mode()[0], inplace=True)
#loan_credit_data['mths_since_last_delinq'].fillna(loan_credit_data['mths_since_last_delinq'].mode()[0], inplace=True)
#loan_credit_data['mths_since_last_record'].fillna(loan_credit_data['mths_since_last_record'].mode()[0], inplace=True)
loan_credit_data['revol_util'].fillna(loan_credit_data['revol_util'].mode()[0], inplace=True)
loan_credit_data['collections_12_mths_ex_med'].fillna(loan_credit_data['collections_12_mths_ex_med'].mode()[0], inplace=True)
#loan_credit_data['mths_since_last_major_derog'].fillna(loan_credit_data['mths_since_last_major_derog'].mode()[0], inplace=True)
#loan_credit_data['verification_status_joint'].fillna(loan_credit_data['verification_status_joint'].mode()[0], inplace=True)
loan_credit_data['tot_coll_amt'].fillna(loan_credit_data['tot_coll_amt'].mode()[0], inplace=True)
loan_credit_data['tot_cur_bal'].fillna(loan_credit_data['tot_cur_bal'].mode()[0], inplace=True)
loan_credit_data['total_rev_hi_lim'].fillna(loan_credit_data['total_rev_hi_lim'].mode()[0], inplace=True)


##remove too many null
#'mths_since_last_delinq','mths_since_last_record', 'mths_since_last_major_derog','pymnt_plan','desc', 'verification_status_joint'


features_select = [
                    #'member_id', 
                    'loan_amnt', 
                    'funded_amnt', 
                    'funded_amnt_inv', 
                    'term',
                    #'batch_enrolled',
                    'int_rate', 
                    'grade', 
                    #'sub_grade', 
                    #'emp_title',
                    'emp_length',
                    'home_ownership', 
                    'annual_inc', 
                    'verification_status',
                    #'pymnt_plan', 
                    #'desc', 
                    'purpose', 
                    'title', 
                    #'zip_code', 
                    #'addr_state',
                    'dti', 
                    'delinq_2yrs', 
                    'inq_last_6mths', 
                    #'mths_since_last_delinq',
                    #'mths_since_last_record',
                    'open_acc', 
                    'pub_rec', 
                    'revol_bal',
                    'revol_util', 
                    'total_acc', 
                    'initial_list_status', 
                    'total_rec_int',
                    'total_rec_late_fee', 
                    'recoveries', 
                    'collection_recovery_fee',
                    'collections_12_mths_ex_med', 
                    #'mths_since_last_major_derog',
                    'application_type', 
                    #'verification_status_joint', 
                    'last_week_pay',
                    'acc_now_delinq', 
                    'tot_coll_amt', 
                    'tot_cur_bal', 
                    'total_rev_hi_lim',
                    'loan_status'
                    ]

loan_credit_data = loan_credit_data[features_select]

nominal_features_loan_credit = [

                        ]
ordinal_features_loan_credit = [
                    #'member_id', 
                    'loan_amnt', 
                    'funded_amnt', 
                    'funded_amnt_inv', 
                    'term',
                    #'batch_enrolled',
                    'int_rate', 
                    'grade', 
                    #'sub_grade', 
                    #'emp_title',
                    'emp_length',
                    'home_ownership', 
                    'annual_inc', 
                    'verification_status',
                    #'pymnt_plan', 
                    #'desc', 
                    'purpose', 
                    'title', 
                    #'zip_code', 
                    #'addr_state',
                    'dti', 
                    'delinq_2yrs', 
                    'inq_last_6mths', 
                    #'mths_since_last_delinq',
                    #'mths_since_last_record',
                    'open_acc', 
                    'pub_rec', 
                    'revol_bal',
                    'revol_util', 
                    'total_acc', 
                    'initial_list_status', 
                    'total_rec_int',
                    'total_rec_late_fee', 
                    'recoveries', 
                    'collection_recovery_fee',
                    'collections_12_mths_ex_med', 
                    #'mths_since_last_major_derog',
                    'application_type', 
                    #'verification_status_joint', 
                    'last_week_pay',
                    'acc_now_delinq', 
                    'tot_coll_amt', 
                    'tot_cur_bal', 
                    'total_rev_hi_lim',
                   ]
    
X_data_loan_credit = loan_credit_data.drop(['loan_status'], axis = 1)
y_data_loan_credit = pd.Series(OrdinalEncoder().fit_transform(loan_credit_data['loan_status'].values.reshape(-1, 1)).flatten(), name='loan_status')

# %%
identifier = 'Loan Credit'
identifier_list.append(identifier)

(distances_dict[identifier], 
 evaluation_result_dict[identifier], 
 results_dict[identifier], 
 dt_inet_dict[identifier], 
 dt_distilled_list_dict[identifier], 
 data_dict[identifier],
 normalizer_list_dict[identifier]) = evaluate_real_world_dataset(model,
                                                                dataset_size_list,
                                                                mean_train_parameters,
                                                                std_train_parameters,
                                                                lambda_net_dataset_train.network_parameters_array,
                                                                X_data_loan_credit, 
                                                                y_data_loan_credit, 
                                                                nominal_features = nominal_features_loan_credit, 
                                                                ordinal_features = ordinal_features_loan_credit,
                                                                config = config,
                                                                config_train_network = None)
print_head = None
if verbosity > 0:
    print_results_different_data_sizes(results_dict[identifier], dataset_size_list_print)
    print_network_distances(distances_dict)

    dt_inet_plot = plot_decision_tree_from_parameters(dt_inet_dict[identifier], normalizer_list_dict[identifier], config)
    dt_distilled_plot = plot_decision_tree_from_model(dt_distilled_list_dict[identifier][-2], config)

    display(dt_inet_plot, dt_distilled_plot)

    print_head = data_dict[identifier]['X_train'].head()
print_head
# Out:
# Original Data Shape:  (63999, 32)
# (38401, 10) (38401,)
# (12799, 10) (12799,)
# (12799, 10) (12799,)
# True Ratio:  0.5

# %% [markdown]
# # Medical Insurance

# %%
medical_insurance_data = pd.read_csv('real_world_datasets/Medical Insurance/insurance.csv', delimiter=',')

features_select = [
                    'age', 
                    'sex', 
                    'bmi', 
                    'children', 
                    'smoker',
                    'region',
                    'charges'
                    ]

medical_insurance_data = medical_insurance_data[features_select]

nominal_features_medical_insurance = [

                        ]
ordinal_features_medical_insurance = [
                    'sex',
                    'region',
                    'smoker'
                   ]

    
X_data_medical_insurance = medical_insurance_data.drop(['charges'], axis = 1)
y_data_medical_insurance = ((medical_insurance_data['charges'] > 10_000) * 1)


print(X_data_medical_insurance.shape)
X_data_medical_insurance.head()
# Out:
# (1338, 6)
#    age     sex    bmi  children smoker     region
# 0   19  female 27.900         0    yes  southwest
# 1   18    male 33.770         1     no  southeast
# 2   28    male 33.000         3     no  southeast
# 3   33    male 22.705         0     no  northwest
# 4   32    male 28.880         0     no  northwest

# %%
identifier = 'Medical Insurance'
identifier_list.append(identifier)

(distances_dict[identifier], 
 evaluation_result_dict[identifier], 
 results_dict[identifier], 
 dt_inet_dict[identifier], 
 dt_distilled_list_dict[identifier], 
 data_dict[identifier],
 normalizer_list_dict[identifier]) = evaluate_real_world_dataset(model,
                                                                dataset_size_list,
                                                                mean_train_parameters,
                                                                std_train_parameters,
                                                                lambda_net_dataset_train.network_parameters_array,
                                                                X_data_medical_insurance, 
                                                                y_data_medical_insurance, 
                                                                nominal_features = nominal_features_medical_insurance, 
                                                                ordinal_features = ordinal_features_medical_insurance,
                                                                config = config,
                                                                config_train_network = None)
print_head = None
if verbosity > 0:
    print_results_different_data_sizes(results_dict[identifier], dataset_size_list_print)
    print_network_distances(distances_dict)

    dt_inet_plot = plot_decision_tree_from_parameters(dt_inet_dict[identifier], normalizer_list_dict[identifier], config)
    dt_distilled_plot = plot_decision_tree_from_model(dt_distilled_list_dict[identifier][-2], config)

    display(dt_inet_plot, dt_distilled_plot)

    print_head = data_dict[identifier]['X_train'].head()
print_head
# Out:
# Original Data Shape:  (1338, 6)
# (804, 10) (804,)
# (267, 10) (267,)
# (267, 10) (267,)
# True Ratio:  0.5

# %% [markdown]
# # Bank Marketing

# %%
bank_data = pd.read_csv('real_world_datasets/Bank Marketing/bank-full.csv', delimiter=';') #bank

features_select = [
                    'age',
                    #'job', 
                    'marital', 
                    'education', 
                    'default',
                    'housing',
                    'loan',
                    #'contact',
                    #'day',
                    #'month',
                    'duration',
                    'campaign',
                    'pdays',
                    'previous',
                    'poutcome',
                    'y',
                    ]

bank_data = bank_data[features_select]

nominal_features_bank = [
                        #'job',
                        'education',
                        #'contact',
                        #'day',
                        #'month',
                        'poutcome',
                        ]
ordinal_features_bank = [
                    'marital',
                    'default',
                    'housing',
                    'loan',
                   ]

    
X_data_bank = bank_data.drop(['y'], axis = 1)
y_data_bank = pd.Series(OrdinalEncoder().fit_transform(bank_data['y'].values.reshape(-1, 1)).flatten(), name='y')

# %%
identifier = 'Bank Marketing'
identifier_list.append(identifier)

(distances_dict[identifier], 
 evaluation_result_dict[identifier], 
 results_dict[identifier], 
 dt_inet_dict[identifier], 
 dt_distilled_list_dict[identifier], 
 data_dict[identifier],
 normalizer_list_dict[identifier]) = evaluate_real_world_dataset(model,
                                                                dataset_size_list,
                                                                mean_train_parameters,
                                                                std_train_parameters,
                                                                lambda_net_dataset_train.network_parameters_array,
                                                                X_data_bank, 
                                                                y_data_bank, 
                                                                nominal_features = nominal_features_bank, 
                                                                ordinal_features = ordinal_features_bank,
                                                                config = config,
                                                                config_train_network = None)
print_head = None
if verbosity > 0:
    print_results_different_data_sizes(results_dict[identifier], dataset_size_list_print)
    print_network_distances(distances_dict)

    dt_inet_plot = plot_decision_tree_from_parameters(dt_inet_dict[identifier], normalizer_list_dict[identifier], config)
    dt_distilled_plot = plot_decision_tree_from_model(dt_distilled_list_dict[identifier][-2], config)

    display(dt_inet_plot, dt_distilled_plot)

    print_head = data_dict[identifier]['X_train'].head()
print_head
# Out:
# Original Data Shape:  (45211, 17)
# (27127, 10) (27127,)
# (9042, 10) (9042,)
# (9042, 10) (9042,)
# True Ratio:  0.5

# %% [markdown]
# # Brest Cancer Wisconsin

# %%
feature_names = [
                'Sample code number',
                'Clump Thickness',
                'Uniformity of Cell Size',
                'Uniformity of Cell Shape',
                'Marginal Adhesion',
                'Single Epithelial Cell Size',
                'Bare Nuclei',
                'Bland Chromatin',
                'Normal Nucleoli',
                'Mitoses',
                'Class',
                ]

bcw_data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data', names=feature_names, index_col=False)

bcw_data['Clump Thickness'][bcw_data['Clump Thickness'] == '?'] = bcw_data['Clump Thickness'].mode()[0]
bcw_data['Uniformity of Cell Size'][bcw_data['Uniformity of Cell Size'] == '?'] = bcw_data['Uniformity of Cell Size'].mode()[0]
bcw_data['Uniformity of Cell Shape'][bcw_data['Uniformity of Cell Shape'] == '?'] = bcw_data['Uniformity of Cell Shape'].mode()[0]
bcw_data['Marginal Adhesion'][bcw_data['Marginal Adhesion'] == '?'] = bcw_data['Marginal Adhesion'].mode()[0]
bcw_data['Single Epithelial Cell Size'][bcw_data['Single Epithelial Cell Size'] == '?'] = bcw_data['Single Epithelial Cell Size'].mode()[0]
bcw_data['Bare Nuclei'][bcw_data['Bare Nuclei'] == '?'] = bcw_data['Bare Nuclei'].mode()[0]
bcw_data['Bland Chromatin'][bcw_data['Bland Chromatin'] == '?'] = bcw_data['Bland Chromatin'].mode()[0]
bcw_data['Normal Nucleoli'][bcw_data['Normal Nucleoli'] == '?'] = bcw_data['Normal Nucleoli'].mode()[0]
bcw_data['Mitoses'][bcw_data['Mitoses'] == '?'] = bcw_data['Mitoses'].mode()[0]

features_select = [
                #'Sample code number',
                'Clump Thickness',
                'Uniformity of Cell Size',
                'Uniformity of Cell Shape',
                'Marginal Adhesion',
                'Single Epithelial Cell Size',
                'Bare Nuclei',
                'Bland Chromatin',
                'Normal Nucleoli',
                'Mitoses',
                'Class',
                    ]

bcw_data = bcw_data[features_select]

nominal_features_bcw = [
                        ]
ordinal_features_bcw = [
                   ]

    
X_data_bcw = bcw_data.drop(['Class'], axis = 1)
y_data_bcw = pd.Series(OrdinalEncoder().fit_transform(bcw_data['Class'].values.reshape(-1, 1)).flatten(), name='Class')

# %%
identifier = 'Brest Cancer Wisconsin'
identifier_list.append(identifier)

(distances_dict[identifier], 
 evaluation_result_dict[identifier], 
 results_dict[identifier], 
 dt_inet_dict[identifier], 
 dt_distilled_list_dict[identifier], 
 data_dict[identifier],
 normalizer_list_dict[identifier]) = evaluate_real_world_dataset(model,
                                                                dataset_size_list,
                                                                mean_train_parameters,
                                                                std_train_parameters,
                                                                lambda_net_dataset_train.network_parameters_array,
                                                                X_data_bcw, 
                                                                y_data_bcw, 
                                                                nominal_features = nominal_features_bcw, 
                                                                ordinal_features = ordinal_features_bcw,
                                                                config = config,
                                                                config_train_network = None)
print_head = None
if verbosity > 0:
    print_results_different_data_sizes(results_dict[identifier], dataset_size_list_print)
    print_network_distances(distances_dict)

    dt_inet_plot = plot_decision_tree_from_parameters(dt_inet_dict[identifier], normalizer_list_dict[identifier], config)
    dt_distilled_plot = plot_decision_tree_from_model(dt_distilled_list_dict[identifier][-2], config)

    display(dt_inet_plot, dt_distilled_plot)

    print_head = data_dict[identifier]['X_train'].head()
print_head
# Out:
# Original Data Shape:  (699, 9)
# (421, 10) (421,)
# (139, 10) (139,)
# (139, 10) (139,)
# True Ratio:  0.5

# %% [markdown]
# # Wisconsin Diagnostic Breast Cancer

# %%
feature_names = [
                'ID number',
                'Diagnosis',
                'radius',# (mean of distances from center to points on the perimeter)
                'texture',# (standard deviation of gray-scale values)
                'perimeter',
                'area',
                'smoothness',# (local variation in radius lengths)
                'compactness',# (perimeter^2 / area - 1.0)
                'concavity',# (severity of concave portions of the contour)
                'concave points',# (number of concave portions of the contour)
                'symmetry',
                'fractal dimension',# ("coastline approximation" - 1)
                ]
#Wisconsin Diagnostic Breast Cancer
wdbc_data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data', names=feature_names, index_col=False)

features_select = [
                    #'ID number',
                    'Diagnosis',
                    'radius',# (mean of distances from center to points on the perimeter)
                    'texture',# (standard deviation of gray-scale values)
                    'perimeter',
                    'area',
                    'smoothness',# (local variation in radius lengths)
                    'compactness',# (perimeter^2 / area - 1.0)
                    'concavity',# (severity of concave portions of the contour)
                    'concave points',# (number of concave portions of the contour)
                    'symmetry',
                    'fractal dimension',# ("coastline approximation" - 1)
                    ]

wdbc_data = wdbc_data[features_select]

nominal_features_wdbc = [
                        ]
ordinal_features_wdbc = [
                   ]

    
X_data_wdbc = wdbc_data.drop(['Diagnosis'], axis = 1)
y_data_wdbc= pd.Series(OrdinalEncoder().fit_transform(wdbc_data['Diagnosis'].values.reshape(-1, 1)).flatten(), name='Diagnosis')

# %%
identifier = 'Wisconsin Diagnostic Breast Cancer'
identifier_list.append(identifier)

(distances_dict[identifier], 
 evaluation_result_dict[identifier], 
 results_dict[identifier], 
 dt_inet_dict[identifier], 
 dt_distilled_list_dict[identifier], 
 data_dict[identifier],
 normalizer_list_dict[identifier]) = evaluate_real_world_dataset(model,
                                                                dataset_size_list,
                                                                mean_train_parameters,
                                                                std_train_parameters,
                                                                lambda_net_dataset_train.network_parameters_array,
                                                                X_data_wdbc, 
                                                                y_data_wdbc, 
                                                                nominal_features = nominal_features_wdbc, 
                                                                ordinal_features = ordinal_features_wdbc,
                                                                config = config,
                                                                config_train_network = None)
print_head = None
if verbosity > 0:
    print_results_different_data_sizes(results_dict[identifier], dataset_size_list_print)
    print_network_distances(distances_dict)

    dt_inet_plot = plot_decision_tree_from_parameters(dt_inet_dict[identifier], normalizer_list_dict[identifier], config)
    dt_distilled_plot = plot_decision_tree_from_model(dt_distilled_list_dict[identifier][-2], config)

    display(dt_inet_plot, dt_distilled_plot)

    print_head = data_dict[identifier]['X_train'].head()
print_head
# Out:
# Original Data Shape:  (569, 10)
# (343, 10) (343,)
# (113, 10) (113,)
# (113, 10) (113,)
# True Ratio:  0.5

# %% [markdown]
# # Wisconsin Prognostic Breast Cancer

# %%
feature_names = [
                'ID number',
                'Diagnosis',
                'radius',# (mean of distances from center to points on the perimeter)
                'texture',# (standard deviation of gray-scale values)
                'perimeter',
                'area',
                'smoothness',# (local variation in radius lengths)
                'compactness',# (perimeter^2 / area - 1.0)
                'concavity',# (severity of concave portions of the contour)
                'concave points',# (number of concave portions of the contour)
                'symmetry',
                'fractal dimension',# ("coastline approximation" - 1)
                ]
#Wisconsin Prognostic Breast Cancer
wpbc_data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wpbc.data', names=feature_names, index_col=False)

features_select = [
                    #'ID number',
                    'Diagnosis',
                    'radius',# (mean of distances from center to points on the perimeter)
                    'texture',# (standard deviation of gray-scale values)
                    'perimeter',
                    'area',
                    'smoothness',# (local variation in radius lengths)
                    'compactness',# (perimeter^2 / area - 1.0)
                    'concavity',# (severity of concave portions of the contour)
                    'concave points',# (number of concave portions of the contour)
                    'symmetry',
                    'fractal dimension',# ("coastline approximation" - 1)
                    ]

wpbc_data = wpbc_data[features_select]

nominal_features_wpbc = [
                        ]
ordinal_features_wpbc = [
                   ]
 
X_data_wpbc = wpbc_data.drop(['Diagnosis'], axis = 1)
y_data_wpbc= pd.Series(OrdinalEncoder().fit_transform(wpbc_data['Diagnosis'].values.reshape(-1, 1)).flatten(), name='Diagnosis')

# %%
identifier = 'Wisconsin Prognostic Breast Cancer'
identifier_list.append(identifier)

(distances_dict[identifier], 
 evaluation_result_dict[identifier], 
 results_dict[identifier], 
 dt_inet_dict[identifier], 
 dt_distilled_list_dict[identifier], 
 data_dict[identifier],
 normalizer_list_dict[identifier]) = evaluate_real_world_dataset(model,
                                                                dataset_size_list,
                                                                mean_train_parameters,
                                                                std_train_parameters,
                                                                lambda_net_dataset_train.network_parameters_array,
                                                                X_data_wpbc, 
                                                                y_data_wpbc, 
                                                                nominal_features = nominal_features_wpbc, 
                                                                ordinal_features = ordinal_features_wpbc,
                                                                config = config,
                                                                config_train_network = None)
print_head = None
if verbosity > 0:
    print_results_different_data_sizes(results_dict[identifier], dataset_size_list_print)
    print_network_distances(distances_dict)

    dt_inet_plot = plot_decision_tree_from_parameters(dt_inet_dict[identifier], normalizer_list_dict[identifier], config)
    dt_distilled_plot = plot_decision_tree_from_model(dt_distilled_list_dict[identifier][-2], config)

    display(dt_inet_plot, dt_distilled_plot)

    print_head = data_dict[identifier]['X_train'].head()
print_head
# Out:
# Original Data Shape:  (198, 10)
# (120, 10) (120,)
# (39, 10) (39,)
# (39, 10) (39,)
# True Ratio:  0.5

# %% [markdown]
# # Abalone

# %%
feature_names = [
                'Sex',#		nominal			M, F, and I (infant)
                'Length',#	continuous	mm	Longest shell measurement
                'Diameter',#	continuous	mm	perpendicular to length
                'Height',#		continuous	mm	with meat in shell
                'Whole weight',#	continuous	grams	whole abalone
                'Shucked weight',#	continuous	grams	weight of meat
                'Viscera weight',#	continuous	grams	gut weight (after bleeding)
                'Shell weight',#	continuous	grams	after being dried
                'Rings',#		integer			+1.5 gives the age in years
                ]

abalone_data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data', names=feature_names, index_col=False)


features_select = [
                'Sex',#		nominal			M, F, and I (infant)
                'Length',#	continuous	mm	Longest shell measurement
                'Diameter',#	continuous	mm	perpendicular to length
                'Height',#		continuous	mm	with meat in shell
                'Whole weight',#	continuous	grams	whole abalone
                'Shucked weight',#	continuous	grams	weight of meat
                'Viscera weight',#	continuous	grams	gut weight (after bleeding)
                'Shell weight',#	continuous	grams	after being dried
                'Rings',#		integer			+1.5 gives the age in years
                    ]

abalone_data = abalone_data[features_select]

nominal_features_abalone = [
                        'Sex',
                        ]
ordinal_features_abalone = [
                   ]
   
X_data_abalone = abalone_data.drop(['Rings'], axis = 1)
y_data_abalone = ((abalone_data['Rings'] > 10) * 1)

# %%
identifier = 'Abalone'
identifier_list.append(identifier)

(distances_dict[identifier], 
 evaluation_result_dict[identifier], 
 results_dict[identifier], 
 dt_inet_dict[identifier], 
 dt_distilled_list_dict[identifier], 
 data_dict[identifier],
 normalizer_list_dict[identifier]) = evaluate_real_world_dataset(model,
                                                                dataset_size_list,
                                                                mean_train_parameters,
                                                                std_train_parameters,
                                                                lambda_net_dataset_train.network_parameters_array,
                                                                X_data_abalone, 
                                                                y_data_abalone, 
                                                                nominal_features = nominal_features_abalone, 
                                                                ordinal_features = ordinal_features_abalone,
                                                                config = config,
                                                                config_train_network = None)
print_head = None
if verbosity > 0:
    print_results_different_data_sizes(results_dict[identifier], dataset_size_list_print)
    print_network_distances(distances_dict)

    dt_inet_plot = plot_decision_tree_from_parameters(dt_inet_dict[identifier], normalizer_list_dict[identifier], config)
    dt_distilled_plot = plot_decision_tree_from_model(dt_distilled_list_dict[identifier][-2], config)

    display(dt_inet_plot, dt_distilled_plot)

    print_head = data_dict[identifier]['X_train'].head()
print_head
# Out:
# Original Data Shape:  (4177, 10)
# (2507, 10) (2507,)
# (835, 10) (835,)
# (835, 10) (835,)
# True Ratio:  0.5

# %% [markdown]
# # Car

# %%
feature_names = [
   'buying',#       v-high, high, med, low
   'maint',#        v-high, high, med, low
   'doors',#        2, 3, 4, 5-more
   'persons',#      2, 4, more
   'lug_boot',#     small, med, big
   'safety',#       low, med, high
   'class',#        unacc, acc, good, v-good
                ]

car_data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/car/car.data', names=feature_names, index_col=False)

features_select = [
                   'buying',#       v-high, high, med, low
                   'maint',#        v-high, high, med, low
                   'doors',#        2, 3, 4, 5-more
                   'persons',#      2, 4, more
                   'lug_boot',#     small, med, big
                   'safety',#       low, med, high
                   'class',#        unacc, acc, good, v-good
                    ]

car_data = car_data[features_select]

nominal_features_car = [
                       'buying',#       v-high, high, med, low
                       'maint',#        v-high, high, med, low
                       'doors',#        2, 3, 4, 5-more
                       'persons',#      2, 4, more
                       'lug_boot',#     small, med, big
                       'safety',#       low, med, high
                        ]

ordinal_features_car = [
                   ]


    
X_data_car = car_data.drop(['class'], axis = 1)
y_data_car = ((car_data['class'] != 'unacc') * 1)

# %%
identifier = 'Car'
identifier_list.append(identifier)

(distances_dict[identifier], 
 evaluation_result_dict[identifier], 
 results_dict[identifier], 
 dt_inet_dict[identifier], 
 dt_distilled_list_dict[identifier], 
 data_dict[identifier],
 normalizer_list_dict[identifier]) = evaluate_real_world_dataset(model,
                                                                dataset_size_list,
                                                                mean_train_parameters,
                                                                std_train_parameters,
                                                                lambda_net_dataset_train.network_parameters_array,
                                                                X_data_car, 
                                                                y_data_car, 
                                                                nominal_features = nominal_features_car, 
                                                                ordinal_features = ordinal_features_car,
                                                                config = config,
                                                                config_train_network = None)
print_head = None
if verbosity > 0:
    print_results_different_data_sizes(results_dict[identifier], dataset_size_list_print)
    print_network_distances(distances_dict)

    dt_inet_plot = plot_decision_tree_from_parameters(dt_inet_dict[identifier], normalizer_list_dict[identifier], config)
    dt_distilled_plot = plot_decision_tree_from_model(dt_distilled_list_dict[identifier][-2], config)

    display(dt_inet_plot, dt_distilled_plot)

    print_head = data_dict[identifier]['X_train'].head()
print_head
# Out:
# Original Data Shape:  (1728, 21)
# (1038, 10) (1038,)
# (345, 10) (345,)
# (345, 10) (345,)
# True Ratio:  0.5

# %% [markdown]
# # Plot and Save Results

# %%
#print_complete_performance_evaluation_results(results_dict, identifier_list, dataset_size_list, dataset_size=10000)
complete_performance_evaluation_results = get_complete_performance_evaluation_results_dataframe(results_dict, 
                                                                                                identifier_list, 
                                                                                                dataset_size_list,
                                                                                                dataset_size=10000)
complete_performance_evaluation_results.head(20)
# Out:
#                                     Acc Distilled  Acc I-Net  \
# Adult                                       0.409      0.844
# Titanic                                     0.770      0.719
# Absenteeism                                 0.662      0.581
# Loan House                                  0.934      0.910
# Loan Credit                                 0.564      0.569
# Medical Insurance                           0.861      0.764
# Bank Marketing                              0.845      0.281
# Brest Cancer Wisconsin                      0.971      0.964
# Wisconsin Diagnostic Breast Cancer          0.398      0.628
# Wisconsin Prognostic Breast Cancer          0.923      0.744
# Abalone                                     0.474      0.726
# Car                                         0.786      0.693
#
#                                     Soft BC Distilled  Soft BC I-Net  \
# Adult                                           0.830          0.688
# Titanic                                         0.558          0.646
# Absenteeism                                     0.639          0.691
# Loan House                                      0.607          0.647
# Loan Credit                                     0.691          0.686
# Medical Insurance                               0.505          0.627
# Bank Marketing                                  0.580          0.707
# Brest Cancer Wisconsin                          0.387          0.506
# Wisconsin Diagnostic Breast Cancer              0.734          0.663
# Wisconsin Prognostic Breast Cancer              0.589          0.665
# Abalone                                         0.755          0.685
# Car                                             0.465          0.585
#
#                                     BC Distilled  BC I-Net  \
# Adult                                      1.320     0.676
# Titanic                                    0.334     0.587
# Absenteeism                                0.568     0.736
# Loan House                                 0.874     0.500
# Loan Credit                                0.705     0.679
# Medical Insurance                          2.798     0.570
# Bank Marketing                             0.440     0.731
# Brest Cancer Wisconsin                     0.124     0.343
# Wisconsin Diagnostic Breast Cancer         1.078     0.660
# Wisconsin Prognostic Breast Cancer         0.216     0.599
# Abalone                                    0.971     0.673
# Car                                        0.324     0.592
#
#                                     F1 Score Distilled  F1 Score I-Net  \
# Adult                                            0.550           0.810
# Titanic                                          0.739           0.554
# Absenteeism                                      0.648           0.367
# Loan House                                       0.959           0.945
# Loan Credit                                      0.557           0.534
# Medical Insurance                                0.853           0.725
# Bank Marketing                                   0.622           0.439
# Brest Cancer Wisconsin                           0.951           0.940
# Wisconsin Diagnostic Breast Cancer               0.564           0.276
# Wisconsin Prognostic Breast Cancer               0.889           0.583
# Abalone                                          0.561           0.763
# Car                                              0.598           0.569
#
#                                     Runtime Distilled  Runtime I-Net
# Adult                                           0.047          0.072
# Titanic                                         0.049          0.079
# Absenteeism                                     0.048          0.075
# Loan House                                      0.047          0.073
# Loan Credit                                     0.047          0.081
# Medical Insurance                               0.048          0.083
# Bank Marketing                                  0.047          0.070
# Brest Cancer Wisconsin                          0.045          0.075
# Wisconsin Diagnostic Breast Cancer              0.046          0.082
# Wisconsin Prognostic Breast Cancer              0.048          0.090
# Abalone                                         0.047          0.082
# Car                                             0.048          0.088

# %%
complete_distribution_evaluation_results = get_complete_distribution_evaluation_results_dataframe(inet_evaluation_result_dict_mean_by_distribution_test)
complete_distribution_evaluation_results.head(20)
# Out:
#              Acc Distilled Train Data  Acc Distilled Data Random  \
# uniform                         0.999                      0.831
# gamma                           0.999                      0.877
# beta                            0.999                      0.874
# poisson                         0.999                      0.894
# normal                          0.999                      0.881
# binomial                        0.999                      0.885
# exponential                     0.999                      0.882
#
#              Acc Distilled  Acc I-Net  Soft BC Distilled Train Data  \
# uniform              0.975      0.893                         0.320
# gamma                0.768      0.893                         0.320
# beta                 0.838      0.893                         0.320
# poisson              0.847      0.893                         0.320
# normal               0.945      0.893                         0.321
# binomial             0.940      0.893                         0.320
# exponential          0.784      0.893                         0.321
#
#              Soft BC Distilled Data Random  Soft BC Distilled  Soft BC I-Net  \
# uniform                              0.521              0.370          0.483
# gamma                                0.562              0.556          0.483
# beta                                 0.509              0.464          0.483
# poisson                              0.527              0.485          0.483
# normal                               0.504              0.407          0.483
# binomial                             0.498              0.412          0.483
# exponential                          0.560              0.539          0.483
#
#              BC Distilled Train Data  BC Distilled Data Random  BC Distilled  \
# uniform                        0.017                     0.373         0.103
# gamma                          0.017                     1.915         4.645
# beta                           0.017                     0.297         1.448
# poisson                        0.017                     0.256         1.122
# normal                         0.024                     0.274         0.321
# binomial                       0.021                     0.262         0.625
# exponential                    0.024                     1.908         2.967
#
#              BC I-Net  F1 Score Distilled Train Data  \
# uniform         0.309                          0.999
# gamma           0.309                          0.999
# beta            0.309                          0.999
# poisson         0.309                          0.999
# normal          0.309                          0.999
# binomial        0.309                          0.999
# exponential     0.309                          0.999
#
#              F1 Score Distilled Data Random  F1 Score Distilled  \
# uniform                               0.808               0.978
# gamma                                 0.730               0.752
# beta                                  0.807               0.786
# poisson                               0.739               0.823
# normal                                0.771               0.948
# binomial                              0.797               0.944
# exponential                           0.732               0.754
#
#              F1 Score I-Net  Runtime Distilled Train Data  \
# uniform               0.865                         0.050
# gamma                 0.865                         0.049
# beta                  0.865                         0.048
# poisson               0.865                         0.007
# normal                0.865                         0.050
# binomial              0.865                         0.015
# exponential           0.865                         0.049
#
#              Runtime Distilled Data Random  Runtime Distilled  Runtime I-Net
# uniform                              0.050              0.050          0.147
# gamma                                0.049              0.049          0.039
# beta                                 0.048              0.048          0.041
# poisson                              0.007              0.007          0.037
# normal                               0.050              0.050          0.038
# binomial                             0.015              0.015          0.037
# exponential                          0.049              0.049          0.039

# %%
#print_network_distances(distances_dict)
network_distances = get_print_network_distances_dataframe(distances_dict)
network_distances.head(20)
# Out:
#                                     Average Z-Score (Sample to Train Data)  \
# train                                                