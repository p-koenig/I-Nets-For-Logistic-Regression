# %% [markdown]
# # Inerpretation-Net Training

# %% [markdown]
# ## Specitication of Experiment Settings

# %%
#######################################################################################################################################
###################################################### CONFIG FILE ####################################################################
#######################################################################################################################################
sleep_time = 0 #minutes

config = {
    'data': {
        'd': 3, #degree
        'n': 1, #number of variables
        'monomial_vars': None, #int or None
        'laurent': True, #use Laurent polynomials (negative degree with up to -d)  
        'neg_d': 1,#int or None
        'neg_d_prob': 0.2,
        'sparsity': None,
        'sample_sparsity': None,
        'x_max': 1,
        'x_min': 0.05,
        'x_distrib': 'uniform', #'normal', 'uniform', 'beta', 'Gamma', 'laplace'
        'a_max': 1,
        'a_min': -1,
        'lambda_nets_total': 50000,
        'noise': 0,
        'noise_distrib': 'normal', #'normal', 'uniform', 'beta', 'Gamma', 'laplace'
        
        'border_min': 0.2, #needs to be between 0 and (x_max-x_min)/2
        'border_max': 0.4,
        'lower_degree_prob': 0.5,
        'a_zero_prob': 0.25,
        'a_random_prob': 0.1,      
        
        'same_training_all_lambda_nets': False,

        'fixed_seed_lambda_training': True,
        'fixed_initialization_lambda_training': False,
        'number_different_lambda_trainings': 1,
    },
    'lambda_net': {
        'epochs_lambda': 1000,
        'early_stopping_lambda': True,  #if early stopping is used, multi_epoch_analysis is deactivated
        'early_stopping_min_delta_lambda': 1e-4,
        'batch_lambda': 64,
        'dropout': 0,
        'lambda_network_layers': [5*'sparsity'],
        'optimizer_lambda': 'adam',
        'loss_lambda': 'mae',
        'number_of_lambda_weights': None,
        'lambda_dataset_size': 5000,
    },
    'i_net': {
        'optimizer': 'custom',#adam
        'inet_loss': 'mae',
        'inet_metrics': ['r2'],
        'dropout': 0.25,
        'dropout_output': 0,
        'epochs': 500, 
        'early_stopping': True,
        'batch_size': 256,
        'dense_layers': [512, 1024],
        'convolution_layers': None,
        'lstm_layers': None,
        'interpretation_dataset_size': 50000,
                
        'interpretation_net_output_monomials': 3, #(None, int) #CONSTANT IS NOT INCLUDED
        'interpretation_net_output_shape': None, #calculated automatically later
        'test_size': 100, #Float for fraction, Int for number 0
        
        'normalize_inet_data': True,

        'evaluate_with_real_function': False,
        'consider_labels_training': False,
                      
        'data_reshape_version': None, #default to 2 options:(None, 0,1 2)
        'nas': False,
        'nas_type': 'SEQUENTIAL', #options:(None, 'SEQUENTIAL', 'CNN', 'LSTM', 'CNN-LSTM', 'CNN-LSTM-parallel')      
        'nas_trials': 100,
    },
    'evaluation': {   
        'inet_holdout_seed_evaluation': False,
        
        #set if multi_epoch_analysis should be performed
        'multi_epoch_analysis': True,
        'each_epochs_save_lambda': 100,
        'epoch_start': 0, #use to skip first epochs in multi_epoch_analysis
        
        #set if samples analysis should be performed
        'samples_list': None,#[100, 500, 750, 1000, 2500, 5000, 7500, 10000, 15000, 20000, 25000, 28125] 
       
        'random_evaluation_dataset_size': 500,
    },
    'computation':{
        'n_jobs': 7,
        'use_gpu': False,
        'gpu_numbers': '0',
        'RANDOM_SEED': 42,   
    }
}

# %% [markdown]
# ## Imports

# %%
#######################################################################################################################################
########################################### IMPORT GLOBAL VARIABLES FROM CONFIG #######################################################
#######################################################################################################################################
globals().update(config['data'])
globals().update(config['lambda_net'])
globals().update(config['i_net'])
globals().update(config['evaluation'])
globals().update(config['computation'])

# %%
#######################################################################################################################################
##################################################### IMPORT LIBRARIES ################################################################
#######################################################################################################################################
from itertools import product       
from tqdm import tqdm_notebook as tqdm
import pickle
import numpy as np
import pandas as pd
import scipy as sp
import timeit
import psutil

from functools import reduce
from more_itertools import random_product 
from sklearn.preprocessing import Normalizer

import sys
import os
import shutil

import logging

from prettytable import PrettyTable
import colored
import math

import time
from datetime import datetime
from collections.abc import Iterable


from joblib import Parallel, delayed

from scipy.integrate import quad

from sklearn.model_selection import cross_val_score, train_test_split, StratifiedKFold, KFold, ParameterGrid, ParameterSampler
from sklearn.metrics import accuracy_score, log_loss, roc_auc_score, f1_score, mean_absolute_error, r2_score

from similaritymeasures import frechet_dist, area_between_two_curves, dtw
import keras
from keras.models import Sequential
from keras.layers.core import Dense, Dropout
from keras.utils import plot_model
from IPython.display import Image

import keras.backend as K
from livelossplot import PlotLossesKerasTF
from keras_tqdm import TQDMNotebookCallback
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

from matplotlib import pyplot as plt
import seaborn as sns


import tensorflow as tf
import random 


import warnings


from IPython.display import display, Math, Latex, clear_output

# %%
#######################################################################################################################################
################################################### VARIABLE ADJUSTMENTS ##############################################################
#######################################################################################################################################
variables = 'abcdefghijklmnopqrstuvwxyz'[:n]

n_jobs = min((epochs_lambda//each_epochs_save_lambda+1, n_jobs)) if multi_epoch_analysis else min(len(samples_list), n_jobs) if samples_list!=None else 1

multi_epoch_analysis = False if early_stopping_lambda else multi_epoch_analysis #deactivate multi_epoch_analysis if early stopping is used

each_epochs_save_lambda = each_epochs_save_lambda if multi_epoch_analysis else epochs_lambda
epochs_save_range_lambda = range(epoch_start//each_epochs_save_lambda, epochs_lambda//each_epochs_save_lambda) if each_epochs_save_lambda == 1 else range(epoch_start//each_epochs_save_lambda, epochs_lambda//each_epochs_save_lambda+1) if multi_epoch_analysis else range(1,2)

data_reshape_version = 2 if data_reshape_version == None and (convolution_layers != None or lstm_layers != None or (nas and nas_type != 'SEQUENTIAL')) else data_reshape_version
#######################################################################################################################################
###################################################### SET VARIABLES + DESIGN #########################################################
#######################################################################################################################################

#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 
os.environ['CUDA_VISIBLE_DEVICES'] = gpu_numbers if use_gpu else ''

logging.getLogger('tensorflow').disabled = True

sns.set_style("darkgrid")
#np.set_printoptions(suppress=True)

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
if int(tf.__version__[0]) >= 2:
    tf.random.set_seed(RANDOM_SEED)
else:
    tf.set_random_seed(RANDOM_SEED)
    
    
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.max_columns', 500)

warnings.filterwarnings('ignore')

sys.path.append('..')

# %%
from utilities.utility_functions import flatten, rec_gen

list_of_monomial_identifiers_extended = []

if laurent:
    variable_sets = [list(flatten([[_d for _d in range(d+1)], [-_d for _d in range(1, neg_d+1)]])) for _ in range(n)]
    list_of_monomial_identifiers_extended = rec_gen(variable_sets)    
        
    print('List length: ' + str(len(list_of_monomial_identifiers_extended)))
    #print('Number of monomials in a polynomial with ' + str(n) + ' variables and degree ' + str(d) + ': ' + str(sparsity))
    #print('Sparsity:' + str(sparsity))
    print(list_of_monomial_identifiers_extended)        
else:
    variable_sets = [[_d for _d in range(d+1)] for _ in range(n)]  
    list_of_monomial_identifiers_extended = rec_gen(variable_sets)

    print('List length: ' + str(len(list_of_monomial_identifiers_extended)))
    #print('Number of monomials in a polynomial with ' + str(n) + ' variables and degree ' + str(d) + ': ' + str(sparsity))
    #print('Sparsity: ' + str(sparsity))
    print(list_of_monomial_identifiers_extended)

list_of_monomial_identifiers = []
for monomial_identifier in tqdm(list_of_monomial_identifiers_extended):
    if np.sum(monomial_identifier) <= d:
        if monomial_vars == None or len(list(filter(lambda x: x != 0, monomial_identifier))) <= monomial_vars:
            list_of_monomial_identifiers.append(monomial_identifier)

print('List length: ' + str(len(list_of_monomial_identifiers)))
#print('Number of monomials in a polynomial with ' + str(n) + ' variables and degree ' + str(d) + ': ' + str(sparsity))
#print('Sparsity: ' + str(sparsity))
print(list_of_monomial_identifiers)
# Out:
# List length: 5
# [[0], [1], [2], [3], [-1]]
#   0%|          | 0/5 [00:00<?, ?it/s]
# List length: 5
# [[0], [1], [2], [3], [-1]]

# %%
from utilities.InterpretationNet import *
from utilities.LambdaNet import *
from utilities.metrics import *
from utilities.utility_functions import *
#######################################################################################################################################
####################################################### CONFIG ADJUSTMENTS ############################################################
#######################################################################################################################################
config['evaluation']['multi_epoch_analysis'] = multi_epoch_analysis
config['evaluation']['each_epochs_save_lambda'] = each_epochs_save_lambda
config['i_net']['data_reshape_version'] = data_reshape_version

config['data']['sparsity'] = nCr(config['data']['n']+config['data']['d'], config['data']['d']) if not laurent else len(list_of_monomial_identifiers)
config['data']['sample_sparsity'] = config['data']['sparsity'] if config['data']['sample_sparsity'] == None else config['data']['sample_sparsity']

config['i_net']['interpretation_net_output_shape'] = config['data']['sparsity'] if config['i_net']['interpretation_net_output_monomials'] is None else config['data']['sparsity']*config['i_net']['interpretation_net_output_monomials']+config['i_net']['interpretation_net_output_monomials']


transformed_layers = []
for layer in config['lambda_net']['lambda_network_layers']:
    if type(layer) == str:
        transformed_layers.append(layer.count('sparsity')*config['data']['sparsity'])
    else:
        transformed_layers.append(layer)
config['lambda_net']['lambda_network_layers'] = transformed_layers

layers_with_input_output = list(flatten([[config['data']['n']], config['lambda_net']['lambda_network_layers'], [1]]))
number_of_lambda_weights = 0
for i in range(len(layers_with_input_output)-1):
    number_of_lambda_weights += (layers_with_input_output[i]+1)*layers_with_input_output[i+1]  
config['lambda_net']['number_of_lambda_weights'] = number_of_lambda_weights
    
#######################################################################################################################################
################################################## UPDATE VARIABLES ###################################################################
#######################################################################################################################################
globals().update(config['data'])
globals().update(config['lambda_net'])
globals().update(config['i_net'])
globals().update(config['evaluation'])
globals().update(config['computation'])



initialize_LambdaNet_config_from_curent_notebook(config)
initialize_metrics_config_from_curent_notebook(config)
initialize_utility_functions_config_from_curent_notebook(config)
initialize_InterpretationNet_config_from_curent_notebook(config)


#######################################################################################################################################
###################################################### PATH + FOLDER CREATION #########################################################
#######################################################################################################################################
globals().update(generate_paths(path_type='interpretation_net'))
create_folders_inet()

#######################################################################################################################################
############################################################ SLEEP TIMER ##############################################################
#######################################################################################################################################
sleep_minutes(sleep_time)

# %%
print(path_identifier_interpretation_net_data)

print(path_identifier_lambda_net_data)
# Out:
# inet_dense512-1024-output_18_drop0.25e500b256_custom/lnets_50000_25-1000e_ES0.0001_64b_adam_mae_train_5000_diffX_1-FixSeed_42/var_1_d_3_laurent_negd_1_prob_0.2_spars_5_amin_-1_amax_1_xdist_uniform_noise_normal_0bmin0.2bmax0.4lowd0.5azero0.25arand0.1
# lnets_50000_25-1000e_ES0.0001_64b_adam_mae_train_5000_diffX_1-FixSeed_42/var_1_d_3_laurent_negd_1_prob_0.2_spars_5_amin_-1_amax_1_xdist_uniform_noise_normal_0bmin0.2bmax0.4lowd0.5azero0.25arand0.1

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print("Num XLA-GPUs Available: ", len(tf.config.experimental.list_physical_devices('XLA_GPU')))
# Out:
# Num GPUs Available:  0
# Num XLA-GPUs Available:  0

# %% [markdown]
# ## Load Data and Generate Datasets

# %%
def load_lambda_nets(index):
    
    if psutil.virtual_memory().percent > 80:
        raise SystemExit("Out of RAM!")
    
    directory = './data/weights/' + 'weights_' + path_identifier_lambda_net_data + '/'
    path_weights = directory + 'weights_epoch_' + str(index).zfill(3) + '.txt'
    path_X_data = directory + 'lambda_X_test_data.txt'
    path_y_data = directory + 'lambda_y_test_data.txt'        
    
    weight_data = pd.read_csv(path_weights, sep=",", header=None)
    weight_data = weight_data.sort_values(by=0).sample(frac=1, random_state=RANDOM_SEED)
    weight_data = weight_data.sort_values(by=0).sample(n=interpretation_dataset_size, random_state=RANDOM_SEED)
    
    lambda_X_test_data = pd.read_csv(path_X_data, sep=",", header=None)
    lambda_X_test_data = lambda_X_test_data.sort_values(by=0).sample(frac=1, random_state=RANDOM_SEED)
    lambda_X_test_data = lambda_X_test_data.sort_values(by=0).sample(n=interpretation_dataset_size, random_state=RANDOM_SEED)
    
    lambda_y_test_data = pd.read_csv(path_y_data, sep=",", header=None)
    lambda_y_test_data = lambda_y_test_data.sort_values(by=0).sample(frac=1, random_state=RANDOM_SEED)
    lambda_y_test_data = lambda_y_test_data.sort_values(by=0).sample(n=interpretation_dataset_size, random_state=RANDOM_SEED)
        
    lambda_nets = [None] * weight_data.shape[0]
    for i, (row_weights, row_lambda_X_test_data, row_lambda_y_test_data) in enumerate(zip(weight_data.values, lambda_X_test_data.values, lambda_y_test_data.values)):        
        lambda_net = LambdaNet(row_weights, row_lambda_X_test_data, row_lambda_y_test_data)
        lambda_nets[i] = lambda_net
                
    lambda_net_dataset = LambdaNetDataset(lambda_nets)
        
    return lambda_net_dataset

# %%
#LOAD DATA

parallel = Parallel(n_jobs=n_jobs, verbose=3, backend='multiprocessing')
lambda_net_dataset_list = parallel(delayed(load_lambda_nets)((i+1)*each_epochs_save_lambda if each_epochs_save_lambda==1 else i*each_epochs_save_lambda if i > 1 else each_epochs_save_lambda if i==1 else 1) for i in epochs_save_range_lambda)  
del parallel

lambda_net_dataset = lambda_net_dataset_list[-1]
# Out:
# [Parallel(n_jobs=7)]: Using backend MultiprocessingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done   1 out of   1 | elapsed:  1.2min finished

# %% [markdown]
# ## Data Inspection

# %%
lambda_net_dataset.as_pandas().head()
# Out:
#              seed  0-target  1-target  2-target  3-target  -1-target  \
# 33553  1373158606     0.110     0.904     0.347    -0.851      0.000
# 9427   1373158606    -0.294     0.859    -0.018    -0.458      0.000
# 199    1373158606     0.000     0.000    -0.124     0.000     -0.588
# 12447  1373158606    -0.145     0.000     0.000     0.000      0.000
# 39489  1373158606     0.884    -0.248     0.000    -0.571      0.357
#
#        0-lstsq_lambda  1-lstsq_lambda  2-lstsq_lambda  3-lstsq_lambda  \
#
# 25%      -0.285    -0.418    -0.266
# 50%      -0.285    -0.418    -0.001
# 75%      -0.285    -0.418     0.276
# max      -0.285    -0.418     3.121

# %%
lambda_net_dataset.X_test_data_list[0][:10]
# Out:
# array([[0.46090259],
#        [0.10577573],
#        [0.9130468 ],
#        [0.49852098],
#        [0.78355729],
#        [0.70730873],
#        [0.21320786],
#        [0.57263504],
#        [0.62688689],
#        [0.53872974]])

# %%
lambda_net_dataset.y_test_data_list[0][:10]
# Out:
# array([[0.5166591 ],
#        [0.20806498],
#        [0.57668708],
#        [0.54108354],
#        [0.62168377],
#        [0.6215422 ],
#        [0.30984831],
#        [0.5812829 ],
#        [0.60306484],
#        [0.56428691]])

# %% [markdown]
# ## Generate Datasets for Interpretation-Net training

# %%
#generate train, test and validation data for training

lambda_net_train_dataset_list = []
lambda_net_valid_dataset_list = []
lambda_net_test_dataset_list = []

for lambda_net_dataset in lambda_net_dataset_list:
    
    
    if inet_holdout_seed_evaluation:
        complete_seed_list = list(set(lambda_net_dataset.train_settings_list['seed']))#list(weight_data.iloc[:,1].unique())

        random.seed(RANDOM_SEED)
        
        if isinstance(test_size, float):
            test_size = int(len(complete_seed_list)-len(complete_seed_list)/(1/(1-test_size)))
        
        test_seeds = random.sample(complete_seed_list, test_size)
        lambda_net_test_dataset = lambda_net_dataset.get_lambda_nets_by_seed(test_seeds)
        complete_seed_list = list(set(complete_seed_list) - set(test_seeds))#complete_seed_list.remove(test_seeds)
        
        random.seed(RANDOM_SEED)
        valid_seeds = random.sample(complete_seed_list, int(len(complete_seed_list)-len(complete_seed_list)/(1/(1-0.1))))
        lambda_net_valid_dataset = lambda_net_dataset.get_lambda_nets_by_seed(valid_seeds)
        complete_seed_list = list(set(complete_seed_list) - set(valid_seeds))

        train_seeds = complete_seed_list
        lambda_net_train_dataset = lambda_net_dataset.get_lambda_nets_by_seed(train_seeds)       
        
        lambda_net_train_dataset_list.append(lambda_net_train_dataset)
        lambda_net_valid_dataset_list.append(lambda_net_valid_dataset)
        lambda_net_test_dataset_list.append(lambda_net_test_dataset)
        
        del lambda_net_dataset
    else:
        lambda_net_train_with_valid_dataset, lambda_net_test_dataset = split_LambdaNetDataset(lambda_net_dataset, test_split=test_size)
        lambda_net_train_dataset, lambda_net_valid_dataset = split_LambdaNetDataset(lambda_net_train_with_valid_dataset, test_split=0.1)
        
        lambda_net_train_dataset_list.append(lambda_net_train_dataset)
        lambda_net_valid_dataset_list.append(lambda_net_valid_dataset)
        lambda_net_test_dataset_list.append(lambda_net_test_dataset)
    
        del lambda_net_dataset, lambda_net_train_with_valid_dataset

        
del lambda_net_dataset_list

# %%
lambda_net_train_dataset_list[-1].as_pandas().shape
# Out:
# (44910, 92)

# %%
lambda_net_valid_dataset_list[-1].as_pandas().shape
# Out:
# (4990, 92)

# %%
lambda_net_test_dataset_list[-1].as_pandas().shape
# Out:
# (100, 92)

# %%
lambda_net_train_dataset_list[-1].as_pandas().head()
# Out:
#              seed  0-target  1-target  2-target  3-target  -1-target  \
# 9901   1373158606     0.000     0.796     0.164    -0.157      0.000
# 5910   1373158606     0.000    -0.421    -0.211    -0.123      0.000
# 18619  1373158606     0.350    -0.764     0.000     0.000      0.000
# 33312  1373158606    -0.424     0.603    -0.154    -0.562      0.000
# 47430  1373158606     0.000    -0.476     0.356     0.887      0.000
#
#        0-lstsq_lambda  1-lstsq_lambda  2-lstsq_lambda  3-lstsq_lambda  \
#
#   -0.24752532]
#  [ 0.40547797  0.28023607  0.4025111  ...  0.06072533  0.0378772
#   -0.01712652]
#  ...
#  [ 0.246       0.246       0.246      ...  0.246       0.246
#    0.246     ]
#  [-0.74561495 -1.2422997  -1.1994356  ... -1.3252165  -0.35538536
#   -1.5302424 ]
#  [-0.26388428 -0.29086187 -0.10791578 ... -0.17136721 -0.17059453
#   -0.307028  ]]
# Score Calculation Time: 0:00:02
# ---------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Evaluate Interpretation Net

# %%
polynomial_dict_test_list[-1].keys()
# Out:
# dict_keys(['lstsq_lambda_pred_polynomials', 'lstsq_target_polynomials', 'target_polynomials', 'inet_polynomials', 'symbolic_regression_functions'])

# %%
poly_optimize = tf.constant([float(i) for i in range(interpretation_net_output_shape)])

if interpretation_net_output_monomials != None:
    poly_optimize_coeffs = poly_optimize[:interpretation_net_output_monomials]

    poly_optimize_identifiers_list = []
    for i in range(interpretation_net_output_monomials):
        poly_optimize_identifiers = tf.math.softmax(poly_optimize[sparsity*i+interpretation_net_output_monomials:sparsity*(i+1)+interpretation_net_output_monomials])
        poly_optimize_identifiers_list.append(poly_optimize_identifiers)
    poly_optimize_identifiers_list = tf.keras.backend.flatten(poly_optimize_identifiers_list)
    poly_optimize = tf.concat([poly_optimize_coeffs, poly_optimize_identifiers_list], axis=0)

# %%
poly_optimize
# Out:
# <tf.Tensor: shape=(18,), dtype=float32, numpy=
# array([0.        , 1.        , 2.        , 0.01165623, 0.03168492,
#        0.08612854, 0.23412165, 0.6364086 , 0.01165623, 0.03168492,
#        0.08612854, 0.23412165, 0.6364086 , 0.01165623, 0.03168492,
#        0.08612854, 0.23412165, 0.6364086 ], dtype=float32)>

# %%
if nas:
    for trial in history_list[-1]: 
        print(trial.summary())

# %%
if len(model_list) >= 1:
    print(model_list[-1].summary())
    print(model_list[-1].get_config())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 76)]         0
# __________________________________________________________________________________________________
# hidden1_512 (Dense)             (None, 512)          39424       input[0][0]
# __________________________________________________________________________________________________
# dropout1_0.25 (Dropout)         (None, 512)          0           hidden1_512[0][0]
# __________________________________________________________________________________________________
# hidden2_1024 (Dense)            (None, 1024)         525312      dropout1_0.25[0][0]
# __________________________________________________________________________________________________
# output_coeff_3 (Dense)          (None, 3)            3075        hidden2_1024[0][0]
# __________________________________________________________________________________________________
# output_identifier1_5 (Dense)    (None, 5)            5125        hidden2_1024[0][0]
# __________________________________________________________________________________________________
# output_identifier2_5 (Dense)    (None, 5)            5125        hidden2_1024[0][0]
# __________________________________________________________________________________________________
# output_identifier3_5 (Dense)    (None, 5)            5125        hidden2_1024[0][0]
# __________________________________________________________________________________________________
# output_combined (Concatenate)   (None, 18)           0           output_coeff_3[0][0]
#                                                                  output_identifier1_5[0][0]
#                                                                  output_identifier2_5[0][0]
#                                                                  output_identifier3_5[0][0]
# ==================================================================================================
# Total params: 583,186
# Trainable params: 583,186
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# {'name': 'model', 'layers': [{'class_name': 'InputLayer', 'config': {'batch_input_shape': (None, 76), 'dtype': 'float32', 'sparse': False, 'ragged': False, 'name': 'input'}, 'name': 'input', 'inbound_nodes': []}, {'class_name': 'Dense', 'config': {'name': 'hidden1_512', 'trainable': True, 'dtype': 'float32', 'units': 512, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'name': 'hidden1_512', 'inbound_nodes': [[['input', 0, 0, {}]]]}, {'class_name': 'Dropout', 'config': {'name': 'dropout1_0.25', 'trainable': True, 'dtype': 'float32', 'rate': 0.25, 'noise_shape': None, 'seed': None}, 'name': 'dropout1_0.25', 'inbound_nodes': [[['hidden1_512', 0, 0, {}]]]}, {'class_name': 'Dense', 'config': {'name': 'hidden2_1024', 'trainable': True, 'dtype': 'float32', 'units': 1024, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'name': 'hidden2_1024', 'inbound_nodes': [[['dropout1_0.25', 0, 0, {}]]]}, {'class_name': 'Dense', 'config': {'name': 'output_coeff_3', 'trainable': True, 'dtype': 'float32', 'units': 3, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'name': 'output_coeff_3', 'inbound_nodes': [[['hidden2_1024', 0, 0, {}]]]}, {'class_name': 'Dense', 'config': {'name': 'output_identifier1_5', 'trainable': True, 'dtype': 'float32', 'units': 5, 'activation': 'softmax', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'name': 'output_identifier1_5', 'inbound_nodes': [[['hidden2_1024', 0, 0, {}]]]}, {'class_name': 'Dense', 'config': {'name': 'output_identifier2_5', 'trainable': True, 'dtype': 'float32', 'units': 5, 'activation': 'softmax', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'name': 'output_identifier2_5', 'inbound_nodes': [[['hidden2_1024', 0, 0, {}]]]}, {'class_name': 'Dense', 'config': {'name': 'output_identifier3_5', 'trainable': True, 'dtype': 'float32', 'units': 5, 'activation': 'softmax', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'name': 'output_identifier3_5', 'inbound_nodes': [[['hidden2_1024', 0, 0, {}]]]}, {'class_name': 'Concatenate', 'config': {'name': 'output_combined', 'trainable': True, 'dtype': 'float32', 'axis': -1}, 'name': 'output_combined', 'inbound_nodes': [[['output_coeff_3', 0, 0, {}], ['output_identifier1_5', 0, 0, {}], ['output_identifier2_5', 0, 0, {}], ['output_identifier3_5', 0, 0, {}]]]}], 'input_layers': [['input', 0, 0]], 'output_layers': [['output_combined', 0, 0]]}

# %%
if evaluate_with_real_function:
    keys = ['inetPoly_VS_targetPoly_test', 'perNetworkPoly_VS_targetPoly_test', 'predLambda_VS_targetPoly_test', 'lstsqLambda_VS_targetPoly_test', 'lstsqTarget_VS_targetPoly_test']
else:
    keys = ['inetPoly_VS_predLambda_test', 'inetPoly_VS_lstsqLambda_test', 'perNetworkPoly_VS_predLambda_test', 'perNetworkPoly_VS_lstsqLambda_test', 'lstsqLambda_VS_predLambda_test', 'predLambda_VS_targetPoly_test']

# %%
scores_test_list[-1]
# Out:
#                                                      MAE  RMSE   MAPE  \
# lambda_preds_VS_target_polynomials                   NaN   NaN    NaN
# lambda_preds_VS_lstsq_lambda_pred_polynomials        NaN   NaN    NaN
# lambda_preds_VS_lstsq_target_polynomials             NaN   NaN    NaN
# lambda_preds_VS_inet_polynomials                     NaN   NaN    NaN
# lambda_preds_VS_symbolic_regression_functions        NaN   NaN    NaN
# target_polynomials_VS_lstsq_lambda_pred_polynom... 1.473 5.018 39.843
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000  0.000
# target_polynomials_VS_inet_polynomials             0.490 1.592  8.616
# target_polynomials_VS_symbolic_regression_funct...   NaN   NaN    NaN
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 1.473 5.018  1.870
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  1.290 4.130  3.173
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...   NaN   NaN    NaN
# lstsq_target_polynomials_VS_inet_polynomials       0.490 1.592  8.616
# lstsq_target_polynomials_VS_symbolic_regression...   NaN   NaN    NaN
# inet_polynomials_VS_symbolic_regression_functions    NaN   NaN    NaN
#
#                                                     Accuracy  \
# lambda_preds_VS_target_polynomials                       NaN
# lambda_preds_VS_lstsq_lambda_pred_polynomials            NaN
# lambda_preds_VS_lstsq_target_polynomials                 NaN
# lambda_preds_VS_inet_polynomials                         NaN
# lambda_preds_VS_symbolic_regression_functions            NaN
# target_polynomials_VS_lstsq_lambda_pred_polynom...     0.402
# target_polynomials_VS_lstsq_target_polynomials         1.000
# target_polynomials_VS_inet_polynomials                 0.377
# target_polynomials_VS_symbolic_regression_funct...       NaN
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...     0.402
# lstsq_lambda_pred_polynomials_VS_inet_polynomials      0.345
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...       NaN
# lstsq_target_polynomials_VS_inet_polynomials           0.377
# lstsq_target_polynomials_VS_symbolic_regression...       NaN
# inet_polynomials_VS_symbolic_regression_functions        NaN
#
#                                                     Accuracy Multilabel  \
# lambda_preds_VS_target_polynomials                                  NaN
# lambda_preds_VS_lstsq_lambda_pred_polynomials                       NaN
# lambda_preds_VS_lstsq_target_polynomials                            NaN
# lambda_preds_VS_inet_polynomials                                    NaN
# lambda_preds_VS_symbolic_regression_functions                       NaN
# target_polynomials_VS_lstsq_lambda_pred_polynom...                0.110
# target_polynomials_VS_lstsq_target_polynomials                    1.000
# target_polynomials_VS_inet_polynomials                            0.100
# target_polynomials_VS_symbolic_regression_funct...                  NaN
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...                0.110
# lstsq_lambda_pred_polynomials_VS_inet_polynomials                 0.080
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...                  NaN
# lstsq_target_polynomials_VS_inet_polynomials                      0.100
# lstsq_target_polynomials_VS_symbolic_regression...                  NaN
# inet_polynomials_VS_symbolic_regression_functions                   NaN
#
#                                                     MAE FV  RMSE FV  MAPE FV  \
# lambda_preds_VS_target_polynomials                   0.028    0.071    0.082
# lambda_preds_VS_lstsq_lambda_pred_polynomials        0.016    0.023    0.055
# lambda_preds_VS_lstsq_target_polynomials             0.028    0.071    0.082
# lambda_preds_VS_inet_polynomials                     0.189    0.229    1.386
# lambda_preds_VS_symbolic_regression_functions        0.037    0.068    0.328
# target_polynomials_VS_lstsq_lambda_pred_polynom...   0.031    0.064    0.105
# target_polynomials_VS_lstsq_target_polynomials       0.000    0.000    0.000
# target_polynomials_VS_inet_polynomials               0.198    0.249    1.872
# target_polynomials_VS_symbolic_regression_funct...   0.047    0.074    0.795
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...   0.031    0.064    0.098
# lstsq_lambda_pred_polynomials_VS_inet_polynomials    0.187    0.226    1.641
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...   0.040    0.062    0.350
# lstsq_target_polynomials_VS_inet_polynomials         0.198    0.249    1.872
# lstsq_target_polynomials_VS_symbolic_regression...   0.047    0.074    0.795
# inet_polynomials_VS_symbolic_regression_functions    0.185    0.220    1.062
#
#                                                              R2 FV  RAAE FV  \
# lambda_preds_VS_target_polynomials                           0.452    0.164
# lambda_preds_VS_lstsq_lambda_pred_polynomials                0.974    0.056
# lambda_preds_VS_lstsq_target_polynomials                     0.452    0.164
# lambda_preds_VS_inet_polynomials                             0.120    0.650
# lambda_preds_VS_symbolic_regression_functions             -109.546    1.936
# target_polynomials_VS_lstsq_lambda_pred_polynom... -3463401103.817      inf
# target_polynomials_VS_lstsq_target_polynomials               1.000      NaN
# target_polynomials_VS_inet_polynomials             -2702140475.973      inf
# target_polynomials_VS_symbolic_regression_funct... -4232111428.699      inf
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...           0.449    0.169
# lstsq_lambda_pred_polynomials_VS_inet_polynomials            0.007    0.661
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...        -243.603    2.508
# lstsq_target_polynomials_VS_inet_polynomials       -2702140475.973      inf
# lstsq_target_polynomials_VS_symbolic_regression... -4232111428.699      inf
# inet_polynomials_VS_symbolic_regression_functions         -569.823    4.039
#
#                                                     RMAE FV  MEAN STD FV DIFF  \
# lambda_preds_VS_target_polynomials                    0.885             0.069
# lambda_preds_VS_lstsq_lambda_pred_polynomials         0.231             0.023
# lambda_preds_VS_lstsq_target_polynomials              0.885             0.069
# lambda_preds_VS_inet_polynomials                      1.237             0.198
# lambda_preds_VS_symbolic_regression_functions         1.455             0.065
# target_polynomials_VS_lstsq_lambda_pred_polynom...      inf             0.062
# target_polynomials_VS_lstsq_target_polynomials          NaN             0.000
# target_polynomials_VS_inet_polynomials                  NaN             0.220
# target_polynomials_VS_symbolic_regression_funct...      inf             0.070
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...    0.798             0.062
# lstsq_lambda_pred_polynomials_VS_inet_polynomials     1.212             0.194
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...    1.791             0.059
# lstsq_target_polynomials_VS_inet_polynomials            NaN             0.220
# lstsq_target_polynomials_VS_symbolic_regression...      inf             0.070
# inet_polynomials_VS_symbolic_regression_functions     1.988             0.186
#
#                                                     MEAN FV1  MEAN FV2  \
# lambda_preds_VS_target_polynomials                    -0.023    -0.027
# lambda_preds_VS_lstsq_lambda_pred_polynomials         -0.023    -0.023
# lambda_preds_VS_lstsq_target_polynomials              -0.023    -0.027
# lambda_preds_VS_inet_polynomials                      -0.023    -0.065
# lambda_preds_VS_symbolic_regression_functions         -0.023    -0.023
# target_polynomials_VS_lstsq_lambda_pred_polynom...    -0.027    -0.023
# target_polynomials_VS_lstsq_target_polynomials        -0.027    -0.027
# target_polynomials_VS_inet_polynomials                -0.027    -0.065
# target_polynomials_VS_symbolic_regression_funct...    -0.027    -0.023
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...    -0.023    -0.027
# lstsq_lambda_pred_polynomials_VS_inet_polynomials     -0.023    -0.065
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...    -0.023    -0.023
# lstsq_target_polynomials_VS_inet_polynomials          -0.027    -0.065
# lstsq_target_polynomials_VS_symbolic_regression...    -0.027    -0.023
# inet_polynomials_VS_symbolic_regression_functions     -0.065    -0.023
#
#                                                     STD FV1  STD FV2
# lambda_preds_VS_target_polynomials                    1.100    1.184
# lambda_preds_VS_lstsq_lambda_pred_polynomials         1.100    1.103
# lambda_preds_VS_lstsq_target_polynomials              1.100    1.184
# lambda_preds_VS_inet_polynomials                      1.100    1.369
# lambda_preds_VS_symbolic_regression_functions         1.100    1.135
# target_polynomials_VS_lstsq_lambda_pred_polynom...    1.184    1.103
# target_polynomials_VS_lstsq_target_polynomials        1.184    1.184
# target_polynomials_VS_inet_polynomials                1.184    1.369
# target_polynomials_VS_symbolic_regression_funct...    1.184    1.135
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...    1.103    1.184
# lstsq_lambda_pred_polynomials_VS_inet_polynomials     1.103    1.369
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...    1.103    1.135
# lstsq_target_polynomials_VS_inet_polynomials          1.184    1.369
# lstsq_target_polynomials_VS_symbolic_regression...    1.184    1.135
# inet_polynomials_VS_symbolic_regression_functions     1.369    1.135

# %%
distrib_dict_test_list[-1]['MAE']
# Out:
#                                                      L-0   L-1   L-2   L-3  \
# lambda_preds_VS_target_polynomials                 0.002 0.002 0.010 0.009
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.000 0.001 0.003 0.005
# lambda_preds_VS_lstsq_target_polynomials           0.002 0.002 0.010 0.009
# lambda_preds_VS_inet_polynomials                   0.022 0.081 0.156 0.042
# lambda_preds_VS_symbolic_regression_functions      0.033 0.004 0.035 0.032
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.002 0.002 0.010 0.008
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.021 0.081 0.157 0.049
# target_polynomials_VS_symbolic_regression_funct... 0.032 0.005 0.036 0.039
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.002 0.002 0.010 0.008
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.022 0.081 0.155 0.042
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.033 0.004 0.035 0.032
# lstsq_target_polynomials_VS_inet_polynomials       0.021 0.081 0.157 0.049
# lstsq_target_polynomials_VS_symbolic_regression... 0.032 0.005 0.036 0.039
# inet_polynomials_VS_symbolic_regression_functions  0.018 0.080 0.130 0.011
#
#                                                      L-4   L-5   L-6   L-7  \
# lambda_preds_VS_target_polynomials                 0.001 0.112 0.004 0.004
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.000 0.109 0.002 0.001
# lambda_preds_VS_lstsq_target_polynomials           0.001 0.112 0.004 0.004
# lambda_preds_VS_inet_polynomials                   0.021 0.273 0.014 0.156
# lambda_preds_VS_symbolic_regression_functions      0.018 0.118 0.016 0.008
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.001 0.163 0.003 0.005
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.021 0.222 0.015 0.156
# target_polynomials_VS_symbolic_regression_funct... 0.019 0.098 0.017 0.012
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.001 0.163 0.003 0.005
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.021 0.263 0.014 0.156
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.018 0.158 0.015 0.008
# lstsq_target_polynomials_VS_inet_polynomials       0.021 0.222 0.015 0.156
# lstsq_target_polynomials_VS_symbolic_regression... 0.019 0.098 0.017 0.012
# inet_polynomials_VS_symbolic_regression_functions  0.022 0.197 0.007 0.149
#
#                                                      L-8   L-9  L-10  L-11  \
# lambda_preds_VS_target_polynomials                 0.010 0.014 0.169 0.000
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.008 0.007 0.174 0.000
# lambda_preds_VS_lstsq_target_polynomials           0.010 0.014 0.169 0.000
# lambda_preds_VS_inet_polynomials                   0.100 0.229 0.506 0.000
# lambda_preds_VS_symbolic_regression_functions      0.022 0.056 0.127 0.002
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.007 0.013 0.194 0.000
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.106 0.238 0.403 0.000
# target_polynomials_VS_symbolic_regression_funct... 0.022 0.054 0.084 0.002
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.007 0.013 0.194 0.000
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.100 0.229 0.466 0.000
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.022 0.055 0.175 0.002
# lstsq_target_polynomials_VS_inet_polynomials       0.106 0.238 0.403 0.000
# lstsq_target_polynomials_VS_symbolic_regression... 0.022 0.054 0.084 0.002
# inet_polynomials_VS_symbolic_regression_functions  0.100 0.201 0.427 0.002
#
#                                                     L-12  L-13  L-14  L-15  \
# lambda_preds_VS_target_polynomials                 0.008 0.000 0.006 0.100
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.005 0.000 0.002 0.125
# lambda_preds_VS_lstsq_target_polynomials           0.008 0.000 0.006 0.100
# lambda_preds_VS_inet_polynomials                   0.041 0.000 0.047 0.497
# lambda_preds_VS_symbolic_regression_functions      0.043 0.006 0.050 0.095
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.006 0.000 0.006 0.119
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.044 0.000 0.048 0.445
# target_polynomials_VS_symbolic_regression_funct... 0.046 0.006 0.055 0.069
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.006 0.000 0.006 0.119
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.040 0.000 0.047 0.462
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.044 0.006 0.049 0.119
# lstsq_target_polynomials_VS_inet_polynomials       0.044 0.000 0.048 0.445
# lstsq_target_polynomials_VS_symbolic_regression... 0.046 0.006 0.055 0.069
# inet_polynomials_VS_symbolic_regression_functions  0.056 0.006 0.058 0.453
#
#                                                     L-16  L-17  L-18  L-19  \
# lambda_preds_VS_target_polynomials                 0.095 0.009 0.003 0.002
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.121 0.003 0.002 0.002
# lambda_preds_VS_lstsq_target_polynomials           0.095 0.009 0.003 0.002
# lambda_preds_VS_inet_polynomials                   2.267 0.053 0.130 0.132
# lambda_preds_VS_symbolic_regression_functions      0.082 0.048 0.009 0.008
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.133 0.008 0.003 0.002
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             2.269 0.060 0.131 0.133
# target_polynomials_VS_symbolic_regression_funct... 0.080 0.051 0.009 0.009
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.133 0.008 0.003 0.002
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  2.285 0.053 0.130 0.132
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.144 0.048 0.009 0.008
# lstsq_target_polynomials_VS_inet_polynomials       2.269 0.060 0.131 0.133
# lstsq_target_polynomials_VS_symbolic_regression... 0.080 0.051 0.009 0.009
# inet_polynomials_VS_symbolic_regression_functions  2.327 0.088 0.124 0.128
#
#                                                     L-20  L-21  L-22  L-23  \
# lambda_preds_VS_target_polynomials                 0.008 0.003 0.000 0.000
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.004 0.002 0.000 0.000
# lambda_preds_VS_lstsq_target_polynomials           0.008 0.003 0.000 0.000
# lambda_preds_VS_inet_polynomials                   0.079 0.061 0.000 0.000
# lambda_preds_VS_symbolic_regression_functions      0.054 0.010 0.003 0.009
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.007 0.003 0.000 0.000
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.082 0.062 0.000 0.000
# target_polynomials_VS_symbolic_regression_funct... 0.053 0.011 0.003 0.009
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.007 0.003 0.000 0.000
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.078 0.061 0.000 0.000
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.053 0.010 0.003 0.009
# lstsq_target_polynomials_VS_inet_polynomials       0.082 0.062 0.000 0.000
# lstsq_target_polynomials_VS_symbolic_regression... 0.053 0.011 0.003 0.009
# inet_polynomials_VS_symbolic_regression_functions  0.042 0.051 0.003 0.009
#
#                                                     L-24  L-25  L-26  L-27  \
# lambda_preds_VS_target_polynomials                 0.011 0.023 0.009 0.007
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.005 0.005 0.005 0.003
# lambda_preds_VS_lstsq_target_polynomials           0.011 0.023 0.009 0.007
# lambda_preds_VS_inet_polynomials                   0.391 0.097 0.335 0.121
# lambda_preds_VS_symbolic_regression_functions      0.018 0.023 0.023 0.024
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.008 0.023 0.007 0.008
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.395 0.100 0.332 0.122
# target_polynomials_VS_symbolic_regression_funct... 0.024 0.016 0.024 0.026
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.008 0.023 0.007 0.008
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.391 0.097 0.334 0.121
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.017 0.023 0.023 0.024
# lstsq_target_polynomials_VS_inet_polynomials       0.395 0.100 0.332 0.122
# lstsq_target_polynomials_VS_symbolic_regression... 0.024 0.016 0.024 0.026
# inet_polynomials_VS_symbolic_regression_functions  0.389 0.090 0.346 0.105
#
#                                                     L-28  L-29  L-30  L-31  \
# lambda_preds_VS_target_polynomials                 0.013 0.024 0.008 0.005
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.005 0.011 0.004 0.002
# lambda_preds_VS_lstsq_target_polynomials           0.013 0.024 0.008 0.005
# lambda_preds_VS_inet_polynomials                   0.060 0.126 0.111 0.045
# lambda_preds_VS_symbolic_regression_functions      0.014 0.032 0.016 0.037
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.013 0.022 0.008 0.005
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.068 0.135 0.112 0.049
# target_polynomials_VS_symbolic_regression_funct... 0.010 0.039 0.018 0.041
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.013 0.022 0.008 0.005
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.060 0.126 0.110 0.045
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.014 0.030 0.016 0.037
# lstsq_target_polynomials_VS_inet_polynomials       0.068 0.135 0.112 0.049
# lstsq_target_polynomials_VS_symbolic_regression... 0.010 0.039 0.018 0.041
# inet_polynomials_VS_symbolic_regression_functions  0.065 0.099 0.103 0.021
#
#                                                     L-32  L-33  L-34  L-35  \
# lambda_preds_VS_target_polynomials                 0.007 0.072 0.141 0.008
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.002 0.087 0.173 0.004
# lambda_preds_VS_lstsq_target_polynomials           0.007 0.072 0.141 0.008
# lambda_preds_VS_inet_polynomials                   0.056 0.241 0.405 0.036
# lambda_preds_VS_symbolic_regression_functions      0.062 0.067 0.131 0.043
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.006 0.091 0.192 0.006
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.061 0.219 0.321 0.039
# target_polynomials_VS_symbolic_regression_funct... 0.068 0.066 0.065 0.048
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.006 0.091 0.192 0.006
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.056 0.233 0.379 0.035
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.062 0.090 0.183 0.042
# lstsq_target_polynomials_VS_inet_polynomials       0.061 0.219 0.321 0.039
# lstsq_target_polynomials_VS_symbolic_regression... 0.068 0.066 0.065 0.048
# inet_polynomials_VS_symbolic_regression_functions  0.034 0.234 0.321 0.011
#
#                                                     L-36  L-37  L-38  L-39  \
# lambda_preds_VS_target_polynomials                 0.858 0.088 0.001 0.003
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.001 0.114 0.000 0.001
# lambda_preds_VS_lstsq_target_polynomials           0.858 0.088 0.001 0.003
# lambda_preds_VS_inet_polynomials                   0.040 2.627 0.009 0.020
# lambda_preds_VS_symbolic_regression_functions      0.050 0.089 0.002 0.005
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.857 0.121 0.001 0.003
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.857 2.599 0.009 0.019
# target_polynomials_VS_symbolic_regression_funct... 0.861 0.092 0.002 0.006
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.857 0.121 0.001 0.003
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.040 2.641 0.009 0.020
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.051 0.114 0.001 0.005
# lstsq_target_polynomials_VS_inet_polynomials       0.857 2.599 0.009 0.019
# lstsq_target_polynomials_VS_symbolic_regression... 0.861 0.092 0.002 0.006
# inet_polynomials_VS_symbolic_regression_functions  0.055 2.682 0.010 0.025
#
#                                                     L-40  L-41  L-42  L-43  \
# lambda_preds_VS_target_polynomials                 0.009 0.011 0.000 0.007
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.001 0.004 0.000 0.004
# lambda_preds_VS_lstsq_target_polynomials           0.009 0.011 0.000 0.007
# lambda_preds_VS_inet_polynomials                   0.127 0.009 0.002 0.049
# lambda_preds_VS_symbolic_regression_functions      0.007 0.010 0.004 0.063
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.010 0.013 0.000 0.005
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.134 0.016 0.002 0.054
# target_polynomials_VS_symbolic_regression_funct... 0.015 0.001 0.004 0.068
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.010 0.013 0.000 0.005
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.127 0.008 0.002 0.049
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.007 0.012 0.004 0.064
# lstsq_target_polynomials_VS_inet_polynomials       0.134 0.016 0.002 0.054
# lstsq_target_polynomials_VS_symbolic_regression... 0.015 0.001 0.004 0.068
# inet_polynomials_VS_symbolic_regression_functions  0.121 0.015 0.002 0.064
#
#                                                     L-44  L-45  L-46  L-47  \
# lambda_preds_VS_target_polynomials                 0.001 0.004 0.002 0.002
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.001 0.001 0.001 0.001
# lambda_preds_VS_lstsq_target_polynomials           0.001 0.004 0.002 0.002
# lambda_preds_VS_inet_polynomials                   0.093 0.146 0.103 0.110
# lambda_preds_VS_symbolic_regression_functions      0.009 0.007 0.062 0.016
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.001 0.003 0.002 0.002
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.093 0.147 0.105 0.110
# target_polynomials_VS_symbolic_regression_funct... 0.008 0.005 0.064 0.017
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.001 0.003 0.002 0.002
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.093 0.146 0.104 0.110
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.009 0.007 0.062 0.016
# lstsq_target_polynomials_VS_inet_polynomials       0.093 0.147 0.105 0.110
# lstsq_target_polynomials_VS_symbolic_regression... 0.008 0.005 0.064 0.017
# inet_polynomials_VS_symbolic_regression_functions  0.098 0.149 0.088 0.095
#
#                                                     L-48  L-49  L-50  L-51  \
# lambda_preds_VS_target_polynomials                 0.001 0.000 0.008 0.007
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.000 0.000 0.003 0.005
# lambda_preds_VS_lstsq_target_polynomials           0.001 0.000 0.008 0.007
# lambda_preds_VS_inet_polynomials                   0.188 0.001 0.073 0.145
# lambda_preds_VS_symbolic_regression_functions      0.004 0.001 0.019 0.008
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.001 0.000 0.007 0.006
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.188 0.001 0.076 0.146
# target_polynomials_VS_symbolic_regression_funct... 0.005 0.001 0.023 0.003
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.001 0.000 0.007 0.006
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.188 0.001 0.073 0.145
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.004 0.001 0.019 0.007
# lstsq_target_polynomials_VS_inet_polynomials       0.188 0.001 0.076 0.146
# lstsq_target_polynomials_VS_symbolic_regression... 0.005 0.001 0.023 0.003
# inet_polynomials_VS_symbolic_regression_functions  0.187 0.001 0.079 0.145
#
#                                                     L-52  L-53  L-54  L-55  \
# lambda_preds_VS_target_polynomials                 0.009 0.010 0.008 0.006
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.005 0.003 0.004 0.003
# lambda_preds_VS_lstsq_target_polynomials           0.009 0.010 0.008 0.006
# lambda_preds_VS_inet_polynomials                   0.042 0.014 0.155 0.056
# lambda_preds_VS_symbolic_regression_functions      0.055 0.018 0.021 0.044
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.006 0.010 0.008 0.005
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.041 0.017 0.149 0.060
# target_polynomials_VS_symbolic_regression_funct... 0.061 0.012 0.025 0.047
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.006 0.010 0.008 0.005
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.040 0.014 0.156 0.055
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.056 0.017 0.022 0.043
# lstsq_target_polynomials_VS_inet_polynomials       0.041 0.017 0.149 0.060
# lstsq_target_polynomials_VS_symbolic_regression... 0.061 0.012 0.025 0.047
# inet_polynomials_VS_symbolic_regression_functions  0.048 0.020 0.168 0.039
#
#                                                     L-56  L-57  L-58  L-59  \
# lambda_preds_VS_target_polynomials                 0.005 0.004 0.005 0.007
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.002 0.001 0.003 0.004
# lambda_preds_VS_lstsq_target_polynomials           0.005 0.004 0.005 0.007
# lambda_preds_VS_inet_polynomials                   0.211 0.057 0.069 0.117
# lambda_preds_VS_symbolic_regression_functions      0.028 0.014 0.058 0.074
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.006 0.004 0.005 0.006
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.212 0.058 0.071 0.121
# target_polynomials_VS_symbolic_regression_funct... 0.030 0.016 0.060 0.078
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.006 0.004 0.005 0.006
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.211 0.056 0.069 0.116
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.028 0.014 0.058 0.075
# lstsq_target_polynomials_VS_inet_polynomials       0.212 0.058 0.071 0.121
# lstsq_target_polynomials_VS_symbolic_regression... 0.030 0.016 0.060 0.078
# inet_polynomials_VS_symbolic_regression_functions  0.200 0.044 0.083 0.089
#
#                                                     L-60  L-61  L-62  L-63  \
# lambda_preds_VS_target_polynomials                 0.012 0.005 0.048 0.002
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.006 0.001 0.046 0.001
# lambda_preds_VS_lstsq_target_polynomials           0.012 0.005 0.048 0.002
# lambda_preds_VS_inet_polynomials                   0.041 0.016 0.403 0.053
# lambda_preds_VS_symbolic_regression_functions      0.050 0.033 0.103 0.037
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.012 0.005 0.055 0.001
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.052 0.020 0.366 0.053
# target_polynomials_VS_symbolic_regression_funct... 0.061 0.036 0.128 0.037
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.012 0.005 0.055 0.001
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.041 0.016 0.392 0.053
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.049 0.033 0.115 0.037
# lstsq_target_polynomials_VS_inet_polynomials       0.052 0.020 0.366 0.053
# lstsq_target_polynomials_VS_symbolic_regression... 0.061 0.036 0.128 0.037
# inet_polynomials_VS_symbolic_regression_functions  0.019 0.033 0.447 0.025
#
#                                                     L-64  L-65  L-66  L-67  \
# lambda_preds_VS_target_polynomials                 0.013 0.002 0.121 0.001
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.009 0.001 0.140 0.000
# lambda_preds_VS_lstsq_target_polynomials           0.013 0.002 0.121 0.001
# lambda_preds_VS_inet_polynomials                   0.260 0.045 1.957 0.045
# lambda_preds_VS_symbolic_regression_functions      0.027 0.036 0.151 0.002
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.009 0.002 0.155 0.001
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.267 0.047 1.984 0.044
# target_polynomials_VS_symbolic_regression_funct... 0.035 0.037 0.150 0.002
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.009 0.002 0.155 0.001
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.260 0.045 1.955 0.045
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.026 0.036 0.168 0.002
# lstsq_target_polynomials_VS_inet_polynomials       0.267 0.047 1.984 0.044
# lstsq_target_polynomials_VS_symbolic_regression... 0.035 0.037 0.150 0.002
# inet_polynomials_VS_symbolic_regression_functions  0.237 0.039 2.076 0.044
#
#                                                     L-68  L-69  L-70  L-71  \
# lambda_preds_VS_target_polynomials                 0.010 0.072 0.001 0.008
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.006 0.000 0.001 0.004
# lambda_preds_VS_lstsq_target_polynomials           0.010 0.072 0.001 0.008
# lambda_preds_VS_inet_polynomials                   0.167 0.003 0.066 0.079
# lambda_preds_VS_symbolic_regression_functions      0.017 0.007 0.058 0.065
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.008 0.072 0.001 0.008
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.173 0.072 0.066 0.085
# target_polynomials_VS_symbolic_regression_funct... 0.016 0.072 0.058 0.072
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.008 0.072 0.001 0.008
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.166 0.003 0.066 0.079
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.014 0.007 0.058 0.064
# lstsq_target_polynomials_VS_inet_polynomials       0.173 0.072 0.066 0.085
# lstsq_target_polynomials_VS_symbolic_regression... 0.016 0.072 0.058 0.072
# inet_polynomials_VS_symbolic_regression_functions  0.162 0.010 0.048 0.074
#
#                                                     L-72  L-73  L-74  L-75  \
# lambda_preds_VS_target_polynomials                 0.004 0.006 0.005 0.003
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.001 0.003 0.002 0.002
# lambda_preds_VS_lstsq_target_polynomials           0.004 0.006 0.005 0.003
# lambda_preds_VS_inet_polynomials                   0.022 0.174 0.173 0.088
# lambda_preds_VS_symbolic_regression_functions      0.006 0.024 0.035 0.052
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.004 0.004 0.005 0.002
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.020 0.177 0.176 0.088
# target_polynomials_VS_symbolic_regression_funct... 0.004 0.020 0.035 0.053
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.004 0.004 0.005 0.002
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.022 0.174 0.172 0.087
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.006 0.023 0.036 0.052
# lstsq_target_polynomials_VS_inet_polynomials       0.020 0.177 0.176 0.088
# lstsq_target_polynomials_VS_symbolic_regression... 0.004 0.020 0.035 0.053
# inet_polynomials_VS_symbolic_regression_functions  0.016 0.184 0.183 0.086
#
#                                                     L-76  L-77  L-78  L-79  \
# lambda_preds_VS_target_polynomials                 0.005 0.004 0.014 0.208
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.003 0.001 0.003 0.004
# lambda_preds_VS_lstsq_target_polynomials           0.005 0.004 0.014 0.208
# lambda_preds_VS_inet_polynomials                   0.015 0.167 0.015 0.077
# lambda_preds_VS_symbolic_regression_functions      0.010 0.008 0.055 0.029
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.005 0.004 0.015 0.208
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.018 0.165 0.019 0.263
# target_polynomials_VS_symbolic_regression_funct... 0.014 0.011 0.047 0.229
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.005 0.004 0.015 0.208
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.015 0.167 0.015 0.076
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.010 0.008 0.055 0.029
# lstsq_target_polynomials_VS_inet_polynomials       0.018 0.165 0.019 0.263
# lstsq_target_polynomials_VS_symbolic_regression... 0.014 0.011 0.047 0.229
# inet_polynomials_VS_symbolic_regression_functions  0.012 0.173 0.065 0.062
#
#                                                     L-80  L-81  L-82  L-83  \
# lambda_preds_VS_target_polynomials                 0.008 0.089 0.004 0.005
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.005 0.100 0.001 0.004
# lambda_preds_VS_lstsq_target_polynomials           0.008 0.089 0.004 0.005
# lambda_preds_VS_inet_polynomials                   0.122 0.226 0.009 0.183
# lambda_preds_VS_symbolic_regression_functions      0.009 0.094 0.010 0.052
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.007 0.117 0.004 0.003
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.127 0.195 0.009 0.185
# target_polynomials_VS_symbolic_regression_funct... 0.008 0.061 0.011 0.052
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.007 0.117 0.004 0.003
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.122 0.235 0.009 0.182
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.007 0.110 0.010 0.051
# lstsq_target_polynomials_VS_inet_polynomials       0.127 0.195 0.009 0.185
# lstsq_target_polynomials_VS_symbolic_regression... 0.008 0.061 0.011 0.052
# inet_polynomials_VS_symbolic_regression_functions  0.126 0.159 0.014 0.139
#
#                                                     L-84  L-85  L-86  L-87  \
# lambda_preds_VS_target_polynomials                 0.014 0.011 0.005 0.005
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.009 0.004 0.003 0.003
# lambda_preds_VS_lstsq_target_polynomials           0.014 0.011 0.005 0.005
# lambda_preds_VS_inet_polynomials                   0.072 0.007 0.083 0.080
# lambda_preds_VS_symbolic_regression_functions      0.053 0.011 0.016 0.056
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.012 0.012 0.005 0.004
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.081 0.008 0.083 0.081
# target_polynomials_VS_symbolic_regression_funct... 0.059 0.000 0.017 0.057
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.012 0.012 0.005 0.004
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.071 0.007 0.083 0.080
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.051 0.012 0.015 0.056
# lstsq_target_polynomials_VS_inet_polynomials       0.081 0.008 0.083 0.081
# lstsq_target_polynomials_VS_symbolic_regression... 0.059 0.000 0.017 0.057
# inet_polynomials_VS_symbolic_regression_functions  0.038 0.008 0.090 0.077
#
#                                                     L-88  L-89  L-90  L-91  \
# lambda_preds_VS_target_polynomials                 0.019 0.005 0.091 0.002
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.027 0.002 0.114 0.001
# lambda_preds_VS_lstsq_target_polynomials           0.019 0.005 0.091 0.002
# lambda_preds_VS_inet_polynomials                   0.162 0.065 1.534 0.089
# lambda_preds_VS_symbolic_regression_functions      0.040 0.050 0.099 0.005
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.028 0.004 0.120 0.001
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.170 0.068 1.559 0.090
# target_polynomials_VS_symbolic_regression_funct... 0.035 0.053 0.062 0.005
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.028 0.004 0.120 0.001
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.162 0.065 1.518 0.089
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.053 0.049 0.106 0.006
# lstsq_target_polynomials_VS_inet_polynomials       0.170 0.068 1.559 0.090
# lstsq_target_polynomials_VS_symbolic_regression... 0.035 0.053 0.062 0.005
# inet_polynomials_VS_symbolic_regression_functions  0.164 0.036 1.561 0.093
#
#                                                     L-92  L-93  L-94  L-95  \
# lambda_preds_VS_target_polynomials                 0.015 0.021 0.000 0.011
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.007 0.001 0.000 0.006
# lambda_preds_VS_lstsq_target_polynomials           0.015 0.021 0.000 0.011
# lambda_preds_VS_inet_polynomials                   0.428 0.023 0.000 0.049
# lambda_preds_VS_symbolic_regression_functions      0.090 0.006 0.001 0.048
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.014 0.022 0.000 0.008
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.435 0.029 0.000 0.057
# target_polynomials_VS_symbolic_regression_funct... 0.094 0.021 0.001 0.055
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.014 0.022 0.000 0.008
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.426 0.023 0.000 0.048
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.089 0.007 0.001 0.048
# lstsq_target_polynomials_VS_inet_polynomials       0.435 0.029 0.000 0.057
# lstsq_target_polynomials_VS_symbolic_regression... 0.094 0.021 0.001 0.055
# inet_polynomials_VS_symbolic_regression_functions  0.424 0.020 0.002 0.046
#
#                                                     L-96  L-97  L-98  L-99
# lambda_preds_VS_target_polynomials                 0.012 0.011 0.010 0.002
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.004 0.005 0.008 0.001
# lambda_preds_VS_lstsq_target_polynomials           0.012 0.011 0.010 0.002
# lambda_preds_VS_inet_polynomials                   0.025 0.038 0.402 0.004
# lambda_preds_VS_symbolic_regression_functions      0.011 0.056 0.102 0.019
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.013 0.010 0.010 0.002
# target_polynomials_VS_lstsq_target_polynomials     0.000 0.000 0.000 0.000
# target_polynomials_VS_inet_polynomials             0.023 0.047 0.407 0.005
# target_polynomials_VS_symbolic_regression_funct... 0.002 0.062 0.109 0.018
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.013 0.010 0.010 0.002
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.025 0.038 0.399 0.003
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.012 0.057 0.101 0.019
# lstsq_target_polynomials_VS_inet_polynomials       0.023 0.047 0.407 0.005
# lstsq_target_polynomials_VS_symbolic_regression... 0.002 0.062 0.109 0.018
# inet_polynomials_VS_symbolic_regression_functions  0.023 0.065 0.370 0.021

# %%
distrib_dict_test_list[-1]['R2']
# Out:
#                                                       L-0    L-1    L-2   L-3  \
# lambda_preds_VS_target_polynomials                  0.995  0.999  0.992 0.996
# lambda_preds_VS_lstsq_lambda_pred_polynomials       1.000  1.000  0.999 0.999
# lambda_preds_VS_lstsq_target_polynomials            0.995  0.999  0.992 0.996
# lambda_preds_VS_inet_polynomials                    0.545 -0.321 -0.184 0.916
# lambda_preds_VS_symbolic_regression_functions      -0.024  0.995  0.944 0.948
# target_polynomials_VS_lstsq_lambda_pred_polynom...  0.995  0.999  0.994 0.997
# target_polynomials_VS_lstsq_target_polynomials      1.000  1.000  1.000 1.000
# target_polynomials_VS_inet_polynomials              0.585 -0.275 -0.055 0.896
# target_polynomials_VS_symbolic_regression_funct... -0.010  0.993  0.946 0.932
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  0.995  0.999  0.993 0.997
# lstsq_lambda_pred_polynomials_VS_inet_polynomials   0.545 -0.320 -0.183 0.916
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... -0.024  0.995  0.943 0.948
# lstsq_target_polynomials_VS_inet_polynomials        0.585 -0.275 -0.055 0.896
# lstsq_target_polynomials_VS_symbolic_regression... -0.010  0.993  0.946 0.932
# inet_polynomials_VS_symbolic_regression_functions  -0.014  0.013  0.355 0.990
#
#                                                       L-4   L-5    L-6   L-7  \
# lambda_preds_VS_target_polynomials                  0.998 0.914  0.946 0.999
# lambda_preds_VS_lstsq_lambda_pred_polynomials       1.000 0.989  0.976 1.000
# lambda_preds_VS_lstsq_target_polynomials            0.998 0.914  0.946 0.999
# lambda_preds_VS_inet_polynomials                   -0.310 0.929  0.290 0.203
# lambda_preds_VS_symbolic_regression_functions      -0.097 0.946 -0.090 0.998
# target_polynomials_VS_lstsq_lambda_pred_polynom...  0.998 0.947  0.982 0.999
# target_polynomials_VS_lstsq_target_polynomials      1.000 1.000  1.000 1.000
# target_polynomials_VS_inet_polynomials             -0.254 0.974  0.268 0.264
# target_polynomials_VS_symbolic_regression_funct... -0.089 0.990 -0.039 0.997
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  0.998 0.928  0.977 0.999
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  -0.308 0.940  0.286 0.202
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... -0.096 0.956 -0.086 0.998
# lstsq_target_polynomials_VS_inet_polynomials       -0.254 0.974  0.268 0.264
# lstsq_target_polynomials_VS_symbolic_regression... -0.089 0.990 -0.039 0.997
# inet_polynomials_VS_symbolic_regression_functions  -0.218 0.978 -1.398 0.480
#
#                                                      L-8    L-9  L-10  \
# lambda_preds_VS_target_polynomials                 0.998  0.994 0.970
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.999  0.999 0.992
# lambda_preds_VS_lstsq_target_polynomials           0.998  0.994 0.970
# lambda_preds_VS_inet_polynomials                   0.801 -0.207 0.959
# lambda_preds_VS_symbolic_regression_functions      0.993  0.929 0.979
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.999  0.996 0.986
# target_polynomials_VS_lstsq_target_polynomials     1.000  1.000 1.000
# target_polynomials_VS_inet_polynomials             0.786 -0.144 0.985
# target_polynomials_VS_symbolic_regression_funct... 0.993  0.945 0.998
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.999  0.996 0.983
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.798 -0.208 0.971
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.994  0.930 0.990
# lstsq_target_polynomials_VS_inet_polynomials       0.786 -0.144 0.985
# lstsq_target_polynomials_VS_symbolic_regression... 0.993  0.945 0.998
# inet_polynomials_VS_symbolic_regression_functions  0.588  0.305 0.981
#
#                                                        L-11   L-12       L-13  \
# lambda_preds_VS_target_polynomials                   -0.006  0.979     -0.175
# lambda_preds_VS_lstsq_lambda_pred_polynomials         0.273  0.990      0.281
# lambda_preds_VS_lstsq_target_polynomials             -0.006  0.979     -0.175
# lambda_preds_VS_inet_polynomials                     -2.335  0.514     -1.434
# lambda_preds_VS_symbolic_regression_functions      -112.685 -0.323  -4768.349
# target_polynomials_VS_lstsq_lambda_pred_polynom...    0.000  0.991      0.000
# target_polynomials_VS_lstsq_target_polynomials        1.000  1.000      1.000
# target_polynomials_VS_inet_polynomials                0.000  0.455      0.000
# target_polynomials_VS_symbolic_regression_funct...    0.000 -0.257      0.000
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...   -0.021  0.990     -0.460
# lstsq_lambda_pred_polynomials_VS_inet_polynomials    -8.504  0.511     -5.475
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... -419.036 -0.314 -16903.966
# lstsq_target_polynomials_VS_inet_polynomials          0.000  0.455      0.000
# lstsq_target_polynomials_VS_symbolic_regression...    0.000 -0.257      0.000
# inet_polynomials_VS_symbolic_regression_functions  -198.694 -2.787  -9954.558
#
#                                                      L-14  L-15   L-16  L-17  \
# lambda_preds_VS_target_polynomials                  0.980 0.980  0.982 0.996
# lambda_preds_VS_lstsq_lambda_pred_polynomials       0.998 0.991  0.994 1.000
# lambda_preds_VS_lstsq_target_polynomials            0.980 0.980  0.982 0.996
# lambda_preds_VS_inet_polynomials                   -0.132 0.931 -0.521 0.931
# lambda_preds_VS_symbolic_regression_functions      -0.074 0.980  0.972 0.881
# target_polynomials_VS_lstsq_lambda_pred_polynom...  0.985 0.991  0.989 0.997
# target_polynomials_VS_lstsq_target_polynomials      1.000 1.000  1.000 1.000
# target_polynomials_VS_inet_polynomials             -0.006 0.952 -0.299 0.915
# target_polynomials_VS_symbolic_regression_funct... -0.101 0.999  0.998 0.884
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  0.982 0.989  0.987 0.997
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  -0.133 0.939 -0.507 0.931
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... -0.074 0.989  0.977 0.882
# lstsq_target_polynomials_VS_inet_polynomials       -0.006 0.952 -0.299 0.915
# lstsq_target_polynomials_VS_symbolic_regression... -0.101 0.999  0.998 0.884
# inet_polynomials_VS_symbolic_regression_functions  -0.053 0.938  0.384 0.711
#
#                                                      L-18   L-19  L-20  L-21  \
# lambda_preds_VS_target_polynomials                  0.999  0.998 0.998 0.999
# lambda_preds_VS_lstsq_lambda_pred_polynomials       1.000  1.000 1.000 1.000
# lambda_preds_VS_lstsq_target_polynomials            0.999  0.998 0.998 0.999
# lambda_preds_VS_inet_polynomials                   -0.043 -0.566 0.911 0.844
# lambda_preds_VS_symbolic_regression_functions       0.996  0.994 0.949 0.996
# target_polynomials_VS_lstsq_lambda_pred_polynom...  0.999  0.999 0.999 0.999
# target_polynomials_VS_lstsq_target_polynomials      1.000  1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials              0.010 -0.530 0.904 0.840
# target_polynomials_VS_symbolic_regression_funct...  0.995  0.991 0.944 0.994
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  0.999  0.999 0.999 0.999
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  -0.043 -0.560 0.910 0.843
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...  0.996  0.994 0.949 0.996
# lstsq_target_polynomials_VS_inet_polynomials        0.010 -0.530 0.904 0.840
# lstsq_target_polynomials_VS_symbolic_regression...  0.995  0.991 0.944 0.994
# inet_polynomials_VS_symbolic_regression_functions   0.254 -0.389 0.961 0.805
#
#                                                               L-22  \
# lambda_preds_VS_target_polynomials                          -0.505
# lambda_preds_VS_lstsq_lambda_pred_polynomials                0.989
# lambda_preds_VS_lstsq_target_polynomials                    -0.505
# lambda_preds_VS_inet_polynomials                            -1.432
# lambda_preds_VS_symbolic_regression_functions            -4805.563
# target_polynomials_VS_lstsq_lambda_pred_polynom...     -350379.617
# target_polynomials_VS_lstsq_target_polynomials               1.000
# target_polynomials_VS_inet_polynomials                 -596538.706
# target_polynomials_VS_symbolic_regression_funct... -1136768681.667
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...          -0.506
# lstsq_lambda_pred_polynomials_VS_inet_polynomials           -1.496
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...       -4986.647
# lstsq_target_polynomials_VS_inet_polynomials           -596538.706
# lstsq_target_polynomials_VS_symbolic_regression... -1136768681.667
# inet_polynomials_VS_symbolic_regression_functions       -44831.785
#
#                                                                 L-23   L-24  \
# lambda_preds_VS_target_polynomials                            -0.006  0.999
# lambda_preds_VS_lstsq_lambda_pred_polynomials                  0.614  1.000
# lambda_preds_VS_lstsq_target_polynomials                      -0.006  0.999
# lambda_preds_VS_inet_polynomials                              -0.540 -0.075
# lambda_preds_VS_symbolic_regression_functions              -1138.637  0.997
# target_polynomials_VS_lstsq_lambda_pred_polynom...    -229558874.671  0.999
# target_polynomials_VS_lstsq_target_polynomials                 1.000  1.000
# target_polynomials_VS_inet_polynomials                -509793835.148 -0.047
# target_polynomials_VS_symbolic_regression_funct... -421278292180.811  0.997
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...            -0.023  0.999
# lstsq_lambda_pred_polynomials_VS_inet_polynomials             -0.902 -0.072
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...         -1849.584  0.998
# lstsq_target_polynomials_VS_inet_polynomials          -509793835.148 -0.047
# lstsq_target_polynomials_VS_symbolic_regression... -421278292180.811  0.997
# inet_polynomials_VS_symbolic_regression_functions          -1644.189  0.233
#
#                                                     L-25   L-26  L-27  L-28  \
# lambda_preds_VS_target_polynomials                 0.995  0.999 0.998 0.993
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000  1.000 1.000 0.999
# lambda_preds_VS_lstsq_target_polynomials           0.995  0.999 0.998 0.993
# lambda_preds_VS_inet_polynomials                   0.916 -0.229 0.806 0.887
# lambda_preds_VS_symbolic_regression_functions      0.995  0.992 0.993 0.993
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.995  0.999 0.999 0.996
# target_polynomials_VS_lstsq_target_polynomials     1.000  1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials             0.927 -0.198 0.799 0.869
# target_polynomials_VS_symbolic_regression_funct... 0.997  0.994 0.990 0.997
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.995  0.999 0.999 0.995
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.916 -0.228 0.805 0.886
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.996  0.993 0.993 0.994
# lstsq_target_polynomials_VS_inet_polynomials       0.927 -0.198 0.799 0.869
# lstsq_target_polynomials_VS_symbolic_regression... 0.997  0.994 0.990 0.997
# inet_polynomials_VS_symbolic_regression_functions  0.935 -0.331 0.716 0.812
#
#                                                     L-29  L-30   L-31   L-32  \
# lambda_preds_VS_target_polynomials                 0.992 0.999  0.976  0.984
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.999 1.000  0.997  0.999
# lambda_preds_VS_lstsq_target_polynomials           0.992 0.999  0.976  0.984
# lambda_preds_VS_inet_polynomials                   0.877 0.895 -1.025  0.347
# lambda_preds_VS_symbolic_regression_functions      0.992 0.997 -0.128 -0.137
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.995 0.999  0.984  0.989
# target_polynomials_VS_lstsq_target_polynomials     1.000 1.000  1.000  1.000
# target_polynomials_VS_inet_polynomials             0.870 0.891 -0.979  0.311
# target_polynomials_VS_symbolic_regression_funct... 0.988 0.997 -0.156 -0.157
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.994 0.999  0.981  0.987
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.877 0.894 -1.025  0.346
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.993 0.997 -0.128 -0.137
# lstsq_target_polynomials_VS_inet_polynomials       0.870 0.891 -0.979  0.311
# lstsq_target_polynomials_VS_symbolic_regression... 0.988 0.997 -0.156 -0.157
# inet_polynomials_VS_symbolic_regression_functions  0.898 0.871 -4.763 -0.443
#
#                                                     L-33  L-34   L-35    L-36  \
# lambda_preds_VS_target_polynomials                 0.987 0.969  0.959 -33.526
# lambda_preds_VS_lstsq_lambda_pred_polynomials      0.993 0.991  0.991   1.000
# lambda_preds_VS_lstsq_target_polynomials           0.987 0.969  0.959 -33.526
# lambda_preds_VS_inet_polynomials                   0.970 0.958  0.199   0.979
# lambda_preds_VS_symbolic_regression_functions      0.979 0.970 -0.055   0.966
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.992 0.982  0.974   0.079
# target_polynomials_VS_lstsq_target_polynomials     1.000 1.000  1.000   1.000
# target_polynomials_VS_inet_polynomials             0.978 0.986  0.252   0.058
# target_polynomials_VS_symbolic_regression_funct... 0.997 0.999 -0.058   0.063
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.991 0.978  0.969 -33.486
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.973 0.967  0.201   0.979
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.982 0.979 -0.052   0.966
# lstsq_target_polynomials_VS_inet_polynomials       0.978 0.986  0.252   0.058
# lstsq_target_polynomials_VS_symbolic_regression... 0.997 0.999 -0.058   0.063
# inet_polynomials_VS_symbolic_regression_functions  0.969 0.984 -0.221   0.959
#
#                                                      L-37   L-38  L-39  L-40  \
# lambda_preds_VS_target_polynomials                  0.988  0.997 0.997 0.993
# lambda_preds_VS_lstsq_lambda_pred_polynomials       0.994  1.000 0.999 1.000
# lambda_preds_VS_lstsq_target_polynomials            0.988  0.997 0.997 0.993
# lambda_preds_VS_inet_polynomials                   -1.103  0.674 0.855 0.217
# lambda_preds_VS_symbolic_regression_functions       0.987 -0.926 0.986 0.998
# target_polynomials_VS_lstsq_lambda_pred_polynom...  0.991  0.998 0.998 0.994
# target_polynomials_VS_lstsq_target_polynomials      1.000  1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials             -0.806  0.711 0.874 0.262
# target_polynomials_VS_symbolic_regression_funct...  0.998 -0.833 0.987 0.988
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  0.989  0.998 0.998 0.993
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  -1.110  0.675 0.855 0.218
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...  0.987 -0.912 0.987 0.998
# lstsq_target_polynomials_VS_inet_polynomials       -0.806  0.711 0.874 0.262
# lstsq_target_polynomials_VS_symbolic_regression...  0.998 -0.833 0.987 0.988
# inet_polynomials_VS_symbolic_regression_functions   0.291 -2.677 0.669 0.480
#
#                                                                 L-41   L-42  \
# lambda_preds_VS_target_polynomials                            -0.249  0.987
# lambda_preds_VS_lstsq_lambda_pred_polynomials                  0.959  0.999
# lambda_preds_VS_lstsq_target_polynomials                      -0.249  0.987
# lambda_preds_VS_inet_polynomials                               0.788  0.640
# lambda_preds_VS_symbolic_regression_functions                 -0.211 -0.023
# target_polynomials_VS_lstsq_lambda_pred_polynom... -175143566433.454  0.988
# target_polynomials_VS_lstsq_target_polynomials                 1.000  1.000
# target_polynomials_VS_inet_polynomials             -133429058487.730  0.667
# target_polynomials_VS_symbolic_regression_funct...    -229037951.000 -0.056
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...            -0.253  0.987
# lstsq_lambda_pred_polynomials_VS_inet_polynomials              0.812  0.639
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...            -0.214 -0.022
# lstsq_target_polynomials_VS_inet_polynomials       -133429058487.730  0.667
# lstsq_target_polynomials_VS_symbolic_regression...    -229037951.000 -0.056
# inet_polynomials_VS_symbolic_regression_functions             -0.930 -0.409
#
#                                                      L-43   L-44  L-45   L-46  \
# lambda_preds_VS_target_polynomials                  0.987  1.000 0.999  0.997
# lambda_preds_VS_lstsq_lambda_pred_polynomials       0.997  1.000 1.000  0.999
# lambda_preds_VS_lstsq_target_polynomials            0.987  1.000 0.999  0.997
# lambda_preds_VS_inet_polynomials                    0.563 -0.304 0.096 -0.894
# lambda_preds_VS_symbolic_regression_functions      -0.347  0.990 0.998 -0.183
# target_polynomials_VS_lstsq_lambda_pred_polynom...  0.991  1.000 0.999  0.998
# target_polynomials_VS_lstsq_target_polynomials      1.000  1.000 1.000  1.000
# target_polynomials_VS_inet_polynomials              0.509 -0.295 0.159 -0.819
# target_polynomials_VS_symbolic_regression_funct... -0.366  0.992 0.999 -0.185
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  0.991  1.000 0.999  0.998
# lstsq_lambda_pred_polynomials_VS_inet_polynomials   0.559 -0.303 0.095 -0.887
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... -0.340  0.990 0.998 -0.183
# lstsq_target_polynomials_VS_inet_polynomials        0.509 -0.295 0.159 -0.819
# lstsq_target_polynomials_VS_symbolic_regression... -0.366  0.992 0.999 -0.185
# inet_polynomials_VS_symbolic_regression_functions  -1.474 -0.451 0.459 -1.957
#
#                                                      L-47  L-48  \
# lambda_preds_VS_target_polynomials                  0.999 1.000
# lambda_preds_VS_lstsq_lambda_pred_polynomials       1.000 1.000
# lambda_preds_VS_lstsq_target_polynomials            0.999 1.000
# lambda_preds_VS_inet_polynomials                   -0.122 0.069
# lambda_preds_VS_symbolic_regression_functions       0.983 1.000
# target_polynomials_VS_lstsq_lambda_pred_polynom...  0.999 1.000
# target_polynomials_VS_lstsq_target_polynomials      1.000 1.000
# target_polynomials_VS_inet_polynomials             -0.036 0.075
# target_polynomials_VS_symbolic_regression_funct...  0.982 1.000
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  0.999 1.000
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  -0.121 0.069
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...  0.983 1.000
# lstsq_target_polynomials_VS_inet_polynomials       -0.036 0.075
# lstsq_target_polynomials_VS_symbolic_regression...  0.982 1.000
# inet_polynomials_VS_symbolic_regression_functions   0.476 0.508
#
#                                                              L-49  L-50  L-51  \
# lambda_preds_VS_target_polynomials                         -0.061 0.999 0.999
# lambda_preds_VS_lstsq_lambda_pred_polynomials               0.913 1.000 0.999
# lambda_preds_VS_lstsq_target_polynomials                   -0.061 0.999 0.999
# lambda_preds_VS_inet_polynomials                           -5.215 0.917 0.676
# lambda_preds_VS_symbolic_regression_functions              -3.649 0.994 0.999
# target_polynomials_VS_lstsq_lambda_pred_polynom... -102055090.335 0.999 0.999
# target_polynomials_VS_lstsq_target_polynomials              1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials             -343947788.315 0.914 0.668
# target_polynomials_VS_symbolic_regression_funct... -301577951.000 0.992 1.000
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...         -0.065 0.999 0.999
# lstsq_lambda_pred_polynomials_VS_inet_polynomials          -5.870 0.916 0.676
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...         -4.116 0.994 0.999
# lstsq_target_polynomials_VS_inet_polynomials       -343947788.315 0.914 0.668
# lstsq_target_polynomials_VS_symbolic_regression... -301577951.000 0.992 1.000
# inet_polynomials_VS_symbolic_regression_functions          -0.061 0.848 0.061
#
#                                                      L-52  L-53  L-54  L-55  \
# lambda_preds_VS_target_polynomials                  0.955 0.989 0.997 0.993
# lambda_preds_VS_lstsq_lambda_pred_polynomials       0.987 0.999 1.000 0.999
# lambda_preds_VS_lstsq_target_polynomials            0.955 0.989 0.997 0.993
# lambda_preds_VS_inet_polynomials                    0.246 0.985 0.250 0.773
# lambda_preds_VS_symbolic_regression_functions      -0.000 0.978 0.979 0.852
# target_polynomials_VS_lstsq_lambda_pred_polynom...  0.975 0.990 0.998 0.995
# target_polynomials_VS_lstsq_target_polynomials      1.000 1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials              0.400 0.983 0.345 0.743
# target_polynomials_VS_symbolic_regression_funct... -0.001 0.991 0.976 0.828
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  0.969 0.990 0.998 0.994
# lstsq_lambda_pred_polynomials_VS_inet_polynomials   0.235 0.984 0.252 0.771
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... -0.000 0.979 0.979 0.852
# lstsq_target_polynomials_VS_inet_polynomials        0.400 0.983 0.345 0.743
# lstsq_target_polynomials_VS_symbolic_regression... -0.001 0.991 0.976 0.828
# inet_polynomials_VS_symbolic_regression_functions  -0.086 0.976 0.555 0.784
#
#                                                      L-56  L-57  L-58  L-59  \
# lambda_preds_VS_target_polynomials                  0.999 0.994 0.998 0.999
# lambda_preds_VS_lstsq_lambda_pred_polynomials       1.000 1.000 1.000 1.000
# lambda_preds_VS_lstsq_target_polynomials            0.999 0.994 0.998 0.999
# lambda_preds_VS_inet_polynomials                   -0.055 0.137 0.881 0.866
# lambda_preds_VS_symbolic_regression_functions       0.973 0.958 0.893 0.908
# target_polynomials_VS_lstsq_lambda_pred_polynom...  0.999 0.995 0.999 0.999
# target_polynomials_VS_lstsq_target_polynomials      1.000 1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials              0.006 0.251 0.872 0.857
# target_polynomials_VS_symbolic_regression_funct...  0.976 0.952 0.898 0.898
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  0.999 0.994 0.999 0.999
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  -0.056 0.137 0.880 0.865
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...  0.973 0.958 0.893 0.907
# lstsq_target_polynomials_VS_inet_polynomials        0.006 0.251 0.872 0.857
# lstsq_target_polynomials_VS_symbolic_regression...  0.976 0.952 0.898 0.898
# inet_polynomials_VS_symbolic_regression_functions   0.317 0.645 0.757 0.841
#
#                                                      L-60   L-61  L-62   L-63  \
# lambda_preds_VS_target_polynomials                  0.901  0.975 0.957  0.997
# lambda_preds_VS_lstsq_lambda_pred_polynomials       0.990  0.998 0.992  0.999
# lambda_preds_VS_lstsq_target_polynomials            0.901  0.975 0.957  0.997
# lambda_preds_VS_inet_polynomials                    0.361  0.812 0.550 -0.546
# lambda_preds_VS_symbolic_regression_functions      -0.109 -0.244 0.960  0.329
# target_polynomials_VS_lstsq_lambda_pred_polynom...  0.928  0.979 0.975  0.999
# target_polynomials_VS_lstsq_target_polynomials      1.000  1.000 1.000  1.000
# target_polynomials_VS_inet_polynomials              0.278  0.758 0.764 -0.503
# target_polynomials_VS_symbolic_regression_funct... -0.131 -0.137 0.950  0.352
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  0.911  0.977 0.968  0.999
# lstsq_lambda_pred_polynomials_VS_inet_polynomials   0.363  0.811 0.579 -0.539
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... -0.105 -0.240 0.967  0.331
# lstsq_target_polynomials_VS_inet_polynomials        0.278  0.758 0.764 -0.503
# lstsq_target_polynomials_VS_symbolic_regression... -0.131 -0.137 0.950  0.352
# inet_polynomials_VS_symbolic_regression_functions  -0.501 -0.583 0.731  0.690
#
#                                                      L-64  L-65   L-66  L-67  \
# lambda_preds_VS_target_polynomials                  0.993 0.998  0.966 0.998
# lambda_preds_VS_lstsq_lambda_pred_polynomials       0.998 1.000  0.991 1.000
# lambda_preds_VS_lstsq_target_polynomials            0.993 0.998  0.966 0.998
# lambda_preds_VS_inet_polynomials                   -0.746 0.713 -0.202 0.112
# lambda_preds_VS_symbolic_regression_functions       0.979 0.815  0.972 0.997
# target_polynomials_VS_lstsq_lambda_pred_polynom...  0.995 0.999  0.982 0.998
# target_polynomials_VS_lstsq_target_polynomials      1.000 1.000  1.000 1.000
# target_polynomials_VS_inet_polynomials             -0.852 0.699 -0.024 0.187
# target_polynomials_VS_symbolic_regression_funct...  0.967 0.808  0.993 0.999
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  0.995 0.999  0.978 0.998
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  -0.731 0.712 -0.174 0.112
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...  0.979 0.815  0.982 0.997
# lstsq_target_polynomials_VS_inet_polynomials       -0.852 0.699 -0.024 0.187
# lstsq_target_polynomials_VS_symbolic_regression...  0.967 0.808  0.993 0.999
# inet_polynomials_VS_symbolic_regression_functions  -0.252 0.574  0.285 0.501
#
#                                                      L-68   L-69   L-70  \
# lambda_preds_VS_target_polynomials                  0.985 -6.486  1.000
# lambda_preds_VS_lstsq_lambda_pred_polynomials       0.996  1.000  1.000
# lambda_preds_VS_lstsq_target_polynomials            0.985 -6.486  1.000
# lambda_preds_VS_inet_polynomials                   -1.329  0.988 -0.581
# lambda_preds_VS_symbolic_regression_functions       0.977  0.927 -0.051
# target_polynomials_VS_lstsq_lambda_pred_polynom...  0.989  0.154  1.000
# target_polynomials_VS_lstsq_target_polynomials      1.000  1.000  1.000
# target_polynomials_VS_inet_polynomials             -1.480  0.156 -0.564
# target_polynomials_VS_symbolic_regression_funct...  0.977  0.140 -0.048
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  0.988 -6.489  1.000
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  -1.306  0.988 -0.581
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...  0.978  0.927 -0.051
# lstsq_target_polynomials_VS_inet_polynomials       -1.480  0.156 -0.564
# lstsq_target_polynomials_VS_symbolic_regression...  0.977  0.140 -0.048
# inet_polynomials_VS_symbolic_regression_functions  -0.800  0.836 -0.004
#
#                                                      L-71  L-72    L-73  \
# lambda_preds_VS_target_polynomials                  0.966 0.998   0.995
# lambda_preds_VS_lstsq_lambda_pred_polynomials       0.995 1.000   0.999
# lambda_preds_VS_lstsq_target_polynomials            0.966 0.998   0.995
# lambda_preds_VS_inet_polynomials                   -1.050 0.975  -2.547
# lambda_preds_VS_symbolic_regression_functions      -0.070 0.997   0.900
# target_polynomials_VS_lstsq_lambda_pred_polynom...  0.981 0.998   0.996
# target_polynomials_VS_lstsq_target_polynomials      1.000 1.000   1.000
# target_polynomials_VS_inet_polynomials             -0.871 0.983  -2.514
# target_polynomials_VS_symbolic_regression_funct... -0.073 0.999   0.938
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  0.976 0.998   0.996
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  -1.048 0.975  -2.538
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... -0.068 0.997   0.903
# lstsq_target_polynomials_VS_inet_polynomials       -0.871 0.983  -2.514
# lstsq_target_polynomials_VS_symbolic_regression... -0.073 0.999   0.938
# inet_polynomials_VS_symbolic_regression_functions  -0.010 0.987 -23.027
#
#                                                      L-74   L-75  L-76  L-77  \
# lambda_preds_VS_target_polynomials                  0.998  0.997 0.989 1.000
# lambda_preds_VS_lstsq_lambda_pred_polynomials       1.000  0.998 0.998 1.000
# lambda_preds_VS_lstsq_target_polynomials            0.998  0.997 0.989 1.000
# lambda_preds_VS_inet_polynomials                   -0.188 -0.912 0.907 0.043
# lambda_preds_VS_symbolic_regression_functions       0.952 -0.380 0.960 0.996
# target_polynomials_VS_lstsq_lambda_pred_polynom...  0.999  0.999 0.992 1.000
# target_polynomials_VS_lstsq_target_polynomials      1.000  1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials             -0.157 -0.894 0.873 0.072
# target_polynomials_VS_symbolic_regression_funct...  0.954 -0.390 0.934 0.995
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  0.999  0.999 0.992 1.000
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  -0.188 -0.900 0.906 0.043
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...  0.952 -0.375 0.961 0.996
# lstsq_target_polynomials_VS_inet_polynomials       -0.157 -0.894 0.873 0.072
# lstsq_target_polynomials_VS_symbolic_regression...  0.954 -0.390 0.934 0.995
# inet_polynomials_VS_symbolic_regression_functions   0.445 -0.651 0.954 0.529
#
#                                                      L-78  L-79   L-80  L-81  \
# lambda_preds_VS_target_polynomials                  0.824 0.190  0.981 0.969
# lambda_preds_VS_lstsq_lambda_pred_polynomials       0.998 1.000  0.997 0.993
# lambda_preds_VS_lstsq_target_polynomials            0.824 0.190  0.981 0.969
# lambda_preds_VS_inet_polynomials                    0.931 0.983 -1.000 0.947
# lambda_preds_VS_symbolic_regression_functions      -0.014 0.997  0.988 0.974
# target_polynomials_VS_lstsq_lambda_pred_polynom...  0.722 0.688  0.982 0.982
# target_polynomials_VS_lstsq_target_polynomials      1.000 1.000  1.000 1.000
# target_polynomials_VS_inet_polynomials              0.752 0.696 -1.258 0.986
# target_polynomials_VS_symbolic_regression_funct... -0.004 0.680  0.992 0.999
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  0.823 0.190  0.982 0.978
# lstsq_lambda_pred_polynomials_VS_inet_polynomials   0.933 0.983 -0.973 0.957
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... -0.014 0.997  0.991 0.983
# lstsq_target_polynomials_VS_inet_polynomials        0.752 0.696 -1.258 0.986
# lstsq_target_polynomials_VS_symbolic_regression... -0.004 0.680  0.992 0.999
# inet_polynomials_VS_symbolic_regression_functions  -0.024 0.982 -0.863 0.989
#
#                                                     L-82   L-83  L-84  \
# lambda_preds_VS_target_polynomials                 0.994  0.998 0.990
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000  0.999 0.996
# lambda_preds_VS_lstsq_target_polynomials           0.994  0.998 0.990
# lambda_preds_VS_inet_polynomials                   0.989 -0.665 0.770
# lambda_preds_VS_symbolic_regression_functions      0.980  0.843 0.858
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.995  0.999 0.995
# target_polynomials_VS_lstsq_target_polynomials     1.000  1.000 1.000
# target_polynomials_VS_inet_polynomials             0.992 -0.649 0.729
# target_polynomials_VS_symbolic_regression_funct... 0.979  0.834 0.833
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.994  0.999 0.994
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.989 -0.654 0.768
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.980  0.841 0.858
# lstsq_target_polynomials_VS_inet_polynomials       0.992 -0.649 0.729
# lstsq_target_polynomials_VS_symbolic_regression... 0.979  0.834 0.833
# inet_polynomials_VS_symbolic_regression_functions  0.969  0.205 0.818
#
#                                                                 L-85  L-86  \
# lambda_preds_VS_target_polynomials                            -0.096 0.999
# lambda_preds_VS_lstsq_lambda_pred_polynomials                  0.956 1.000
# lambda_preds_VS_lstsq_target_polynomials                      -0.096 0.999
# lambda_preds_VS_inet_polynomials                               0.802 0.840
# lambda_preds_VS_symbolic_regression_functions                 -0.091 0.990
# target_polynomials_VS_lstsq_lambda_pred_polynom... -135111658559.237 0.999
# target_polynomials_VS_lstsq_target_polynomials                 1.000 1.000
# target_polynomials_VS_inet_polynomials              -84010462292.892 0.841
# target_polynomials_VS_symbolic_regression_funct...     -11095560.000 0.991
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...            -0.102 0.999
# lstsq_lambda_pred_polynomials_VS_inet_polynomials              0.834 0.840
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...            -0.096 0.991
# lstsq_target_polynomials_VS_inet_polynomials        -84010462292.892 0.841
# lstsq_target_polynomials_VS_symbolic_regression...     -11095560.000 0.991
# inet_polynomials_VS_symbolic_regression_functions             -0.259 0.714
#
#                                                     L-87   L-88  L-89  L-90  \
# lambda_preds_VS_target_polynomials                 0.999  0.967 0.997 0.969
# lambda_preds_VS_lstsq_lambda_pred_polynomials      1.000  0.987 1.000 0.992
# lambda_preds_VS_lstsq_target_polynomials           0.999  0.967 0.997 0.969
# lambda_preds_VS_inet_polynomials                   0.869  0.660 0.743 0.029
# lambda_preds_VS_symbolic_regression_functions      0.916  0.905 0.846 0.984
# target_polynomials_VS_lstsq_lambda_pred_polynom... 0.999  0.976 0.997 0.984
# target_polynomials_VS_lstsq_target_polynomials     1.000  1.000 1.000 1.000
# target_polynomials_VS_inet_polynomials             0.866  0.634 0.722 0.072
# target_polynomials_VS_symbolic_regression_funct... 0.916  0.975 0.830 0.996
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p... 0.999  0.970 0.997 0.981
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  0.868  0.670 0.742 0.048
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... 0.916  0.900 0.845 0.993
# lstsq_target_polynomials_VS_inet_polynomials       0.866  0.634 0.722 0.072
# lstsq_target_polynomials_VS_symbolic_regression... 0.916  0.975 0.830 0.996
# inet_polynomials_VS_symbolic_regression_functions  0.803 -0.267 0.857 0.188
#
#                                                      L-91   L-92  L-93  \
# lambda_preds_VS_target_polynomials                  0.999  0.997 0.976
# lambda_preds_VS_lstsq_lambda_pred_polynomials       1.000  1.000 1.000
# lambda_preds_VS_lstsq_target_polynomials            0.999  0.997 0.976
# lambda_preds_VS_inet_polynomials                   -0.409 -0.154 0.986
# lambda_preds_VS_symbolic_regression_functions       0.989  0.924 0.999
# target_polynomials_VS_lstsq_lambda_pred_polynom...  1.000  0.997 0.980
# target_polynomials_VS_lstsq_target_polynomials      1.000  1.000 1.000
# target_polynomials_VS_inet_polynomials             -0.417 -0.104 0.983
# target_polynomials_VS_symbolic_regression_funct...  0.992  0.927 0.984
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  1.000  0.997 0.976
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  -0.408 -0.155 0.986
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...  0.990  0.925 0.999
# lstsq_target_polynomials_VS_inet_polynomials       -0.417 -0.104 0.983
# lstsq_target_polynomials_VS_symbolic_regression...  0.992  0.927 0.984
# inet_polynomials_VS_symbolic_regression_functions  -0.352 -0.104 0.991
#
#                                                        L-94   L-95  \
# lambda_preds_VS_target_polynomials                   -0.361  0.920
# lambda_preds_VS_lstsq_lambda_pred_polynomials         0.700  0.981
# lambda_preds_VS_lstsq_target_polynomials             -0.361  0.920
# lambda_preds_VS_inet_polynomials                     -1.333 -0.589
# lambda_preds_VS_symbolic_regression_functions      -188.497 -0.011
# target_polynomials_VS_lstsq_lambda_pred_polynom...    0.000  0.959
# target_polynomials_VS_lstsq_target_polynomials        1.000  1.000
# target_polynomials_VS_inet_polynomials                0.000 -0.378
# target_polynomials_VS_symbolic_regression_funct...    0.000 -0.017
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...   -0.606  0.942
# lstsq_lambda_pred_polynomials_VS_inet_polynomials    -1.687 -0.589
# lstsq_lambda_pred_polynomials_VS_symbolic_regre... -259.804 -0.009
# lstsq_target_polynomials_VS_inet_polynomials          0.000 -0.378
# lstsq_target_polynomials_VS_symbolic_regression...    0.000 -0.017
# inet_polynomials_VS_symbolic_regression_functions  -345.517 -0.087
#
#                                                                L-96   L-97  \
# lambda_preds_VS_target_polynomials                           -0.162  0.937
# lambda_preds_VS_lstsq_lambda_pred_polynomials                 0.952  0.991
# lambda_preds_VS_lstsq_target_polynomials                     -0.162  0.937
# lambda_preds_VS_inet_polynomials                             -0.950  0.326
# lambda_preds_VS_symbolic_regression_functions                -0.098 -0.072
# target_polynomials_VS_lstsq_lambda_pred_polynom... -35752921132.243  0.962
# target_polynomials_VS_lstsq_target_polynomials                1.000  1.000
# target_polynomials_VS_inet_polynomials             -51920188678.261  0.343
# target_polynomials_VS_symbolic_regression_funct...   -254370607.000 -0.074
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...           -0.170  0.949
# lstsq_lambda_pred_polynomials_VS_inet_polynomials            -0.927  0.304
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...           -0.103 -0.072
# lstsq_target_polynomials_VS_inet_polynomials       -51920188678.261  0.343
# lstsq_target_polynomials_VS_symbolic_regression...   -254370607.000 -0.074
# inet_polynomials_VS_symbolic_regression_functions            -0.375 -0.014
#
#                                                      L-98  L-99
# lambda_preds_VS_target_polynomials                  0.997 0.997
# lambda_preds_VS_lstsq_lambda_pred_polynomials       0.999 1.000
# lambda_preds_VS_lstsq_target_polynomials            0.997 0.997
# lambda_preds_VS_inet_polynomials                   -0.275 0.991
# lambda_preds_VS_symbolic_regression_functions       0.896 0.782
# target_polynomials_VS_lstsq_lambda_pred_polynom...  0.998 0.997
# target_polynomials_VS_lstsq_target_polynomials      1.000 1.000
# target_polynomials_VS_inet_polynomials             -0.244 0.983
# target_polynomials_VS_symbolic_regression_funct...  0.893 0.821
# lstsq_lambda_pred_polynomials_VS_lstsq_target_p...  0.998 0.997
# lstsq_lambda_pred_polynomials_VS_inet_polynomials  -0.274 0.992
# lstsq_lambda_pred_polynomials_VS_symbolic_regre...  0.896 0.782
# lstsq_target_polynomials_VS_inet_polynomials       -0.244 0.983
# lstsq_target_polynomials_VS_symbolic_regression...  0.893 0.821
# inet_polynomials_VS_symbolic_regression_functions  -0.311 0.757

# %%
index_min = int(np.argmin(distrib_dict_test_list[-1]['R2'].loc['lambda_preds_VS_lstsq_target_polynomials']))
polynomial_inet = polynomial_dict_test_list[-1]['inet_polynomials'][index_min]

print(distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_inet_polynomials'][index_min])

print_polynomial_from_coefficients(polynomial_inet)
# Out:
# 0.057691317199282555
# -0.0199464131146669*a**2 + 1.10524927545339*a - 2.27522015571594

# %%
index_min = int(np.argmin(distrib_dict_test_list[-1]['R2'].loc['lambda_preds_VS_lstsq_lambda_pred_polynomials']))
#polynomial_target = lambda_net_test_dataset.get_lambda_net_by_lambda_index(index_min).target_polynomial

print(distrib_dict_test_list[-1]['R2'].loc['lstsq_lambda_pred_polynomials_VS_inet_polynomials'][index_min])

polynomial_lambda = lambda_net_test_dataset.lstsq_lambda_pred_polynomial_list[index_min]
print_polynomial_from_coefficients(polynomial_lambda, force_complete_poly_representation=True)
# Out:
# -8.504310677202877
# 0.006965951855602*a**3 - 0.012369441509272*a**2 + 0.0064806776365486*a - 0.183799491730862 + 4.52621138168951e-5/a

# %%
index_min = int(np.argmin(distrib_dict_test_list[-1]['R2'].loc['lambda_preds_VS_lstsq_target_polynomials']))
#polynomial_target = lambda_net_test_dataset.get_lambda_net_by_lambda_index(index_min).target_polynomial
polynomial_target = lambda_net_test_dataset.target_polynomial_list[index_min]
print_polynomial_from_coefficients(polynomial_target, force_complete_poly_representation=True)
# Out:
# -0.980746790040838*a**2 - 0.924766174926323*a + 0.761711582158579 - 0.712019241522892/a

# %%
index_max = int(np.argmax(distrib_dict_test_list[-1]['R2'].loc['lambda_preds_VS_lstsq_target_polynomials']))
polynomial_inet = polynomial_dict_test_list[-1]['inet_polynomials'][index_max]

print(distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_inet_polynomials'][index_max])

print_polynomial_from_coefficients(polynomial_inet)
# Out:
# 0.07497698379959206
# 0.0911250598728657*a - 1.2930109500885 + 0.120101012289524/a

# %%
index_max = int(np.argmax(distrib_dict_test_list[-1]['R2'].loc['lambda_preds_VS_lstsq_target_polynomials']))
#polynomial_target = lambda_net_test_dataset.get_lambda_net_by_lambda_index(index_min).target_polynomial

print(distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_lstsq_lambda_pred_polynomials'][index_max])

polynomial_lambda = lambda_net_test_dataset.lstsq_lambda_pred_polynomial_list[index_max]
print_polynomial_from_coefficients(polynomial_lambda, force_complete_poly_representation=True)
# Out:
# 0.9999823445646886
# 0.0070670207985689*a**3 - 0.0128557045188074*a**2 - 0.978970838288904*a - 0.309506002514107 + 4.90736863298924e-5/a

# %%
index_max = int(np.argmax(distrib_dict_test_list[-1]['R2'].loc['lambda_preds_VS_lstsq_target_polynomials']))
#polynomial_target = lambda_net_test_dataset.get_lambda_net_by_lambda_index(index_min).target_polynomial
polynomial_target = lambda_net_test_dataset.target_polynomial_list[index_max]
print_polynomial_from_coefficients(polynomial_target, force_complete_poly_representation=True)
# Out:
# -0.988838227087776*a - 0.307710102528583

# %%
r2_values_inet = distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_inet_polynomials']
print('Mean: ' + str(np.mean(r2_values_inet)) + ' (' + str(r2_values_inet.shape[0]) + ' Samples)')

r2_values_positive_inet = r2_values_inet[r2_values_inet>0]
print('Mean (only positive): ' + str(np.mean(r2_values_positive_inet)) + ' (' + str(r2_values_positive_inet.shape[0]) + ' Samples)')
# Out:
# Mean: -2702140475.9726458 (100 Samples)
# Mean (only positive): 0.6361149199512632 (62 Samples)

# %%
r2_values_lstsq_lambda = distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_lstsq_lambda_pred_polynomials']
print('Mean: ' + str(np.mean(r2_values_lstsq_lambda)) + ' (' + str(r2_values_inet.shape[0]) + ' Samples)')

r2_values_positive_lstsq_lambda = r2_values_lstsq_lambda[r2_values_lstsq_lambda>0]
print('Mean (only positive): ' + str(np.mean(r2_values_positive_lstsq_lambda)) + ' (' + str(r2_values_positive_lstsq_lambda.shape[0]) + ' Samples)')
# Out:
# Mean: -3463401103.8165755 (100 Samples)
# Mean (only positive): 0.9659293662070654 (91 Samples)

# %%
p = sns.histplot(distrib_dict_test_list[-1]['MAE'].loc['lambda_preds_VS_inet_polynomials'][distrib_dict_test_list[-1]['R2'].loc['lambda_preds_VS_inet_polynomials'] < 50], binwidth=0.1)
#p.set(xlim=(0, 20))

# %%
p = sns.histplot(distrib_dict_test_list[-1]['MAE'].loc['lambda_preds_VS_inet_polynomials'][distrib_dict_test_list[-1]['R2'].loc['lambda_preds_VS_inet_polynomials'] < 50], binwidth=0.1)
p.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
p = sns.histplot(distrib_dict_test_list[-1]['MAE'].loc['target_polynomials_VS_inet_polynomials'][distrib_dict_test_list[-1]['MAE'].loc['target_polynomials_VS_inet_polynomials'] < 50], binwidth=0.1)
#p.set(xlim=(0, 20))

# %%
p = sns.histplot(distrib_dict_test_list[-1]['MAE'].loc['target_polynomials_VS_inet_polynomials'][distrib_dict_test_list[-1]['MAE'].loc['target_polynomials_VS_inet_polynomials'] < 50], binwidth=0.1)
p.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
p = sns.histplot(distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_inet_polynomials'][distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_inet_polynomials'] > -50], binwidth=0.2)
p.set(xlim=(-30, 1))
# Out:
# [(-30.0, 1.0)]

# %%
p = sns.histplot(distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_inet_polynomials'][distrib_dict_test_list[-1]['R2'].loc['target_polynomials_VS_inet_polynomials'] > -50], binwidth=0.1)
p.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
if not nas:
    history = history_list[-1]

    plt.plot(history[list(history.keys())[1]])
    if consider_labels_training or evaluate_with_real_function:
        plt.plot(history[list(history.keys())[len(history.keys())//2+1]]) 
    plt.title('model ' + list(history.keys())[1])
    plt.ylabel('metric')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')
    plt.savefig('./data/results/' + path_identifier_interpretation_net_data + '/metric_' + '_epoch_' + str(epochs_lambda).zfill(3) + '.png')

# %%
if not nas:
    history = history_list[-1]

    plt.plot(history['loss'])
    if consider_labels_training or evaluate_with_real_function:
        plt.plot(history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')
    plt.savefig('./data/results/' + path_identifier_interpretation_net_data + '/loss_' + '_epoch_' + str(epochs_lambda).zfill(3) + '.png')

# %% [markdown]
# ### Multi Epoch/Sampes Analysis

# %% [markdown]
# ### Generate Comparison Plots

# %%
if len(scores_test_list) > 1:
    plot_metric_list = ['MAE FV', 'RMSE FV', 'MAPE FV', 'R2 FV', 'RAAE FV', 'RMAE FV']

    generate_inet_comparison_plot(scores_test_list, plot_metric_list)

# %%
if len(scores_test_list) > 1:
    plot_metric_list = ['MAE FV']

    generate_inet_comparison_plot(scores_test_list, plot_metric_list)

# %%
if len(scores_test_list) > 1:
    plot_metric_list = ['R2 FV']

    generate_inet_comparison_plot(scores_test_list, plot_metric_list, ylim=(-5, 1))

# %% [markdown]
# #### Generate and Analyze Predictions for Random Function

# %%
index = 6

custom_representation_keys_fixed = ['target_polynomials', 'lstsq_target_polynomials', 'lstsq_lambda_pred_polynomials', 'lstsq_lambda_pred_polynomials']
custom_representation_keys_dynamic = ['inet_polynomials', 'per_network_polynomials']
sympy_representation_keys = ['metamodel_functions']


print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')

for key in polynomial_dict_test_list[-1].keys():
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print(key)
    if key in custom_representation_keys_fixed:
        print_polynomial_from_coefficients(polynomial_dict_test_list[-1][key][index], force_complete_poly_representation=True, round_digits=4)
    elif key in custom_representation_keys_dynamic:
        print_polynomial_from_coefficients(polynomial_dict_test_list[-1][key][index], round_digits=4)
    else:
        display(polynomial_dict_test_list[-1][key][index])

print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# lstsq_lambda_pred_polynomials
# 0.3885*a**3 - 0.3541*a**2 + 0.0279*a - 0.5208 + 0.0001/a
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# lstsq_target_polynomials
# 0.3779*a**3 - 0.3018*a**2 - 0.012*a - 0.5168
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# target_polynomials
# 0.3779*a**3 - 0.3018*a**2 - 0.012*a - 0.5168
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# inet_polynomials
# -0.0003*a**2 + 0.0328*a - 0.5502 + 0.0021/a
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# symbolic_regression_functions
# -0.533000000000000
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
plot_and_save_single_polynomial_prediction_evaluation(lambda_net_test_dataset_list, 
                                                      function_values_test_list, 
                                                      polynomial_dict_test_list,
                                                      rand_index=index, 
                                                      plot_type=1)

# %%
plot_and_save_single_polynomial_prediction_evaluation(lambda_net_test_dataset_list, 
                                                      function_values_test_list, 
                                                      polynomial_dict_test_list,
                                                      rand_index=index, 
                                                      plot_type=2)

# %%
plot_and_save_single_polynomial_prediction_evaluation(lambda_net_test_dataset_list, 
                                                      function_values_test_list, 
                                                      polynomial_dict_test_list,
                                                      rand_index=index, 
                                                      plot_type=3)

# %% [markdown]
# # BENCHMARK (RANDOM GUESS) EVALUATION

# %%
list_of_random_polynomials = np.random.uniform(low=-10, high=10, size=(len(lambda_net_test_dataset_list[-1]), sparsity))

# %%
true_fv_test = parallel_fv_calculation_from_polynomial(lambda_net_test_dataset_list[-1].target_polynomial_list, lambda_net_test_dataset_list[-1].X_test_data_list, force_complete_poly_representation=True)
random_fv_test = parallel_fv_calculation_from_polynomial(list_of_random_polynomials, lambda_net_test_dataset_list[-1].X_test_data_list, force_complete_poly_representation=True)

# %%
print('Random Guess Error Coefficients: ' + str(np.round(mean_absolute_error(lambda_net_test_dataset_list[-1].target_polynomial_list, list_of_random_polynomials), 4)))
# Out:
# Random Guess Error Coefficients: 5.2213

# %%
print('Random Guess Error FVs: ' + str(np.round(mean_absolute_error_function_values(true_fv_test, random_fv_test), 4)))
# Out:
# Random Guess Error FVs: 18.3952

# %% [markdown]
# # BENCHMARK (EDUCATED GUESS/MEAN PREDICTION) EVALUATION

# %%
true_fv_train = parallel_fv_calculation_from_polynomial(lambda_net_test_dataset_list[-1].target_polynomial_list, lambda_net_test_dataset_list[-1].X_test_data_list, force_complete_poly_representation=True)

mean_fv = np.mean(true_fv_train)
mean_fv_pred_test = [mean_fv for _ in range(true_fv_test.shape[0])]

# %%
print('Educated Guess/Mean Prediction Error FVs: ' + str(np.round(mean_absolute_error_function_values(true_fv_test, mean_fv_pred_test), 4)))
# Out:
# Educated Guess/Mean Prediction Error FVs: 0.635

# %%
# %%script false --no-raise-error
#
# base_model = generate_base_model()
# random_evaluation_dataset = np.random.uniform(low=x_min, high=x_max, size=(random_evaluation_dataset_size, n))
# #random_evaluation_dataset = lambda_train_input_train_split[0]#lambda_train_input[0] #JUST [0] HERE BECAUSE EVALUATION ALWAYS ON THE SAME DATASET FOR ALL!!
# list_of_monomial_identifiers_numbers = np.array([list(monomial_identifiers) for monomial_identifiers in list_of_monomial_identifiers]).astype(float)
#
#
# loss_function = mean_absolute_error_tf_fv_lambda_extended_wrapper(random_evaluation_dataset, list_of_monomial_identifiers_numbers, base_model)
#
# X_train = X_train_list[-1].values[:,1:]
# y_train = y_train_list[-1].values[:,2:]
#
# #X_train = X_train[:,1:]
# y_train_model = np.hstack((y_train, X_train))
#
# print('seed_in_inet_training = ' + str(seed_in_inet_training), loss_function(y_train_model, y_train))
#
#
# seed_in_inet_training = False
#
# loss_function = mean_absolute_error_tf_fv_lambda_extended_wrapper(random_evaluation_dataset, list_of_monomial_identifiers_numbers, base_model)
#
# X_train = X_train_list[-1].values[:,1:]
# y_train = y_train_list[-1].values[:,2:]
#
# X_train = X_train[:,1:]
# y_train_model = np.hstack((y_train, X_train))
#
# print('seed_in_inet_training = ' + str(seed_in_inet_training), loss_function(y_train_model, y_train))
#
# seed_in_inet_training = True

# %%
lambda_net_test_dataset = lambda_net_test_dataset_list[-1]
current_jobs = 1

lr=0.5
max_steps = 100
early_stopping=10
restarts=2
per_network_dataset_size = 500

list_of_monomial_identifiers_numbers = np.array([list(monomial_identifiers) for monomial_identifiers in list_of_monomial_identifiers]).astype(float)  

if n_jobs != -1:
    n_jobs_per_network = min(n_jobs, os.cpu_count() // current_jobs)
else: 
    n_jobs_per_network = os.cpu_count() // current_jobs - 1

printing = True if n_jobs_per_network == 1 else False


lambda_network_weights_list = np.array(lambda_net_test_dataset.weight_list)
if evaluate_with_real_function: #target polynomial as inet target
    poly_representation_list = np.array(lambda_net_test_dataset.target_polynomial_list)
else: #lstsq lambda pred polynomial as inet target
    poly_representation_list = np.array(lambda_net_test_dataset.lstsq_lambda_pred_polynomial_list)


config = {
         'n': n,
         'inet_loss': inet_loss,
         'sparsity': sparsity,
         'lambda_network_layers': lambda_network_layers,
         'interpretation_net_output_shape': interpretation_net_output_shape,
         'RANDOM_SEED': RANDOM_SEED,
         'nas': nas,
         'number_of_lambda_weights': number_of_lambda_weights,
         'interpretation_net_output_monomials': interpretation_net_output_monomials,
         #'list_of_monomial_identifiers': list_of_monomial_identifiers,
         'x_min': x_min,
         'x_max': x_max,
         }


lambda_network_weights = lambda_network_weights_list[0]
poly_representation = poly_representation_list[0]



per_network_poly_optimization_tf(per_network_dataset_size, 
                                lambda_network_weights, 
                                  list_of_monomial_identifiers_numbers, 
                                  config, 
                                  lr=lr, 
                                  max_steps = max_steps, 
                                  early_stopping=early_stopping, 
                                  restarts=restarts, 
                                  printing=True)
# Out:
# Current best: 0.01806284487247467
#  Curr_res: 0.043330851942300797
#  Iteration 1, Step 30
# Optimization terminated at 0.01806284487247467
# array([ 0.43726218, -0.5042477 , -0.78008115,  0.16013157,  0.7148702 ,
#         0.7892921 ,  0.11484027,  0.33310425,  0.21091413,  0.62329304,
#         0.9865029 ,  0.12230623,  0.20660043,  0.87113273,  0.0206511 ,
#         0.21824265,  0.6902214 ,  0.70987105], dtype=float32)

# %% [markdown]
# # Evaluate Real Dataset

# %% [markdown]
# ##  Auto MPG-Dataset

# %%
interpretation_possible_autoMPG = False
print_head_autoMPG = None

url_autoMPG = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'
column_names_autoMPG = ['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
                'Acceleration', 'Model Year', 'Origin']

raw_dataset_autoMPG = pd.read_csv(url_autoMPG, names=column_names_autoMPG,
                          na_values='?', comment='\t',
                          sep=' ', skipinitialspace=True)

dataset_autoMPG = raw_dataset_autoMPG.dropna()

dataset_autoMPG['Origin'] = dataset_autoMPG['Origin'].map({1: 'USA', 2: 'Europe', 3: 'Japan'})
dataset_autoMPG = pd.get_dummies(dataset_autoMPG, columns=['Origin'], prefix='', prefix_sep='')


features_autoMPG = dataset_autoMPG.copy()

labels_autoMPG = features_autoMPG.pop('MPG')

features_autoMPG_normalized = (x_max-x_min)*(features_autoMPG-features_autoMPG.min())/(features_autoMPG.max()-features_autoMPG.min())+x_min

#labels_autoMPG = (labels_autoMPG-labels_autoMPG.min())/(labels_autoMPG.max()-labels_autoMPG.min())


if features_autoMPG_normalized.shape[1] >= n:
    if n == 1:
        features_autoMPG_model = features_autoMPG_normalized[['Horsepower']]
    elif n == train_features_normalized.shape[1]:
        features_autoMPG_model = features_autoMPG_normalized
    else:
        features_autoMPG_model = features_autoMPG_normalized.sample(n=n, axis='columns')
        
    print_head_autoMPG = features_autoMPG_model.head()
    interpretation_possible_autoMPG = True

print_head_autoMPG
# Out:
#    Horsepower
# 0       0.484
# 1       0.664
# 2       0.587
# 3       0.587
# 4       0.535

# %%
#%load_ext autoreload

# %%
np.isinf(features_autoMPG_model.values).any()
# Out:
# False

# %%
#%autoreload 2
if interpretation_possible_autoMPG:
    ((lambda_index_autoMPG, 
     current_seed_autoMPG, 
     polynomial_autoMPG, 
     polynomial_lstsq_pred_list_autoMPG, 
     polynomial_lstsq_true_list_autoMPG), 
    scores_list_autoMPG, 
    pred_list_autoMPG, 
    history_autoMPG, 
    model_autoMPG) = train_nn(lambda_index=0, 
                              X_data_lambda=features_autoMPG_model.values, 
                              y_data_real_lambda=labels_autoMPG.values, 
                              polynomial=None, 
                              seed_list=[RANDOM_SEED], 
                              callbacks=[PlotLossesKerasTF()], 
                              return_history=True, 
                              each_epochs_save=None, 
                              printing=False, 
                              return_model=True)
    
    polynomial_lstsq_pred_autoMPG = polynomial_lstsq_pred_list_autoMPG[-1]
# Out:
# Loss
# 	training         	 (min:    4.905, max:   23.529, cur:    5.310)
# 	validation       	 (min:    4.754, max:   23.420, cur:    4.760)
# mae
# 	training         	 (min:    4.905, max:   23.529, cur:    5.310)
# 	validation       	 (min:    4.754, max:   23.420, cur:    4.760)
# r2_keras_loss
# 	training         	 (min:   -0.358, max:    9.875, cur:   -0.265)
# 	validation       	 (min:   -0.163, max:   10.744, cur:   -0.141)
# root_mean_squared_error
# 	training         	 (min:    6.348, max:   24.931, cur:    6.868)
# 	validation       	 (min:    5.743, max:   24.609, cur:    5.776)

# %%
if interpretation_possible_autoMPG:
    x = tf.linspace(0.0, 1, 250)#tf.linspace(0.0, 250, 251)
    y = model_autoMPG.predict(x)

    plt.scatter(features_autoMPG_model['Horsepower'], labels_autoMPG, label='Data')
    plt.plot(x, y, color='k', label='Predictions')
    plt.xlabel('Horsepower')
    plt.ylabel('MPG')
    plt.legend()

# %%
config = {
        'n': n,
        'd': d,
        'inet_loss': inet_loss,
        'sparsity': sparsity,
        'lambda_network_layers': lambda_network_layers,
        'interpretation_net_output_shape': interpretation_net_output_shape,
        'RANDOM_SEED': RANDOM_SEED,
        'nas': nas,
        'number_of_lambda_weights': number_of_lambda_weights,
        'interpretation_net_output_monomials': interpretation_net_output_monomials,
        'fixed_initialization_lambda_training': fixed_initialization_lambda_training,
        'dropout': dropout,
        'lambda_network_layers': lambda_network_layers,
        'optimizer_lambda': optimizer_lambda,
        'loss_lambda': loss_lambda,        
         #'list_of_monomial_identifiers': list_of_monomial_identifiers,
         'x_min': x_min,
         'x_max': x_max,
         }

weights_autoMPG = model_autoMPG.get_weights()

weights_flat_autoMPG = []
for layer_weights, biases in pairwise(weights_autoMPG):    #clf.get_weights()
    for neuron in layer_weights:
        for weight in neuron:
            weights_flat_autoMPG.append(weight)
    for bias in biases:
        weights_flat_autoMPG.append(bias)
        
weights_flat_autoMPG = np.array(weights_flat_autoMPG)


x = pred_list_autoMPG['X_test_lambda']
y = pred_list_autoMPG['y_test_real_lambda']

y_model_autoMPG = model_autoMPG.predict(x)

# %%
if interpretation_possible_autoMPG:
    y_polynomial_lstsq_pred_autoMPG = calculate_function_values_from_polynomial(polynomial_lstsq_pred_autoMPG, x, force_complete_poly_representation=True)

    mae_model_polynomial_lstsq_pred_autoMPGy = mean_absolute_error(y_model_autoMPG, y_polynomial_lstsq_pred_autoMPG)
    mae_data_polynomial_lstsq_pred_autoMPG = mean_absolute_error(y, y_polynomial_lstsq_pred_autoMPG)

    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('LSTSQt Poly:')
    print_polynomial_from_coefficients(y_polynomial_lstsq_pred_autoMPG, force_complete_poly_representation=True)
    print('MAE Model: ', mae_model_polynomial_lstsq_pred_autoMPGy)
    print('MAE Data: ', mae_data_polynomial_lstsq_pred_autoMPG)
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# LSTSQt Poly:
# 26.3629591833812*a**3 + 27.3060494828427*a**2 + 21.3597457921857*a + 26.4634383195709 + 24.6599957531488/a
# MAE Model:  0.05356619874318937
# MAE Data:  3.6239935048463634
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
#%autoreload 2
if interpretation_possible_autoMPG:
    interpretation_net = model_list[-1]
    
    start = time.time() 
    
    #interpretation_net_poly = interpretation_net.predict(np.array([weights_flat_autoMPG]))[0]
    interpretation_net_poly = make_inet_prediction(interpretation_net, weights_flat_autoMPG, network_data=None, normalized=False, normalization_parameter_dict=None)
    
    
    end = time.time()     
    generation_time = (end - start) 
    minutes, seconds = divmod(int(generation_time), 60)
    hours, minutes = divmod(minutes, 60)        
    
    y_interpretation_net_poly = calculate_function_values_from_polynomial(interpretation_net_poly, x, force_complete_poly_representation=False)
    
    mae_model_interpretation_net_poly = mean_absolute_error(y_model_autoMPG, y_interpretation_net_poly)
    mae_data_interpretation_net_poly = mean_absolute_error(y, y_interpretation_net_poly)
    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('Interpretation Net Poly:')
    print_polynomial_from_coefficients(interpretation_net_poly, force_complete_poly_representation=False)
    print('MAE Model: ', mae_model_interpretation_net_poly)
    print('MAE Data: ', mae_data_interpretation_net_poly)    
    print('Computation Time: ' +  f'{hours:d}:{minutes:02d}:{seconds:02d}')    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Interpretation Net Poly:
# 12.3915214538574*a + 7.66886791586876 + 0.315670222043991/a
# MAE Model:  10.361902631371082
# MAE Data:  10.563334016026664
# Computation Time: 0:00:00
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
if interpretation_possible_autoMPG:

    start = time.time() 
    
    if False:
        per_network_hyperparams = {
            'optimizer':  'Powell',
            'jac': 'fprime',
            'max_steps': 5000,#100,
            'restarts': 3,
            'per_network_dataset_size': 500,
        }      
        
        per_network_function =  per_network_poly_optimization_scipy(per_network_dataset_size, 
                                                                  weights_flat_autoMPG, 
                                                                  list_of_monomial_identifiers_numbers, 
                                                                  config, 
                                                                  optimizer = per_network_hyperparams['optimizer'],
                                                                  jac = per_network_hyperparams['jac'],
                                                                  max_steps = per_network_hyperparams['max_steps'], 
                                                                  restarts=per_network_hyperparams['restarts'], 
                                                                  printing=True,
                                                                  return_error=False)
    else:
        per_network_hyperparams = {
            'optimizer': tf.keras.optimizers.RMSprop,
            'lr': 0.02,
            'max_steps': 500,
            'early_stopping': 10,
            'restarts': 3,
            'per_network_dataset_size': 5000,
        }   
        
        per_network_function =  per_network_poly_optimization_tf(per_network_hyperparams['per_network_dataset_size'], 
                                                              weights_flat_autoMPG, 
                                                              list_of_monomial_identifiers_numbers, 
                                                              config, 
                                                              optimizer = per_network_hyperparams['optimizer'],
                                                              lr=per_network_hyperparams['lr'], 
                                                              max_steps = per_network_hyperparams['max_steps'], 
                                                              early_stopping=per_network_hyperparams['early_stopping'], 
                                                              restarts=per_network_hyperparams['restarts'], 
                                                              printing=True,
                                                              return_error=False)
            
    end = time.time()     
    generation_time = (end - start) 
    minutes, seconds = divmod(int(generation_time), 60)
    hours, minutes = divmod(minutes, 60)  
    
    y_per_network_function = calculate_function_values_from_polynomial(per_network_function, x, force_complete_poly_representation=False)
    
    mae_model_interpretation_net_poly = mean_absolute_error(y_model_autoMPG, y_per_network_function)
    mae_data_interpretation_net_poly = mean_absolute_error(y, y_per_network_function)    
    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('Per Network Poly:')
    print_polynomial_from_coefficients(per_network_function)
    print('MAE Model: ', mae_model_interpretation_net_poly)
    print('MAE Data: ', mae_data_interpretation_net_poly)       
    print('Computation Time: ' +  f'{hours:d}:{minutes:02d}:{seconds:02d}')    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
# Out:
# Current best: 7.438439846038818
#  Curr_res: 7.438431262969971
#  Iteration 2, Step 499
# Optimization terminated at 3.6312174797058105
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Per Network Poly:
# -1.46445035934448*a**2 + 10.7217578887939 + 2.62981057167053/a
# MAE Model:  3.7819907106299833
# MAE Data:  4.003902169927048
# Computation Time: 0:00:19
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
if interpretation_possible_autoMPG:
    
    symbolic_regression_hyperparams = {
        'dataset_size': 500,
    }

    start = time.time() 
    
    symbolic_regression_function =  symbolic_regression(model_autoMPG, 
                                                      config,
                                                      symbolic_regression_hyperparams,
                                                      #printing = True,
                                                      return_error = False)
    
    end = time.time()     
    generation_time = (end - start) 
    minutes, seconds = divmod(int(generation_time), 60)
    hours, minutes = divmod(minutes, 60)        
    
    y_symbolic_regression_function = calculate_function_values_from_sympy(symbolic_regression_function, x)
    
    mae_model_symbolic_regression_function = mean_absolute_error(y_model_autoMPG, y_symbolic_regression_function)
    mae_data_symbolic_regression_function = mean_absolute_error(y, y_symbolic_regression_function)
    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('Symbolic Regression Poly:')    
    display(symbolic_regression_function)
    print('MAE Model: ', mae_model_symbolic_regression_function)
    print('MAE Data: ', mae_data_symbolic_regression_function)      
    print('Computation Time: ' +  f'{hours:d}:{minutes:02d}:{seconds:02d}')    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
# Out:
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0    48.81          2444.72       63          3.94532          3.67948      3.68m
#    1    38.53          24.5583       63          1.45493          1.45514      2.67m
#    2    52.08          35.9285       93          1.03246            1.069      2.82m
#    3    58.53          28.3778       19         0.906275         0.894441      2.89m
#    4    62.05          30.8687       37         0.464196         0.446686      2.82m
#    5    59.33          36.3004       37         0.457284         0.508896      2.48m
#    6    54.06          36.0888       79         0.209057         0.215841      2.16m
#    7    47.69          37.7952       79         0.207623         0.228741      1.95m
#    8    37.95          30.9722       75        0.0910759         0.108298      1.50m
#    9    34.60          32.2924       37         0.089759          0.11905      1.29m
#   10    34.07          68.5569       37        0.0895505         0.120927      1.19m
#   11    34.18          35.3165       37        0.0893921         0.122352      1.04m
#   12    32.96          40.6198       37        0.0913237         0.104968     56.16s
#   13    31.04          35.2074       35         0.087181         0.127727     45.03s
#   14    30.07          50.6036       35        0.0884528         0.116282     37.22s
#   15    29.99          39.0579       41        0.0871162          0.12803     29.85s
#   16    29.63          56.4017       27        0.0842444         0.122909     22.73s
#   17    29.25          42.4318       33        0.0840933          0.11378     14.72s
#   18    28.77          45.8957       27        0.0790633         0.146484      7.62s
#   19    28.35          45.4884       27         0.078028         0.178856      0.00s
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Symbolic Regression Poly:
# 29.8208944411041 - 22.1168461538462*x
# MAE Model:  0.4802163659699698
# MAE Data:  3.5791647436608423
# Computation Time: 0:03:01
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
#%autoreload 2
if interpretation_possible_autoMPG and False:
    metamodeling_hyperparams = {
        'num_iter': 500,
        'batch_size': None,
        'learning_rate': 0.01,        
        'dataset_size': 500,
    }
    
    start = time.time() 

    metamodel_function =  symbolic_metamodeling(model_autoMPG, 
                                              config,
                                              metamodeling_hyperparams,
                                              #printing = True,
                                              return_error = False,
                                              return_expression = 'approx', #'approx', #'exact',
                                              function_metamodeling = False,
                                              force_polynomial=False)
    
    end = time.time()     
    generation_time = (end - start) 
    minutes, seconds = divmod(int(generation_time), 60)
    hours, minutes = divmod(minutes, 60)        
    
    y_metamodel_function = calculate_function_values_from_sympy(metamodel_function, x)
    
    mae_model_metamodel_function = mean_absolute_error(y_model_autoMPG, y_metamodel_function)
    mae_data_metamodel_function = mean_absolute_error(y, y_metamodel_function)
    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('Metamodel Function:')    
    display(metamodel_function)
    print('MAE Model: ', mae_model_metamodel_function)
    print('MAE Data: ', mae_data_metamodel_function)      
    print('Computation Time: ' +  f'{hours:d}:{minutes:02d}:{seconds:02d}')    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')

# %%
if interpretation_possible_autoMPG and False:
    metamodeling_hyperparams = {
        'num_iter': 500,
        'batch_size': None,
        'learning_rate': 0.01,        
        'dataset_size': 500,
    }
    
    start = time.time() 

    metamodel_function_basic =  symbolic_metamodeling(model_autoMPG, 
                                              config,
                                              metamodeling_hyperparams,
                                              #printing = True,
                                              return_error = False,
                                              return_expression = 'approx', #'approx', #'exact',
                                              function_metamodeling = True,
                                              force_polynomial=False)
    
    end = time.time()     
    generation_time = (end - start) 
    minutes, seconds = divmod(int(generation_time), 60)
    hours, minutes = divmod(minutes, 60)        
    
    y_metamodel_function_basic = calculate_function_values_from_sympy(metamodel_function_basic, x)
    
    mae_metamodel_function_basic = mean_absolute_error(y_model_autoMPG, y_metamodel_function_basic)
    mae_metamodel_function_basic = mean_absolute_error(y, y_metamodel_function_basic)
    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('Metamodel Function Basic:')    
    display(metamodel_function_basic)
    print('MAE Model: ', mae_metamodel_function_basic)
    print('MAE Data: ', mae_metamodel_function_basic)      
    print('Computation Time: ' +  f'{hours:d}:{minutes:02d}:{seconds:02d}')    
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')

# %%
if interpretation_possible_autoMPG:
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('Interpretation Net Poly:')
    print_polynomial_from_coefficients(interpretation_net_poly, force_complete_poly_representation=False)
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('Per Network Poly:')
    print_polynomial_from_coefficients(per_network_function, force_complete_poly_representation=False)
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('LSTSQ Poly:')
    print_polynomial_from_coefficients(polynomial_lstsq_pred_autoMPG, force_complete_poly_representation=True)
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('Symbolic Regression Function:')
    display(symbolic_regression_function)
    #print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    #print('Metamodel Function:')
    #display(metamodel_function)
    #print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    #print('Metamodel Function Basic:')
    #display(metamodel_function_basic)
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Interpretation Net Poly:
# 12.3915214538574*a + 7.66886791586876 + 0.315670222043991/a
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Per Network Poly:
# -1.46445035934448*a**2 + 10.7217578887939 + 2.62981057167053/a
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# LSTSQ Poly:
# 1.84012559701005*a**3 - 3.01586898931663*a**2 - 21.4705611123967*a + 30.6646268052821 - 0.0845424493476941/a
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Symbolic Regression Function:
# 29.8208944411041 - 22.1168461538462*x
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
if interpretation_possible_autoMPG:
    fig, ax = plt.subplots(1, 1, figsize=(20,10))
    
    ax.set_ylim([0,50])
    
    plt.scatter(features_autoMPG_model['Horsepower'], labels_autoMPG, label='Data')
    plt.scatter(x, y, label='Test Data')
    plt.plot(np.sort(x, axis=0), np.array([y for _, y in sorted(zip(x, y_model_autoMPG))]) , label='Model Predictions')
    plt.plot(np.sort(x, axis=0), np.array([y for _, y in sorted(zip(x, y_interpretation_net_poly))]) , label='Interpretation Net Poly')
    #plt.plot(np.sort(x, axis=0), np.array([y for _, y in sorted(zip(x, y_per_network_function))]) , label='Per Network Poly')
    plt.plot(np.sort(x, axis=0), np.array([y for _, y in sorted(zip(x, y_polynomial_lstsq_pred_autoMPG))]) , label='LSTSQ Poly')
    plt.plot(np.sort(x, axis=0), np.array([y for _, y in sorted(zip(x, y_symbolic_regression_function))]) , label='Symbolic Regression Function')
    #plt.plot(np.sort(x, axis=0), np.array([y for _, y in sorted(zip(x, y_metamodel_function))]) , label='Metamodel Function')
    #plt.plot(np.sort(x, axis=0), np.array([y for _, y in sorted(zip(x, y))]) y_metamodel_function_basic, label='Metamodel Function Basic')
    plt.xlabel('Horsepower')
    plt.ylabel('MPG')
    plt.legend()

# %%
sample_data_X = np.array([i for i in range(1000)])
sample_data_y = np.array([3*i for i in range(1000)])

# %%
current_seed = 42

# %%
random.seed(current_seed)
np.random.seed(current_seed)
if int(tf.__version__[0]) >= 2:
    tf.random.set_seed(current_seed)
else:
    tf.set_random_seed(current_seed)

# %%
model = keras.models.Sequential()

model.add(Dense(5, input_shape=(1,), activation='relu'))
model.add(Dense(3, activation='relu'))
model.add(Dense(1))

model.compile(loss='mae', optimizer='adam')
          
    
model.summary()
# Out:
# Model: "sequential_205"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_410 (Dense)            (None, 5)                 10
# _________________________________________________________________
# dense_411 (Dense)            (None, 3)                 18
# _________________________________________________________________
# dense_412 (Dense)            (None, 1)                 4
# =================================================================
# Total params: 32
# Trainable params: 32
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(sample_data_X,
         sample_data_y,
         epochs=5000,
         verbose=0)

# %%
model.get_weights()
# Out:
# [array([[ 1.0167775 , -0.11798644, -0.294235  , -0.07103491, -0.9326792 ]],
#        dtype=float32),
#  array([-0.16888502,  0.        ,  0.        ,  0.        ,  0.        ],
#        dtype=float32),
#  array([[ 1.562712  , -0.02688342, -0.01456122],
#         [-0.42922467,  0.40037042,  0.67994815],
#         [ 0.77379066,  0.4318593 , -0.26109576],
#         [ 0.08172262, -0.41291407,  0.3418085 ],
#         [-0.6588274 ,  0.0603506 ,  0.3722121 ]], dtype=float32),
#  array([ 0.17921136,  0.        , -0.65470314], dtype=float32),
#  array([[ 1.8889189 ],
#         [ 0.31487274],
#         [-0.6415678 ]], dtype=float32),
#  array([0.16035195], dtype=float32)]

# %%
model.predict([1, 10])
# Out:
# array([[ 3.0017073],
#        [30.013954 ]], dtype=float32)

# %%
random.seed(current_seed)
np.random.seed(current_seed)
if int(tf.__version__[0]) >= 2:
    tf.random.set_seed(current_seed)
else:
    tf.set_random_seed(current_seed)

# %%
model = keras.models.Sequential()

model.add(Dense(5, input_shape=(1,), activation='relu'))
model.add(Dense(3, activation='relu'))
model.add(Dense(1))

model.compile(loss='mae', optimizer='adam')
          
    
model.summary()
# Out:
# Model: "sequential_206"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_413 (Dense)            (None, 5)                 10
# _________________________________________________________________
# dense_414 (Dense)            (None, 3)                 18
# _________________________________________________________________
# dense_415 (Dense)            (None, 1)                 4
# =================================================================
# Total params: 32
# Trainable params: 32
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(sample_data_X,
         sample_data_y*1000,
         epochs=5000,
         verbose=0)

# %%
model.get_weights()
# Out:
# [array([[13.799208  , -0.11798644, -0.294235  , -0.07103491, -0.9326792 ]],
#        dtype=float32),
#  array([0.0819062, 0.       , 0.       , 0.       , 0.       ],
#        dtype=float32),
#  array([[14.5386095 , -0.02688342, -0.01456132],
#         [-0.42922467,  0.40037042,  0.67994815],
#         [ 0.77379066,  0.4318593 , -0.26109576],
#         [ 0.08172262, -0.41291407,  0.3418085 ],
#         [-0.6588274 ,  0.0603506 ,  0.3722121 ]], dtype=float32),
#  array([-1.0085758 ,  0.        , -0.65470314], dtype=float32),
#  array([[14.952865  ],
#         [ 0.31487274],
#         [-0.6415678 ]], dtype=float32),
#  array([-2.94973], dtype=float32)]

# %%
model.predict([1, 10])
# Out:
# array([[ 2999.6382],
#        [29998.408 ]], dtype=float32)

# %%
model = keras.models.Sequential()

model.add(Dense(5, input_shape=(1,), activation='relu'))
model.add(Dense(3, activation='relu'))
model.add(Dense(1))

model.compile(loss='mae', optimizer='adam')
          
    
model.summary()
# Out:
# Model: "sequential_207"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_416 (Dense)            (None, 5)                 10
# _________________________________________________________________
# dense_417 (Dense)            (None, 3)                 18
# _________________________________________________________________
# dense_418 (Dense)            (None, 1)                 4
# =================================================================
# Total params: 32
# Trainable params: 32
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(sample_data_X,
         sample_data_y,
         epochs=500,
         verbose=0)

# %%
model_2 = keras.models.clone_model(model)

model_2.summary()
# Out:
# Model: "sequential_207"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_416 (Dense)            (None, 5)                 10
# _________________________________________________________________
# dense_417 (Dense)            (None, 3)                 18
# _________________________________________________________________
# dense_418 (Dense)            (None, 1)                 4
# =================================================================
# Total params: 32
# Trainable params: 32
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.get_weights()
# Out:
# [array([[ 1.0263984 , -0.32123613,  0.7346986 , -0.10377216, -0.41428995]],
#        dtype=float32),
#  array([-0.00108473,  0.        ,  0.0154547 ,  0.        ,  0.        ],
#        dtype=float32),
#  array([[ 1.0745947 , -0.00384974, -0.22423065],
#         [ 0.7133753 ,  0.23840302, -0.55062425],
#         [ 0.8624115 , -0.3862218 , -0.7928096 ],
#         [ 0.5926971 ,  0.7038569 , -0.4805471 ],
#         [ 0.72719485,  0.3254363 , -0.12635005]], dtype=float32),
#  array([-0.01405041,  0.        ,  0.        ], dtype=float32),
#  array([[ 1.7258295 ],
#         [-1.1835729 ],
#         [-0.45167738]], dtype=float32),
#  array([-0.00102174], dtype=float32)]

# %%
model.predict([1, 10])
# Out:
# array([[ 2.9927526],
#        [29.966043 ]], dtype=float32)

# %%
model_2_weights = model.get_weights()
model_2_normalized_weights = model_2_weights #[weights/10 for weights in model_2_weights]

# %%
model_2_normalized_weights[-6] = model_2_normalized_weights[-6]/10
model_2_normalized_weights[-5] = model_2_normalized_weights[-5]/10

model_2_normalized_weights[-4] = model_2_normalized_weights[-4]/10
model_2_normalized_weights[-3] = model_2_normalized_weights[-3]/100

model_2_normalized_weights[-2] = model_2_normalized_weights[-2]/10
model_2_normalized_weights[-1] = model_2_normalized_weights[-1]/1000

# %%
#model_2_normalized_weights[-2] = model_2_normalized_weights[-2]/1000
#model_2_normalized_weights[-1] = model_2_normalized_weights[-1]/1000

# %%
model_2.set_weights(model_2_normalized_weights)

# %%
model_2.get_weights()
# Out:
# [array([[ 0.10263984, -0.03212361,  0.07346986, -0.01037722, -0.04142899]],
#        dtype=float32),
#  array([-0.00010847,  0.        ,  0.00154547,  0.        ,  0.        ],
#        dtype=float32),
#  array([[ 0.10745947, -0.00038497, -0.02242306],
#         [ 0.07133753,  0.0238403 , -0.05506242],
#         [ 0.08624115, -0.03862218, -0.07928096],
#         [ 0.05926971,  0.07038569, -0.04805471],
#         [ 0.07271948,  0.03254363, -0.012635  ]], dtype=float32),
#  array([-0.0001405,  0.       ,  0.       ], dtype=float32),
#  array([[ 0.17258295],
#         [-0.11835729],
#         [-0.04516774]], dtype=float32),
#  array([-1.0217431e-06], dtype=float32)]

# %%
model_2.predict([1, 10])
# Out:
# array([[0.00299275],
#        [0.02996604]], dtype=float32)

# %%
    #Plot Polynom, lamdba net, and Interpration net
    length_plt = len(plot_metric_list)
    if length_plt >= 2:
        fig, ax = plt.subplots(length_plt//2, 2, figsize=(30,20))
    else:
        fig, ax = plt.subplots(1, 1, figsize=(20,10))

    for index, metric in enumerate(plot_metric_list):
        
        plot_scores_dict = {}
        for key in evaluation_key_list:
            try:
                scores_list[-1][metric].loc[key]
                plot_scores_dict[key] = []
            except:
                #print(key + 'not in scores_list')
                continue
            
        
        for scores in scores_list:
            for key in evaluation_key_list:
                try:
                    plot_scores_dict[key].append(scores[metric].loc[key])
                except:
                    #print(key + 'not in scores_list')
                    continue
                                        
            
        plot_df = pd.DataFrame(data=np.vstack(plot_scores_dict.values()).T, 
                               index=x_axis_steps,
                               columns=plot_scores_dict.keys())

        if length_plt >= 2:
            ax[index//2, index%2].set_title(metric)
            sns.set(font_scale = 1.25)
            p = sns.lineplot(data=plot_df, ax=ax[index//2, index%2])
        else:
            ax.set_title(metric)
            sns.set(font_scale = 1.25)
            p = sns.lineplot(data=plot_df, ax=ax)

        if ylim != None:
            p.set(ylim=ylim)

        p.set_yticklabels(np.round(p.get_yticks(), 2), size = 20)
        p.set_xticklabels(p.get_xticks(), size = 20)     
        
        #p.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
        p.legend(loc='upper center', bbox_to_anchor=(0.47, -0.1),
          fancybox=False, shadow=False, ncol=2, fontsize=12)   
        
    plt.subplots_adjust(wspace=0.1, hspace=0.75)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-101-907b5cbea90a> in <module>
#       1 #Plot Polynom, lamdba net, and Interpration net
# ----> 2 length_plt = len(plot_metric_list)
#       3 if length_plt >= 2:
#       4     fig, ax = plt.subplots(length_plt//2, 2, figsize=(30,20))
#       5 else:
#
# NameError: name 'plot_metric_list' is not defined

# %% [markdown]
# # Evaluate Per-Network Poly Optimization

# %% [markdown]
# ## Example Optimization (Common Optimizer)

# %%
random_index = RANDOM_SEED

per_network_hyperparams = {
    'optimizer':  'Powell',
    'jac': 'fprime',
    'max_steps': 5000,#100,
    'restarts': 3,
    'per_network_dataset_size': 500,
}

lambda_net_test_dataset = lambda_net_test_dataset_list[-1]
lambda_network_weights_list = np.array(lambda_net_test_dataset.weight_list)
lambda_network_weights = lambda_network_weights_list[random_index]

list_of_monomial_identifiers_numbers = np.array([list(monomial_identifiers) for monomial_identifiers in list_of_monomial_identifiers]).astype(float)  

printing = True

config = {
         'n': n,
         'inet_loss': inet_loss,
         'sparsity': sparsity,
         'lambda_network_layers': lambda_network_layers,
         'interpretation_net_output_shape': interpretation_net_output_shape,
         'RANDOM_SEED': RANDOM_SEED,
         'nas': nas,
         'number_of_lambda_weights': number_of_lambda_weights,
         'interpretation_net_output_monomials': interpretation_net_output_monomials,
         'x_min': x_min,
         'x_max': x_max,
         }


per_network_optimization_error, per_network_optimization_polynomial = per_network_poly_optimization_scipy(per_network_hyperparams['per_network_dataset_size'], 
                                                                                                      lambda_network_weights, 
                                                                                                      list_of_monomial_identifiers_numbers, 
                                                                                                      config,
                                                                                                      optimizer = per_network_hyperparams['optimizer'],
                                                                                                      jac = per_network_hyperparams['jac'],
                                                                                                      max_steps = per_network_hyperparams['max_steps'], 
                                                                                                      restarts = per_network_hyperparams['restarts'],
                                                                                                      printing = True,
                                                                                                      return_error = True)

print('\n\nError: ' + str(per_network_optimization_error))
print_polynomial_from_coefficients(per_network_optimization_polynomial)

# %% [markdown]
# ## Example Optimization (Neural Optimizer)

# %%
random_index = RANDOM_SEED

per_network_hyperparams = {
    'optimizer': tf.keras.optimizers.RMSprop,
    'lr': 0.02,
    'max_steps': 500,
    'early_stopping': 10,
    'restarts': 3,
    'per_network_dataset_size': 5000,
}

lambda_net_test_dataset = lambda_net_test_dataset_list[-1]
lambda_network_weights_list = np.array(lambda_net_test_dataset.weight_list)
lambda_network_weights = lambda_network_weights_list[random_index]

list_of_monomial_identifiers_numbers = np.array([list(monomial_identifiers) for monomial_identifiers in list_of_monomial_identifiers]).astype(float)  

printing = True

config = {
         'n': n,
         'inet_loss': inet_loss,
         'sparsity': sparsity,
         'lambda_network_layers': lambda_network_layers,
         'interpretation_net_output_shape': interpretation_net_output_shape,
         'RANDOM_SEED': RANDOM_SEED,
         'nas': nas,
         'number_of_lambda_weights': number_of_lambda_weights,
         'interpretation_net_output_monomials': interpretation_net_output_monomials,
         'x_min': x_min,
         'x_max': x_max,
         }


per_network_optimization_error, per_network_optimization_polynomial = per_network_poly_optimization_tf(per_network_hyperparams['per_network_dataset_size'], 
                                                                                                      lambda_network_weights, 
                                                                                                      list_of_monomial_identifiers_numbers, 
                                                                                                      config,
                                                                                                      optimizer = per_network_hyperparams['optimizer'],
                                                                                                      lr = per_network_hyperparams['lr'], 
                                                                                                      max_steps = per_network_hyperparams['max_steps'], 
                                                                                                      early_stopping = per_network_hyperparams['early_stopping'], 
                                                                                                      restarts = per_network_hyperparams['restarts'],
                                                                                                      printing = True,
                                                                                                      return_error = True)

print('\n\nError: ' + str(per_network_optimization_error.numpy()))
print_polynomial_from_coefficients(per_network_optimization_polynomial)

# %% [markdown]
# ## Grid Search Common Optimizers

# %%
# %%script false --no-raise-error
#
# pd.set_option('max_colwidth', 100)
#
# evaluation_size = 10
#
# per_network_hyperparams = {
#     'optimizer':  [
#                    'Nelder-Mead',
#                    'Powell',
#
#                    'CG',
#                    'BFGS',
#                    'Newton-CG',
#                    #'L-BFGS-B', #'>' not supported between instances of 'int' and 'NoneType'
#                    'TNC',
#
#                    'COBYLA',
#                    'SLSQP',
#
#                    #'trust-constr', # TypeError: _minimize_trustregion_constr() got an unexpected keyword argument 'maxfun'
#                    #'dogleg', # ValueError: Hessian is required for dogleg minimization
#                    #'trust-ncg', #ValueError: Either the Hessian or the Hessian-vector product is required for Newton-CG trust-region minimization
#                    #'trust-exact', # ValueError: Hessian matrix is required for trust region exact minimization.
#                    #'trust-krylov' #ValueError: Either the Hessian or the Hessian-vector product is required for Krylov trust-region minimization
#                    ],
#     'jac': ['fprime'],
#     'max_steps': [5000],#100,
#     'restarts': [3],
#     'per_network_dataset_size': [500],
# }
#
# #param_iterator = ParameterSampler(per_network_hyperparams, n_iter=60, random_state=RANDOM_SEED)
# param_iterator = ParameterGrid(per_network_hyperparams)
#
#
# lambda_net_test_dataset = lambda_net_test_dataset_list[-1]
# lambda_network_weights_list = np.array(lambda_net_test_dataset.weight_list)
#
# list_of_monomial_identifiers_numbers = np.array([list(monomial_identifiers) for monomial_identifiers in list_of_monomial_identifiers]).astype(float)
# printing = True if n_jobs == 1 else False
#
# config = {
#          'n': n,
#          'inet_loss': inet_loss,
#          'sparsity': sparsity,
#          'lambda_network_layers': lambda_network_layers,
#          'interpretation_net_output_shape': interpretation_net_output_shape,
#          'RANDOM_SEED': RANDOM_SEED,
#          'nas': nas,
#          'number_of_lambda_weights': number_of_lambda_weights,
#          'interpretation_net_output_monomials': interpretation_net_output_monomials,
#          'x_min': x_min,
#          'x_max': x_max,
#          }

# %%
# %%script false --no-raise-error
#
# params_error_list = []
# for params in tqdm(param_iterator):
#     parallel_per_network = Parallel(n_jobs=n_jobs, verbose=0, backend='loky')
#
#     result_list = parallel_per_network(delayed(per_network_poly_optimization_scipy)(params['per_network_dataset_size'],
#                                                                                   lambda_network_weights,
#                                                                                   list_of_monomial_identifiers_numbers,
#                                                                                   config,
#                                                                                   optimizer = params['optimizer'],
#                                                                                   jac = params['jac'],
#                                                                                   max_steps = params['max_steps'],
#                                                                                   restarts = params['restarts'],
#                                                                                   printing = printing,
#                                                                                   return_error = True) for lambda_network_weights in lambda_network_weights_list[:evaluation_size])
#
#
#     per_network_optimization_errors = [result[0] for result in result_list]
#     per_network_optimization_polynomials = [result[1] for result in result_list]
#
#     params_score = np.mean(per_network_optimization_errors)
#
#     evaluation_result = list(params.values())
#     evaluation_result.append(params_score)
#
#     params_error_list.append(evaluation_result)
#
#     del parallel_per_network
#
# columns = list(params.keys())
# columns.append('score')
# params_error_df = pd.DataFrame(data=params_error_list, columns=columns).sort_values(by='score')
# params_error_df.head(10)

# %% [markdown]
# ## Grid Search Neural Optimizers

# %%
# %%script false --no-raise-error
#
# pd.set_option('max_colwidth', 100)
#
# evaluation_size = 100
#
# per_network_hyperparams = {
#     'optimizer': [tf.keras.optimizers.RMSprop], #[tf.keras.optimizers.SGD, tf.optimizers.Adam, tf.keras.optimizers.RMSprop, tf.keras.optimizers.Adadelta]
#     'lr': [0.02], #[0.5, 0.25, 0.1, 0.05, 0.025]
#     'max_steps': [5000],#100,
#     'early_stopping': [10],
#     'restarts': [3],
#     'per_network_dataset_size': [5000],
# }
#
# #param_iterator = ParameterSampler(per_network_hyperparams, n_iter=60, random_state=RANDOM_SEED)
# param_iterator = ParameterGrid(per_network_hyperparams)
#
#
# lambda_net_test_dataset = lambda_net_test_dataset_list[-1]
# lambda_network_weights_list = np.array(lambda_net_test_dataset.weight_list)
#
# list_of_monomial_identifiers_numbers = np.array([list(monomial_identifiers) for monomial_identifiers in list_of_monomial_identifiers]).astype(float)
# printing = True if n_jobs == 1 else False
#
# config = {
#          'n': n,
#          'inet_loss': inet_loss,
#          'sparsity': sparsity,
#          'lambda_network_layers': lambda_network_layers,
#          'interpretation_net_output_shape': interpretation_net_output_shape,
#          'RANDOM_SEED': RANDOM_SEED,
#          'nas': nas,
#          'number_of_lambda_weights': number_of_lambda_weights,
#          'interpretation_net_output_monomials': interpretation_net_output_monomials,
#          'x_min': x_min,
#          'x_max': x_max,
#          }

# %%
# %%script false --no-raise-error
#
# params_error_list = []
# for params in tqdm(param_iterator):
#     parallel_per_network = Parallel(n_jobs=n_jobs, verbose=0, backend='loky')
#
#     result_list = parallel_per_network(delayed(per_network_poly_optimization_tf)(params['per_network_dataset_size'],
#                                                                                   lambda_network_weights,
#                                                                                   list_of_monomial_identifiers_numbers,
#                                                                                   config,
#                                                                                   optimizer = params['optimizer'],
#                                                                                   lr = params['lr'],
#                                                                                   max_steps = params['max_steps'],
#                                                                                   early_stopping = params['early_stopping'],
#                                                                                   restarts = params['restarts'],
#                                                                                   printing = printing,
#                                                                                   return_error = True) for lambda_network_weights in lambda_network_weights_list[:evaluation_size])
#
#
#     per_network_optimization_errors = [result[0] for result in result_list]
#     per_network_optimization_polynomials = [result[1] for result in result_list]
#
#     params_score = np.mean(per_network_optimization_errors)
#
#     evaluation_result = list(params.values())
#     evaluation_result.append(params_score)
#
#     params_error_list.append(evaluation_result)
#
#     del parallel_per_network
#
# columns = list(params.keys())
# columns.append('score')
# params_error_df = pd.DataFrame(data=params_error_list, columns=columns).sort_values(by='score')
# params_error_df.head(10)

# %%
if use_gpu:
    from numba import cuda 
    device = cuda.get_current_device()
    device.reset()
